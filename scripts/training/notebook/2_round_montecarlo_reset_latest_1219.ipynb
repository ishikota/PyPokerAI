# %% [markdown]
# # 実験1 とりあえず走らせてみて観察
# ## 2-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 50万x2=100万
# - 5万iteration毎に敵のvalue_functionを最新(agentと同じ重み)に更新しながらself-play
# - 計算時間 : 58075s + 40659s => 16.1h + 11.3h

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# ### 0~50万

# %% [markdown]
# <img src="./resource/2round_montecarlo_first_run_1216_11_33_55/initial_value_transition.png" width=500/>

# %% [markdown]
# ### 50万~100万

# %% [markdown]
# <img src="./resource/2round_montecarlo_load_from_500000_1217_22_19_58/initial_value_transition.png" width=500/>

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# ### 0~50万

# %% [markdown]
# <img src="./resource/2round_montecarlo_first_run_1216_11_33_55/2_round_1000_match_subplot_1218_13_56_26.png"/>

# %% [markdown]
# ### 50万~100万

# %% [markdown]
# <img src="./resource/2round_montecarlo_load_from_500000_1217_22_19_58/2_round_3000_match_subplot_1219_15_44_21.png" />

# %% [markdown]
# ### 0~100万

# %% [markdown]
# <img src="./resource/2round_montecarlo_summary/2_round_3000_match_subplot_1218_13_16_19.png" />

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# ### 50万iteration後のvalue function10人で対戦
# big blindの次で必ずallin.他のplayerはそれに対して必ずfoldで決着.

# %% [markdown]
# ### DOUBLE RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 1700
#   - raise: [2900, 18225]
# -- hole card --
#   - ['HJ', 'DJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 2425, side = []
#   - players information
#     - 0 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 1 : cpu8 (uuid-8) => state : participating, stack : 9975
#     - 2 : cpu5 (uuid-5) => state : participating, stack : 9925 <= SB
#     - 3 : cpu3 (uuid-3) => state : participating, stack : 9950 <= BB
#     - 4 : cpu2 (uuid-2) => state : folded, stack : 9850
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9350
#     - 6 : cpu4 (uuid-4) => state : participating, stack : 7800
#     - 7 : cpu9 (uuid-9) => state : participating, stack : 8300
#     - 8 : cpu1 (uuid-1) => state : folded, stack : 4200
#     - 9 : agent (uuid-0) => state : participating, stack : 18225 <= CURRENT
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 500, 'action': 'RAISE'}
#       - {'add_amount': 1200, 'paid': 1700, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 1700, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
# ======================================================================
# Agent took action [ raise: 5800 (double_raise) ] at round 2
#   => [('fold', 0.43208372592926025), ('call', -0.9678030014038086), ('min_raise', -0.2390192747116089), ('double_raise', 0.7468974590301514), ('triple_raise', 0.30198824405670166), ('max_raise', 0.1022915244102478)]
# ** weights and features in detail **
# bias : [-1.4178803  -1.45636129 -1.84081948 -1.6855011  -1.6358695  -0.65171939]
#
# linear combination for fold :
#     (-1.6036138534545898, 1, -1.6036138534545898, 'round level 2')
#     (-1.4178803, 0, 0, 'bias')
#     (-1.39131760597229, 1, -1.39131760597229, 'player-0:state-active')
#     (1.2994141578674316, 1, 1.2994141578674316, 'player-5:state-fold')
#     (1.0975725650787354, 1, 1.0975725650787354, 'player-6:state-active')
#     (0.9571974277496338, 1, 0.9571974277496338, 'player-4:state-active')
#     (-0.9237383008003235, 1, -0.9237383008003235, 'player-7:state-active')
#     (0.7665530443191528, 1, 0.7665530443191528, 'player-3:state-active')
#     (0.5988581450944094, 0.7010309278350515, 0.8542535305023193, 'player-8:history')
#     (0.57443767786026, 1, 0.57443767786026, 'player-8:state-active')
#     (0.5158258676528931, 1, 0.5158258676528931, 'player-2:state-active')
#     (0.43394148349761963, 1, 0.43394148349761963, 'player-9:state-fold')
#     (0.3970932960510254, 1, 0.3970932960510254, 'player-1:state-active')
#     (-0.21979893743991852, 1, -0.21979893743991852, 'street-preflop')
#     (0.17825857880189247, 0.20618556701030927, 0.8645541071891785, 'player-7:history')
#     (-0.13483219701051713, 0.0935, -1.442055583000183, 'player-6:stack')
#     (-0.13117964470386506, 0.0985, -1.331773042678833, 'player-5:stack')
#     (-0.10160433053970337, 0.1, -1.0160433053970337, 'player-1:stack')
#     (-0.0896229522228241, 0.078, -1.1490122079849243, 'player-7:stack')
#     (-0.08922403334081173, 0.09925, -0.8989827036857605, 'player-3:stack')
#     (-0.08336744838953018, 0.0995, -0.8378638029098511, 'player-4:stack')
#     (-0.07634796550869942, 0.09975, -0.7653931379318237, 'player-2:stack')
#     (-0.0738867005109787, 0.083, -0.890201210975647, 'player-8:stack')
#     (0.06211766016851995, 0.061855670103092786, 1.0042355060577393, 'player-6:history')
#     (-0.05282701924443245, 1, -0.05282701924443245, 'btn distance=8')
#     (-0.03774396300315857, 0.042, -0.8986657857894897, 'player-9:stack')
#     (-0.03305872330069542, 0.02425, -1.3632463216781616, 'pot')
#     (-0.02679494035989046, 0.18225, -0.14702299237251282, 'player-0:stack')
#     (0.014134011872112752, 0.796, 0.017756296321749687, 'cards')
#     (0.014110240739645417, 0.020618556701030927, 0.6843466758728027, 'player-4:history')
#     (0.009408577201292687, 0.010309278350515464, 0.9126319885253906, 'player-3:history')
#     (0.0, 0.0, 0.901857852935791, 'player-9:history')
#     (0.0, 0, 0.3955329656600952, 'player-9:state-active')
#     (0.0, 0, 0.5259191989898682, 'player-8:state-fold')
#     (-0.0, 0, -1.1010795831680298, 'player-7:state-fold')
#     (0.0, 0, 1.1583092212677002, 'player-6:state-fold')
#     (0.0, 0.0, 1.2162835597991943, 'player-5:history')
#     (0.0, 0, 1.1927926540374756, 'player-5:state-active')
#     (0.0, 0, 0.9590729475021362, 'player-4:state-fold')
#     (0.0, 0, 0.8350928425788879, 'player-3:state-fold')
#     (0.0, 0.0, 0.7212132215499878, 'player-2:history')
#     (0.0, 0, 0.48248523473739624, 'player-2:state-fold')
#     (0.0, 0.0, 0.8106897473335266, 'player-1:history')
#     (0.0, 0, 0.3462808132171631, 'player-1:state-fold')
#     (0.0, 0.0, 1.4909923076629639, 'player-0:history')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.06423696130514145, 'street-river')
#     (-0.0, 0, -0.07568676769733429, 'street-turn')
#     (-0.0, 0, -0.37015533447265625, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.20629911124706268, 'btn distance=6')
#     (-0.0, 0, -0.224297434091568, 'btn distance=5')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-1.5606324672698975, 1, -1.5606324672698975, 'player-0:state-active')
#     (-1.4563613, 0, 0, 'bias')
#     (-1.3921525478363037, 1, -1.3921525478363037, 'round level 2')
#     (0.7527860999107361, 1, 0.7527860999107361, 'player-8:state-active')
#     (0.6535208821296692, 1, 0.6535208821296692, 'player-7:state-active')
#     (0.5804115533828735, 1, 0.5804115533828735, 'player-9:state-fold')
#     (0.46976761719615184, 0.7010309278350515, 0.6701096892356873, 'player-8:history')
#     (0.45938295125961304, 1, 0.45938295125961304, 'player-4:state-active')
#     (0.268941730260849, 1, 0.268941730260849, 'street-preflop')
#     (0.261310875415802, 1, 0.261310875415802, 'player-2:state-active')
#     (0.23353859321358275, 0.20618556701030927, 1.1326621770858765, 'player-7:history')
#     (-0.19617345929145813, 1, -0.19617345929145813, 'btn distance=8')
#     (0.12657607385516167, 0.18225, 0.6945189237594604, 'player-0:stack')
#     (-0.11012765020132065, 1, -0.11012765020132065, 'player-3:state-active')
#     (0.10197724755277339, 0.061855670103092786, 1.6486321687698364, 'player-6:history')
#     (-0.08210933429002762, 0.0985, -0.8335973024368286, 'player-5:stack')
#     (-0.06378527781367302, 0.0935, -0.6821954846382141, 'player-6:stack')
#     (-0.053323414832353595, 0.09975, -0.534570574760437, 'player-2:stack')
#     (0.051786798238754275, 0.1, 0.5178679823875427, 'player-1:stack')
#     (-0.04218589890003204, 0.078, -0.5408448576927185, 'player-7:stack')
#     (-0.0362560627758503, 0.02425, -1.4950953722000122, 'pot')
#     (-0.03405972570180893, 1, -0.03405972570180893, 'player-5:state-fold')
#     (0.0315157462656498, 0.0995, 0.3167411684989929, 'player-4:stack')
#     (0.029568467289209366, 1, 0.029568467289209366, 'player-6:state-active')
#     (0.029283292591571808, 1, 0.029283292591571808, 'player-1:state-active')
#     (0.022533775604877276, 0.020618556701030927, 1.0928881168365479, 'player-4:history')
#     (-0.01539282785356045, 0.09925, -0.15509146451950073, 'player-3:stack')
#     (0.011926601842506645, 0.010309278350515464, 1.1568803787231445, 'player-3:history')
#     (-0.008564776718616485, 0.042, -0.20392325520515442, 'player-9:stack')
#     (-0.004442621756345034, 0.083, -0.05352556332945824, 'player-8:stack')
#     (0.0029363696156069637, 0.796, 0.003688906552270055, 'cards')
#     (0.0, 0.0, 0.8021431565284729, 'player-9:history')
#     (0.0, 0, 0.5328446626663208, 'player-9:state-active')
#     (0.0, 0, 0.3526769280433655, 'player-8:state-fold')
#     (0.0, 0, 0.31508174538612366, 'player-7:state-fold')
#     (0.0, 0, 0.04104764759540558, 'player-6:state-fold')
#     (0.0, 0.0, 1.946606159210205, 'player-5:history')
#     (-0.0, 0, -0.11219464987516403, 'player-5:state-active')
#     (0.0, 0, 0.7162779569625854, 'player-4:state-fold')
#     (-0.0, 0, -0.160588338971138, 'player-3:state-fold')
#     (0.0, 0.0, 0.8823971748352051, 'player-2:history')
#     (0.0, 0, 0.16398480534553528, 'player-2:state-fold')
#     (0.0, 0.0, 1.590529441833496, 'player-1:history')
#     (0.0, 0, 0.21514472365379333, 'player-1:state-fold')
#     (0.0, 0.0, 2.6005444526672363, 'player-0:history')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (-0.0, 0, -0.2850165069103241, 'street-river')
#     (-0.0, 0, -0.07254668325185776, 'street-turn')
#     (-0.0, 0, -0.17641568183898926, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 0.8125324249267578, 'btn distance=6')
#     (0.0, 0, 0.9285439848899841, 'btn distance=5')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.0189969539642334, 1, -2.0189969539642334, 'round level 2')
#     (-1.8873168230056763, 1, -1.8873168230056763, 'player-0:state-active')
#     (-1.8408195, 0, 0, 'bias')
#     (1.4327375888824463, 1, 1.4327375888824463, 'player-8:state-active')
#     (1.3117984533309937, 1, 1.3117984533309937, 'player-9:state-fold')
#     (1.0681812763214111, 1, 1.0681812763214111, 'player-7:state-active')
#     (0.9267115101371843, 0.7010309278350515, 1.3219267129898071, 'player-8:history')
#     (0.5238251090049744, 1, 0.5238251090049744, 'player-5:state-fold')
#     (0.4657408595085144, 1, 0.4657408595085144, 'player-1:state-active')
#     (0.3027276648688562, 0.20618556701030927, 1.4682291746139526, 'player-7:history')
#     (0.181107759475708, 1, 0.181107759475708, 'player-2:state-active')
#     (-0.17494592809677123, 0.0935, -1.871079444885254, 'player-6:stack')
#     (-0.12966528761386872, 0.0985, -1.3163988590240479, 'player-5:stack')
#     (0.11686373502016068, 1, 0.11686373502016068, 'player-6:state-active')
#     (-0.11313341546058656, 0.09975, -1.134169578552246, 'player-2:stack')
#     (-0.10129671132564545, 0.09925, -1.0206217765808105, 'player-3:stack')
#     (0.09802182433531456, 0.061855670103092786, 1.5846861600875854, 'player-6:history')
#     (-0.09366194915771485, 0.078, -1.2007942199707031, 'player-7:stack')
#     (-0.07531900471448899, 0.083, -0.9074578881263733, 'player-8:stack')
#     (-0.06900055572390557, 0.0995, -0.6934729218482971, 'player-4:stack')
#     (-0.056135100126266484, 0.1, -0.5613510012626648, 'player-1:stack')
#     (-0.047159694135189056, 1, -0.047159694135189056, 'btn distance=8')
#     (-0.03763818368315697, 0.02425, -1.552090048789978, 'pot')
#     (-0.03449150174856186, 1, -0.03449150174856186, 'street-preflop')
#     (-0.0334225047826767, 0.042, -0.7957739233970642, 'player-9:stack')
#     (0.024704503029892126, 0.020618556701030927, 1.198168396949768, 'player-4:history')
#     (-0.022928380463272332, 0.18225, -0.12580730020999908, 'player-0:stack')
#     (0.02177312597632408, 1, 0.02177312597632408, 'player-4:state-active')
#     (0.012376614452637347, 0.010309278350515464, 1.2005316019058228, 'player-3:history')
#     (0.012104667723178864, 1, 0.012104667723178864, 'player-3:state-active')
#     (-0.0017630741028115155, 0.796, -0.002214917214587331, 'cards')
#     (0.0, 0.0, 1.2501732110977173, 'player-9:history')
#     (0.0, 0, 1.3076800107955933, 'player-9:state-active')
#     (0.0, 0, 0.9296978116035461, 'player-8:state-fold')
#     (0.0, 0, 0.5567418336868286, 'player-7:state-fold')
#     (0.0, 0, 0.273332804441452, 'player-6:state-fold')
#     (0.0, 0.0, 2.969327449798584, 'player-5:history')
#     (0.0, 0, 0.2067711055278778, 'player-5:state-active')
#     (0.0, 0, 0.1382988840341568, 'player-4:state-fold')
#     (-0.0, 0, -0.2806473970413208, 'player-3:state-fold')
#     (0.0, 0.0, 0.4781334698200226, 'player-2:history')
#     (0.0, 0, 0.6119090914726257, 'player-2:state-fold')
#     (0.0, 0.0, 1.5168819427490234, 'player-1:history')
#     (0.0, 0, 0.5179490447044373, 'player-1:state-fold')
#     (0.0, 0.0, 0.9410321116447449, 'player-0:history')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.09289492666721344, 'street-river')
#     (0.0, 0, 0.08158420771360397, 'street-turn')
#     (-0.0, 0, -0.008587334305047989, 'street-flop')
#     (-0.0, 0, -0.1774212121963501, 'btn distance=9')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 0.8966071605682373, 'btn distance=6')
#     (0.0, 0, 0.9084417223930359, 'btn distance=5')
#     (0.0, 0, 0.5843061804771423, 'btn distance=4')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for double_raise :
#     (-1.890042781829834, 1, -1.890042781829834, 'player-0:state-active')
#     (-1.6855011, 0, 0, 'bias')
#     (1.579129934310913, 1, 1.579129934310913, 'player-7:state-active')
#     (-1.493640422821045, 1, -1.493640422821045, 'round level 2')
#     (1.4171169996261597, 1, 1.4171169996261597, 'player-8:state-active')
#     (1.0924323858674039, 0.7010309278350515, 1.5583226680755615, 'player-8:history')
#     (0.6326179504394531, 1, 0.6326179504394531, 'player-9:state-fold')
#     (0.6208521127700806, 1, 0.6208521127700806, 'player-2:state-active')
#     (0.6132532954216003, 1, 0.6132532954216003, 'player-5:state-fold')
#     (0.3246434693483962, 0.20618556701030927, 1.5745208263397217, 'player-7:history')
#     (0.3113657534122467, 1, 0.3113657534122467, 'player-3:state-active')
#     (0.22094464302062988, 1, 0.22094464302062988, 'player-1:state-active')
#     (-0.17136875343322755, 0.0935, -1.8328208923339844, 'player-6:stack')
#     (-0.16994917392730713, 1, -0.16994917392730713, 'btn distance=8')
#     (-0.1614345653951168, 0.09975, -1.6183916330337524, 'player-2:stack')
#     (-0.12263333415985107, 0.0985, -1.2450084686279297, 'player-5:stack')
#     (0.11845963448286057, 1, 0.11845963448286057, 'player-4:state-active')
#     (-0.09981744933128357, 0.078, -1.2797108888626099, 'player-7:stack')
#     (-0.0964425727725029, 1, -0.0964425727725029, 'street-preflop')
#     (-0.08499118211865425, 0.09925, -0.8563343286514282, 'player-3:stack')
#     (0.06648856585787744, 0.061855670103092786, 1.0748984813690186, 'player-6:history')
#     (-0.06544606673717498, 0.0995, -0.6577494144439697, 'player-4:stack')
#     (-0.053348499417305, 0.083, -0.642753005027771, 'player-8:stack')
#     (-0.04984709918498993, 0.1, -0.4984709918498993, 'player-1:stack')
#     (-0.04696066677570343, 1, -0.04696066677570343, 'player-6:state-active')
#     (-0.03760358762741089, 0.042, -0.8953235149383545, 'player-9:stack')
#     (-0.03106159072369337, 0.18225, -0.17043396830558777, 'player-0:stack')
#     (-0.028182753860950472, 0.02425, -1.1621754169464111, 'pot')
#     (0.016312540191965003, 0.020618556701030927, 0.7911581993103027, 'player-4:history')
#     (0.012511365192452656, 0.010309278350515464, 1.2136024236679077, 'player-3:history')
#     (0.00904060946404934, 0.796, 0.011357549577951431, 'cards')
#     (0.0, 0.0, 1.2206922769546509, 'player-9:history')
#     (0.0, 0, 0.9602558016777039, 'player-9:state-active')
#     (0.0, 0, 0.8128073215484619, 'player-8:state-fold')
#     (0.0, 0, 1.004594087600708, 'player-7:state-fold')
#     (-0.0, 0, -0.019796406850218773, 'player-6:state-fold')
#     (0.0, 0.0, 2.685377597808838, 'player-5:history')
#     (-0.0, 0, -0.3400891423225403, 'player-5:state-active')
#     (0.0, 0, 0.13921548426151276, 'player-4:state-fold')
#     (-0.0, 0, -0.37810608744621277, 'player-3:state-fold')
#     (0.0, 0.0, 0.5778486728668213, 'player-2:history')
#     (0.0, 0, 0.3839629590511322, 'player-2:state-fold')
#     (0.0, 0.0, 1.0377970933914185, 'player-1:history')
#     (0.0, 0, 0.08879715204238892, 'player-1:state-fold')
#     (0.0, 0.0, 0.6625462770462036, 'player-0:history')
#     (0.0, 0, 0.1994665414094925, 'player-0:state-fold')
#     (0.0, 0, 0.12679634988307953, 'street-river')
#     (0.0, 0, 0.17079395055770874, 'street-turn')
#     (0.0, 0, 0.038072943687438965, 'street-flop')
#     (0.0, 0, 0.16180437803268433, 'btn distance=9')
#     (-0.0, 0, -0.2551056444644928, 'btn distance=7')
#     (0.0, 0, 1.3056889772415161, 'btn distance=6')
#     (0.0, 0, 0.9235722422599792, 'btn distance=5')
#     (0.0, 0, 0.2912150025367737, 'btn distance=4')
#     (-0.0, 0, -0.07808863371610641, 'btn distance=3')
#     (0.0, 0, 0.07531379163265228, 'btn distance=2')
#     (-0.0, 0, -0.04036684334278107, 'btn distance=1')
#     (-0.0, 0, -0.241798534989357, 'btn distance=0')
#     (-0.0, 0, -0.012274674139916897, 'round level 27')
#     (-0.0, 0, -0.1700371652841568, 'round level 26')
#     (-0.0, 0, -0.06231385096907616, 'round level 25')
#     (-0.0, 0, -0.19142040610313416, 'round level 24')
#     (0.0, 0, 0.0052865338511765, 'round level 23')
#     (0.0, 0, 0.10509058088064194, 'round level 22')
#     (0.0, 0, 0.148484006524086, 'round level 21')
#     (-0.0, 0, -0.2335253208875656, 'round level 20')
#     (0.0, 0, 0.024247899651527405, 'round level 19')
#     (0.0, 0, 0.24292117357254028, 'round level 18')
#     (0.0, 0, 0.059873905032873154, 'round level 17')
#     (0.0, 0, 0.13325431942939758, 'round level 16')
#     (0.0, 0, 0.12490264326334, 'round level 15')
#     (0.0, 0, 0.17109589278697968, 'round level 14')
#     (-0.0, 0, -0.23500089347362518, 'round level 13')
#     (0.0, 0, 0.1816813349723816, 'round level 12')
#     (-0.0, 0, -0.14072857797145844, 'round level 11')
#     (-0.0, 0, -0.02639414370059967, 'round level 10')
#     (-0.0, 0, -0.12533557415008545, 'round level 9')
#     (0.0, 0, 0.21444687247276306, 'round level 8')
#     (0.0, 0, 0.2577686905860901, 'round level 7')
#     (-0.0, 0, -0.020569249987602234, 'round level 6')
#     (-0.0, 0, -0.08953545987606049, 'round level 5')
#     (-0.0, 0, -0.13333763182163239, 'round level 4')
#     (-0.0, 0, -0.00587732857093215, 'round level 3')
#     (0.0, 0, 0.05715208500623703, 'round level 1')
#
# linear combination for triple_raise :
#     (-1.8290526866912842, 1, -1.8290526866912842, 'round level 2')
#     (1.6622405052185059, 1, 1.6622405052185059, 'player-8:state-active')
#     (-1.6358695, 0, 0, 'bias')
#     (-1.506331443786621, 1, -1.506331443786621, 'player-0:state-active')
#     (1.287436604499817, 1, 1.287436604499817, 'player-7:state-active')
#     (1.0987898443163056, 0.7010309278350515, 1.5673913955688477, 'player-8:history')
#     (0.9787710309028625, 1, 0.9787710309028625, 'player-5:state-fold')
#     (0.7214456796646118, 1, 0.7214456796646118, 'player-9:state-fold')
#     (-0.5476931929588318, 1, -0.5476931929588318, 'street-preflop')
#     (0.3521125832783807, 0.20618556701030927, 1.7077460289001465, 'player-7:history')
#     (0.28875961899757385, 1, 0.28875961899757385, 'player-2:state-active')
#     (0.20302264392375946, 1, 0.20302264392375946, 'player-1:state-active')
#     (-0.15855892235040664, 0.0935, -1.6958173513412476, 'player-6:stack')
#     (0.14650724828243256, 1, 0.14650724828243256, 'player-3:state-active')
#     (-0.13042927658557893, 0.0985, -1.3241550922393799, 'player-5:stack')
#     (-0.11413408070802689, 1, -0.11413408070802689, 'btn distance=8')
#     (-0.11396698343753815, 0.09975, -1.1425261497497559, 'player-2:stack')
#     (-0.1137312650680542, 0.1, -1.137312650680542, 'player-1:stack')
#     (0.11046312749385834, 1, 0.11046312749385834, 'player-4:state-active')
#     (-0.10848474311828614, 0.078, -1.3908300399780273, 'player-7:stack')
#     (-0.10305163550376893, 0.083, -1.2415859699249268, 'player-8:stack')
#     (-0.09719484688341617, 0.09925, -0.979293167591095, 'player-3:stack')
#     (-0.08869998547434807, 0.0995, -0.8914571404457092, 'player-4:stack')
#     (0.07758700478937208, 0.061855670103092786, 1.2543232440948486, 'player-6:history')
#     (-0.062071921646595, 0.02425, -2.559666872024536, 'pot')
#     (-0.03722002494335175, 0.042, -0.8861910700798035, 'player-9:stack')
#     (-0.025857318710535763, 0.18225, -0.14187829196453094, 'player-0:stack')
#     (0.019619829952716827, 1, 0.019619829952716827, 'player-6:state-active')
#     (0.012642937837187777, 0.020618556701030927, 0.6131824851036072, 'player-4:history')
#     (0.011211545197005124, 0.010309278350515464, 1.087519884109497, 'player-3:history')
#     (0.0037260600775480273, 0.796, 0.004680979996919632, 'cards')
#     (0.0, 0.0, 1.1874668598175049, 'player-9:history')
#     (0.0, 0, 0.948584794998169, 'player-9:state-active')
#     (0.0, 0, 1.0308332443237305, 'player-8:state-fold')
#     (0.0, 0, 0.92313551902771, 'player-7:state-fold')
#     (-0.0, 0, -0.053947821259498596, 'player-6:state-fold')
#     (0.0, 0.0, 2.602756977081299, 'player-5:history')
#     (0.0, 0, 0.18653632700443268, 'player-5:state-active')
#     (0.0, 0, 0.22894993424415588, 'player-4:state-fold')
#     (-0.0, 0, -0.462467223405838, 'player-3:state-fold')
#     (0.0, 0.0, 0.5847306847572327, 'player-2:history')
#     (0.0, 0, 0.2699165940284729, 'player-2:state-fold')
#     (0.0, 0.0, 0.4720967710018158, 'player-1:history')
#     (0.0, 0, 0.15962710976600647, 'player-1:state-fold')
#     (0.0, 0.0, 0.7099671363830566, 'player-0:history')
#     (-0.0, 0, -0.23924040794372559, 'player-0:state-fold')
#     (-0.0, 0, -0.12872657179832458, 'street-river')
#     (-0.0, 0, -0.06145308166742325, 'street-turn')
#     (-0.0, 0, -0.47339075803756714, 'street-flop')
#     (-0.0, 0, -0.1619005799293518, 'btn distance=9')
#     (-0.0, 0, -0.12604860961437225, 'btn distance=7')
#     (0.0, 0, 1.364205002784729, 'btn distance=6')
#     (0.0, 0, 1.1333545446395874, 'btn distance=5')
#     (0.0, 0, 0.4832393229007721, 'btn distance=4')
#     (0.0, 0, 0.21936601400375366, 'btn distance=3')
#     (0.0, 0, 0.21691006422042847, 'btn distance=2')
#     (0.0, 0, 0.0388103649020195, 'btn distance=1')
#     (-0.0, 0, -0.15196388959884644, 'btn distance=0')
#     (-0.0, 0, -0.24565012753009796, 'round level 27')
#     (0.0, 0, 0.18738245964050293, 'round level 26')
#     (0.0, 0, 0.13563582301139832, 'round level 25')
#     (0.0, 0, 0.0051093026995658875, 'round level 24')
#     (0.0, 0, 0.15698617696762085, 'round level 23')
#     (-0.0, 0, -0.25703445076942444, 'round level 22')
#     (-0.0, 0, -0.2061779946088791, 'round level 21')
#     (-0.0, 0, -0.041454460471868515, 'round level 20')
#     (-0.0, 0, -0.09786731749773026, 'round level 19')
#     (-0.0, 0, -0.1264774352312088, 'round level 18')
#     (0.0, 0, 0.24566134810447693, 'round level 17')
#     (-0.0, 0, -0.1010018065571785, 'round level 16')
#     (-0.0, 0, -0.020011145621538162, 'round level 15')
#     (-0.0, 0, -0.05574813857674599, 'round level 14')
#     (-0.0, 0, -0.08178351819515228, 'round level 13')
#     (0.0, 0, 0.18671230971813202, 'round level 12')
#     (-0.0, 0, -0.05788012966513634, 'round level 11')
#     (-0.0, 0, -0.13147558271884918, 'round level 10')
#     (-0.0, 0, -0.23238608241081238, 'round level 9')
#     (-0.0, 0, -0.1202930361032486, 'round level 8')
#     (-0.0, 0, -0.12012208253145218, 'round level 7')
#     (-0.0, 0, -0.09084489941596985, 'round level 6')
#     (-0.0, 0, -0.057835355401039124, 'round level 5')
#     (-0.0, 0, -0.01247967779636383, 'round level 4')
#     (-0.0, 0, -0.2314309924840927, 'round level 3')
#     (0.0, 0, 0.10510239750146866, 'round level 1')
#
# linear combination for max_raise :
#     (-0.8723345398902893, 1, -0.8723345398902893, 'player-0:state-active')
#     (-0.65171939, 0, 0, 'bias')
#     (0.4902391731739044, 1, 0.4902391731739044, 'player-3:state-active')
#     (0.4607435464859009, 1, 0.4607435464859009, 'street-preflop')
#     (0.44726306200027466, 1, 0.44726306200027466, 'player-7:state-active')
#     (-0.43338099122047424, 1, -0.43338099122047424, 'round level 2')
#     (0.258046418428421, 1, 0.258046418428421, 'player-4:state-active')
#     (0.234825998544693, 1, 0.234825998544693, 'btn distance=8')
#     (0.17766355535387993, 0.18225, 0.9748343229293823, 'player-0:stack')
#     (0.12710493803024292, 1, 0.12710493803024292, 'player-2:state-active')
#     (0.11825132369995117, 1, 0.11825132369995117, 'player-9:state-fold')
#     (-0.10525474560260774, 0.0985, -1.0685760974884033, 'player-5:stack')
#     (-0.09855811214447022, 0.078, -1.2635655403137207, 'player-7:stack')
#     (0.09451472014188766, 1, 0.09451472014188766, 'player-6:state-active')
#     (-0.09298242172598839, 0.0995, -0.9344967007637024, 'player-4:stack')
#     (-0.0903611221909523, 0.0935, -0.9664291143417358, 'player-6:stack')
#     (0.07311210036277771, 1, 0.07311210036277771, 'player-5:state-fold')
#     (-0.06759135769307614, 0.09975, -0.6776075959205627, 'player-2:stack')
#     (0.05825741880947781, 0.7010309278350515, 0.08310249447822571, 'player-8:history')
#     (0.047792963683605194, 1, 0.047792963683605194, 'player-8:state-active')
#     (-0.04303246115893126, 0.09925, -0.43357643485069275, 'player-3:stack')
#     (-0.04085352718830109, 0.1, -0.40853527188301086, 'player-1:stack')
#     (0.020795263273199808, 0.20618556701030927, 0.10085702687501907, 'player-7:history')
#     (-0.017791075974702836, 0.083, -0.21435031294822693, 'player-8:stack')
#     (0.007543391788128725, 0.010309278350515464, 0.7317090034484863, 'player-3:history')
#     (-0.00739014009013772, 1, -0.00739014009013772, 'player-1:state-active')
#     (0.0069548711948788046, 0.061855670103092786, 0.11243708431720734, 'player-6:history')
#     (0.003779609862715006, 0.02425, 0.15586020052433014, 'pot')
#     (-0.0036428967118263245, 0.042, -0.08673563599586487, 'player-9:stack')
#     (0.0016155199906260696, 0.020618556701030927, 0.07835271954536438, 'player-4:history')
#     (-0.0013196599921211601, 0.796, -0.00165786431171, 'cards')
#     (0.0, 0.0, 0.2744649648666382, 'player-9:history')
#     (-0.0, 0, -0.03964691609144211, 'player-9:state-active')
#     (0.0, 0, 0.18172471225261688, 'player-8:state-fold')
#     (0.0, 0, 0.24555613100528717, 'player-7:state-fold')
#     (-0.0, 0, -0.2633019685745239, 'player-6:state-fold')
#     (0.0, 0.0, 0.664268434047699, 'player-5:history')
#     (0.0, 0, 0.1984817534685135, 'player-5:state-active')
#     (0.0, 0, 0.3422784209251404, 'player-4:state-fold')
#     (0.0, 0, 0.3658958375453949, 'player-3:state-fold')
#     (-0.0, 0.0, -1.1066265106201172, 'player-2:history')
#     (0.0, 0, 0.20135240256786346, 'player-2:state-fold')
#     (-0.0, 0.0, -0.06738851964473724, 'player-1:history')
#     (-0.0, 0, -0.07760539650917053, 'player-1:state-fold')
#     (0.0, 0.0, 0.4268271327018738, 'player-0:history')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.5152031779289246, 'street-river')
#     (0.0, 0, 0.6108424067497253, 'street-turn')
#     (0.0, 0, 0.5292854905128479, 'street-flop')
#     (-0.0, 0, -0.10669941455125809, 'btn distance=9')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.1012987494468689, 'btn distance=6')
#     (0.0, 0, 0.09859668463468552, 'btn distance=5')
#     (0.0, 0, 0.18136386573314667, 'btn distance=4')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')

# %% [markdown]
# ### ALLIN する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 5800
#   - raise: [9900, 10000]
# -- hole card --
#   - ['SJ', 'S7']
# -- round state --
#   - dealer btn : cpu6
#   - street : preflop
#   - community card : []
#   - pot : main = 8225, side = []
#   - players information
#     - 0 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 1 : cpu8 (uuid-8) => state : participating, stack : 9975 <= SB
#     - 2 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 3 : cpu3 (uuid-3) => state : folded, stack : 10000
#     - 4 : cpu2 (uuid-2) => state : participating, stack : 9850
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9500
#     - 6 : cpu4 (uuid-4) => state : participating, stack : 8300
#     - 7 : cpu9 (uuid-9) => state : folded, stack : 10000
#     - 8 : cpu1 (uuid-1) => state : participating, stack : 4200
#     - 9 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 500, 'action': 'RAISE'}
#       - {'add_amount': 1200, 'paid': 1700, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 1700, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'add_amount': 4100, 'paid': 5800, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 5800, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', -0.012949705123901367), ('call', -1.0511488914489746), ('min_raise', -1.2014198303222656), ('max_raise', 0.0027711987495422363)]
# ** weights and features in detail **
# bias : [-1.4178803  -1.45636129 -1.84081948 -1.6855011  -1.6358695  -0.65171939]
#
# linear combination for fold :
#     (-1.6036138534545898, 1, -1.6036138534545898, 'round level 2')
#     (-1.4178803, 0, 0, 'bias')
#     (-1.39131760597229, 1, -1.39131760597229, 'player-0:state-active')
#     (1.1927926540374756, 1, 1.1927926540374756, 'player-5:state-active')
#     (1.0975725650787354, 1, 1.0975725650787354, 'player-6:state-active')
#     (0.9590729475021362, 1, 0.9590729475021362, 'player-4:state-fold')
#     (-0.9237383008003235, 1, -0.9237383008003235, 'player-7:state-active')
#     (0.7665530443191528, 1, 0.7665530443191528, 'player-3:state-active')
#     (0.6359605528301019, 0.7051671732522796, 0.901857852935791, 'player-9:history')
#     (0.5259191989898682, 1, 0.5259191989898682, 'player-8:state-fold')
#     (0.5158258676528931, 1, 0.5158258676528931, 'player-2:state-active')
#     (0.3970932960510254, 1, 0.3970932960510254, 'player-1:state-active')
#     (0.3955329656600952, 1, 0.3955329656600952, 'player-9:state-active')
#     (-0.25582072138786316, 1, -0.25582072138786316, 'btn distance=9')
#     (-0.21979893743991852, 1, -0.21979893743991852, 'street-preflop')
#     (0.17869203431265696, 0.2066869300911854, 0.8645541071891785, 'player-7:history')
#     (-0.1369952803850174, 0.095, -1.442055583000183, 'player-6:stack')
#     (-0.13117964470386506, 0.0985, -1.331773042678833, 'player-5:stack')
#     (-0.1121270099580288, 0.08225, -1.3632463216781616, 'pot')
#     (-0.10160433053970337, 0.1, -1.0160433053970337, 'player-1:stack')
#     (-0.09536801326274873, 0.083, -1.1490122079849243, 'player-7:stack')
#     (-0.08944877901673318, 0.0995, -0.8989827036857605, 'player-3:stack')
#     (-0.0890201210975647, 0.1, -0.890201210975647, 'player-8:stack')
#     (-0.08378638029098512, 0.1, -0.8378638029098511, 'player-4:stack')
#     (-0.07634796550869942, 0.09975, -0.7653931379318237, 'player-2:stack')
#     (0.061047751128130046, 0.060790273556231005, 1.0042355060577393, 'player-6:history')
#     (-0.03774396300315857, 0.042, -0.8986657857894897, 'player-9:stack')
#     (0.022181463096641842, 0.0182370820668693, 1.2162835597991943, 'player-5:history')
#     (-0.014702299237251283, 0.1, -0.14702299237251282, 'player-0:stack')
#     (0.011559348905459047, 0.651, 0.017756296321749687, 'cards')
#     (0.005547914823862557, 0.0060790273556231, 0.9126319885253906, 'player-3:history')
#     (0.00219213745151972, 0.00303951367781155, 0.7212132215499878, 'player-2:history')
#     (0.0, 0, 0.43394148349761963, 'player-9:state-fold')
#     (0.0, 0.0, 0.8542535305023193, 'player-8:history')
#     (0.0, 0, 0.57443767786026, 'player-8:state-active')
#     (-0.0, 0, -1.1010795831680298, 'player-7:state-fold')
#     (0.0, 0, 1.1583092212677002, 'player-6:state-fold')
#     (0.0, 0, 1.2994141578674316, 'player-5:state-fold')
#     (0.0, 0.0, 0.6843466758728027, 'player-4:history')
#     (0.0, 0, 0.9571974277496338, 'player-4:state-active')
#     (0.0, 0, 0.8350928425788879, 'player-3:state-fold')
#     (0.0, 0, 0.48248523473739624, 'player-2:state-fold')
#     (0.0, 0.0, 0.8106897473335266, 'player-1:history')
#     (0.0, 0, 0.3462808132171631, 'player-1:state-fold')
#     (0.0, 0.0, 1.4909923076629639, 'player-0:history')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.06423696130514145, 'street-river')
#     (-0.0, 0, -0.07568676769733429, 'street-turn')
#     (-0.0, 0, -0.37015533447265625, 'street-flop')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.20629911124706268, 'btn distance=6')
#     (-0.0, 0, -0.224297434091568, 'btn distance=5')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-1.5606324672698975, 1, -1.5606324672698975, 'player-0:state-active')
#     (-1.4563613, 0, 0, 'bias')
#     (-1.3921525478363037, 1, -1.3921525478363037, 'round level 2')
#     (0.7162779569625854, 1, 0.7162779569625854, 'player-4:state-fold')
#     (0.6535208821296692, 1, 0.6535208821296692, 'player-7:state-active')
#     (0.5656450222328441, 0.7051671732522796, 0.8021431565284729, 'player-9:history')
#     (0.5328446626663208, 1, 0.5328446626663208, 'player-9:state-active')
#     (0.3526769280433655, 1, 0.3526769280433655, 'player-8:state-fold')
#     (0.268941730260849, 1, 0.268941730260849, 'street-preflop')
#     (0.261310875415802, 1, 0.261310875415802, 'player-2:state-active')
#     (0.23410646821227843, 0.2066869300911854, 1.1326621770858765, 'player-7:history')
#     (-0.12297159436345101, 0.08225, -1.4950953722000122, 'pot')
#     (-0.11219464987516403, 1, -0.11219464987516403, 'player-5:state-active')
#     (-0.11012765020132065, 1, -0.11012765020132065, 'player-3:state-active')
#     (0.10022080053312075, 0.060790273556231005, 1.6486321687698364, 'player-6:history')
#     (-0.08210933429002762, 0.0985, -0.8335973024368286, 'player-5:stack')
#     (0.06945189237594605, 0.1, 0.6945189237594604, 'player-0:stack')
#     (-0.06480857104063034, 0.095, -0.6821954846382141, 'player-6:stack')
#     (-0.053323414832353595, 0.09975, -0.534570574760437, 'player-2:stack')
#     (0.051786798238754275, 0.1, 0.5178679823875427, 'player-1:stack')
#     (-0.04489012318849564, 0.083, -0.5408448576927185, 'player-7:stack')
#     (0.03550041627738976, 0.0182370820668693, 1.946606159210205, 'player-5:history')
#     (0.032845038920640945, 1, 0.032845038920640945, 'btn distance=9')
#     (0.03167411684989929, 0.1, 0.3167411684989929, 'player-4:stack')
#     (0.029568467289209366, 1, 0.029568467289209366, 'player-6:state-active')
#     (0.029283292591571808, 1, 0.029283292591571808, 'player-1:state-active')
#     (-0.015431600719690323, 0.0995, -0.15509146451950073, 'player-3:stack')
#     (-0.008564776718616485, 0.042, -0.20392325520515442, 'player-9:stack')
#     (0.007032707469441608, 0.0060790273556231, 1.1568803787231445, 'player-3:history')
#     (-0.005352556332945824, 0.1, -0.05352556332945824, 'player-8:stack')
#     (0.0026820582821738756, 0.00303951367781155, 0.8823971748352051, 'player-2:history')
#     (0.0024014781655278057, 0.651, 0.003688906552270055, 'cards')
#     (0.0, 0, 0.5804115533828735, 'player-9:state-fold')
#     (0.0, 0.0, 0.6701096892356873, 'player-8:history')
#     (0.0, 0, 0.7527860999107361, 'player-8:state-active')
#     (0.0, 0, 0.31508174538612366, 'player-7:state-fold')
#     (0.0, 0, 0.04104764759540558, 'player-6:state-fold')
#     (-0.0, 0, -0.03405972570180893, 'player-5:state-fold')
#     (0.0, 0.0, 1.0928881168365479, 'player-4:history')
#     (0.0, 0, 0.45938295125961304, 'player-4:state-active')
#     (-0.0, 0, -0.160588338971138, 'player-3:state-fold')
#     (0.0, 0, 0.16398480534553528, 'player-2:state-fold')
#     (0.0, 0.0, 1.590529441833496, 'player-1:history')
#     (0.0, 0, 0.21514472365379333, 'player-1:state-fold')
#     (0.0, 0.0, 2.6005444526672363, 'player-0:history')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (-0.0, 0, -0.2850165069103241, 'street-river')
#     (-0.0, 0, -0.07254668325185776, 'street-turn')
#     (-0.0, 0, -0.17641568183898926, 'street-flop')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 0.8125324249267578, 'btn distance=6')
#     (0.0, 0, 0.9285439848899841, 'btn distance=5')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.0189969539642334, 1, -2.0189969539642334, 'round level 2')
#     (-1.8873168230056763, 1, -1.8873168230056763, 'player-0:state-active')
#     (-1.8408195, 0, 0, 'bias')
#     (1.3076800107955933, 1, 1.3076800107955933, 'player-9:state-active')
#     (1.0681812763214111, 1, 1.0681812763214111, 'player-7:state-active')
#     (0.9296978116035461, 1, 0.9296978116035461, 'player-8:state-fold')
#     (0.8815811093455027, 0.7051671732522796, 1.2501732110977173, 'player-9:history')
#     (0.4657408595085144, 1, 0.4657408595085144, 'player-1:state-active')
#     (0.3034637807712729, 0.2066869300911854, 1.4682291746139526, 'player-7:history')
#     (0.2067711055278778, 1, 0.2067711055278778, 'player-5:state-active')
#     (0.181107759475708, 1, 0.181107759475708, 'player-2:state-active')
#     (-0.17775254726409911, 0.095, -1.871079444885254, 'player-6:stack')
#     (-0.1774212121963501, 1, -0.1774212121963501, 'btn distance=9')
#     (0.1382988840341568, 1, 0.1382988840341568, 'player-4:state-fold')
#     (-0.12966528761386872, 0.0985, -1.3163988590240479, 'player-5:stack')
#     (-0.1276594065129757, 0.08225, -1.552090048789978, 'pot')
#     (0.11686373502016068, 1, 0.11686373502016068, 'player-6:state-active')
#     (-0.11313341546058656, 0.09975, -1.134169578552246, 'player-2:stack')
#     (-0.10155186676979065, 0.0995, -1.0206217765808105, 'player-3:stack')
#     (-0.09966592025756836, 0.083, -1.2007942199707031, 'player-7:stack')
#     (0.0963335051724976, 0.060790273556231005, 1.5846861600875854, 'player-6:history')
#     (-0.09074578881263734, 0.1, -0.9074578881263733, 'player-8:stack')
#     (-0.06934729218482971, 0.1, -0.6934729218482971, 'player-4:stack')
#     (-0.056135100126266484, 0.1, -0.5613510012626648, 'player-1:stack')
#     (0.05415186838538451, 0.0182370820668693, 2.969327449798584, 'player-5:history')
#     (-0.03449150174856186, 1, -0.03449150174856186, 'street-preflop')
#     (-0.0334225047826767, 0.042, -0.7957739233970642, 'player-9:stack')
#     (-0.012580730020999908, 0.1, -0.12580730020999908, 'player-0:stack')
#     (0.012104667723178864, 1, 0.012104667723178864, 'player-3:state-active')
#     (0.007298064449275519, 0.0060790273556231, 1.2005316019058228, 'player-3:history')
#     (0.0014532932213374547, 0.00303951367781155, 0.4781334698200226, 'player-2:history')
#     (-0.0014419111066963524, 0.651, -0.002214917214587331, 'cards')
#     (0.0, 0, 1.3117984533309937, 'player-9:state-fold')
#     (0.0, 0.0, 1.3219267129898071, 'player-8:history')
#     (0.0, 0, 1.4327375888824463, 'player-8:state-active')
#     (0.0, 0, 0.5567418336868286, 'player-7:state-fold')
#     (0.0, 0, 0.273332804441452, 'player-6:state-fold')
#     (0.0, 0, 0.5238251090049744, 'player-5:state-fold')
#     (0.0, 0.0, 1.198168396949768, 'player-4:history')
#     (0.0, 0, 0.02177312597632408, 'player-4:state-active')
#     (-0.0, 0, -0.2806473970413208, 'player-3:state-fold')
#     (0.0, 0, 0.6119090914726257, 'player-2:state-fold')
#     (0.0, 0.0, 1.5168819427490234, 'player-1:history')
#     (0.0, 0, 0.5179490447044373, 'player-1:state-fold')
#     (0.0, 0.0, 0.9410321116447449, 'player-0:history')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.09289492666721344, 'street-river')
#     (0.0, 0, 0.08158420771360397, 'street-turn')
#     (-0.0, 0, -0.008587334305047989, 'street-flop')
#     (-0.0, 0, -0.047159694135189056, 'btn distance=8')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 0.8966071605682373, 'btn distance=6')
#     (0.0, 0, 0.9084417223930359, 'btn distance=5')
#     (0.0, 0, 0.5843061804771423, 'btn distance=4')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for max_raise :
#     (-0.8723345398902893, 1, -0.8723345398902893, 'player-0:state-active')
#     (-0.65171939, 0, 0, 'bias')
#     (0.4902391731739044, 1, 0.4902391731739044, 'player-3:state-active')
#     (0.4607435464859009, 1, 0.4607435464859009, 'street-preflop')
#     (0.44726306200027466, 1, 0.44726306200027466, 'player-7:state-active')
#     (-0.43338099122047424, 1, -0.43338099122047424, 'round level 2')
#     (0.3422784209251404, 1, 0.3422784209251404, 'player-4:state-fold')
#     (0.1984817534685135, 1, 0.1984817534685135, 'player-5:state-active')
#     (0.19354368343179348, 0.7051671732522796, 0.2744649648666382, 'player-9:history')
#     (0.18172471225261688, 1, 0.18172471225261688, 'player-8:state-fold')
#     (0.12710493803024292, 1, 0.12710493803024292, 'player-2:state-active')
#     (-0.10669941455125809, 1, -0.10669941455125809, 'btn distance=9')
#     (-0.10525474560260774, 0.0985, -1.0685760974884033, 'player-5:stack')
#     (-0.10487593984603882, 0.083, -1.2635655403137207, 'player-7:stack')
#     (0.09748343229293824, 0.1, 0.9748343229293823, 'player-0:stack')
#     (0.09451472014188766, 1, 0.09451472014188766, 'player-6:state-active')
#     (-0.09344967007637024, 0.1, -0.9344967007637024, 'player-4:stack')
#     (-0.09181076586246491, 0.095, -0.9664291143417358, 'player-6:stack')
#     (-0.06759135769307614, 0.09975, -0.6776075959205627, 'player-2:stack')
#     (-0.043140855267643934, 0.0995, -0.43357643485069275, 'player-3:stack')
#     (-0.04085352718830109, 0.1, -0.40853527188301086, 'player-1:stack')
#     (-0.03964691609144211, 1, -0.03964691609144211, 'player-9:state-active')
#     (-0.021435031294822694, 0.1, -0.21435031294822693, 'player-8:stack')
#     (0.020845829262921875, 0.2066869300911854, 0.10085702687501907, 'player-7:history')
#     (0.012819501493126155, 0.08225, 0.15586020052433014, 'pot')
#     (0.012114317946158644, 0.0182370820668693, 0.664268434047699, 'player-5:history')
#     (-0.00739014009013772, 1, -0.00739014009013772, 'player-1:state-active')
#     (0.006835081113508045, 0.060790273556231005, 0.11243708431720734, 'player-6:history')
#     (0.0044480790483190655, 0.0060790273556231, 0.7317090034484863, 'player-3:history')
#     (-0.0036428967118263245, 0.042, -0.08673563599586487, 'player-9:stack')
#     (-0.003363606415258715, 0.00303951367781155, -1.1066265106201172, 'player-2:history')
#     (-0.0010792696669232101, 0.651, -0.00165786431171, 'cards')
#     (0.0, 0, 0.11825132369995117, 'player-9:state-fold')
#     (0.0, 0.0, 0.08310249447822571, 'player-8:history')
#     (0.0, 0, 0.047792963683605194, 'player-8:state-active')
#     (0.0, 0, 0.24555613100528717, 'player-7:state-fold')
#     (-0.0, 0, -0.2633019685745239, 'player-6:state-fold')
#     (0.0, 0, 0.07311210036277771, 'player-5:state-fold')
#     (0.0, 0.0, 0.07835271954536438, 'player-4:history')
#     (0.0, 0, 0.258046418428421, 'player-4:state-active')
#     (0.0, 0, 0.3658958375453949, 'player-3:state-fold')
#     (0.0, 0, 0.20135240256786346, 'player-2:state-fold')
#     (-0.0, 0.0, -0.06738851964473724, 'player-1:history')
#     (-0.0, 0, -0.07760539650917053, 'player-1:state-fold')
#     (0.0, 0.0, 0.4268271327018738, 'player-0:history')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.5152031779289246, 'street-river')
#     (0.0, 0, 0.6108424067497253, 'street-turn')
#     (0.0, 0, 0.5292854905128479, 'street-flop')
#     (0.0, 0, 0.234825998544693, 'btn distance=8')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.1012987494468689, 'btn distance=6')
#     (0.0, 0, 0.09859668463468552, 'btn distance=5')
#     (0.0, 0, 0.18136386573314667, 'btn distance=4')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')

# %% [markdown]
# ### Fold する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['SA', 'D7']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 18225, side = [{'amount': 0, 'eligibles': ['uuid-5']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu7 (uuid-7) => state : folded, stack : 9975 <= SB
#     - 2 : agent (uuid-0) => state : participating, stack : 9950 <= BB, CURRENT
#     - 3 : cpu3 (uuid-3) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9850
#     - 5 : cpu9 (uuid-9) => state : participating, stack : 9500
#     - 6 : cpu1 (uuid-1) => state : participating, stack : 8300
#     - 7 : cpu4 (uuid-4) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 4200
#     - 9 : cpu5 (uuid-5) => state : allin, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 500, 'action': 'RAISE'}
#       - {'add_amount': 1200, 'paid': 1700, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 1700, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'add_amount': 4100, 'paid': 5800, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 5800, 'action': 'RAISE'}
#       - {'add_amount': 4200, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.5679386854171753), ('call', -0.851997971534729)]
# ** weights and features in detail **
# bias : [-1.4178803  -1.45636129 -1.84081948 -1.6855011  -1.6358695  -0.65171939]
#
# linear combination for fold :
#     (-1.6036138534545898, 1, -1.6036138534545898, 'round level 2')
#     (-1.4178803, 0, 0, 'bias')
#     (-1.39131760597229, 1, -1.39131760597229, 'player-0:state-active')
#     (1.2994141578674316, 1, 1.2994141578674316, 'player-5:state-fold')
#     (1.0975725650787354, 1, 1.0975725650787354, 'player-6:state-active')
#     (0.9571974277496338, 1, 0.9571974277496338, 'player-4:state-active')
#     (-0.9237383008003235, 1, -0.9237383008003235, 'player-7:state-active')
#     (0.7665530443191528, 1, 0.7665530443191528, 'player-3:state-active')
#     (0.5259191989898682, 1, 0.5259191989898682, 'player-8:state-fold')
#     (0.5158258676528931, 1, 0.5158258676528931, 'player-2:state-active')
#     (0.4743781109405643, 0.5486968449931413, 0.8645541071891785, 'player-7:history')
#     (0.43394148349761963, 1, 0.43394148349761963, 'player-9:state-fold')
#     (0.3462808132171631, 1, 0.3462808132171631, 'player-1:state-fold')
#     (0.3195920952063039, 0.31824417009602196, 1.0042355060577393, 'player-6:history')
#     (-0.24845164212584495, 0.18225, -1.3632463216781616, 'pot')
#     (0.24461735785007477, 1, 0.24461735785007477, 'btn distance=2')
#     (-0.21979893743991852, 1, -0.21979893743991852, 'street-preflop')
#     (-0.1331773042678833, 0.1, -1.331773042678833, 'player-5:stack')
#     (-0.10160433053970337, 0.1, -1.0160433053970337, 'player-1:stack')
#     (-0.08964191213250161, 0.09975, -0.8986657857894897, 'player-9:stack')
#     (-0.0890201210975647, 0.1, -0.890201210975647, 'player-8:stack')
#     (-0.08540335685014724, 0.095, -0.8989827036857605, 'player-3:stack')
#     (-0.07539122408628464, 0.0985, -0.7653931379318237, 'player-2:stack')
#     (-0.06954269564151765, 0.083, -0.8378638029098511, 'player-4:stack')
#     (0.06383480652860163, 0.09327846364883402, 0.6843466758728027, 'player-4:history')
#     (-0.06056633448600769, 0.042, -1.442055583000183, 'player-6:stack')
#     (0.025037914637184928, 0.027434842249657063, 0.9126319885253906, 'player-3:history')
#     (-0.014628787741065026, 0.0995, -0.14702299237251282, 'player-0:stack')
#     (0.011523836312815547, 0.649, 0.017756296321749687, 'cards')
#     (0.005935911288477267, 0.00823045267489712, 0.7212132215499878, 'player-2:history')
#     (0.0040905138756185564, 0.0027434842249657062, 1.4909923076629639, 'player-0:history')
#     (0.0, 0.0, 0.901857852935791, 'player-9:history')
#     (0.0, 0, 0.3955329656600952, 'player-9:state-active')
#     (0.0, 0.0, 0.8542535305023193, 'player-8:history')
#     (0.0, 0, 0.57443767786026, 'player-8:state-active')
#     (-0.0, 0, -1.1010795831680298, 'player-7:state-fold')
#     (-0.0, 0.0, -1.1490122079849243, 'player-7:stack')
#     (0.0, 0, 1.1583092212677002, 'player-6:state-fold')
#     (0.0, 0.0, 1.2162835597991943, 'player-5:history')
#     (0.0, 0, 1.1927926540374756, 'player-5:state-active')
#     (0.0, 0, 0.9590729475021362, 'player-4:state-fold')
#     (0.0, 0, 0.8350928425788879, 'player-3:state-fold')
#     (0.0, 0, 0.48248523473739624, 'player-2:state-fold')
#     (0.0, 0.0, 0.8106897473335266, 'player-1:history')
#     (0.0, 0, 0.3970932960510254, 'player-1:state-active')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.06423696130514145, 'street-river')
#     (-0.0, 0, -0.07568676769733429, 'street-turn')
#     (-0.0, 0, -0.37015533447265625, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.20629911124706268, 'btn distance=6')
#     (-0.0, 0, -0.224297434091568, 'btn distance=5')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-1.5606324672698975, 1, -1.5606324672698975, 'player-0:state-active')
#     (-1.4563613, 0, 0, 'bias')
#     (-1.3921525478363037, 1, -1.3921525478363037, 'round level 2')
#     (0.6535208821296692, 1, 0.6535208821296692, 'player-7:state-active')
#     (0.6214881630100831, 0.5486968449931413, 1.1326621770858765, 'player-7:history')
#     (0.5804115533828735, 1, 0.5804115533828735, 'player-9:state-fold')
#     (0.5246675763437614, 0.31824417009602196, 1.6486321687698364, 'player-6:history')
#     (0.45938295125961304, 1, 0.45938295125961304, 'player-4:state-active')
#     (0.3526769280433655, 1, 0.3526769280433655, 'player-8:state-fold')
#     (-0.2724811315834522, 0.18225, -1.4950953722000122, 'pot')
#     (0.268941730260849, 1, 0.268941730260849, 'street-preflop')
#     (0.261310875415802, 1, 0.261310875415802, 'player-2:state-active')
#     (0.21514472365379333, 1, 0.21514472365379333, 'player-1:state-fold')
#     (-0.11012765020132065, 1, -0.11012765020132065, 'player-3:state-active')
#     (0.1019429244785806, 0.09327846364883402, 1.0928881168365479, 'player-4:history')
#     (-0.08585645258426666, 1, -0.08585645258426666, 'btn distance=2')
#     (-0.08335973024368287, 0.1, -0.8335973024368286, 'player-5:stack')
#     (0.06910463291406632, 0.0995, 0.6945189237594604, 'player-0:stack')
#     (-0.052655201613903045, 0.0985, -0.534570574760437, 'player-2:stack')
#     (0.051786798238754275, 0.1, 0.5178679823875427, 'player-1:stack')
#     (-0.03405972570180893, 1, -0.03405972570180893, 'player-5:state-fold')
#     (0.03173883069199299, 0.027434842249657063, 1.1568803787231445, 'player-3:history')
#     (0.029568467289209366, 1, 0.029568467289209366, 'player-6:state-active')
#     (-0.028652210354804995, 0.042, -0.6821954846382141, 'player-6:stack')
#     (0.026289516985416414, 0.083, 0.3167411684989929, 'player-4:stack')
#     (-0.020341344706714153, 0.09975, -0.20392325520515442, 'player-9:stack')
#     (-0.01473368912935257, 0.095, -0.15509146451950073, 'player-3:stack')
#     (0.007262528187944075, 0.00823045267489712, 0.8823971748352051, 'player-2:history')
#     (0.0071345526822146395, 0.0027434842249657062, 2.6005444526672363, 'player-0:history')
#     (-0.005352556332945824, 0.1, -0.05352556332945824, 'player-8:stack')
#     (0.0023941003524232656, 0.649, 0.003688906552270055, 'cards')
#     (0.0, 0.0, 0.8021431565284729, 'player-9:history')
#     (0.0, 0, 0.5328446626663208, 'player-9:state-active')
#     (0.0, 0.0, 0.6701096892356873, 'player-8:history')
#     (0.0, 0, 0.7527860999107361, 'player-8:state-active')
#     (0.0, 0, 0.31508174538612366, 'player-7:state-fold')
#     (-0.0, 0.0, -0.5408448576927185, 'player-7:stack')
#     (0.0, 0, 0.04104764759540558, 'player-6:state-fold')
#     (0.0, 0.0, 1.946606159210205, 'player-5:history')
#     (-0.0, 0, -0.11219464987516403, 'player-5:state-active')
#     (0.0, 0, 0.7162779569625854, 'player-4:state-fold')
#     (-0.0, 0, -0.160588338971138, 'player-3:state-fold')
#     (0.0, 0, 0.16398480534553528, 'player-2:state-fold')
#     (0.0, 0.0, 1.590529441833496, 'player-1:history')
#     (0.0, 0, 0.029283292591571808, 'player-1:state-active')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (-0.0, 0, -0.2850165069103241, 'street-river')
#     (-0.0, 0, -0.07254668325185776, 'street-turn')
#     (-0.0, 0, -0.17641568183898926, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 0.8125324249267578, 'btn distance=6')
#     (0.0, 0, 0.9285439848899841, 'btn distance=5')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')

# %% [markdown]
# ### 100万iteration後のvalue function10人で対戦
# min_raiseしたあと,foldしちゃう.

# %% [markdown]
# ### MIN_RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 75
#   - raise: [100, 10000]
# -- hole card --
#   - ['HT', 'D5']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 150, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9925
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 75, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 100 (min_raise) ] at round 1
#   => [('fold', -0.013892650604248047), ('call', -0.10626578330993652), ('min_raise', 0.16391921043395996), ('double_raise', 0.16141867637634277), ('triple_raise', -0.014379262924194336), ('max_raise', 0.062408447265625)]
# do you want to see weights? (y/n)y
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 75
#   - raise: [100, 10000]
# -- hole card --
#   - ['HT', 'D5']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 150, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9925
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 75, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 100 (min_raise) ] at round 1
#   => [('fold', -0.013892650604248047), ('call', -0.10626578330993652), ('min_raise', 0.16391921043395996), ('double_raise', 0.16141867637634277), ('triple_raise', -0.014379262924194336), ('max_raise', 0.062408447265625)]
# ** weights and features in detail **
# bias : [-2.24537802 -2.14030123 -2.49615192 -2.38752079 -2.37243271 -1.10460341]
#
# linear combination for fold :
#     (-2.431051731109619, 1, -2.431051731109619, 'round level 2')
#     (-2.245378, 0, 0, 'bias')
#     (-2.218794345855713, 1, -2.218794345855713, 'player-0:state-active')
#     (-2.0704636573791504, 1, -2.0704636573791504, 'player-7:state-fold')
#     (1.9195448160171509, 1, 1.9195448160171509, 'player-5:state-active')
#     (1.8243247270584106, 1, 1.8243247270584106, 'player-6:state-active')
#     (1.558862328529358, 1, 1.558862328529358, 'player-4:state-active')
#     (1.5222080945968628, 1, 1.5222080945968628, 'player-3:state-active')
#     (1.1019710302352905, 1, 1.1019710302352905, 'player-1:state-active')
#     (1.0325573682785034, 1, 1.0325573682785034, 'player-2:state-active')
#     (0.8168973922729492, 1, 0.8168973922729492, 'player-9:state-active')
#     (0.38073388735453284, 0.16666666666666666, 2.2844033241271973, 'player-5:history')
#     (0.379616896311442, 0.3333333333333333, 1.1388506889343262, 'player-6:history')
#     (0.3521125614643097, 0.5, 0.7042251229286194, 'player-9:history')
#     (-0.3098161518573761, 1, -0.3098161518573761, 'player-8:state-fold')
#     (-0.22828711569309235, 1, -0.22828711569309235, 'btn distance=6')
#     (-0.22798677551746369, 0.0995, -2.2913243770599365, 'player-6:stack')
#     (-0.21541132628917695, 0.09975, -2.1595120429992676, 'player-5:stack')
#     (-0.19724332094192507, 0.1, -1.9724332094192505, 'player-7:stack')
#     (0.1943889558315277, 1, 0.1943889558315277, 'street-preflop')
#     (-0.17302608489990234, 0.1, -1.7302608489990234, 'player-8:stack')
#     (-0.1693753242492676, 0.1, -1.6937532424926758, 'player-4:stack')
#     (-0.16680443286895752, 0.1, -1.6680443286895752, 'player-1:stack')
#     (-0.13382815122604372, 0.1, -1.338281512260437, 'player-2:stack')
#     (-0.13178757283091547, 0.09925, -1.3278344869613647, 'player-9:stack')
#     (-0.12089370489120484, 0.1, -1.2089370489120483, 'player-3:stack')
#     (-0.031118673086166383, 0.1, -0.3111867308616638, 'player-0:stack')
#     (-0.02439675723016262, 0.622, -0.0392230823636055, 'cards')
#     (-0.0014471769332885743, 0.0015, -0.9647846221923828, 'pot')
#     (0.0, 0, 0.5911204218864441, 'player-9:state-fold')
#     (0.0, 0.0, 1.086035966873169, 'player-8:history')
#     (0.0, 0, 0.7840678095817566, 'player-8:state-active')
#     (0.0, 0.0, 0.15181133151054382, 'player-7:history')
#     (-0.0, 0, -1.5541051626205444, 'player-7:state-active')
#     (0.0, 0, 1.6409307718276978, 'player-6:state-fold')
#     (0.0, 0, 1.7820357084274292, 'player-5:state-fold')
#     (0.0, 0.0, 0.05564766377210617, 'player-4:history')
#     (0.0, 0, 1.4899870157241821, 'player-4:state-fold')
#     (0.0, 0.0, 1.0570818185806274, 'player-3:history')
#     (0.0, 0, 1.6157982349395752, 'player-3:state-fold')
#     (0.0, 0.0, 0.8161777853965759, 'player-2:history')
#     (0.0, 0, 1.1088765859603882, 'player-2:state-fold')
#     (0.0, 0.0, 0.23884399235248566, 'player-1:history')
#     (0.0, 0, 1.7078877687454224, 'player-1:state-fold')
#     (0.0, 0.0, 1.0608843564987183, 'player-0:history')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.3334566652774811, 'street-river')
#     (0.0, 0, 0.343752384185791, 'street-turn')
#     (0.0, 0, 0.5796384215354919, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.12463589757680893, 'btn distance=5')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-2.2445640563964844, 1, -2.2445640563964844, 'player-0:state-active')
#     (-2.1403012, 0, 0, 'bias')
#     (-2.0760812759399414, 1, -2.0760812759399414, 'round level 2')
#     (1.8865877389907837, 1, 1.8865877389907837, 'player-9:state-active')
#     (1.8069616556167603, 1, 1.8069616556167603, 'btn distance=6')
#     (0.9312220215797424, 0.5, 1.8624440431594849, 'player-9:history')
#     (0.7556829452514648, 1, 0.7556829452514648, 'player-4:state-active')
#     (0.5820401906967163, 1, 0.5820401906967163, 'player-1:state-active')
#     (0.4903734525044759, 0.3333333333333333, 1.4711203575134277, 'player-6:history')
#     (0.4035125970840454, 1, 0.4035125970840454, 'player-6:state-active')
#     (-0.3545590043067932, 1, -0.3545590043067932, 'player-7:state-fold')
#     (-0.3125944137573242, 1, -0.3125944137573242, 'player-8:state-fold')
#     (0.28508293628692627, 1, 0.28508293628692627, 'player-2:state-active')
#     (0.26324620842933655, 1, 0.26324620842933655, 'player-5:state-active')
#     (0.19915358225504556, 0.16666666666666666, 1.1949214935302734, 'player-5:history')
#     (0.19035984575748444, 1, 0.19035984575748444, 'player-3:state-active')
#     (-0.151426137059927, 0.09975, -1.5180565118789673, 'player-5:stack')
#     (-0.1355175161957741, 0.0995, -1.3619850873947144, 'player-6:stack')
#     (-0.12220861911773682, 0.1, -1.2220861911773682, 'player-7:stack')
#     (-0.10055559661984444, 0.09925, -1.0131546258926392, 'player-9:stack')
#     (-0.09908056855201722, 0.1, -0.9908056855201721, 'player-1:stack')
#     (-0.08827736228704453, 1, -0.08827736228704453, 'street-preflop')
#     (-0.0729588806629181, 0.1, -0.7295888066291809, 'player-8:stack')
#     (-0.06614058613777161, 0.1, -0.6614058613777161, 'player-2:stack')
#     (0.04054495990276337, 0.1, 0.40544959902763367, 'player-0:stack')
#     (0.03658467829227448, 0.1, 0.36584678292274475, 'player-4:stack')
#     (-0.021985971927642824, 0.1, -0.21985971927642822, 'player-3:stack')
#     (0.00920182423852384, 0.622, 0.014793929643929005, 'cards')
#     (-0.0005693951547145843, 0.0015, -0.3795967698097229, 'pot')
#     (0.0, 0, 1.4917446374893188, 'player-9:state-fold')
#     (0.0, 0.0, 0.617439329624176, 'player-8:history')
#     (0.0, 0, 0.7037453651428223, 'player-8:state-active')
#     (0.0, 0.0, 1.068838119506836, 'player-7:history')
#     (0.0, 0, 0.5837045907974243, 'player-7:state-active')
#     (-0.0, 0, -0.06702187657356262, 'player-6:state-fold')
#     (-0.0, 0, -0.14356182515621185, 'player-5:state-fold')
#     (0.0, 0.0, 1.6109318733215332, 'player-4:history')
#     (0.0, 0, 1.0968955755233765, 'player-4:state-fold')
#     (0.0, 0.0, 2.3010153770446777, 'player-3:history')
#     (0.0, 0, 0.2964814305305481, 'player-3:state-fold')
#     (0.0, 0.0, 0.8736161589622498, 'player-2:history')
#     (0.0, 0, 0.3408045768737793, 'player-2:state-fold')
#     (0.0, 0.0, 0.9040548205375671, 'player-1:history')
#     (0.0, 0, 0.9013826251029968, 'player-1:state-fold')
#     (0.0, 0.0, 2.0581040382385254, 'player-0:history')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (0.0, 0, 0.1361539363861084, 'street-river')
#     (0.0, 0, 0.12363648414611816, 'street-turn')
#     (0.0, 0, 0.138866126537323, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 1.8200968503952026, 'btn distance=5')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.6741485595703125, 1, -2.6741485595703125, 'round level 2')
#     (-2.5425000190734863, 1, -2.5425000190734863, 'player-0:state-active')
#     (-2.4961519, 0, 0, 'bias')
#     (2.2141034603118896, 1, 2.2141034603118896, 'player-9:state-active')
#     (1.4792786836624146, 1, 1.4792786836624146, 'btn distance=6')
#     (1.1605361700057983, 1, 1.1605361700057983, 'player-1:state-active')
#     (0.8643693327903748, 0.5, 1.7287386655807495, 'player-9:history')
#     (0.709435760974884, 1, 0.709435760974884, 'player-5:state-active')
#     (0.7028936743736267, 1, 0.7028936743736267, 'player-2:state-active')
#     (0.6351824402809143, 1, 0.6351824402809143, 'player-6:state-active')
#     (0.6032495896021525, 0.16666666666666666, 3.619497537612915, 'player-5:history')
#     (0.43497592210769653, 1, 0.43497592210769653, 'player-4:state-active')
#     (0.40691188971201575, 0.3333333333333333, 1.2207356691360474, 'player-6:history')
#     (0.36654409766197205, 1, 0.36654409766197205, 'player-7:state-fold')
#     (0.30986031889915466, 1, 0.30986031889915466, 'player-8:state-fold')
#     (-0.25397777557373047, 0.1, -2.5397777557373047, 'player-1:stack')
#     (-0.2510509308576584, 0.0995, -2.523124933242798, 'player-6:stack')
#     (-0.19676381608843804, 0.09975, -1.9725695848464966, 'player-5:stack')
#     (-0.18543928861618042, 0.1, -1.8543928861618042, 'player-7:stack')
#     (-0.1815817281007767, 0.09925, -1.8295388221740723, 'player-9:stack')
#     (-0.16726447343826295, 0.1, -1.6726447343826294, 'player-2:stack')
#     (-0.15637184381484986, 0.1, -1.5637184381484985, 'player-8:stack')
#     (-0.15340092182159426, 0.1, -1.5340092182159424, 'player-3:stack')
#     (-0.14664705991744995, 0.1, -1.4664705991744995, 'player-4:stack')
#     (-0.1426054686307907, 1, -0.1426054686307907, 'player-3:state-active')
#     (-0.11383439600467682, 1, -0.11383439600467682, 'street-preflop')
#     (-0.07038970589637757, 0.1, -0.7038970589637756, 'player-0:stack')
#     (0.011435995157808066, 0.622, 0.01838584430515766, 'cards')
#     (-0.002730104148387909, 0.0015, -1.820069432258606, 'pot')
#     (0.0, 0, 2.033776044845581, 'player-9:state-fold')
#     (0.0, 0.0, 1.2142130136489868, 'player-8:history')
#     (0.0, 0, 1.3269157409667969, 'player-8:state-active')
#     (0.0, 0.0, 1.401948094367981, 'player-7:history')
#     (0.0, 0, 1.0241550207138062, 'player-7:state-active')
#     (0.0, 0, 0.4207422137260437, 'player-6:state-fold')
#     (0.0, 0, 0.6914798617362976, 'player-5:state-fold')
#     (0.0, 0.0, 1.1321343183517456, 'player-4:history')
#     (0.0, 0, 0.5677550435066223, 'player-4:state-fold')
#     (0.0, 0.0, 2.0687448978424072, 'player-3:history')
#     (-0.0, 0, -0.03342190384864807, 'player-3:state-fold')
#     (0.0, 0.0, 0.5935136675834656, 'player-2:history')
#     (0.0, 0, 0.7674608826637268, 'player-2:state-fold')
#     (0.0, 0.0, 1.0035585165023804, 'player-1:history')
#     (0.0, 0, 1.1311455965042114, 'player-1:state-fold')
#     (0.0, 0.0, 1.6993013620376587, 'player-0:history')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.04107475280761719, 'street-river')
#     (0.0, 0, 0.026161091402173042, 'street-turn')
#     (-0.0, 0, -0.02991003915667534, 'street-flop')
#     (-0.0, 0, -0.1774212121963501, 'btn distance=9')
#     (-0.0, 0, -0.047159694135189056, 'btn distance=8')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 1.4675281047821045, 'btn distance=5')
#     (0.0, 0, 0.5843061804771423, 'btn distance=4')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for double_raise :
#     (-2.5915870666503906, 1, -2.5915870666503906, 'player-0:state-active')
#     (-2.3875208, 0, 0, 'bias')
#     (-2.1957459449768066, 1, -2.1957459449768066, 'round level 2')
#     (1.7864481210708618, 1, 1.7864481210708618, 'btn distance=6')
#     (1.4783991575241089, 1, 1.4783991575241089, 'player-9:state-active')
#     (1.3565353155136108, 1, 1.3565353155136108, 'player-7:state-fold')
#     (0.8989899754524231, 0.5, 1.7979799509048462, 'player-9:history')
#     (0.8493184447288513, 1, 0.8493184447288513, 'player-2:state-active')
#     (0.7123739719390869, 0.16666666666666666, 4.2742438316345215, 'player-5:history')
#     (0.6920390725135803, 1, 0.6920390725135803, 'player-1:state-active')
#     (0.36283689737319946, 1, 0.36283689737319946, 'player-3:state-active')
#     (0.3248136341571808, 1, 0.3248136341571808, 'player-4:state-active')
#     (0.29325035214424133, 1, 0.29325035214424133, 'player-6:state-active')
#     (-0.25168015038967134, 0.0995, -2.5294487476348877, 'player-6:stack')
#     (0.20312217871348062, 0.3333333333333333, 0.6093665361404419, 'player-6:history')
#     (-0.20290050506591797, 0.1, -2.0290050506591797, 'player-1:stack')
#     (-0.19800236225128176, 0.1, -1.9800236225128174, 'player-7:stack')
#     (0.1973874717950821, 1, 0.1973874717950821, 'player-8:state-fold')
#     (-0.19426556172966958, 0.09975, -1.9475244283676147, 'player-5:stack')
#     (-0.17938907146453859, 0.1, -1.7938907146453857, 'player-2:stack')
#     (-0.17708672285079957, 0.1, -1.7708672285079956, 'player-3:stack')
#     (-0.1768890270292759, 0.09925, -1.7822571992874146, 'player-9:stack')
#     (-0.13466938734054565, 0.1, -1.3466938734054565, 'player-8:stack')
#     (-0.13437527418136597, 0.1, -1.3437527418136597, 'player-4:stack')
#     (-0.10949435830116272, 1, -0.10949435830116272, 'street-preflop')
#     (-0.08243178725242616, 0.1, -0.8243178725242615, 'player-0:stack')
#     (0.02128782607614994, 0.622, 0.034224800765514374, 'cards')
#     (0.005027344916015863, 1, 0.005027344916015863, 'player-5:state-active')
#     (-0.004373242378234863, 0.0015, -2.915494918823242, 'pot')
#     (0.0, 0, 1.7065824270248413, 'player-9:state-fold')
#     (0.0, 0.0, 1.4511357545852661, 'player-8:history')
#     (0.0, 0, 1.307974100112915, 'player-8:state-active')
#     (0.0, 0.0, 1.5180848836898804, 'player-7:history')
#     (0.0, 0, 1.5541554689407349, 'player-7:state-active')
#     (0.0, 0, 0.09614922106266022, 'player-6:state-fold')
#     (0.0, 0, 0.7188841104507446, 'player-5:state-fold')
#     (0.0, 0.0, 0.8796502351760864, 'player-4:history')
#     (0.0, 0, 0.4836919605731964, 'player-4:state-fold')
#     (0.0, 0.0, 1.0582114458084106, 'player-3:history')
#     (0.0, 0, 0.4559221565723419, 'player-3:state-fold')
#     (0.0, 0.0, 0.5237418413162231, 'player-2:history')
#     (0.0, 0, 0.902125358581543, 'player-2:state-fold')
#     (0.0, 0.0, 0.791723906993866, 'player-1:history')
#     (0.0, 0, 0.20732176303863525, 'player-1:state-fold')
#     (0.0, 0.0, 0.7544894218444824, 'player-0:history')
#     (0.0, 0, 0.1994665414094925, 'player-0:state-fold')
#     (0.0, 0, 0.18096104264259338, 'street-river')
#     (0.0, 0, 0.015104751102626324, 'street-turn')
#     (-0.0, 0, -0.11874984204769135, 'street-flop')
#     (0.0, 0, 0.16180437803268433, 'btn distance=9')
#     (-0.0, 0, -0.16994917392730713, 'btn distance=8')
#     (-0.0, 0, -0.2551056444644928, 'btn distance=7')
#     (0.0, 0, 1.8671458959579468, 'btn distance=5')
#     (0.0, 0, 0.2912150025367737, 'btn distance=4')
#     (-0.0, 0, -0.07808863371610641, 'btn distance=3')
#     (0.0, 0, 0.07531379163265228, 'btn distance=2')
#     (-0.0, 0, -0.04036684334278107, 'btn distance=1')
#     (-0.0, 0, -0.241798534989357, 'btn distance=0')
#     (-0.0, 0, -0.012274674139916897, 'round level 27')
#     (-0.0, 0, -0.1700371652841568, 'round level 26')
#     (-0.0, 0, -0.06231385096907616, 'round level 25')
#     (-0.0, 0, -0.19142040610313416, 'round level 24')
#     (0.0, 0, 0.0052865338511765, 'round level 23')
#     (0.0, 0, 0.10509058088064194, 'round level 22')
#     (0.0, 0, 0.148484006524086, 'round level 21')
#     (-0.0, 0, -0.2335253208875656, 'round level 20')
#     (0.0, 0, 0.024247899651527405, 'round level 19')
#     (0.0, 0, 0.24292117357254028, 'round level 18')
#     (0.0, 0, 0.059873905032873154, 'round level 17')
#     (0.0, 0, 0.13325431942939758, 'round level 16')
#     (0.0, 0, 0.12490264326334, 'round level 15')
#     (0.0, 0, 0.17109589278697968, 'round level 14')
#     (-0.0, 0, -0.23500089347362518, 'round level 13')
#     (0.0, 0, 0.1816813349723816, 'round level 12')
#     (-0.0, 0, -0.14072857797145844, 'round level 11')
#     (-0.0, 0, -0.02639414370059967, 'round level 10')
#     (-0.0, 0, -0.12533557415008545, 'round level 9')
#     (0.0, 0, 0.21444687247276306, 'round level 8')
#     (0.0, 0, 0.2577686905860901, 'round level 7')
#     (-0.0, 0, -0.020569249987602234, 'round level 6')
#     (-0.0, 0, -0.08953545987606049, 'round level 5')
#     (-0.0, 0, -0.13333763182163239, 'round level 4')
#     (-0.0, 0, -0.00587732857093215, 'round level 3')
#     (0.0, 0, 0.05715208500623703, 'round level 1')
#
# linear combination for triple_raise :
#     (-2.5654096603393555, 1, -2.5654096603393555, 'round level 2')
#     (-2.3724327, 0, 0, 'bias')
#     (-2.242950439453125, 1, -2.242950439453125, 'player-0:state-active')
#     (1.8543310165405273, 1, 1.8543310165405273, 'btn distance=6')
#     (1.4920952320098877, 1, 1.4920952320098877, 'player-9:state-active')
#     (1.1818435192108154, 1, 1.1818435192108154, 'player-7:state-fold')
#     (-0.8888930082321167, 1, -0.8888930082321167, 'street-preflop')
#     (0.8872708678245544, 0.5, 1.7745417356491089, 'player-9:history')
#     (0.8314283490180969, 1, 0.8314283490180969, 'player-2:state-active')
#     (0.6933884620666504, 0.16666666666666666, 4.160330772399902, 'player-5:history')
#     (0.6820471882820129, 1, 0.6820471882820129, 'player-5:state-active')
#     (0.658285915851593, 1, 0.658285915851593, 'player-1:state-active')
#     (0.5164560675621033, 1, 0.5164560675621033, 'player-4:state-active')
#     (0.5151159167289734, 1, 0.5151159167289734, 'player-6:state-active')
#     (0.3644866645336151, 1, 0.3644866645336151, 'player-8:state-fold')
#     (-0.3222849369049072, 0.1, -3.2228493690490723, 'player-1:stack')
#     (0.2746110955874125, 0.3333333333333333, 0.8238332867622375, 'player-6:history')
#     (-0.2414394625425339, 0.0995, -2.426527261734009, 'player-6:stack')
#     (-0.21250860691070558, 0.1, -2.1250860691070557, 'player-7:stack')
#     (-0.20555657887458803, 0.09975, -2.0607175827026367, 'player-5:stack')
#     (-0.19778493642807007, 0.1, -1.9778493642807007, 'player-8:stack')
#     (-0.19321404695510866, 0.1, -1.9321404695510864, 'player-3:stack')
#     (-0.184048068523407, 0.1, -1.8404806852340698, 'player-2:stack')
#     (-0.17889500242471695, 0.09925, -1.8024685382843018, 'player-9:stack')
#     (-0.16303051710128785, 0.1, -1.6303051710128784, 'player-4:stack')
#     (0.11180011928081512, 1, 0.11180011928081512, 'player-3:state-active')
#     (-0.09695944786071778, 0.1, -0.9695944786071777, 'player-0:stack')
#     (-0.0062749872207641605, 0.0015, -4.183324813842773, 'pot')
#     (-0.005857018461450934, 0.622, -0.00941642839461565, 'cards')
#     (0.0, 0, 1.7017498016357422, 'player-9:state-fold')
#     (0.0, 0.0, 1.4680891036987305, 'player-8:history')
#     (0.0, 0, 1.5621132850646973, 'player-8:state-active')
#     (0.0, 0.0, 1.582472324371338, 'player-7:history')
#     (0.0, 0, 1.2232623100280762, 'player-7:state-active')
#     (0.0, 0, 0.3370206356048584, 'player-6:state-fold')
#     (0.0, 0, 1.3701834678649902, 'player-5:state-fold')
#     (0.0, 0.0, 0.9121751189231873, 'player-4:history')
#     (0.0, 0, 0.6458732485771179, 'player-4:state-fold')
#     (0.0, 0.0, 0.9788299798965454, 'player-3:history')
#     (0.0, 0, 0.09074126929044724, 'player-3:state-fold')
#     (0.0, 0.0, 0.5327305793762207, 'player-2:history')
#     (0.0, 0, 0.7871614098548889, 'player-2:state-fold')
#     (0.0, 0.0, 0.6838011741638184, 'player-1:history')
#     (0.0, 0, 0.38340216875076294, 'player-1:state-fold')
#     (0.0, 0.0, 0.6423398852348328, 'player-0:history')
#     (-0.0, 0, -0.23924040794372559, 'player-0:state-fold')
#     (-0.0, 0, -0.5806674361228943, 'street-river')
#     (-0.0, 0, -0.7105857729911804, 'street-turn')
#     (-0.0, 0, -0.7075456380844116, 'street-flop')
#     (-0.0, 0, -0.1619005799293518, 'btn distance=9')
#     (-0.0, 0, -0.11413408070802689, 'btn distance=8')
#     (-0.0, 0, -0.12604860961437225, 'btn distance=7')
#     (0.0, 0, 1.973375678062439, 'btn distance=5')
#     (0.0, 0, 0.4832393229007721, 'btn distance=4')
#     (0.0, 0, 0.21936601400375366, 'btn distance=3')
#     (0.0, 0, 0.21691006422042847, 'btn distance=2')
#     (0.0, 0, 0.0388103649020195, 'btn distance=1')
#     (-0.0, 0, -0.15196388959884644, 'btn distance=0')
#     (-0.0, 0, -0.24565012753009796, 'round level 27')
#     (0.0, 0, 0.18738245964050293, 'round level 26')
#     (0.0, 0, 0.13563582301139832, 'round level 25')
#     (0.0, 0, 0.0051093026995658875, 'round level 24')
#     (0.0, 0, 0.15698617696762085, 'round level 23')
#     (-0.0, 0, -0.25703445076942444, 'round level 22')
#     (-0.0, 0, -0.2061779946088791, 'round level 21')
#     (-0.0, 0, -0.041454460471868515, 'round level 20')
#     (-0.0, 0, -0.09786731749773026, 'round level 19')
#     (-0.0, 0, -0.1264774352312088, 'round level 18')
#     (0.0, 0, 0.24566134810447693, 'round level 17')
#     (-0.0, 0, -0.1010018065571785, 'round level 16')
#     (-0.0, 0, -0.020011145621538162, 'round level 15')
#     (-0.0, 0, -0.05574813857674599, 'round level 14')
#     (-0.0, 0, -0.08178351819515228, 'round level 13')
#     (0.0, 0, 0.18671230971813202, 'round level 12')
#     (-0.0, 0, -0.05788012966513634, 'round level 11')
#     (-0.0, 0, -0.13147558271884918, 'round level 10')
#     (-0.0, 0, -0.23238608241081238, 'round level 9')
#     (-0.0, 0, -0.1202930361032486, 'round level 8')
#     (-0.0, 0, -0.12012208253145218, 'round level 7')
#     (-0.0, 0, -0.09084489941596985, 'round level 6')
#     (-0.0, 0, -0.057835355401039124, 'round level 5')
#     (-0.0, 0, -0.01247967779636383, 'round level 4')
#     (-0.0, 0, -0.2314309924840927, 'round level 3')
#     (0.0, 0, 0.10510239750146866, 'round level 1')
#
# linear combination for max_raise :
#     (-1.3251365423202515, 1, -1.3251365423202515, 'player-0:state-active')
#     (-1.1046034, 0, 0, 'bias')
#     (-0.8862913250923157, 1, -0.8862913250923157, 'round level 2')
#     (0.6906992197036743, 1, 0.6906992197036743, 'player-9:state-active')
#     (0.6775450706481934, 1, 0.6775450706481934, 'player-3:state-active')
#     (0.632209837436676, 1, 0.632209837436676, 'player-7:state-fold')
#     (0.5216233730316162, 1, 0.5216233730316162, 'btn distance=6')
#     (0.3826307952404022, 1, 0.3826307952404022, 'player-4:state-active')
#     (0.3420032560825348, 1, 0.3420032560825348, 'street-preflop')
#     (0.3167867660522461, 0.5, 0.6335735321044922, 'player-9:history')
#     (-0.28196588158607483, 1, -0.28196588158607483, 'player-8:state-fold')
#     (0.2646414041519165, 1, 0.2646414041519165, 'player-2:state-active')
#     (0.2176381746927897, 0.16666666666666666, 1.3058290481567383, 'player-5:history')
#     (-0.17161058187484743, 0.1, -1.7161058187484741, 'player-7:stack')
#     (0.16865608096122742, 1, 0.16865608096122742, 'player-5:state-active')
#     (-0.15172435462474823, 0.09975, -1.5210461616516113, 'player-5:stack')
#     (-0.1408655856847763, 0.0995, -1.4157345294952393, 'player-6:stack')
#     (-0.11298981904983521, 0.1, -1.129898190498352, 'player-4:stack')
#     (-0.09582640713453293, 0.09925, -0.9655053615570068, 'player-9:stack')
#     (-0.09473544359207153, 0.1, -0.9473544359207153, 'player-2:stack')
#     (0.09468989819288254, 1, 0.09468989819288254, 'player-1:state-active')
#     (0.08407319585482279, 0.3333333333333333, 0.2522195875644684, 'player-6:history')
#     (0.07842633128166199, 0.1, 0.7842633128166199, 'player-0:stack')
#     (-0.06652165651321411, 0.1, -0.6652165651321411, 'player-8:stack')
#     (0.064662866294384, 1, 0.064662866294384, 'player-6:state-active')
#     (-0.043883422017097475, 0.1, -0.43883422017097473, 'player-1:stack')
#     (0.018775761108845473, 0.622, 0.030186111107468605, 'cards')
#     (-0.017020438611507416, 0.1, -0.17020438611507416, 'player-3:stack')
#     (0.0005212453454732894, 0.0015, 0.347496896982193, 'pot')
#     (0.0, 0, 0.44052013754844666, 'player-9:state-fold')
#     (0.0, 0.0, 0.1239309161901474, 'player-8:history')
#     (0.0, 0, 0.09257758408784866, 'player-8:state-active')
#     (0.0, 0.0, 0.6136317849159241, 'player-7:history')
#     (0.0, 0, 0.9286585450172424, 'player-7:state-active')
#     (-0.0, 0, -0.004348215647041798, 'player-6:state-fold')
#     (0.0, 0, 0.3320745527744293, 'player-5:state-fold')
#     (0.0, 0.0, 0.478394091129303, 'player-4:history')
#     (0.0, 0, 0.48257705569267273, 'player-4:state-fold')
#     (0.0, 0.0, 0.8370112776756287, 'player-3:history')
#     (0.0, 0, 0.6391070485115051, 'player-3:state-fold')
#     (-0.0, 0.0, -1.0136412382125854, 'player-2:history')
#     (0.0, 0, 0.173703134059906, 'player-2:state-fold')
#     (0.0, 0.0, 0.25422853231430054, 'player-1:history')
#     (-0.0, 0, -0.051687128841876984, 'player-1:state-fold')
#     (0.0, 0.0, 0.7255996465682983, 'player-0:history')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.6425154805183411, 'street-river')
#     (0.0, 0, 0.5084975957870483, 'street-turn')
#     (0.0, 0, 0.5016143321990967, 'street-flop')
#     (-0.0, 0, -0.10669941455125809, 'btn distance=9')
#     (0.0, 0, 0.234825998544693, 'btn distance=8')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.5480400919914246, 'btn distance=5')
#     (0.0, 0, 0.18136386573314667, 'btn distance=4')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')

# %% [markdown]
# ### FOLD する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 250
#   - raise: [400, 10000]
# -- hole card --
#   - ['HT', 'D5']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 425, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9750
#     - 6 : agent (uuid-0) => state : participating, stack : 9900 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'agent (uuid=uuid-0)', 'amount': 100, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'add_amount': 150, 'paid': 175, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 250, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', -0.07645630836486816), ('call', -0.2018204927444458), ('min_raise', -0.2502269744873047), ('double_raise', -0.08517074584960938), ('triple_raise', -0.3827943801879883), ('max_raise', -0.09220874309539795)]
# ** weights and features in detail **
# bias : [-2.24537802 -2.14030123 -2.49615192 -2.38752079 -2.37243271 -1.10460341]
#
# linear combination for fold :
#     (-2.431051731109619, 1, -2.431051731109619, 'round level 2')
#     (-2.245378, 0, 0, 'bias')
#     (-2.218794345855713, 1, -2.218794345855713, 'player-0:state-active')
#     (-2.0704636573791504, 1, -2.0704636573791504, 'player-7:state-fold')
#     (1.7820357084274292, 1, 1.7820357084274292, 'player-5:state-fold')
#     (1.7078877687454224, 1, 1.7078877687454224, 'player-1:state-fold')
#     (1.6409307718276978, 1, 1.6409307718276978, 'player-6:state-fold')
#     (1.6157982349395752, 1, 1.6157982349395752, 'player-3:state-fold')
#     (1.4899870157241821, 1, 1.4899870157241821, 'player-4:state-fold')
#     (1.1088765859603882, 1, 1.1088765859603882, 'player-2:state-fold')
#     (0.8168973922729492, 1, 0.8168973922729492, 'player-9:state-active')
#     (0.41425007231095257, 0.5882352941176471, 0.7042251229286194, 'player-9:history')
#     (-0.3098161518573761, 1, -0.3098161518573761, 'player-8:state-fold')
#     (0.2496198485879337, 0.23529411764705882, 1.0608843564987183, 'player-0:history')
#     (-0.22828711569309235, 1, -0.22828711569309235, 'btn distance=6')
#     (-0.22798677551746369, 0.0995, -2.2913243770599365, 'player-6:stack')
#     (-0.21541132628917695, 0.09975, -2.1595120429992676, 'player-5:stack')
#     (-0.19724332094192507, 0.1, -1.9724332094192505, 'player-7:stack')
#     (0.1943889558315277, 1, 0.1943889558315277, 'street-preflop')
#     (-0.17302608489990234, 0.1, -1.7302608489990234, 'player-8:stack')
#     (-0.1693753242492676, 0.1, -1.6937532424926758, 'player-4:stack')
#     (-0.16680443286895752, 0.1, -1.6680443286895752, 'player-1:stack')
#     (-0.13382815122604372, 0.1, -1.338281512260437, 'player-2:stack')
#     (-0.12946386247873307, 0.0975, -1.3278344869613647, 'player-9:stack')
#     (-0.12089370489120484, 0.1, -1.2089370489120483, 'player-3:stack')
#     (-0.030807486355304718, 0.099, -0.3111867308616638, 'player-0:stack')
#     (-0.02439675723016262, 0.622, -0.0392230823636055, 'cards')
#     (-0.004100334644317628, 0.00425, -0.9647846221923828, 'pot')
#     (0.0, 0, 0.5911204218864441, 'player-9:state-fold')
#     (0.0, 0.0, 1.086035966873169, 'player-8:history')
#     (0.0, 0, 0.7840678095817566, 'player-8:state-active')
#     (0.0, 0.0, 0.15181133151054382, 'player-7:history')
#     (-0.0, 0, -1.5541051626205444, 'player-7:state-active')
#     (0.0, 0.0, 1.1388506889343262, 'player-6:history')
#     (0.0, 0, 1.8243247270584106, 'player-6:state-active')
#     (0.0, 0.0, 2.2844033241271973, 'player-5:history')
#     (0.0, 0, 1.9195448160171509, 'player-5:state-active')
#     (0.0, 0.0, 0.05564766377210617, 'player-4:history')
#     (0.0, 0, 1.558862328529358, 'player-4:state-active')
#     (0.0, 0.0, 1.0570818185806274, 'player-3:history')
#     (0.0, 0, 1.5222080945968628, 'player-3:state-active')
#     (0.0, 0.0, 0.8161777853965759, 'player-2:history')
#     (0.0, 0, 1.0325573682785034, 'player-2:state-active')
#     (0.0, 0.0, 0.23884399235248566, 'player-1:history')
#     (0.0, 0, 1.1019710302352905, 'player-1:state-active')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.3334566652774811, 'street-river')
#     (0.0, 0, 0.343752384185791, 'street-turn')
#     (0.0, 0, 0.5796384215354919, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.12463589757680893, 'btn distance=5')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-2.2445640563964844, 1, -2.2445640563964844, 'player-0:state-active')
#     (-2.1403012, 0, 0, 'bias')
#     (-2.0760812759399414, 1, -2.0760812759399414, 'round level 2')
#     (1.8865877389907837, 1, 1.8865877389907837, 'player-9:state-active')
#     (1.8069616556167603, 1, 1.8069616556167603, 'btn distance=6')
#     (1.0968955755233765, 1, 1.0968955755233765, 'player-4:state-fold')
#     (1.0955553195055794, 0.5882352941176471, 1.8624440431594849, 'player-9:history')
#     (0.9013826251029968, 1, 0.9013826251029968, 'player-1:state-fold')
#     (0.48425977370318246, 0.23529411764705882, 2.0581040382385254, 'player-0:history')
#     (-0.3545590043067932, 1, -0.3545590043067932, 'player-7:state-fold')
#     (0.3408045768737793, 1, 0.3408045768737793, 'player-2:state-fold')
#     (-0.3125944137573242, 1, -0.3125944137573242, 'player-8:state-fold')
#     (0.2964814305305481, 1, 0.2964814305305481, 'player-3:state-fold')
#     (-0.151426137059927, 0.09975, -1.5180565118789673, 'player-5:stack')
#     (-0.14356182515621185, 1, -0.14356182515621185, 'player-5:state-fold')
#     (-0.1355175161957741, 0.0995, -1.3619850873947144, 'player-6:stack')
#     (-0.12220861911773682, 0.1, -1.2220861911773682, 'player-7:stack')
#     (-0.09908056855201722, 0.1, -0.9908056855201721, 'player-1:stack')
#     (-0.09878257602453232, 0.0975, -1.0131546258926392, 'player-9:stack')
#     (-0.08827736228704453, 1, -0.08827736228704453, 'street-preflop')
#     (-0.0729588806629181, 0.1, -0.7295888066291809, 'player-8:stack')
#     (-0.06702187657356262, 1, -0.06702187657356262, 'player-6:state-fold')
#     (-0.06614058613777161, 0.1, -0.6614058613777161, 'player-2:stack')
#     (0.040139510303735734, 0.099, 0.40544959902763367, 'player-0:stack')
#     (0.03658467829227448, 0.1, 0.36584678292274475, 'player-4:stack')
#     (-0.021985971927642824, 0.1, -0.21985971927642822, 'player-3:stack')
#     (0.00920182423852384, 0.622, 0.014793929643929005, 'cards')
#     (-0.0016132862716913225, 0.00425, -0.3795967698097229, 'pot')
#     (0.0, 0, 1.4917446374893188, 'player-9:state-fold')
#     (0.0, 0.0, 0.617439329624176, 'player-8:history')
#     (0.0, 0, 0.7037453651428223, 'player-8:state-active')
#     (0.0, 0.0, 1.068838119506836, 'player-7:history')
#     (0.0, 0, 0.5837045907974243, 'player-7:state-active')
#     (0.0, 0.0, 1.4711203575134277, 'player-6:history')
#     (0.0, 0, 0.4035125970840454, 'player-6:state-active')
#     (0.0, 0.0, 1.1949214935302734, 'player-5:history')
#     (0.0, 0, 0.26324620842933655, 'player-5:state-active')
#     (0.0, 0.0, 1.6109318733215332, 'player-4:history')
#     (0.0, 0, 0.7556829452514648, 'player-4:state-active')
#     (0.0, 0.0, 2.3010153770446777, 'player-3:history')
#     (0.0, 0, 0.19035984575748444, 'player-3:state-active')
#     (0.0, 0.0, 0.8736161589622498, 'player-2:history')
#     (0.0, 0, 0.28508293628692627, 'player-2:state-active')
#     (0.0, 0.0, 0.9040548205375671, 'player-1:history')
#     (0.0, 0, 0.5820401906967163, 'player-1:state-active')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (0.0, 0, 0.1361539363861084, 'street-river')
#     (0.0, 0, 0.12363648414611816, 'street-turn')
#     (0.0, 0, 0.138866126537323, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 1.8200968503952026, 'btn distance=5')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.6741485595703125, 1, -2.6741485595703125, 'round level 2')
#     (-2.5425000190734863, 1, -2.5425000190734863, 'player-0:state-active')
#     (-2.4961519, 0, 0, 'bias')
#     (2.2141034603118896, 1, 2.2141034603118896, 'player-9:state-active')
#     (1.4792786836624146, 1, 1.4792786836624146, 'btn distance=6')
#     (1.1311455965042114, 1, 1.1311455965042114, 'player-1:state-fold')
#     (1.016905097400441, 0.5882352941176471, 1.7287386655807495, 'player-9:history')
#     (0.7674608826637268, 1, 0.7674608826637268, 'player-2:state-fold')
#     (0.6914798617362976, 1, 0.6914798617362976, 'player-5:state-fold')
#     (0.5677550435066223, 1, 0.5677550435066223, 'player-4:state-fold')
#     (0.4207422137260437, 1, 0.4207422137260437, 'player-6:state-fold')
#     (0.39983561459709616, 0.23529411764705882, 1.6993013620376587, 'player-0:history')
#     (0.36654409766197205, 1, 0.36654409766197205, 'player-7:state-fold')
#     (0.30986031889915466, 1, 0.30986031889915466, 'player-8:state-fold')
#     (-0.25397777557373047, 0.1, -2.5397777557373047, 'player-1:stack')
#     (-0.2510509308576584, 0.0995, -2.523124933242798, 'player-6:stack')
#     (-0.19676381608843804, 0.09975, -1.9725695848464966, 'player-5:stack')
#     (-0.18543928861618042, 0.1, -1.8543928861618042, 'player-7:stack')
#     (-0.17838003516197204, 0.0975, -1.8295388221740723, 'player-9:stack')
#     (-0.16726447343826295, 0.1, -1.6726447343826294, 'player-2:stack')
#     (-0.15637184381484986, 0.1, -1.5637184381484985, 'player-8:stack')
#     (-0.15340092182159426, 0.1, -1.5340092182159424, 'player-3:stack')
#     (-0.14664705991744995, 0.1, -1.4664705991744995, 'player-4:stack')
#     (-0.11383439600467682, 1, -0.11383439600467682, 'street-preflop')
#     (-0.06968580883741379, 0.099, -0.7038970589637756, 'player-0:stack')
#     (-0.03342190384864807, 1, -0.03342190384864807, 'player-3:state-fold')
#     (0.011435995157808066, 0.622, 0.01838584430515766, 'cards')
#     (-0.007735295087099076, 0.00425, -1.820069432258606, 'pot')
#     (0.0, 0, 2.033776044845581, 'player-9:state-fold')
#     (0.0, 0.0, 1.2142130136489868, 'player-8:history')
#     (0.0, 0, 1.3269157409667969, 'player-8:state-active')
#     (0.0, 0.0, 1.401948094367981, 'player-7:history')
#     (0.0, 0, 1.0241550207138062, 'player-7:state-active')
#     (0.0, 0.0, 1.2207356691360474, 'player-6:history')
#     (0.0, 0, 0.6351824402809143, 'player-6:state-active')
#     (0.0, 0.0, 3.619497537612915, 'player-5:history')
#     (0.0, 0, 0.709435760974884, 'player-5:state-active')
#     (0.0, 0.0, 1.1321343183517456, 'player-4:history')
#     (0.0, 0, 0.43497592210769653, 'player-4:state-active')
#     (0.0, 0.0, 2.0687448978424072, 'player-3:history')
#     (-0.0, 0, -0.1426054686307907, 'player-3:state-active')
#     (0.0, 0.0, 0.5935136675834656, 'player-2:history')
#     (0.0, 0, 0.7028936743736267, 'player-2:state-active')
#     (0.0, 0.0, 1.0035585165023804, 'player-1:history')
#     (0.0, 0, 1.1605361700057983, 'player-1:state-active')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.04107475280761719, 'street-river')
#     (0.0, 0, 0.026161091402173042, 'street-turn')
#     (-0.0, 0, -0.02991003915667534, 'street-flop')
#     (-0.0, 0, -0.1774212121963501, 'btn distance=9')
#     (-0.0, 0, -0.047159694135189056, 'btn distance=8')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 1.4675281047821045, 'btn distance=5')
#     (0.0, 0, 0.5843061804771423, 'btn distance=4')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for double_raise :
#     (-2.5915870666503906, 1, -2.5915870666503906, 'player-0:state-active')
#     (-2.3875208, 0, 0, 'bias')
#     (-2.1957459449768066, 1, -2.1957459449768066, 'round level 2')
#     (1.7864481210708618, 1, 1.7864481210708618, 'btn distance=6')
#     (1.4783991575241089, 1, 1.4783991575241089, 'player-9:state-active')
#     (1.3565353155136108, 1, 1.3565353155136108, 'player-7:state-fold')
#     (1.0576352652381449, 0.5882352941176471, 1.7979799509048462, 'player-9:history')
#     (0.902125358581543, 1, 0.902125358581543, 'player-2:state-fold')
#     (0.7188841104507446, 1, 0.7188841104507446, 'player-5:state-fold')
#     (0.4836919605731964, 1, 0.4836919605731964, 'player-4:state-fold')
#     (0.4559221565723419, 1, 0.4559221565723419, 'player-3:state-fold')
#     (-0.25168015038967134, 0.0995, -2.5294487476348877, 'player-6:stack')
#     (0.20732176303863525, 1, 0.20732176303863525, 'player-1:state-fold')
#     (-0.20290050506591797, 0.1, -2.0290050506591797, 'player-1:stack')
#     (-0.19800236225128176, 0.1, -1.9800236225128174, 'player-7:stack')
#     (0.1973874717950821, 1, 0.1973874717950821, 'player-8:state-fold')
#     (-0.19426556172966958, 0.09975, -1.9475244283676147, 'player-5:stack')
#     (-0.17938907146453859, 0.1, -1.7938907146453857, 'player-2:stack')
#     (0.17752692278693705, 0.23529411764705882, 0.7544894218444824, 'player-0:history')
#     (-0.17708672285079957, 0.1, -1.7708672285079956, 'player-3:stack')
#     (-0.17377007693052293, 0.0975, -1.7822571992874146, 'player-9:stack')
#     (-0.13466938734054565, 0.1, -1.3466938734054565, 'player-8:stack')
#     (-0.13437527418136597, 0.1, -1.3437527418136597, 'player-4:stack')
#     (-0.10949435830116272, 1, -0.10949435830116272, 'street-preflop')
#     (0.09614922106266022, 1, 0.09614922106266022, 'player-6:state-fold')
#     (-0.08160746937990189, 0.099, -0.8243178725242615, 'player-0:stack')
#     (0.02128782607614994, 0.622, 0.034224800765514374, 'cards')
#     (-0.01239085340499878, 0.00425, -2.915494918823242, 'pot')
#     (0.0, 0, 1.7065824270248413, 'player-9:state-fold')
#     (0.0, 0.0, 1.4511357545852661, 'player-8:history')
#     (0.0, 0, 1.307974100112915, 'player-8:state-active')
#     (0.0, 0.0, 1.5180848836898804, 'player-7:history')
#     (0.0, 0, 1.5541554689407349, 'player-7:state-active')
#     (0.0, 0.0, 0.6093665361404419, 'player-6:history')
#     (0.0, 0, 0.29325035214424133, 'player-6:state-active')
#     (0.0, 0.0, 4.2742438316345215, 'player-5:history')
#     (0.0, 0, 0.005027344916015863, 'player-5:state-active')
#     (0.0, 0.0, 0.8796502351760864, 'player-4:history')
#     (0.0, 0, 0.3248136341571808, 'player-4:state-active')
#     (0.0, 0.0, 1.0582114458084106, 'player-3:history')
#     (0.0, 0, 0.36283689737319946, 'player-3:state-active')
#     (0.0, 0.0, 0.5237418413162231, 'player-2:history')
#     (0.0, 0, 0.8493184447288513, 'player-2:state-active')
#     (0.0, 0.0, 0.791723906993866, 'player-1:history')
#     (0.0, 0, 0.6920390725135803, 'player-1:state-active')
#     (0.0, 0, 0.1994665414094925, 'player-0:state-fold')
#     (0.0, 0, 0.18096104264259338, 'street-river')
#     (0.0, 0, 0.015104751102626324, 'street-turn')
#     (-0.0, 0, -0.11874984204769135, 'street-flop')
#     (0.0, 0, 0.16180437803268433, 'btn distance=9')
#     (-0.0, 0, -0.16994917392730713, 'btn distance=8')
#     (-0.0, 0, -0.2551056444644928, 'btn distance=7')
#     (0.0, 0, 1.8671458959579468, 'btn distance=5')
#     (0.0, 0, 0.2912150025367737, 'btn distance=4')
#     (-0.0, 0, -0.07808863371610641, 'btn distance=3')
#     (0.0, 0, 0.07531379163265228, 'btn distance=2')
#     (-0.0, 0, -0.04036684334278107, 'btn distance=1')
#     (-0.0, 0, -0.241798534989357, 'btn distance=0')
#     (-0.0, 0, -0.012274674139916897, 'round level 27')
#     (-0.0, 0, -0.1700371652841568, 'round level 26')
#     (-0.0, 0, -0.06231385096907616, 'round level 25')
#     (-0.0, 0, -0.19142040610313416, 'round level 24')
#     (0.0, 0, 0.0052865338511765, 'round level 23')
#     (0.0, 0, 0.10509058088064194, 'round level 22')
#     (0.0, 0, 0.148484006524086, 'round level 21')
#     (-0.0, 0, -0.2335253208875656, 'round level 20')
#     (0.0, 0, 0.024247899651527405, 'round level 19')
#     (0.0, 0, 0.24292117357254028, 'round level 18')
#     (0.0, 0, 0.059873905032873154, 'round level 17')
#     (0.0, 0, 0.13325431942939758, 'round level 16')
#     (0.0, 0, 0.12490264326334, 'round level 15')
#     (0.0, 0, 0.17109589278697968, 'round level 14')
#     (-0.0, 0, -0.23500089347362518, 'round level 13')
#     (0.0, 0, 0.1816813349723816, 'round level 12')
#     (-0.0, 0, -0.14072857797145844, 'round level 11')
#     (-0.0, 0, -0.02639414370059967, 'round level 10')
#     (-0.0, 0, -0.12533557415008545, 'round level 9')
#     (0.0, 0, 0.21444687247276306, 'round level 8')
#     (0.0, 0, 0.2577686905860901, 'round level 7')
#     (-0.0, 0, -0.020569249987602234, 'round level 6')
#     (-0.0, 0, -0.08953545987606049, 'round level 5')
#     (-0.0, 0, -0.13333763182163239, 'round level 4')
#     (-0.0, 0, -0.00587732857093215, 'round level 3')
#     (0.0, 0, 0.05715208500623703, 'round level 1')
#
# linear combination for triple_raise :
#     (-2.5654096603393555, 1, -2.5654096603393555, 'round level 2')
#     (-2.3724327, 0, 0, 'bias')
#     (-2.242950439453125, 1, -2.242950439453125, 'player-0:state-active')
#     (1.8543310165405273, 1, 1.8543310165405273, 'btn distance=6')
#     (1.4920952320098877, 1, 1.4920952320098877, 'player-9:state-active')
#     (1.3701834678649902, 1, 1.3701834678649902, 'player-5:state-fold')
#     (1.1818435192108154, 1, 1.1818435192108154, 'player-7:state-fold')
#     (1.0438480797935934, 0.5882352941176471, 1.7745417356491089, 'player-9:history')
#     (-0.8888930082321167, 1, -0.8888930082321167, 'street-preflop')
#     (0.7871614098548889, 1, 0.7871614098548889, 'player-2:state-fold')
#     (0.6458732485771179, 1, 0.6458732485771179, 'player-4:state-fold')
#     (0.38340216875076294, 1, 0.38340216875076294, 'player-1:state-fold')
#     (0.3644866645336151, 1, 0.3644866645336151, 'player-8:state-fold')
#     (0.3370206356048584, 1, 0.3370206356048584, 'player-6:state-fold')
#     (-0.3222849369049072, 0.1, -3.2228493690490723, 'player-1:stack')
#     (-0.2414394625425339, 0.0995, -2.426527261734009, 'player-6:stack')
#     (-0.21250860691070558, 0.1, -2.1250860691070557, 'player-7:stack')
#     (-0.20555657887458803, 0.09975, -2.0607175827026367, 'player-5:stack')
#     (-0.19778493642807007, 0.1, -1.9778493642807007, 'player-8:stack')
#     (-0.19321404695510866, 0.1, -1.9321404695510864, 'player-3:stack')
#     (-0.184048068523407, 0.1, -1.8404806852340698, 'player-2:stack')
#     (-0.17574068248271943, 0.0975, -1.8024685382843018, 'player-9:stack')
#     (-0.16303051710128785, 0.1, -1.6303051710128784, 'player-4:stack')
#     (0.151138796525843, 0.23529411764705882, 0.6423398852348328, 'player-0:history')
#     (-0.09598985338211061, 0.099, -0.9695944786071777, 'player-0:stack')
#     (0.09074126929044724, 1, 0.09074126929044724, 'player-3:state-fold')
#     (-0.01777913045883179, 0.00425, -4.183324813842773, 'pot')
#     (-0.005857018461450934, 0.622, -0.00941642839461565, 'cards')
#     (0.0, 0, 1.7017498016357422, 'player-9:state-fold')
#     (0.0, 0.0, 1.4680891036987305, 'player-8:history')
#     (0.0, 0, 1.5621132850646973, 'player-8:state-active')
#     (0.0, 0.0, 1.582472324371338, 'player-7:history')
#     (0.0, 0, 1.2232623100280762, 'player-7:state-active')
#     (0.0, 0.0, 0.8238332867622375, 'player-6:history')
#     (0.0, 0, 0.5151159167289734, 'player-6:state-active')
#     (0.0, 0.0, 4.160330772399902, 'player-5:history')
#     (0.0, 0, 0.6820471882820129, 'player-5:state-active')
#     (0.0, 0.0, 0.9121751189231873, 'player-4:history')
#     (0.0, 0, 0.5164560675621033, 'player-4:state-active')
#     (0.0, 0.0, 0.9788299798965454, 'player-3:history')
#     (0.0, 0, 0.11180011928081512, 'player-3:state-active')
#     (0.0, 0.0, 0.5327305793762207, 'player-2:history')
#     (0.0, 0, 0.8314283490180969, 'player-2:state-active')
#     (0.0, 0.0, 0.6838011741638184, 'player-1:history')
#     (0.0, 0, 0.658285915851593, 'player-1:state-active')
#     (-0.0, 0, -0.23924040794372559, 'player-0:state-fold')
#     (-0.0, 0, -0.5806674361228943, 'street-river')
#     (-0.0, 0, -0.7105857729911804, 'street-turn')
#     (-0.0, 0, -0.7075456380844116, 'street-flop')
#     (-0.0, 0, -0.1619005799293518, 'btn distance=9')
#     (-0.0, 0, -0.11413408070802689, 'btn distance=8')
#     (-0.0, 0, -0.12604860961437225, 'btn distance=7')
#     (0.0, 0, 1.973375678062439, 'btn distance=5')
#     (0.0, 0, 0.4832393229007721, 'btn distance=4')
#     (0.0, 0, 0.21936601400375366, 'btn distance=3')
#     (0.0, 0, 0.21691006422042847, 'btn distance=2')
#     (0.0, 0, 0.0388103649020195, 'btn distance=1')
#     (-0.0, 0, -0.15196388959884644, 'btn distance=0')
#     (-0.0, 0, -0.24565012753009796, 'round level 27')
#     (0.0, 0, 0.18738245964050293, 'round level 26')
#     (0.0, 0, 0.13563582301139832, 'round level 25')
#     (0.0, 0, 0.0051093026995658875, 'round level 24')
#     (0.0, 0, 0.15698617696762085, 'round level 23')
#     (-0.0, 0, -0.25703445076942444, 'round level 22')
#     (-0.0, 0, -0.2061779946088791, 'round level 21')
#     (-0.0, 0, -0.041454460471868515, 'round level 20')
#     (-0.0, 0, -0.09786731749773026, 'round level 19')
#     (-0.0, 0, -0.1264774352312088, 'round level 18')
#     (0.0, 0, 0.24566134810447693, 'round level 17')
#     (-0.0, 0, -0.1010018065571785, 'round level 16')
#     (-0.0, 0, -0.020011145621538162, 'round level 15')
#     (-0.0, 0, -0.05574813857674599, 'round level 14')
#     (-0.0, 0, -0.08178351819515228, 'round level 13')
#     (0.0, 0, 0.18671230971813202, 'round level 12')
#     (-0.0, 0, -0.05788012966513634, 'round level 11')
#     (-0.0, 0, -0.13147558271884918, 'round level 10')
#     (-0.0, 0, -0.23238608241081238, 'round level 9')
#     (-0.0, 0, -0.1202930361032486, 'round level 8')
#     (-0.0, 0, -0.12012208253145218, 'round level 7')
#     (-0.0, 0, -0.09084489941596985, 'round level 6')
#     (-0.0, 0, -0.057835355401039124, 'round level 5')
#     (-0.0, 0, -0.01247967779636383, 'round level 4')
#     (-0.0, 0, -0.2314309924840927, 'round level 3')
#     (0.0, 0, 0.10510239750146866, 'round level 1')
#
# linear combination for max_raise :
#     (-1.3251365423202515, 1, -1.3251365423202515, 'player-0:state-active')
#     (-1.1046034, 0, 0, 'bias')
#     (-0.8862913250923157, 1, -0.8862913250923157, 'round level 2')
#     (0.6906992197036743, 1, 0.6906992197036743, 'player-9:state-active')
#     (0.6391070485115051, 1, 0.6391070485115051, 'player-3:state-fold')
#     (0.632209837436676, 1, 0.632209837436676, 'player-7:state-fold')
#     (0.5216233730316162, 1, 0.5216233730316162, 'btn distance=6')
#     (0.48257705569267273, 1, 0.48257705569267273, 'player-4:state-fold')
#     (0.3726903130026425, 0.5882352941176471, 0.6335735321044922, 'player-9:history')
#     (0.3420032560825348, 1, 0.3420032560825348, 'street-preflop')
#     (0.3320745527744293, 1, 0.3320745527744293, 'player-5:state-fold')
#     (-0.28196588158607483, 1, -0.28196588158607483, 'player-8:state-fold')
#     (0.173703134059906, 1, 0.173703134059906, 'player-2:state-fold')
#     (-0.17161058187484743, 0.1, -1.7161058187484741, 'player-7:stack')
#     (0.17072932860430548, 0.23529411764705882, 0.7255996465682983, 'player-0:history')
#     (-0.15172435462474823, 0.09975, -1.5210461616516113, 'player-5:stack')
#     (-0.1408655856847763, 0.0995, -1.4157345294952393, 'player-6:stack')
#     (-0.11298981904983521, 0.1, -1.129898190498352, 'player-4:stack')
#     (-0.09473544359207153, 0.1, -0.9473544359207153, 'player-2:stack')
#     (-0.09413677275180816, 0.0975, -0.9655053615570068, 'player-9:stack')
#     (0.07764206796884537, 0.099, 0.7842633128166199, 'player-0:stack')
#     (-0.06652165651321411, 0.1, -0.6652165651321411, 'player-8:stack')
#     (-0.051687128841876984, 1, -0.051687128841876984, 'player-1:state-fold')
#     (-0.043883422017097475, 0.1, -0.43883422017097473, 'player-1:stack')
#     (0.018775761108845473, 0.622, 0.030186111107468605, 'cards')
#     (-0.017020438611507416, 0.1, -0.17020438611507416, 'player-3:stack')
#     (-0.004348215647041798, 1, -0.004348215647041798, 'player-6:state-fold')
#     (0.0014768618121743203, 0.00425, 0.347496896982193, 'pot')
#     (0.0, 0, 0.44052013754844666, 'player-9:state-fold')
#     (0.0, 0.0, 0.1239309161901474, 'player-8:history')
#     (0.0, 0, 0.09257758408784866, 'player-8:state-active')
#     (0.0, 0.0, 0.6136317849159241, 'player-7:history')
#     (0.0, 0, 0.9286585450172424, 'player-7:state-active')
#     (0.0, 0.0, 0.2522195875644684, 'player-6:history')
#     (0.0, 0, 0.064662866294384, 'player-6:state-active')
#     (0.0, 0.0, 1.3058290481567383, 'player-5:history')
#     (0.0, 0, 0.16865608096122742, 'player-5:state-active')
#     (0.0, 0.0, 0.478394091129303, 'player-4:history')
#     (0.0, 0, 0.3826307952404022, 'player-4:state-active')
#     (0.0, 0.0, 0.8370112776756287, 'player-3:history')
#     (0.0, 0, 0.6775450706481934, 'player-3:state-active')
#     (-0.0, 0.0, -1.0136412382125854, 'player-2:history')
#     (0.0, 0, 0.2646414041519165, 'player-2:state-active')
#     (0.0, 0.0, 0.25422853231430054, 'player-1:history')
#     (0.0, 0, 0.09468989819288254, 'player-1:state-active')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.6425154805183411, 'street-river')
#     (0.0, 0, 0.5084975957870483, 'street-turn')
#     (0.0, 0, 0.5016143321990967, 'street-flop')
#     (-0.0, 0, -0.10669941455125809, 'btn distance=9')
#     (0.0, 0, 0.234825998544693, 'btn distance=8')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.5480400919914246, 'btn distance=5')
#     (0.0, 0, 0.18136386573314667, 'btn distance=4')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')

# %% [markdown]
# ### 再びMIN_RAISEする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 9900]
# -- hole card --
#   - ['C7', 'D7']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10175
#     - 6 : agent (uuid-0) => state : participating, stack : 9900 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 75 (min_raise) ] at round 2
#   => [('fold', -0.2554759979248047), ('call', 0.03207254409790039), ('min_raise', 0.0971369743347168), ('double_raise', 0.07180190086364746), ('triple_raise', -0.16949725151062012), ('max_raise', 0.010167360305786133)]
# ** weights and features in detail **
# bias : [-2.24537802 -2.14030123 -2.49615192 -2.38752079 -2.37243271 -1.10460341]
#
# linear combination for fold :
#     (-2.431051731109619, 1, -2.431051731109619, 'round level 2')
#     (-2.245378, 0, 0, 'bias')
#     (-2.218794345855713, 1, -2.218794345855713, 'player-0:state-active')
#     (1.9195448160171509, 1, 1.9195448160171509, 'player-5:state-active')
#     (1.8243247270584106, 1, 1.8243247270584106, 'player-6:state-active')
#     (1.558862328529358, 1, 1.558862328529358, 'player-4:state-active')
#     (-1.5541051626205444, 1, -1.5541051626205444, 'player-7:state-active')
#     (1.5222080945968628, 1, 1.5222080945968628, 'player-3:state-active')
#     (1.1019710302352905, 1, 1.1019710302352905, 'player-1:state-active')
#     (1.0325573682785034, 1, 1.0325573682785034, 'player-2:state-active')
#     (0.5911204218864441, 1, 0.5911204218864441, 'player-9:state-fold')
#     (0.379616896311442, 0.3333333333333333, 1.1388506889343262, 'player-6:history')
#     (-0.3098161518573761, 1, -0.3098161518573761, 'player-8:state-fold')
#     (-0.2274139444231987, 0.09925, -2.2913243770599365, 'player-6:stack')
#     (-0.21541132628917695, 0.09975, -2.1595120429992676, 'player-5:stack')
#     (-0.19625710433721544, 0.0995, -1.9724332094192505, 'player-7:stack')
#     (0.1943889558315277, 1, 0.1943889558315277, 'street-preflop')
#     (-0.17302608489990234, 0.1, -1.7302608489990234, 'player-8:stack')
#     (-0.1693753242492676, 0.1, -1.6937532424926758, 'player-4:stack')
#     (-0.16680443286895752, 0.1, -1.6680443286895752, 'player-1:stack')
#     (-0.13510715904831885, 0.10175, -1.3278344869613647, 'player-9:stack')
#     (-0.13382815122604372, 0.1, -1.338281512260437, 'player-2:stack')
#     (-0.12463589757680893, 1, -0.12463589757680893, 'btn distance=5')
#     (-0.12089370489120484, 0.1, -1.2089370489120483, 'player-3:stack')
#     (0.10120755434036255, 0.6666666666666666, 0.15181133151054382, 'player-7:history')
#     (-0.030807486355304718, 0.099, -0.3111867308616638, 'player-0:stack')
#     (-0.027848388478159902, 0.71, -0.0392230823636055, 'cards')
#     (-0.0007235884666442872, 0.00075, -0.9647846221923828, 'pot')
#     (0.0, 0.0, 0.7042251229286194, 'player-9:history')
#     (0.0, 0, 0.8168973922729492, 'player-9:state-active')
#     (0.0, 0.0, 1.086035966873169, 'player-8:history')
#     (0.0, 0, 0.7840678095817566, 'player-8:state-active')
#     (-0.0, 0, -2.0704636573791504, 'player-7:state-fold')
#     (0.0, 0, 1.6409307718276978, 'player-6:state-fold')
#     (0.0, 0.0, 2.2844033241271973, 'player-5:history')
#     (0.0, 0, 1.7820357084274292, 'player-5:state-fold')
#     (0.0, 0.0, 0.05564766377210617, 'player-4:history')
#     (0.0, 0, 1.4899870157241821, 'player-4:state-fold')
#     (0.0, 0.0, 1.0570818185806274, 'player-3:history')
#     (0.0, 0, 1.6157982349395752, 'player-3:state-fold')
#     (0.0, 0.0, 0.8161777853965759, 'player-2:history')
#     (0.0, 0, 1.1088765859603882, 'player-2:state-fold')
#     (0.0, 0.0, 0.23884399235248566, 'player-1:history')
#     (0.0, 0, 1.7078877687454224, 'player-1:state-fold')
#     (0.0, 0.0, 1.0608843564987183, 'player-0:history')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.3334566652774811, 'street-river')
#     (0.0, 0, 0.343752384185791, 'street-turn')
#     (0.0, 0, 0.5796384215354919, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.22828711569309235, 'btn distance=6')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-2.2445640563964844, 1, -2.2445640563964844, 'player-0:state-active')
#     (-2.1403012, 0, 0, 'bias')
#     (-2.0760812759399414, 1, -2.0760812759399414, 'round level 2')
#     (1.8200968503952026, 1, 1.8200968503952026, 'btn distance=5')
#     (1.4917446374893188, 1, 1.4917446374893188, 'player-9:state-fold')
#     (0.7556829452514648, 1, 0.7556829452514648, 'player-4:state-active')
#     (0.7125587463378906, 0.6666666666666666, 1.068838119506836, 'player-7:history')
#     (0.5837045907974243, 1, 0.5837045907974243, 'player-7:state-active')
#     (0.5820401906967163, 1, 0.5820401906967163, 'player-1:state-active')
#     (0.4903734525044759, 0.3333333333333333, 1.4711203575134277, 'player-6:history')
#     (0.4035125970840454, 1, 0.4035125970840454, 'player-6:state-active')
#     (-0.3125944137573242, 1, -0.3125944137573242, 'player-8:state-fold')
#     (0.28508293628692627, 1, 0.28508293628692627, 'player-2:state-active')
#     (0.26324620842933655, 1, 0.26324620842933655, 'player-5:state-active')
#     (0.19035984575748444, 1, 0.19035984575748444, 'player-3:state-active')
#     (-0.151426137059927, 0.09975, -1.5180565118789673, 'player-5:stack')
#     (-0.13517701992392542, 0.09925, -1.3619850873947144, 'player-6:stack')
#     (-0.12159757602214814, 0.0995, -1.2220861911773682, 'player-7:stack')
#     (-0.10308848318457603, 0.10175, -1.0131546258926392, 'player-9:stack')
#     (-0.09908056855201722, 0.1, -0.9908056855201721, 'player-1:stack')
#     (-0.08827736228704453, 1, -0.08827736228704453, 'street-preflop')
#     (-0.0729588806629181, 0.1, -0.7295888066291809, 'player-8:stack')
#     (-0.06614058613777161, 0.1, -0.6614058613777161, 'player-2:stack')
#     (0.040139510303735734, 0.099, 0.40544959902763367, 'player-0:stack')
#     (0.03658467829227448, 0.1, 0.36584678292274475, 'player-4:stack')
#     (-0.021985971927642824, 0.1, -0.21985971927642822, 'player-3:stack')
#     (0.010503690047189592, 0.71, 0.014793929643929005, 'cards')
#     (-0.00028469757735729217, 0.00075, -0.3795967698097229, 'pot')
#     (0.0, 0.0, 1.8624440431594849, 'player-9:history')
#     (0.0, 0, 1.8865877389907837, 'player-9:state-active')
#     (0.0, 0.0, 0.617439329624176, 'player-8:history')
#     (0.0, 0, 0.7037453651428223, 'player-8:state-active')
#     (-0.0, 0, -0.3545590043067932, 'player-7:state-fold')
#     (-0.0, 0, -0.06702187657356262, 'player-6:state-fold')
#     (0.0, 0.0, 1.1949214935302734, 'player-5:history')
#     (-0.0, 0, -0.14356182515621185, 'player-5:state-fold')
#     (0.0, 0.0, 1.6109318733215332, 'player-4:history')
#     (0.0, 0, 1.0968955755233765, 'player-4:state-fold')
#     (0.0, 0.0, 2.3010153770446777, 'player-3:history')
#     (0.0, 0, 0.2964814305305481, 'player-3:state-fold')
#     (0.0, 0.0, 0.8736161589622498, 'player-2:history')
#     (0.0, 0, 0.3408045768737793, 'player-2:state-fold')
#     (0.0, 0.0, 0.9040548205375671, 'player-1:history')
#     (0.0, 0, 0.9013826251029968, 'player-1:state-fold')
#     (0.0, 0.0, 2.0581040382385254, 'player-0:history')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (0.0, 0, 0.1361539363861084, 'street-river')
#     (0.0, 0, 0.12363648414611816, 'street-turn')
#     (0.0, 0, 0.138866126537323, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 1.8069616556167603, 'btn distance=6')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.6741485595703125, 1, -2.6741485595703125, 'round level 2')
#     (-2.5425000190734863, 1, -2.5425000190734863, 'player-0:state-active')
#     (-2.4961519, 0, 0, 'bias')
#     (2.033776044845581, 1, 2.033776044845581, 'player-9:state-fold')
#     (1.4675281047821045, 1, 1.4675281047821045, 'btn distance=5')
#     (1.1605361700057983, 1, 1.1605361700057983, 'player-1:state-active')
#     (1.0241550207138062, 1, 1.0241550207138062, 'player-7:state-active')
#     (0.9346320629119873, 0.6666666666666666, 1.401948094367981, 'player-7:history')
#     (0.709435760974884, 1, 0.709435760974884, 'player-5:state-active')
#     (0.7028936743736267, 1, 0.7028936743736267, 'player-2:state-active')
#     (0.6351824402809143, 1, 0.6351824402809143, 'player-6:state-active')
#     (0.43497592210769653, 1, 0.43497592210769653, 'player-4:state-active')
#     (0.40691188971201575, 0.3333333333333333, 1.2207356691360474, 'player-6:history')
#     (0.30986031889915466, 1, 0.30986031889915466, 'player-8:state-fold')
#     (-0.25397777557373047, 0.1, -2.5397777557373047, 'player-1:stack')
#     (-0.2504201496243477, 0.09925, -2.523124933242798, 'player-6:stack')
#     (-0.19676381608843804, 0.09975, -1.9725695848464966, 'player-5:stack')
#     (-0.18615557515621184, 0.10175, -1.8295388221740723, 'player-9:stack')
#     (-0.18451209217309952, 0.0995, -1.8543928861618042, 'player-7:stack')
#     (-0.16726447343826295, 0.1, -1.6726447343826294, 'player-2:stack')
#     (-0.15637184381484986, 0.1, -1.5637184381484985, 'player-8:stack')
#     (-0.15340092182159426, 0.1, -1.5340092182159424, 'player-3:stack')
#     (-0.14664705991744995, 0.1, -1.4664705991744995, 'player-4:stack')
#     (-0.1426054686307907, 1, -0.1426054686307907, 'player-3:state-active')
#     (-0.11383439600467682, 1, -0.11383439600467682, 'street-preflop')
#     (-0.06968580883741379, 0.099, -0.7038970589637756, 'player-0:stack')
#     (0.01305394945666194, 0.71, 0.01838584430515766, 'cards')
#     (-0.0013650520741939544, 0.00075, -1.820069432258606, 'pot')
#     (0.0, 0.0, 1.7287386655807495, 'player-9:history')
#     (0.0, 0, 2.2141034603118896, 'player-9:state-active')
#     (0.0, 0.0, 1.2142130136489868, 'player-8:history')
#     (0.0, 0, 1.3269157409667969, 'player-8:state-active')
#     (0.0, 0, 0.36654409766197205, 'player-7:state-fold')
#     (0.0, 0, 0.4207422137260437, 'player-6:state-fold')
#     (0.0, 0.0, 3.619497537612915, 'player-5:history')
#     (0.0, 0, 0.6914798617362976, 'player-5:state-fold')
#     (0.0, 0.0, 1.1321343183517456, 'player-4:history')
#     (0.0, 0, 0.5677550435066223, 'player-4:state-fold')
#     (0.0, 0.0, 2.0687448978424072, 'player-3:history')
#     (-0.0, 0, -0.03342190384864807, 'player-3:state-fold')
#     (0.0, 0.0, 0.5935136675834656, 'player-2:history')
#     (0.0, 0, 0.7674608826637268, 'player-2:state-fold')
#     (0.0, 0.0, 1.0035585165023804, 'player-1:history')
#     (0.0, 0, 1.1311455965042114, 'player-1:state-fold')
#     (0.0, 0.0, 1.6993013620376587, 'player-0:history')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.04107475280761719, 'street-river')
#     (0.0, 0, 0.026161091402173042, 'street-turn')
#     (-0.0, 0, -0.02991003915667534, 'street-flop')
#     (-0.0, 0, -0.1774212121963501, 'btn distance=9')
#     (-0.0, 0, -0.047159694135189056, 'btn distance=8')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 1.4792786836624146, 'btn distance=6')
#     (0.0, 0, 0.5843061804771423, 'btn distance=4')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for double_raise :
#     (-2.5915870666503906, 1, -2.5915870666503906, 'player-0:state-active')
#     (-2.3875208, 0, 0, 'bias')
#     (-2.1957459449768066, 1, -2.1957459449768066, 'round level 2')
#     (1.8671458959579468, 1, 1.8671458959579468, 'btn distance=5')
#     (1.7065824270248413, 1, 1.7065824270248413, 'player-9:state-fold')
#     (1.5541554689407349, 1, 1.5541554689407349, 'player-7:state-active')
#     (1.012056589126587, 0.6666666666666666, 1.5180848836898804, 'player-7:history')
#     (0.8493184447288513, 1, 0.8493184447288513, 'player-2:state-active')
#     (0.6920390725135803, 1, 0.6920390725135803, 'player-1:state-active')
#     (0.36283689737319946, 1, 0.36283689737319946, 'player-3:state-active')
#     (0.3248136341571808, 1, 0.3248136341571808, 'player-4:state-active')
#     (0.29325035214424133, 1, 0.29325035214424133, 'player-6:state-active')
#     (-0.25104778820276263, 0.09925, -2.5294487476348877, 'player-6:stack')
#     (0.20312217871348062, 0.3333333333333333, 0.6093665361404419, 'player-6:history')
#     (-0.20290050506591797, 0.1, -2.0290050506591797, 'player-1:stack')
#     (0.1973874717950821, 1, 0.1973874717950821, 'player-8:state-fold')
#     (-0.19701235044002535, 0.0995, -1.9800236225128174, 'player-7:stack')
#     (-0.19426556172966958, 0.09975, -1.9475244283676147, 'player-5:stack')
#     (-0.1813446700274944, 0.10175, -1.7822571992874146, 'player-9:stack')
#     (-0.17938907146453859, 0.1, -1.7938907146453857, 'player-2:stack')
#     (-0.17708672285079957, 0.1, -1.7708672285079956, 'player-3:stack')
#     (-0.13466938734054565, 0.1, -1.3466938734054565, 'player-8:stack')
#     (-0.13437527418136597, 0.1, -1.3437527418136597, 'player-4:stack')
#     (-0.10949435830116272, 1, -0.10949435830116272, 'street-preflop')
#     (-0.08160746937990189, 0.099, -0.8243178725242615, 'player-0:stack')
#     (0.024299608543515205, 0.71, 0.034224800765514374, 'cards')
#     (0.005027344916015863, 1, 0.005027344916015863, 'player-5:state-active')
#     (-0.0021866211891174315, 0.00075, -2.915494918823242, 'pot')
#     (0.0, 0.0, 1.7979799509048462, 'player-9:history')
#     (0.0, 0, 1.4783991575241089, 'player-9:state-active')
#     (0.0, 0.0, 1.4511357545852661, 'player-8:history')
#     (0.0, 0, 1.307974100112915, 'player-8:state-active')
#     (0.0, 0, 1.3565353155136108, 'player-7:state-fold')
#     (0.0, 0, 0.09614922106266022, 'player-6:state-fold')
#     (0.0, 0.0, 4.2742438316345215, 'player-5:history')
#     (0.0, 0, 0.7188841104507446, 'player-5:state-fold')
#     (0.0, 0.0, 0.8796502351760864, 'player-4:history')
#     (0.0, 0, 0.4836919605731964, 'player-4:state-fold')
#     (0.0, 0.0, 1.0582114458084106, 'player-3:history')
#     (0.0, 0, 0.4559221565723419, 'player-3:state-fold')
#     (0.0, 0.0, 0.5237418413162231, 'player-2:history')
#     (0.0, 0, 0.902125358581543, 'player-2:state-fold')
#     (0.0, 0.0, 0.791723906993866, 'player-1:history')
#     (0.0, 0, 0.20732176303863525, 'player-1:state-fold')
#     (0.0, 0.0, 0.7544894218444824, 'player-0:history')
#     (0.0, 0, 0.1994665414094925, 'player-0:state-fold')
#     (0.0, 0, 0.18096104264259338, 'street-river')
#     (0.0, 0, 0.015104751102626324, 'street-turn')
#     (-0.0, 0, -0.11874984204769135, 'street-flop')
#     (0.0, 0, 0.16180437803268433, 'btn distance=9')
#     (-0.0, 0, -0.16994917392730713, 'btn distance=8')
#     (-0.0, 0, -0.2551056444644928, 'btn distance=7')
#     (0.0, 0, 1.7864481210708618, 'btn distance=6')
#     (0.0, 0, 0.2912150025367737, 'btn distance=4')
#     (-0.0, 0, -0.07808863371610641, 'btn distance=3')
#     (0.0, 0, 0.07531379163265228, 'btn distance=2')
#     (-0.0, 0, -0.04036684334278107, 'btn distance=1')
#     (-0.0, 0, -0.241798534989357, 'btn distance=0')
#     (-0.0, 0, -0.012274674139916897, 'round level 27')
#     (-0.0, 0, -0.1700371652841568, 'round level 26')
#     (-0.0, 0, -0.06231385096907616, 'round level 25')
#     (-0.0, 0, -0.19142040610313416, 'round level 24')
#     (0.0, 0, 0.0052865338511765, 'round level 23')
#     (0.0, 0, 0.10509058088064194, 'round level 22')
#     (0.0, 0, 0.148484006524086, 'round level 21')
#     (-0.0, 0, -0.2335253208875656, 'round level 20')
#     (0.0, 0, 0.024247899651527405, 'round level 19')
#     (0.0, 0, 0.24292117357254028, 'round level 18')
#     (0.0, 0, 0.059873905032873154, 'round level 17')
#     (0.0, 0, 0.13325431942939758, 'round level 16')
#     (0.0, 0, 0.12490264326334, 'round level 15')
#     (0.0, 0, 0.17109589278697968, 'round level 14')
#     (-0.0, 0, -0.23500089347362518, 'round level 13')
#     (0.0, 0, 0.1816813349723816, 'round level 12')
#     (-0.0, 0, -0.14072857797145844, 'round level 11')
#     (-0.0, 0, -0.02639414370059967, 'round level 10')
#     (-0.0, 0, -0.12533557415008545, 'round level 9')
#     (0.0, 0, 0.21444687247276306, 'round level 8')
#     (0.0, 0, 0.2577686905860901, 'round level 7')
#     (-0.0, 0, -0.020569249987602234, 'round level 6')
#     (-0.0, 0, -0.08953545987606049, 'round level 5')
#     (-0.0, 0, -0.13333763182163239, 'round level 4')
#     (-0.0, 0, -0.00587732857093215, 'round level 3')
#     (0.0, 0, 0.05715208500623703, 'round level 1')
#
# linear combination for triple_raise :
#     (-2.5654096603393555, 1, -2.5654096603393555, 'round level 2')
#     (-2.3724327, 0, 0, 'bias')
#     (-2.242950439453125, 1, -2.242950439453125, 'player-0:state-active')
#     (1.973375678062439, 1, 1.973375678062439, 'btn distance=5')
#     (1.7017498016357422, 1, 1.7017498016357422, 'player-9:state-fold')
#     (1.2232623100280762, 1, 1.2232623100280762, 'player-7:state-active')
#     (1.0549815495808919, 0.6666666666666666, 1.582472324371338, 'player-7:history')
#     (-0.8888930082321167, 1, -0.8888930082321167, 'street-preflop')
#     (0.8314283490180969, 1, 0.8314283490180969, 'player-2:state-active')
#     (0.6820471882820129, 1, 0.6820471882820129, 'player-5:state-active')
#     (0.658285915851593, 1, 0.658285915851593, 'player-1:state-active')
#     (0.5164560675621033, 1, 0.5164560675621033, 'player-4:state-active')
#     (0.5151159167289734, 1, 0.5151159167289734, 'player-6:state-active')
#     (0.3644866645336151, 1, 0.3644866645336151, 'player-8:state-fold')
#     (-0.3222849369049072, 0.1, -3.2228493690490723, 'player-1:stack')
#     (0.2746110955874125, 0.3333333333333333, 0.8238332867622375, 'player-6:history')
#     (-0.24083283072710038, 0.09925, -2.426527261734009, 'player-6:stack')
#     (-0.21144606387615206, 0.0995, -2.1250860691070557, 'player-7:stack')
#     (-0.20555657887458803, 0.09975, -2.0607175827026367, 'player-5:stack')
#     (-0.19778493642807007, 0.1, -1.9778493642807007, 'player-8:stack')
#     (-0.19321404695510866, 0.1, -1.9321404695510864, 'player-3:stack')
#     (-0.184048068523407, 0.1, -1.8404806852340698, 'player-2:stack')
#     (-0.1834011737704277, 0.10175, -1.8024685382843018, 'player-9:stack')
#     (-0.16303051710128785, 0.1, -1.6303051710128784, 'player-4:stack')
#     (0.11180011928081512, 1, 0.11180011928081512, 'player-3:state-active')
#     (-0.09598985338211061, 0.099, -0.9695944786071777, 'player-0:stack')
#     (-0.006685664160177111, 0.71, -0.00941642839461565, 'cards')
#     (-0.0031374936103820803, 0.00075, -4.183324813842773, 'pot')
#     (0.0, 0.0, 1.7745417356491089, 'player-9:history')
#     (0.0, 0, 1.4920952320098877, 'player-9:state-active')
#     (0.0, 0.0, 1.4680891036987305, 'player-8:history')
#     (0.0, 0, 1.5621132850646973, 'player-8:state-active')
#     (0.0, 0, 1.1818435192108154, 'player-7:state-fold')
#     (0.0, 0, 0.3370206356048584, 'player-6:state-fold')
#     (0.0, 0.0, 4.160330772399902, 'player-5:history')
#     (0.0, 0, 1.3701834678649902, 'player-5:state-fold')
#     (0.0, 0.0, 0.9121751189231873, 'player-4:history')
#     (0.0, 0, 0.6458732485771179, 'player-4:state-fold')
#     (0.0, 0.0, 0.9788299798965454, 'player-3:history')
#     (0.0, 0, 0.09074126929044724, 'player-3:state-fold')
#     (0.0, 0.0, 0.5327305793762207, 'player-2:history')
#     (0.0, 0, 0.7871614098548889, 'player-2:state-fold')
#     (0.0, 0.0, 0.6838011741638184, 'player-1:history')
#     (0.0, 0, 0.38340216875076294, 'player-1:state-fold')
#     (0.0, 0.0, 0.6423398852348328, 'player-0:history')
#     (-0.0, 0, -0.23924040794372559, 'player-0:state-fold')
#     (-0.0, 0, -0.5806674361228943, 'street-river')
#     (-0.0, 0, -0.7105857729911804, 'street-turn')
#     (-0.0, 0, -0.7075456380844116, 'street-flop')
#     (-0.0, 0, -0.1619005799293518, 'btn distance=9')
#     (-0.0, 0, -0.11413408070802689, 'btn distance=8')
#     (-0.0, 0, -0.12604860961437225, 'btn distance=7')
#     (0.0, 0, 1.8543310165405273, 'btn distance=6')
#     (0.0, 0, 0.4832393229007721, 'btn distance=4')
#     (0.0, 0, 0.21936601400375366, 'btn distance=3')
#     (0.0, 0, 0.21691006422042847, 'btn distance=2')
#     (0.0, 0, 0.0388103649020195, 'btn distance=1')
#     (-0.0, 0, -0.15196388959884644, 'btn distance=0')
#     (-0.0, 0, -0.24565012753009796, 'round level 27')
#     (0.0, 0, 0.18738245964050293, 'round level 26')
#     (0.0, 0, 0.13563582301139832, 'round level 25')
#     (0.0, 0, 0.0051093026995658875, 'round level 24')
#     (0.0, 0, 0.15698617696762085, 'round level 23')
#     (-0.0, 0, -0.25703445076942444, 'round level 22')
#     (-0.0, 0, -0.2061779946088791, 'round level 21')
#     (-0.0, 0, -0.041454460471868515, 'round level 20')
#     (-0.0, 0, -0.09786731749773026, 'round level 19')
#     (-0.0, 0, -0.1264774352312088, 'round level 18')
#     (0.0, 0, 0.24566134810447693, 'round level 17')
#     (-0.0, 0, -0.1010018065571785, 'round level 16')
#     (-0.0, 0, -0.020011145621538162, 'round level 15')
#     (-0.0, 0, -0.05574813857674599, 'round level 14')
#     (-0.0, 0, -0.08178351819515228, 'round level 13')
#     (0.0, 0, 0.18671230971813202, 'round level 12')
#     (-0.0, 0, -0.05788012966513634, 'round level 11')
#     (-0.0, 0, -0.13147558271884918, 'round level 10')
#     (-0.0, 0, -0.23238608241081238, 'round level 9')
#     (-0.0, 0, -0.1202930361032486, 'round level 8')
#     (-0.0, 0, -0.12012208253145218, 'round level 7')
#     (-0.0, 0, -0.09084489941596985, 'round level 6')
#     (-0.0, 0, -0.057835355401039124, 'round level 5')
#     (-0.0, 0, -0.01247967779636383, 'round level 4')
#     (-0.0, 0, -0.2314309924840927, 'round level 3')
#     (0.0, 0, 0.10510239750146866, 'round level 1')
#
# linear combination for max_raise :
#     (-1.3251365423202515, 1, -1.3251365423202515, 'player-0:state-active')
#     (-1.1046034, 0, 0, 'bias')
#     (0.9286585450172424, 1, 0.9286585450172424, 'player-7:state-active')
#     (-0.8862913250923157, 1, -0.8862913250923157, 'round level 2')
#     (0.6775450706481934, 1, 0.6775450706481934, 'player-3:state-active')
#     (0.5480400919914246, 1, 0.5480400919914246, 'btn distance=5')
#     (0.44052013754844666, 1, 0.44052013754844666, 'player-9:state-fold')
#     (0.40908785661061603, 0.6666666666666666, 0.6136317849159241, 'player-7:history')
#     (0.3826307952404022, 1, 0.3826307952404022, 'player-4:state-active')
#     (0.3420032560825348, 1, 0.3420032560825348, 'street-preflop')
#     (-0.28196588158607483, 1, -0.28196588158607483, 'player-8:state-fold')
#     (0.2646414041519165, 1, 0.2646414041519165, 'player-2:state-active')
#     (-0.1707525289654732, 0.0995, -1.7161058187484741, 'player-7:stack')
#     (0.16865608096122742, 1, 0.16865608096122742, 'player-5:state-active')
#     (-0.15172435462474823, 0.09975, -1.5210461616516113, 'player-5:stack')
#     (-0.1405116520524025, 0.09925, -1.4157345294952393, 'player-6:stack')
#     (-0.11298981904983521, 0.1, -1.129898190498352, 'player-4:stack')
#     (-0.09824017053842544, 0.10175, -0.9655053615570068, 'player-9:stack')
#     (-0.09473544359207153, 0.1, -0.9473544359207153, 'player-2:stack')
#     (0.09468989819288254, 1, 0.09468989819288254, 'player-1:state-active')
#     (0.08407319585482279, 0.3333333333333333, 0.2522195875644684, 'player-6:history')
#     (0.07764206796884537, 0.099, 0.7842633128166199, 'player-0:stack')
#     (-0.06652165651321411, 0.1, -0.6652165651321411, 'player-8:stack')
#     (0.064662866294384, 1, 0.064662866294384, 'player-6:state-active')
#     (-0.043883422017097475, 0.1, -0.43883422017097473, 'player-1:stack')
#     (0.021432138886302708, 0.71, 0.030186111107468605, 'cards')
#     (-0.017020438611507416, 0.1, -0.17020438611507416, 'player-3:stack')
#     (0.0002606226727366447, 0.00075, 0.347496896982193, 'pot')
#     (0.0, 0.0, 0.6335735321044922, 'player-9:history')
#     (0.0, 0, 0.6906992197036743, 'player-9:state-active')
#     (0.0, 0.0, 0.1239309161901474, 'player-8:history')
#     (0.0, 0, 0.09257758408784866, 'player-8:state-active')
#     (0.0, 0, 0.632209837436676, 'player-7:state-fold')
#     (-0.0, 0, -0.004348215647041798, 'player-6:state-fold')
#     (0.0, 0.0, 1.3058290481567383, 'player-5:history')
#     (0.0, 0, 0.3320745527744293, 'player-5:state-fold')
#     (0.0, 0.0, 0.478394091129303, 'player-4:history')
#     (0.0, 0, 0.48257705569267273, 'player-4:state-fold')
#     (0.0, 0.0, 0.8370112776756287, 'player-3:history')
#     (0.0, 0, 0.6391070485115051, 'player-3:state-fold')
#     (-0.0, 0.0, -1.0136412382125854, 'player-2:history')
#     (0.0, 0, 0.173703134059906, 'player-2:state-fold')
#     (0.0, 0.0, 0.25422853231430054, 'player-1:history')
#     (-0.0, 0, -0.051687128841876984, 'player-1:state-fold')
#     (0.0, 0.0, 0.7255996465682983, 'player-0:history')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.6425154805183411, 'street-river')
#     (0.0, 0, 0.5084975957870483, 'street-turn')
#     (0.0, 0, 0.5016143321990967, 'street-flop')
#     (-0.0, 0, -0.10669941455125809, 'btn distance=9')
#     (0.0, 0, 0.234825998544693, 'btn distance=8')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.5216233730316162, 'btn distance=6')
#     (0.0, 0, 0.18136386573314667, 'btn distance=4')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')

# %% [markdown]
# ### DOUBLE_RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 100
#   - raise: [125, 9900]
# -- hole card --
#   - ['C7', 'D7']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 250, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10175
#     - 6 : agent (uuid-0) => state : participating, stack : 9825 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 9900
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'agent (uuid=uuid-0)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 100, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
# ======================================================================
# Agent took action [ raise: 250 (double_raise) ] at round 2
#   => [('fold', -1.0585123300552368), ('call', -1.5043342113494873), ('min_raise', -0.9167881011962891), ('double_raise', 0.02111053466796875), ('triple_raise', -0.503524899482727), ('max_raise', -0.3946347236633301)]
# ** weights and features in detail **
# bias : [-2.24537802 -2.14030123 -2.49615192 -2.38752079 -2.37243271 -1.10460341]
#
# linear combination for fold :
#     (-2.431051731109619, 1, -2.431051731109619, 'round level 2')
#     (-2.245378, 0, 0, 'bias')
#     (-2.218794345855713, 1, -2.218794345855713, 'player-0:state-active')
#     (-2.0704636573791504, 1, -2.0704636573791504, 'player-7:state-fold')
#     (1.7820357084274292, 1, 1.7820357084274292, 'player-5:state-fold')
#     (1.6409307718276978, 1, 1.6409307718276978, 'player-6:state-fold')
#     (1.6157982349395752, 1, 1.6157982349395752, 'player-3:state-fold')
#     (1.4899870157241821, 1, 1.4899870157241821, 'player-4:state-fold')
#     (1.1088765859603882, 1, 1.1088765859603882, 'player-2:state-fold')
#     (1.1019710302352905, 1, 1.1019710302352905, 'player-1:state-active')
#     (0.5911204218864441, 1, 0.5911204218864441, 'player-9:state-fold')
#     (0.31826530694961547, 0.3, 1.0608843564987183, 'player-0:history')
#     (-0.3098161518573761, 1, -0.3098161518573761, 'player-8:state-fold')
#     (-0.2274139444231987, 0.09925, -2.2913243770599365, 'player-6:stack')
#     (-0.21541132628917695, 0.09975, -2.1595120429992676, 'player-5:stack')
#     (-0.19625710433721544, 0.0995, -1.9724332094192505, 'player-7:stack')
#     (0.1943889558315277, 1, 0.1943889558315277, 'street-preflop')
#     (-0.17302608489990234, 0.1, -1.7302608489990234, 'player-8:stack')
#     (-0.1693753242492676, 0.1, -1.6937532424926758, 'player-4:stack')
#     (-0.16513638854026796, 0.099, -1.6680443286895752, 'player-1:stack')
#     (-0.13510715904831885, 0.10175, -1.3278344869613647, 'player-9:stack')
#     (-0.13382815122604372, 0.1, -1.338281512260437, 'player-2:stack')
#     (-0.12463589757680893, 1, -0.12463589757680893, 'btn distance=5')
#     (-0.12089370489120484, 0.1, -1.2089370489120483, 'player-3:stack')
#     (0.09553759694099427, 0.4, 0.23884399235248566, 'player-1:history')
#     (-0.03057409630715847, 0.09825, -0.3111867308616638, 'player-0:stack')
#     (-0.027848388478159902, 0.71, -0.0392230823636055, 'cards')
#     (-0.002411961555480957, 0.0025, -0.9647846221923828, 'pot')
#     (0.0, 0.0, 0.7042251229286194, 'player-9:history')
#     (0.0, 0, 0.8168973922729492, 'player-9:state-active')
#     (0.0, 0.0, 1.086035966873169, 'player-8:history')
#     (0.0, 0, 0.7840678095817566, 'player-8:state-active')
#     (0.0, 0.0, 0.15181133151054382, 'player-7:history')
#     (-0.0, 0, -1.5541051626205444, 'player-7:state-active')
#     (0.0, 0.0, 1.1388506889343262, 'player-6:history')
#     (0.0, 0, 1.8243247270584106, 'player-6:state-active')
#     (0.0, 0.0, 2.2844033241271973, 'player-5:history')
#     (0.0, 0, 1.9195448160171509, 'player-5:state-active')
#     (0.0, 0.0, 0.05564766377210617, 'player-4:history')
#     (0.0, 0, 1.558862328529358, 'player-4:state-active')
#     (0.0, 0.0, 1.0570818185806274, 'player-3:history')
#     (0.0, 0, 1.5222080945968628, 'player-3:state-active')
#     (0.0, 0.0, 0.8161777853965759, 'player-2:history')
#     (0.0, 0, 1.0325573682785034, 'player-2:state-active')
#     (0.0, 0, 1.7078877687454224, 'player-1:state-fold')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.3334566652774811, 'street-river')
#     (0.0, 0, 0.343752384185791, 'street-turn')
#     (0.0, 0, 0.5796384215354919, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.22828711569309235, 'btn distance=6')
#     (-0.0, 0, -0.1934162676334381, 'btn distance=4')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-2.2445640563964844, 1, -2.2445640563964844, 'player-0:state-active')
#     (-2.1403012, 0, 0, 'bias')
#     (-2.0760812759399414, 1, -2.0760812759399414, 'round level 2')
#     (1.8200968503952026, 1, 1.8200968503952026, 'btn distance=5')
#     (1.4917446374893188, 1, 1.4917446374893188, 'player-9:state-fold')
#     (1.0968955755233765, 1, 1.0968955755233765, 'player-4:state-fold')
#     (0.6174312114715576, 0.3, 2.0581040382385254, 'player-0:history')
#     (0.5820401906967163, 1, 0.5820401906967163, 'player-1:state-active')
#     (0.36162192821502687, 0.4, 0.9040548205375671, 'player-1:history')
#     (-0.3545590043067932, 1, -0.3545590043067932, 'player-7:state-fold')
#     (0.3408045768737793, 1, 0.3408045768737793, 'player-2:state-fold')
#     (-0.3125944137573242, 1, -0.3125944137573242, 'player-8:state-fold')
#     (0.2964814305305481, 1, 0.2964814305305481, 'player-3:state-fold')
#     (-0.151426137059927, 0.09975, -1.5180565118789673, 'player-5:stack')
#     (-0.14356182515621185, 1, -0.14356182515621185, 'player-5:state-fold')
#     (-0.13517701992392542, 0.09925, -1.3619850873947144, 'player-6:stack')
#     (-0.12159757602214814, 0.0995, -1.2220861911773682, 'player-7:stack')
#     (-0.10308848318457603, 0.10175, -1.0131546258926392, 'player-9:stack')
#     (-0.09808976286649704, 0.099, -0.9908056855201721, 'player-1:stack')
#     (-0.08827736228704453, 1, -0.08827736228704453, 'street-preflop')
#     (-0.0729588806629181, 0.1, -0.7295888066291809, 'player-8:stack')
#     (-0.06702187657356262, 1, -0.06702187657356262, 'player-6:state-fold')
#     (-0.06614058613777161, 0.1, -0.6614058613777161, 'player-2:stack')
#     (0.03983542310446501, 0.09825, 0.40544959902763367, 'player-0:stack')
#     (0.03658467829227448, 0.1, 0.36584678292274475, 'player-4:stack')
#     (-0.021985971927642824, 0.1, -0.21985971927642822, 'player-3:stack')
#     (0.010503690047189592, 0.71, 0.014793929643929005, 'cards')
#     (-0.0009489919245243073, 0.0025, -0.3795967698097229, 'pot')
#     (0.0, 0.0, 1.8624440431594849, 'player-9:history')
#     (0.0, 0, 1.8865877389907837, 'player-9:state-active')
#     (0.0, 0.0, 0.617439329624176, 'player-8:history')
#     (0.0, 0, 0.7037453651428223, 'player-8:state-active')
#     (0.0, 0.0, 1.068838119506836, 'player-7:history')
#     (0.0, 0, 0.5837045907974243, 'player-7:state-active')
#     (0.0, 0.0, 1.4711203575134277, 'player-6:history')
#     (0.0, 0, 0.4035125970840454, 'player-6:state-active')
#     (0.0, 0.0, 1.1949214935302734, 'player-5:history')
#     (0.0, 0, 0.26324620842933655, 'player-5:state-active')
#     (0.0, 0.0, 1.6109318733215332, 'player-4:history')
#     (0.0, 0, 0.7556829452514648, 'player-4:state-active')
#     (0.0, 0.0, 2.3010153770446777, 'player-3:history')
#     (0.0, 0, 0.19035984575748444, 'player-3:state-active')
#     (0.0, 0.0, 0.8736161589622498, 'player-2:history')
#     (0.0, 0, 0.28508293628692627, 'player-2:state-active')
#     (0.0, 0, 0.9013826251029968, 'player-1:state-fold')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (0.0, 0, 0.1361539363861084, 'street-river')
#     (0.0, 0, 0.12363648414611816, 'street-turn')
#     (0.0, 0, 0.138866126537323, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 1.8069616556167603, 'btn distance=6')
#     (0.0, 0, 0.715787947177887, 'btn distance=4')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.6741485595703125, 1, -2.6741485595703125, 'round level 2')
#     (-2.5425000190734863, 1, -2.5425000190734863, 'player-0:state-active')
#     (-2.4961519, 0, 0, 'bias')
#     (2.033776044845581, 1, 2.033776044845581, 'player-9:state-fold')
#     (1.4675281047821045, 1, 1.4675281047821045, 'btn distance=5')
#     (1.1605361700057983, 1, 1.1605361700057983, 'player-1:state-active')
#     (0.7674608826637268, 1, 0.7674608826637268, 'player-2:state-fold')
#     (0.6914798617362976, 1, 0.6914798617362976, 'player-5:state-fold')
#     (0.5677550435066223, 1, 0.5677550435066223, 'player-4:state-fold')
#     (0.5097904086112975, 0.3, 1.6993013620376587, 'player-0:history')
#     (0.4207422137260437, 1, 0.4207422137260437, 'player-6:state-fold')
#     (0.40142340660095216, 0.4, 1.0035585165023804, 'player-1:history')
#     (0.36654409766197205, 1, 0.36654409766197205, 'player-7:state-fold')
#     (0.30986031889915466, 1, 0.30986031889915466, 'player-8:state-fold')
#     (-0.2514379978179932, 0.099, -2.5397777557373047, 'player-1:stack')
#     (-0.2504201496243477, 0.09925, -2.523124933242798, 'player-6:stack')
#     (-0.19676381608843804, 0.09975, -1.9725695848464966, 'player-5:stack')
#     (-0.18615557515621184, 0.10175, -1.8295388221740723, 'player-9:stack')
#     (-0.18451209217309952, 0.0995, -1.8543928861618042, 'player-7:stack')
#     (-0.16726447343826295, 0.1, -1.6726447343826294, 'player-2:stack')
#     (-0.15637184381484986, 0.1, -1.5637184381484985, 'player-8:stack')
#     (-0.15340092182159426, 0.1, -1.5340092182159424, 'player-3:stack')
#     (-0.14664705991744995, 0.1, -1.4664705991744995, 'player-4:stack')
#     (-0.11383439600467682, 1, -0.11383439600467682, 'street-preflop')
#     (-0.06915788604319095, 0.09825, -0.7038970589637756, 'player-0:stack')
#     (-0.03342190384864807, 1, -0.03342190384864807, 'player-3:state-fold')
#     (0.01305394945666194, 0.71, 0.01838584430515766, 'cards')
#     (-0.004550173580646515, 0.0025, -1.820069432258606, 'pot')
#     (0.0, 0.0, 1.7287386655807495, 'player-9:history')
#     (0.0, 0, 2.2141034603118896, 'player-9:state-active')
#     (0.0, 0.0, 1.2142130136489868, 'player-8:history')
#     (0.0, 0, 1.3269157409667969, 'player-8:state-active')
#     (0.0, 0.0, 1.401948094367981, 'player-7:history')
#     (0.0, 0, 1.0241550207138062, 'player-7:state-active')
#     (0.0, 0.0, 1.2207356691360474, 'player-6:history')
#     (0.0, 0, 0.6351824402809143, 'player-6:state-active')
#     (0.0, 0.0, 3.619497537612915, 'player-5:history')
#     (0.0, 0, 0.709435760974884, 'player-5:state-active')
#     (0.0, 0.0, 1.1321343183517456, 'player-4:history')
#     (0.0, 0, 0.43497592210769653, 'player-4:state-active')
#     (0.0, 0.0, 2.0687448978424072, 'player-3:history')
#     (-0.0, 0, -0.1426054686307907, 'player-3:state-active')
#     (0.0, 0.0, 0.5935136675834656, 'player-2:history')
#     (0.0, 0, 0.7028936743736267, 'player-2:state-active')
#     (0.0, 0, 1.1311455965042114, 'player-1:state-fold')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.04107475280761719, 'street-river')
#     (0.0, 0, 0.026161091402173042, 'street-turn')
#     (-0.0, 0, -0.02991003915667534, 'street-flop')
#     (-0.0, 0, -0.1774212121963501, 'btn distance=9')
#     (-0.0, 0, -0.047159694135189056, 'btn distance=8')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 1.4792786836624146, 'btn distance=6')
#     (0.0, 0, 0.5843061804771423, 'btn distance=4')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for double_raise :
#     (-2.5915870666503906, 1, -2.5915870666503906, 'player-0:state-active')
#     (-2.3875208, 0, 0, 'bias')
#     (-2.1957459449768066, 1, -2.1957459449768066, 'round level 2')
#     (1.8671458959579468, 1, 1.8671458959579468, 'btn distance=5')
#     (1.7065824270248413, 1, 1.7065824270248413, 'player-9:state-fold')
#     (1.3565353155136108, 1, 1.3565353155136108, 'player-7:state-fold')
#     (0.902125358581543, 1, 0.902125358581543, 'player-2:state-fold')
#     (0.7188841104507446, 1, 0.7188841104507446, 'player-5:state-fold')
#     (0.6920390725135803, 1, 0.6920390725135803, 'player-1:state-active')
#     (0.4836919605731964, 1, 0.4836919605731964, 'player-4:state-fold')
#     (0.4559221565723419, 1, 0.4559221565723419, 'player-3:state-fold')
#     (0.3166895627975464, 0.4, 0.791723906993866, 'player-1:history')
#     (-0.25104778820276263, 0.09925, -2.5294487476348877, 'player-6:stack')
#     (0.2263468265533447, 0.3, 0.7544894218444824, 'player-0:history')
#     (-0.2008715000152588, 0.099, -2.0290050506591797, 'player-1:stack')
#     (0.1973874717950821, 1, 0.1973874717950821, 'player-8:state-fold')
#     (-0.19701235044002535, 0.0995, -1.9800236225128174, 'player-7:stack')
#     (-0.19426556172966958, 0.09975, -1.9475244283676147, 'player-5:stack')
#     (-0.1813446700274944, 0.10175, -1.7822571992874146, 'player-9:stack')
#     (-0.17938907146453859, 0.1, -1.7938907146453857, 'player-2:stack')
#     (-0.17708672285079957, 0.1, -1.7708672285079956, 'player-3:stack')
#     (-0.13466938734054565, 0.1, -1.3466938734054565, 'player-8:stack')
#     (-0.13437527418136597, 0.1, -1.3437527418136597, 'player-4:stack')
#     (-0.10949435830116272, 1, -0.10949435830116272, 'street-preflop')
#     (0.09614922106266022, 1, 0.09614922106266022, 'player-6:state-fold')
#     (-0.0809892309755087, 0.09825, -0.8243178725242615, 'player-0:stack')
#     (0.024299608543515205, 0.71, 0.034224800765514374, 'cards')
#     (-0.0072887372970581055, 0.0025, -2.915494918823242, 'pot')
#     (0.0, 0.0, 1.7979799509048462, 'player-9:history')
#     (0.0, 0, 1.4783991575241089, 'player-9:state-active')
#     (0.0, 0.0, 1.4511357545852661, 'player-8:history')
#     (0.0, 0, 1.307974100112915, 'player-8:state-active')
#     (0.0, 0.0, 1.5180848836898804, 'player-7:history')
#     (0.0, 0, 1.5541554689407349, 'player-7:state-active')
#     (0.0, 0.0, 0.6093665361404419, 'player-6:history')
#     (0.0, 0, 0.29325035214424133, 'player-6:state-active')
#     (0.0, 0.0, 4.2742438316345215, 'player-5:history')
#     (0.0, 0, 0.005027344916015863, 'player-5:state-active')
#     (0.0, 0.0, 0.8796502351760864, 'player-4:history')
#     (0.0, 0, 0.3248136341571808, 'player-4:state-active')
#     (0.0, 0.0, 1.0582114458084106, 'player-3:history')
#     (0.0, 0, 0.36283689737319946, 'player-3:state-active')
#     (0.0, 0.0, 0.5237418413162231, 'player-2:history')
#     (0.0, 0, 0.8493184447288513, 'player-2:state-active')
#     (0.0, 0, 0.20732176303863525, 'player-1:state-fold')
#     (0.0, 0, 0.1994665414094925, 'player-0:state-fold')
#     (0.0, 0, 0.18096104264259338, 'street-river')
#     (0.0, 0, 0.015104751102626324, 'street-turn')
#     (-0.0, 0, -0.11874984204769135, 'street-flop')
#     (0.0, 0, 0.16180437803268433, 'btn distance=9')
#     (-0.0, 0, -0.16994917392730713, 'btn distance=8')
#     (-0.0, 0, -0.2551056444644928, 'btn distance=7')
#     (0.0, 0, 1.7864481210708618, 'btn distance=6')
#     (0.0, 0, 0.2912150025367737, 'btn distance=4')
#     (-0.0, 0, -0.07808863371610641, 'btn distance=3')
#     (0.0, 0, 0.07531379163265228, 'btn distance=2')
#     (-0.0, 0, -0.04036684334278107, 'btn distance=1')
#     (-0.0, 0, -0.241798534989357, 'btn distance=0')
#     (-0.0, 0, -0.012274674139916897, 'round level 27')
#     (-0.0, 0, -0.1700371652841568, 'round level 26')
#     (-0.0, 0, -0.06231385096907616, 'round level 25')
#     (-0.0, 0, -0.19142040610313416, 'round level 24')
#     (0.0, 0, 0.0052865338511765, 'round level 23')
#     (0.0, 0, 0.10509058088064194, 'round level 22')
#     (0.0, 0, 0.148484006524086, 'round level 21')
#     (-0.0, 0, -0.2335253208875656, 'round level 20')
#     (0.0, 0, 0.024247899651527405, 'round level 19')
#     (0.0, 0, 0.24292117357254028, 'round level 18')
#     (0.0, 0, 0.059873905032873154, 'round level 17')
#     (0.0, 0, 0.13325431942939758, 'round level 16')
#     (0.0, 0, 0.12490264326334, 'round level 15')
#     (0.0, 0, 0.17109589278697968, 'round level 14')
#     (-0.0, 0, -0.23500089347362518, 'round level 13')
#     (0.0, 0, 0.1816813349723816, 'round level 12')
#     (-0.0, 0, -0.14072857797145844, 'round level 11')
#     (-0.0, 0, -0.02639414370059967, 'round level 10')
#     (-0.0, 0, -0.12533557415008545, 'round level 9')
#     (0.0, 0, 0.21444687247276306, 'round level 8')
#     (0.0, 0, 0.2577686905860901, 'round level 7')
#     (-0.0, 0, -0.020569249987602234, 'round level 6')
#     (-0.0, 0, -0.08953545987606049, 'round level 5')
#     (-0.0, 0, -0.13333763182163239, 'round level 4')
#     (-0.0, 0, -0.00587732857093215, 'round level 3')
#     (0.0, 0, 0.05715208500623703, 'round level 1')
#
# linear combination for triple_raise :
#     (-2.5654096603393555, 1, -2.5654096603393555, 'round level 2')
#     (-2.3724327, 0, 0, 'bias')
#     (-2.242950439453125, 1, -2.242950439453125, 'player-0:state-active')
#     (1.973375678062439, 1, 1.973375678062439, 'btn distance=5')
#     (1.7017498016357422, 1, 1.7017498016357422, 'player-9:state-fold')
#     (1.3701834678649902, 1, 1.3701834678649902, 'player-5:state-fold')
#     (1.1818435192108154, 1, 1.1818435192108154, 'player-7:state-fold')
#     (-0.8888930082321167, 1, -0.8888930082321167, 'street-preflop')
#     (0.7871614098548889, 1, 0.7871614098548889, 'player-2:state-fold')
#     (0.658285915851593, 1, 0.658285915851593, 'player-1:state-active')
#     (0.6458732485771179, 1, 0.6458732485771179, 'player-4:state-fold')
#     (0.3644866645336151, 1, 0.3644866645336151, 'player-8:state-fold')
#     (0.3370206356048584, 1, 0.3370206356048584, 'player-6:state-fold')
#     (-0.3190620875358582, 0.099, -3.2228493690490723, 'player-1:stack')
#     (0.27352046966552734, 0.4, 0.6838011741638184, 'player-1:history')
#     (-0.24083283072710038, 0.09925, -2.426527261734009, 'player-6:stack')
#     (-0.21144606387615206, 0.0995, -2.1250860691070557, 'player-7:stack')
#     (-0.20555657887458803, 0.09975, -2.0607175827026367, 'player-5:stack')
#     (-0.19778493642807007, 0.1, -1.9778493642807007, 'player-8:stack')
#     (-0.19321404695510866, 0.1, -1.9321404695510864, 'player-3:stack')
#     (0.19270196557044983, 0.3, 0.6423398852348328, 'player-0:history')
#     (-0.184048068523407, 0.1, -1.8404806852340698, 'player-2:stack')
#     (-0.1834011737704277, 0.10175, -1.8024685382843018, 'player-9:stack')
#     (-0.16303051710128785, 0.1, -1.6303051710128784, 'player-4:stack')
#     (-0.09526265752315521, 0.09825, -0.9695944786071777, 'player-0:stack')
#     (0.09074126929044724, 1, 0.09074126929044724, 'player-3:state-fold')
#     (-0.010458312034606934, 0.0025, -4.183324813842773, 'pot')
#     (-0.006685664160177111, 0.71, -0.00941642839461565, 'cards')
#     (0.0, 0.0, 1.7745417356491089, 'player-9:history')
#     (0.0, 0, 1.4920952320098877, 'player-9:state-active')
#     (0.0, 0.0, 1.4680891036987305, 'player-8:history')
#     (0.0, 0, 1.5621132850646973, 'player-8:state-active')
#     (0.0, 0.0, 1.582472324371338, 'player-7:history')
#     (0.0, 0, 1.2232623100280762, 'player-7:state-active')
#     (0.0, 0.0, 0.8238332867622375, 'player-6:history')
#     (0.0, 0, 0.5151159167289734, 'player-6:state-active')
#     (0.0, 0.0, 4.160330772399902, 'player-5:history')
#     (0.0, 0, 0.6820471882820129, 'player-5:state-active')
#     (0.0, 0.0, 0.9121751189231873, 'player-4:history')
#     (0.0, 0, 0.5164560675621033, 'player-4:state-active')
#     (0.0, 0.0, 0.9788299798965454, 'player-3:history')
#     (0.0, 0, 0.11180011928081512, 'player-3:state-active')
#     (0.0, 0.0, 0.5327305793762207, 'player-2:history')
#     (0.0, 0, 0.8314283490180969, 'player-2:state-active')
#     (0.0, 0, 0.38340216875076294, 'player-1:state-fold')
#     (-0.0, 0, -0.23924040794372559, 'player-0:state-fold')
#     (-0.0, 0, -0.5806674361228943, 'street-river')
#     (-0.0, 0, -0.7105857729911804, 'street-turn')
#     (-0.0, 0, -0.7075456380844116, 'street-flop')
#     (-0.0, 0, -0.1619005799293518, 'btn distance=9')
#     (-0.0, 0, -0.11413408070802689, 'btn distance=8')
#     (-0.0, 0, -0.12604860961437225, 'btn distance=7')
#     (0.0, 0, 1.8543310165405273, 'btn distance=6')
#     (0.0, 0, 0.4832393229007721, 'btn distance=4')
#     (0.0, 0, 0.21936601400375366, 'btn distance=3')
#     (0.0, 0, 0.21691006422042847, 'btn distance=2')
#     (0.0, 0, 0.0388103649020195, 'btn distance=1')
#     (-0.0, 0, -0.15196388959884644, 'btn distance=0')
#     (-0.0, 0, -0.24565012753009796, 'round level 27')
#     (0.0, 0, 0.18738245964050293, 'round level 26')
#     (0.0, 0, 0.13563582301139832, 'round level 25')
#     (0.0, 0, 0.0051093026995658875, 'round level 24')
#     (0.0, 0, 0.15698617696762085, 'round level 23')
#     (-0.0, 0, -0.25703445076942444, 'round level 22')
#     (-0.0, 0, -0.2061779946088791, 'round level 21')
#     (-0.0, 0, -0.041454460471868515, 'round level 20')
#     (-0.0, 0, -0.09786731749773026, 'round level 19')
#     (-0.0, 0, -0.1264774352312088, 'round level 18')
#     (0.0, 0, 0.24566134810447693, 'round level 17')
#     (-0.0, 0, -0.1010018065571785, 'round level 16')
#     (-0.0, 0, -0.020011145621538162, 'round level 15')
#     (-0.0, 0, -0.05574813857674599, 'round level 14')
#     (-0.0, 0, -0.08178351819515228, 'round level 13')
#     (0.0, 0, 0.18671230971813202, 'round level 12')
#     (-0.0, 0, -0.05788012966513634, 'round level 11')
#     (-0.0, 0, -0.13147558271884918, 'round level 10')
#     (-0.0, 0, -0.23238608241081238, 'round level 9')
#     (-0.0, 0, -0.1202930361032486, 'round level 8')
#     (-0.0, 0, -0.12012208253145218, 'round level 7')
#     (-0.0, 0, -0.09084489941596985, 'round level 6')
#     (-0.0, 0, -0.057835355401039124, 'round level 5')
#     (-0.0, 0, -0.01247967779636383, 'round level 4')
#     (-0.0, 0, -0.2314309924840927, 'round level 3')
#     (0.0, 0, 0.10510239750146866, 'round level 1')
#
# linear combination for max_raise :
#     (-1.3251365423202515, 1, -1.3251365423202515, 'player-0:state-active')
#     (-1.1046034, 0, 0, 'bias')
#     (-0.8862913250923157, 1, -0.8862913250923157, 'round level 2')
#     (0.6391070485115051, 1, 0.6391070485115051, 'player-3:state-fold')
#     (0.632209837436676, 1, 0.632209837436676, 'player-7:state-fold')
#     (0.5480400919914246, 1, 0.5480400919914246, 'btn distance=5')
#     (0.48257705569267273, 1, 0.48257705569267273, 'player-4:state-fold')
#     (0.44052013754844666, 1, 0.44052013754844666, 'player-9:state-fold')
#     (0.3420032560825348, 1, 0.3420032560825348, 'street-preflop')
#     (0.3320745527744293, 1, 0.3320745527744293, 'player-5:state-fold')
#     (-0.28196588158607483, 1, -0.28196588158607483, 'player-8:state-fold')
#     (0.2176798939704895, 0.3, 0.7255996465682983, 'player-0:history')
#     (0.173703134059906, 1, 0.173703134059906, 'player-2:state-fold')
#     (-0.1707525289654732, 0.0995, -1.7161058187484741, 'player-7:stack')
#     (-0.15172435462474823, 0.09975, -1.5210461616516113, 'player-5:stack')
#     (-0.1405116520524025, 0.09925, -1.4157345294952393, 'player-6:stack')
#     (-0.11298981904983521, 0.1, -1.129898190498352, 'player-4:stack')
#     (0.10169141292572022, 0.4, 0.25422853231430054, 'player-1:history')
#     (-0.09824017053842544, 0.10175, -0.9655053615570068, 'player-9:stack')
#     (-0.09473544359207153, 0.1, -0.9473544359207153, 'player-2:stack')
#     (0.09468989819288254, 1, 0.09468989819288254, 'player-1:state-active')
#     (0.0770538704842329, 0.09825, 0.7842633128166199, 'player-0:stack')
#     (-0.06652165651321411, 0.1, -0.6652165651321411, 'player-8:stack')
#     (-0.043444587796926504, 0.099, -0.43883422017097473, 'player-1:stack')
#     (0.021432138886302708, 0.71, 0.030186111107468605, 'cards')
#     (-0.017020438611507416, 0.1, -0.17020438611507416, 'player-3:stack')
#     (-0.004348215647041798, 1, -0.004348215647041798, 'player-6:state-fold')
#     (0.0008687422424554825, 0.0025, 0.347496896982193, 'pot')
#     (0.0, 0.0, 0.6335735321044922, 'player-9:history')
#     (0.0, 0, 0.6906992197036743, 'player-9:state-active')
#     (0.0, 0.0, 0.1239309161901474, 'player-8:history')
#     (0.0, 0, 0.09257758408784866, 'player-8:state-active')
#     (0.0, 0.0, 0.6136317849159241, 'player-7:history')
#     (0.0, 0, 0.9286585450172424, 'player-7:state-active')
#     (0.0, 0.0, 0.2522195875644684, 'player-6:history')
#     (0.0, 0, 0.064662866294384, 'player-6:state-active')
#     (0.0, 0.0, 1.3058290481567383, 'player-5:history')
#     (0.0, 0, 0.16865608096122742, 'player-5:state-active')
#     (0.0, 0.0, 0.478394091129303, 'player-4:history')
#     (0.0, 0, 0.3826307952404022, 'player-4:state-active')
#     (0.0, 0.0, 0.8370112776756287, 'player-3:history')
#     (0.0, 0, 0.6775450706481934, 'player-3:state-active')
#     (-0.0, 0.0, -1.0136412382125854, 'player-2:history')
#     (0.0, 0, 0.2646414041519165, 'player-2:state-active')
#     (-0.0, 0, -0.051687128841876984, 'player-1:state-fold')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.6425154805183411, 'street-river')
#     (0.0, 0, 0.5084975957870483, 'street-turn')
#     (0.0, 0, 0.5016143321990967, 'street-flop')
#     (-0.0, 0, -0.10669941455125809, 'btn distance=9')
#     (0.0, 0, 0.234825998544693, 'btn distance=8')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.5216233730316162, 'btn distance=6')
#     (0.0, 0, 0.18136386573314667, 'btn distance=4')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')

# %% [markdown]
# ### FOLD する場面2

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['S3', 'HK']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu4 (uuid-4) => state : participating, stack : 9975 <= SB
#     - 2 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 3 : cpu3 (uuid-3) => state : folded, stack : 10000
#     - 4 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 5 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 6 : cpu7 (uuid-7) => state : participating, stack : 10000
#     - 7 : cpu9 (uuid-9) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu1 (uuid-1) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 1.0686166286468506), ('call', -0.49199461936950684), ('min_raise', 0.1642765998840332), ('double_raise', -0.13959550857543945), ('triple_raise', -0.2838606834411621), ('max_raise', -0.19092047214508057)]
# ** weights and features in detail **
# bias : [-2.24537802 -2.14030123 -2.49615192 -2.38752079 -2.37243271 -1.10460341]
#
# linear combination for fold :
#     (-2.431051731109619, 1, -2.431051731109619, 'round level 2')
#     (-2.245378, 0, 0, 'bias')
#     (-2.218794345855713, 1, -2.218794345855713, 'player-0:state-active')
#     (1.9195448160171509, 1, 1.9195448160171509, 'player-5:state-active')
#     (1.8243247270584106, 1, 1.8243247270584106, 'player-6:state-active')
#     (1.558862328529358, 1, 1.558862328529358, 'player-4:state-active')
#     (-1.5541051626205444, 1, -1.5541051626205444, 'player-7:state-active')
#     (1.5222080945968628, 1, 1.5222080945968628, 'player-3:state-active')
#     (1.1019710302352905, 1, 1.1019710302352905, 'player-1:state-active')
#     (1.0325573682785034, 1, 1.0325573682785034, 'player-2:state-active')
#     (0.7840678095817566, 1, 0.7840678095817566, 'player-8:state-active')
#     (0.7240239779154459, 0.6666666666666666, 1.086035966873169, 'player-8:history')
#     (0.5911204218864441, 1, 0.5911204218864441, 'player-9:state-fold')
#     (-0.22913243770599367, 0.1, -2.2913243770599365, 'player-6:stack')
#     (-0.21595120429992676, 0.1, -2.1595120429992676, 'player-5:stack')
#     (-0.19675021263957024, 0.09975, -1.9724332094192505, 'player-7:stack')
#     (0.1943889558315277, 1, 0.1943889558315277, 'street-preflop')
#     (-0.1934162676334381, 1, -0.1934162676334381, 'btn distance=4')
#     (-0.17216095447540283, 0.0995, -1.7302608489990234, 'player-8:stack')
#     (-0.1693753242492676, 0.1, -1.6937532424926758, 'player-4:stack')
#     (-0.16680443286895752, 0.1, -1.6680443286895752, 'player-1:stack')
#     (-0.13382815122604372, 0.1, -1.338281512260437, 'player-2:stack')
#     (-0.13278344869613648, 0.1, -1.3278344869613647, 'player-9:stack')
#     (-0.12089370489120484, 0.1, -1.2089370489120483, 'player-3:stack')
#     (0.050603777170181274, 0.3333333333333333, 0.15181133151054382, 'player-7:history')
#     (-0.031118673086166383, 0.1, -0.3111867308616638, 'player-0:stack')
#     (-0.022788610853254794, 0.581, -0.0392230823636055, 'cards')
#     (-0.0007235884666442872, 0.00075, -0.9647846221923828, 'pot')
#     (0.0, 0.0, 0.7042251229286194, 'player-9:history')
#     (0.0, 0, 0.8168973922729492, 'player-9:state-active')
#     (-0.0, 0, -0.3098161518573761, 'player-8:state-fold')
#     (-0.0, 0, -2.0704636573791504, 'player-7:state-fold')
#     (0.0, 0.0, 1.1388506889343262, 'player-6:history')
#     (0.0, 0, 1.6409307718276978, 'player-6:state-fold')
#     (0.0, 0.0, 2.2844033241271973, 'player-5:history')
#     (0.0, 0, 1.7820357084274292, 'player-5:state-fold')
#     (0.0, 0.0, 0.05564766377210617, 'player-4:history')
#     (0.0, 0, 1.4899870157241821, 'player-4:state-fold')
#     (0.0, 0.0, 1.0570818185806274, 'player-3:history')
#     (0.0, 0, 1.6157982349395752, 'player-3:state-fold')
#     (0.0, 0.0, 0.8161777853965759, 'player-2:history')
#     (0.0, 0, 1.1088765859603882, 'player-2:state-fold')
#     (0.0, 0.0, 0.23884399235248566, 'player-1:history')
#     (0.0, 0, 1.7078877687454224, 'player-1:state-fold')
#     (0.0, 0.0, 1.0608843564987183, 'player-0:history')
#     (-0.0, 0, -0.16855023801326752, 'player-0:state-fold')
#     (0.0, 0, 0.3334566652774811, 'street-river')
#     (0.0, 0, 0.343752384185791, 'street-turn')
#     (0.0, 0, 0.5796384215354919, 'street-flop')
#     (-0.0, 0, -0.25582072138786316, 'btn distance=9')
#     (-0.0, 0, -0.05282701924443245, 'btn distance=8')
#     (-0.0, 0, -0.0038959376979619265, 'btn distance=7')
#     (-0.0, 0, -0.22828711569309235, 'btn distance=6')
#     (-0.0, 0, -0.12463589757680893, 'btn distance=5')
#     (0.0, 0, 0.24655739963054657, 'btn distance=3')
#     (0.0, 0, 0.24461735785007477, 'btn distance=2')
#     (0.0, 0, 0.00847628340125084, 'btn distance=1')
#     (0.0, 0, 0.020165950059890747, 'btn distance=0')
#     (-0.0, 0, -0.2213701456785202, 'round level 27')
#     (-0.0, 0, -0.10197050869464874, 'round level 26')
#     (0.0, 0, 0.10495710372924805, 'round level 25')
#     (-0.0, 0, -0.08853317052125931, 'round level 24')
#     (-0.0, 0, -0.1523839384317398, 'round level 23')
#     (-0.0, 0, -0.017349783331155777, 'round level 22')
#     (-0.0, 0, -0.19680342078208923, 'round level 21')
#     (-0.0, 0, -0.06522854417562485, 'round level 20')
#     (-0.0, 0, -0.11076478660106659, 'round level 19')
#     (0.0, 0, 0.0205842275172472, 'round level 18')
#     (0.0, 0, 0.012719148769974709, 'round level 17')
#     (0.0, 0, 0.04748936742544174, 'round level 16')
#     (0.0, 0, 0.12460202723741531, 'round level 15')
#     (-0.0, 0, -0.2402883917093277, 'round level 14')
#     (-0.0, 0, -0.18431814014911652, 'round level 13')
#     (0.0, 0, 0.11604927480220795, 'round level 12')
#     (-0.0, 0, -0.22294166684150696, 'round level 11')
#     (-0.0, 0, -0.033192384988069534, 'round level 10')
#     (0.0, 0, 0.1476805955171585, 'round level 9')
#     (-0.0, 0, -0.2127474993467331, 'round level 8')
#     (-0.0, 0, -0.22087788581848145, 'round level 7')
#     (-0.0, 0, -0.24462102353572845, 'round level 6')
#     (-0.0, 0, -0.18650652468204498, 'round level 5')
#     (-0.0, 0, -0.16058392822742462, 'round level 4')
#     (-0.0, 0, -0.2439037710428238, 'round level 3')
#     (-0.0, 0, -0.14012868702411652, 'round level 1')
#
# linear combination for call :
#     (-2.2445640563964844, 1, -2.2445640563964844, 'player-0:state-active')
#     (-2.1403012, 0, 0, 'bias')
#     (-2.0760812759399414, 1, -2.0760812759399414, 'round level 2')
#     (1.4917446374893188, 1, 1.4917446374893188, 'player-9:state-fold')
#     (0.7556829452514648, 1, 0.7556829452514648, 'player-4:state-active')
#     (0.715787947177887, 1, 0.715787947177887, 'btn distance=4')
#     (0.7037453651428223, 1, 0.7037453651428223, 'player-8:state-active')
#     (0.5837045907974243, 1, 0.5837045907974243, 'player-7:state-active')
#     (0.5820401906967163, 1, 0.5820401906967163, 'player-1:state-active')
#     (0.4116262197494507, 0.6666666666666666, 0.617439329624176, 'player-8:history')
#     (0.4035125970840454, 1, 0.4035125970840454, 'player-6:state-active')
#     (0.3562793731689453, 0.3333333333333333, 1.068838119506836, 'player-7:history')
#     (0.28508293628692627, 1, 0.28508293628692627, 'player-2:state-active')
#     (0.26324620842933655, 1, 0.26324620842933655, 'player-5:state-active')
#     (0.19035984575748444, 1, 0.19035984575748444, 'player-3:state-active')
#     (-0.15180565118789674, 0.1, -1.5180565118789673, 'player-5:stack')
#     (-0.13619850873947145, 0.1, -1.3619850873947144, 'player-6:stack')
#     (-0.12190309756994248, 0.09975, -1.2220861911773682, 'player-7:stack')
#     (-0.10131546258926392, 0.1, -1.0131546258926392, 'player-9:stack')
#     (-0.09908056855201722, 0.1, -0.9908056855201721, 'player-1:stack')
#     (-0.08827736228704453, 1, -0.08827736228704453, 'street-preflop')
#     (-0.07259408625960351, 0.0995, -0.7295888066291809, 'player-8:stack')
#     (-0.06614058613777161, 0.1, -0.6614058613777161, 'player-2:stack')
#     (0.04054495990276337, 0.1, 0.40544959902763367, 'player-0:stack')
#     (0.03658467829227448, 0.1, 0.36584678292274475, 'player-4:stack')
#     (-0.021985971927642824, 0.1, -0.21985971927642822, 'player-3:stack')
#     (0.00859527312312275, 0.581, 0.014793929643929005, 'cards')
#     (-0.00028469757735729217, 0.00075, -0.3795967698097229, 'pot')
#     (0.0, 0.0, 1.8624440431594849, 'player-9:history')
#     (0.0, 0, 1.8865877389907837, 'player-9:state-active')
#     (-0.0, 0, -0.3125944137573242, 'player-8:state-fold')
#     (-0.0, 0, -0.3545590043067932, 'player-7:state-fold')
#     (0.0, 0.0, 1.4711203575134277, 'player-6:history')
#     (-0.0, 0, -0.06702187657356262, 'player-6:state-fold')
#     (0.0, 0.0, 1.1949214935302734, 'player-5:history')
#     (-0.0, 0, -0.14356182515621185, 'player-5:state-fold')
#     (0.0, 0.0, 1.6109318733215332, 'player-4:history')
#     (0.0, 0, 1.0968955755233765, 'player-4:state-fold')
#     (0.0, 0.0, 2.3010153770446777, 'player-3:history')
#     (0.0, 0, 0.2964814305305481, 'player-3:state-fold')
#     (0.0, 0.0, 0.8736161589622498, 'player-2:history')
#     (0.0, 0, 0.3408045768737793, 'player-2:state-fold')
#     (0.0, 0.0, 0.9040548205375671, 'player-1:history')
#     (0.0, 0, 0.9013826251029968, 'player-1:state-fold')
#     (0.0, 0.0, 2.0581040382385254, 'player-0:history')
#     (-0.0, 0, -0.24465030431747437, 'player-0:state-fold')
#     (0.0, 0, 0.1361539363861084, 'street-river')
#     (0.0, 0, 0.12363648414611816, 'street-turn')
#     (0.0, 0, 0.138866126537323, 'street-flop')
#     (0.0, 0, 0.032845038920640945, 'btn distance=9')
#     (-0.0, 0, -0.19617345929145813, 'btn distance=8')
#     (0.0, 0, 0.07213658094406128, 'btn distance=7')
#     (0.0, 0, 1.8069616556167603, 'btn distance=6')
#     (0.0, 0, 1.8200968503952026, 'btn distance=5')
#     (-0.0, 0, -0.013489801436662674, 'btn distance=3')
#     (-0.0, 0, -0.08585645258426666, 'btn distance=2')
#     (0.0, 0, 0.06344975531101227, 'btn distance=1')
#     (0.0, 0, 0.15164510905742645, 'btn distance=0')
#     (0.0, 0, 0.0985424593091011, 'round level 27')
#     (0.0, 0, 0.14169394969940186, 'round level 26')
#     (-0.0, 0, -0.0893365889787674, 'round level 25')
#     (0.0, 0, 0.20847563445568085, 'round level 24')
#     (-0.0, 0, -0.03645148128271103, 'round level 23')
#     (-0.0, 0, -0.18086203932762146, 'round level 22')
#     (0.0, 0, 0.02206127904355526, 'round level 21')
#     (0.0, 0, 0.22536905109882355, 'round level 20')
#     (-0.0, 0, -0.0331120602786541, 'round level 19')
#     (0.0, 0, 0.20565178990364075, 'round level 18')
#     (0.0, 0, 0.0686635747551918, 'round level 17')
#     (-0.0, 0, -0.08000461012125015, 'round level 16')
#     (0.0, 0, 0.0541294701397419, 'round level 15')
#     (-0.0, 0, -0.02931520901620388, 'round level 14')
#     (0.0, 0, 0.12170209735631943, 'round level 13')
#     (0.0, 0, 0.03970080614089966, 'round level 12')
#     (0.0, 0, 0.038793016225099564, 'round level 11')
#     (-0.0, 0, -0.054109975695610046, 'round level 10')
#     (-0.0, 0, -0.17569488286972046, 'round level 9')
#     (-0.0, 0, -0.17326530814170837, 'round level 8')
#     (0.0, 0, 0.02020121179521084, 'round level 7')
#     (-0.0, 0, -0.23628146946430206, 'round level 6')
#     (0.0, 0, 0.002258514752611518, 'round level 5')
#     (-0.0, 0, -0.1273975968360901, 'round level 4')
#     (0.0, 0, 0.10532896220684052, 'round level 3')
#     (0.0, 0, 0.24328196048736572, 'round level 1')
#
# linear combination for min_raise :
#     (-2.6741485595703125, 1, -2.6741485595703125, 'round level 2')
#     (-2.5425000190734863, 1, -2.5425000190734863, 'player-0:state-active')
#     (-2.4961519, 0, 0, 'bias')
#     (2.033776044845581, 1, 2.033776044845581, 'player-9:state-fold')
#     (1.3269157409667969, 1, 1.3269157409667969, 'player-8:state-active')
#     (1.1605361700057983, 1, 1.1605361700057983, 'player-1:state-active')
#     (1.0241550207138062, 1, 1.0241550207138062, 'player-7:state-active')
#     (0.8094753424326578, 0.6666666666666666, 1.2142130136489868, 'player-8:history')
#     (0.709435760974884, 1, 0.709435760974884, 'player-5:state-active')
#     (0.7028936743736267, 1, 0.7028936743736267, 'player-2:state-active')
#     (0.6351824402809143, 1, 0.6351824402809143, 'player-6:state-active')
#     (0.5843061804771423, 1, 0.5843061804771423, 'btn distance=4')
#     (0.46731603145599365, 0.3333333333333333, 1.401948094367981, 'player-7:history')
#     (0.43497592210769653, 1, 0.43497592210769653, 'player-4:state-active')
#     (-0.25397777557373047, 0.1, -2.5397777557373047, 'player-1:stack')
#     (-0.2523124933242798, 0.1, -2.523124933242798, 'player-6:stack')
#     (-0.19725695848464966, 0.1, -1.9725695848464966, 'player-5:stack')
#     (-0.18497569039463999, 0.09975, -1.8543928861618042, 'player-7:stack')
#     (-0.18295388221740724, 0.1, -1.8295388221740723, 'player-9:stack')
#     (-0.16726447343826295, 0.1, -1.6726447343826294, 'player-2:stack')
#     (-0.1555899845957756, 0.0995, -1.5637184381484985, 'player-8:stack')
#     (-0.15340092182159426, 0.1, -1.5340092182159424, 'player-3:stack')
#     (-0.14664705991744995, 0.1, -1.4664705991744995, 'player-4:stack')
#     (-0.1426054686307907, 1, -0.1426054686307907, 'player-3:state-active')
#     (-0.11383439600467682, 1, -0.11383439600467682, 'street-preflop')
#     (-0.07038970589637757, 0.1, -0.7038970589637756, 'player-0:stack')
#     (0.0106821755412966, 0.581, 0.01838584430515766, 'cards')
#     (-0.0013650520741939544, 0.00075, -1.820069432258606, 'pot')
#     (0.0, 0.0, 1.7287386655807495, 'player-9:history')
#     (0.0, 0, 2.2141034603118896, 'player-9:state-active')
#     (0.0, 0, 0.30986031889915466, 'player-8:state-fold')
#     (0.0, 0, 0.36654409766197205, 'player-7:state-fold')
#     (0.0, 0.0, 1.2207356691360474, 'player-6:history')
#     (0.0, 0, 0.4207422137260437, 'player-6:state-fold')
#     (0.0, 0.0, 3.619497537612915, 'player-5:history')
#     (0.0, 0, 0.6914798617362976, 'player-5:state-fold')
#     (0.0, 0.0, 1.1321343183517456, 'player-4:history')
#     (0.0, 0, 0.5677550435066223, 'player-4:state-fold')
#     (0.0, 0.0, 2.0687448978424072, 'player-3:history')
#     (-0.0, 0, -0.03342190384864807, 'player-3:state-fold')
#     (0.0, 0.0, 0.5935136675834656, 'player-2:history')
#     (0.0, 0, 0.7674608826637268, 'player-2:state-fold')
#     (0.0, 0.0, 1.0035585165023804, 'player-1:history')
#     (0.0, 0, 1.1311455965042114, 'player-1:state-fold')
#     (0.0, 0.0, 1.6993013620376587, 'player-0:history')
#     (-0.0, 0, -0.20744803547859192, 'player-0:state-fold')
#     (-0.0, 0, -0.04107475280761719, 'street-river')
#     (0.0, 0, 0.026161091402173042, 'street-turn')
#     (-0.0, 0, -0.02991003915667534, 'street-flop')
#     (-0.0, 0, -0.1774212121963501, 'btn distance=9')
#     (-0.0, 0, -0.047159694135189056, 'btn distance=8')
#     (-0.0, 0, -0.23359006643295288, 'btn distance=7')
#     (0.0, 0, 1.4792786836624146, 'btn distance=6')
#     (0.0, 0, 1.4675281047821045, 'btn distance=5')
#     (0.0, 0, 0.1799440085887909, 'btn distance=3')
#     (-0.0, 0, -0.20211511850357056, 'btn distance=2')
#     (0.0, 0, 0.09343760460615158, 'btn distance=1')
#     (0.0, 0, 0.11541350930929184, 'btn distance=0')
#     (-0.0, 0, -0.13404113054275513, 'round level 27')
#     (-0.0, 0, -0.0732564777135849, 'round level 26')
#     (-0.0, 0, -0.11470962315797806, 'round level 25')
#     (-0.0, 0, -0.25008055567741394, 'round level 24')
#     (0.0, 0, 0.17256297171115875, 'round level 23')
#     (-0.0, 0, -0.1267537772655487, 'round level 22')
#     (-0.0, 0, -0.07261916995048523, 'round level 21')
#     (0.0, 0, 0.1588955521583557, 'round level 20')
#     (0.0, 0, 0.08600028604269028, 'round level 19')
#     (-0.0, 0, -0.02734578587114811, 'round level 18')
#     (-0.0, 0, -0.17110729217529297, 'round level 17')
#     (0.0, 0, 0.24235090613365173, 'round level 16')
#     (0.0, 0, 0.12469331175088882, 'round level 15')
#     (0.0, 0, 0.11679039150476456, 'round level 14')
#     (0.0, 0, 0.07780515402555466, 'round level 13')
#     (-0.0, 0, -0.14643879234790802, 'round level 12')
#     (0.0, 0, 0.007210777141153812, 'round level 11')
#     (-0.0, 0, -0.19605398178100586, 'round level 10')
#     (-0.0, 0, -0.04223441332578659, 'round level 9')
#     (0.0, 0, 0.04012596234679222, 'round level 8')
#     (-0.0, 0, -0.12791728973388672, 'round level 7')
#     (-0.0, 0, -0.14899274706840515, 'round level 6')
#     (0.0, 0, 0.21625015139579773, 'round level 5')
#     (0.0, 0, 0.04604363441467285, 'round level 4')
#     (-0.0, 0, -0.2570226490497589, 'round level 3')
#     (0.0, 0, 0.07486462593078613, 'round level 1')
#
# linear combination for double_raise :
#     (-2.5915870666503906, 1, -2.5915870666503906, 'player-0:state-active')
#     (-2.3875208, 0, 0, 'bias')
#     (-2.1957459449768066, 1, -2.1957459449768066, 'round level 2')
#     (1.7065824270248413, 1, 1.7065824270248413, 'player-9:state-fold')
#     (1.5541554689407349, 1, 1.5541554689407349, 'player-7:state-active')
#     (1.307974100112915, 1, 1.307974100112915, 'player-8:state-active')
#     (0.9674238363901774, 0.6666666666666666, 1.4511357545852661, 'player-8:history')
#     (0.8493184447288513, 1, 0.8493184447288513, 'player-2:state-active')
#     (0.6920390725135803, 1, 0.6920390725135803, 'player-1:state-active')
#     (0.5060282945632935, 0.3333333333333333, 1.5180848836898804, 'player-7:history')
#     (0.36283689737319946, 1, 0.36283689737319946, 'player-3:state-active')
#     (0.3248136341571808, 1, 0.3248136341571808, 'player-4:state-active')
#     (0.29325035214424133, 1, 0.29325035214424133, 'player-6:state-active')
#     (0.2912150025367737, 1, 0.2912150025367737, 'btn distance=4')
#     (-0.25294487476348876, 0.1, -2.5294487476348877, 'player-6:stack')
#     (-0.20290050506591797, 0.1, -2.0290050506591797, 'player-1:stack')
#     (-0.19750735634565356, 0.09975, -1.9800236225128174, 'player-7:stack')
#     (-0.1947524428367615, 0.1, -1.9475244283676147, 'player-5:stack')
#     (-0.17938907146453859, 0.1, -1.7938907146453857, 'player-2:stack')
#     (-0.17822571992874148, 0.1, -1.7822571992874146, 'player-9:stack')
#     (-0.17708672285079957, 0.1, -1.7708672285079956, 'player-3:stack')
#     (-0.13437527418136597, 0.1, -1.3437527418136597, 'player-4:stack')
#     (-0.13399604040384294, 0.0995, -1.3466938734054565, 'player-8:stack')
#     (-0.10949435830116272, 1, -0.10949435830116272, 'street-preflop')
#     (-0.08243178725242616, 0.1, -0.8243178725242615, 'player-0:stack')
#     (0.01988460924476385, 0.581, 0.034224800765514374, 'cards')
#     (0.005027344916015863, 1, 0.005027344916015863, 'player-5:state-active')
#     (-0.0021866211891174315, 0.00075, -2.915494918823242, 'pot')
#     (0.0, 0.0, 1.7979799509048462, 'player-9:history')
#     (0.0, 0, 1.4783991575241089, 'player-9:state-active')
#     (0.0, 0, 0.1973874717950821, 'player-8:state-fold')
#     (0.0, 0, 1.3565353155136108, 'player-7:state-fold')
#     (0.0, 0.0, 0.6093665361404419, 'player-6:history')
#     (0.0, 0, 0.09614922106266022, 'player-6:state-fold')
#     (0.0, 0.0, 4.2742438316345215, 'player-5:history')
#     (0.0, 0, 0.7188841104507446, 'player-5:state-fold')
#     (0.0, 0.0, 0.8796502351760864, 'player-4:history')
#     (0.0, 0, 0.4836919605731964, 'player-4:state-fold')
#     (0.0, 0.0, 1.0582114458084106, 'player-3:history')
#     (0.0, 0, 0.4559221565723419, 'player-3:state-fold')
#     (0.0, 0.0, 0.5237418413162231, 'player-2:history')
#     (0.0, 0, 0.902125358581543, 'player-2:state-fold')
#     (0.0, 0.0, 0.791723906993866, 'player-1:history')
#     (0.0, 0, 0.20732176303863525, 'player-1:state-fold')
#     (0.0, 0.0, 0.7544894218444824, 'player-0:history')
#     (0.0, 0, 0.1994665414094925, 'player-0:state-fold')
#     (0.0, 0, 0.18096104264259338, 'street-river')
#     (0.0, 0, 0.015104751102626324, 'street-turn')
#     (-0.0, 0, -0.11874984204769135, 'street-flop')
#     (0.0, 0, 0.16180437803268433, 'btn distance=9')
#     (-0.0, 0, -0.16994917392730713, 'btn distance=8')
#     (-0.0, 0, -0.2551056444644928, 'btn distance=7')
#     (0.0, 0, 1.7864481210708618, 'btn distance=6')
#     (0.0, 0, 1.8671458959579468, 'btn distance=5')
#     (-0.0, 0, -0.07808863371610641, 'btn distance=3')
#     (0.0, 0, 0.07531379163265228, 'btn distance=2')
#     (-0.0, 0, -0.04036684334278107, 'btn distance=1')
#     (-0.0, 0, -0.241798534989357, 'btn distance=0')
#     (-0.0, 0, -0.012274674139916897, 'round level 27')
#     (-0.0, 0, -0.1700371652841568, 'round level 26')
#     (-0.0, 0, -0.06231385096907616, 'round level 25')
#     (-0.0, 0, -0.19142040610313416, 'round level 24')
#     (0.0, 0, 0.0052865338511765, 'round level 23')
#     (0.0, 0, 0.10509058088064194, 'round level 22')
#     (0.0, 0, 0.148484006524086, 'round level 21')
#     (-0.0, 0, -0.2335253208875656, 'round level 20')
#     (0.0, 0, 0.024247899651527405, 'round level 19')
#     (0.0, 0, 0.24292117357254028, 'round level 18')
#     (0.0, 0, 0.059873905032873154, 'round level 17')
#     (0.0, 0, 0.13325431942939758, 'round level 16')
#     (0.0, 0, 0.12490264326334, 'round level 15')
#     (0.0, 0, 0.17109589278697968, 'round level 14')
#     (-0.0, 0, -0.23500089347362518, 'round level 13')
#     (0.0, 0, 0.1816813349723816, 'round level 12')
#     (-0.0, 0, -0.14072857797145844, 'round level 11')
#     (-0.0, 0, -0.02639414370059967, 'round level 10')
#     (-0.0, 0, -0.12533557415008545, 'round level 9')
#     (0.0, 0, 0.21444687247276306, 'round level 8')
#     (0.0, 0, 0.2577686905860901, 'round level 7')
#     (-0.0, 0, -0.020569249987602234, 'round level 6')
#     (-0.0, 0, -0.08953545987606049, 'round level 5')
#     (-0.0, 0, -0.13333763182163239, 'round level 4')
#     (-0.0, 0, -0.00587732857093215, 'round level 3')
#     (0.0, 0, 0.05715208500623703, 'round level 1')
#
# linear combination for triple_raise :
#     (-2.5654096603393555, 1, -2.5654096603393555, 'round level 2')
#     (-2.3724327, 0, 0, 'bias')
#     (-2.242950439453125, 1, -2.242950439453125, 'player-0:state-active')
#     (1.7017498016357422, 1, 1.7017498016357422, 'player-9:state-fold')
#     (1.5621132850646973, 1, 1.5621132850646973, 'player-8:state-active')
#     (1.2232623100280762, 1, 1.2232623100280762, 'player-7:state-active')
#     (0.9787260691324869, 0.6666666666666666, 1.4680891036987305, 'player-8:history')
#     (-0.8888930082321167, 1, -0.8888930082321167, 'street-preflop')
#     (0.8314283490180969, 1, 0.8314283490180969, 'player-2:state-active')
#     (0.6820471882820129, 1, 0.6820471882820129, 'player-5:state-active')
#     (0.658285915851593, 1, 0.658285915851593, 'player-1:state-active')
#     (0.5274907747904459, 0.3333333333333333, 1.582472324371338, 'player-7:history')
#     (0.5164560675621033, 1, 0.5164560675621033, 'player-4:state-active')
#     (0.5151159167289734, 1, 0.5151159167289734, 'player-6:state-active')
#     (0.4832393229007721, 1, 0.4832393229007721, 'btn distance=4')
#     (-0.3222849369049072, 0.1, -3.2228493690490723, 'player-1:stack')
#     (-0.2426527261734009, 0.1, -2.426527261734009, 'player-6:stack')
#     (-0.2119773353934288, 0.09975, -2.1250860691070557, 'player-7:stack')
#     (-0.2060717582702637, 0.1, -2.0607175827026367, 'player-5:stack')
#     (-0.19679601174592973, 0.0995, -1.9778493642807007, 'player-8:stack')
#     (-0.19321404695510866, 0.1, -1.9321404695510864, 'player-3:stack')
#     (-0.184048068523407, 0.1, -1.8404806852340698, 'player-2:stack')
#     (-0.1802468538284302, 0.1, -1.8024685382843018, 'player-9:stack')
#     (-0.16303051710128785, 0.1, -1.6303051710128784, 'player-4:stack')
#     (0.11180011928081512, 1, 0.11180011928081512, 'player-3:state-active')
#     (-0.09695944786071778, 0.1, -0.9695944786071777, 'player-0:stack')
#     (-0.005470944897271692, 0.581, -0.00941642839461565, 'cards')
#     (-0.0031374936103820803, 0.00075, -4.183324813842773, 'pot')
#     (0.0, 0.0, 1.7745417356491089, 'player-9:history')
#     (0.0, 0, 1.4920952320098877, 'player-9:state-active')
#     (0.0, 0, 0.3644866645336151, 'player-8:state-fold')
#     (0.0, 0, 1.1818435192108154, 'player-7:state-fold')
#     (0.0, 0.0, 0.8238332867622375, 'player-6:history')
#     (0.0, 0, 0.3370206356048584, 'player-6:state-fold')
#     (0.0, 0.0, 4.160330772399902, 'player-5:history')
#     (0.0, 0, 1.3701834678649902, 'player-5:state-fold')
#     (0.0, 0.0, 0.9121751189231873, 'player-4:history')
#     (0.0, 0, 0.6458732485771179, 'player-4:state-fold')
#     (0.0, 0.0, 0.9788299798965454, 'player-3:history')
#     (0.0, 0, 0.09074126929044724, 'player-3:state-fold')
#     (0.0, 0.0, 0.5327305793762207, 'player-2:history')
#     (0.0, 0, 0.7871614098548889, 'player-2:state-fold')
#     (0.0, 0.0, 0.6838011741638184, 'player-1:history')
#     (0.0, 0, 0.38340216875076294, 'player-1:state-fold')
#     (0.0, 0.0, 0.6423398852348328, 'player-0:history')
#     (-0.0, 0, -0.23924040794372559, 'player-0:state-fold')
#     (-0.0, 0, -0.5806674361228943, 'street-river')
#     (-0.0, 0, -0.7105857729911804, 'street-turn')
#     (-0.0, 0, -0.7075456380844116, 'street-flop')
#     (-0.0, 0, -0.1619005799293518, 'btn distance=9')
#     (-0.0, 0, -0.11413408070802689, 'btn distance=8')
#     (-0.0, 0, -0.12604860961437225, 'btn distance=7')
#     (0.0, 0, 1.8543310165405273, 'btn distance=6')
#     (0.0, 0, 1.973375678062439, 'btn distance=5')
#     (0.0, 0, 0.21936601400375366, 'btn distance=3')
#     (0.0, 0, 0.21691006422042847, 'btn distance=2')
#     (0.0, 0, 0.0388103649020195, 'btn distance=1')
#     (-0.0, 0, -0.15196388959884644, 'btn distance=0')
#     (-0.0, 0, -0.24565012753009796, 'round level 27')
#     (0.0, 0, 0.18738245964050293, 'round level 26')
#     (0.0, 0, 0.13563582301139832, 'round level 25')
#     (0.0, 0, 0.0051093026995658875, 'round level 24')
#     (0.0, 0, 0.15698617696762085, 'round level 23')
#     (-0.0, 0, -0.25703445076942444, 'round level 22')
#     (-0.0, 0, -0.2061779946088791, 'round level 21')
#     (-0.0, 0, -0.041454460471868515, 'round level 20')
#     (-0.0, 0, -0.09786731749773026, 'round level 19')
#     (-0.0, 0, -0.1264774352312088, 'round level 18')
#     (0.0, 0, 0.24566134810447693, 'round level 17')
#     (-0.0, 0, -0.1010018065571785, 'round level 16')
#     (-0.0, 0, -0.020011145621538162, 'round level 15')
#     (-0.0, 0, -0.05574813857674599, 'round level 14')
#     (-0.0, 0, -0.08178351819515228, 'round level 13')
#     (0.0, 0, 0.18671230971813202, 'round level 12')
#     (-0.0, 0, -0.05788012966513634, 'round level 11')
#     (-0.0, 0, -0.13147558271884918, 'round level 10')
#     (-0.0, 0, -0.23238608241081238, 'round level 9')
#     (-0.0, 0, -0.1202930361032486, 'round level 8')
#     (-0.0, 0, -0.12012208253145218, 'round level 7')
#     (-0.0, 0, -0.09084489941596985, 'round level 6')
#     (-0.0, 0, -0.057835355401039124, 'round level 5')
#     (-0.0, 0, -0.01247967779636383, 'round level 4')
#     (-0.0, 0, -0.2314309924840927, 'round level 3')
#     (0.0, 0, 0.10510239750146866, 'round level 1')
#
# linear combination for max_raise :
#     (-1.3251365423202515, 1, -1.3251365423202515, 'player-0:state-active')
#     (-1.1046034, 0, 0, 'bias')
#     (0.9286585450172424, 1, 0.9286585450172424, 'player-7:state-active')
#     (-0.8862913250923157, 1, -0.8862913250923157, 'round level 2')
#     (0.6775450706481934, 1, 0.6775450706481934, 'player-3:state-active')
#     (0.44052013754844666, 1, 0.44052013754844666, 'player-9:state-fold')
#     (0.3826307952404022, 1, 0.3826307952404022, 'player-4:state-active')
#     (0.3420032560825348, 1, 0.3420032560825348, 'street-preflop')
#     (0.2646414041519165, 1, 0.2646414041519165, 'player-2:state-active')
#     (0.20454392830530801, 0.3333333333333333, 0.6136317849159241, 'player-7:history')
#     (0.18136386573314667, 1, 0.18136386573314667, 'btn distance=4')
#     (-0.1711815554201603, 0.09975, -1.7161058187484741, 'player-7:stack')
#     (0.16865608096122742, 1, 0.16865608096122742, 'player-5:state-active')
#     (-0.15210461616516113, 0.1, -1.5210461616516113, 'player-5:stack')
#     (-0.14157345294952392, 0.1, -1.4157345294952393, 'player-6:stack')
#     (-0.11298981904983521, 0.1, -1.129898190498352, 'player-4:stack')
#     (-0.0965505361557007, 0.1, -0.9655053615570068, 'player-9:stack')
#     (-0.09473544359207153, 0.1, -0.9473544359207153, 'player-2:stack')
#     (0.09468989819288254, 1, 0.09468989819288254, 'player-1:state-active')
#     (0.09257758408784866, 1, 0.09257758408784866, 'player-8:state-active')
#     (0.0826206107934316, 0.6666666666666666, 0.1239309161901474, 'player-8:history')
#     (0.07842633128166199, 0.1, 0.7842633128166199, 'player-0:stack')
#     (-0.06618904823064804, 0.0995, -0.6652165651321411, 'player-8:stack')
#     (0.064662866294384, 1, 0.064662866294384, 'player-6:state-active')
#     (-0.043883422017097475, 0.1, -0.43883422017097473, 'player-1:stack')
#     (0.01753813055343926, 0.581, 0.030186111107468605, 'cards')
#     (-0.017020438611507416, 0.1, -0.17020438611507416, 'player-3:stack')
#     (0.0002606226727366447, 0.00075, 0.347496896982193, 'pot')
#     (0.0, 0.0, 0.6335735321044922, 'player-9:history')
#     (0.0, 0, 0.6906992197036743, 'player-9:state-active')
#     (-0.0, 0, -0.28196588158607483, 'player-8:state-fold')
#     (0.0, 0, 0.632209837436676, 'player-7:state-fold')
#     (0.0, 0.0, 0.2522195875644684, 'player-6:history')
#     (-0.0, 0, -0.004348215647041798, 'player-6:state-fold')
#     (0.0, 0.0, 1.3058290481567383, 'player-5:history')
#     (0.0, 0, 0.3320745527744293, 'player-5:state-fold')
#     (0.0, 0.0, 0.478394091129303, 'player-4:history')
#     (0.0, 0, 0.48257705569267273, 'player-4:state-fold')
#     (0.0, 0.0, 0.8370112776756287, 'player-3:history')
#     (0.0, 0, 0.6391070485115051, 'player-3:state-fold')
#     (-0.0, 0.0, -1.0136412382125854, 'player-2:history')
#     (0.0, 0, 0.173703134059906, 'player-2:state-fold')
#     (0.0, 0.0, 0.25422853231430054, 'player-1:history')
#     (-0.0, 0, -0.051687128841876984, 'player-1:state-fold')
#     (0.0, 0.0, 0.7255996465682983, 'player-0:history')
#     (0.0, 0, 0.05972422659397125, 'player-0:state-fold')
#     (0.0, 0, 0.6425154805183411, 'street-river')
#     (0.0, 0, 0.5084975957870483, 'street-turn')
#     (0.0, 0, 0.5016143321990967, 'street-flop')
#     (-0.0, 0, -0.10669941455125809, 'btn distance=9')
#     (0.0, 0, 0.234825998544693, 'btn distance=8')
#     (0.0, 0, 0.24791757762432098, 'btn distance=7')
#     (0.0, 0, 0.5216233730316162, 'btn distance=6')
#     (0.0, 0, 0.5480400919914246, 'btn distance=5')
#     (0.0, 0, 0.11917581409215927, 'btn distance=3')
#     (-0.0, 0, -0.1073332354426384, 'btn distance=2')
#     (-0.0, 0, -0.16934698820114136, 'btn distance=1')
#     (-0.0, 0, -0.1712239384651184, 'btn distance=0')
#     (0.0, 0, 0.24530474841594696, 'round level 27')
#     (-0.0, 0, -0.07771812379360199, 'round level 26')
#     (-0.0, 0, -0.17958907783031464, 'round level 25')
#     (-0.0, 0, -0.12927888333797455, 'round level 24')
#     (-0.0, 0, -0.13175217807292938, 'round level 23')
#     (0.0, 0, 0.005823968909680843, 'round level 22')
#     (0.0, 0, 0.24492628872394562, 'round level 21')
#     (-0.0, 0, -0.12643815577030182, 'round level 20')
#     (0.0, 0, 0.13060271739959717, 'round level 19')
#     (0.0, 0, 0.17788179218769073, 'round level 18')
#     (-0.0, 0, -0.05944858491420746, 'round level 17')
#     (0.0, 0, 0.0719224363565445, 'round level 16')
#     (-0.0, 0, -0.033691249787807465, 'round level 15')
#     (-0.0, 0, -0.007938333787024021, 'round level 14')
#     (-0.0, 0, -0.1456688791513443, 'round level 13')
#     (-0.0, 0, -0.1447516828775406, 'round level 12')
#     (0.0, 0, 0.1404879093170166, 'round level 11')
#     (-0.0, 0, -0.189093679189682, 'round level 10')
#     (-0.0, 0, -0.17959700524806976, 'round level 9')
#     (0.0, 0, 0.14175057411193848, 'round level 8')
#     (-0.0, 0, -0.0198837723582983, 'round level 7')
#     (-0.0, 0, -0.1419888585805893, 'round level 6')
#     (0.0, 0, 0.128541961312294, 'round level 5')
#     (-0.0, 0, -0.2505762279033661, 'round level 4')
#     (-0.0, 0, -0.13708339631557465, 'round level 3')
#     (-0.0, 0, -0.15736539661884308, 'round level 1')
