# %% [markdown]
# # 実験1 とりあえず走らせてみて観察

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 50万x2=100万
# - 5万iteration毎に敵のvalue_functionを最新(agentと同じ重み)に更新しながらself-play
# - 計算時間 : 17030s + 20700s => 4.7h + 5.7h

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# ### 0~50万

# %% [markdown]
# <img src="./resource/1round_montecarlo_first_run_1217_00_57_57/initial_value_transition.png" width=500/>

# %% [markdown]
# ### 50万~100万

# %% [markdown]
# <img src="./resource/1round_montecarlo_after_500000_training_1217_23_07_13/initial_value_transition.png" width=500/>

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# ### 0~50万

# %% [markdown]
# <img src="./resource/1round_montecarlo_first_run_1217_00_57_57/1_round_3000_match_subplot_1219_12_18_03.png"/>

# %% [markdown]
# <img src="./resource/1round_montecarlo_first_run_1217_00_57_57/1_round_3000_match_subplot_1219_12_23_14.png"/>

# %% [markdown]
# ### 50万~100万

# %% [markdown]
# <img src="./resource/1round_montecarlo_after_500000_training_1217_23_07_13/1_round_3000_match_subplot_1219_12_20_58.png" />

# %% [markdown]
# <img src="./resource/1round_montecarlo_after_500000_training_1217_23_07_13/1_round_3000_match_subplot_1219_12_33_07.png" />

# %% [markdown]
# ### 0~100万

# %% [markdown]
# <img src="./resource/1round_montecarlo_1217_summary/1_round_3000_match_subplot_1219_13_11_22.png" />

# %% [markdown]
# <img src="./resource/1round_montecarlo_1217_summary/1_round_3000_match_subplot_1219_13_12_15.png" />

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# ### 50万iteration後のvalue function10人で対戦
# big blindの次で必ずallin.他のplayerはそれに対して必ずfoldで決着.

# %% [markdown]
# ### ALLIN する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['CT', 'D2']
# -- round state --
#   - dealer btn : cpu6
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 1 : cpu3 (uuid-3) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 4 : cpu5 (uuid-5) => state : participating, stack : 10000
#     - 5 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 6 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 7 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 8 : cpu7 (uuid-7) => state : participating, stack : 10000
#     - 9 : cpu9 (uuid-9) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', -0.06095900014042854), ('call', -0.8745517730712891), ('min_raise', 0.5638440251350403), ('double_raise', 0.002785854507237673), ('triple_raise', -0.41446131467819214), ('max_raise', 0.7613644003868103)]
# ** weights and features in detail **
# bias : [ 0.05021409 -0.07007032  0.          0.          0.          0.        ]
#
# linear combination for fold :
#     (0.2593560218811035, 1, 0.2593560218811035, 'round level 2')
#     (-0.18217360973358154, 1, -0.18217360973358154, 'player-3:state-active')
#     (0.17122866710027057, 0.6666666666666666, 0.2568430006504059, 'player-9:history')
#     (-0.16950692236423492, 1, -0.16950692236423492, 'player-0:state-active')
#     (-0.15831279754638672, 1, -0.15831279754638672, 'player-5:state-active')
#     (-0.10564642399549484, 1, -0.10564642399549484, 'player-2:state-active')
#     (0.08540087938308716, 1, 0.08540087938308716, 'player-4:state-active')
#     (-0.07444114983081818, 1, -0.07444114983081818, 'player-6:state-active')
#     (0.06565069407224655, 1, 0.06565069407224655, 'street-preflop')
#     (0.06462918221950531, 1, 0.06462918221950531, 'player-7:state-active')
#     (0.06049284338951111, 0.3333333333333333, 0.18147853016853333, 'player-8:history')
#     (-0.05335110425949097, 1, -0.05335110425949097, 'player-1:state-active')
#     (0.050214093, 0, 0, 'bias')
#     (-0.04882608726620674, 1, -0.04882608726620674, 'player-9:state-active')
#     (0.03734046220779419, 1, 0.03734046220779419, 'player-8:state-active')
#     (-0.02996821515262127, 1, -0.02996821515262127, 'btn distance=3')
#     (0.024843131005764008, 0.1, 0.24843131005764008, 'player-7:stack')
#     (-0.01920406371355057, 0.1, -0.19204063713550568, 'player-5:stack')
#     (-0.018669122457504274, 0.1, -0.18669122457504272, 'player-3:stack')
#     (-0.014060595631599428, 0.1, -0.14060595631599426, 'player-6:stack')
#     (0.010947541147470475, 0.1, 0.10947541147470474, 'player-0:stack')
#     (-0.010750764083117247, 0.0995, -0.10804788023233414, 'player-9:stack')
#     (-0.005204113200306892, 0.1, -0.052041132003068924, 'player-1:stack')
#     (-0.0032040614634752276, 0.1, -0.032040614634752274, 'player-2:stack')
#     (0.0028930313885211947, 0.1, 0.028930313885211945, 'player-4:stack')
#     (-0.0004986377663444728, 0.09975, -0.0049988748505711555, 'player-8:stack')
#     (-0.00013784689083695413, 0.00075, -0.18379585444927216, 'pot')
#     (-9.239738634647664e-09, 0.578, -1.5985706980359282e-08, 'cards')
#     (-0.0, 0, -7.162844849517569e-05, 'player-9:state-fold')
#     (0.0, 0, 0.0851890966296196, 'player-8:state-fold')
#     (0.0, 0.0, 0.04918234422802925, 'player-7:history')
#     (0.0, 0, 0.2520604729652405, 'player-7:state-fold')
#     (-0.0, 0.0, -0.13236480951309204, 'player-6:history')
#     (0.0, 0, 0.12269149720668793, 'player-6:state-fold')
#     (0.0, 0.0, 0.027349501848220825, 'player-5:history')
#     (0.0, 0, 0.18234078586101532, 'player-5:state-fold')
#     (-0.0, 0.0, -0.04018624871969223, 'player-4:history')
#     (-0.0, 0, -0.03126266226172447, 'player-4:state-fold')
#     (-0.0, 0.0, -0.11032020300626755, 'player-3:history')
#     (-0.0, 0, -0.23660315573215485, 'player-3:state-fold')
#     (-0.0, 0.0, -0.2168671041727066, 'player-2:history')
#     (-0.0, 0, -0.023304414004087448, 'player-2:state-fold')
#     (-0.0, 0.0, -0.09811871498823166, 'player-1:history')
#     (-0.0, 0, -0.13428644835948944, 'player-1:state-fold')
#     (0.0, 0.0, 0.15051233768463135, 'player-0:history')
#     (0.0, 0, 0.1941356360912323, 'player-0:state-fold')
#     (0.0, 0, 0.11871553212404251, 'street-river')
#     (-0.0, 0, -0.1110917180776596, 'street-turn')
#     (-0.0, 0, -0.04047925025224686, 'street-flop')
#     (-0.0, 0, -0.018506085500121117, 'btn distance=9')
#     (0.0, 0, 0.19392263889312744, 'btn distance=8')
#     (0.0, 0, 0.25639697909355164, 'btn distance=7')
#     (0.0, 0, 0.26104164123535156, 'btn distance=6')
#     (-0.0, 0, -0.08797938376665115, 'btn distance=5')
#     (-0.0, 0, -0.11347238719463348, 'btn distance=4')
#     (0.0, 0, 0.1622413545846939, 'btn distance=2')
#     (-0.0, 0, -0.07458839565515518, 'btn distance=1')
#     (-0.0, 0, -0.21464864909648895, 'btn distance=0')
#     (-0.0, 0, -0.157193124294281, 'round level 27')
#     (-0.0, 0, -0.022340422496199608, 'round level 26')
#     (0.0, 0, 0.0732913464307785, 'round level 25')
#     (-0.0, 0, -0.20247098803520203, 'round level 24')
#     (-0.0, 0, -0.017685072496533394, 'round level 23')
#     (-0.0, 0, -0.21231283247470856, 'round level 22')
#     (0.0, 0, 0.09466390311717987, 'round level 21')
#     (-0.0, 0, -0.1319267451763153, 'round level 20')
#     (-0.0, 0, -0.19355502724647522, 'round level 19')
#     (0.0, 0, 0.1310054361820221, 'round level 18')
#     (-0.0, 0, -0.25354498624801636, 'round level 17')
#     (-0.0, 0, -0.11440449953079224, 'round level 16')
#     (-0.0, 0, -0.02884536236524582, 'round level 15')
#     (-0.0, 0, -0.09855259209871292, 'round level 14')
#     (0.0, 0, 0.14381340146064758, 'round level 13')
#     (0.0, 0, 0.09439601004123688, 'round level 12')
#     (-0.0, 0, -0.15986812114715576, 'round level 11')
#     (-0.0, 0, -0.1445908546447754, 'round level 10')
#     (0.0, 0, 0.054770808666944504, 'round level 9')
#     (0.0, 0, 0.17681853473186493, 'round level 8')
#     (0.0, 0, 0.2500433325767517, 'round level 7')
#     (0.0, 0, 0.010542628355324268, 'round level 6')
#     (-0.0, 0, -0.14735162258148193, 'round level 5')
#     (0.0, 0, 0.09386766701936722, 'round level 4')
#     (-0.0, 0, -0.021699830889701843, 'round level 3')
#     (0.0, 0, 0.20931224524974823, 'round level 1')
#
# linear combination for call :
#     (0.987714763879776, 0.578, 1.7088490724563599, 'cards')
#     (-0.3368537724018097, 1, -0.3368537724018097, 'player-8:state-active')
#     (-0.3212963938713074, 1, -0.3212963938713074, 'player-5:state-active')
#     (-0.3197002112865448, 1, -0.3197002112865448, 'player-1:state-active')
#     (-0.2666216790676117, 1, -0.2666216790676117, 'player-9:state-active')
#     (-0.21882309516270954, 0.6666666666666666, -0.32823464274406433, 'player-9:history')
#     (-0.1982337236404419, 1, -0.1982337236404419, 'round level 2')
#     (-0.17861095070838928, 1, -0.17861095070838928, 'player-3:state-active')
#     (0.12856797873973846, 1, 0.12856797873973846, 'btn distance=3')
#     (0.10939254611730576, 1, 0.10939254611730576, 'player-6:state-active')
#     (-0.08371289819478989, 1, -0.08371289819478989, 'player-7:state-active')
#     (-0.070070319, 0, 0, 'bias')
#     (0.038519132882356644, 1, 0.038519132882356644, 'player-4:state-active')
#     (-0.0277217298746109, 0.1, -0.277217298746109, 'player-1:stack')
#     (-0.027078548073768617, 0.1, -0.27078548073768616, 'player-6:stack')
#     (0.02629021182656288, 1, 0.02629021182656288, 'player-2:state-active')
#     (-0.025514967739582062, 0.3333333333333333, -0.07654490321874619, 'player-8:history')
#     (-0.022854586344212294, 0.09975, -0.22911866009235382, 'player-8:stack')
#     (-0.020092482864856723, 0.1, -0.2009248286485672, 'player-5:stack')
#     (-0.015462919063866138, 0.0995, -0.15540622174739838, 'player-9:stack')
#     (-0.012172213941812516, 0.1, -0.12172213941812515, 'player-2:stack')
#     (-0.011084485054016114, 0.1, -0.11084485054016113, 'player-0:stack')
#     (-0.007960747182369233, 0.1, -0.07960747182369232, 'player-3:stack')
#     (0.00761592760682106, 1, 0.00761592760682106, 'player-0:state-active')
#     (-0.005347672384232283, 1, -0.005347672384232283, 'street-preflop')
#     (-0.00253579318523407, 0.1, -0.025357931852340698, 'player-4:stack')
#     (-0.0008409954607486725, 0.1, -0.008409954607486725, 'player-7:stack')
#     (-6.219266541302204e-05, 0.00075, -0.08292355388402939, 'pot')
#     (-0.0, 0, -0.27076178789138794, 'player-9:state-fold')
#     (-0.0, 0, -0.0028167935088276863, 'player-8:state-fold')
#     (-0.0, 0.0, -0.1829005628824234, 'player-7:history')
#     (-0.0, 0, -0.06349091976881027, 'player-7:state-fold')
#     (-0.0, 0.0, -0.07865343987941742, 'player-6:history')
#     (-0.0, 0, -0.21911293268203735, 'player-6:state-fold')
#     (-0.0, 0.0, -0.022896258160471916, 'player-5:history')
#     (-0.0, 0, -0.003028217004612088, 'player-5:state-fold')
#     (0.0, 0.0, 0.09201591461896896, 'player-4:history')
#     (-0.0, 0, -0.12634769082069397, 'player-4:state-fold')
#     (-0.0, 0.0, -0.05259004980325699, 'player-3:history')
#     (-0.0, 0, -0.20077961683273315, 'player-3:state-fold')
#     (-0.0, 0.0, -0.04389026761054993, 'player-2:history')
#     (-0.0, 0, -0.1257881075143814, 'player-2:state-fold')
#     (0.0, 0.0, 0.13273072242736816, 'player-1:history')
#     (0.0, 0, 0.04784411936998367, 'player-1:state-fold')
#     (-0.0, 0.0, -0.1697363406419754, 'player-0:history')
#     (0.0, 0, 0.04256691783666611, 'player-0:state-fold')
#     (0.0, 0, 0.0020736893638968468, 'street-river')
#     (0.0, 0, 0.1725275069475174, 'street-turn')
#     (0.0, 0, 0.1546308994293213, 'street-flop')
#     (0.0, 0, 0.12520329654216766, 'btn distance=9')
#     (0.0, 0, 0.023359322920441628, 'btn distance=8')
#     (0.0, 0, 0.028022725135087967, 'btn distance=7')
#     (0.0, 0, 0.081553615629673, 'btn distance=6')
#     (-0.0, 0, -0.22745220363140106, 'btn distance=5')
#     (0.0, 0, 0.13111388683319092, 'btn distance=4')
#     (-0.0, 0, -0.18685166537761688, 'btn distance=2')
#     (-0.0, 0, -0.15054799616336823, 'btn distance=1')
#     (0.0, 0, 0.19323912262916565, 'btn distance=0')
#     (-0.0, 0, -0.243196040391922, 'round level 27')
#     (-0.0, 0, -0.023156270384788513, 'round level 26')
#     (0.0, 0, 0.003470483236014843, 'round level 25')
#     (0.0, 0, 0.15401211380958557, 'round level 24')
#     (0.0, 0, 0.21780440211296082, 'round level 23')
#     (-0.0, 0, -0.22260673344135284, 'round level 22')
#     (0.0, 0, 0.05764830857515335, 'round level 21')
#     (0.0, 0, 0.2020353376865387, 'round level 20')
#     (-0.0, 0, -0.2548794448375702, 'round level 19')
#     (-0.0, 0, -0.1148628517985344, 'round level 18')
#     (0.0, 0, 0.07593721896409988, 'round level 17')
#     (0.0, 0, 0.24762311577796936, 'round level 16')
#     (-0.0, 0, -0.05122379958629608, 'round level 15')
#     (-0.0, 0, -0.004059555009007454, 'round level 14')
#     (0.0, 0, 0.16804750263690948, 'round level 13')
#     (-0.0, 0, -0.224433034658432, 'round level 12')
#     (-0.0, 0, -0.19422996044158936, 'round level 11')
#     (-0.0, 0, -0.08357469737529755, 'round level 10')
#     (0.0, 0, 0.2517589330673218, 'round level 9')
#     (0.0, 0, 0.0839981883764267, 'round level 8')
#     (0.0, 0, 0.08711250126361847, 'round level 7')
#     (0.0, 0, 0.23109890520572662, 'round level 6')
#     (-0.0, 0, -0.07619556784629822, 'round level 5')
#     (0.0, 0, 0.10016213357448578, 'round level 4')
#     (-0.0, 0, -0.2349204421043396, 'round level 3')
#     (-0.0, 0, -0.007748506497591734, 'round level 1')
#
# linear combination for min_raise :
#     (0.20849823951721191, 1, 0.20849823951721191, 'player-4:state-active')
#     (-0.18592405319213867, 1, -0.18592405319213867, 'player-9:state-active')
#     (0.1589733064174652, 1, 0.1589733064174652, 'player-8:state-active')
#     (0.15025772154331207, 1, 0.15025772154331207, 'round level 2')
#     (0.14384786784648895, 1, 0.14384786784648895, 'player-1:state-active')
#     (0.13899749517440796, 1, 0.13899749517440796, 'player-2:state-active')
#     (-0.13198605179786682, 1, -0.13198605179786682, 'player-5:state-active')
#     (0.1024339497089386, 1, 0.1024339497089386, 'player-0:state-active')
#     (-0.08589034527540207, 1, -0.08589034527540207, 'street-preflop')
#     (0.07346060872077942, 1, 0.07346060872077942, 'player-3:state-active')
#     (-0.06415576487779617, 1, -0.06415576487779617, 'player-6:state-active')
#     (-0.06316948682069778, 1, -0.06316948682069778, 'btn distance=3')
#     (0.055896177887916565, 0.3333333333333333, 0.1676885336637497, 'player-8:history')
#     (0.028040999546647072, 1, 0.028040999546647072, 'player-7:state-active')
#     (0.025915625691413882, 0.1, 0.2591562569141388, 'player-3:stack')
#     (-0.024658223513513804, 0.09975, -0.24720023572444916, 'player-8:stack')
#     (-0.021758350729942325, 0.1, -0.21758350729942322, 'player-2:stack')
#     (0.021592644587159156, 0.578, 0.03735751658678055, 'cards')
#     (0.02005092054605484, 0.6666666666666666, 0.03007638081908226, 'player-9:history')
#     (0.017303086817264557, 0.1, 0.17303086817264557, 'player-6:stack')
#     (0.01478569656610489, 0.1, 0.1478569656610489, 'player-4:stack')
#     (-0.012943124771118164, 0.1, -0.12943124771118164, 'player-5:stack')
#     (-0.004929295927286148, 0.1, -0.04929295927286148, 'player-1:stack')
#     (0.0017137076416984202, 0.0995, 0.017223192378878593, 'player-9:stack')
#     (-0.0013368891552090645, 0.1, -0.013368891552090645, 'player-0:stack')
#     (-0.0012864792719483376, 0.1, -0.012864792719483376, 'player-7:stack')
#     (0.00011405199766159058, 0.00075, 0.1520693302154541, 'pot')
#     (0.0, 0, 0, 'bias')
#     (0.0, 0, 0.18296323716640472, 'player-9:state-fold')
#     (0.0, 0, 0.10726218670606613, 'player-8:state-fold')
#     (-0.0, 0.0, -0.20136457681655884, 'player-7:history')
#     (-0.0, 0, -0.22921545803546906, 'player-7:state-fold')
#     (0.0, 0.0, 0.08433707803487778, 'player-6:history')
#     (0.0, 0, 0.14500127732753754, 'player-6:state-fold')
#     (0.0, 0.0, 0.12295147031545639, 'player-5:history')
#     (-0.0, 0, -0.047310616821050644, 'player-5:state-fold')
#     (0.0, 0.0, 0.19297930598258972, 'player-4:history')
#     (0.0, 0, 0.07710491865873337, 'player-4:state-fold')
#     (0.0, 0.0, 0.19381718337535858, 'player-3:history')
#     (-0.0, 0, -0.18229132890701294, 'player-3:state-fold')
#     (0.0, 0.0, 0.1123739555478096, 'player-2:history')
#     (0.0, 0, 0.17827273905277252, 'player-2:state-fold')
#     (-0.0, 0.0, -0.21221531927585602, 'player-1:history')
#     (0.0, 0, 0.01488448679447174, 'player-1:state-fold')
#     (0.0, 0.0, 0.07965674251317978, 'player-0:history')
#     (0.0, 0, 0.11470087617635727, 'player-0:state-fold')
#     (0.0, 0, 0.22769775986671448, 'street-river')
#     (0.0, 0, 0.019793173298239708, 'street-turn')
#     (-0.0, 0, -0.08614850044250488, 'street-flop')
#     (0.0, 0, 0.12430199980735779, 'btn distance=9')
#     (0.0, 0, 0.18569010496139526, 'btn distance=8')
#     (-0.0, 0, -0.2330344021320343, 'btn distance=7')
#     (-0.0, 0, -0.24160028994083405, 'btn distance=6')
#     (0.0, 0, 0.04411689564585686, 'btn distance=5')
#     (-0.0, 0, -0.07802970707416534, 'btn distance=4')
#     (0.0, 0, 0.06924721598625183, 'btn distance=2')
#     (0.0, 0, 0.24695640802383423, 'btn distance=1')
#     (-0.0, 0, -0.09765464812517166, 'btn distance=0')
#     (-0.0, 0, -0.07168193906545639, 'round level 27')
#     (0.0, 0, 0.0020102381240576506, 'round level 26')
#     (-0.0, 0, -0.05149857699871063, 'round level 25')
#     (0.0, 0, 0.25409719347953796, 'round level 24')
#     (-0.0, 0, -0.00434030219912529, 'round level 23')
#     (0.0, 0, 0.08832600712776184, 'round level 22')
#     (-0.0, 0, -0.1749695986509323, 'round level 21')
#     (0.0, 0, 0.09540113806724548, 'round level 20')
#     (-0.0, 0, -0.24687255918979645, 'round level 19')
#     (0.0, 0, 0.1442979872226715, 'round level 18')
#     (0.0, 0, 0.18567436933517456, 'round level 17')
#     (-0.0, 0, -0.11047004908323288, 'round level 16')
#     (0.0, 0, 0.24146737158298492, 'round level 15')
#     (-0.0, 0, -0.014989090152084827, 'round level 14')
#     (-0.0, 0, -0.1395028531551361, 'round level 13')
#     (0.0, 0, 0.06579896807670593, 'round level 12')
#     (-0.0, 0, -0.2015688121318817, 'round level 11')
#     (-0.0, 0, -0.02576248161494732, 'round level 10')
#     (0.0, 0, 0.15448996424674988, 'round level 9')
#     (-0.0, 0, -0.013245650567114353, 'round level 8')
#     (0.0, 0, 0.09939922392368317, 'round level 7')
#     (0.0, 0, 0.16422493755817413, 'round level 6')
#     (-0.0, 0, -0.08207165449857712, 'round level 5')
#     (-0.0, 0, -0.2075251340866089, 'round level 4')
#     (-0.0, 0, -0.2374327927827835, 'round level 3')
#     (0.0, 0, 0.1168898493051529, 'round level 1')
#
# linear combination for double_raise :
#     (-0.25238075852394104, 1, -0.25238075852394104, 'btn distance=3')
#     (0.2504120469093323, 1, 0.2504120469093323, 'player-4:state-active')
#     (-0.23892885446548462, 1, -0.23892885446548462, 'player-2:state-active')
#     (0.22203806042671204, 1, 0.22203806042671204, 'player-7:state-active')
#     (0.19552835822105408, 1, 0.19552835822105408, 'player-0:state-active')
#     (-0.19116884469985962, 1, -0.19116884469985962, 'player-9:state-active')
#     (0.1883895844221115, 1, 0.1883895844221115, 'player-1:state-active')
#     (-0.15767088532447815, 0.6666666666666666, -0.23650632798671722, 'player-9:history')
#     (-0.1149071604013443, 1, -0.1149071604013443, 'player-3:state-active')
#     (0.10941916421055793, 0.578, 0.18930651247501373, 'cards')
#     (-0.10108418762683868, 1, -0.10108418762683868, 'round level 2')
#     (0.09949827194213867, 1, 0.09949827194213867, 'player-5:state-active')
#     (-0.06473118563493092, 0.3333333333333333, -0.19419355690479279, 'player-8:history')
#     (0.06192198023200035, 1, 0.06192198023200035, 'player-8:state-active')
#     (0.049831047654151917, 1, 0.049831047654151917, 'street-preflop')
#     (-0.04342479258775711, 1, -0.04342479258775711, 'player-6:state-active')
#     (-0.024801722656935456, 0.09975, -0.2486388236284256, 'player-8:stack')
#     (0.018260061740875244, 0.1, 0.18260061740875244, 'player-6:stack')
#     (-0.01680694967508316, 0.1, -0.1680694967508316, 'player-1:stack')
#     (0.014583063125610352, 0.1, 0.14583063125610352, 'player-2:stack')
#     (0.011933237314224243, 0.1, 0.11933237314224243, 'player-3:stack')
#     (0.010158253461122514, 0.1, 0.10158253461122513, 'player-0:stack')
#     (-0.009252853777259588, 0.0995, -0.09299350529909134, 'player-9:stack')
#     (-0.0065494880080223085, 0.1, -0.06549488008022308, 'player-4:stack')
#     (-0.005681443586945534, 0.1, -0.05681443586945534, 'player-5:stack')
#     (-0.0018397508189082147, 0.1, -0.018397508189082146, 'player-7:stack')
#     (4.1626866906881334e-05, 0.00075, 0.05550248920917511, 'pot')
#     (0.0, 0, 0, 'bias')
#     (0.0, 0, 0.04853530600667, 'player-9:state-fold')
#     (0.0, 0, 0.031480174511671066, 'player-8:state-fold')
#     (0.0, 0.0, 0.04559958353638649, 'player-7:history')
#     (0.0, 0, 0.2451270967721939, 'player-7:state-fold')
#     (0.0, 0.0, 0.18599508702754974, 'player-6:history')
#     (0.0, 0, 0.21151751279830933, 'player-6:state-fold')
#     (-0.0, 0.0, -0.07166066765785217, 'player-5:history')
#     (-0.0, 0, -0.08182913064956665, 'player-5:state-fold')
#     (0.0, 0.0, 0.09959843009710312, 'player-4:history')
#     (-0.0, 0, -0.0668734461069107, 'player-4:state-fold')
#     (0.0, 0.0, 0.10553708672523499, 'player-3:history')
#     (-0.0, 0, -0.00968413706868887, 'player-3:state-fold')
#     (0.0, 0.0, 0.06693552434444427, 'player-2:history')
#     (-0.0, 0, -0.05680442973971367, 'player-2:state-fold')
#     (0.0, 0.0, 0.008215732872486115, 'player-1:history')
#     (0.0, 0, 0.036690764129161835, 'player-1:state-fold')
#     (0.0, 0.0, 0.07938522100448608, 'player-0:history')
#     (-0.0, 0, -0.048810120671987534, 'player-0:state-fold')
#     (0.0, 0, 0.14103002846240997, 'street-river')
#     (-0.0, 0, -0.02233775705099106, 'street-turn')
#     (-0.0, 0, -0.01179889403283596, 'street-flop')
#     (0.0, 0, 0.1674492508172989, 'btn distance=9')
#     (0.0, 0, 0.08124087750911713, 'btn distance=8')
#     (-0.0, 0, -0.14939723908901215, 'btn distance=7')
#     (-0.0, 0, -0.15247425436973572, 'btn distance=6')
#     (0.0, 0, 0.20726671814918518, 'btn distance=5')
#     (-0.0, 0, -0.10643009841442108, 'btn distance=4')
#     (0.0, 0, 0.05170707032084465, 'btn distance=2')
#     (0.0, 0, 0.11139650642871857, 'btn distance=1')
#     (0.0, 0, 0.0504719503223896, 'btn distance=0')
#     (-0.0, 0, -0.22878989577293396, 'round level 27')
#     (-0.0, 0, -0.09713347256183624, 'round level 26')
#     (0.0, 0, 0.0183255672454834, 'round level 25')
#     (-0.0, 0, -0.02316262759268284, 'round level 24')
#     (0.0, 0, 0.14512333273887634, 'round level 23')
#     (0.0, 0, 0.14382004737854004, 'round level 22')
#     (0.0, 0, 0.05084460973739624, 'round level 21')
#     (-0.0, 0, -0.22428904473781586, 'round level 20')
#     (0.0, 0, 0.11020268499851227, 'round level 19')
#     (0.0, 0, 0.17648957669734955, 'round level 18')
#     (0.0, 0, 0.24417027831077576, 'round level 17')
#     (-0.0, 0, -0.19540438055992126, 'round level 16')
#     (-0.0, 0, -0.12288767844438553, 'round level 15')
#     (0.0, 0, 0.2205205112695694, 'round level 14')
#     (-0.0, 0, -0.012383097782731056, 'round level 13')
#     (-0.0, 0, -0.13942918181419373, 'round level 12')
#     (0.0, 0, 0.03898955136537552, 'round level 11')
#     (0.0, 0, 0.18798846006393433, 'round level 10')
#     (0.0, 0, 0.07701212912797928, 'round level 9')
#     (-0.0, 0, -0.04181545972824097, 'round level 8')
#     (0.0, 0, 0.14689508080482483, 'round level 7')
#     (-0.0, 0, -0.22795704007148743, 'round level 6')
#     (-0.0, 0, -0.1961844116449356, 'round level 5')
#     (0.0, 0, 0.17895659804344177, 'round level 4')
#     (-0.0, 0, -0.25631412863731384, 'round level 3')
#     (0.0, 0, 0.24536371231079102, 'round level 1')
#
# linear combination for triple_raise :
#     (0.24694661796092987, 1, 0.24694661796092987, 'player-7:state-active')
#     (-0.1813841164112091, 1, -0.1813841164112091, 'player-4:state-active')
#     (-0.1704285442829132, 1, -0.1704285442829132, 'player-2:state-active')
#     (-0.14387516677379608, 1, -0.14387516677379608, 'player-5:state-active')
#     (-0.13792431354522705, 1, -0.13792431354522705, 'btn distance=3')
#     (-0.13786941766738892, 1, -0.13786941766738892, 'player-1:state-active')
#     (0.10676056146621704, 1, 0.10676056146621704, 'street-preflop')
#     (-0.10657975822687149, 1, -0.10657975822687149, 'player-0:state-active')
#     (0.08353433012962341, 1, 0.08353433012962341, 'round level 2')
#     (-0.07543616741895676, 1, -0.07543616741895676, 'player-3:state-active')
#     (0.060930077582597726, 0.578, 0.10541535913944244, 'cards')
#     (-0.048610419034957886, 0.6666666666666666, -0.07291562855243683, 'player-9:history')
#     (0.04814155027270317, 1, 0.04814155027270317, 'player-9:state-active')
#     (0.024430599063634872, 1, 0.024430599063634872, 'player-8:state-active')
#     (-0.021866764128208163, 0.1, -0.2186676412820816, 'player-2:stack')
#     (0.02185601592063904, 0.1, 0.21856015920639038, 'player-6:stack')
#     (0.01669674813747406, 0.1, 0.1669674813747406, 'player-4:stack')
#     (0.016079960390925407, 1, 0.016079960390925407, 'player-6:state-active')
#     (-0.014583208908637364, 0.3333333333333333, -0.043749626725912094, 'player-8:history')
#     (0.013153241895139218, 0.09975, 0.131862074136734, 'player-8:stack')
#     (-0.009703592956066133, 0.1, -0.09703592956066132, 'player-1:stack')
#     (-0.00760205164551735, 0.1, -0.07602051645517349, 'player-7:stack')
#     (-0.0075607202947139745, 0.1, -0.07560720294713974, 'player-0:stack')
#     (0.005143529476597905, 0.0995, 0.051693763583898544, 'player-9:stack')
#     (0.004650874435901642, 0.1, 0.04650874435901642, 'player-5:stack')
#     (0.0007889139465987683, 0.1, 0.007889139465987682, 'player-3:stack')
#     (-0.00015010637417435646, 0.00075, -0.20014183223247528, 'pot')
#     (0.0, 0, 0, 'bias')
#     (-0.0, 0, -0.0027812873013317585, 'player-9:state-fold')
#     (-0.0, 0, -0.09964339435100555, 'player-8:state-fold')
#     (0.0, 0.0, 0.006627007387578487, 'player-7:history')
#     (0.0, 0, 0.029756052419543266, 'player-7:state-fold')
#     (-0.0, 0.0, -0.0868103951215744, 'player-6:history')
#     (0.0, 0, 0.03582059592008591, 'player-6:state-fold')
#     (0.0, 0.0, 0.14977802336215973, 'player-5:history')
#     (0.0, 0, 0.05285193771123886, 'player-5:state-fold')
#     (0.0, 0.0, 0.08622831851243973, 'player-4:history')
#     (-0.0, 0, -0.03153127431869507, 'player-4:state-fold')
#     (0.0, 0.0, 0.03464150056242943, 'player-3:history')
#     (0.0, 0, 0.031059280037879944, 'player-3:state-fold')
#     (-0.0, 0.0, -0.17729148268699646, 'player-2:history')
#     (-0.0, 0, -0.23033276200294495, 'player-2:state-fold')
#     (-0.0, 0.0, -0.16155922412872314, 'player-1:history')
#     (-0.0, 0, -0.036232080310583115, 'player-1:state-fold')
#     (-0.0, 0.0, -0.17815719544887543, 'player-0:history')
#     (-0.0, 0, -0.13336129486560822, 'player-0:state-fold')
#     (-0.0, 0, -0.213123619556427, 'street-river')
#     (0.0, 0, 0.20355470478534698, 'street-turn')
#     (-0.0, 0, -0.08059458434581757, 'street-flop')
#     (-0.0, 0, -0.09507381170988083, 'btn distance=9')
#     (-0.0, 0, -0.2554704248905182, 'btn distance=8')
#     (-0.0, 0, -0.1417112499475479, 'btn distance=7')
#     (0.0, 0, 0.0655583068728447, 'btn distance=6')
#     (-0.0, 0, -0.10293184220790863, 'btn distance=5')
#     (0.0, 0, 0.23919938504695892, 'btn distance=4')
#     (0.0, 0, 0.10632307082414627, 'btn distance=2')
#     (0.0, 0, 0.11176927387714386, 'btn distance=1')
#     (-0.0, 0, -0.17196720838546753, 'btn distance=0')
#     (-0.0, 0, -0.11413256824016571, 'round level 27')
#     (0.0, 0, 0.031105956062674522, 'round level 26')
#     (0.0, 0, 0.23647229373455048, 'round level 25')
#     (0.0, 0, 0.10683319717645645, 'round level 24')
#     (-0.0, 0, -0.20570926368236542, 'round level 23')
#     (0.0, 0, 0.06475907564163208, 'round level 22')
#     (0.0, 0, 0.23939149081707, 'round level 21')
#     (-0.0, 0, -0.17680984735488892, 'round level 20')
#     (-0.0, 0, -0.04781121388077736, 'round level 19')
#     (0.0, 0, 0.06822703033685684, 'round level 18')
#     (0.0, 0, 0.23281681537628174, 'round level 17')
#     (-0.0, 0, -0.06258570402860641, 'round level 16')
#     (-0.0, 0, -0.062407203018665314, 'round level 15')
#     (-0.0, 0, -0.21637608110904694, 'round level 14')
#     (-0.0, 0, -0.24704204499721527, 'round level 13')
#     (0.0, 0, 0.06390265375375748, 'round level 12')
#     (-0.0, 0, -0.023371661081910133, 'round level 11')
#     (-0.0, 0, -0.10753955692052841, 'round level 10')
#     (-0.0, 0, -0.15809255838394165, 'round level 9')
#     (-0.0, 0, -0.20982156693935394, 'round level 8')
#     (-0.0, 0, -0.04409642517566681, 'round level 7')
#     (-0.0, 0, -0.12233775854110718, 'round level 6')
#     (0.0, 0, 0.12443231791257858, 'round level 5')
#     (-0.0, 0, -0.18804314732551575, 'round level 4')
#     (0.0, 0, 0.1655283123254776, 'round level 3')
#     (0.0, 0, 0.047176800668239594, 'round level 1')
#
# linear combination for max_raise :
#     (0.23114421963691711, 1, 0.23114421963691711, 'round level 2')
#     (-0.2247796654701233, 1, -0.2247796654701233, 'btn distance=3')
#     (0.20934996008872986, 1, 0.20934996008872986, 'player-1:state-active')
#     (0.1951204538345337, 1, 0.1951204538345337, 'player-5:state-active')
#     (0.17200875282287598, 1, 0.17200875282287598, 'street-preflop')
#     (0.1420652446746826, 0.578, 0.2457876205444336, 'cards')
#     (-0.1418961137533188, 1, -0.1418961137533188, 'player-8:state-active')
#     (0.13060857355594635, 1, 0.13060857355594635, 'player-9:state-active')
#     (-0.12555615603923798, 1, -0.12555615603923798, 'player-6:state-active')
#     (0.11714696139097214, 1, 0.11714696139097214, 'player-2:state-active')
#     (0.09808074434598286, 0.6666666666666666, 0.1471211165189743, 'player-9:history')
#     (0.06449420750141144, 1, 0.06449420750141144, 'player-0:state-active')
#     (-0.04089307536681493, 0.3333333333333333, -0.1226792261004448, 'player-8:history')
#     (-0.03879714012145996, 1, -0.03879714012145996, 'player-3:state-active')
#     (0.025830911472439766, 1, 0.025830911472439766, 'player-7:state-active')
#     (-0.023544734716415407, 0.1, -0.23544734716415405, 'player-1:stack')
#     (0.02064388394355774, 0.1, 0.2064388394355774, 'player-4:stack')
#     (-0.016720090806484223, 0.1, -0.16720090806484222, 'player-2:stack')
#     (-0.011749492585659028, 0.1, -0.11749492585659027, 'player-7:stack')
#     (-0.011552865382283927, 0.0995, -0.116109199821949, 'player-9:stack')
#     (-0.01003548800945282, 0.1, -0.1003548800945282, 'player-5:stack')
#     (-0.007861196994781494, 0.1, -0.07861196994781494, 'player-3:stack')
#     (-0.0073168776929378515, 0.1, -0.07316877692937851, 'player-6:stack')
#     (0.00675180833786726, 1, 0.00675180833786726, 'player-4:state-active')
#     (0.0060490967547521, 0.09975, 0.06064257398247719, 'player-8:stack')
#     (0.0026476880535483364, 0.1, 0.02647688053548336, 'player-0:stack')
#     (0.0001247873604297638, 0.00075, 0.16638314723968506, 'pot')
#     (0.0, 0, 0, 'bias')
#     (0.0, 0, 0.2593461275100708, 'player-9:state-fold')
#     (-0.0, 0, -0.21160270273685455, 'player-8:state-fold')
#     (-0.0, 0.0, -0.2054324895143509, 'player-7:history')
#     (0.0, 0, 0.22931134700775146, 'player-7:state-fold')
#     (-0.0, 0.0, -0.15349073708057404, 'player-6:history')
#     (0.0, 0, 0.2240581065416336, 'player-6:state-fold')
#     (-0.0, 0.0, -0.06440378725528717, 'player-5:history')
#     (-0.0, 0, -0.11622752994298935, 'player-5:state-fold')
#     (-0.0, 0.0, -0.18086472153663635, 'player-4:history')
#     (0.0, 0, 0.13435931503772736, 'player-4:state-fold')
#     (0.0, 0.0, 0.08639606833457947, 'player-3:history')
#     (0.0, 0, 0.11308294534683228, 'player-3:state-fold')
#     (-0.0, 0.0, -0.033438269048929214, 'player-2:history')
#     (-0.0, 0, -0.24040423333644867, 'player-2:state-fold')
#     (0.0, 0.0, 0.17977386713027954, 'player-1:history')
#     (0.0, 0, 0.13203458487987518, 'player-1:state-fold')
#     (-0.0, 0.0, -0.14835110306739807, 'player-0:history')
#     (0.0, 0, 0.08087477087974548, 'player-0:state-fold')
#     (-0.0, 0, -0.19033072888851166, 'street-river')
#     (-0.0, 0, -0.19670742750167847, 'street-turn')
#     (0.0, 0, 0.23690591752529144, 'street-flop')
#     (0.0, 0, 0.19500409066677094, 'btn distance=9')
#     (-0.0, 0, -0.159495010972023, 'btn distance=8')
#     (-0.0, 0, -0.07510904222726822, 'btn distance=7')
#     (-0.0, 0, -0.1130678579211235, 'btn distance=6')
#     (-0.0, 0, -0.01575898565351963, 'btn distance=5')
#     (-0.0, 0, -0.20628832280635834, 'btn distance=4')
#     (0.0, 0, 0.052926573902368546, 'btn distance=2')
#     (-0.0, 0, -0.030675364658236504, 'btn distance=1')
#     (-0.0, 0, -0.018590666353702545, 'btn distance=0')
#     (0.0, 0, 0.24902744591236115, 'round level 27')
#     (-0.0, 0, -0.13526393473148346, 'round level 26')
#     (0.0, 0, 0.23494407534599304, 'round level 25')
#     (-0.0, 0, -0.07349041104316711, 'round level 24')
#     (0.0, 0, 0.2440856546163559, 'round level 23')
#     (0.0, 0, 0.18772095441818237, 'round level 22')
#     (-0.0, 0, -0.16728129982948303, 'round level 21')
#     (-0.0, 0, -0.04031484201550484, 'round level 20')
#     (0.0, 0, 0.23258255422115326, 'round level 19')
#     (0.0, 0, 0.11064807325601578, 'round level 18')
#     (0.0, 0, 0.07781971991062164, 'round level 17')
#     (-0.0, 0, -0.022468965500593185, 'round level 16')
#     (0.0, 0, 0.026893282309174538, 'round level 15')
#     (0.0, 0, 0.1576375514268875, 'round level 14')
#     (0.0, 0, 0.14820368587970734, 'round level 13')
#     (-0.0, 0, -0.08295246213674545, 'round level 12')
#     (-0.0, 0, -0.24188120663166046, 'round level 11')
#     (0.0, 0, 0.19233454763889313, 'round level 10')
#     (0.0, 0, 0.1286068707704544, 'round level 9')
#     (-0.0, 0, -0.11806211620569229, 'round level 8')
#     (-0.0, 0, -0.03643910214304924, 'round level 7')
#     (-0.0, 0, -0.13878880441188812, 'round level 6')
#     (0.0, 0, 0.1881687492132187, 'round level 5')
#     (0.0, 0, 0.25155341625213623, 'round level 4')
#     (0.0, 0, 0.07624056190252304, 'round level 3')
#     (0.0, 0, 0.13523666560649872, 'round level 1')

# %% [markdown]
# ### Fold する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['D2', 'S2']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-5']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.09999996423721313), ('call', -0.49570563435554504)]
# ** weights and features in detail **
# bias : [ 0.05021409 -0.07007032  0.          0.          0.          0.        ]
#
# linear combination for fold :
#     (0.26104164123535156, 1, 0.26104164123535156, 'btn distance=6')
#     (0.2593560218811035, 1, 0.2593560218811035, 'round level 2')
#     (-0.18217360973358154, 1, -0.18217360973358154, 'player-3:state-active')
#     (-0.16950692236423492, 1, -0.16950692236423492, 'player-0:state-active')
#     (-0.15831279754638672, 1, -0.15831279754638672, 'player-5:state-active')
#     (-0.10564642399549484, 1, -0.10564642399549484, 'player-2:state-active')
#     (0.08540087938308716, 1, 0.08540087938308716, 'player-4:state-active')
#     (0.0851890966296196, 1, 0.0851890966296196, 'player-8:state-fold')
#     (-0.07444114983081818, 1, -0.07444114983081818, 'player-6:state-active')
#     (0.06565069407224655, 1, 0.06565069407224655, 'street-preflop')
#     (0.06462918221950531, 1, 0.06462918221950531, 'player-7:state-active')
#     (-0.05335110425949097, 1, -0.05335110425949097, 'player-1:state-active')
#     (0.050214093, 0, 0, 'bias')
#     (0.04881622255883797, 0.9925558312655087, 0.04918234422802925, 'player-7:history')
#     (-0.01915605355426669, 0.09975, -0.19204063713550568, 'player-5:stack')
#     (-0.018669122457504274, 0.1, -0.18669122457504272, 'player-3:stack')
#     (-0.01851743233576417, 0.10075, -0.18379585444927216, 'pot')
#     (-0.013990292653441429, 0.0995, -0.14060595631599426, 'player-6:stack')
#     (0.010947541147470475, 0.1, 0.10947541147470474, 'player-0:stack')
#     (-0.010804788023233414, 0.1, -0.10804788023233414, 'player-9:stack')
#     (-0.005204113200306892, 0.1, -0.052041132003068924, 'player-1:stack')
#     (-0.0032040614634752276, 0.1, -0.032040614634752274, 'player-2:stack')
#     (0.0028930313885211947, 0.1, 0.028930313885211945, 'player-4:stack')
#     (-0.000656897317682839, 0.004962779156327543, -0.13236480951309204, 'player-6:history')
#     (-0.0004998874850571155, 0.1, -0.0049988748505711555, 'player-8:stack')
#     (-7.162844849517569e-05, 1, -7.162844849517569e-05, 'player-9:state-fold')
#     (6.786476885414597e-05, 0.0024813895781637717, 0.027349501848220825, 'player-5:history')
#     (-9.623395602176287e-09, 0.602, -1.5985706980359282e-08, 'cards')
#     (0.0, 0.0, 0.2568430006504059, 'player-9:history')
#     (-0.0, 0, -0.04882608726620674, 'player-9:state-active')
#     (0.0, 0.0, 0.18147853016853333, 'player-8:history')
#     (0.0, 0, 0.03734046220779419, 'player-8:state-active')
#     (0.0, 0, 0.2520604729652405, 'player-7:state-fold')
#     (0.0, 0.0, 0.24843131005764008, 'player-7:stack')
#     (0.0, 0, 0.12269149720668793, 'player-6:state-fold')
#     (0.0, 0, 0.18234078586101532, 'player-5:state-fold')
#     (-0.0, 0.0, -0.04018624871969223, 'player-4:history')
#     (-0.0, 0, -0.03126266226172447, 'player-4:state-fold')
#     (-0.0, 0.0, -0.11032020300626755, 'player-3:history')
#     (-0.0, 0, -0.23660315573215485, 'player-3:state-fold')
#     (-0.0, 0.0, -0.2168671041727066, 'player-2:history')
#     (-0.0, 0, -0.023304414004087448, 'player-2:state-fold')
#     (-0.0, 0.0, -0.09811871498823166, 'player-1:history')
#     (-0.0, 0, -0.13428644835948944, 'player-1:state-fold')
#     (0.0, 0.0, 0.15051233768463135, 'player-0:history')
#     (0.0, 0, 0.1941356360912323, 'player-0:state-fold')
#     (0.0, 0, 0.11871553212404251, 'street-river')
#     (-0.0, 0, -0.1110917180776596, 'street-turn')
#     (-0.0, 0, -0.04047925025224686, 'street-flop')
#     (-0.0, 0, -0.018506085500121117, 'btn distance=9')
#     (0.0, 0, 0.19392263889312744, 'btn distance=8')
#     (0.0, 0, 0.25639697909355164, 'btn distance=7')
#     (-0.0, 0, -0.08797938376665115, 'btn distance=5')
#     (-0.0, 0, -0.11347238719463348, 'btn distance=4')
#     (-0.0, 0, -0.02996821515262127, 'btn distance=3')
#     (0.0, 0, 0.1622413545846939, 'btn distance=2')
#     (-0.0, 0, -0.07458839565515518, 'btn distance=1')
#     (-0.0, 0, -0.21464864909648895, 'btn distance=0')
#     (-0.0, 0, -0.157193124294281, 'round level 27')
#     (-0.0, 0, -0.022340422496199608, 'round level 26')
#     (0.0, 0, 0.0732913464307785, 'round level 25')
#     (-0.0, 0, -0.20247098803520203, 'round level 24')
#     (-0.0, 0, -0.017685072496533394, 'round level 23')
#     (-0.0, 0, -0.21231283247470856, 'round level 22')
#     (0.0, 0, 0.09466390311717987, 'round level 21')
#     (-0.0, 0, -0.1319267451763153, 'round level 20')
#     (-0.0, 0, -0.19355502724647522, 'round level 19')
#     (0.0, 0, 0.1310054361820221, 'round level 18')
#     (-0.0, 0, -0.25354498624801636, 'round level 17')
#     (-0.0, 0, -0.11440449953079224, 'round level 16')
#     (-0.0, 0, -0.02884536236524582, 'round level 15')
#     (-0.0, 0, -0.09855259209871292, 'round level 14')
#     (0.0, 0, 0.14381340146064758, 'round level 13')
#     (0.0, 0, 0.09439601004123688, 'round level 12')
#     (-0.0, 0, -0.15986812114715576, 'round level 11')
#     (-0.0, 0, -0.1445908546447754, 'round level 10')
#     (0.0, 0, 0.054770808666944504, 'round level 9')
#     (0.0, 0, 0.17681853473186493, 'round level 8')
#     (0.0, 0, 0.2500433325767517, 'round level 7')
#     (0.0, 0, 0.010542628355324268, 'round level 6')
#     (-0.0, 0, -0.14735162258148193, 'round level 5')
#     (0.0, 0, 0.09386766701936722, 'round level 4')
#     (-0.0, 0, -0.021699830889701843, 'round level 3')
#     (0.0, 0, 0.20931224524974823, 'round level 1')
#
# linear combination for call :
#     (1.0287271416187287, 0.602, 1.7088490724563599, 'cards')
#     (-0.3212963938713074, 1, -0.3212963938713074, 'player-5:state-active')
#     (-0.3197002112865448, 1, -0.3197002112865448, 'player-1:state-active')
#     (-0.27076178789138794, 1, -0.27076178789138794, 'player-9:state-fold')
#     (-0.1982337236404419, 1, -0.1982337236404419, 'round level 2')
#     (-0.1815390202306932, 0.9925558312655087, -0.1829005628824234, 'player-7:history')
#     (-0.17861095070838928, 1, -0.17861095070838928, 'player-3:state-active')
#     (0.10939254611730576, 1, 0.10939254611730576, 'player-6:state-active')
#     (-0.08371289819478989, 1, -0.08371289819478989, 'player-7:state-active')
#     (0.081553615629673, 1, 0.081553615629673, 'btn distance=6')
#     (-0.070070319, 0, 0, 'bias')
#     (0.038519132882356644, 1, 0.038519132882356644, 'player-4:state-active')
#     (-0.0277217298746109, 0.1, -0.277217298746109, 'player-1:stack')
#     (-0.026943155333399773, 0.0995, -0.27078548073768616, 'player-6:stack')
#     (0.02629021182656288, 1, 0.02629021182656288, 'player-2:state-active')
#     (-0.022911866009235383, 0.1, -0.22911866009235382, 'player-8:stack')
#     (-0.02004225165769458, 0.09975, -0.2009248286485672, 'player-5:stack')
#     (-0.015540622174739838, 0.1, -0.15540622174739838, 'player-9:stack')
#     (-0.012172213941812516, 0.1, -0.12172213941812515, 'player-2:stack')
#     (-0.011084485054016114, 0.1, -0.11084485054016113, 'player-0:stack')
#     (-0.008354548053815962, 0.10075, -0.08292355388402939, 'pot')
#     (-0.007960747182369233, 0.1, -0.07960747182369232, 'player-3:stack')
#     (0.00761592760682106, 1, 0.00761592760682106, 'player-0:state-active')
#     (-0.005347672384232283, 1, -0.005347672384232283, 'street-preflop')
#     (-0.0028167935088276863, 1, -0.0028167935088276863, 'player-8:state-fold')
#     (-0.00253579318523407, 0.1, -0.025357931852340698, 'player-4:stack')
#     (-0.0003903396520070343, 0.004962779156327543, -0.07865343987941742, 'player-6:history')
#     (-5.681453637834222e-05, 0.0024813895781637717, -0.022896258160471916, 'player-5:history')
#     (-0.0, 0.0, -0.32823464274406433, 'player-9:history')
#     (-0.0, 0, -0.2666216790676117, 'player-9:state-active')
#     (-0.0, 0.0, -0.07654490321874619, 'player-8:history')
#     (-0.0, 0, -0.3368537724018097, 'player-8:state-active')
#     (-0.0, 0, -0.06349091976881027, 'player-7:state-fold')
#     (-0.0, 0.0, -0.008409954607486725, 'player-7:stack')
#     (-0.0, 0, -0.21911293268203735, 'player-6:state-fold')
#     (-0.0, 0, -0.003028217004612088, 'player-5:state-fold')
#     (0.0, 0.0, 0.09201591461896896, 'player-4:history')
#     (-0.0, 0, -0.12634769082069397, 'player-4:state-fold')
#     (-0.0, 0.0, -0.05259004980325699, 'player-3:history')
#     (-0.0, 0, -0.20077961683273315, 'player-3:state-fold')
#     (-0.0, 0.0, -0.04389026761054993, 'player-2:history')
#     (-0.0, 0, -0.1257881075143814, 'player-2:state-fold')
#     (0.0, 0.0, 0.13273072242736816, 'player-1:history')
#     (0.0, 0, 0.04784411936998367, 'player-1:state-fold')
#     (-0.0, 0.0, -0.1697363406419754, 'player-0:history')
#     (0.0, 0, 0.04256691783666611, 'player-0:state-fold')
#     (0.0, 0, 0.0020736893638968468, 'street-river')
#     (0.0, 0, 0.1725275069475174, 'street-turn')
#     (0.0, 0, 0.1546308994293213, 'street-flop')
#     (0.0, 0, 0.12520329654216766, 'btn distance=9')
#     (0.0, 0, 0.023359322920441628, 'btn distance=8')
#     (0.0, 0, 0.028022725135087967, 'btn distance=7')
#     (-0.0, 0, -0.22745220363140106, 'btn distance=5')
#     (0.0, 0, 0.13111388683319092, 'btn distance=4')
#     (0.0, 0, 0.12856797873973846, 'btn distance=3')
#     (-0.0, 0, -0.18685166537761688, 'btn distance=2')
#     (-0.0, 0, -0.15054799616336823, 'btn distance=1')
#     (0.0, 0, 0.19323912262916565, 'btn distance=0')
#     (-0.0, 0, -0.243196040391922, 'round level 27')
#     (-0.0, 0, -0.023156270384788513, 'round level 26')
#     (0.0, 0, 0.003470483236014843, 'round level 25')
#     (0.0, 0, 0.15401211380958557, 'round level 24')
#     (0.0, 0, 0.21780440211296082, 'round level 23')
#     (-0.0, 0, -0.22260673344135284, 'round level 22')
#     (0.0, 0, 0.05764830857515335, 'round level 21')
#     (0.0, 0, 0.2020353376865387, 'round level 20')
#     (-0.0, 0, -0.2548794448375702, 'round level 19')
#     (-0.0, 0, -0.1148628517985344, 'round level 18')
#     (0.0, 0, 0.07593721896409988, 'round level 17')
#     (0.0, 0, 0.24762311577796936, 'round level 16')
#     (-0.0, 0, -0.05122379958629608, 'round level 15')
#     (-0.0, 0, -0.004059555009007454, 'round level 14')
#     (0.0, 0, 0.16804750263690948, 'round level 13')
#     (-0.0, 0, -0.224433034658432, 'round level 12')
#     (-0.0, 0, -0.19422996044158936, 'round level 11')
#     (-0.0, 0, -0.08357469737529755, 'round level 10')
#     (0.0, 0, 0.2517589330673218, 'round level 9')
#     (0.0, 0, 0.0839981883764267, 'round level 8')
#     (0.0, 0, 0.08711250126361847, 'round level 7')
#     (0.0, 0, 0.23109890520572662, 'round level 6')
#     (-0.0, 0, -0.07619556784629822, 'round level 5')
#     (0.0, 0, 0.10016213357448578, 'round level 4')
#     (-0.0, 0, -0.2349204421043396, 'round level 3')
#     (-0.0, 0, -0.007748506497591734, 'round level 1')

# %% [markdown]
# ### 100万iteration後のvalue function10人で対戦
# 変わらずbig blindの次で必ずallin.他のplayerはそれに対して必ずfoldで決着.

# %% [markdown]
# ### ALLIN する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['S4', 'CQ']
# -- round state --
#   - dealer btn : cpu5
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu5 (uuid-5) => state : participating, stack : 10000
#     - 1 : cpu8 (uuid-8) => state : participating, stack : 9975 <= SB
#     - 2 : cpu7 (uuid-7) => state : participating, stack : 9950 <= BB
#     - 3 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 5 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 6 : cpu9 (uuid-9) => state : participating, stack : 10000
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu3 (uuid-3) => state : participating, stack : 10000
#     - 9 : cpu4 (uuid-4) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'add_amount': 25}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', -0.06095900014042854), ('call', -0.7978218793869019), ('min_raise', 0.5653756856918335), ('double_raise', 0.010547422803938389), ('triple_raise', -0.410139262676239), ('max_raise', 0.7714416980743408)]
# ** weights and features in detail **
# bias : [ 0.05021409 -0.07686041  0.          0.          0.          0.        ]
#
# linear combination for fold :
#     (0.2593560218811035, 1, 0.2593560218811035, 'round level 2')
#     (-0.18217360973358154, 1, -0.18217360973358154, 'player-3:state-active')
#     (0.17122866710027057, 0.6666666666666666, 0.2568430006504059, 'player-9:history')
#     (-0.16950692236423492, 1, -0.16950692236423492, 'player-0:state-active')
#     (-0.15831279754638672, 1, -0.15831279754638672, 'player-5:state-active')
#     (-0.10564642399549484, 1, -0.10564642399549484, 'player-2:state-active')
#     (0.08540087938308716, 1, 0.08540087938308716, 'player-4:state-active')
#     (-0.07444114983081818, 1, -0.07444114983081818, 'player-6:state-active')
#     (0.06565069407224655, 1, 0.06565069407224655, 'street-preflop')
#     (0.06462918221950531, 1, 0.06462918221950531, 'player-7:state-active')
#     (0.06049284338951111, 0.3333333333333333, 0.18147853016853333, 'player-8:history')
#     (-0.05335110425949097, 1, -0.05335110425949097, 'player-1:state-active')
#     (0.050214093, 0, 0, 'bias')
#     (-0.04882608726620674, 1, -0.04882608726620674, 'player-9:state-active')
#     (0.03734046220779419, 1, 0.03734046220779419, 'player-8:state-active')
#     (-0.02996821515262127, 1, -0.02996821515262127, 'btn distance=3')
#     (0.024843131005764008, 0.1, 0.24843131005764008, 'player-7:stack')
#     (-0.01920406371355057, 0.1, -0.19204063713550568, 'player-5:stack')
#     (-0.018669122457504274, 0.1, -0.18669122457504272, 'player-3:stack')
#     (-0.014060595631599428, 0.1, -0.14060595631599426, 'player-6:stack')
#     (0.010947541147470475, 0.1, 0.10947541147470474, 'player-0:stack')
#     (-0.010750764083117247, 0.0995, -0.10804788023233414, 'player-9:stack')
#     (-0.005204113200306892, 0.1, -0.052041132003068924, 'player-1:stack')
#     (-0.0032040614634752276, 0.1, -0.032040614634752274, 'player-2:stack')
#     (0.0028930313885211947, 0.1, 0.028930313885211945, 'player-4:stack')
#     (-0.0004986377663444728, 0.09975, -0.0049988748505711555, 'player-8:stack')
#     (-0.00013784689083695413, 0.00075, -0.18379585444927216, 'pot')
#     (-9.895152620842396e-09, 0.619, -1.5985706980359282e-08, 'cards')
#     (-0.0, 0, -7.162844849517569e-05, 'player-9:state-fold')
#     (0.0, 0, 0.0851890966296196, 'player-8:state-fold')
#     (0.0, 0.0, 0.04918234422802925, 'player-7:history')
#     (0.0, 0, 0.2520604729652405, 'player-7:state-fold')
#     (-0.0, 0.0, -0.13236480951309204, 'player-6:history')
#     (0.0, 0, 0.12269149720668793, 'player-6:state-fold')
#     (0.0, 0.0, 0.027349501848220825, 'player-5:history')
#     (0.0, 0, 0.18234078586101532, 'player-5:state-fold')
#     (-0.0, 0.0, -0.04018624871969223, 'player-4:history')
#     (-0.0, 0, -0.03126266226172447, 'player-4:state-fold')
#     (-0.0, 0.0, -0.11032020300626755, 'player-3:history')
#     (-0.0, 0, -0.23660315573215485, 'player-3:state-fold')
#     (-0.0, 0.0, -0.2168671041727066, 'player-2:history')
#     (-0.0, 0, -0.023304414004087448, 'player-2:state-fold')
#     (-0.0, 0.0, -0.09811871498823166, 'player-1:history')
#     (-0.0, 0, -0.13428644835948944, 'player-1:state-fold')
#     (0.0, 0.0, 0.15051233768463135, 'player-0:history')
#     (0.0, 0, 0.1941356360912323, 'player-0:state-fold')
#     (0.0, 0, 0.11871553212404251, 'street-river')
#     (-0.0, 0, -0.1110917180776596, 'street-turn')
#     (-0.0, 0, -0.04047925025224686, 'street-flop')
#     (-0.0, 0, -0.018506085500121117, 'btn distance=9')
#     (0.0, 0, 0.19392263889312744, 'btn distance=8')
#     (0.0, 0, 0.25639697909355164, 'btn distance=7')
#     (0.0, 0, 0.26104164123535156, 'btn distance=6')
#     (-0.0, 0, -0.08797938376665115, 'btn distance=5')
#     (-0.0, 0, -0.11347238719463348, 'btn distance=4')
#     (0.0, 0, 0.1622413545846939, 'btn distance=2')
#     (-0.0, 0, -0.07458839565515518, 'btn distance=1')
#     (-0.0, 0, -0.21464864909648895, 'btn distance=0')
#     (-0.0, 0, -0.157193124294281, 'round level 27')
#     (-0.0, 0, -0.022340422496199608, 'round level 26')
#     (0.0, 0, 0.0732913464307785, 'round level 25')
#     (-0.0, 0, -0.20247098803520203, 'round level 24')
#     (-0.0, 0, -0.017685072496533394, 'round level 23')
#     (-0.0, 0, -0.21231283247470856, 'round level 22')
#     (0.0, 0, 0.09466390311717987, 'round level 21')
#     (-0.0, 0, -0.1319267451763153, 'round level 20')
#     (-0.0, 0, -0.19355502724647522, 'round level 19')
#     (0.0, 0, 0.1310054361820221, 'round level 18')
#     (-0.0, 0, -0.25354498624801636, 'round level 17')
#     (-0.0, 0, -0.11440449953079224, 'round level 16')
#     (-0.0, 0, -0.02884536236524582, 'round level 15')
#     (-0.0, 0, -0.09855259209871292, 'round level 14')
#     (0.0, 0, 0.14381340146064758, 'round level 13')
#     (0.0, 0, 0.09439601004123688, 'round level 12')
#     (-0.0, 0, -0.15986812114715576, 'round level 11')
#     (-0.0, 0, -0.1445908546447754, 'round level 10')
#     (0.0, 0, 0.054770808666944504, 'round level 9')
#     (0.0, 0, 0.17681853473186493, 'round level 8')
#     (0.0, 0, 0.2500433325767517, 'round level 7')
#     (0.0, 0, 0.010542628355324268, 'round level 6')
#     (-0.0, 0, -0.14735162258148193, 'round level 5')
#     (0.0, 0, 0.09386766701936722, 'round level 4')
#     (-0.0, 0, -0.021699830889701843, 'round level 3')
#     (0.0, 0, 0.20931224524974823, 'round level 1')
#
# linear combination for call :
#     (1.145220632314682, 0.619, 1.850114107131958, 'cards')
#     (-0.3368537724018097, 1, -0.3368537724018097, 'player-8:state-active')
#     (-0.3280845284461975, 1, -0.3280845284461975, 'player-5:state-active')
#     (-0.32648834586143494, 1, -0.32648834586143494, 'player-1:state-active')
#     (-0.2666216790676117, 1, -0.2666216790676117, 'player-9:state-active')
#     (-0.21882309516270954, 0.6666666666666666, -0.32823464274406433, 'player-9:history')
#     (-0.20502464473247528, 1, -0.20502464473247528, 'round level 2')
#     (-0.18540187180042267, 1, -0.18540187180042267, 'player-3:state-active')
#     (0.12856797873973846, 1, 0.12856797873973846, 'btn distance=3')
#     (0.10260237753391266, 1, 0.10260237753391266, 'player-6:state-active')
#     (-0.09050312638282776, 1, -0.09050312638282776, 'player-7:state-active')
#     (-0.076860406, 0, 0, 'bias')
#     (0.031727343797683716, 1, 0.031727343797683716, 'player-4:state-active')
#     (-0.028397318720817567, 0.1, -0.28397318720817566, 'player-1:stack')
#     (-0.027754145860672, 0.1, -0.27754145860671997, 'player-6:stack')
#     (-0.025514967739582062, 0.3333333333333333, -0.07654490321874619, 'player-8:history')
#     (-0.02352860958874226, 0.09975, -0.23587578535079956, 'player-8:stack')
#     (-0.02076815515756607, 0.1, -0.2076815515756607, 'player-5:stack')
#     (0.019498586654663086, 1, 0.019498586654663086, 'player-2:state-active')
#     (-0.016135235235095025, 0.0995, -0.1621631681919098, 'player-9:stack')
#     (-0.012847885489463806, 0.1, -0.12847885489463806, 'player-2:stack')
#     (-0.012138771824538708, 1, -0.012138771824538708, 'street-preflop')
#     (-0.011760220676660538, 0.1, -0.11760220676660538, 'player-0:stack')
#     (-0.008636468648910522, 0.1, -0.08636468648910522, 'player-3:stack')
#     (-0.0032116163522005084, 0.1, -0.03211616352200508, 'player-4:stack')
#     (-0.0008409954607486725, 0.1, -0.008409954607486725, 'player-7:stack')
#     (0.000824270595330745, 1, 0.000824270595330745, 'player-0:state-active')
#     (-6.726064905524254e-05, 0.00075, -0.08968086540699005, 'pot')
#     (-0.0, 0, -0.2775499224662781, 'player-9:state-fold')
#     (-0.0, 0, -0.009608046151697636, 'player-8:state-fold')
#     (-0.0, 0.0, -0.18969103693962097, 'player-7:history')
#     (-0.0, 0, -0.06349091976881027, 'player-7:state-fold')
#     (-0.0, 0.0, -0.08540630340576172, 'player-6:history')
#     (-0.0, 0, -0.21911293268203735, 'player-6:state-fold')
#     (-0.0, 0.0, -0.02964521013200283, 'player-5:history')
#     (-0.0, 0, -0.003028217004612088, 'player-5:state-fold')
#     (0.0, 0.0, 0.09201591461896896, 'player-4:history')
#     (-0.0, 0, -0.12634769082069397, 'player-4:state-fold')
#     (-0.0, 0.0, -0.05259004980325699, 'player-3:history')
#     (-0.0, 0, -0.20077961683273315, 'player-3:state-fold')
#     (-0.0, 0.0, -0.04389026761054993, 'player-2:history')
#     (-0.0, 0, -0.1257881075143814, 'player-2:state-fold')
#     (0.0, 0.0, 0.13273072242736816, 'player-1:history')
#     (0.0, 0, 0.04784411936998367, 'player-1:state-fold')
#     (-0.0, 0.0, -0.1697363406419754, 'player-0:history')
#     (0.0, 0, 0.04256691783666611, 'player-0:state-fold')
#     (0.0, 0, 0.0020736893638968468, 'street-river')
#     (0.0, 0, 0.1725275069475174, 'street-turn')
#     (0.0, 0, 0.1546308994293213, 'street-flop')
#     (0.0, 0, 0.12520329654216766, 'btn distance=9')
#     (0.0, 0, 0.023359322920441628, 'btn distance=8')
#     (0.0, 0, 0.028022725135087967, 'btn distance=7')
#     (0.0, 0, 0.07476399093866348, 'btn distance=6')
#     (-0.0, 0, -0.22745220363140106, 'btn distance=5')
#     (0.0, 0, 0.13111388683319092, 'btn distance=4')
#     (-0.0, 0, -0.18685166537761688, 'btn distance=2')
#     (-0.0, 0, -0.15054799616336823, 'btn distance=1')
#     (0.0, 0, 0.19323912262916565, 'btn distance=0')
#     (-0.0, 0, -0.243196040391922, 'round level 27')
#     (-0.0, 0, -0.023156270384788513, 'round level 26')
#     (0.0, 0, 0.003470483236014843, 'round level 25')
#     (0.0, 0, 0.15401211380958557, 'round level 24')
#     (0.0, 0, 0.21780440211296082, 'round level 23')
#     (-0.0, 0, -0.22260673344135284, 'round level 22')
#     (0.0, 0, 0.05764830857515335, 'round level 21')
#     (0.0, 0, 0.2020353376865387, 'round level 20')
#     (-0.0, 0, -0.2548794448375702, 'round level 19')
#     (-0.0, 0, -0.1148628517985344, 'round level 18')
#     (0.0, 0, 0.07593721896409988, 'round level 17')
#     (0.0, 0, 0.24762311577796936, 'round level 16')
#     (-0.0, 0, -0.05122379958629608, 'round level 15')
#     (-0.0, 0, -0.004059555009007454, 'round level 14')
#     (0.0, 0, 0.16804750263690948, 'round level 13')
#     (-0.0, 0, -0.224433034658432, 'round level 12')
#     (-0.0, 0, -0.19422996044158936, 'round level 11')
#     (-0.0, 0, -0.08357469737529755, 'round level 10')
#     (0.0, 0, 0.2517589330673218, 'round level 9')
#     (0.0, 0, 0.0839981883764267, 'round level 8')
#     (0.0, 0, 0.08711250126361847, 'round level 7')
#     (0.0, 0, 0.23109890520572662, 'round level 6')
#     (-0.0, 0, -0.07619556784629822, 'round level 5')
#     (0.0, 0, 0.10016213357448578, 'round level 4')
#     (-0.0, 0, -0.2349204421043396, 'round level 3')
#     (-0.0, 0, -0.007748506497591734, 'round level 1')
#
# linear combination for min_raise :
#     (0.20849823951721191, 1, 0.20849823951721191, 'player-4:state-active')
#     (-0.18592405319213867, 1, -0.18592405319213867, 'player-9:state-active')
#     (0.1589733064174652, 1, 0.1589733064174652, 'player-8:state-active')
#     (0.15025772154331207, 1, 0.15025772154331207, 'round level 2')
#     (0.14384786784648895, 1, 0.14384786784648895, 'player-1:state-active')
#     (0.13899749517440796, 1, 0.13899749517440796, 'player-2:state-active')
#     (-0.13198605179786682, 1, -0.13198605179786682, 'player-5:state-active')
#     (0.1024339497089386, 1, 0.1024339497089386, 'player-0:state-active')
#     (-0.08589034527540207, 1, -0.08589034527540207, 'street-preflop')
#     (0.07346060872077942, 1, 0.07346060872077942, 'player-3:state-active')
#     (-0.06415576487779617, 1, -0.06415576487779617, 'player-6:state-active')
#     (-0.06316948682069778, 1, -0.06316948682069778, 'btn distance=3')
#     (0.055896177887916565, 0.3333333333333333, 0.1676885336637497, 'player-8:history')
#     (0.028040999546647072, 1, 0.028040999546647072, 'player-7:state-active')
#     (0.025915625691413882, 0.1, 0.2591562569141388, 'player-3:stack')
#     (-0.024658223513513804, 0.09975, -0.24720023572444916, 'player-8:stack')
#     (0.02312430276721716, 0.619, 0.03735751658678055, 'cards')
#     (-0.021758350729942325, 0.1, -0.21758350729942322, 'player-2:stack')
#     (0.02005092054605484, 0.6666666666666666, 0.03007638081908226, 'player-9:history')
#     (0.017303086817264557, 0.1, 0.17303086817264557, 'player-6:stack')
#     (0.01478569656610489, 0.1, 0.1478569656610489, 'player-4:stack')
#     (-0.012943124771118164, 0.1, -0.12943124771118164, 'player-5:stack')
#     (-0.004929295927286148, 0.1, -0.04929295927286148, 'player-1:stack')
#     (0.0017137076416984202, 0.0995, 0.017223192378878593, 'player-9:stack')
#     (-0.0013368891552090645, 0.1, -0.013368891552090645, 'player-0:stack')
#     (-0.0012864792719483376, 0.1, -0.012864792719483376, 'player-7:stack')
#     (0.00011405199766159058, 0.00075, 0.1520693302154541, 'pot')
#     (0.0, 0, 0, 'bias')
#     (0.0, 0, 0.18296323716640472, 'player-9:state-fold')
#     (0.0, 0, 0.10726218670606613, 'player-8:state-fold')
#     (-0.0, 0.0, -0.20136457681655884, 'player-7:history')
#     (-0.0, 0, -0.22921545803546906, 'player-7:state-fold')
#     (0.0, 0.0, 0.08433707803487778, 'player-6:history')
#     (0.0, 0, 0.14500127732753754, 'player-6:state-fold')
#     (0.0, 0.0, 0.12295147031545639, 'player-5:history')
#     (-0.0, 0, -0.047310616821050644, 'player-5:state-fold')
#     (0.0, 0.0, 0.19297930598258972, 'player-4:history')
#     (0.0, 0, 0.07710491865873337, 'player-4:state-fold')
#     (0.0, 0.0, 0.19381718337535858, 'player-3:history')
#     (-0.0, 0, -0.18229132890701294, 'player-3:state-fold')
#     (0.0, 0.0, 0.1123739555478096, 'player-2:history')
#     (0.0, 0, 0.17827273905277252, 'player-2:state-fold')
#     (-0.0, 0.0, -0.21221531927585602, 'player-1:history')
#     (0.0, 0, 0.01488448679447174, 'player-1:state-fold')
#     (0.0, 0.0, 0.07965674251317978, 'player-0:history')
#     (0.0, 0, 0.11470087617635727, 'player-0:state-fold')
#     (0.0, 0, 0.22769775986671448, 'street-river')
#     (0.0, 0, 0.019793173298239708, 'street-turn')
#     (-0.0, 0, -0.08614850044250488, 'street-flop')
#     (0.0, 0, 0.12430199980735779, 'btn distance=9')
#     (0.0, 0, 0.18569010496139526, 'btn distance=8')
#     (-0.0, 0, -0.2330344021320343, 'btn distance=7')
#     (-0.0, 0, -0.24160028994083405, 'btn distance=6')
#     (0.0, 0, 0.04411689564585686, 'btn distance=5')
#     (-0.0, 0, -0.07802970707416534, 'btn distance=4')
#     (0.0, 0, 0.06924721598625183, 'btn distance=2')
#     (0.0, 0, 0.24695640802383423, 'btn distance=1')
#     (-0.0, 0, -0.09765464812517166, 'btn distance=0')
#     (-0.0, 0, -0.07168193906545639, 'round level 27')
#     (0.0, 0, 0.0020102381240576506, 'round level 26')
#     (-0.0, 0, -0.05149857699871063, 'round level 25')
#     (0.0, 0, 0.25409719347953796, 'round level 24')
#     (-0.0, 0, -0.00434030219912529, 'round level 23')
#     (0.0, 0, 0.08832600712776184, 'round level 22')
#     (-0.0, 0, -0.1749695986509323, 'round level 21')
#     (0.0, 0, 0.09540113806724548, 'round level 20')
#     (-0.0, 0, -0.24687255918979645, 'round level 19')
#     (0.0, 0, 0.1442979872226715, 'round level 18')
#     (0.0, 0, 0.18567436933517456, 'round level 17')
#     (-0.0, 0, -0.11047004908323288, 'round level 16')
#     (0.0, 0, 0.24146737158298492, 'round level 15')
#     (-0.0, 0, -0.014989090152084827, 'round level 14')
#     (-0.0, 0, -0.1395028531551361, 'round level 13')
#     (0.0, 0, 0.06579896807670593, 'round level 12')
#     (-0.0, 0, -0.2015688121318817, 'round level 11')
#     (-0.0, 0, -0.02576248161494732, 'round level 10')
#     (0.0, 0, 0.15448996424674988, 'round level 9')
#     (-0.0, 0, -0.013245650567114353, 'round level 8')
#     (0.0, 0, 0.09939922392368317, 'round level 7')
#     (0.0, 0, 0.16422493755817413, 'round level 6')
#     (-0.0, 0, -0.08207165449857712, 'round level 5')
#     (-0.0, 0, -0.2075251340866089, 'round level 4')
#     (-0.0, 0, -0.2374327927827835, 'round level 3')
#     (0.0, 0, 0.1168898493051529, 'round level 1')
#
# linear combination for double_raise :
#     (-0.25238075852394104, 1, -0.25238075852394104, 'btn distance=3')
#     (0.2504120469093323, 1, 0.2504120469093323, 'player-4:state-active')
#     (-0.23892885446548462, 1, -0.23892885446548462, 'player-2:state-active')
#     (0.22203806042671204, 1, 0.22203806042671204, 'player-7:state-active')
#     (0.19552835822105408, 1, 0.19552835822105408, 'player-0:state-active')
#     (-0.19116884469985962, 1, -0.19116884469985962, 'player-9:state-active')
#     (0.1883895844221115, 1, 0.1883895844221115, 'player-1:state-active')
#     (-0.15767088532447815, 0.6666666666666666, -0.23650632798671722, 'player-9:history')
#     (0.1171807312220335, 0.619, 0.18930651247501373, 'cards')
#     (-0.1149071604013443, 1, -0.1149071604013443, 'player-3:state-active')
#     (-0.10108418762683868, 1, -0.10108418762683868, 'round level 2')
#     (0.09949827194213867, 1, 0.09949827194213867, 'player-5:state-active')
#     (-0.06473118563493092, 0.3333333333333333, -0.19419355690479279, 'player-8:history')
#     (0.06192198023200035, 1, 0.06192198023200035, 'player-8:state-active')
#     (0.049831047654151917, 1, 0.049831047654151917, 'street-preflop')
#     (-0.04342479258775711, 1, -0.04342479258775711, 'player-6:state-active')
#     (-0.024801722656935456, 0.09975, -0.2486388236284256, 'player-8:stack')
#     (0.018260061740875244, 0.1, 0.18260061740875244, 'player-6:stack')
#     (-0.01680694967508316, 0.1, -0.1680694967508316, 'player-1:stack')
#     (0.014583063125610352, 0.1, 0.14583063125610352, 'player-2:stack')
#     (0.011933237314224243, 0.1, 0.11933237314224243, 'player-3:stack')
#     (0.010158253461122514, 0.1, 0.10158253461122513, 'player-0:stack')
#     (-0.009252853777259588, 0.0995, -0.09299350529909134, 'player-9:stack')
#     (-0.0065494880080223085, 0.1, -0.06549488008022308, 'player-4:stack')
#     (-0.005681443586945534, 0.1, -0.05681443586945534, 'player-5:stack')
#     (-0.0018397508189082147, 0.1, -0.018397508189082146, 'player-7:stack')
#     (4.1626866906881334e-05, 0.00075, 0.05550248920917511, 'pot')
#     (0.0, 0, 0, 'bias')
#     (0.0, 0, 0.04853530600667, 'player-9:state-fold')
#     (0.0, 0, 0.031480174511671066, 'player-8:state-fold')
#     (0.0, 0.0, 0.04559958353638649, 'player-7:history')
#     (0.0, 0, 0.2451270967721939, 'player-7:state-fold')
#     (0.0, 0.0, 0.18599508702754974, 'player-6:history')
#     (0.0, 0, 0.21151751279830933, 'player-6:state-fold')
#     (-0.0, 0.0, -0.07166066765785217, 'player-5:history')
#     (-0.0, 0, -0.08182913064956665, 'player-5:state-fold')
#     (0.0, 0.0, 0.09959843009710312, 'player-4:history')
#     (-0.0, 0, -0.0668734461069107, 'player-4:state-fold')
#     (0.0, 0.0, 0.10553708672523499, 'player-3:history')
#     (-0.0, 0, -0.00968413706868887, 'player-3:state-fold')
#     (0.0, 0.0, 0.06693552434444427, 'player-2:history')
#     (-0.0, 0, -0.05680442973971367, 'player-2:state-fold')
#     (0.0, 0.0, 0.008215732872486115, 'player-1:history')
#     (0.0, 0, 0.036690764129161835, 'player-1:state-fold')
#     (0.0, 0.0, 0.07938522100448608, 'player-0:history')
#     (-0.0, 0, -0.048810120671987534, 'player-0:state-fold')
#     (0.0, 0, 0.14103002846240997, 'street-river')
#     (-0.0, 0, -0.02233775705099106, 'street-turn')
#     (-0.0, 0, -0.01179889403283596, 'street-flop')
#     (0.0, 0, 0.1674492508172989, 'btn distance=9')
#     (0.0, 0, 0.08124087750911713, 'btn distance=8')
#     (-0.0, 0, -0.14939723908901215, 'btn distance=7')
#     (-0.0, 0, -0.15247425436973572, 'btn distance=6')
#     (0.0, 0, 0.20726671814918518, 'btn distance=5')
#     (-0.0, 0, -0.10643009841442108, 'btn distance=4')
#     (0.0, 0, 0.05170707032084465, 'btn distance=2')
#     (0.0, 0, 0.11139650642871857, 'btn distance=1')
#     (0.0, 0, 0.0504719503223896, 'btn distance=0')
#     (-0.0, 0, -0.22878989577293396, 'round level 27')
#     (-0.0, 0, -0.09713347256183624, 'round level 26')
#     (0.0, 0, 0.0183255672454834, 'round level 25')
#     (-0.0, 0, -0.02316262759268284, 'round level 24')
#     (0.0, 0, 0.14512333273887634, 'round level 23')
#     (0.0, 0, 0.14382004737854004, 'round level 22')
#     (0.0, 0, 0.05084460973739624, 'round level 21')
#     (-0.0, 0, -0.22428904473781586, 'round level 20')
#     (0.0, 0, 0.11020268499851227, 'round level 19')
#     (0.0, 0, 0.17648957669734955, 'round level 18')
#     (0.0, 0, 0.24417027831077576, 'round level 17')
#     (-0.0, 0, -0.19540438055992126, 'round level 16')
#     (-0.0, 0, -0.12288767844438553, 'round level 15')
#     (0.0, 0, 0.2205205112695694, 'round level 14')
#     (-0.0, 0, -0.012383097782731056, 'round level 13')
#     (-0.0, 0, -0.13942918181419373, 'round level 12')
#     (0.0, 0, 0.03898955136537552, 'round level 11')
#     (0.0, 0, 0.18798846006393433, 'round level 10')
#     (0.0, 0, 0.07701212912797928, 'round level 9')
#     (-0.0, 0, -0.04181545972824097, 'round level 8')
#     (0.0, 0, 0.14689508080482483, 'round level 7')
#     (-0.0, 0, -0.22795704007148743, 'round level 6')
#     (-0.0, 0, -0.1961844116449356, 'round level 5')
#     (0.0, 0, 0.17895659804344177, 'round level 4')
#     (-0.0, 0, -0.25631412863731384, 'round level 3')
#     (0.0, 0, 0.24536371231079102, 'round level 1')
#
# linear combination for triple_raise :
#     (0.24694661796092987, 1, 0.24694661796092987, 'player-7:state-active')
#     (-0.1813841164112091, 1, -0.1813841164112091, 'player-4:state-active')
#     (-0.1704285442829132, 1, -0.1704285442829132, 'player-2:state-active')
#     (-0.14387516677379608, 1, -0.14387516677379608, 'player-5:state-active')
#     (-0.13792431354522705, 1, -0.13792431354522705, 'btn distance=3')
#     (-0.13786941766738892, 1, -0.13786941766738892, 'player-1:state-active')
#     (0.10676056146621704, 1, 0.10676056146621704, 'street-preflop')
#     (-0.10657975822687149, 1, -0.10657975822687149, 'player-0:state-active')
#     (0.08353433012962341, 1, 0.08353433012962341, 'round level 2')
#     (-0.07543616741895676, 1, -0.07543616741895676, 'player-3:state-active')
#     (0.06525210730731487, 0.619, 0.10541535913944244, 'cards')
#     (-0.048610419034957886, 0.6666666666666666, -0.07291562855243683, 'player-9:history')
#     (0.04814155027270317, 1, 0.04814155027270317, 'player-9:state-active')
#     (0.024430599063634872, 1, 0.024430599063634872, 'player-8:state-active')
#     (-0.021866764128208163, 0.1, -0.2186676412820816, 'player-2:stack')
#     (0.02185601592063904, 0.1, 0.21856015920639038, 'player-6:stack')
#     (0.01669674813747406, 0.1, 0.1669674813747406, 'player-4:stack')
#     (0.016079960390925407, 1, 0.016079960390925407, 'player-6:state-active')
#     (-0.014583208908637364, 0.3333333333333333, -0.043749626725912094, 'player-8:history')
#     (0.013153241895139218, 0.09975, 0.131862074136734, 'player-8:stack')
#     (-0.009703592956066133, 0.1, -0.09703592956066132, 'player-1:stack')
#     (-0.00760205164551735, 0.1, -0.07602051645517349, 'player-7:stack')
#     (-0.0075607202947139745, 0.1, -0.07560720294713974, 'player-0:stack')
#     (0.005143529476597905, 0.0995, 0.051693763583898544, 'player-9:stack')
#     (0.004650874435901642, 0.1, 0.04650874435901642, 'player-5:stack')
#     (0.0007889139465987683, 0.1, 0.007889139465987682, 'player-3:stack')
#     (-0.00015010637417435646, 0.00075, -0.20014183223247528, 'pot')
#     (0.0, 0, 0, 'bias')
#     (-0.0, 0, -0.0027812873013317585, 'player-9:state-fold')
#     (-0.0, 0, -0.09964339435100555, 'player-8:state-fold')
#     (0.0, 0.0, 0.006627007387578487, 'player-7:history')
#     (0.0, 0, 0.029756052419543266, 'player-7:state-fold')
#     (-0.0, 0.0, -0.0868103951215744, 'player-6:history')
#     (0.0, 0, 0.03582059592008591, 'player-6:state-fold')
#     (0.0, 0.0, 0.14977802336215973, 'player-5:history')
#     (0.0, 0, 0.05285193771123886, 'player-5:state-fold')
#     (0.0, 0.0, 0.08622831851243973, 'player-4:history')
#     (-0.0, 0, -0.03153127431869507, 'player-4:state-fold')
#     (0.0, 0.0, 0.03464150056242943, 'player-3:history')
#     (0.0, 0, 0.031059280037879944, 'player-3:state-fold')
#     (-0.0, 0.0, -0.17729148268699646, 'player-2:history')
#     (-0.0, 0, -0.23033276200294495, 'player-2:state-fold')
#     (-0.0, 0.0, -0.16155922412872314, 'player-1:history')
#     (-0.0, 0, -0.036232080310583115, 'player-1:state-fold')
#     (-0.0, 0.0, -0.17815719544887543, 'player-0:history')
#     (-0.0, 0, -0.13336129486560822, 'player-0:state-fold')
#     (-0.0, 0, -0.213123619556427, 'street-river')
#     (0.0, 0, 0.20355470478534698, 'street-turn')
#     (-0.0, 0, -0.08059458434581757, 'street-flop')
#     (-0.0, 0, -0.09507381170988083, 'btn distance=9')
#     (-0.0, 0, -0.2554704248905182, 'btn distance=8')
#     (-0.0, 0, -0.1417112499475479, 'btn distance=7')
#     (0.0, 0, 0.0655583068728447, 'btn distance=6')
#     (-0.0, 0, -0.10293184220790863, 'btn distance=5')
#     (0.0, 0, 0.23919938504695892, 'btn distance=4')
#     (0.0, 0, 0.10632307082414627, 'btn distance=2')
#     (0.0, 0, 0.11176927387714386, 'btn distance=1')
#     (-0.0, 0, -0.17196720838546753, 'btn distance=0')
#     (-0.0, 0, -0.11413256824016571, 'round level 27')
#     (0.0, 0, 0.031105956062674522, 'round level 26')
#     (0.0, 0, 0.23647229373455048, 'round level 25')
#     (0.0, 0, 0.10683319717645645, 'round level 24')
#     (-0.0, 0, -0.20570926368236542, 'round level 23')
#     (0.0, 0, 0.06475907564163208, 'round level 22')
#     (0.0, 0, 0.23939149081707, 'round level 21')
#     (-0.0, 0, -0.17680984735488892, 'round level 20')
#     (-0.0, 0, -0.04781121388077736, 'round level 19')
#     (0.0, 0, 0.06822703033685684, 'round level 18')
#     (0.0, 0, 0.23281681537628174, 'round level 17')
#     (-0.0, 0, -0.06258570402860641, 'round level 16')
#     (-0.0, 0, -0.062407203018665314, 'round level 15')
#     (-0.0, 0, -0.21637608110904694, 'round level 14')
#     (-0.0, 0, -0.24704204499721527, 'round level 13')
#     (0.0, 0, 0.06390265375375748, 'round level 12')
#     (-0.0, 0, -0.023371661081910133, 'round level 11')
#     (-0.0, 0, -0.10753955692052841, 'round level 10')
#     (-0.0, 0, -0.15809255838394165, 'round level 9')
#     (-0.0, 0, -0.20982156693935394, 'round level 8')
#     (-0.0, 0, -0.04409642517566681, 'round level 7')
#     (-0.0, 0, -0.12233775854110718, 'round level 6')
#     (0.0, 0, 0.12443231791257858, 'round level 5')
#     (-0.0, 0, -0.18804314732551575, 'round level 4')
#     (0.0, 0, 0.1655283123254776, 'round level 3')
#     (0.0, 0, 0.047176800668239594, 'round level 1')
#
# linear combination for max_raise :
#     (0.23114421963691711, 1, 0.23114421963691711, 'round level 2')
#     (-0.2247796654701233, 1, -0.2247796654701233, 'btn distance=3')
#     (0.20934996008872986, 1, 0.20934996008872986, 'player-1:state-active')
#     (0.1951204538345337, 1, 0.1951204538345337, 'player-5:state-active')
#     (0.17200875282287598, 1, 0.17200875282287598, 'street-preflop')
#     (0.1521425371170044, 0.619, 0.2457876205444336, 'cards')
#     (-0.1418961137533188, 1, -0.1418961137533188, 'player-8:state-active')
#     (0.13060857355594635, 1, 0.13060857355594635, 'player-9:state-active')
#     (-0.12555615603923798, 1, -0.12555615603923798, 'player-6:state-active')
#     (0.11714696139097214, 1, 0.11714696139097214, 'player-2:state-active')
#     (0.09808074434598286, 0.6666666666666666, 0.1471211165189743, 'player-9:history')
#     (0.06449420750141144, 1, 0.06449420750141144, 'player-0:state-active')
#     (-0.04089307536681493, 0.3333333333333333, -0.1226792261004448, 'player-8:history')
#     (-0.03879714012145996, 1, -0.03879714012145996, 'player-3:state-active')
#     (0.025830911472439766, 1, 0.025830911472439766, 'player-7:state-active')
#     (-0.023544734716415407, 0.1, -0.23544734716415405, 'player-1:stack')
#     (0.02064388394355774, 0.1, 0.2064388394355774, 'player-4:stack')
#     (-0.016720090806484223, 0.1, -0.16720090806484222, 'player-2:stack')
#     (-0.011749492585659028, 0.1, -0.11749492585659027, 'player-7:stack')
#     (-0.011552865382283927, 0.0995, -0.116109199821949, 'player-9:stack')
#     (-0.01003548800945282, 0.1, -0.1003548800945282, 'player-5:stack')
#     (-0.007861196994781494, 0.1, -0.07861196994781494, 'player-3:stack')
#     (-0.0073168776929378515, 0.1, -0.07316877692937851, 'player-6:stack')
#     (0.00675180833786726, 1, 0.00675180833786726, 'player-4:state-active')
#     (0.0060490967547521, 0.09975, 0.06064257398247719, 'player-8:stack')
#     (0.0026476880535483364, 0.1, 0.02647688053548336, 'player-0:stack')
#     (0.0001247873604297638, 0.00075, 0.16638314723968506, 'pot')
#     (0.0, 0, 0, 'bias')
#     (0.0, 0, 0.2593461275100708, 'player-9:state-fold')
#     (-0.0, 0, -0.21160270273685455, 'player-8:state-fold')
#     (-0.0, 0.0, -0.2054324895143509, 'player-7:history')
#     (0.0, 0, 0.22931134700775146, 'player-7:state-fold')
#     (-0.0, 0.0, -0.15349073708057404, 'player-6:history')
#     (0.0, 0, 0.2240581065416336, 'player-6:state-fold')
#     (-0.0, 0.0, -0.06440378725528717, 'player-5:history')
#     (-0.0, 0, -0.11622752994298935, 'player-5:state-fold')
#     (-0.0, 0.0, -0.18086472153663635, 'player-4:history')
#     (0.0, 0, 0.13435931503772736, 'player-4:state-fold')
#     (0.0, 0.0, 0.08639606833457947, 'player-3:history')
#     (0.0, 0, 0.11308294534683228, 'player-3:state-fold')
#     (-0.0, 0.0, -0.033438269048929214, 'player-2:history')
#     (-0.0, 0, -0.24040423333644867, 'player-2:state-fold')
#     (0.0, 0.0, 0.17977386713027954, 'player-1:history')
#     (0.0, 0, 0.13203458487987518, 'player-1:state-fold')
#     (-0.0, 0.0, -0.14835110306739807, 'player-0:history')
#     (0.0, 0, 0.08087477087974548, 'player-0:state-fold')
#     (-0.0, 0, -0.19033072888851166, 'street-river')
#     (-0.0, 0, -0.19670742750167847, 'street-turn')
#     (0.0, 0, 0.23690591752529144, 'street-flop')
#     (0.0, 0, 0.19500409066677094, 'btn distance=9')
#     (-0.0, 0, -0.159495010972023, 'btn distance=8')
#     (-0.0, 0, -0.07510904222726822, 'btn distance=7')
#     (-0.0, 0, -0.1130678579211235, 'btn distance=6')
#     (-0.0, 0, -0.01575898565351963, 'btn distance=5')
#     (-0.0, 0, -0.20628832280635834, 'btn distance=4')
#     (0.0, 0, 0.052926573902368546, 'btn distance=2')
#     (-0.0, 0, -0.030675364658236504, 'btn distance=1')
#     (-0.0, 0, -0.018590666353702545, 'btn distance=0')
#     (0.0, 0, 0.24902744591236115, 'round level 27')
#     (-0.0, 0, -0.13526393473148346, 'round level 26')
#     (0.0, 0, 0.23494407534599304, 'round level 25')
#     (-0.0, 0, -0.07349041104316711, 'round level 24')
#     (0.0, 0, 0.2440856546163559, 'round level 23')
#     (0.0, 0, 0.18772095441818237, 'round level 22')
#     (-0.0, 0, -0.16728129982948303, 'round level 21')
#     (-0.0, 0, -0.04031484201550484, 'round level 20')
#     (0.0, 0, 0.23258255422115326, 'round level 19')
#     (0.0, 0, 0.11064807325601578, 'round level 18')
#     (0.0, 0, 0.07781971991062164, 'round level 17')
#     (-0.0, 0, -0.022468965500593185, 'round level 16')
#     (0.0, 0, 0.026893282309174538, 'round level 15')
#     (0.0, 0, 0.1576375514268875, 'round level 14')
#     (0.0, 0, 0.14820368587970734, 'round level 13')
#     (-0.0, 0, -0.08295246213674545, 'round level 12')
#     (-0.0, 0, -0.24188120663166046, 'round level 11')
#     (0.0, 0, 0.19233454763889313, 'round level 10')
#     (0.0, 0, 0.1286068707704544, 'round level 9')
#     (-0.0, 0, -0.11806211620569229, 'round level 8')
#     (-0.0, 0, -0.03643910214304924, 'round level 7')
#     (-0.0, 0, -0.13878880441188812, 'round level 6')
#     (0.0, 0, 0.1881687492132187, 'round level 5')
#     (0.0, 0, 0.25155341625213623, 'round level 4')
#     (0.0, 0, 0.07624056190252304, 'round level 3')
#     (0.0, 0, 0.13523666560649872, 'round level 1')

# %% [markdown]
# ### FOLD する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['C7', 'HJ']
# -- round state --
#   - dealer btn : cpu2
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-8']}]
#   - players information
#     - 0 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 1 : cpu5 (uuid-5) => state : participating, stack : 9975 <= SB
#     - 2 : cpu1 (uuid-1) => state : participating, stack : 9950 <= BB
#     - 3 : cpu8 (uuid-8) => state : allin, stack : 0
#     - 4 : cpu4 (uuid-4) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : cpu9 (uuid-9) => state : folded, stack : 10000
#     - 7 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 8 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.14209018647670746), ('call', -0.37848100066185)]
# ** weights and features in detail **
# bias : [ 0.05021409 -0.07686041  0.          0.          0.          0.        ]
#
# linear combination for fold :
#     (0.2593560218811035, 1, 0.2593560218811035, 'round level 2')
#     (0.25639697909355164, 1, 0.25639697909355164, 'btn distance=7')
#     (0.2520604729652405, 1, 0.2520604729652405, 'player-7:state-fold')
#     (-0.18217360973358154, 1, -0.18217360973358154, 'player-3:state-active')
#     (-0.16950692236423492, 1, -0.16950692236423492, 'player-0:state-active')
#     (-0.15831279754638672, 1, -0.15831279754638672, 'player-5:state-active')
#     (-0.1313794635365678, 0.9925558312655087, -0.13236480951309204, 'player-6:history')
#     (-0.10564642399549484, 1, -0.10564642399549484, 'player-2:state-active')
#     (0.08540087938308716, 1, 0.08540087938308716, 'player-4:state-active')
#     (0.0851890966296196, 1, 0.0851890966296196, 'player-8:state-fold')
#     (-0.07444114983081818, 1, -0.07444114983081818, 'player-6:state-active')
#     (0.06565069407224655, 1, 0.06565069407224655, 'street-preflop')
#     (-0.05335110425949097, 1, -0.05335110425949097, 'player-1:state-active')
#     (0.050214093, 0, 0, 'bias')
#     (0.024843131005764008, 0.1, 0.24843131005764008, 'player-7:stack')
#     (-0.019108043394982815, 0.0995, -0.19204063713550568, 'player-5:stack')
#     (-0.018669122457504274, 0.1, -0.18669122457504272, 'player-3:stack')
#     (-0.01851743233576417, 0.10075, -0.18379585444927216, 'pot')
#     (0.010947541147470475, 0.1, 0.10947541147470474, 'player-0:stack')
#     (-0.010804788023233414, 0.1, -0.10804788023233414, 'player-9:stack')
#     (-0.005204113200306892, 0.1, -0.052041132003068924, 'player-1:stack')
#     (-0.0032040614634752276, 0.1, -0.032040614634752274, 'player-2:stack')
#     (0.0028857988100498915, 0.09975, 0.028930313885211945, 'player-4:stack')
#     (-0.0004998874850571155, 0.1, -0.0049988748505711555, 'player-8:stack')
#     (0.00013572953770829194, 0.004962779156327543, 0.027349501848220825, 'player-5:history')
#     (-9.971773875854152e-05, 0.0024813895781637717, -0.04018624871969223, 'player-4:history')
#     (-7.162844849517569e-05, 1, -7.162844849517569e-05, 'player-9:state-fold')
#     (-9.879166913862036e-09, 0.618, -1.5985706980359282e-08, 'cards')
#     (0.0, 0.0, 0.2568430006504059, 'player-9:history')
#     (-0.0, 0, -0.04882608726620674, 'player-9:state-active')
#     (0.0, 0.0, 0.18147853016853333, 'player-8:history')
#     (0.0, 0, 0.03734046220779419, 'player-8:state-active')
#     (0.0, 0.0, 0.04918234422802925, 'player-7:history')
#     (0.0, 0, 0.06462918221950531, 'player-7:state-active')
#     (0.0, 0, 0.12269149720668793, 'player-6:state-fold')
#     (-0.0, 0.0, -0.14060595631599426, 'player-6:stack')
#     (0.0, 0, 0.18234078586101532, 'player-5:state-fold')
#     (-0.0, 0, -0.03126266226172447, 'player-4:state-fold')
#     (-0.0, 0.0, -0.11032020300626755, 'player-3:history')
#     (-0.0, 0, -0.23660315573215485, 'player-3:state-fold')
#     (-0.0, 0.0, -0.2168671041727066, 'player-2:history')
#     (-0.0, 0, -0.023304414004087448, 'player-2:state-fold')
#     (-0.0, 0.0, -0.09811871498823166, 'player-1:history')
#     (-0.0, 0, -0.13428644835948944, 'player-1:state-fold')
#     (0.0, 0.0, 0.15051233768463135, 'player-0:history')
#     (0.0, 0, 0.1941356360912323, 'player-0:state-fold')
#     (0.0, 0, 0.11871553212404251, 'street-river')
#     (-0.0, 0, -0.1110917180776596, 'street-turn')
#     (-0.0, 0, -0.04047925025224686, 'street-flop')
#     (-0.0, 0, -0.018506085500121117, 'btn distance=9')
#     (0.0, 0, 0.19392263889312744, 'btn distance=8')
#     (0.0, 0, 0.26104164123535156, 'btn distance=6')
#     (-0.0, 0, -0.08797938376665115, 'btn distance=5')
#     (-0.0, 0, -0.11347238719463348, 'btn distance=4')
#     (-0.0, 0, -0.02996821515262127, 'btn distance=3')
#     (0.0, 0, 0.1622413545846939, 'btn distance=2')
#     (-0.0, 0, -0.07458839565515518, 'btn distance=1')
#     (-0.0, 0, -0.21464864909648895, 'btn distance=0')
#     (-0.0, 0, -0.157193124294281, 'round level 27')
#     (-0.0, 0, -0.022340422496199608, 'round level 26')
#     (0.0, 0, 0.0732913464307785, 'round level 25')
#     (-0.0, 0, -0.20247098803520203, 'round level 24')
#     (-0.0, 0, -0.017685072496533394, 'round level 23')
#     (-0.0, 0, -0.21231283247470856, 'round level 22')
#     (0.0, 0, 0.09466390311717987, 'round level 21')
#     (-0.0, 0, -0.1319267451763153, 'round level 20')
#     (-0.0, 0, -0.19355502724647522, 'round level 19')
#     (0.0, 0, 0.1310054361820221, 'round level 18')
#     (-0.0, 0, -0.25354498624801636, 'round level 17')
#     (-0.0, 0, -0.11440449953079224, 'round level 16')
#     (-0.0, 0, -0.02884536236524582, 'round level 15')
#     (-0.0, 0, -0.09855259209871292, 'round level 14')
#     (0.0, 0, 0.14381340146064758, 'round level 13')
#     (0.0, 0, 0.09439601004123688, 'round level 12')
#     (-0.0, 0, -0.15986812114715576, 'round level 11')
#     (-0.0, 0, -0.1445908546447754, 'round level 10')
#     (0.0, 0, 0.054770808666944504, 'round level 9')
#     (0.0, 0, 0.17681853473186493, 'round level 8')
#     (0.0, 0, 0.2500433325767517, 'round level 7')
#     (0.0, 0, 0.010542628355324268, 'round level 6')
#     (-0.0, 0, -0.14735162258148193, 'round level 5')
#     (0.0, 0, 0.09386766701936722, 'round level 4')
#     (-0.0, 0, -0.021699830889701843, 'round level 3')
#     (0.0, 0, 0.20931224524974823, 'round level 1')
#
# linear combination for call :
#     (1.14337051820755, 0.618, 1.850114107131958, 'cards')
#     (-0.3280845284461975, 1, -0.3280845284461975, 'player-5:state-active')
#     (-0.32648834586143494, 1, -0.32648834586143494, 'player-1:state-active')
#     (-0.2775499224662781, 1, -0.2775499224662781, 'player-9:state-fold')
#     (-0.20502464473247528, 1, -0.20502464473247528, 'round level 2')
#     (-0.18540187180042267, 1, -0.18540187180042267, 'player-3:state-active')
#     (0.10260237753391266, 1, 0.10260237753391266, 'player-6:state-active')
#     (-0.08477052447222007, 0.9925558312655087, -0.08540630340576172, 'player-6:history')
#     (-0.076860406, 0, 0, 'bias')
#     (-0.06349091976881027, 1, -0.06349091976881027, 'player-7:state-fold')
#     (0.031727343797683716, 1, 0.031727343797683716, 'player-4:state-active')
#     (-0.028397318720817567, 0.1, -0.28397318720817566, 'player-1:stack')
#     (0.028022725135087967, 1, 0.028022725135087967, 'btn distance=7')
#     (-0.023587578535079957, 0.1, -0.23587578535079956, 'player-8:stack')
#     (-0.02066431438177824, 0.0995, -0.2076815515756607, 'player-5:stack')
#     (0.019498586654663086, 1, 0.019498586654663086, 'player-2:state-active')
#     (-0.01621631681919098, 0.1, -0.1621631681919098, 'player-9:stack')
#     (-0.012847885489463806, 0.1, -0.12847885489463806, 'player-2:stack')
#     (-0.012138771824538708, 1, -0.012138771824538708, 'street-preflop')
#     (-0.011760220676660538, 0.1, -0.11760220676660538, 'player-0:stack')
#     (-0.009608046151697636, 1, -0.009608046151697636, 'player-8:state-fold')
#     (-0.009035347189754248, 0.10075, -0.08968086540699005, 'pot')
#     (-0.008636468648910522, 0.1, -0.08636468648910522, 'player-3:stack')
#     (-0.003203587311320007, 0.09975, -0.03211616352200508, 'player-4:stack')
#     (-0.0008409954607486725, 0.1, -0.008409954607486725, 'player-7:stack')
#     (0.000824270595330745, 1, 0.000824270595330745, 'player-0:state-active')
#     (0.00022832733156071704, 0.0024813895781637717, 0.09201591461896896, 'player-4:history')
#     (-0.00014712263092805374, 0.004962779156327543, -0.02964521013200283, 'player-5:history')
#     (-0.0, 0.0, -0.32823464274406433, 'player-9:history')
#     (-0.0, 0, -0.2666216790676117, 'player-9:state-active')
#     (-0.0, 0.0, -0.07654490321874619, 'player-8:history')
#     (-0.0, 0, -0.3368537724018097, 'player-8:state-active')
#     (-0.0, 0.0, -0.18969103693962097, 'player-7:history')
#     (-0.0, 0, -0.09050312638282776, 'player-7:state-active')
#     (-0.0, 0, -0.21911293268203735, 'player-6:state-fold')
#     (-0.0, 0.0, -0.27754145860671997, 'player-6:stack')
#     (-0.0, 0, -0.003028217004612088, 'player-5:state-fold')
#     (-0.0, 0, -0.12634769082069397, 'player-4:state-fold')
#     (-0.0, 0.0, -0.05259004980325699, 'player-3:history')
#     (-0.0, 0, -0.20077961683273315, 'player-3:state-fold')
#     (-0.0, 0.0, -0.04389026761054993, 'player-2:history')
#     (-0.0, 0, -0.1257881075143814, 'player-2:state-fold')
#     (0.0, 0.0, 0.13273072242736816, 'player-1:history')
#     (0.0, 0, 0.04784411936998367, 'player-1:state-fold')
#     (-0.0, 0.0, -0.1697363406419754, 'player-0:history')
#     (0.0, 0, 0.04256691783666611, 'player-0:state-fold')
#     (0.0, 0, 0.0020736893638968468, 'street-river')
#     (0.0, 0, 0.1725275069475174, 'street-turn')
#     (0.0, 0, 0.1546308994293213, 'street-flop')
#     (0.0, 0, 0.12520329654216766, 'btn distance=9')
#     (0.0, 0, 0.023359322920441628, 'btn distance=8')
#     (0.0, 0, 0.07476399093866348, 'btn distance=6')
#     (-0.0, 0, -0.22745220363140106, 'btn distance=5')
#     (0.0, 0, 0.13111388683319092, 'btn distance=4')
#     (0.0, 0, 0.12856797873973846, 'btn distance=3')
#     (-0.0, 0, -0.18685166537761688, 'btn distance=2')
#     (-0.0, 0, -0.15054799616336823, 'btn distance=1')
#     (0.0, 0, 0.19323912262916565, 'btn distance=0')
#     (-0.0, 0, -0.243196040391922, 'round level 27')
#     (-0.0, 0, -0.023156270384788513, 'round level 26')
#     (0.0, 0, 0.003470483236014843, 'round level 25')
#     (0.0, 0, 0.15401211380958557, 'round level 24')
#     (0.0, 0, 0.21780440211296082, 'round level 23')
#     (-0.0, 0, -0.22260673344135284, 'round level 22')
#     (0.0, 0, 0.05764830857515335, 'round level 21')
#     (0.0, 0, 0.2020353376865387, 'round level 20')
#     (-0.0, 0, -0.2548794448375702, 'round level 19')
#     (-0.0, 0, -0.1148628517985344, 'round level 18')
#     (0.0, 0, 0.07593721896409988, 'round level 17')
#     (0.0, 0, 0.24762311577796936, 'round level 16')
#     (-0.0, 0, -0.05122379958629608, 'round level 15')
#     (-0.0, 0, -0.004059555009007454, 'round level 14')
#     (0.0, 0, 0.16804750263690948, 'round level 13')
#     (-0.0, 0, -0.224433034658432, 'round level 12')
#     (-0.0, 0, -0.19422996044158936, 'round level 11')
#     (-0.0, 0, -0.08357469737529755, 'round level 10')
#     (0.0, 0, 0.2517589330673218, 'round level 9')
#     (0.0, 0, 0.0839981883764267, 'round level 8')
#     (0.0, 0, 0.08711250126361847, 'round level 7')
#     (0.0, 0, 0.23109890520572662, 'round level 6')
#     (-0.0, 0, -0.07619556784629822, 'round level 5')
#     (0.0, 0, 0.10016213357448578, 'round level 4')
#     (-0.0, 0, -0.2349204421043396, 'round level 3')
#     (-0.0, 0, -0.007748506497591734, 'round level 1')
