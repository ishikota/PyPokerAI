# %% [markdown]
# # 実験3 いろんなfeature表現を試す
# ## scalar feature (not scaled)

# %% [markdown]
# ## 1-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 100万
# - 5万iteration毎に敵のvalue_functionを過去のweightsのいずれかにセットし直しながらself-play
# - 計算時間 : 34221s => 9.5h
#     - aws g2.x.large上でやった

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# <img src="./resource/1round_scalar_feature_montecarlo_trash_1224_02_40_24/initial_value_transition.png" />

# %% [markdown]
# <img src="./resource/1round_scalar_feature_montecarlo_trash_1224_02_40_24/initial_value_transition_slimmed.png" />

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# <img src="./resource/1round_scalar_feature_montecarlo_trash_1224_02_40_24/1_round_3000_match_subplot_1225_17_08_34.png" />

# %% [markdown]
# <img src="./resource/1round_scalar_feature_montecarlo_trash_1224_02_40_24/1_round_3000_match_histgram_1225_17_08_34.png" />

# %% [markdown]
# # Weight analysis

# %% [markdown]
# ### 100万iteration後

# %% [raw]
# ****************************************
# After 1000000 iteration
# ****************************************
# round count
#   FOLD : 0.1006
#   CALL : -0.2268
#   MIN_RAISE : 0.0654
#   DOUBLE_RAISE : 0.0769
#   TRIPLE_RAISE : -0.3193
#   MAX_RAISE : 0.2719
# dealer button
#   FOLD : -0.0487
#   CALL : -0.4325
#   MIN_RAISE : -0.2503
#   DOUBLE_RAISE : 0.339
#   TRIPLE_RAISE : -0.3544
#   MAX_RAISE : -0.3282
# street
#   FOLD : 0.5464
#   CALL : -0.2028
#   MIN_RAISE : -0.055
#   DOUBLE_RAISE : 0.0278
#   TRIPLE_RAISE : -0.1517
#   MAX_RAISE : 0.3383
# cards
#   FOLD : 0.2226
#   CALL : 0.0025
#   MIN_RAISE : 0.1669
#   DOUBLE_RAISE : -0.0022
#   TRIPLE_RAISE : 0.2804
#   MAX_RAISE : -0.1752
# pot
#   FOLD : 0.0292
#   CALL : -0.0481
#   MIN_RAISE : 0.0502
#   DOUBLE_RAISE : 0.1715
#   TRIPLE_RAISE : -0.0687
#   MAX_RAISE : -0.149
# seats
#     player 0
#       stack : {'DOUBLE_RAISE': -0.1388, 'TRIPLE_RAISE': -0.2059, 'MAX_RAISE': -0.201, 'FOLD': 0.036, 'MIN_RAISE': 0.0783, 'CALL': -0.2087}
#       state : {'DOUBLE_RAISE': -0.18, 'TRIPLE_RAISE': -0.3133, 'MAX_RAISE': 0.0572, 'FOLD': 0.0973, 'MIN_RAISE': -0.2584, 'CALL': 0.2007}
#       history(paid sum) : {'DOUBLE_RAISE': -0.249, 'TRIPLE_RAISE': 0.1062, 'MAX_RAISE': 0.1475, 'FOLD': -0.0744, 'MIN_RAISE': 0.2874, 'CALL': -0.0407}
#     player 1
#       stack : {'DOUBLE_RAISE': -0.1944, 'TRIPLE_RAISE': -0.0542, 'MAX_RAISE': 0.0591, 'FOLD': 0.1807, 'MIN_RAISE': 0.0356, 'CALL': -0.2451}
#       state : {'DOUBLE_RAISE': 0.0168, 'TRIPLE_RAISE': -0.0302, 'MAX_RAISE': -0.081, 'FOLD': -0.0089, 'MIN_RAISE': -0.4464, 'CALL': 0.1542}
#       history(paid sum) : {'DOUBLE_RAISE': 0.2632, 'TRIPLE_RAISE': -0.1002, 'MAX_RAISE': 0.0735, 'FOLD': -0.059, 'MIN_RAISE': -0.0047, 'CALL': -0.0125}
#     player 2
#       stack : {'DOUBLE_RAISE': -0.1491, 'TRIPLE_RAISE': 0.2334, 'MAX_RAISE': 0.2016, 'FOLD': -0.1121, 'MIN_RAISE': -0.0963, 'CALL': -0.0112}
#       state : {'DOUBLE_RAISE': 0.0946, 'TRIPLE_RAISE': 0.0651, 'MAX_RAISE': -0.2097, 'FOLD': -0.1122, 'MIN_RAISE': -0.2274, 'CALL': 0.2783}
#       history(paid sum) : {'DOUBLE_RAISE': 0.1476, 'TRIPLE_RAISE': -0.1828, 'MAX_RAISE': -0.184, 'FOLD': 0.0767, 'MIN_RAISE': -0.041, 'CALL': 0.2606}
#     player 3
#       stack : {'DOUBLE_RAISE': 0.1847, 'TRIPLE_RAISE': -0.1904, 'MAX_RAISE': 0.1192, 'FOLD': -0.0526, 'MIN_RAISE': 0.0913, 'CALL': -0.1242}
#       state : {'DOUBLE_RAISE': 0.0694, 'TRIPLE_RAISE': -0.3655, 'MAX_RAISE': 0.3165, 'FOLD': 0.1065, 'MIN_RAISE': 0.223, 'CALL': 0.2328}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0489, 'TRIPLE_RAISE': -0.3416, 'MAX_RAISE': -0.2392, 'FOLD': 0.0177, 'MIN_RAISE': -0.353, 'CALL': -0.2628}
#     player 4
#       stack : {'DOUBLE_RAISE': 0.0473, 'TRIPLE_RAISE': -0.0801, 'MAX_RAISE': -0.1028, 'FOLD': -0.3326, 'MIN_RAISE': 0.0144, 'CALL': 0.1522}
#       state : {'DOUBLE_RAISE': -0.003, 'TRIPLE_RAISE': 0.1611, 'MAX_RAISE': -0.217, 'FOLD': 0.3676, 'MIN_RAISE': 0.0825, 'CALL': -0.149}
#       history(paid sum) : {'DOUBLE_RAISE': 0.2667, 'TRIPLE_RAISE': -0.0576, 'MAX_RAISE': 0.2754, 'FOLD': -0.2124, 'MIN_RAISE': -0.2852, 'CALL': 0.1094}
#     player 5
#       stack : {'DOUBLE_RAISE': -0.0344, 'TRIPLE_RAISE': -0.1341, 'MAX_RAISE': 0.0107, 'FOLD': 0.3045, 'MIN_RAISE': -0.0018, 'CALL': 0.2224}
#       state : {'DOUBLE_RAISE': 0.088, 'TRIPLE_RAISE': 0.1955, 'MAX_RAISE': 0.2828, 'FOLD': -0.0437, 'MIN_RAISE': 0.1757, 'CALL': 0.1882}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0798, 'TRIPLE_RAISE': 0.3663, 'MAX_RAISE': 0.0454, 'FOLD': 0.1236, 'MIN_RAISE': -0.0188, 'CALL': -0.199}
#     player 6
#       stack : {'DOUBLE_RAISE': 0.1725, 'TRIPLE_RAISE': -0.01, 'MAX_RAISE': 0.07, 'FOLD': -0.3419, 'MIN_RAISE': -0.3343, 'CALL': 0.0242}
#       state : {'DOUBLE_RAISE': 0.3325, 'TRIPLE_RAISE': -0.0955, 'MAX_RAISE': -0.134, 'FOLD': 0.1029, 'MIN_RAISE': 0.0762, 'CALL': -0.0221}
#       history(paid sum) : {'DOUBLE_RAISE': 0.2247, 'TRIPLE_RAISE': 0.2045, 'MAX_RAISE': 0.2639, 'FOLD': -0.241, 'MIN_RAISE': 0.1645, 'CALL': 0.2074}
#     player 7
#       stack : {'DOUBLE_RAISE': -0.2548, 'TRIPLE_RAISE': 0.2019, 'MAX_RAISE': -0.243, 'FOLD': 0.2936, 'MIN_RAISE': 0.2154, 'CALL': -0.1226}
#       state : {'DOUBLE_RAISE': -0.0738, 'TRIPLE_RAISE': 0.4285, 'MAX_RAISE': -0.2068, 'FOLD': 0.0637, 'MIN_RAISE': -0.071, 'CALL': 0.0725}
#       history(paid sum) : {'DOUBLE_RAISE': -0.4528, 'TRIPLE_RAISE': 0.0018, 'MAX_RAISE': -0.1244, 'FOLD': 0.0035, 'MIN_RAISE': 0.1303, 'CALL': 0.098}
#     player 8
#       stack : {'DOUBLE_RAISE': -0.0617, 'TRIPLE_RAISE': -0.0772, 'MAX_RAISE': -0.1215, 'FOLD': -0.1524, 'MIN_RAISE': 0.0208, 'CALL': 0.2182}
#       state : {'DOUBLE_RAISE': 0.0168, 'TRIPLE_RAISE': -0.0451, 'MAX_RAISE': 0.3738, 'FOLD': 0.0089, 'MIN_RAISE': -0.1829, 'CALL': -0.2335}
#       history(paid sum) : {'DOUBLE_RAISE': -0.3047, 'TRIPLE_RAISE': 0.3263, 'MAX_RAISE': 0.2126, 'FOLD': 0.1524, 'MIN_RAISE': -0.012, 'CALL': 0.1811}
#     player 9
#       stack : {'DOUBLE_RAISE': 0.2564, 'TRIPLE_RAISE': 0.2068, 'MAX_RAISE': 0.2212, 'FOLD': 0.1033, 'MIN_RAISE': -0.0801, 'CALL': 0.0039}
#       state : {'DOUBLE_RAISE': 0.3912, 'TRIPLE_RAISE': 0.2949, 'MAX_RAISE': -0.2801, 'FOLD': -0.1662, 'MIN_RAISE': 0.0892, 'CALL': -0.2426}
#       history(paid sum) : {'DOUBLE_RAISE': 0.104, 'TRIPLE_RAISE': 0.2355, 'MAX_RAISE': 0.2449, 'FOLD': -0.1466, 'MIN_RAISE': 0.1704, 'CALL': 0.1367}

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# - 100万iteration後の価値関数10人で対戦させる.
# - ALLIN -> FOLDでほぼ試合が決まる. CALLする人もいる.
# - stack, historyなど値が大きい要素が支配的になってしまっている.
# - 重みはstackなど大きい値に対しても,cardsなど小さい値に対しても同じくらいのscaleになってしまってる

# %% [markdown]
# ### ALLINに対してFOLD

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['H5', 'D5']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 20075, side = [{'amount': 0, 'eligibles': ['uuid-5', 'uuid-6']}, {'amount': 0, 'eligibles': ['uuid-5', 'uuid-6']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.10167340934276581), ('call', -45.26713943481445)]
# ** weights and features in detail **
# features : [1, 6, 0, 0.684, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 9975, 1, 25, 9950, 1, 50, 0, 1, 10000, 0, 1, 10000, 10000, 0, 0, 20075]
# bias : [-0.02582904 -0.11168402 -0.14239502  0.03051758 -0.0279541   0.0333252 ]
#
# linear combination for fold :
#     (-3401.5203073620796, 9950, -0.3418613374233246, 'player-6:stack')
#     (-3325.6307244300842, 10000, -0.3325630724430084, 'player-4:stack')
#     (3037.0707370340824, 9975, 0.3044682443141937, 'player-5:stack')
#     (1806.5130710601807, 10000, 0.18065130710601807, 'player-1:stack')
#     (1523.6319601535797, 10000, 0.15236319601535797, 'player-8:history')
#     (-1120.7900941371918, 10000, -0.11207900941371918, 'player-2:stack')
#     (1033.0107808113098, 10000, 0.10330107808113098, 'player-9:stack')
#     (586.7107805795968, 20075, 0.029225941747426987, 'pot')
#     (-525.5133286118507, 10000, -0.052551332861185074, 'player-3:stack')
#     (359.7653657197952, 10000, 0.03597653657197952, 'player-0:stack')
#     (35.29318142682314, 10000, 0.003529318142682314, 'player-7:history')
#     (-12.047814577817917, 50, -0.24095629155635834, 'player-6:history')
#     (3.090798854827881, 25, 0.12363195419311523, 'player-5:history')
#     (0.3676084280014038, 1, 0.3676084280014038, 'player-4:state')
#     (-0.29208163172006607, 6, -0.048680271953344345, 'btn distance')
#     (0.15226965111494065, 0.684, 0.22261644899845123, 'cards')
#     (-0.11218959838151932, 1, -0.11218959838151932, 'player-2:state')
#     (0.10653182119131088, 1, 0.10653182119131088, 'player-3:state')
#     (0.1029132828116417, 1, 0.1029132828116417, 'player-6:state')
#     (0.10058097541332245, 1, 0.10058097541332245, 'round level')
#     (0.09728144854307175, 1, 0.09728144854307175, 'player-0:state')
#
# linear combination for call :
#     (-2451.1609971523285, 10000, -0.24511609971523285, 'player-1:stack')
#     (2218.135980516672, 9975, 0.22236952185630798, 'player-5:stack')
#     (-2087.28164434433, 10000, -0.20872816443443298, 'player-0:stack')
#     (1810.508370399475, 10000, 0.1810508370399475, 'player-8:history')
#     (1522.0795571804047, 10000, 0.15220795571804047, 'player-4:stack')
#     (-1242.4366921186447, 10000, -0.12424366921186447, 'player-3:stack')
#     (980.396643280983, 10000, 0.0980396643280983, 'player-7:history')
#     (-966.0456340759993, 20075, -0.048121824860572815, 'pot')
#     (240.561038069427, 9950, 0.024176988750696182, 'player-6:stack')
#     (-112.34433390200138, 10000, -0.011234433390200138, 'player-2:stack')
#     (39.135534316301346, 10000, 0.003913553431630135, 'player-9:stack')
#     (10.369080305099487, 50, 0.20738160610198975, 'player-6:history')
#     (-4.974496737122536, 25, -0.19897986948490143, 'player-5:history')
#     (-2.595175802707672, 6, -0.4325293004512787, 'btn distance')
#     (0.2783051133155823, 1, 0.2783051133155823, 'player-2:state')
#     (-0.2335108369588852, 1, -0.2335108369588852, 'player-8:state')
#     (0.23277698457241058, 1, 0.23277698457241058, 'player-3:state')
#     (-0.22680805623531342, 1, -0.22680805623531342, 'round level')
#     (0.20072954893112183, 1, 0.20072954893112183, 'player-0:state')
#     (0.18821313977241516, 1, 0.18821313977241516, 'player-5:state')
#     (0.154216930270195, 1, 0.154216930270195, 'player-1:state')
#     (-0.14900977909564972, 1, -0.14900977909564972, 'player-4:state')
#     (-0.11168402, 0, 0, 'bias')
#     (0.07247157394886017, 1, 0.07247157394886017, 'player-7:state')
#     (-0.022066965699195862, 1, -0.022066965699195862, 'player-6:state')

# %% [markdown]
# ### ALLINに対してCALL

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['DQ', 'H7']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 30075, side = [{'amount': 0, 'eligibles': ['uuid-3', 'uuid-1', 'uuid-8']}, {'amount': 0, 'eligibles': ['uuid-3', 'uuid-1', 'uuid-8']}, {'amount': 0, 'eligibles': ['uuid-3', 'uuid-1', 'uuid-8']}]
#   - players information
#     - 0 : cpu9 (uuid-9) => state : folded, stack : 10000
#     - 1 : cpu2 (uuid-2) => state : folded, stack : 9975 <= SB
#     - 2 : agent (uuid-0) => state : participating, stack : 9950 <= BB, CURRENT
#     - 3 : cpu3 (uuid-3) => state : allin, stack : 0
#     - 4 : cpu1 (uuid-1) => state : allin, stack : 0
#     - 5 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 6 : cpu4 (uuid-4) => state : folded, stack : 10000
#     - 7 : cpu8 (uuid-8) => state : allin, stack : 0
#     - 8 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 9 : cpu7 (uuid-7) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu2 (uuid=uuid-2)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', -2181.09375), ('call', -1518.7015380859375)]
# ** weights and features in detail **
# features : [1, 2, 0, 0.634, 9950, 1, 50, 0, 1, 10000, 0, 1, 10000, 10000, 0, 0, 10000, 0, 0, 0, 1, 10000, 10000, 0, 0, 10000, 0, 0, 10000, 0, 0, 9975, 0, 0, 30075]
# bias : [-0.02582904 -0.11168402 -0.14239502  0.03051758 -0.0279541   0.0333252 ]
#
# linear combination for fold :
#     (-3418.613374233246, 10000, -0.3418613374233246, 'player-6:stack')
#     (-3325.6307244300842, 10000, -0.3325630724430084, 'player-4:stack')
#     (2935.766279697418, 10000, 0.2935766279697418, 'player-7:stack')
#     (-1524.2257714271545, 10000, -0.15242257714271545, 'player-8:stack')
#     (1236.3195419311523, 10000, 0.12363195419311523, 'player-5:history')
#     (1030.4282538592815, 9975, 0.10330107808113098, 'player-9:stack')
#     (878.9701980538666, 30075, 0.029225941747426987, 'pot')
#     (767.0465856790543, 10000, 0.07670465856790543, 'player-2:history')
#     (-589.9402871727943, 10000, -0.058994028717279434, 'player-1:history')
#     (-525.5133286118507, 10000, -0.052551332861185074, 'player-3:stack')
#     (357.96653889119625, 9950, 0.03597653657197952, 'player-0:stack')
#     (-3.7185415625572205, 50, -0.07437083125114441, 'player-0:history')
#     (0.1411388286650181, 0.634, 0.22261644899845123, 'cards')
#     (-0.11218959838151932, 1, -0.11218959838151932, 'player-2:state')
#     (0.10058097541332245, 1, 0.10058097541332245, 'round level')
#     (-0.09736054390668869, 2, -0.048680271953344345, 'btn distance')
#     (0.09728144854307175, 1, 0.09728144854307175, 'player-0:state')
#     (-0.043743908405303955, 1, -0.043743908405303955, 'player-5:state')
#     (-0.025829036, 0, 0, 'bias')
#
# linear combination for call :
#     (2605.7133078575134, 10000, 0.26057133078575134, 'player-2:history')
#     (2182.2169423103333, 10000, 0.21822169423103333, 'player-8:stack')
#     (-2076.845236122608, 9950, -0.20872816443443298, 'player-0:stack')
#     (-1989.7986948490143, 10000, -0.19897986948490143, 'player-5:history')
#     (1522.0795571804047, 10000, 0.15220795571804047, 'player-4:stack')
#     (-1447.2638826817274, 30075, -0.048121824860572815, 'pot')
#     (-1242.4366921186447, 10000, -0.12424366921186447, 'player-3:stack')
#     (-1225.678101181984, 10000, -0.1225678101181984, 'player-7:stack')
#     (241.76988750696182, 10000, 0.024176988750696182, 'player-6:stack')
#     (-125.07916428148746, 10000, -0.012507916428148746, 'player-1:history')
#     (39.03769548051059, 9975, 0.003913553431630135, 'player-9:stack')
#     (-2.0365461707115173, 50, -0.04073092341423035, 'player-0:history')
#     (-0.8650586009025574, 2, -0.4325293004512787, 'btn distance')
#     (0.2783051133155823, 1, 0.2783051133155823, 'player-2:state')
#     (-0.22680805623531342, 1, -0.22680805623531342, 'round level')
#     (0.20072954893112183, 1, 0.20072954893112183, 'player-0:state')
#     (0.18821313977241516, 1, 0.18821313977241516, 'player-5:state')
#     (0.154216930270195, 1, 0.154216930270195, 'player-1:state')
#     (-0.11168402, 0, 0, 'bias')

# %% [markdown]
# ### ALLINする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['HT', 'D6']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu7 (uuid-7) => state : participating, stack : 9975 <= SB
#     - 2 : cpu1 (uuid-1) => state : participating, stack : 9950 <= BB
#     - 3 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 4 : cpu9 (uuid-9) => state : participating, stack : 10000
#     - 5 : cpu3 (uuid-3) => state : participating, stack : 10000
#     - 6 : cpu5 (uuid-5) => state : participating, stack : 10000
#     - 7 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 8 : cpu4 (uuid-4) => state : participating, stack : 10000
#     - 9 : cpu6 (uuid-6) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 50, 'add_amount': 25}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', -737.2398071289062), ('call', -909.05859375), ('min_raise', -552.91064453125), ('double_raise', -1721.8544921875), ('triple_raise', -1092.1944580078125), ('max_raise', 133.185302734375)]
# ** weights and features in detail **
# features : [1, 3, 0, 0.609, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 9975, 1, 25, 9950, 1, 50, 75]
# bias : [-0.02582904 -0.11168402 -0.14239502  0.03051758 -0.0279541   0.0333252 ]
#
# linear combination for fold :
#     (-3418.613374233246, 10000, -0.3418613374233246, 'player-6:stack')
#     (-3325.6307244300842, 10000, -0.3325630724430084, 'player-4:stack')
#     (3044.6824431419373, 10000, 0.3044682443141937, 'player-5:stack')
#     (2935.766279697418, 10000, 0.2935766279697418, 'player-7:stack')
#     (1806.5130710601807, 10000, 0.18065130710601807, 'player-1:stack')
#     (-1520.4152069985867, 9975, -0.15242257714271545, 'player-8:stack')
#     (-1120.7900941371918, 10000, -0.11207900941371918, 'player-2:stack')
#     (1027.8457269072533, 9950, 0.10330107808113098, 'player-9:stack')
#     (-525.5133286118507, 10000, -0.052551332861185074, 'player-3:stack')
#     (359.7653657197952, 10000, 0.03597653657197952, 'player-0:stack')
#     (-7.331555336713791, 50, -0.14663110673427582, 'player-9:history')
#     (3.8090799003839493, 25, 0.15236319601535797, 'player-8:history')
#     (2.191945631057024, 75, 0.029225941747426987, 'pot')
#     (0.3676084280014038, 1, 0.3676084280014038, 'player-4:state')
#     (-0.1661682277917862, 1, -0.1661682277917862, 'player-9:state')
#     (-0.14604081586003304, 3, -0.048680271953344345, 'btn distance')
#     (0.1355734174400568, 0.609, 0.22261644899845123, 'cards')
#     (-0.11218959838151932, 1, -0.11218959838151932, 'player-2:state')
#     (0.10653182119131088, 1, 0.10653182119131088, 'player-3:state')
#     (0.1029132828116417, 1, 0.1029132828116417, 'player-6:state')
#     (0.10058097541332245, 1, 0.10058097541332245, 'round level')
#     (0.09728144854307175, 1, 0.09728144854307175, 'player-0:state')
#
# linear combination for call :
#     (-2451.1609971523285, 10000, -0.24511609971523285, 'player-1:stack')
#     (2223.69521856308, 10000, 0.22236952185630798, 'player-5:stack')
#     (2176.7613999545574, 9975, 0.21822169423103333, 'player-8:stack')
#     (-2087.28164434433, 10000, -0.20872816443443298, 'player-0:stack')
#     (1522.0795571804047, 10000, 0.15220795571804047, 'player-4:stack')
#     (-1242.4366921186447, 10000, -0.12424366921186447, 'player-3:stack')
#     (-1225.678101181984, 10000, -0.1225678101181984, 'player-7:stack')
#     (241.76988750696182, 10000, 0.024176988750696182, 'player-6:stack')
#     (-112.34433390200138, 10000, -0.011234433390200138, 'player-2:stack')
#     (38.93985664471984, 9950, 0.003913553431630135, 'player-9:stack')
#     (6.835521012544632, 50, 0.13671042025089264, 'player-9:history')
#     (4.526270925998688, 25, 0.1810508370399475, 'player-8:history')
#     (-3.609136864542961, 75, -0.048121824860572815, 'pot')
#     (-1.297587901353836, 3, -0.4325293004512787, 'btn distance')
#     (0.2783051133155823, 1, 0.2783051133155823, 'player-2:state')
#     (-0.242599219083786, 1, -0.242599219083786, 'player-9:state')
#     (-0.2335108369588852, 1, -0.2335108369588852, 'player-8:state')
#     (0.23277698457241058, 1, 0.23277698457241058, 'player-3:state')
#     (-0.22680805623531342, 1, -0.22680805623531342, 'round level')
#     (0.20072954893112183, 1, 0.20072954893112183, 'player-0:state')
#     (0.18821313977241516, 1, 0.18821313977241516, 'player-5:state')
#     (0.154216930270195, 1, 0.154216930270195, 'player-1:state')
#     (-0.14900977909564972, 1, -0.14900977909564972, 'player-4:state')
#     (-0.11168402, 0, 0, 'bias')
#     (0.07247157394886017, 1, 0.07247157394886017, 'player-7:state')
#     (-0.022066965699195862, 1, -0.022066965699195862, 'player-6:state')
#
# linear combination for min_raise :
#     (-3343.091309070587, 10000, -0.3343091309070587, 'player-6:stack')
#     (2153.5448729991913, 10000, 0.21535448729991913, 'player-7:stack')
#     (-962.6723825931549, 10000, -0.09626723825931549, 'player-2:stack')
#     (913.0260348320007, 10000, 0.09130260348320007, 'player-3:stack')
#     (-796.9439212232828, 9950, -0.08009486645460129, 'player-9:stack')
#     (783.3623886108398, 10000, 0.07833623886108398, 'player-0:stack')
#     (355.9078276157379, 10000, 0.03559078276157379, 'player-1:stack')
#     (207.1565805003047, 9975, 0.02076757699251175, 'player-8:stack')
#     (143.9804956316948, 10000, 0.01439804956316948, 'player-4:stack')
#     (-17.900036182254553, 10000, -0.0017900036182254553, 'player-5:stack')
#     (8.521319925785065, 50, 0.1704263985157013, 'player-9:history')
#     (3.7621619179844856, 75, 0.05016215890645981, 'pot')
#     (-0.7508425712585449, 3, -0.25028085708618164, 'btn distance')
#     (-0.44640809297561646, 1, -0.44640809297561646, 'player-1:state')
#     (-0.2991229295730591, 25, -0.011964917182922363, 'player-8:history')
#     (-0.2584007680416107, 1, -0.2584007680416107, 'player-0:state')
#     (-0.22736838459968567, 1, -0.22736838459968567, 'player-2:state')
#     (0.22304067015647888, 1, 0.22304067015647888, 'player-3:state')
#     (-0.18291741609573364, 1, -0.18291741609573364, 'player-8:state')
#     (0.1757383942604065, 1, 0.1757383942604065, 'player-5:state')
#     (-0.14239502, 0, 0, 'bias')
#     (0.10164258639514447, 0.609, 0.16690079867839813, 'cards')
#     (0.08924590796232224, 1, 0.08924590796232224, 'player-9:state')
#     (0.08247970044612885, 1, 0.08247970044612885, 'player-4:state')
#     (0.07622965425252914, 1, 0.07622965425252914, 'player-6:state')
#
# linear combination for double_raise :
#     (2551.1416390538216, 9950, 0.2563961446285248, 'player-9:stack')
#     (-2548.319101333618, 10000, -0.2548319101333618, 'player-7:stack')
#     (-1944.4435834884644, 10000, -0.19444435834884644, 'player-1:stack')
#     (1847.4127352237701, 10000, 0.18474127352237701, 'player-3:stack')
#     (1725.1741886138916, 10000, 0.17251741886138916, 'player-6:stack')
#     (-1490.6851947307587, 10000, -0.14906851947307587, 'player-2:stack')
#     (-1387.8177106380463, 10000, -0.13878177106380463, 'player-0:stack')
#     (-615.5873869545758, 9975, -0.061713021248579025, 'player-8:stack')
#     (473.04701060056686, 10000, 0.047304701060056686, 'player-4:stack')
#     (-344.09884363412857, 10000, -0.03440988436341286, 'player-5:stack')
#     (12.86337710916996, 75, 0.1715116947889328, 'pot')
#     (-7.616487890481949, 25, -0.30465951561927795, 'player-8:history')
#     (5.199719220399857, 50, 0.10399438440799713, 'player-9:history')
#     (1.0168791711330414, 3, 0.3389597237110138, 'btn distance')
#     (0.3912465572357178, 1, 0.3912465572357178, 'player-9:state')
#     (0.332505464553833, 1, 0.332505464553833, 'player-6:state')
#     (-0.18001742660999298, 1, -0.18001742660999298, 'player-0:state')
#     (0.09462222456932068, 1, 0.09462222456932068, 'player-2:state')
#     (0.08799289911985397, 1, 0.08799289911985397, 'player-5:state')
#     (0.07689426094293594, 1, 0.07689426094293594, 'round level')
#     (-0.07382427155971527, 1, -0.07382427155971527, 'player-7:state')
#     (0.06938382983207703, 1, 0.06938382983207703, 'player-3:state')
#     (0.030517578, 0, 0, 'bias')
#     (0.016795257106423378, 1, 0.016795257106423378, 'player-1:state')
#     (0.016767339780926704, 1, 0.016767339780926704, 'player-8:state')
#
# linear combination for triple_raise :
#     (2333.7504267692566, 10000, 0.23337504267692566, 'player-2:stack')
#     (-2058.6296916007996, 10000, -0.20586296916007996, 'player-0:stack')
#     (2057.543896138668, 9950, 0.2067883312702179, 'player-9:stack')
#     (2019.038200378418, 10000, 0.2019038200378418, 'player-7:stack')
#     (-1903.7744402885437, 10000, -0.19037744402885437, 'player-3:stack')
#     (-1341.218501329422, 10000, -0.1341218501329422, 'player-5:stack')
#     (-801.2343943119049, 10000, -0.08012343943119049, 'player-4:stack')
#     (-769.6620896458626, 9975, -0.0771591067314148, 'player-8:stack')
#     (-542.2648414969444, 10000, -0.05422648414969444, 'player-1:stack')
#     (-99.5775405317545, 10000, -0.00995775405317545, 'player-6:stack')
#     (11.774099618196487, 50, 0.23548199236392975, 'player-9:history')
#     (8.157240599393845, 25, 0.3262896239757538, 'player-8:history')
#     (-5.152829177677631, 75, -0.06870438903570175, 'pot')
#     (-1.0632745921611786, 3, -0.3544248640537262, 'btn distance')
#     (0.4285110831260681, 1, 0.4285110831260681, 'player-7:state')
#     (-0.3655012547969818, 1, -0.3655012547969818, 'player-3:state')
#     (-0.31927505135536194, 1, -0.31927505135536194, 'round level')
#     (-0.31334879994392395, 1, -0.31334879994392395, 'player-0:state')
#     (0.29491081833839417, 1, 0.29491081833839417, 'player-9:state')
#     (0.1955157220363617, 1, 0.1955157220363617, 'player-5:state')
#     (0.17078908690810204, 0.609, 0.28044185042381287, 'cards')
#     (0.16112683713436127, 1, 0.16112683713436127, 'player-4:state')
#     (-0.09550351649522781, 1, -0.09550351649522781, 'player-6:state')
#     (0.06509168446063995, 1, 0.06509168446063995, 'player-2:state')
#     (-0.045064959675073624, 1, -0.045064959675073624, 'player-8:state')
#     (-0.030168231576681137, 1, -0.030168231576681137, 'player-1:state')
#     (-0.027954102, 0, 0, 'bias')
#
# linear combination for max_raise :
#     (-2430.0968647003174, 10000, -0.24300968647003174, 'player-7:stack')
#     (2200.593691319227, 9950, 0.22116519510746002, 'player-9:stack')
#     (2016.0384476184845, 10000, 0.20160384476184845, 'player-2:stack')
#     (-2009.6686482429504, 10000, -0.20096686482429504, 'player-0:stack')
#     (-1211.930100247264, 9975, -0.12149675190448761, 'player-8:stack')
#     (1192.4778670072556, 10000, 0.11924778670072556, 'player-3:stack')
#     (-1027.8527438640594, 10000, -0.10278527438640594, 'player-4:stack')
#     (699.74385201931, 10000, 0.069974385201931, 'player-6:stack')
#     (591.1856517195702, 10000, 0.059118565171957016, 'player-1:stack')
#     (107.19187557697296, 10000, 0.010719187557697296, 'player-5:stack')
#     (12.24466785788536, 50, 0.24489335715770721, 'player-9:history')
#     (-11.174118518829346, 75, -0.1489882469177246, 'pot')
#     (5.316226929426193, 25, 0.21264907717704773, 'player-8:history')
#     (-0.9846747815608978, 3, -0.32822492718696594, 'btn distance')
#     (0.3737882077693939, 1, 0.3737882077693939, 'player-8:state')
#     (0.3165394961833954, 1, 0.3165394961833954, 'player-3:state')
#     (0.28279805183410645, 1, 0.28279805183410645, 'player-5:state')
#     (-0.2801085114479065, 1, -0.2801085114479065, 'player-9:state')
#     (0.27185556292533875, 1, 0.27185556292533875, 'round level')
#     (-0.21696385741233826, 1, -0.21696385741233826, 'player-4:state')
#     (-0.20966623723506927, 1, -0.20966623723506927, 'player-2:state')
#     (-0.2068101316690445, 1, -0.2068101316690445, 'player-7:state')
#     (-0.1340475082397461, 1, -0.1340475082397461, 'player-6:state')
#     (-0.10671030355989933, 0.609, -0.17522217333316803, 'cards')
