# %% [markdown]
# # 実験3 いろんなfeature表現を試す
# ## scalar feature (not scaled)

# %% [markdown]
# ## 3-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 100万
# - 5万iteration毎に敵のvalue_functionを過去のweightsのいずれかにセットし直しながらself-play
# - 計算時間 : 83653s => 23.2h
#     - aws g2.x.large上でやった

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# <img src="./resource/3round_scalar_feature_montecarlo_trash_1224_02_46_55/initial_value_transition.png" />

# %% [markdown]
# <img src="./resource/3round_scalar_feature_montecarlo_trash_1224_02_46_55/initial_value_transition_slimmed.png" />

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# <img src="./resource/3round_scalar_feature_montecarlo_trash_1224_02_46_55/3_round_3000_match_subplot_1225_17_38_33.png" />

# %% [markdown]
# <img src="./resource/3round_scalar_feature_montecarlo_trash_1224_02_46_55/3_round_3000_match_histgram_1225_17_38_33.png" />

# %% [markdown]
# # Weight analysis

# %% [markdown]
# ### 100万iteration後

# %% [raw]
# ****************************************
# After 1000000 iteration
# ****************************************
# round count
#   FOLD : -2.1256
#   CALL : -2.8628
#   MIN_RAISE : -3.3813
#   DOUBLE_RAISE : -1.7486
#   TRIPLE_RAISE : -2.106
#   MAX_RAISE : -0.8296
# dealer button
#   FOLD : 17.2029
#   CALL : -0.9498
#   MIN_RAISE : 4.8833
#   DOUBLE_RAISE : 6.1132
#   TRIPLE_RAISE : 5.3333
#   MAX_RAISE : -0.0345
# street
#   FOLD : 28.4405
#   CALL : 9.7553
#   MIN_RAISE : 19.6434
#   DOUBLE_RAISE : 9.7224
#   TRIPLE_RAISE : 13.3788
#   MAX_RAISE : 27.8818
# cards
#   FOLD : -2.3802
#   CALL : -1.9131
#   MIN_RAISE : -4.1725
#   DOUBLE_RAISE : -2.9503
#   TRIPLE_RAISE : -2.6678
#   MAX_RAISE : -1.8967
# pot
#   FOLD : -0.2702
#   CALL : -0.0323
#   MIN_RAISE : -0.1218
#   DOUBLE_RAISE : 0.0295
#   TRIPLE_RAISE : -0.0708
#   MAX_RAISE : -0.1951
# seats
#     player 0
#       stack : {'DOUBLE_RAISE': -0.0003, 'TRIPLE_RAISE': -0.0142, 'MAX_RAISE': 0.0047, 'FOLD': -0.0205, 'MIN_RAISE': -0.0156, 'CALL': 0.0101}
#       state : {'DOUBLE_RAISE': -1.931, 'TRIPLE_RAISE': -2.1822, 'MAX_RAISE': -0.7758, 'FOLD': -1.572, 'MIN_RAISE': -3.1594, 'CALL': -2.6422}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0582, 'TRIPLE_RAISE': -0.0824, 'MAX_RAISE': 0.1889, 'FOLD': 0.2748, 'MIN_RAISE': 0.1459, 'CALL': 0.0204}
#     player 1
#       stack : {'DOUBLE_RAISE': 0.0125, 'TRIPLE_RAISE': -0.0069, 'MAX_RAISE': 0.0064, 'FOLD': 0.0073, 'MIN_RAISE': -0.0002, 'CALL': -0.0132}
#       state : {'DOUBLE_RAISE': 17.748, 'TRIPLE_RAISE': 19.1879, 'MAX_RAISE': 5.6587, 'FOLD': 21.8096, 'MIN_RAISE': 18.8312, 'CALL': 14.0992}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0342, 'TRIPLE_RAISE': 0.0459, 'MAX_RAISE': 0.2254, 'FOLD': 0.3138, 'MIN_RAISE': 0.1068, 'CALL': 0.0397}
#     player 2
#       stack : {'DOUBLE_RAISE': -0.0144, 'TRIPLE_RAISE': -0.0124, 'MAX_RAISE': -0.0133, 'FOLD': -0.0062, 'MIN_RAISE': -0.0046, 'CALL': 0.0075}
#       state : {'DOUBLE_RAISE': 8.9657, 'TRIPLE_RAISE': 5.0171, 'MAX_RAISE': -5.7883, 'FOLD': -0.6986, 'MIN_RAISE': 7.7875, 'CALL': 5.7296}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0766, 'TRIPLE_RAISE': 0.0672, 'MAX_RAISE': 0.2394, 'FOLD': 0.2709, 'MIN_RAISE': 0.1253, 'CALL': 0.0423}
#     player 3
#       stack : {'DOUBLE_RAISE': 0.0034, 'TRIPLE_RAISE': -0.0077, 'MAX_RAISE': -0.0036, 'FOLD': -0.0148, 'MIN_RAISE': 0.0072, 'CALL': -0.0}
#       state : {'DOUBLE_RAISE': 17.782, 'TRIPLE_RAISE': 17.1126, 'MAX_RAISE': 6.9424, 'FOLD': 13.2779, 'MIN_RAISE': 17.2273, 'CALL': 12.9669}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0726, 'TRIPLE_RAISE': 0.0031, 'MAX_RAISE': 0.1971, 'FOLD': 0.2633, 'MIN_RAISE': -0.0768, 'CALL': 0.041}
#     player 4
#       stack : {'DOUBLE_RAISE': 0.0024, 'TRIPLE_RAISE': 0.0325, 'MAX_RAISE': 0.006, 'FOLD': -0.0133, 'MIN_RAISE': -0.0018, 'CALL': -0.0206}
#       state : {'DOUBLE_RAISE': 8.5913, 'TRIPLE_RAISE': 5.0535, 'MAX_RAISE': -7.486, 'FOLD': -1.9896, 'MIN_RAISE': 7.8831, 'CALL': 3.42}
#       history(paid sum) : {'DOUBLE_RAISE': -0.1344, 'TRIPLE_RAISE': 0.0739, 'MAX_RAISE': 0.2368, 'FOLD': 0.2481, 'MIN_RAISE': 0.1364, 'CALL': 0.0058}
#     player 5
#       stack : {'DOUBLE_RAISE': 0.0011, 'TRIPLE_RAISE': -0.0207, 'MAX_RAISE': -0.0006, 'FOLD': 0.0005, 'MIN_RAISE': -0.0249, 'CALL': 0.0036}
#       state : {'DOUBLE_RAISE': 9.909, 'TRIPLE_RAISE': 8.7246, 'MAX_RAISE': -0.4335, 'FOLD': 7.4451, 'MIN_RAISE': 8.1429, 'CALL': 2.0284}
#       history(paid sum) : {'DOUBLE_RAISE': -0.119, 'TRIPLE_RAISE': -0.0677, 'MAX_RAISE': 0.192, 'FOLD': 0.2733, 'MIN_RAISE': 0.0878, 'CALL': 0.0499}
#     player 6
#       stack : {'DOUBLE_RAISE': -0.0032, 'TRIPLE_RAISE': -0.0074, 'MAX_RAISE': 0.0101, 'FOLD': 0.0049, 'MIN_RAISE': 0.0017, 'CALL': -0.0031}
#       state : {'DOUBLE_RAISE': 14.2369, 'TRIPLE_RAISE': 13.5881, 'MAX_RAISE': 2.2646, 'FOLD': 18.3972, 'MIN_RAISE': 16.6065, 'CALL': 12.1684}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0562, 'TRIPLE_RAISE': 0.1385, 'MAX_RAISE': 0.1994, 'FOLD': 0.2499, 'MIN_RAISE': 0.0595, 'CALL': 0.0118}
#     player 7
#       stack : {'DOUBLE_RAISE': 0.0101, 'TRIPLE_RAISE': -0.0095, 'MAX_RAISE': -0.0017, 'FOLD': -0.0097, 'MIN_RAISE': -0.0025, 'CALL': -0.0031}
#       state : {'DOUBLE_RAISE': 9.4087, 'TRIPLE_RAISE': 10.1443, 'MAX_RAISE': 3.3844, 'FOLD': 5.7216, 'MIN_RAISE': 12.8648, 'CALL': 7.3424}
#       history(paid sum) : {'DOUBLE_RAISE': 0.0504, 'TRIPLE_RAISE': 0.1745, 'MAX_RAISE': 0.2998, 'FOLD': 0.2551, 'MIN_RAISE': 0.141, 'CALL': 0.0417}
#     player 8
#       stack : {'DOUBLE_RAISE': -0.0059, 'TRIPLE_RAISE': -0.0072, 'MAX_RAISE': 0.0033, 'FOLD': -0.0011, 'MIN_RAISE': -0.0056, 'CALL': 0.0022}
#       state : {'DOUBLE_RAISE': -3.6068, 'TRIPLE_RAISE': -3.2877, 'MAX_RAISE': -10.3181, 'FOLD': -14.4981, 'MIN_RAISE': -4.4657, 'CALL': -9.1136}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0358, 'TRIPLE_RAISE': 0.0197, 'MAX_RAISE': 0.2024, 'FOLD': 0.2725, 'MIN_RAISE': 0.1243, 'CALL': 0.0141}
#     player 9
#       stack : {'DOUBLE_RAISE': -0.0156, 'TRIPLE_RAISE': -0.0332, 'MAX_RAISE': -0.0123, 'FOLD': -0.0018, 'MIN_RAISE': -0.0091, 'CALL': -0.0097}
#       state : {'DOUBLE_RAISE': -13.9944, 'TRIPLE_RAISE': -13.3377, 'MAX_RAISE': -10.1349, 'FOLD': -8.0032, 'MIN_RAISE': -14.1063, 'CALL': -10.4201}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0038, 'TRIPLE_RAISE': 0.0411, 'MAX_RAISE': 0.1823, 'FOLD': 0.2672, 'MIN_RAISE': 0.105, 'CALL': 0.0323}

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# - 100万iteration後の価値関数10人で対戦させる.
# - 席を変えないと同じプレイ (みんなRAISEしていって,ALLINになったらFOLD)
#     - 一応potが大きくなったらFOLDが強くなる.とはなってる
# - stack, historyなど値が大きい要素が支配的になってしまっている.
# - 1,2-roundと同じような結果

# %% [markdown]
# ### ALLIN に FOLD する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['D7', 'C8']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 95800, side = [{'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-9', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : allin, stack : 0
#     - 1 : cpu9 (uuid-9) => state : allin, stack : 0 <= SB
#     - 2 : cpu4 (uuid-4) => state : allin, stack : 0 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 4200 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : allin, stack : 0
#     - 8 : cpu2 (uuid-2) => state : allin, stack : 0
#     - 9 : cpu3 (uuid-3) => state : allin, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 500, 'action': 'RAISE'}
#       - {'add_amount': 1200, 'paid': 1700, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 1700, 'action': 'RAISE'}
#       - {'add_amount': 4100, 'paid': 5800, 'player': 'agent (uuid=uuid-0)', 'amount': 5800, 'action': 'RAISE'}
#       - {'add_amount': 4200, 'paid': 10000, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu2 (uuid=uuid-2)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'CALL', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'CALL', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 10000, 'paid': 9975}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 10000, 'paid': 9950}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'paid': 9850}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'paid': 9500}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'paid': 8300}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', -100.25920104980469), ('call', -126.40084838867188)]
# ** weights and features in detail **
# features : [1, 6, 0, 0.613, 4200, 1, 5800, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 95800]
# bias : [-1.91349554 -2.5890789  -3.26634741 -1.77870572 -2.12701964 -1.1205889 ]
#
# linear combination for fold :
#     (-25887.78515458107, 95800, -0.2702274024486542, 'pot')
#     (3138.3270025253296, 10000, 0.31383270025253296, 'player-1:history')
#     (2733.435332775116, 10000, 0.2733435332775116, 'player-5:history')
#     (2724.8433232307434, 10000, 0.27248433232307434, 'player-8:history')
#     (2709.455192089081, 10000, 0.2709455192089081, 'player-2:history')
#     (2671.8753576278687, 10000, 0.26718753576278687, 'player-9:history')
#     (2633.2220435142517, 10000, 0.26332220435142517, 'player-3:history')
#     (2551.3699650764465, 10000, 0.25513699650764465, 'player-7:history')
#     (2498.8093972206116, 10000, 0.24988093972206116, 'player-6:history')
#     (2481.105476617813, 10000, 0.2481105476617813, 'player-4:history')
#     (1593.5620665550232, 5800, 0.27475208044052124, 'player-0:history')
#     (103.21735382080078, 6, 17.202892303466797, 'btn distance')
#     (-86.08780615031719, 4200, -0.020497096702456474, 'player-0:stack')
#     (21.809558868408203, 1, 21.809558868408203, 'player-1:state')
#     (18.397220611572266, 1, 18.397220611572266, 'player-6:state')
#     (-14.498130798339844, 1, -14.498130798339844, 'player-8:state')
#     (13.277877807617188, 1, 13.277877807617188, 'player-3:state')
#     (-8.003195762634277, 1, -8.003195762634277, 'player-9:state')
#     (7.445101261138916, 1, 7.445101261138916, 'player-5:state')
#     (5.721554756164551, 1, 5.721554756164551, 'player-7:state')
#     (-2.1255996227264404, 1, -2.1255996227264404, 'round level')
#     (-1.9895706176757812, 1, -1.9895706176757812, 'player-4:state')
#     (-1.9134955, 0, 0, 'bias')
#     (-1.5719746351242065, 1, -1.5719746351242065, 'player-0:state')
#     (-1.4590742363929747, 0.613, -2.380218982696533, 'cards')
#     (-0.6986337900161743, 1, -0.6986337900161743, 'player-2:state')
#
# linear combination for call :
#     (-3096.2520964443684, 95800, -0.03231995925307274, 'pot')
#     (498.97775053977966, 10000, 0.049897775053977966, 'player-5:history')
#     (422.5863888859749, 10000, 0.04225863888859749, 'player-2:history')
#     (416.50060564279556, 10000, 0.041650060564279556, 'player-7:history')
#     (410.25470942258835, 10000, 0.041025470942258835, 'player-3:history')
#     (397.44142442941666, 10000, 0.039744142442941666, 'player-1:history')
#     (323.3344852924347, 10000, 0.03233344852924347, 'player-9:history')
#     (140.98013751208782, 10000, 0.014098013751208782, 'player-8:history')
#     (118.39368306100368, 5800, 0.020412703976035118, 'player-0:history')
#     (117.7879050374031, 10000, 0.01177879050374031, 'player-6:history')
#     (58.07292181998491, 10000, 0.005807292181998491, 'player-4:history')
#     (42.26599261164665, 4200, 0.010063331574201584, 'player-0:stack')
#     (14.099238395690918, 1, 14.099238395690918, 'player-1:state')
#     (12.966889381408691, 1, 12.966889381408691, 'player-3:state')
#     (12.168386459350586, 1, 12.168386459350586, 'player-6:state')
#     (-10.420100212097168, 1, -10.420100212097168, 'player-9:state')
#     (-9.113622665405273, 1, -9.113622665405273, 'player-8:state')
#     (7.342386245727539, 1, 7.342386245727539, 'player-7:state')
#     (5.729604721069336, 1, 5.729604721069336, 'player-2:state')
#     (-5.698982834815979, 6, -0.9498304724693298, 'btn distance')
#     (3.4200077056884766, 1, 3.4200077056884766, 'player-4:state')
#     (-2.8627536296844482, 1, -2.8627536296844482, 'round level')
#     (-2.6422207355499268, 1, -2.6422207355499268, 'player-0:state')
#     (-2.5890789, 0, 0, 'bias')
#     (2.0283594131469727, 1, 2.0283594131469727, 'player-5:state')
#     (-1.1727288410663606, 0.613, -1.913097620010376, 'cards')

# %% [markdown]
# ### DOUBLE_RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 1700
#   - raise: [2900, 10000]
# -- hole card --
#   - ['ST', 'H8']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 2425, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9850
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9500
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 8300
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 500, 'action': 'RAISE'}
#       - {'add_amount': 1200, 'paid': 1700, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 1700, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 5800 (double_raise) ] at round 1
#   => [('fold', -412.04534912109375), ('call', -232.30186462402344), ('min_raise', -475.0249938964844), ('double_raise', 76.26396179199219), ('triple_raise', -777.66943359375), ('max_raise', -13.918745994567871)]
# ** weights and features in detail **
# features : [1, 6, 0, 0.625, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 9975, 1, 25, 9950, 1, 50, 9850, 1, 150, 9500, 1, 500, 8300, 1, 1700, 2425]
# bias : [-1.91349554 -2.5890789  -3.26634741 -1.77870572 -2.12701964 -1.1205889 ]
#
# linear combination for fold :
#     (-655.3014509379864, 2425, -0.2702274024486542, 'pot')
#     (454.21881079673767, 1700, 0.26718753576278687, 'player-9:history')
#     (-204.97096702456474, 10000, -0.020497096702456474, 'player-0:stack')
#     (-148.14309775829315, 10000, -0.014814309775829315, 'player-3:stack')
#     (136.24216616153717, 500, 0.27248433232307434, 'player-8:history')
#     (-133.2798320800066, 10000, -0.01332798320800066, 'player-4:stack')
#     (103.21735382080078, 6, 17.202892303466797, 'btn distance')
#     (-96.01151337847114, 9850, -0.00974736176431179, 'player-7:stack')
#     (73.36862850934267, 10000, 0.007336862850934267, 'player-1:stack')
#     (-62.11313419044018, 10000, -0.006211313419044018, 'player-2:stack')
#     (48.84263074491173, 9950, 0.00490880711004138, 'player-6:stack')
#     (38.2705494761467, 150, 0.25513699650764465, 'player-7:history')
#     (21.809558868408203, 1, 21.809558868408203, 'player-1:state')
#     (18.397220611572266, 1, 18.397220611572266, 'player-6:state')
#     (-14.926070324145257, 8300, -0.0017983217258006334, 'player-9:stack')
#     (-14.498130798339844, 1, -14.498130798339844, 'player-8:state')
#     (13.277877807617188, 1, 13.277877807617188, 'player-3:state')
#     (12.494046986103058, 50, 0.24988093972206116, 'player-6:history')
#     (-10.634234989993274, 9500, -0.0011193931568413973, 'player-8:stack')
#     (-8.003195762634277, 1, -8.003195762634277, 'player-9:state')
#     (7.445101261138916, 1, 7.445101261138916, 'player-5:state')
#     (6.83358833193779, 25, 0.2733435332775116, 'player-5:history')
#     (5.721554756164551, 1, 5.721554756164551, 'player-7:state')
#     (5.484066253120545, 9975, 0.0005497810780070722, 'player-5:stack')
#     (-2.1255996227264404, 1, -2.1255996227264404, 'round level')
#     (-1.9895706176757812, 1, -1.9895706176757812, 'player-4:state')
#     (-1.9134955, 0, 0, 'bias')
#     (-1.5719746351242065, 1, -1.5719746351242065, 'player-0:state')
#     (-1.4876368641853333, 0.625, -2.380218982696533, 'cards')
#     (-0.6986337900161743, 1, -0.6986337900161743, 'player-2:state')
#
# linear combination for call :
#     (-206.19980990886688, 10000, -0.020619980990886688, 'player-4:stack')
#     (-132.48508796095848, 10000, -0.013248508796095848, 'player-1:stack')
#     (100.63331574201584, 10000, 0.010063331574201584, 'player-0:stack')
#     (-80.6516851298511, 8300, -0.009717070497572422, 'player-9:stack')
#     (-78.37590118870139, 2425, -0.03231995925307274, 'pot')
#     (75.44589228928089, 10000, 0.007544589228928089, 'player-2:stack')
#     (54.9668624997139, 1700, 0.03233344852924347, 'player-9:history')
#     (36.033506848616526, 9975, 0.00361238163895905, 'player-5:stack')
#     (-30.7323808548972, 9950, -0.0030886814929544926, 'player-6:stack')
#     (-30.234577029477805, 9850, -0.003069500206038356, 'player-7:stack')
#     (21.31246670614928, 9500, 0.0022434175480157137, 'player-8:stack')
#     (14.099238395690918, 1, 14.099238395690918, 'player-1:state')
#     (12.966889381408691, 1, 12.966889381408691, 'player-3:state')
#     (12.168386459350586, 1, 12.168386459350586, 'player-6:state')
#     (-10.420100212097168, 1, -10.420100212097168, 'player-9:state')
#     (-9.113622665405273, 1, -9.113622665405273, 'player-8:state')
#     (7.342386245727539, 1, 7.342386245727539, 'player-7:state')
#     (7.049006875604391, 500, 0.014098013751208782, 'player-8:history')
#     (6.247509084641933, 150, 0.041650060564279556, 'player-7:history')
#     (5.729604721069336, 1, 5.729604721069336, 'player-2:state')
#     (-5.698982834815979, 6, -0.9498304724693298, 'btn distance')
#     (3.4200077056884766, 1, 3.4200077056884766, 'player-4:state')
#     (-2.8627536296844482, 1, -2.8627536296844482, 'round level')
#     (-2.6422207355499268, 1, -2.6422207355499268, 'player-0:state')
#     (-2.5890789, 0, 0, 'bias')
#     (2.0283594131469727, 1, 2.0283594131469727, 'player-5:state')
#     (1.2474443763494492, 25, 0.049897775053977966, 'player-5:history')
#     (-1.195686012506485, 0.625, -1.913097620010376, 'cards')
#     (0.5889395251870155, 50, 0.01177879050374031, 'player-6:history')
#     (-0.3797626050072722, 10000, -3.797626050072722e-05, 'player-3:stack')
#
# linear combination for min_raise :
#     (-295.44456508010626, 2425, -0.12183281034231186, 'pot')
#     (-248.38631227612495, 9975, -0.024900883436203003, 'player-5:stack')
#     (178.49451005458832, 1700, 0.10499677062034607, 'player-9:history')
#     (-155.51789663732052, 10000, -0.015551789663732052, 'player-0:stack')
#     (-75.42581846937537, 8300, -0.009087448008358479, 'player-9:stack')
#     (72.42737337946892, 10000, 0.007242737337946892, 'player-3:stack')
#     (62.13457137346268, 500, 0.12426914274692535, 'player-8:history')
#     (-53.58331883326173, 9500, -0.005640349350869656, 'player-8:stack')
#     (-46.302671544253826, 10000, -0.004630267154425383, 'player-2:stack')
#     (29.29976463317871, 6, 4.883294105529785, 'btn distance')
#     (-24.968410446308553, 9850, -0.002534864004701376, 'player-7:stack')
#     (21.156933903694153, 150, 0.14104622602462769, 'player-7:history')
#     (18.831239700317383, 1, 18.831239700317383, 'player-1:state')
#     (-17.599014099687338, 10000, -0.0017599014099687338, 'player-4:stack')
#     (17.227312088012695, 1, 17.227312088012695, 'player-3:state')
#     (16.77510493900627, 9950, 0.001685940194875002, 'player-6:stack')
#     (16.606454849243164, 1, 16.606454849243164, 'player-6:state')
#     (-14.106328964233398, 1, -14.106328964233398, 'player-9:state')
#     (12.864800453186035, 1, 12.864800453186035, 'player-7:state')
#     (8.14291000366211, 1, 8.14291000366211, 'player-5:state')
#     (7.883059978485107, 1, 7.883059978485107, 'player-4:state')
#     (7.787469387054443, 1, 7.787469387054443, 'player-2:state')
#     (-4.465710163116455, 1, -4.465710163116455, 'player-8:state')
#     (-3.3812899589538574, 1, -3.3812899589538574, 'round level')
#     (-3.2663474, 0, 0, 'bias')
#     (-3.159418821334839, 1, -3.159418821334839, 'player-0:state')
#     (2.9732264578342438, 50, 0.059464529156684875, 'player-6:history')
#     (-2.6078087091445923, 0.625, -4.172493934631348, 'cards')
#     (2.194257453083992, 25, 0.08777029812335968, 'player-5:history')
#     (-1.6090486315079033, 10000, -0.00016090486315079033, 'player-1:stack')
#
# linear combination for double_raise :
#     (-143.77199113368988, 10000, -0.014377199113368988, 'player-2:stack')
#     (-129.5419754460454, 8300, -0.015607466921210289, 'player-9:stack')
#     (124.78596530854702, 10000, 0.012478596530854702, 'player-1:stack')
#     (99.22504588030279, 9850, 0.010073608718812466, 'player-7:stack')
#     (71.55384263023734, 2425, 0.029506739228963852, 'pot')
#     (-55.84661429747939, 9500, -0.005878590978682041, 'player-8:stack')
#     (36.67935276031494, 6, 6.11322546005249, 'btn distance')
#     (33.5565535351634, 10000, 0.0033556553535163403, 'player-3:stack')
#     (-32.31699818279594, 9950, -0.0032479395158588886, 'player-6:stack')
#     (24.273351300507784, 10000, 0.0024273351300507784, 'player-4:stack')
#     (-17.92377047240734, 500, -0.03584754094481468, 'player-8:history')
#     (17.78204345703125, 1, 17.78204345703125, 'player-3:state')
#     (17.748003005981445, 1, 17.748003005981445, 'player-1:state')
#     (14.23690414428711, 1, 14.23690414428711, 'player-6:state')
#     (-13.994378089904785, 1, -13.994378089904785, 'player-9:state')
#     (11.09862484736368, 9975, 0.0011126440949738026, 'player-5:stack')
#     (9.909022331237793, 1, 9.909022331237793, 'player-5:state')
#     (9.4087495803833, 1, 9.4087495803833, 'player-7:state')
#     (8.96573257446289, 1, 8.96573257446289, 'player-2:state')
#     (8.591320037841797, 1, 8.591320037841797, 'player-4:state')
#     (7.563130371272564, 150, 0.05042086914181709, 'player-7:history')
#     (-6.485249754041433, 1700, -0.003814852796494961, 'player-9:history')
#     (-3.606846332550049, 1, -3.606846332550049, 'player-8:state')
#     (-2.975733205676079, 25, -0.11902932822704315, 'player-5:history')
#     (-2.809288166463375, 50, -0.0561857633292675, 'player-6:history')
#     (-2.5386124616488814, 10000, -0.00025386124616488814, 'player-0:stack')
#     (-1.9310275316238403, 1, -1.9310275316238403, 'player-0:state')
#     (-1.8439081311225891, 0.625, -2.9502530097961426, 'cards')
#     (-1.7787057, 0, 0, 'bias')
#     (-1.7485724687576294, 1, -1.7485724687576294, 'round level')
#
# linear combination for triple_raise :
#     (325.0828757882118, 10000, 0.03250828757882118, 'player-4:stack')
#     (-275.6516732275486, 8300, -0.03321104496717453, 'player-9:stack')
#     (-206.37308531440794, 9975, -0.02068903110921383, 'player-5:stack')
#     (-171.5787187218666, 2425, -0.07075411081314087, 'pot')
#     (-141.7248509824276, 10000, -0.01417248509824276, 'player-0:stack')
#     (-123.57929721474648, 10000, -0.012357929721474648, 'player-2:stack')
#     (-93.56514462269843, 9850, -0.009498999454081059, 'player-7:stack')
#     (-77.0092150196433, 10000, -0.007700921501964331, 'player-3:stack')
#     (-73.95336937624961, 9950, -0.007432499434798956, 'player-6:stack')
#     (69.89955455064774, 1700, 0.041117385029792786, 'player-9:history')
#     (-68.55055689811707, 10000, -0.0068550556898117065, 'player-1:stack')
#     (-68.04180960170925, 9500, -0.007162295747548342, 'player-8:stack')
#     (31.999774932861328, 6, 5.333295822143555, 'btn distance')
#     (26.16851180791855, 150, 0.17445674538612366, 'player-7:history')
#     (19.187915802001953, 1, 19.187915802001953, 'player-1:state')
#     (17.112611770629883, 1, 17.112611770629883, 'player-3:state')
#     (13.588098526000977, 1, 13.588098526000977, 'player-6:state')
#     (-13.337702751159668, 1, -13.337702751159668, 'player-9:state')
#     (10.144253730773926, 1, 10.144253730773926, 'player-7:state')
#     (9.855334646999836, 500, 0.019710669293999672, 'player-8:history')
#     (8.724634170532227, 1, 8.724634170532227, 'player-5:state')
#     (6.924968957901001, 50, 0.13849937915802002, 'player-6:history')
#     (5.053474426269531, 1, 5.053474426269531, 'player-4:state')
#     (5.017087936401367, 1, 5.017087936401367, 'player-2:state')
#     (-3.287733316421509, 1, -3.287733316421509, 'player-8:state')
#     (-2.1822237968444824, 1, -2.1822237968444824, 'player-0:state')
#     (-2.1270196, 0, 0, 'bias')
#     (-2.106022357940674, 1, -2.106022357940674, 'round level')
#     (-1.6927018761634827, 25, -0.0677080750465393, 'player-5:history')
#     (-1.667390614748001, 0.625, -2.6678249835968018, 'cards')
#
# linear combination for max_raise :
#     (-473.02046343684196, 2425, -0.19505998492240906, 'pot')
#     (309.8870515823364, 1700, 0.18228650093078613, 'player-9:history')
#     (-132.76321813464165, 10000, -0.013276321813464165, 'player-2:stack')
#     (-101.84786282479763, 8300, -0.01227082684636116, 'player-9:stack')
#     (101.19593888521194, 500, 0.2023918777704239, 'player-8:history')
#     (100.03804783336818, 9950, 0.01005407515913248, 'player-6:stack')
#     (63.847689889371395, 10000, 0.0063847689889371395, 'player-1:stack')
#     (59.52429957687855, 10000, 0.005952429957687855, 'player-4:stack')
#     (47.26773127913475, 10000, 0.004726773127913475, 'player-0:stack')
#     (44.96975541114807, 150, 0.2997983694076538, 'player-7:history')
#     (-35.8464615419507, 10000, -0.0035846461541950703, 'player-3:stack')
#     (30.92821652535349, 9500, 0.003255601739510894, 'player-8:stack')
#     (-16.396728402469307, 9850, -0.0016646424774080515, 'player-7:stack')
#     (-10.318137168884277, 1, -10.318137168884277, 'player-8:state')
#     (-10.134866714477539, 1, -10.134866714477539, 'player-9:state')
#     (9.970083832740784, 50, 0.19940167665481567, 'player-6:history')
#     (-7.485950946807861, 1, -7.485950946807861, 'player-4:state')
#     (6.942420959472656, 1, 6.942420959472656, 'player-3:state')
#     (-6.444073833699804, 9975, -0.000646022439468652, 'player-5:stack')
#     (-5.788305282592773, 1, -5.788305282592773, 'player-2:state')
#     (5.6586713790893555, 1, 5.6586713790893555, 'player-1:state')
#     (4.80034202337265, 25, 0.192013680934906, 'player-5:history')
#     (3.384356737136841, 1, 3.384356737136841, 'player-7:state')
#     (2.2646031379699707, 1, 2.2646031379699707, 'player-6:state')
#     (-1.185426190495491, 0.625, -1.8966819047927856, 'cards')
#     (-1.1205889, 0, 0, 'bias')
#     (-0.8296393752098083, 1, -0.8296393752098083, 'round level')
#     (-0.7758181095123291, 1, -0.7758181095123291, 'player-0:state')
#     (-0.4335341155529022, 1, -0.4335341155529022, 'player-5:state')
#     (-0.20687386393547058, 6, -0.03447897732257843, 'btn distance')
