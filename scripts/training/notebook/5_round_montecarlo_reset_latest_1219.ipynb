# %% [markdown]
# # 実験1 とりあえず走らせてみて観察
# ## 5-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 31万6490で打ち切った
# - 5万iteration毎に敵のvalue_functionを最新(agentと同じ重み)に更新しながらself-play
# - 計算時間 : 85450s  => 23.7h

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# <img src="./resource/5_round_montecarlo_after_500000_training_1217_23_37_17/initial_value_transition.png" />

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# <img src="./resource/5_round_montecarlo_after_500000_training_1217_23_37_17/5_round_3000_match_subplot_1219_19_22_13.png" />

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# 結果がdeterministicじゃなくなった
# => なんでだ? カードの重みが加わったか?（TODOみる)
# ```
# (PyPokerAIEnv)Kota-no-MacBook-Air-2:montecarlo_after_500000_training_1217_23_37_17 kota$ python episode_generator.py
# Using Theano backend.
# final reward = -1, episode_length=9.
# >> Do you see this episode in detail? (y/n)
# >> type 'y' to quit the script else generate another episode.
# final reward = -1, episode_length=6.
# >> Do you see this episode in detail? (y/n)
# >> type 'y' to quit the script else generate another episode.
# final reward = -1, episode_length=6.
# >> Do you see this episode in detail? (y/n)
# >> type 'y' to quit the script else generate another episode.
# final reward = 0.40275, episode_length=14.
# >> Do you see this episode in detail? (y/n)
# >> type 'y' to quit the script else generate another episode.
# final reward = -1, episode_length=6.
# >> Do you see this episode in detail? (y/n)
# >> type 'y' to quit the script else generate another episode.
# final reward = 0.60275, episode_length=12.
# >> Do you see this episode in detail? (y/n)
# >> type 'y' to quit the script else generate another episode.
# final reward = -1, episode_length=6.
# >> Do you see this episode in detail? (y/n)^CTraceback (most recent call last):
# ```
#
# - パターン１: raise, double_raise, foldなど色々する.9900raiseしてfoldしたせいで,4 roundでジリ貧負け.
# - パターン2: 一度金が手に入ってから、大きくraiseして、他がFOLDを繰り返して,7万勝ち
#
# イメージ
# - raiseが多い
# - turnとかまでいって、どっちかが降りて決着がつく(showdownまでいってなさそう)
# - 大きく金が手に入るのは,１度３万くらい手にして、そこから2万以上RAISEで相手を揺すって稼ぐパターン
# - turnとかまで進んで2人になったのに,raise100程度でfoldしてしまうのはよくない.

# %% [markdown]
# ### 1round目のMIN_RAISE続きに乗っかってMIN_RAISEする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 125
#   - raise: [150, 10000]
# -- hole card --
#   - ['DT', 'H2']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 375, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9900
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9875
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 150 (min_raise) ] at round 1
#   => [('fold', -0.3284825086593628), ('call', -0.38425976037979126), ('min_raise', -0.0050814151763916016), ('double_raise', -0.381056547164917), ('triple_raise', -0.2366650104522705), ('max_raise', -0.4961118698120117)]
# do you want to see weights? (y/n)y
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 125
#   - raise: [150, 10000]
# -- hole card --
#   - ['DT', 'H2']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 375, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9900
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9875
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 150 (min_raise) ] at round 1
#   => [('fold', -0.3284825086593628), ('call', -0.38425976037979126), ('min_raise', -0.0050814151763916016), ('double_raise', -0.381056547164917), ('triple_raise', -0.2366650104522705), ('max_raise', -0.4961118698120117)]
# ** weights and features in detail **
# bias : [-1.17843068 -1.02286565 -2.06678295 -1.95017385 -1.70704675 -1.56853747]
#
# linear combination for fold :
#     (-1.218326449394226, 1, -1.218326449394226, 'player-0:state-active')
#     (-1.1784307, 0, 0, 'bias')
#     (-1.1665277481079102, 1, -1.1665277481079102, 'round level 2')
#     (0.9125367403030396, 1, 0.9125367403030396, 'btn distance=6')
#     (0.5131024519602457, 0.3333333333333333, 1.5393073558807373, 'player-9:history')
#     (0.42502614855766296, 1, 0.42502614855766296, 'street-preflop')
#     (0.4040111859639486, 0.26666666666666666, 1.5150419473648071, 'player-8:history')
#     (0.31118364334106446, 0.2, 1.5559182167053223, 'player-7:history')
#     (0.24999964237213135, 1, 0.24999964237213135, 'player-5:state-active')
#     (0.18961564699808756, 0.13333333333333333, 1.4221173524856567, 'player-6:history')
#     (0.1653481423854828, 1, 0.1653481423854828, 'player-6:state-active')
#     (0.11704733967781067, 1, 0.11704733967781067, 'player-4:state-active')
#     (0.10609544068574905, 1, 0.10609544068574905, 'player-7:state-active')
#     (0.10491863489151002, 0.1, 1.0491863489151, 'player-0:stack')
#     (0.09600760142008463, 0.06666666666666667, 1.4401140213012695, 'player-5:history')
#     (0.08732421696186066, 1, 0.08732421696186066, 'player-3:state-active')
#     (-0.0766095346212387, 0.09975, -0.7680153846740723, 'player-5:stack')
#     (0.07350452244281769, 1, 0.07350452244281769, 'player-8:state-active')
#     (-0.059801459312438965, 0.1, -0.5980145931243896, 'player-4:stack')
#     (-0.0480258112102747, 0.0995, -0.48267146944999695, 'player-6:stack')
#     (-0.04744648897647858, 0.099, -0.4792574644088745, 'player-8:stack')
#     (-0.046631285548210145, 0.1, -0.46631285548210144, 'player-3:stack')
#     (-0.045521721839904786, 0.09875, -0.4609794616699219, 'player-9:stack')
#     (-0.04510365128517151, 0.1, -0.4510365128517151, 'player-1:stack')
#     (-0.04000033786147833, 0.09925, -0.4030260741710663, 'player-7:stack')
#     (-0.037520101666450506, 0.1, -0.375201016664505, 'player-2:stack')
#     (-0.0341634006164968, 0.569, -0.06004112586379051, 'cards')
#     (-0.030225859954953194, 1, -0.030225859954953194, 'player-1:state-active')
#     (-0.010440158657729626, 1, -0.010440158657729626, 'player-2:state-active')
#     (0.0024986343923956156, 1, 0.0024986343923956156, 'player-9:state-active')
#     (-0.0019279514998197555, 0.00375, -0.5141203999519348, 'pot')
#     (0.0, 0, 0.04484445974230766, 'player-9:state-fold')
#     (0.0, 0, 0.11467187851667404, 'player-8:state-fold')
#     (0.0, 0, 0.12127767503261566, 'player-7:state-fold')
#     (0.0, 0, 0.18702542781829834, 'player-6:state-fold')
#     (0.0, 0, 0.27499473094940186, 'player-5:state-fold')
#     (0.0, 0.0, 1.4575220346450806, 'player-4:history')
#     (0.0, 0, 0.12093259394168854, 'player-4:state-fold')
#     (0.0, 0.0, 1.4820276498794556, 'player-3:history')
#     (0.0, 0, 0.12527720630168915, 'player-3:state-fold')
#     (0.0, 0.0, 1.5585168600082397, 'player-2:history')
#     (0.0, 0, 0.03868267685174942, 'player-2:state-fold')
#     (0.0, 0.0, 1.5680538415908813, 'player-1:history')
#     (0.0, 0, 0.005368893034756184, 'player-1:state-fold')
#     (0.0, 0.0, 1.615420937538147, 'player-0:history')
#     (0.0, 0, 0.13104617595672607, 'player-0:state-fold')
#     (0.0, 0, 0.5163982510566711, 'street-river')
#     (0.0, 0, 0.47896459698677063, 'street-turn')
#     (0.0, 0, 0.4114610552787781, 'street-flop')
#     (0.0, 0, 1.2318480014801025, 'btn distance=9')
#     (0.0, 0, 1.2068599462509155, 'btn distance=8')
#     (0.0, 0, 0.694226086139679, 'btn distance=7')
#     (0.0, 0, 0.980753481388092, 'btn distance=5')
#     (0.0, 0, 1.0374095439910889, 'btn distance=4')
#     (0.0, 0, 1.1171241998672485, 'btn distance=3')
#     (0.0, 0, 1.143062710762024, 'btn distance=2')
#     (0.0, 0, 1.1736388206481934, 'btn distance=1')
#     (0.0, 0, 1.194989800453186, 'btn distance=0')
#     (0.0, 0, 0.17381861805915833, 'round level 27')
#     (-0.0, 0, -0.1709413379430771, 'round level 26')
#     (0.0, 0, 0.23499497771263123, 'round level 25')
#     (0.0, 0, 0.2400972843170166, 'round level 24')
#     (0.0, 0, 0.07879160344600677, 'round level 23')
#     (-0.0, 0, -0.20467768609523773, 'round level 22')
#     (-0.0, 0, -0.02996756322681904, 'round level 21')
#     (0.0, 0, 0.021945780143141747, 'round level 20')
#     (-0.0, 0, -0.23729455471038818, 'round level 19')
#     (0.0, 0, 0.20108163356781006, 'round level 18')
#     (0.0, 0, 0.13430552184581757, 'round level 17')
#     (0.0, 0, 0.19009800255298615, 'round level 16')
#     (0.0, 0, 0.2580344080924988, 'round level 15')
#     (-0.0, 0, -0.0939929336309433, 'round level 14')
#     (-0.0, 0, -0.17090654373168945, 'round level 13')
#     (-0.0, 0, -0.06041152775287628, 'round level 12')
#     (0.0, 0, 0.07556843012571335, 'round level 11')
#     (0.0, 0, 0.008105643093585968, 'round level 10')
#     (-0.0, 0, -0.19526717066764832, 'round level 9')
#     (-0.0, 0, -0.09471932053565979, 'round level 8')
#     (-0.0, 0, -0.24805116653442383, 'round level 7')
#     (-0.0, 0, -0.05985160171985626, 'round level 6')
#     (0.0, 0, 0.16501252353191376, 'round level 5')
#     (0.0, 0, 0.1510487198829651, 'round level 4')
#     (-0.0, 0, -0.06887161731719971, 'round level 3')
#     (0.0, 0, 0.15396647155284882, 'round level 1')
#
# linear combination for call :
#     (1.8035677671432495, 1, 1.8035677671432495, 'btn distance=6')
#     (-1.267747163772583, 1, -1.267747163772583, 'round level 2')
#     (-1.0228657, 0, 0, 'bias')
#     (-0.815963625907898, 1, -0.815963625907898, 'player-0:state-active')
#     (0.30634018778800964, 1, 0.30634018778800964, 'street-preflop')
#     (0.25262734293937683, 1, 0.25262734293937683, 'player-5:state-active')
#     (0.22698932912945746, 0.569, 0.3989267647266388, 'cards')
#     (0.2195797711610794, 1, 0.2195797711610794, 'player-1:state-active')
#     (0.21264493465423584, 0.3333333333333333, 0.6379348039627075, 'player-9:history')
#     (-0.17343391478061676, 1, -0.17343391478061676, 'player-8:state-active')
#     (0.1636771043141683, 0.26666666666666666, 0.6137891411781311, 'player-8:history')
#     (0.14360829591751098, 0.1, 1.4360829591751099, 'player-0:stack')
#     (-0.1419263482093811, 1, -0.1419263482093811, 'player-7:state-active')
#     (0.10514569282531738, 0.2, 0.5257284641265869, 'player-7:history')
#     (0.09489867687225342, 0.13333333333333333, 0.7117400765419006, 'player-6:history')
#     (-0.08662305027246475, 1, -0.08662305027246475, 'player-6:state-active')
#     (0.08468693494796753, 1, 0.08468693494796753, 'player-3:state-active')
#     (-0.08420368283987045, 1, -0.08420368283987045, 'player-4:state-active')
#     (-0.07787381112575531, 1, -0.07787381112575531, 'player-9:state-active')
#     (-0.06067101359367371, 0.1, -0.6067101359367371, 'player-4:stack')
#     (-0.05863537141680718, 0.0995, -0.5893002152442932, 'player-6:stack')
#     (-0.05394701845943928, 0.09875, -0.5462989211082458, 'player-9:stack')
#     (-0.05331911619007588, 0.09975, -0.5345274806022644, 'player-5:stack')
#     (0.048872323830922444, 0.06666666666666667, 0.7330848574638367, 'player-5:history')
#     (-0.04231936758756638, 0.099, -0.42746835947036743, 'player-8:stack')
#     (-0.04207629263401032, 0.1, -0.42076292634010315, 'player-2:stack')
#     (-0.04035792490839958, 0.09925, -0.40662896633148193, 'player-7:stack')
#     (0.03985699266195297, 1, 0.03985699266195297, 'player-2:state-active')
#     (-0.03180499970912933, 0.1, -0.31804999709129333, 'player-3:stack')
#     (-0.029204374551773073, 0.1, -0.2920437455177307, 'player-1:stack')
#     (-0.003782305419445038, 0.00375, -1.0086147785186768, 'pot')
#     (-0.0, 0, -0.025723405182361603, 'player-9:state-fold')
#     (-0.0, 0, -0.09087780117988586, 'player-8:state-fold')
#     (-0.0, 0, -0.21578086912631989, 'player-7:state-fold')
#     (-0.0, 0, -0.05289127305150032, 'player-6:state-fold')
#     (0.0, 0, 0.1515781581401825, 'player-5:state-fold')
#     (0.0, 0.0, 0.6583040952682495, 'player-4:history')
#     (-0.0, 0, -0.12312944233417511, 'player-4:state-fold')
#     (0.0, 0.0, 0.7460985779762268, 'player-3:history')
#     (0.0, 0, 0.14377835392951965, 'player-3:state-fold')
#     (0.0, 0.0, 0.6259687542915344, 'player-2:history')
#     (0.0, 0, 0.04315764829516411, 'player-2:state-fold')
#     (0.0, 0.0, 0.6064308881759644, 'player-1:history')
#     (0.0, 0, 0.19041743874549866, 'player-1:state-fold')
#     (0.0, 0.0, 1.424710988998413, 'player-0:history')
#     (-0.0, 0, -0.20277541875839233, 'player-0:state-fold')
#     (0.0, 0, 0.24349345266819, 'street-river')
#     (0.0, 0, 0.2590084373950958, 'street-turn')
#     (0.0, 0, 0.2862991690635681, 'street-flop')
#     (0.0, 0, 1.1173243522644043, 'btn distance=9')
#     (0.0, 0, 0.30222782492637634, 'btn distance=8')
#     (-0.0, 0, -0.1371598094701767, 'btn distance=7')
#     (0.0, 0, 1.8697949647903442, 'btn distance=5')
#     (0.0, 0, 1.9579356908798218, 'btn distance=4')
#     (0.0, 0, 1.9303548336029053, 'btn distance=3')
#     (0.0, 0, 1.977090835571289, 'btn distance=2')
#     (0.0, 0, 1.8424537181854248, 'btn distance=1')
#     (0.0, 0, 1.8680459260940552, 'btn distance=0')
#     (0.0, 0, 0.07092714309692383, 'round level 27')
#     (-0.0, 0, -0.07035121321678162, 'round level 26')
#     (0.0, 0, 0.1974353939294815, 'round level 25')
#     (-0.0, 0, -0.13411521911621094, 'round level 24')
#     (-0.0, 0, -0.15498259663581848, 'round level 23')
#     (-0.0, 0, -0.128531351685524, 'round level 22')
#     (-0.0, 0, -0.19764813780784607, 'round level 21')
#     (-0.0, 0, -0.20146974921226501, 'round level 20')
#     (0.0, 0, 0.05624271556735039, 'round level 19')
#     (-0.0, 0, -0.11658086627721786, 'round level 18')
#     (-0.0, 0, -0.045278843492269516, 'round level 17')
#     (0.0, 0, 0.14562976360321045, 'round level 16')
#     (0.0, 0, 0.23023651540279388, 'round level 15')
#     (-0.0, 0, -0.048296328634023666, 'round level 14')
#     (-0.0, 0, -0.09172365069389343, 'round level 13')
#     (-0.0, 0, -0.06652963906526566, 'round level 12')
#     (0.0, 0, 0.10760240256786346, 'round level 11')
#     (-0.0, 0, -0.019141659140586853, 'round level 10')
#     (0.0, 0, 0.14686106145381927, 'round level 9')
#     (0.0, 0, 0.09601891785860062, 'round level 8')
#     (0.0, 0, 0.21756060421466827, 'round level 7')
#     (-0.0, 0, -0.052764762192964554, 'round level 6')
#     (-0.0, 0, -0.10461476445198059, 'round level 5')
#     (-0.0, 0, -0.16345806419849396, 'round level 4')
#     (-0.0, 0, -0.2176746279001236, 'round level 3')
#     (0.0, 0, 0.1441952884197235, 'round level 1')
#
# linear combination for min_raise :
#     (3.260719060897827, 1, 3.260719060897827, 'btn distance=6')
#     (-2.265869140625, 1, -2.265869140625, 'round level 2')
#     (-2.187678098678589, 1, -2.187678098678589, 'player-0:state-active')
#     (-2.066783, 0, 0, 'bias')
#     (0.86588454246521, 1, 0.86588454246521, 'street-preflop')
#     (0.464592844247818, 1, 0.464592844247818, 'player-1:state-active')
#     (0.3998405933380127, 1, 0.3998405933380127, 'player-2:state-active')
#     (0.39642349878946936, 0.3333333333333333, 1.1892704963684082, 'player-9:history')
#     (0.30910244584083557, 1, 0.30910244584083557, 'player-5:state-active')
#     (0.29781475067138674, 0.26666666666666666, 1.1168053150177002, 'player-8:history')
#     (0.282500296831131, 1, 0.282500296831131, 'player-3:state-active')
#     (0.25056731700897217, 0.2, 1.2528365850448608, 'player-7:history')
#     (0.20017263094584148, 0.13333333333333333, 1.501294732093811, 'player-6:history')
#     (0.18452391028404236, 1, 0.18452391028404236, 'player-4:state-active')
#     (0.12019430100917816, 1, 0.12019430100917816, 'player-6:state-active')
#     (-0.11893913894891739, 1, -0.11893913894891739, 'player-8:state-active')
#     (-0.1166426181793213, 0.1, -1.166426181793213, 'player-4:stack')
#     (0.10889238119125366, 0.1, 1.0889238119125366, 'player-0:stack')
#     (0.1000036875406901, 0.06666666666666667, 1.5000553131103516, 'player-5:history')
#     (-0.09519996146857738, 0.09975, -0.9543855786323547, 'player-5:stack')
#     (0.0858101626932621, 0.569, 0.15080872178077698, 'cards')
#     (-0.0791206692159176, 0.09875, -0.8012219667434692, 'player-9:stack')
#     (-0.07495799481868744, 0.0995, -0.7533466815948486, 'player-6:stack')
#     (-0.073861831381917, 0.09925, -0.744199812412262, 'player-7:stack')
#     (-0.06303411722183228, 0.1, -0.6303411722183228, 'player-2:stack')
#     (-0.06111159920692444, 0.1, -0.6111159920692444, 'player-1:stack')
#     (-0.05724294894933701, 0.099, -0.5782116055488586, 'player-8:stack')
#     (-0.055880334228277206, 1, -0.055880334228277206, 'player-7:state-active')
#     (-0.037508597970008856, 0.1, -0.3750859797000885, 'player-3:stack')
#     (0.02560107409954071, 1, 0.02560107409954071, 'player-9:state-active')
#     (-0.0038951526582241057, 0.00375, -1.0387073755264282, 'pot')
#     (0.0, 0, 0.011712395586073399, 'player-9:state-fold')
#     (-0.0, 0, -0.13986387848854065, 'player-8:state-fold')
#     (-0.0, 0, -0.1362907588481903, 'player-7:state-fold')
#     (0.0, 0, 0.06474278122186661, 'player-6:state-fold')
#     (0.0, 0, 0.16605611145496368, 'player-5:state-fold')
#     (0.0, 0.0, 1.4716317653656006, 'player-4:history')
#     (0.0, 0, 0.11001203209161758, 'player-4:state-fold')
#     (0.0, 0.0, 1.5399361848831177, 'player-3:history')
#     (0.0, 0, 0.38637688755989075, 'player-3:state-fold')
#     (0.0, 0.0, 1.746171236038208, 'player-2:history')
#     (0.0, 0, 0.42541566491127014, 'player-2:state-fold')
#     (0.0, 0.0, 1.468366026878357, 'player-1:history')
#     (0.0, 0, 0.46276387572288513, 'player-1:state-fold')
#     (0.0, 0.0, 1.4896961450576782, 'player-0:history')
#     (-0.0, 0, -0.08319959789514542, 'player-0:state-fold')
#     (0.0, 0, 0.9790592193603516, 'street-river')
#     (0.0, 0, 0.9331514239311218, 'street-turn')
#     (0.0, 0, 0.8445892333984375, 'street-flop')
#     (0.0, 0, 1.4440168142318726, 'btn distance=9')
#     (0.0, 0, 0.6902648210525513, 'btn distance=8')
#     (0.0, 0, 0.6125809550285339, 'btn distance=7')
#     (0.0, 0, 3.378845453262329, 'btn distance=5')
#     (0.0, 0, 3.491258382797241, 'btn distance=4')
#     (0.0, 0, 3.366580009460449, 'btn distance=3')
#     (0.0, 0, 3.403568983078003, 'btn distance=2')
#     (0.0, 0, 3.3066458702087402, 'btn distance=1')
#     (0.0, 0, 3.3113150596618652, 'btn distance=0')
#     (0.0, 0, 0.1864863932132721, 'round level 27')
#     (-0.0, 0, -0.16429129242897034, 'round level 26')
#     (-0.0, 0, -0.046955082565546036, 'round level 25')
#     (-0.0, 0, -0.09106510132551193, 'round level 24')
#     (0.0, 0, 0.19359903037548065, 'round level 23')
#     (-0.0, 0, -0.1129482239484787, 'round level 22')
#     (-0.0, 0, -0.07924514263868332, 'round level 21')
#     (-0.0, 0, -0.07969773560762405, 'round level 20')
#     (-0.0, 0, -0.21454547345638275, 'round level 19')
#     (0.0, 0, 0.059178855270147324, 'round level 18')
#     (-0.0, 0, -0.03560476377606392, 'round level 17')
#     (0.0, 0, 0.007163514383137226, 'round level 16')
#     (-0.0, 0, -0.13512195646762848, 'round level 15')
#     (-0.0, 0, -0.1584649533033371, 'round level 14')
#     (0.0, 0, 0.15792712569236755, 'round level 13')
#     (-0.0, 0, -0.23586158454418182, 'round level 12')
#     (0.0, 0, 0.07051877677440643, 'round level 11')
#     (0.0, 0, 0.08433552831411362, 'round level 10')
#     (0.0, 0, 0.006170609965920448, 'round level 9')
#     (-0.0, 0, -0.07084600627422333, 'round level 8')
#     (0.0, 0, 0.11457421630620956, 'round level 7')
#     (0.0, 0, 0.08975376188755035, 'round level 6')
#     (-0.0, 0, -0.23617757856845856, 'round level 5')
#     (-0.0, 0, -0.22836115956306458, 'round level 4')
#     (0.0, 0, 0.048288315534591675, 'round level 3')
#     (-0.0, 0, -0.07394367456436157, 'round level 1')
#
# linear combination for double_raise :
#     (2.787144184112549, 1, 2.787144184112549, 'btn distance=6')
#     (-1.9725971221923828, 1, -1.9725971221923828, 'round level 2')
#     (-1.9501739, 0, 0, 'bias')
#     (-1.7458921670913696, 1, -1.7458921670913696, 'player-0:state-active')
#     (0.7431500554084778, 1, 0.7431500554084778, 'street-preflop')
#     (0.5919350385665894, 1, 0.5919350385665894, 'player-3:state-active')
#     (0.5230585932731628, 1, 0.5230585932731628, 'player-1:state-active')
#     (0.37250587344169617, 1, 0.37250587344169617, 'player-4:state-active')
#     (0.2917595108350118, 0.3333333333333333, 0.8752785325050354, 'player-9:history')
#     (0.28965461254119873, 1, 0.28965461254119873, 'player-5:state-active')
#     (0.23868544896443686, 0.26666666666666666, 0.8950704336166382, 'player-8:history')
#     (0.18749094009399414, 0.2, 0.9374547004699707, 'player-7:history')
#     (0.18403167724609376, 0.13333333333333333, 1.3802375793457031, 'player-6:history')
#     (-0.16487022638320925, 0.1, -1.6487022638320923, 'player-4:stack')
#     (-0.16440437734127045, 1, -0.16440437734127045, 'player-8:state-active')
#     (-0.15508936509490015, 0.09975, -1.5547806024551392, 'player-5:stack')
#     (0.14463238418102264, 1, 0.14463238418102264, 'player-2:state-active')
#     (-0.1330258196592331, 0.0995, -1.3369429111480713, 'player-6:stack')
#     (0.12281614542007446, 1, 0.12281614542007446, 'player-6:state-active')
#     (-0.12172797039151192, 0.09875, -1.232688307762146, 'player-9:stack')
#     (-0.11971910095214844, 0.09925, -1.20623779296875, 'player-7:stack')
#     (-0.11264981031417848, 0.1, -1.1264981031417847, 'player-2:stack')
#     (-0.10957398414611817, 0.1, -1.0957398414611816, 'player-1:stack')
#     (-0.10789618641138077, 1, -0.10789618641138077, 'player-7:state-active')
#     (-0.1066339305639267, 0.099, -1.0771104097366333, 'player-8:stack')
#     (-0.10069057941436768, 0.1, -1.0069057941436768, 'player-3:stack')
#     (0.08611850738525391, 0.06666666666666667, 1.2917776107788086, 'player-5:history')
#     (0.08266991800069808, 0.569, 0.1452898383140564, 'cards')
#     (0.05994352698326111, 0.1, 0.5994352698326111, 'player-0:stack')
#     (-0.016730034723877907, 1, -0.016730034723877907, 'player-9:state-active')
#     (-0.004978458881378173, 0.00375, -1.3275890350341797, 'pot')
#     (-0.0, 0, -0.09042394906282425, 'player-9:state-fold')
#     (-0.0, 0, -0.22285068035125732, 'player-8:state-fold')
#     (-0.0, 0, -0.0851152092218399, 'player-7:state-fold')
#     (0.0, 0, 0.12394552677869797, 'player-6:state-fold')
#     (0.0, 0, 0.1696426421403885, 'player-5:state-fold')
#     (0.0, 0.0, 1.2546406984329224, 'player-4:history')
#     (0.0, 0, 0.33568552136421204, 'player-4:state-fold')
#     (0.0, 0.0, 1.4033446311950684, 'player-3:history')
#     (0.0, 0, 0.6927028298377991, 'player-3:state-fold')
#     (0.0, 0.0, 1.594526767730713, 'player-2:history')
#     (0.0, 0, 0.24494382739067078, 'player-2:state-fold')
#     (0.0, 0.0, 1.3148036003112793, 'player-1:history')
#     (0.0, 0, 0.6143580079078674, 'player-1:state-fold')
#     (0.0, 0.0, 1.2485133409500122, 'player-0:history')
#     (-0.0, 0, -0.19295382499694824, 'player-0:state-fold')
#     (0.0, 0, 0.8448724150657654, 'street-river')
#     (0.0, 0, 0.8965580463409424, 'street-turn')
#     (0.0, 0, 0.7743945121765137, 'street-flop')
#     (0.0, 0, 1.0809276103973389, 'btn distance=9')
#     (0.0, 0, 0.33288007974624634, 'btn distance=8')
#     (0.0, 0, 0.16215811669826508, 'btn distance=7')
#     (0.0, 0, 2.851736068725586, 'btn distance=5')
#     (0.0, 0, 2.869692802429199, 'btn distance=4')
#     (0.0, 0, 2.9180355072021484, 'btn distance=3')
#     (0.0, 0, 2.906381368637085, 'btn distance=2')
#     (0.0, 0, 2.693354368209839, 'btn distance=1')
#     (0.0, 0, 2.7792532444000244, 'btn distance=0')
#     (0.0, 0, 0.15659865736961365, 'round level 27')
#     (-0.0, 0, -0.05769524350762367, 'round level 26')
#     (0.0, 0, 0.060281381011009216, 'round level 25')
#     (0.0, 0, 0.12171455472707748, 'round level 24')
#     (0.0, 0, 0.2290050983428955, 'round level 23')
#     (-0.0, 0, -0.11531021445989609, 'round level 22')
#     (-0.0, 0, -0.2500810921192169, 'round level 21')
#     (0.0, 0, 0.007750209420919418, 'round level 20')
#     (0.0, 0, 0.13105927407741547, 'round level 19')
#     (-0.0, 0, -0.08005983382463455, 'round level 18')
#     (0.0, 0, 0.21569842100143433, 'round level 17')
#     (-0.0, 0, -0.16492699086666107, 'round level 16')
#     (0.0, 0, 0.1520710587501526, 'round level 15')
#     (-0.0, 0, -0.1770043522119522, 'round level 14')
#     (0.0, 0, 0.04302123188972473, 'round level 13')
#     (-0.0, 0, -0.20310285687446594, 'round level 12')
#     (-0.0, 0, -0.017459731549024582, 'round level 11')
#     (0.0, 0, 0.1835925579071045, 'round level 10')
#     (0.0, 0, 0.05069294944405556, 'round level 9')
#     (0.0, 0, 0.03629465401172638, 'round level 8')
#     (-0.0, 0, -0.0857870876789093, 'round level 7')
#     (0.0, 0, 0.20314936339855194, 'round level 6')
#     (0.0, 0, 0.24049139022827148, 'round level 5')
#     (0.0, 0, 0.22036118805408478, 'round level 4')
#     (-0.0, 0, -0.12533701956272125, 'round level 3')
#     (0.0, 0, 0.17443950474262238, 'round level 1')
#
# linear combination for triple_raise :
#     (2.627833127975464, 1, 2.627833127975464, 'btn distance=6')
#     (-1.8829259872436523, 1, -1.8829259872436523, 'player-0:state-active')
#     (-1.7070467, 0, 0, 'bias')
#     (-1.7052208185195923, 1, -1.7052208185195923, 'round level 2')
#     (0.6542556285858154, 1, 0.6542556285858154, 'street-preflop')
#     (0.45491641759872437, 1, 0.45491641759872437, 'player-5:state-active')
#     (0.36300328373908997, 1, 0.36300328373908997, 'player-2:state-active')
#     (0.300014058748881, 0.3333333333333333, 0.9000421762466431, 'player-9:history')
#     (0.287477970123291, 1, 0.287477970123291, 'player-1:state-active')
#     (0.2616552829742432, 0.26666666666666666, 0.9812073111534119, 'player-8:history')
#     (0.25785180926322937, 1, 0.25785180926322937, 'player-3:state-active')
#     (0.20062950452168782, 0.13333333333333333, 1.5047212839126587, 'player-6:history')
#     (0.1671353280544281, 1, 0.1671353280544281, 'player-4:state-active')
#     (-0.14964689016342164, 0.1, -1.4964689016342163, 'player-4:stack')
#     (0.143082857131958, 0.2, 0.71541428565979, 'player-7:history')
#     (-0.13700897839665413, 0.09975, -1.3735235929489136, 'player-5:stack')
#     (0.13206961750984192, 1, 0.13206961750984192, 'player-9:state-active')
#     (-0.10582003593444825, 0.1, -1.0582003593444824, 'player-1:stack')
#     (-0.10540722417831422, 0.0995, -1.0593690872192383, 'player-6:stack')
#     (-0.10181494817137719, 0.09875, -1.031037449836731, 'player-9:stack')
#     (-0.09874407947063446, 1, -0.09874407947063446, 'player-7:state-active')
#     (-0.09627063870429993, 0.1, -0.9627063870429993, 'player-3:stack')
#     (-0.09537987112998964, 0.1, -0.9537987112998962, 'player-2:stack')
#     (0.09225422541300456, 0.06666666666666667, 1.3838133811950684, 'player-5:history')
#     (-0.0857590960264206, 0.099, -0.8662534952163696, 'player-8:stack')
#     (0.08429592847824097, 0.1, 0.8429592847824097, 'player-0:stack')
#     (-0.08345209632813931, 0.09925, -0.8408271670341492, 'player-7:stack')
#     (0.07474841535091399, 0.569, 0.13136804103851318, 'cards')
#     (0.06523146480321884, 1, 0.06523146480321884, 'player-6:state-active')
#     (-0.04559437185525894, 1, -0.04559437185525894, 'player-8:state-active')
#     (-0.0030282173305749894, 0.00375, -0.8075246214866638, 'pot')
#     (0.0, 0, 0.10115792602300644, 'player-9:state-fold')
#     (-0.0, 0, -0.060533251613378525, 'player-8:state-fold')
#     (-0.0, 0, -0.22947770357131958, 'player-7:state-fold')
#     (0.0, 0, 0.15178783237934113, 'player-6:state-fold')
#     (0.0, 0, 0.3858034908771515, 'player-5:state-fold')
#     (0.0, 0.0, 1.222939372062683, 'player-4:history')
#     (0.0, 0, 0.15441195666790009, 'player-4:state-fold')
#     (0.0, 0.0, 1.4812450408935547, 'player-3:history')
#     (0.0, 0, 0.4172688126564026, 'player-3:state-fold')
#     (0.0, 0.0, 1.4365956783294678, 'player-2:history')
#     (0.0, 0, 0.4363452196121216, 'player-2:state-fold')
#     (0.0, 0.0, 1.2733837366104126, 'player-1:history')
#     (0.0, 0, 0.38805511593818665, 'player-1:state-fold')
#     (0.0, 0.0, 1.0665782690048218, 'player-0:history')
#     (-0.0, 0, -0.16879042983055115, 'player-0:state-fold')
#     (0.0, 0, 0.7164437174797058, 'street-river')
#     (0.0, 0, 0.734492838382721, 'street-turn')
#     (0.0, 0, 0.6086469292640686, 'street-flop')
#     (0.0, 0, 0.9314766526222229, 'btn distance=9')
#     (0.0, 0, 0.2717871069908142, 'btn distance=8')
#     (0.0, 0, 0.3050857186317444, 'btn distance=7')
#     (0.0, 0, 2.7287395000457764, 'btn distance=5')
#     (0.0, 0, 2.8521649837493896, 'btn distance=4')
#     (0.0, 0, 2.7740681171417236, 'btn distance=3')
#     (0.0, 0, 2.6455600261688232, 'btn distance=2')
#     (0.0, 0, 2.4956750869750977, 'btn distance=1')
#     (0.0, 0, 2.534360647201538, 'btn distance=0')
#     (-0.0, 0, -0.03168884664773941, 'round level 27')
#     (-0.0, 0, -0.017876192927360535, 'round level 26')
#     (0.0, 0, 0.24670392274856567, 'round level 25')
#     (0.0, 0, 0.23704470694065094, 'round level 24')
#     (-0.0, 0, -0.12388164550065994, 'round level 23')
#     (-0.0, 0, -0.21403175592422485, 'round level 22')
#     (-0.0, 0, -0.2394574135541916, 'round level 21')
#     (0.0, 0, 0.2087094932794571, 'round level 20')
#     (0.0, 0, 0.016761131584644318, 'round level 19')
#     (0.0, 0, 0.03723394498229027, 'round level 18')
#     (0.0, 0, 0.06718005239963531, 'round level 17')
#     (0.0, 0, 0.195980042219162, 'round level 16')
#     (0.0, 0, 0.04985208436846733, 'round level 15')
#     (0.0, 0, 0.18927551805973053, 'round level 14')
#     (-0.0, 0, -0.22544996440410614, 'round level 13')
#     (-0.0, 0, -0.07048213481903076, 'round level 12')
#     (0.0, 0, 0.1204707995057106, 'round level 11')
#     (-0.0, 0, -0.05045364424586296, 'round level 10')
#     (0.0, 0, 0.1273985356092453, 'round level 9')
#     (-0.0, 0, -0.06570541113615036, 'round level 8')
#     (0.0, 0, 0.09865906834602356, 'round level 7')
#     (-0.0, 0, -0.1552954465150833, 'round level 6')
#     (-0.0, 0, -0.11621785163879395, 'round level 5')
#     (0.0, 0, 0.14041194319725037, 'round level 4')
#     (0.0, 0, 0.005522481631487608, 'round level 3')
#     (-0.0, 0, -0.18949121236801147, 'round level 1')
#
# linear combination for max_raise :
#     (2.019573450088501, 1, 2.019573450088501, 'btn distance=6')
#     (-1.705495834350586, 1, -1.705495834350586, 'round level 2')
#     (-1.5685375, 0, 0, 'bias')
#     (-1.3696188926696777, 1, -1.3696188926696777, 'player-0:state-active')
#     (-0.4739885926246643, 1, -0.4739885926246643, 'player-8:state-active')
#     (0.4439617693424225, 1, 0.4439617693424225, 'street-preflop')
#     (0.44320815801620483, 1, 0.44320815801620483, 'player-2:state-active')
#     (0.43147007624308265, 0.3333333333333333, 1.294410228729248, 'player-9:history')
#     (0.35042362213134765, 0.26666666666666666, 1.3140885829925537, 'player-8:history')
#     (0.2826626016795635, 0.569, 0.49677082896232605, 'cards')
#     (0.2710704803466797, 1, 0.2710704803466797, 'player-6:state-active')
#     (0.25705533027648925, 0.2, 1.2852766513824463, 'player-7:history')
#     (0.21083040237426756, 0.13333333333333333, 1.5812280178070068, 'player-6:history')
#     (0.18305647373199463, 1, 0.18305647373199463, 'player-3:state-active')
#     (-0.1723392754793167, 1, -0.1723392754793167, 'player-9:state-active')
#     (0.1689018964767456, 0.1, 1.689018964767456, 'player-0:stack')
#     (0.1328335702419281, 1, 0.1328335702419281, 'player-4:state-active')
#     (0.09890875021616617, 0.06666666666666667, 1.4836312532424927, 'player-5:history')
#     (-0.08904659152030946, 0.1, -0.8904659152030945, 'player-4:stack')
#     (-0.08302051651477814, 0.0995, -0.8343770503997803, 'player-6:stack')
#     (-0.07135504540801049, 0.09925, -0.7189425230026245, 'player-7:stack')
#     (-0.06816240549087525, 0.1, -0.6816240549087524, 'player-3:stack')
#     (-0.06628311342000962, 0.099, -0.6695263981819153, 'player-8:stack')
#     (-0.06171972751617432, 0.1, -0.6171972751617432, 'player-1:stack')
#     (-0.0568593966960907, 0.09875, -0.5757913589477539, 'player-9:stack')
#     (-0.052268922328948975, 0.1, -0.5226892232894897, 'player-2:stack')
#     (0.050112057477235794, 1, 0.050112057477235794, 'player-5:state-active')
#     (-0.048019469954073433, 0.09975, -0.48139819502830505, 'player-5:stack')
#     (0.03814220800995827, 1, 0.03814220800995827, 'player-1:state-active')
#     (0.009113033302128315, 1, 0.009113033302128315, 'player-7:state-active')
#     (-0.0007205764017999172, 0.00375, -0.1921537071466446, 'pot')
#     (-0.0, 0, -0.1316184550523758, 'player-9:state-fold')
#     (-0.0, 0, -0.45327356457710266, 'player-8:state-fold')
#     (-0.0, 0, -0.0054485369473695755, 'player-7:state-fold')
#     (0.0, 0, 0.16990752518177032, 'player-6:state-fold')
#     (-0.0, 0, -0.008543427102267742, 'player-5:state-fold')
#     (0.0, 0.0, 1.4741692543029785, 'player-4:history')
#     (0.0, 0, 0.18107010424137115, 'player-4:state-fold')
#     (0.0, 0.0, 1.5749785900115967, 'player-3:history')
#     (0.0, 0, 0.16700617969036102, 'player-3:state-fold')
#     (0.0, 0.0, 1.523707628250122, 'player-2:history')
#     (0.0, 0, 0.5559921860694885, 'player-2:state-fold')
#     (0.0, 0.0, 1.399151086807251, 'player-1:history')
#     (0.0, 0, 0.08285059034824371, 'player-1:state-fold')
#     (0.0, 0.0, 1.7490384578704834, 'player-0:history')
#     (-0.0, 0, -0.07082012295722961, 'player-0:state-fold')
#     (0.0, 0, 0.6438460946083069, 'street-river')
#     (0.0, 0, 0.5357523560523987, 'street-turn')
#     (0.0, 0, 0.3845996558666229, 'street-flop')
#     (0.0, 0, 1.0605579614639282, 'btn distance=9')
#     (0.0, 0, 0.5578138828277588, 'btn distance=8')
#     (0.0, 0, 0.3871185779571533, 'btn distance=7')
#     (0.0, 0, 2.1290736198425293, 'btn distance=5')
#     (0.0, 0, 2.1042659282684326, 'btn distance=4')
#     (0.0, 0, 2.0583226680755615, 'btn distance=3')
#     (0.0, 0, 1.996710181236267, 'btn distance=2')
#     (0.0, 0, 1.9347350597381592, 'btn distance=1')
#     (0.0, 0, 1.9695475101470947, 'btn distance=0')
#     (-0.0, 0, -0.0745745450258255, 'round level 27')
#     (0.0, 0, 0.015400783158838749, 'round level 26')
#     (0.0, 0, 0.1319204717874527, 'round level 25')
#     (-0.0, 0, -0.15635602176189423, 'round level 24')
#     (0.0, 0, 0.08905228227376938, 'round level 23')
#     (-0.0, 0, -0.10733900219202042, 'round level 22')
#     (0.0, 0, 0.02085469476878643, 'round level 21')
#     (0.0, 0, 0.24782584607601166, 'round level 20')
#     (-0.0, 0, -0.1948973387479782, 'round level 19')
#     (0.0, 0, 0.1771361082792282, 'round level 18')
#     (0.0, 0, 0.1400010585784912, 'round level 17')
#     (0.0, 0, 0.0674973577260971, 'round level 16')
#     (-0.0, 0, -0.16851937770843506, 'round level 15')
#     (-0.0, 0, -0.10289682447910309, 'round level 14')
#     (0.0, 0, 0.09751802682876587, 'round level 13')
#     (0.0, 0, 0.05579689145088196, 'round level 12')
#     (0.0, 0, 0.062262505292892456, 'round level 11')
#     (0.0, 0, 0.08422500640153885, 'round level 10')
#     (0.0, 0, 0.2191074788570404, 'round level 9')
#     (0.0, 0, 0.1968294382095337, 'round level 8')
#     (-0.0, 0, -0.1691485494375229, 'round level 7')
#     (0.0, 0, 0.08150830864906311, 'round level 6')
#     (0.0, 0, 0.008948147296905518, 'round level 5')
#     (-0.0, 0, -0.23150017857551575, 'round level 4')
#     (0.0, 0, 0.199162557721138, 'round level 3')
#     (0.0, 0, 0.1435113102197647, 'round level 1')
# >>> type something to go next...

# %% [markdown]
# ### RAISE続きに乗っかって,DOUBLE RAISE ($9900)

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 4425
#   - raise: [4950, 10000]
# -- hole card --
#   - ['DT', 'H2']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 17850, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 7150
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 6625 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9775 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9250
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 6100
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 5575
#     - 6 : agent (uuid-0) => state : participating, stack : 7675 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 175, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 200, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 225, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 675, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 750, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1175, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 1275, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1675, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 1800, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2175, 'player': 'agent (uuid=uuid-0)', 'amount': 2325, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2675, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 2850, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 3175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 3375, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 3900, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 4425, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 9900 (double_raise) ] at round 1
#   => [('fold', -0.28471165895462036), ('call', -0.4257909655570984), ('min_raise', -0.08569979667663574), ('double_raise', -0.07556807994842529), ('max_raise', -0.44221067428588867)]
# ** weights and features in detail **
# bias : [-1.17843068 -1.02286565 -2.06678295 -1.95017385 -1.70704675 -1.56853747]
#
# linear combination for fold :
#     (-1.218326449394226, 1, -1.218326449394226, 'player-0:state-active')
#     (-1.1784307, 0, 0, 'bias')
#     (-1.1665277481079102, 1, -1.1665277481079102, 'round level 2')
#     (0.9125367403030396, 1, 0.9125367403030396, 'btn distance=6')
#     (0.42502614855766296, 1, 0.42502614855766296, 'street-preflop')
#     (0.3815929999872416, 0.24789915966386555, 1.5393073558807373, 'player-9:history')
#     (0.3310175683318066, 0.2184873949579832, 1.5150419473648071, 'player-8:history')
#     (0.2722904662124249, 0.18907563025210083, 1.4401140213012695, 'player-5:history')
#     (0.24999964237213135, 1, 0.24999964237213135, 'player-5:state-active')
#     (0.23271360217022294, 0.15966386554621848, 1.4575220346450806, 'player-4:history')
#     (0.21041197085580907, 0.13025210084033614, 1.615420937538147, 'player-0:history')
#     (0.18702542781829834, 1, 0.18702542781829834, 'player-6:state-fold')
#     (0.12527720630168915, 1, 0.12527720630168915, 'player-3:state-fold')
#     (0.12127767503261566, 1, 0.12127767503261566, 'player-7:state-fold')
#     (0.11704733967781067, 1, 0.11704733967781067, 'player-4:state-active')
#     (-0.09177049139142036, 0.1785, -0.5141203999519348, 'pot')
#     (0.08052505227923393, 0.07675, 1.0491863489151, 'player-0:stack')
#     (0.07350452244281769, 1, 0.07350452244281769, 'player-8:state-active')
#     (-0.05088101923465729, 0.06625, -0.7680153846740723, 'player-5:stack')
#     (-0.0471811361387372, 0.09775, -0.48267146944999695, 'player-6:stack')
#     (-0.046631285548210145, 0.1, -0.46631285548210144, 'player-3:stack')
#     (-0.04510365128517151, 0.1, -0.4510365128517151, 'player-1:stack')
#     (-0.042758043408393856, 0.0715, -0.5980145931243896, 'player-4:stack')
#     (0.03868267685174942, 1, 0.03868267685174942, 'player-2:state-fold')
#     (-0.037520101666450506, 0.1, -0.375201016664505, 'player-2:stack')
#     (-0.037279911860823634, 0.0925, -0.4030260741710663, 'player-7:stack')
#     (-0.0341634006164968, 0.569, -0.06004112586379051, 'cards')
#     (-0.029234705328941346, 0.061, -0.4792574644088745, 'player-8:stack')
#     (-0.025699604988098146, 0.05575, -0.4609794616699219, 'player-9:stack')
#     (0.005368893034756184, 1, 0.005368893034756184, 'player-1:state-fold')
#     (0.0024986343923956156, 1, 0.0024986343923956156, 'player-9:state-active')
#     (0.0, 0, 0.04484445974230766, 'player-9:state-fold')
#     (0.0, 0, 0.11467187851667404, 'player-8:state-fold')
#     (0.0, 0.0, 1.5559182167053223, 'player-7:history')
#     (0.0, 0, 0.10609544068574905, 'player-7:state-active')
#     (0.0, 0.0, 1.4221173524856567, 'player-6:history')
#     (0.0, 0, 0.1653481423854828, 'player-6:state-active')
#     (0.0, 0, 0.27499473094940186, 'player-5:state-fold')
#     (0.0, 0, 0.12093259394168854, 'player-4:state-fold')
#     (0.0, 0.0, 1.4820276498794556, 'player-3:history')
#     (0.0, 0, 0.08732421696186066, 'player-3:state-active')
#     (0.0, 0.0, 1.5585168600082397, 'player-2:history')
#     (-0.0, 0, -0.010440158657729626, 'player-2:state-active')
#     (0.0, 0.0, 1.5680538415908813, 'player-1:history')
#     (-0.0, 0, -0.030225859954953194, 'player-1:state-active')
#     (0.0, 0, 0.13104617595672607, 'player-0:state-fold')
#     (0.0, 0, 0.5163982510566711, 'street-river')
#     (0.0, 0, 0.47896459698677063, 'street-turn')
#     (0.0, 0, 0.4114610552787781, 'street-flop')
#     (0.0, 0, 1.2318480014801025, 'btn distance=9')
#     (0.0, 0, 1.2068599462509155, 'btn distance=8')
#     (0.0, 0, 0.694226086139679, 'btn distance=7')
#     (0.0, 0, 0.980753481388092, 'btn distance=5')
#     (0.0, 0, 1.0374095439910889, 'btn distance=4')
#     (0.0, 0, 1.1171241998672485, 'btn distance=3')
#     (0.0, 0, 1.143062710762024, 'btn distance=2')
#     (0.0, 0, 1.1736388206481934, 'btn distance=1')
#     (0.0, 0, 1.194989800453186, 'btn distance=0')
#     (0.0, 0, 0.17381861805915833, 'round level 27')
#     (-0.0, 0, -0.1709413379430771, 'round level 26')
#     (0.0, 0, 0.23499497771263123, 'round level 25')
#     (0.0, 0, 0.2400972843170166, 'round level 24')
#     (0.0, 0, 0.07879160344600677, 'round level 23')
#     (-0.0, 0, -0.20467768609523773, 'round level 22')
#     (-0.0, 0, -0.02996756322681904, 'round level 21')
#     (0.0, 0, 0.021945780143141747, 'round level 20')
#     (-0.0, 0, -0.23729455471038818, 'round level 19')
#     (0.0, 0, 0.20108163356781006, 'round level 18')
#     (0.0, 0, 0.13430552184581757, 'round level 17')
#     (0.0, 0, 0.19009800255298615, 'round level 16')
#     (0.0, 0, 0.2580344080924988, 'round level 15')
#     (-0.0, 0, -0.0939929336309433, 'round level 14')
#     (-0.0, 0, -0.17090654373168945, 'round level 13')
#     (-0.0, 0, -0.06041152775287628, 'round level 12')
#     (0.0, 0, 0.07556843012571335, 'round level 11')
#     (0.0, 0, 0.008105643093585968, 'round level 10')
#     (-0.0, 0, -0.19526717066764832, 'round level 9')
#     (-0.0, 0, -0.09471932053565979, 'round level 8')
#     (-0.0, 0, -0.24805116653442383, 'round level 7')
#     (-0.0, 0, -0.05985160171985626, 'round level 6')
#     (0.0, 0, 0.16501252353191376, 'round level 5')
#     (0.0, 0, 0.1510487198829651, 'round level 4')
#     (-0.0, 0, -0.06887161731719971, 'round level 3')
#     (0.0, 0, 0.15396647155284882, 'round level 1')
#
# linear combination for call :
#     (1.8035677671432495, 1, 1.8035677671432495, 'btn distance=6')
#     (-1.267747163772583, 1, -1.267747163772583, 'round level 2')
#     (-1.0228657, 0, 0, 'bias')
#     (-0.815963625907898, 1, -0.815963625907898, 'player-0:state-active')
#     (0.30634018778800964, 1, 0.30634018778800964, 'street-preflop')
#     (0.25262734293937683, 1, 0.25262734293937683, 'player-5:state-active')
#     (0.22698932912945746, 0.569, 0.3989267647266388, 'cards')
#     (-0.21578086912631989, 1, -0.21578086912631989, 'player-7:state-fold')
#     (0.19041743874549866, 1, 0.19041743874549866, 'player-1:state-fold')
#     (0.18557159940735635, 0.13025210084033614, 1.424710988998413, 'player-0:history')
#     (-0.18003773796558378, 0.1785, -1.0086147785186768, 'pot')
#     (-0.17343391478061676, 1, -0.17343391478061676, 'player-8:state-active')
#     (0.158143501822688, 0.24789915966386555, 0.6379348039627075, 'player-9:history')
#     (0.14377835392951965, 1, 0.14377835392951965, 'player-3:state-fold')
#     (0.13860848145324642, 0.18907563025210083, 0.7330848574638367, 'player-5:history')
#     (0.13410519050950764, 0.2184873949579832, 0.6137891411781311, 'player-8:history')
#     (0.11021936711668968, 0.07675, 1.4360829591751099, 'player-0:stack')
#     (0.10510737655543478, 0.15966386554621848, 0.6583040952682495, 'player-4:history')
#     (-0.08420368283987045, 1, -0.08420368283987045, 'player-4:state-active')
#     (-0.07787381112575531, 1, -0.07787381112575531, 'player-9:state-active')
#     (-0.057604096040129664, 0.09775, -0.5893002152442932, 'player-6:stack')
#     (-0.05289127305150032, 1, -0.05289127305150032, 'player-6:state-fold')
#     (-0.043379774719476696, 0.0715, -0.6067101359367371, 'player-4:stack')
#     (0.04315764829516411, 1, 0.04315764829516411, 'player-2:state-fold')
#     (-0.04207629263401032, 0.1, -0.42076292634010315, 'player-2:stack')
#     (-0.037613179385662075, 0.0925, -0.40662896633148193, 'player-7:stack')
#     (-0.03541244558990002, 0.06625, -0.5345274806022644, 'player-5:stack')
#     (-0.03180499970912933, 0.1, -0.31804999709129333, 'player-3:stack')
#     (-0.030456164851784706, 0.05575, -0.5462989211082458, 'player-9:stack')
#     (-0.029204374551773073, 0.1, -0.2920437455177307, 'player-1:stack')
#     (-0.026075569927692412, 0.061, -0.42746835947036743, 'player-8:stack')
#     (-0.0, 0, -0.025723405182361603, 'player-9:state-fold')
#     (-0.0, 0, -0.09087780117988586, 'player-8:state-fold')
#     (0.0, 0.0, 0.5257284641265869, 'player-7:history')
#     (-0.0, 0, -0.1419263482093811, 'player-7:state-active')
#     (0.0, 0.0, 0.7117400765419006, 'player-6:history')
#     (-0.0, 0, -0.08662305027246475, 'player-6:state-active')
#     (0.0, 0, 0.1515781581401825, 'player-5:state-fold')
#     (-0.0, 0, -0.12312944233417511, 'player-4:state-fold')
#     (0.0, 0.0, 0.7460985779762268, 'player-3:history')
#     (0.0, 0, 0.08468693494796753, 'player-3:state-active')
#     (0.0, 0.0, 0.6259687542915344, 'player-2:history')
#     (0.0, 0, 0.03985699266195297, 'player-2:state-active')
#     (0.0, 0.0, 0.6064308881759644, 'player-1:history')
#     (0.0, 0, 0.2195797711610794, 'player-1:state-active')
#     (-0.0, 0, -0.20277541875839233, 'player-0:state-fold')
#     (0.0, 0, 0.24349345266819, 'street-river')
#     (0.0, 0, 0.2590084373950958, 'street-turn')
#     (0.0, 0, 0.2862991690635681, 'street-flop')
#     (0.0, 0, 1.1173243522644043, 'btn distance=9')
#     (0.0, 0, 0.30222782492637634, 'btn distance=8')
#     (-0.0, 0, -0.1371598094701767, 'btn distance=7')
#     (0.0, 0, 1.8697949647903442, 'btn distance=5')
#     (0.0, 0, 1.9579356908798218, 'btn distance=4')
#     (0.0, 0, 1.9303548336029053, 'btn distance=3')
#     (0.0, 0, 1.977090835571289, 'btn distance=2')
#     (0.0, 0, 1.8424537181854248, 'btn distance=1')
#     (0.0, 0, 1.8680459260940552, 'btn distance=0')
#     (0.0, 0, 0.07092714309692383, 'round level 27')
#     (-0.0, 0, -0.07035121321678162, 'round level 26')
#     (0.0, 0, 0.1974353939294815, 'round level 25')
#     (-0.0, 0, -0.13411521911621094, 'round level 24')
#     (-0.0, 0, -0.15498259663581848, 'round level 23')
#     (-0.0, 0, -0.128531351685524, 'round level 22')
#     (-0.0, 0, -0.19764813780784607, 'round level 21')
#     (-0.0, 0, -0.20146974921226501, 'round level 20')
#     (0.0, 0, 0.05624271556735039, 'round level 19')
#     (-0.0, 0, -0.11658086627721786, 'round level 18')
#     (-0.0, 0, -0.045278843492269516, 'round level 17')
#     (0.0, 0, 0.14562976360321045, 'round level 16')
#     (0.0, 0, 0.23023651540279388, 'round level 15')
#     (-0.0, 0, -0.048296328634023666, 'round level 14')
#     (-0.0, 0, -0.09172365069389343, 'round level 13')
#     (-0.0, 0, -0.06652963906526566, 'round level 12')
#     (0.0, 0, 0.10760240256786346, 'round level 11')
#     (-0.0, 0, -0.019141659140586853, 'round level 10')
#     (0.0, 0, 0.14686106145381927, 'round level 9')
#     (0.0, 0, 0.09601891785860062, 'round level 8')
#     (0.0, 0, 0.21756060421466827, 'round level 7')
#     (-0.0, 0, -0.052764762192964554, 'round level 6')
#     (-0.0, 0, -0.10461476445198059, 'round level 5')
#     (-0.0, 0, -0.16345806419849396, 'round level 4')
#     (-0.0, 0, -0.2176746279001236, 'round level 3')
#     (0.0, 0, 0.1441952884197235, 'round level 1')
#
# linear combination for min_raise :
#     (3.260719060897827, 1, 3.260719060897827, 'btn distance=6')
#     (-2.265869140625, 1, -2.265869140625, 'round level 2')
#     (-2.187678098678589, 1, -2.187678098678589, 'player-0:state-active')
#     (-2.066783, 0, 0, 'bias')
#     (0.86588454246521, 1, 0.86588454246521, 'street-preflop')
#     (0.46276387572288513, 1, 0.46276387572288513, 'player-1:state-fold')
#     (0.42541566491127014, 1, 0.42541566491127014, 'player-2:state-fold')
#     (0.38637688755989075, 1, 0.38637688755989075, 'player-3:state-fold')
#     (0.30910244584083557, 1, 0.30910244584083557, 'player-5:state-active')
#     (0.29481915666275665, 0.24789915966386555, 1.1892704963684082, 'player-9:history')
#     (0.2836239037393522, 0.18907563025210083, 1.5000553131103516, 'player-5:history')
#     (0.2440078839534471, 0.2184873949579832, 1.1168053150177002, 'player-8:history')
#     (0.23496641631887738, 0.15966386554621848, 1.4716317653656006, 'player-4:history')
#     (0.1940360525075127, 0.13025210084033614, 1.4896961450576782, 'player-0:history')
#     (-0.18540926653146744, 0.1785, -1.0387073755264282, 'pot')
#     (0.18452391028404236, 1, 0.18452391028404236, 'player-4:state-active')
#     (-0.1362907588481903, 1, -0.1362907588481903, 'player-7:state-fold')
#     (-0.11893913894891739, 1, -0.11893913894891739, 'player-8:state-active')
#     (0.0858101626932621, 0.569, 0.15080872178077698, 'cards')
#     (0.08357490256428718, 0.07675, 1.0889238119125366, 'player-0:stack')
#     (-0.08339947199821471, 0.0715, -1.166426181793213, 'player-4:stack')
#     (-0.07363963812589645, 0.09775, -0.7533466815948486, 'player-6:stack')
#     (-0.06883848264813423, 0.0925, -0.744199812412262, 'player-7:stack')
#     (0.06474278122186661, 1, 0.06474278122186661, 'player-6:state-fold')
#     (-0.0632280445843935, 0.06625, -0.9543855786323547, 'player-5:stack')
#     (-0.06303411722183228, 0.1, -0.6303411722183228, 'player-2:stack')
#     (-0.06111159920692444, 0.1, -0.6111159920692444, 'player-1:stack')
#     (-0.04466812464594841, 0.05575, -0.8012219667434692, 'player-9:stack')
#     (-0.037508597970008856, 0.1, -0.3750859797000885, 'player-3:stack')
#     (-0.035270907938480374, 0.061, -0.5782116055488586, 'player-8:stack')
#     (0.02560107409954071, 1, 0.02560107409954071, 'player-9:state-active')
#     (0.0, 0, 0.011712395586073399, 'player-9:state-fold')
#     (-0.0, 0, -0.13986387848854065, 'player-8:state-fold')
#     (0.0, 0.0, 1.2528365850448608, 'player-7:history')
#     (-0.0, 0, -0.055880334228277206, 'player-7:state-active')
#     (0.0, 0.0, 1.501294732093811, 'player-6:history')
#     (0.0, 0, 0.12019430100917816, 'player-6:state-active')
#     (0.0, 0, 0.16605611145496368, 'player-5:state-fold')
#     (0.0, 0, 0.11001203209161758, 'player-4:state-fold')
#     (0.0, 0.0, 1.5399361848831177, 'player-3:history')
#     (0.0, 0, 0.282500296831131, 'player-3:state-active')
#     (0.0, 0.0, 1.746171236038208, 'player-2:history')
#     (0.0, 0, 0.3998405933380127, 'player-2:state-active')
#     (0.0, 0.0, 1.468366026878357, 'player-1:history')
#     (0.0, 0, 0.464592844247818, 'player-1:state-active')
#     (-0.0, 0, -0.08319959789514542, 'player-0:state-fold')
#     (0.0, 0, 0.9790592193603516, 'street-river')
#     (0.0, 0, 0.9331514239311218, 'street-turn')
#     (0.0, 0, 0.8445892333984375, 'street-flop')
#     (0.0, 0, 1.4440168142318726, 'btn distance=9')
#     (0.0, 0, 0.6902648210525513, 'btn distance=8')
#     (0.0, 0, 0.6125809550285339, 'btn distance=7')
#     (0.0, 0, 3.378845453262329, 'btn distance=5')
#     (0.0, 0, 3.491258382797241, 'btn distance=4')
#     (0.0, 0, 3.366580009460449, 'btn distance=3')
#     (0.0, 0, 3.403568983078003, 'btn distance=2')
#     (0.0, 0, 3.3066458702087402, 'btn distance=1')
#     (0.0, 0, 3.3113150596618652, 'btn distance=0')
#     (0.0, 0, 0.1864863932132721, 'round level 27')
#     (-0.0, 0, -0.16429129242897034, 'round level 26')
#     (-0.0, 0, -0.046955082565546036, 'round level 25')
#     (-0.0, 0, -0.09106510132551193, 'round level 24')
#     (0.0, 0, 0.19359903037548065, 'round level 23')
#     (-0.0, 0, -0.1129482239484787, 'round level 22')
#     (-0.0, 0, -0.07924514263868332, 'round level 21')
#     (-0.0, 0, -0.07969773560762405, 'round level 20')
#     (-0.0, 0, -0.21454547345638275, 'round level 19')
#     (0.0, 0, 0.059178855270147324, 'round level 18')
#     (-0.0, 0, -0.03560476377606392, 'round level 17')
#     (0.0, 0, 0.007163514383137226, 'round level 16')
#     (-0.0, 0, -0.13512195646762848, 'round level 15')
#     (-0.0, 0, -0.1584649533033371, 'round level 14')
#     (0.0, 0, 0.15792712569236755, 'round level 13')
#     (-0.0, 0, -0.23586158454418182, 'round level 12')
#     (0.0, 0, 0.07051877677440643, 'round level 11')
#     (0.0, 0, 0.08433552831411362, 'round level 10')
#     (0.0, 0, 0.006170609965920448, 'round level 9')
#     (-0.0, 0, -0.07084600627422333, 'round level 8')
#     (0.0, 0, 0.11457421630620956, 'round level 7')
#     (0.0, 0, 0.08975376188755035, 'round level 6')
#     (-0.0, 0, -0.23617757856845856, 'round level 5')
#     (-0.0, 0, -0.22836115956306458, 'round level 4')
#     (0.0, 0, 0.048288315534591675, 'round level 3')
#     (-0.0, 0, -0.07394367456436157, 'round level 1')
#
# linear combination for double_raise :
#     (2.787144184112549, 1, 2.787144184112549, 'btn distance=6')
#     (-1.9725971221923828, 1, -1.9725971221923828, 'round level 2')
#     (-1.9501739, 0, 0, 'bias')
#     (-1.7458921670913696, 1, -1.7458921670913696, 'player-0:state-active')
#     (0.7431500554084778, 1, 0.7431500554084778, 'street-preflop')
#     (0.6927028298377991, 1, 0.6927028298377991, 'player-3:state-fold')
#     (0.6143580079078674, 1, 0.6143580079078674, 'player-1:state-fold')
#     (0.37250587344169617, 1, 0.37250587344169617, 'player-4:state-active')
#     (0.28965461254119873, 1, 0.28965461254119873, 'player-5:state-active')
#     (0.24494382739067078, 1, 0.24494382739067078, 'player-2:state-fold')
#     (0.24424366590355623, 0.18907563025210083, 1.2917776107788086, 'player-5:history')
#     (-0.23697464275360106, 0.1785, -1.3275890350341797, 'pot')
#     (0.2169808126798197, 0.24789915966386555, 0.8752785325050354, 'player-9:history')
#     (0.20032078378340776, 0.15966386554621848, 1.2546406984329224, 'player-4:history')
#     (0.1955616073448117, 0.2184873949579832, 0.8950704336166382, 'player-8:history')
#     (-0.16440437734127045, 1, -0.16440437734127045, 'player-8:state-active')
#     (0.16262148558592598, 0.13025210084033614, 1.2485133409500122, 'player-0:history')
#     (-0.13068616956472398, 0.09775, -1.3369429111480713, 'player-6:stack')
#     (0.12394552677869797, 1, 0.12394552677869797, 'player-6:state-fold')
#     (-0.11788221186399458, 0.0715, -1.6487022638320923, 'player-4:stack')
#     (-0.11264981031417848, 0.1, -1.1264981031417847, 'player-2:stack')
#     (-0.11157699584960937, 0.0925, -1.20623779296875, 'player-7:stack')
#     (-0.10957398414611817, 0.1, -1.0957398414611816, 'player-1:stack')
#     (-0.10300421491265298, 0.06625, -1.5547806024551392, 'player-5:stack')
#     (-0.10069057941436768, 0.1, -1.0069057941436768, 'player-3:stack')
#     (-0.0851152092218399, 1, -0.0851152092218399, 'player-7:state-fold')
#     (0.08266991800069808, 0.569, 0.1452898383140564, 'cards')
#     (-0.06872237315773964, 0.05575, -1.232688307762146, 'player-9:stack')
#     (-0.06570373499393463, 0.061, -1.0771104097366333, 'player-8:stack')
#     (0.0460066569596529, 0.07675, 0.5994352698326111, 'player-0:stack')
#     (-0.016730034723877907, 1, -0.016730034723877907, 'player-9:state-active')
#     (-0.0, 0, -0.09042394906282425, 'player-9:state-fold')
#     (-0.0, 0, -0.22285068035125732, 'player-8:state-fold')
#     (0.0, 0.0, 0.9374547004699707, 'player-7:history')
#     (-0.0, 0, -0.10789618641138077, 'player-7:state-active')
#     (0.0, 0.0, 1.3802375793457031, 'player-6:history')
#     (0.0, 0, 0.12281614542007446, 'player-6:state-active')
#     (0.0, 0, 0.1696426421403885, 'player-5:state-fold')
#     (0.0, 0, 0.33568552136421204, 'player-4:state-fold')
#     (0.0, 0.0, 1.4033446311950684, 'player-3:history')
#     (0.0, 0, 0.5919350385665894, 'player-3:state-active')
#     (0.0, 0.0, 1.594526767730713, 'player-2:history')
#     (0.0, 0, 0.14463238418102264, 'player-2:state-active')
#     (0.0, 0.0, 1.3148036003112793, 'player-1:history')
#     (0.0, 0, 0.5230585932731628, 'player-1:state-active')
#     (-0.0, 0, -0.19295382499694824, 'player-0:state-fold')
#     (0.0, 0, 0.8448724150657654, 'street-river')
#     (0.0, 0, 0.8965580463409424, 'street-turn')
#     (0.0, 0, 0.7743945121765137, 'street-flop')
#     (0.0, 0, 1.0809276103973389, 'btn distance=9')
#     (0.0, 0, 0.33288007974624634, 'btn distance=8')
#     (0.0, 0, 0.16215811669826508, 'btn distance=7')
#     (0.0, 0, 2.851736068725586, 'btn distance=5')
#     (0.0, 0, 2.869692802429199, 'btn distance=4')
#     (0.0, 0, 2.9180355072021484, 'btn distance=3')
#     (0.0, 0, 2.906381368637085, 'btn distance=2')
#     (0.0, 0, 2.693354368209839, 'btn distance=1')
#     (0.0, 0, 2.7792532444000244, 'btn distance=0')
#     (0.0, 0, 0.15659865736961365, 'round level 27')
#     (-0.0, 0, -0.05769524350762367, 'round level 26')
#     (0.0, 0, 0.060281381011009216, 'round level 25')
#     (0.0, 0, 0.12171455472707748, 'round level 24')
#     (0.0, 0, 0.2290050983428955, 'round level 23')
#     (-0.0, 0, -0.11531021445989609, 'round level 22')
#     (-0.0, 0, -0.2500810921192169, 'round level 21')
#     (0.0, 0, 0.007750209420919418, 'round level 20')
#     (0.0, 0, 0.13105927407741547, 'round level 19')
#     (-0.0, 0, -0.08005983382463455, 'round level 18')
#     (0.0, 0, 0.21569842100143433, 'round level 17')
#     (-0.0, 0, -0.16492699086666107, 'round level 16')
#     (0.0, 0, 0.1520710587501526, 'round level 15')
#     (-0.0, 0, -0.1770043522119522, 'round level 14')
#     (0.0, 0, 0.04302123188972473, 'round level 13')
#     (-0.0, 0, -0.20310285687446594, 'round level 12')
#     (-0.0, 0, -0.017459731549024582, 'round level 11')
#     (0.0, 0, 0.1835925579071045, 'round level 10')
#     (0.0, 0, 0.05069294944405556, 'round level 9')
#     (0.0, 0, 0.03629465401172638, 'round level 8')
#     (-0.0, 0, -0.0857870876789093, 'round level 7')
#     (0.0, 0, 0.20314936339855194, 'round level 6')
#     (0.0, 0, 0.24049139022827148, 'round level 5')
#     (0.0, 0, 0.22036118805408478, 'round level 4')
#     (-0.0, 0, -0.12533701956272125, 'round level 3')
#     (0.0, 0, 0.17443950474262238, 'round level 1')
#
# linear combination for max_raise :
#     (2.019573450088501, 1, 2.019573450088501, 'btn distance=6')
#     (-1.705495834350586, 1, -1.705495834350586, 'round level 2')
#     (-1.5685375, 0, 0, 'bias')
#     (-1.3696188926696777, 1, -1.3696188926696777, 'player-0:state-active')
#     (0.5559921860694885, 1, 0.5559921860694885, 'player-2:state-fold')
#     (-0.4739885926246643, 1, -0.4739885926246643, 'player-8:state-active')
#     (0.4439617693424225, 1, 0.4439617693424225, 'street-preflop')
#     (0.3208832079622926, 0.24789915966386555, 1.294410228729248, 'player-9:history')
#     (0.28711179124207054, 0.2184873949579832, 1.3140885829925537, 'player-8:history')
#     (0.2826626016795635, 0.569, 0.49677082896232605, 'cards')
#     (0.2805185142685385, 0.18907563025210083, 1.4836312532424927, 'player-5:history')
#     (0.2353715616113999, 0.15966386554621848, 1.4741692543029785, 'player-4:history')
#     (0.22781593358817223, 0.13025210084033614, 1.7490384578704834, 'player-0:history')
#     (-0.1723392754793167, 1, -0.1723392754793167, 'player-9:state-active')
#     (0.16990752518177032, 1, 0.16990752518177032, 'player-6:state-fold')
#     (0.16700617969036102, 1, 0.16700617969036102, 'player-3:state-fold')
#     (0.1328335702419281, 1, 0.1328335702419281, 'player-4:state-active')
#     (0.12963220554590224, 0.07675, 1.689018964767456, 'player-0:stack')
#     (0.08285059034824371, 1, 0.08285059034824371, 'player-1:state-fold')
#     (-0.08156035667657853, 0.09775, -0.8343770503997803, 'player-6:stack')
#     (-0.06816240549087525, 0.1, -0.6816240549087524, 'player-3:stack')
#     (-0.06650218337774276, 0.0925, -0.7189425230026245, 'player-7:stack')
#     (-0.06366831293702126, 0.0715, -0.8904659152030945, 'player-4:stack')
#     (-0.06171972751617432, 0.1, -0.6171972751617432, 'player-1:stack')
#     (-0.052268922328948975, 0.1, -0.5226892232894897, 'player-2:stack')
#     (0.050112057477235794, 1, 0.050112057477235794, 'player-5:state-active')
#     (-0.04084111028909683, 0.061, -0.6695263981819153, 'player-8:stack')
#     (-0.03429943672567606, 0.1785, -0.1921537071466446, 'pot')
#     (-0.03210036826133728, 0.05575, -0.5757913589477539, 'player-9:stack')
#     (-0.03189263042062521, 0.06625, -0.48139819502830505, 'player-5:stack')
#     (-0.0054485369473695755, 1, -0.0054485369473695755, 'player-7:state-fold')
#     (-0.0, 0, -0.1316184550523758, 'player-9:state-fold')
#     (-0.0, 0, -0.45327356457710266, 'player-8:state-fold')
#     (0.0, 0.0, 1.2852766513824463, 'player-7:history')
#     (0.0, 0, 0.009113033302128315, 'player-7:state-active')
#     (0.0, 0.0, 1.5812280178070068, 'player-6:history')
#     (0.0, 0, 0.2710704803466797, 'player-6:state-active')
#     (-0.0, 0, -0.008543427102267742, 'player-5:state-fold')
#     (0.0, 0, 0.18107010424137115, 'player-4:state-fold')
#     (0.0, 0.0, 1.5749785900115967, 'player-3:history')
#     (0.0, 0, 0.18305647373199463, 'player-3:state-active')
#     (0.0, 0.0, 1.523707628250122, 'player-2:history')
#     (0.0, 0, 0.44320815801620483, 'player-2:state-active')
#     (0.0, 0.0, 1.399151086807251, 'player-1:history')
#     (0.0, 0, 0.03814220800995827, 'player-1:state-active')
#     (-0.0, 0, -0.07082012295722961, 'player-0:state-fold')
#     (0.0, 0, 0.6438460946083069, 'street-river')
#     (0.0, 0, 0.5357523560523987, 'street-turn')
#     (0.0, 0, 0.3845996558666229, 'street-flop')
#     (0.0, 0, 1.0605579614639282, 'btn distance=9')
#     (0.0, 0, 0.5578138828277588, 'btn distance=8')
#     (0.0, 0, 0.3871185779571533, 'btn distance=7')
#     (0.0, 0, 2.1290736198425293, 'btn distance=5')
#     (0.0, 0, 2.1042659282684326, 'btn distance=4')
#     (0.0, 0, 2.0583226680755615, 'btn distance=3')
#     (0.0, 0, 1.996710181236267, 'btn distance=2')
#     (0.0, 0, 1.9347350597381592, 'btn distance=1')
#     (0.0, 0, 1.9695475101470947, 'btn distance=0')
#     (-0.0, 0, -0.0745745450258255, 'round level 27')
#     (0.0, 0, 0.015400783158838749, 'round level 26')
#     (0.0, 0, 0.1319204717874527, 'round level 25')
#     (-0.0, 0, -0.15635602176189423, 'round level 24')
#     (0.0, 0, 0.08905228227376938, 'round level 23')
#     (-0.0, 0, -0.10733900219202042, 'round level 22')
#     (0.0, 0, 0.02085469476878643, 'round level 21')
#     (0.0, 0, 0.24782584607601166, 'round level 20')
#     (-0.0, 0, -0.1948973387479782, 'round level 19')
#     (0.0, 0, 0.1771361082792282, 'round level 18')
#     (0.0, 0, 0.1400010585784912, 'round level 17')
#     (0.0, 0, 0.0674973577260971, 'round level 16')
#     (-0.0, 0, -0.16851937770843506, 'round level 15')
#     (-0.0, 0, -0.10289682447910309, 'round level 14')
#     (0.0, 0, 0.09751802682876587, 'round level 13')
#     (0.0, 0, 0.05579689145088196, 'round level 12')
#     (0.0, 0, 0.062262505292892456, 'round level 11')
#     (0.0, 0, 0.08422500640153885, 'round level 10')
#     (0.0, 0, 0.2191074788570404, 'round level 9')
#     (0.0, 0, 0.1968294382095337, 'round level 8')
#     (-0.0, 0, -0.1691485494375229, 'round level 7')
#     (0.0, 0, 0.08150830864906311, 'round level 6')
#     (0.0, 0, 0.008948147296905518, 'round level 5')
#     (-0.0, 0, -0.23150017857551575, 'round level 4')
#     (0.0, 0, 0.199162557721138, 'round level 3')
#     (0.0, 0, 0.1435113102197647, 'round level 1')

# %% [markdown]
# ### FLOPに来て急に降りる

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [100, 100]
# -- hole card --
#   - ['DT', 'H2']
# -- round state --
#   - dealer btn : cpu8
#   - street : flop
#   - community card : ['HQ', 'SQ', 'H3']
#   - pot : main = 31475, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 7150
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 6625 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9775 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9250
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 50
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 5575
#     - 6 : agent (uuid-0) => state : participating, stack : 100 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 175, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 200, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 225, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 675, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 750, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1175, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 1275, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1675, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 1800, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2175, 'player': 'agent (uuid=uuid-0)', 'amount': 2325, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2675, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 2850, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 3175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 3375, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 3900, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 4425, 'action': 'RAISE'}
#       - {'add_amount': 5475, 'paid': 7575, 'player': 'agent (uuid=uuid-0)', 'amount': 9900, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 9900, 'paid': 6000}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#     - flop
#       - {'add_amount': 50, 'paid': 50, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', -0.7914145588874817), ('call', -0.8144094944000244), ('min_raise', -0.9501399993896484), ('max_raise', -0.9474145174026489)]
# ** weights and features in detail **
# bias : [-1.17843068 -1.02286565 -2.06678295 -1.95017385 -1.70704675 -1.56853747]
#
# linear combination for fold :
#     (-1.218326449394226, 1, -1.218326449394226, 'player-0:state-active')
#     (-1.1784307, 0, 0, 'bias')
#     (-1.1665277481079102, 1, -1.1665277481079102, 'round level 2')
#     (0.9125367403030396, 1, 0.9125367403030396, 'btn distance=6')
#     (0.508106982736383, 0.3145353455123114, 1.615420937538147, 'player-0:history')
#     (0.4789409809779136, 0.3161239078633836, 1.5150419473648071, 'player-8:history')
#     (0.4114610552787781, 1, 0.4114610552787781, 'street-flop')
#     (0.27499473094940186, 1, 0.27499473094940186, 'player-5:state-fold')
#     (0.18702542781829834, 1, 0.18702542781829834, 'player-6:state-fold')
#     (-0.16181939588487146, 0.31475, -0.5141203999519348, 'pot')
#     (0.12527720630168915, 1, 0.12527720630168915, 'player-3:state-fold')
#     (0.12127767503261566, 1, 0.12127767503261566, 'player-7:state-fold')
#     (0.12093259394168854, 1, 0.12093259394168854, 'player-4:state-fold')
#     (0.07350452244281769, 1, 0.07350452244281769, 'player-8:state-active')
#     (-0.05088101923465729, 0.06625, -0.7680153846740723, 'player-5:stack')
#     (-0.0471811361387372, 0.09775, -0.48267146944999695, 'player-6:stack')
#     (-0.046631285548210145, 0.1, -0.46631285548210144, 'player-3:stack')
#     (-0.04510365128517151, 0.1, -0.4510365128517151, 'player-1:stack')
#     (0.04484445974230766, 1, 0.04484445974230766, 'player-9:state-fold')
#     (-0.042758043408393856, 0.0715, -0.5980145931243896, 'player-4:stack')
#     (0.03868267685174942, 1, 0.03868267685174942, 'player-2:state-fold')
#     (-0.037520101666450506, 0.1, -0.375201016664505, 'player-2:stack')
#     (-0.037279911860823634, 0.0925, -0.4030260741710663, 'player-7:stack')
#     (-0.037018966236028961, 0.61656016111373901, -0.06004112586379051, 'cards')
#     (-0.025699604988098146, 0.05575, -0.4609794616699219, 'player-9:stack')
#     (0.005368893034756184, 1, 0.005368893034756184, 'player-1:state-fold')
#     (0.0010491863489151, 0.001, 1.0491863489151, 'player-0:stack')
#     (-0.00023962873220443725, 0.0005, -0.4792574644088745, 'player-8:stack')
#     (0.0, 0.0, 1.5393073558807373, 'player-9:history')
#     (0.0, 0, 0.0024986343923956156, 'player-9:state-active')
#     (0.0, 0, 0.11467187851667404, 'player-8:state-fold')
#     (0.0, 0.0, 1.5559182167053223, 'player-7:history')
#     (0.0, 0, 0.10609544068574905, 'player-7:state-active')
#     (0.0, 0.0, 1.4221173524856567, 'player-6:history')
#     (0.0, 0, 0.1653481423854828, 'player-6:state-active')
#     (0.0, 0.0, 1.4401140213012695, 'player-5:history')
#     (0.0, 0, 0.24999964237213135, 'player-5:state-active')
#     (0.0, 0.0, 1.4575220346450806, 'player-4:history')
#     (0.0, 0, 0.11704733967781067, 'player-4:state-active')
#     (0.0, 0.0, 1.4820276498794556, 'player-3:history')
#     (0.0, 0, 0.08732421696186066, 'player-3:state-active')
#     (0.0, 0.0, 1.5585168600082397, 'player-2:history')
#     (-0.0, 0, -0.010440158657729626, 'player-2:state-active')
#     (0.0, 0.0, 1.5680538415908813, 'player-1:history')
#     (-0.0, 0, -0.030225859954953194, 'player-1:state-active')
#     (0.0, 0, 0.13104617595672607, 'player-0:state-fold')
#     (0.0, 0, 0.5163982510566711, 'street-river')
#     (0.0, 0, 0.47896459698677063, 'street-turn')
#     (0.0, 0, 0.42502614855766296, 'street-preflop')
#     (0.0, 0, 1.2318480014801025, 'btn distance=9')
#     (0.0, 0, 1.2068599462509155, 'btn distance=8')
#     (0.0, 0, 0.694226086139679, 'btn distance=7')
#     (0.0, 0, 0.980753481388092, 'btn distance=5')
#     (0.0, 0, 1.0374095439910889, 'btn distance=4')
#     (0.0, 0, 1.1171241998672485, 'btn distance=3')
#     (0.0, 0, 1.143062710762024, 'btn distance=2')
#     (0.0, 0, 1.1736388206481934, 'btn distance=1')
#     (0.0, 0, 1.194989800453186, 'btn distance=0')
#     (0.0, 0, 0.17381861805915833, 'round level 27')
#     (-0.0, 0, -0.1709413379430771, 'round level 26')
#     (0.0, 0, 0.23499497771263123, 'round level 25')
#     (0.0, 0, 0.2400972843170166, 'round level 24')
#     (0.0, 0, 0.07879160344600677, 'round level 23')
#     (-0.0, 0, -0.20467768609523773, 'round level 22')
#     (-0.0, 0, -0.02996756322681904, 'round level 21')
#     (0.0, 0, 0.021945780143141747, 'round level 20')
#     (-0.0, 0, -0.23729455471038818, 'round level 19')
#     (0.0, 0, 0.20108163356781006, 'round level 18')
#     (0.0, 0, 0.13430552184581757, 'round level 17')
#     (0.0, 0, 0.19009800255298615, 'round level 16')
#     (0.0, 0, 0.2580344080924988, 'round level 15')
#     (-0.0, 0, -0.0939929336309433, 'round level 14')
#     (-0.0, 0, -0.17090654373168945, 'round level 13')
#     (-0.0, 0, -0.06041152775287628, 'round level 12')
#     (0.0, 0, 0.07556843012571335, 'round level 11')
#     (0.0, 0, 0.008105643093585968, 'round level 10')
#     (-0.0, 0, -0.19526717066764832, 'round level 9')
#     (-0.0, 0, -0.09471932053565979, 'round level 8')
#     (-0.0, 0, -0.24805116653442383, 'round level 7')
#     (-0.0, 0, -0.05985160171985626, 'round level 6')
#     (0.0, 0, 0.16501252353191376, 'round level 5')
#     (0.0, 0, 0.1510487198829651, 'round level 4')
#     (-0.0, 0, -0.06887161731719971, 'round level 3')
#     (0.0, 0, 0.15396647155284882, 'round level 1')
#
# linear combination for call :
#     (1.8035677671432495, 1, 1.8035677671432495, 'btn distance=6')
#     (-1.267747163772583, 1, -1.267747163772583, 'round level 2')
#     (-1.0228657, 0, 0, 'bias')
#     (-0.815963625907898, 1, -0.815963625907898, 'player-0:state-active')
#     (0.44812196317980274, 0.3145353455123114, 1.424710988998413, 'player-0:history')
#     (-0.31746150153875347, 0.31475, -1.0086147785186768, 'pot')
#     (0.2862991690635681, 1, 0.2862991690635681, 'street-flop')
#     (0.24596235033243907, 0.61656016111373901, 0.3989267647266388, 'cards')
#     (-0.21578086912631989, 1, -0.21578086912631989, 'player-7:state-fold')
#     (0.1940334219133409, 0.3161239078633836, 0.6137891411781311, 'player-8:history')
#     (0.19041743874549866, 1, 0.19041743874549866, 'player-1:state-fold')
#     (-0.17343391478061676, 1, -0.17343391478061676, 'player-8:state-active')
#     (0.1515781581401825, 1, 0.1515781581401825, 'player-5:state-fold')
#     (0.14377835392951965, 1, 0.14377835392951965, 'player-3:state-fold')
#     (-0.12312944233417511, 1, -0.12312944233417511, 'player-4:state-fold')
#     (-0.057604096040129664, 0.09775, -0.5893002152442932, 'player-6:stack')
#     (-0.05289127305150032, 1, -0.05289127305150032, 'player-6:state-fold')
#     (-0.043379774719476696, 0.0715, -0.6067101359367371, 'player-4:stack')
#     (0.04315764829516411, 1, 0.04315764829516411, 'player-2:state-fold')
#     (-0.04207629263401032, 0.1, -0.42076292634010315, 'player-2:stack')
#     (-0.037613179385662075, 0.0925, -0.40662896633148193, 'player-7:stack')
#     (-0.03541244558990002, 0.06625, -0.5345274806022644, 'player-5:stack')
#     (-0.03180499970912933, 0.1, -0.31804999709129333, 'player-3:stack')
#     (-0.030456164851784706, 0.05575, -0.5462989211082458, 'player-9:stack')
#     (-0.029204374551773073, 0.1, -0.2920437455177307, 'player-1:stack')
#     (-0.025723405182361603, 1, -0.025723405182361603, 'player-9:state-fold')
#     (0.00143608295917511, 0.001, 1.4360829591751099, 'player-0:stack')
#     (-0.00021373417973518372, 0.0005, -0.42746835947036743, 'player-8:stack')
#     (0.0, 0.0, 0.6379348039627075, 'player-9:history')
#     (-0.0, 0, -0.07787381112575531, 'player-9:state-active')
#     (-0.0, 0, -0.09087780117988586, 'player-8:state-fold')
#     (0.0, 0.0, 0.5257284641265869, 'player-7:history')
#     (-0.0, 0, -0.1419263482093811, 'player-7:state-active')
#     (0.0, 0.0, 0.7117400765419006, 'player-6:history')
#     (-0.0, 0, -0.08662305027246475, 'player-6:state-active')
#     (0.0, 0.0, 0.7330848574638367, 'player-5:history')
#     (0.0, 0, 0.25262734293937683, 'player-5:state-active')
#     (0.0, 0.0, 0.6583040952682495, 'player-4:history')
#     (-0.0, 0, -0.08420368283987045, 'player-4:state-active')
#     (0.0, 0.0, 0.7460985779762268, 'player-3:history')
#     (0.0, 0, 0.08468693494796753, 'player-3:state-active')
#     (0.0, 0.0, 0.6259687542915344, 'player-2:history')
#     (0.0, 0, 0.03985699266195297, 'player-2:state-active')
#     (0.0, 0.0, 0.6064308881759644, 'player-1:history')
#     (0.0, 0, 0.2195797711610794, 'player-1:state-active')
#     (-0.0, 0, -0.20277541875839233, 'player-0:state-fold')
#     (0.0, 0, 0.24349345266819, 'street-river')
#     (0.0, 0, 0.2590084373950958, 'street-turn')
#     (0.0, 0, 0.30634018778800964, 'street-preflop')
#     (0.0, 0, 1.1173243522644043, 'btn distance=9')
#     (0.0, 0, 0.30222782492637634, 'btn distance=8')
#     (-0.0, 0, -0.1371598094701767, 'btn distance=7')
#     (0.0, 0, 1.8697949647903442, 'btn distance=5')
#     (0.0, 0, 1.9579356908798218, 'btn distance=4')
#     (0.0, 0, 1.9303548336029053, 'btn distance=3')
#     (0.0, 0, 1.977090835571289, 'btn distance=2')
#     (0.0, 0, 1.8424537181854248, 'btn distance=1')
#     (0.0, 0, 1.8680459260940552, 'btn distance=0')
#     (0.0, 0, 0.07092714309692383, 'round level 27')
#     (-0.0, 0, -0.07035121321678162, 'round level 26')
#     (0.0, 0, 0.1974353939294815, 'round level 25')
#     (-0.0, 0, -0.13411521911621094, 'round level 24')
#     (-0.0, 0, -0.15498259663581848, 'round level 23')
#     (-0.0, 0, -0.128531351685524, 'round level 22')
#     (-0.0, 0, -0.19764813780784607, 'round level 21')
#     (-0.0, 0, -0.20146974921226501, 'round level 20')
#     (0.0, 0, 0.05624271556735039, 'round level 19')
#     (-0.0, 0, -0.11658086627721786, 'round level 18')
#     (-0.0, 0, -0.045278843492269516, 'round level 17')
#     (0.0, 0, 0.14562976360321045, 'round level 16')
#     (0.0, 0, 0.23023651540279388, 'round level 15')
#     (-0.0, 0, -0.048296328634023666, 'round level 14')
#     (-0.0, 0, -0.09172365069389343, 'round level 13')
#     (-0.0, 0, -0.06652963906526566, 'round level 12')
#     (0.0, 0, 0.10760240256786346, 'round level 11')
#     (-0.0, 0, -0.019141659140586853, 'round level 10')
#     (0.0, 0, 0.14686106145381927, 'round level 9')
#     (0.0, 0, 0.09601891785860062, 'round level 8')
#     (0.0, 0, 0.21756060421466827, 'round level 7')
#     (-0.0, 0, -0.052764762192964554, 'round level 6')
#     (-0.0, 0, -0.10461476445198059, 'round level 5')
#     (-0.0, 0, -0.16345806419849396, 'round level 4')
#     (-0.0, 0, -0.2176746279001236, 'round level 3')
#     (0.0, 0, 0.1441952884197235, 'round level 1')
#
# linear combination for min_raise :
#     (3.260719060897827, 1, 3.260719060897827, 'btn distance=6')
#     (-2.265869140625, 1, -2.265869140625, 'round level 2')
#     (-2.187678098678589, 1, -2.187678098678589, 'player-0:state-active')
#     (-2.066783, 0, 0, 'bias')
#     (0.8445892333984375, 1, 0.8445892333984375, 'street-flop')
#     (0.46856209169407514, 0.3145353455123114, 1.4896961450576782, 'player-0:history')
#     (0.46276387572288513, 1, 0.46276387572288513, 'player-1:state-fold')
#     (0.42541566491127014, 1, 0.42541566491127014, 'player-2:state-fold')
#     (0.38637688755989075, 1, 0.38637688755989075, 'player-3:state-fold')
#     (0.3530488605059926, 0.3161239078633836, 1.1168053150177002, 'player-8:history')
#     (-0.32693314644694327, 0.31475, -1.0387073755264282, 'pot')
#     (0.16605611145496368, 1, 0.16605611145496368, 'player-5:state-fold')
#     (-0.1362907588481903, 1, -0.1362907588481903, 'player-7:state-fold')
#     (-0.11893913894891739, 1, -0.11893913894891739, 'player-8:state-active')
#     (0.11001203209161758, 1, 0.11001203209161758, 'player-4:state-fold')
#     (0.092982649798512895, 0.61656016111373901, 0.15080872178077698, 'cards')
#     (-0.08339947199821471, 0.0715, -1.166426181793213, 'player-4:stack')
#     (-0.07363963812589645, 0.09775, -0.7533466815948486, 'player-6:stack')
#     (-0.06883848264813423, 0.0925, -0.744199812412262, 'player-7:stack')
#     (0.06474278122186661, 1, 0.06474278122186661, 'player-6:state-fold')
#     (-0.0632280445843935, 0.06625, -0.9543855786323547, 'player-5:stack')
#     (-0.06303411722183228, 0.1, -0.6303411722183228, 'player-2:stack')
#     (-0.06111159920692444, 0.1, -0.6111159920692444, 'player-1:stack')
#     (-0.04466812464594841, 0.05575, -0.8012219667434692, 'player-9:stack')
#     (-0.037508597970008856, 0.1, -0.3750859797000885, 'player-3:stack')
#     (0.011712395586073399, 1, 0.011712395586073399, 'player-9:state-fold')
#     (0.0010889238119125367, 0.001, 1.0889238119125366, 'player-0:stack')
#     (-0.00028910580277442935, 0.0005, -0.5782116055488586, 'player-8:stack')
#     (0.0, 0.0, 1.1892704963684082, 'player-9:history')
#     (0.0, 0, 0.02560107409954071, 'player-9:state-active')
#     (-0.0, 0, -0.13986387848854065, 'player-8:state-fold')
#     (0.0, 0.0, 1.2528365850448608, 'player-7:history')
#     (-0.0, 0, -0.055880334228277206, 'player-7:state-active')
#     (0.0, 0.0, 1.501294732093811, 'player-6:history')
#     (0.0, 0, 0.12019430100917816, 'player-6:state-active')
#     (0.0, 0.0, 1.5000553131103516, 'player-5:history')
#     (0.0, 0, 0.30910244584083557, 'player-5:state-active')
#     (0.0, 0.0, 1.4716317653656006, 'player-4:history')
#     (0.0, 0, 0.18452391028404236, 'player-4:state-active')
#     (0.0, 0.0, 1.5399361848831177, 'player-3:history')
#     (0.0, 0, 0.282500296831131, 'player-3:state-active')
#     (0.0, 0.0, 1.746171236038208, 'player-2:history')
#     (0.0, 0, 0.3998405933380127, 'player-2:state-active')
#     (0.0, 0.0, 1.468366026878357, 'player-1:history')
#     (0.0, 0, 0.464592844247818, 'player-1:state-active')
#     (-0.0, 0, -0.08319959789514542, 'player-0:state-fold')
#     (0.0, 0, 0.9790592193603516, 'street-river')
#     (0.0, 0, 0.9331514239311218, 'street-turn')
#     (0.0, 0, 0.86588454246521, 'street-preflop')
#     (0.0, 0, 1.4440168142318726, 'btn distance=9')
#     (0.0, 0, 0.6902648210525513, 'btn distance=8')
#     (0.0, 0, 0.6125809550285339, 'btn distance=7')
#     (0.0, 0, 3.378845453262329, 'btn distance=5')
#     (0.0, 0, 3.491258382797241, 'btn distance=4')
#     (0.0, 0, 3.366580009460449, 'btn distance=3')
#     (0.0, 0, 3.403568983078003, 'btn distance=2')
#     (0.0, 0, 3.3066458702087402, 'btn distance=1')
#     (0.0, 0, 3.3113150596618652, 'btn distance=0')
#     (0.0, 0, 0.1864863932132721, 'round level 27')
#     (-0.0, 0, -0.16429129242897034, 'round level 26')
#     (-0.0, 0, -0.046955082565546036, 'round level 25')
#     (-0.0, 0, -0.09106510132551193, 'round level 24')
#     (0.0, 0, 0.19359903037548065, 'round level 23')
#     (-0.0, 0, -0.1129482239484787, 'round level 22')
#     (-0.0, 0, -0.07924514263868332, 'round level 21')
#     (-0.0, 0, -0.07969773560762405, 'round level 20')
#     (-0.0, 0, -0.21454547345638275, 'round level 19')
#     (0.0, 0, 0.059178855270147324, 'round level 18')
#     (-0.0, 0, -0.03560476377606392, 'round level 17')
#     (0.0, 0, 0.007163514383137226, 'round level 16')
#     (-0.0, 0, -0.13512195646762848, 'round level 15')
#     (-0.0, 0, -0.1584649533033371, 'round level 14')
#     (0.0, 0, 0.15792712569236755, 'round level 13')
#     (-0.0, 0, -0.23586158454418182, 'round level 12')
#     (0.0, 0, 0.07051877677440643, 'round level 11')
#     (0.0, 0, 0.08433552831411362, 'round level 10')
#     (0.0, 0, 0.006170609965920448, 'round level 9')
#     (-0.0, 0, -0.07084600627422333, 'round level 8')
#     (0.0, 0, 0.11457421630620956, 'round level 7')
#     (0.0, 0, 0.08975376188755035, 'round level 6')
#     (-0.0, 0, -0.23617757856845856, 'round level 5')
#     (-0.0, 0, -0.22836115956306458, 'round level 4')
#     (0.0, 0, 0.048288315534591675, 'round level 3')
#     (-0.0, 0, -0.07394367456436157, 'round level 1')
#
# linear combination for max_raise :
#     (2.019573450088501, 1, 2.019573450088501, 'btn distance=6')
#     (-1.705495834350586, 1, -1.705495834350586, 'round level 2')
#     (-1.5685375, 0, 0, 'bias')
#     (-1.3696188926696777, 1, -1.3696188926696777, 'player-0:state-active')
#     (0.5559921860694885, 1, 0.5559921860694885, 'player-2:state-fold')
#     (0.5501344156606127, 0.3145353455123114, 1.7490384578704834, 'player-0:history')
#     (-0.4739885926246643, 1, -0.4739885926246643, 'player-8:state-active')
#     (0.4154148181342624, 0.3161239078633836, 1.3140885829925537, 'player-8:history')
#     (0.3845996558666229, 1, 0.3845996558666229, 'street-flop')
#     (0.30628910234161744, 0.61656016111373901, 0.49677082896232605, 'cards')
#     (0.18107010424137115, 1, 0.18107010424137115, 'player-4:state-fold')
#     (0.16990752518177032, 1, 0.16990752518177032, 'player-6:state-fold')
#     (0.16700617969036102, 1, 0.16700617969036102, 'player-3:state-fold')
#     (-0.1316184550523758, 1, -0.1316184550523758, 'player-9:state-fold')
#     (0.08285059034824371, 1, 0.08285059034824371, 'player-1:state-fold')
#     (-0.08156035667657853, 0.09775, -0.8343770503997803, 'player-6:stack')
#     (-0.06816240549087525, 0.1, -0.6816240549087524, 'player-3:stack')
#     (-0.06650218337774276, 0.0925, -0.7189425230026245, 'player-7:stack')
#     (-0.06366831293702126, 0.0715, -0.8904659152030945, 'player-4:stack')
#     (-0.06171972751617432, 0.1, -0.6171972751617432, 'player-1:stack')
#     (-0.06048037932440638, 0.31475, -0.1921537071466446, 'pot')
#     (-0.052268922328948975, 0.1, -0.5226892232894897, 'player-2:stack')
#     (-0.03210036826133728, 0.05575, -0.5757913589477539, 'player-9:stack')
#     (-0.03189263042062521, 0.06625, -0.48139819502830505, 'player-5:stack')
#     (-0.008543427102267742, 1, -0.008543427102267742, 'player-5:state-fold')
#     (-0.0054485369473695755, 1, -0.0054485369473695755, 'player-7:state-fold')
#     (0.001689018964767456, 0.001, 1.689018964767456, 'player-0:stack')
#     (-0.00033476319909095766, 0.0005, -0.6695263981819153, 'player-8:stack')
#     (0.0, 0.0, 1.294410228729248, 'player-9:history')
#     (-0.0, 0, -0.1723392754793167, 'player-9:state-active')
#     (-0.0, 0, -0.45327356457710266, 'player-8:state-fold')
#     (0.0, 0.0, 1.2852766513824463, 'player-7:history')
#     (0.0, 0, 0.009113033302128315, 'player-7:state-active')
#     (0.0, 0.0, 1.5812280178070068, 'player-6:history')
#     (0.0, 0, 0.2710704803466797, 'player-6:state-active')
#     (0.0, 0.0, 1.4836312532424927, 'player-5:history')
#     (0.0, 0, 0.050112057477235794, 'player-5:state-active')
#     (0.0, 0.0, 1.4741692543029785, 'player-4:history')
#     (0.0, 0, 0.1328335702419281, 'player-4:state-active')
#     (0.0, 0.0, 1.5749785900115967, 'player-3:history')
#     (0.0, 0, 0.18305647373199463, 'player-3:state-active')
#     (0.0, 0.0, 1.523707628250122, 'player-2:history')
#     (0.0, 0, 0.44320815801620483, 'player-2:state-active')
#     (0.0, 0.0, 1.399151086807251, 'player-1:history')
#     (0.0, 0, 0.03814220800995827, 'player-1:state-active')
#     (-0.0, 0, -0.07082012295722961, 'player-0:state-fold')
#     (0.0, 0, 0.6438460946083069, 'street-river')
#     (0.0, 0, 0.5357523560523987, 'street-turn')
#     (0.0, 0, 0.4439617693424225, 'street-preflop')
#     (0.0, 0, 1.0605579614639282, 'btn distance=9')
#     (0.0, 0, 0.5578138828277588, 'btn distance=8')
#     (0.0, 0, 0.3871185779571533, 'btn distance=7')
#     (0.0, 0, 2.1290736198425293, 'btn distance=5')
#     (0.0, 0, 2.1042659282684326, 'btn distance=4')
#     (0.0, 0, 2.0583226680755615, 'btn distance=3')
#     (0.0, 0, 1.996710181236267, 'btn distance=2')
#     (0.0, 0, 1.9347350597381592, 'btn distance=1')
#     (0.0, 0, 1.9695475101470947, 'btn distance=0')
#     (-0.0, 0, -0.0745745450258255, 'round level 27')
#     (0.0, 0, 0.015400783158838749, 'round level 26')
#     (0.0, 0, 0.1319204717874527, 'round level 25')
#     (-0.0, 0, -0.15635602176189423, 'round level 24')
#     (0.0, 0, 0.08905228227376938, 'round level 23')
#     (-0.0, 0, -0.10733900219202042, 'round level 22')
#     (0.0, 0, 0.02085469476878643, 'round level 21')
#     (0.0, 0, 0.24782584607601166, 'round level 20')
#     (-0.0, 0, -0.1948973387479782, 'round level 19')
#     (0.0, 0, 0.1771361082792282, 'round level 18')
#     (0.0, 0, 0.1400010585784912, 'round level 17')
#     (0.0, 0, 0.0674973577260971, 'round level 16')
#     (-0.0, 0, -0.16851937770843506, 'round level 15')
#     (-0.0, 0, -0.10289682447910309, 'round level 14')
#     (0.0, 0, 0.09751802682876587, 'round level 13')
#     (0.0, 0, 0.05579689145088196, 'round level 12')
#     (0.0, 0, 0.062262505292892456, 'round level 11')
#     (0.0, 0, 0.08422500640153885, 'round level 10')
#     (0.0, 0, 0.2191074788570404, 'round level 9')
#     (0.0, 0, 0.1968294382095337, 'round level 8')
#     (-0.0, 0, -0.1691485494375229, 'round level 7')
#     (0.0, 0, 0.08150830864906311, 'round level 6')
#     (0.0, 0, 0.008948147296905518, 'round level 5')
#     (-0.0, 0, -0.23150017857551575, 'round level 4')
#     (0.0, 0, 0.199162557721138, 'round level 3')
#     (0.0, 0, 0.1435113102197647, 'round level 1')

# %% [markdown]
# ### TRIPLE_RAISE

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 200
#   - raise: [225, 700]
# -- hole card --
#   - ['D9', 'HQ']
# -- round state --
#   - dealer btn : cpu5
#   - street : preflop
#   - community card : []
#   - pot : main = 625, side = [{'amount': 250, 'eligibles': ['uuid-6']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 7150
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 6475
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 35375
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 8675
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 28325 <= SB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 1325 <= BB
#     - 6 : agent (uuid-0) => state : participating, stack : 625 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : allin, stack : 0
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 1325
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 9850
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'agent (uuid=uuid-0)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 175, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 200, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 675 (triple_raise) ] at round 4
#   => [('fold', -0.24266517162322998), ('call', -0.46778345108032227), ('min_raise', -0.24985527992248535), ('double_raise', -0.5098457336425781), ('triple_raise', -0.17382657527923584), ('max_raise', -0.7720171213150024)]
# ** weights and features in detail **
# bias : [-1.17843068 -1.02286565 -2.06678295 -1.95017385 -1.70704675 -1.56853747]
#
# linear combination for fold :
#     (-1.218326449394226, 1, -1.218326449394226, 'player-0:state-active')
#     (-1.1784307, 0, 0, 'bias')
#     (-1.1665277481079102, 1, -1.1665277481079102, 'round level 2')
#     (1.1171241998672485, 1, 1.1171241998672485, 'btn distance=3')
#     (0.42502614855766296, 1, 0.42502614855766296, 'street-preflop')
#     (0.34629530225481303, 0.22857142857142856, 1.5150419473648071, 'player-8:history')
#     (0.31118364334106446, 0.2, 1.5559182167053223, 'player-7:history')
#     (0.27499473094940186, 1, 0.27499473094940186, 'player-5:state-fold')
#     (0.2540618828364781, 0.17142857142857143, 1.4820276498794556, 'player-3:history')
#     (0.2226452657154628, 0.14285714285714285, 1.5585168600082397, 'player-2:history')
#     (0.18702542781829834, 1, 0.18702542781829834, 'player-6:state-fold')
#     (0.17920615332467216, 0.11428571428571428, 1.5680538415908813, 'player-1:history')
#     (-0.17074503231793642, 0.35375, -0.48267146944999695, 'player-6:stack')
#     (0.13846465178898404, 0.08571428571428572, 1.615420937538147, 'player-0:history')
#     (-0.1357496767938137, 0.28325, -0.4792574644088745, 'player-8:stack')
#     (0.12093259394168854, 1, 0.12093259394168854, 'player-4:state-fold')
#     (0.10609544068574905, 1, 0.10609544068574905, 'player-7:state-active')
#     (0.08732421696186066, 1, 0.08732421696186066, 'player-3:state-active')
#     (0.07350452244281769, 1, 0.07350452244281769, 'player-8:state-active')
#     (-0.04972899615764618, 0.06475, -0.7680153846740723, 'player-5:stack')
#     (-0.04593181626498699, 0.0985, -0.46631285548210144, 'player-3:stack')
#     (0.04484445974230766, 1, 0.04484445974230766, 'player-9:state-fold')
#     (-0.042758043408393856, 0.0715, -0.5980145931243896, 'player-4:stack')
#     (-0.03854640280455351, 0.642, -0.06004112586379051, 'cards')
#     (-0.034962511934339996, 0.08675, -0.4030260741710663, 'player-7:stack')
#     (-0.030225859954953194, 1, -0.030225859954953194, 'player-1:state-active')
#     (-0.010440158657729626, 1, -0.010440158657729626, 'player-2:state-active')
#     (0.006557414680719376, 0.00625, 1.0491863489151, 'player-0:stack')
#     (-0.006107977867126465, 0.01325, -0.4609794616699219, 'player-9:stack')
#     (-0.004971413470804691, 0.01325, -0.375201016664505, 'player-2:stack')
#     (-0.00449855349957943, 0.00875, -0.5141203999519348, 'pot')
#     (0.0, 0.0, 1.5393073558807373, 'player-9:history')
#     (0.0, 0, 0.0024986343923956156, 'player-9:state-active')
#     (0.0, 0, 0.11467187851667404, 'player-8:state-fold')
#     (0.0, 0, 0.12127767503261566, 'player-7:state-fold')
#     (0.0, 0.0, 1.4221173524856567, 'player-6:history')
#     (0.0, 0, 0.1653481423854828, 'player-6:state-active')
#     (0.0, 0.0, 1.4401140213012695, 'player-5:history')
#     (0.0, 0, 0.24999964237213135, 'player-5:state-active')
#     (0.0, 0.0, 1.4575220346450806, 'player-4:history')
#     (0.0, 0, 0.11704733967781067, 'player-4:state-active')
#     (0.0, 0, 0.12527720630168915, 'player-3:state-fold')
#     (0.0, 0, 0.03868267685174942, 'player-2:state-fold')
#     (0.0, 0, 0.005368893034756184, 'player-1:state-fold')
#     (-0.0, 0.0, -0.4510365128517151, 'player-1:stack')
#     (0.0, 0, 0.13104617595672607, 'player-0:state-fold')
#     (0.0, 0, 0.5163982510566711, 'street-river')
#     (0.0, 0, 0.47896459698677063, 'street-turn')
#     (0.0, 0, 0.4114610552787781, 'street-flop')
#     (0.0, 0, 1.2318480014801025, 'btn distance=9')
#     (0.0, 0, 1.2068599462509155, 'btn distance=8')
#     (0.0, 0, 0.694226086139679, 'btn distance=7')
#     (0.0, 0, 0.9125367403030396, 'btn distance=6')
#     (0.0, 0, 0.980753481388092, 'btn distance=5')
#     (0.0, 0, 1.0374095439910889, 'btn distance=4')
#     (0.0, 0, 1.143062710762024, 'btn distance=2')
#     (0.0, 0, 1.1736388206481934, 'btn distance=1')
#     (0.0, 0, 1.194989800453186, 'btn distance=0')
#     (0.0, 0, 0.17381861805915833, 'round level 27')
#     (-0.0, 0, -0.1709413379430771, 'round level 26')
#     (0.0, 0, 0.23499497771263123, 'round level 25')
#     (0.0, 0, 0.2400972843170166, 'round level 24')
#     (0.0, 0, 0.07879160344600677, 'round level 23')
#     (-0.0, 0, -0.20467768609523773, 'round level 22')
#     (-0.0, 0, -0.02996756322681904, 'round level 21')
#     (0.0, 0, 0.021945780143141747, 'round level 20')
#     (-0.0, 0, -0.23729455471038818, 'round level 19')
#     (0.0, 0, 0.20108163356781006, 'round level 18')
#     (0.0, 0, 0.13430552184581757, 'round level 17')
#     (0.0, 0, 0.19009800255298615, 'round level 16')
#     (0.0, 0, 0.2580344080924988, 'round level 15')
#     (-0.0, 0, -0.0939929336309433, 'round level 14')
#     (-0.0, 0, -0.17090654373168945, 'round level 13')
#     (-0.0, 0, -0.06041152775287628, 'round level 12')
#     (0.0, 0, 0.07556843012571335, 'round level 11')
#     (0.0, 0, 0.008105643093585968, 'round level 10')
#     (-0.0, 0, -0.19526717066764832, 'round level 9')
#     (-0.0, 0, -0.09471932053565979, 'round level 8')
#     (-0.0, 0, -0.24805116653442383, 'round level 7')
#     (-0.0, 0, -0.05985160171985626, 'round level 6')
#     (0.0, 0, 0.16501252353191376, 'round level 5')
#     (0.0, 0, 0.1510487198829651, 'round level 4')
#     (-0.0, 0, -0.06887161731719971, 'round level 3')
#     (0.0, 0, 0.15396647155284882, 'round level 1')
#
# linear combination for call :
#     (1.9303548336029053, 1, 1.9303548336029053, 'btn distance=3')
#     (-1.267747163772583, 1, -1.267747163772583, 'round level 2')
#     (-1.0228657, 0, 0, 'bias')
#     (-0.815963625907898, 1, -0.815963625907898, 'player-0:state-active')
#     (0.30634018778800964, 1, 0.30634018778800964, 'street-preflop')
#     (0.25611098295450213, 0.642, 0.3989267647266388, 'cards')
#     (0.2195797711610794, 1, 0.2195797711610794, 'player-1:state-active')
#     (-0.20846495114266872, 0.35375, -0.5893002152442932, 'player-6:stack')
#     (-0.17343391478061676, 1, -0.17343391478061676, 'player-8:state-active')
#     (0.1515781581401825, 1, 0.1515781581401825, 'player-5:state-fold')
#     (-0.1419263482093811, 1, -0.1419263482093811, 'player-7:state-active')
#     (0.14029466084071568, 0.22857142857142856, 0.6137891411781311, 'player-8:history')
#     (0.12790261336735317, 0.17142857142857143, 0.7460985779762268, 'player-3:history')
#     (-0.12312944233417511, 1, -0.12312944233417511, 'player-4:state-fold')
#     (0.12211808477129255, 0.08571428571428572, 1.424710988998413, 'player-0:history')
#     (-0.12108041281998158, 0.28325, -0.42746835947036743, 'player-8:stack')
#     (0.10514569282531738, 0.2, 0.5257284641265869, 'player-7:history')
#     (0.08942410775593349, 0.14285714285714285, 0.6259687542915344, 'player-2:history')
#     (0.08468693494796753, 1, 0.08468693494796753, 'player-3:state-active')
#     (0.0693063872201102, 0.11428571428571428, 0.6064308881759644, 'player-1:history')
#     (-0.05289127305150032, 1, -0.05289127305150032, 'player-6:state-fold')
#     (-0.043379774719476696, 0.0715, -0.6067101359367371, 'player-4:stack')
#     (0.03985699266195297, 1, 0.03985699266195297, 'player-2:state-active')
#     (-0.035275062829256056, 0.08675, -0.40662896633148193, 'player-7:stack')
#     (-0.03461065436899662, 0.06475, -0.5345274806022644, 'player-5:stack')
#     (-0.0313279247134924, 0.0985, -0.31804999709129333, 'player-3:stack')
#     (-0.025723405182361603, 1, -0.025723405182361603, 'player-9:state-fold')
#     (0.008975518494844436, 0.00625, 1.4360829591751099, 'player-0:stack')
#     (-0.008825379312038422, 0.00875, -1.0086147785186768, 'pot')
#     (-0.0072384607046842575, 0.01325, -0.5462989211082458, 'player-9:stack')
#     (-0.0055751087740063664, 0.01325, -0.42076292634010315, 'player-2:stack')
#     (0.0, 0.0, 0.6379348039627075, 'player-9:history')
#     (-0.0, 0, -0.07787381112575531, 'player-9:state-active')
#     (-0.0, 0, -0.09087780117988586, 'player-8:state-fold')
#     (-0.0, 0, -0.21578086912631989, 'player-7:state-fold')
#     (0.0, 0.0, 0.7117400765419006, 'player-6:history')
#     (-0.0, 0, -0.08662305027246475, 'player-6:state-active')
#     (0.0, 0.0, 0.7330848574638367, 'player-5:history')
#     (0.0, 0, 0.25262734293937683, 'player-5:state-active')
#     (0.0, 0.0, 0.6583040952682495, 'player-4:history')
#     (-0.0, 0, -0.08420368283987045, 'player-4:state-active')
#     (0.0, 0, 0.14377835392951965, 'player-3:state-fold')
#     (0.0, 0, 0.04315764829516411, 'player-2:state-fold')
#     (0.0, 0, 0.19041743874549866, 'player-1:state-fold')
#     (-0.0, 0.0, -0.2920437455177307, 'player-1:stack')
#     (-0.0, 0, -0.20277541875839233, 'player-0:state-fold')
#     (0.0, 0, 0.24349345266819, 'street-river')
#     (0.0, 0, 0.2590084373950958, 'street-turn')
#     (0.0, 0, 0.2862991690635681, 'street-flop')
#     (0.0, 0, 1.1173243522644043, 'btn distance=9')
#     (0.0, 0, 0.30222782492637634, 'btn distance=8')
#     (-0.0, 0, -0.1371598094701767, 'btn distance=7')
#     (0.0, 0, 1.8035677671432495, 'btn distance=6')
#     (0.0, 0, 1.8697949647903442, 'btn distance=5')
#     (0.0, 0, 1.9579356908798218, 'btn distance=4')
#     (0.0, 0, 1.977090835571289, 'btn distance=2')
#     (0.0, 0, 1.8424537181854248, 'btn distance=1')
#     (0.0, 0, 1.8680459260940552, 'btn distance=0')
#     (0.0, 0, 0.07092714309692383, 'round level 27')
#     (-0.0, 0, -0.07035121321678162, 'round level 26')
#     (0.0, 0, 0.1974353939294815, 'round level 25')
#     (-0.0, 0, -0.13411521911621094, 'round level 24')
#     (-0.0, 0, -0.15498259663581848, 'round level 23')
#     (-0.0, 0, -0.128531351685524, 'round level 22')
#     (-0.0, 0, -0.19764813780784607, 'round level 21')
#     (-0.0, 0, -0.20146974921226501, 'round level 20')
#     (0.0, 0, 0.05624271556735039, 'round level 19')
#     (-0.0, 0, -0.11658086627721786, 'round level 18')
#     (-0.0, 0, -0.045278843492269516, 'round level 17')
#     (0.0, 0, 0.14562976360321045, 'round level 16')
#     (0.0, 0, 0.23023651540279388, 'round level 15')
#     (-0.0, 0, -0.048296328634023666, 'round level 14')
#     (-0.0, 0, -0.09172365069389343, 'round level 13')
#     (-0.0, 0, -0.06652963906526566, 'round level 12')
#     (0.0, 0, 0.10760240256786346, 'round level 11')
#     (-0.0, 0, -0.019141659140586853, 'round level 10')
#     (0.0, 0, 0.14686106145381927, 'round level 9')
#     (0.0, 0, 0.09601891785860062, 'round level 8')
#     (0.0, 0, 0.21756060421466827, 'round level 7')
#     (-0.0, 0, -0.052764762192964554, 'round level 6')
#     (-0.0, 0, -0.10461476445198059, 'round level 5')
#     (-0.0, 0, -0.16345806419849396, 'round level 4')
#     (-0.0, 0, -0.2176746279001236, 'round level 3')
#     (0.0, 0, 0.1441952884197235, 'round level 1')
#
# linear combination for min_raise :
#     (3.366580009460449, 1, 3.366580009460449, 'btn distance=3')
#     (-2.265869140625, 1, -2.265869140625, 'round level 2')
#     (-2.187678098678589, 1, -2.187678098678589, 'player-0:state-active')
#     (-2.066783, 0, 0, 'bias')
#     (0.86588454246521, 1, 0.86588454246521, 'street-preflop')
#     (0.464592844247818, 1, 0.464592844247818, 'player-1:state-active')
#     (0.3998405933380127, 1, 0.3998405933380127, 'player-2:state-active')
#     (0.282500296831131, 1, 0.282500296831131, 'player-3:state-active')
#     (-0.26649638861417774, 0.35375, -0.7533466815948486, 'player-6:stack')
#     (0.2639890602656773, 0.17142857142857143, 1.5399361848831177, 'player-3:history')
#     (0.25526978628976005, 0.22857142857142856, 1.1168053150177002, 'player-8:history')
#     (0.25056731700897217, 0.2, 1.2528365850448608, 'player-7:history')
#     (0.24945303371974398, 0.14285714285714285, 1.746171236038208, 'player-2:history')
#     (0.16781326021466936, 0.11428571428571428, 1.468366026878357, 'player-1:history')
#     (0.16605611145496368, 1, 0.16605611145496368, 'player-5:state-fold')
#     (-0.1637784372717142, 0.28325, -0.5782116055488586, 'player-8:stack')
#     (0.12768824100494386, 0.08571428571428572, 1.4896961450576782, 'player-0:history')
#     (-0.11893913894891739, 1, -0.11893913894891739, 'player-8:state-active')
#     (0.11001203209161758, 1, 0.11001203209161758, 'player-4:state-fold')
#     (0.09681919938325882, 0.642, 0.15080872178077698, 'cards')
#     (-0.08339947199821471, 0.0715, -1.166426181793213, 'player-4:stack')
#     (0.06474278122186661, 1, 0.06474278122186661, 'player-6:state-fold')
#     (-0.06455933372676372, 0.08675, -0.744199812412262, 'player-7:stack')
#     (-0.061796466216444974, 0.06475, -0.9543855786323547, 'player-5:stack')
#     (-0.055880334228277206, 1, -0.055880334228277206, 'player-7:state-active')
#     (-0.03694596900045872, 0.0985, -0.3750859797000885, 'player-3:stack')
#     (0.011712395586073399, 1, 0.011712395586073399, 'player-9:state-fold')
#     (-0.010616191059350967, 0.01325, -0.8012219667434692, 'player-9:stack')
#     (-0.009088689535856247, 0.00875, -1.0387073755264282, 'pot')
#     (-0.008352020531892776, 0.01325, -0.6303411722183228, 'player-2:stack')
#     (0.006805773824453354, 0.00625, 1.0889238119125366, 'player-0:stack')
#     (0.0, 0.0, 1.1892704963684082, 'player-9:history')
#     (0.0, 0, 0.02560107409954071, 'player-9:state-active')
#     (-0.0, 0, -0.13986387848854065, 'player-8:state-fold')
#     (-0.0, 0, -0.1362907588481903, 'player-7:state-fold')
#     (0.0, 0.0, 1.501294732093811, 'player-6:history')
#     (0.0, 0, 0.12019430100917816, 'player-6:state-active')
#     (0.0, 0.0, 1.5000553131103516, 'player-5:history')
#     (0.0, 0, 0.30910244584083557, 'player-5:state-active')
#     (0.0, 0.0, 1.4716317653656006, 'player-4:history')
#     (0.0, 0, 0.18452391028404236, 'player-4:state-active')
#     (0.0, 0, 0.38637688755989075, 'player-3:state-fold')
#     (0.0, 0, 0.42541566491127014, 'player-2:state-fold')
#     (0.0, 0, 0.46276387572288513, 'player-1:state-fold')
#     (-0.0, 0.0, -0.6111159920692444, 'player-1:stack')
#     (-0.0, 0, -0.08319959789514542, 'player-0:state-fold')
#     (0.0, 0, 0.9790592193603516, 'street-river')
#     (0.0, 0, 0.9331514239311218, 'street-turn')
#     (0.0, 0, 0.8445892333984375, 'street-flop')
#     (0.0, 0, 1.4440168142318726, 'btn distance=9')
#     (0.0, 0, 0.6902648210525513, 'btn distance=8')
#     (0.0, 0, 0.6125809550285339, 'btn distance=7')
#     (0.0, 0, 3.260719060897827, 'btn distance=6')
#     (0.0, 0, 3.378845453262329, 'btn distance=5')
#     (0.0, 0, 3.491258382797241, 'btn distance=4')
#     (0.0, 0, 3.403568983078003, 'btn distance=2')
#     (0.0, 0, 3.3066458702087402, 'btn distance=1')
#     (0.0, 0, 3.3113150596618652, 'btn distance=0')
#     (0.0, 0, 0.1864863932132721, 'round level 27')
#     (-0.0, 0, -0.16429129242897034, 'round level 26')
#     (-0.0, 0, -0.046955082565546036, 'round level 25')
#     (-0.0, 0, -0.09106510132551193, 'round level 24')
#     (0.0, 0, 0.19359903037548065, 'round level 23')
#     (-0.0, 0, -0.1129482239484787, 'round level 22')
#     (-0.0, 0, -0.07924514263868332, 'round level 21')
#     (-0.0, 0, -0.07969773560762405, 'round level 20')
#     (-0.0, 0, -0.21454547345638275, 'round level 19')
#     (0.0, 0, 0.059178855270147324, 'round level 18')
#     (-0.0, 0, -0.03560476377606392, 'round level 17')
#     (0.0, 0, 0.007163514383137226, 'round level 16')
#     (-0.0, 0, -0.13512195646762848, 'round level 15')
#     (-0.0, 0, -0.1584649533033371, 'round level 14')
#     (0.0, 0, 0.15792712569236755, 'round level 13')
#     (-0.0, 0, -0.23586158454418182, 'round level 12')
#     (0.0, 0, 0.07051877677440643, 'round level 11')
#     (0.0, 0, 0.08433552831411362, 'round level 10')
#     (0.0, 0, 0.006170609965920448, 'round level 9')
#     (-0.0, 0, -0.07084600627422333, 'round level 8')
#     (0.0, 0, 0.11457421630620956, 'round level 7')
#     (0.0, 0, 0.08975376188755035, 'round level 6')
#     (-0.0, 0, -0.23617757856845856, 'round level 5')
#     (-0.0, 0, -0.22836115956306458, 'round level 4')
#     (0.0, 0, 0.048288315534591675, 'round level 3')
#     (-0.0, 0, -0.07394367456436157, 'round level 1')
#
# linear combination for double_raise :
#     (2.9180355072021484, 1, 2.9180355072021484, 'btn distance=3')
#     (-1.9725971221923828, 1, -1.9725971221923828, 'round level 2')
#     (-1.9501739, 0, 0, 'bias')
#     (-1.7458921670913696, 1, -1.7458921670913696, 'player-0:state-active')
#     (0.7431500554084778, 1, 0.7431500554084778, 'street-preflop')
#     (0.5919350385665894, 1, 0.5919350385665894, 'player-3:state-active')
#     (0.5230585932731628, 1, 0.5230585932731628, 'player-1:state-active')
#     (-0.4729435548186302, 0.35375, -1.3369429111480713, 'player-6:stack')
#     (0.33568552136421204, 1, 0.33568552136421204, 'player-4:state-fold')
#     (-0.30509152355790137, 0.28325, -1.0771104097366333, 'player-8:stack')
#     (0.240573365347726, 0.17142857142857143, 1.4033446311950684, 'player-3:history')
#     (0.22778953824724468, 0.14285714285714285, 1.594526767730713, 'player-2:history')
#     (0.204587527683803, 0.22857142857142856, 0.8950704336166382, 'player-8:history')
#     (0.18749094009399414, 0.2, 0.9374547004699707, 'player-7:history')
#     (0.1696426421403885, 1, 0.1696426421403885, 'player-5:state-fold')
#     (-0.16440437734127045, 1, -0.16440437734127045, 'player-8:state-active')
#     (0.15026326860700334, 0.11428571428571428, 1.3148036003112793, 'player-1:history')
#     (0.14463238418102264, 1, 0.14463238418102264, 'player-2:state-active')
#     (0.12394552677869797, 1, 0.12394552677869797, 'player-6:state-fold')
#     (-0.11788221186399458, 0.0715, -1.6487022638320923, 'player-4:stack')
#     (-0.10789618641138077, 1, -0.10789618641138077, 'player-7:state-active')
#     (0.10701542922428676, 0.08571428571428572, 1.2485133409500122, 'player-0:history')
#     (-0.10464112854003906, 0.08675, -1.20623779296875, 'player-7:stack')
#     (-0.10067204400897026, 0.06475, -1.5547806024551392, 'player-5:stack')
#     (-0.09918022072315216, 0.0985, -1.0069057941436768, 'player-3:stack')
#     (0.09327607619762421, 0.642, 0.1452898383140564, 'cards')
#     (-0.09042394906282425, 1, -0.09042394906282425, 'player-9:state-fold')
#     (-0.016333120077848436, 0.01325, -1.232688307762146, 'player-9:stack')
#     (-0.014926099866628647, 0.01325, -1.1264981031417847, 'player-2:stack')
#     (-0.011616404056549073, 0.00875, -1.3275890350341797, 'pot')
#     (0.0037464704364538193, 0.00625, 0.5994352698326111, 'player-0:stack')
#     (0.0, 0.0, 0.8752785325050354, 'player-9:history')
#     (-0.0, 0, -0.016730034723877907, 'player-9:state-active')
#     (-0.0, 0, -0.22285068035125732, 'player-8:state-fold')
#     (-0.0, 0, -0.0851152092218399, 'player-7:state-fold')
#     (0.0, 0.0, 1.3802375793457031, 'player-6:history')
#     (0.0, 0, 0.12281614542007446, 'player-6:state-active')
#     (0.0, 0.0, 1.2917776107788086, 'player-5:history')
#     (0.0, 0, 0.28965461254119873, 'player-5:state-active')
#     (0.0, 0.0, 1.2546406984329224, 'player-4:history')
#     (0.0, 0, 0.37250587344169617, 'player-4:state-active')
#     (0.0, 0, 0.6927028298377991, 'player-3:state-fold')
#     (0.0, 0, 0.24494382739067078, 'player-2:state-fold')
#     (0.0, 0, 0.6143580079078674, 'player-1:state-fold')
#     (-0.0, 0.0, -1.0957398414611816, 'player-1:stack')
#     (-0.0, 0, -0.19295382499694824, 'player-0:state-fold')
#     (0.0, 0, 0.8448724150657654, 'street-river')
#     (0.0, 0, 0.8965580463409424, 'street-turn')
#     (0.0, 0, 0.7743945121765137, 'street-flop')
#     (0.0, 0, 1.0809276103973389, 'btn distance=9')
#     (0.0, 0, 0.33288007974624634, 'btn distance=8')
#     (0.0, 0, 0.16215811669826508, 'btn distance=7')
#     (0.0, 0, 2.787144184112549, 'btn distance=6')
#     (0.0, 0, 2.851736068725586, 'btn distance=5')
#     (0.0, 0, 2.869692802429199, 'btn distance=4')
#     (0.0, 0, 2.906381368637085, 'btn distance=2')
#     (0.0, 0, 2.693354368209839, 'btn distance=1')
#     (0.0, 0, 2.7792532444000244, 'btn distance=0')
#     (0.0, 0, 0.15659865736961365, 'round level 27')
#     (-0.0, 0, -0.05769524350762367, 'round level 26')
#     (0.0, 0, 0.060281381011009216, 'round level 25')
#     (0.0, 0, 0.12171455472707748, 'round level 24')
#     (0.0, 0, 0.2290050983428955, 'round level 23')
#     (-0.0, 0, -0.11531021445989609, 'round level 22')
#     (-0.0, 0, -0.2500810921192169, 'round level 21')
#     (0.0, 0, 0.007750209420919418, 'round level 20')
#     (0.0, 0, 0.13105927407741547, 'round level 19')
#     (-0.0, 0, -0.08005983382463455, 'round level 18')
#     (0.0, 0, 0.21569842100143433, 'round level 17')
#     (-0.0, 0, -0.16492699086666107, 'round level 16')
#     (0.0, 0, 0.1520710587501526, 'round level 15')
#     (-0.0, 0, -0.1770043522119522, 'round level 14')
#     (0.0, 0, 0.04302123188972473, 'round level 13')
#     (-0.0, 0, -0.20310285687446594, 'round level 12')
#     (-0.0, 0, -0.017459731549024582, 'round level 11')
#     (0.0, 0, 0.1835925579071045, 'round level 10')
#     (0.0, 0, 0.05069294944405556, 'round level 9')
#     (0.0, 0, 0.03629465401172638, 'round level 8')
#     (-0.0, 0, -0.0857870876789093, 'round level 7')
#     (0.0, 0, 0.20314936339855194, 'round level 6')
#     (0.0, 0, 0.24049139022827148, 'round level 5')
#     (0.0, 0, 0.22036118805408478, 'round level 4')
#     (-0.0, 0, -0.12533701956272125, 'round level 3')
#     (0.0, 0, 0.17443950474262238, 'round level 1')
#
# linear combination for triple_raise :
#     (2.7740681171417236, 1, 2.7740681171417236, 'btn distance=3')
#     (-1.8829259872436523, 1, -1.8829259872436523, 'player-0:state-active')
#     (-1.7070467, 0, 0, 'bias')
#     (-1.7052208185195923, 1, -1.7052208185195923, 'round level 2')
#     (0.6542556285858154, 1, 0.6542556285858154, 'street-preflop')
#     (0.3858034908771515, 1, 0.3858034908771515, 'player-5:state-fold')
#     (-0.3747518146038056, 0.35375, -1.0593690872192383, 'player-6:stack')
#     (0.36300328373908997, 1, 0.36300328373908997, 'player-2:state-active')
#     (0.287477970123291, 1, 0.287477970123291, 'player-1:state-active')
#     (0.25785180926322937, 1, 0.25785180926322937, 'player-3:state-active')
#     (0.25392772129603797, 0.17142857142857143, 1.4812450408935547, 'player-3:history')
#     (-0.2453663025200367, 0.28325, -0.8662534952163696, 'player-8:stack')
#     (0.22427595683506557, 0.22857142857142856, 0.9812073111534119, 'player-8:history')
#     (0.2052279540470668, 0.14285714285714285, 1.4365956783294678, 'player-2:history')
#     (0.15441195666790009, 1, 0.15441195666790009, 'player-4:state-fold')
#     (0.15178783237934113, 1, 0.15178783237934113, 'player-6:state-fold')
#     (0.14552956989833285, 0.11428571428571428, 1.2733837366104126, 'player-1:history')
#     (0.143082857131958, 0.2, 0.71541428565979, 'player-7:history')
#     (-0.10699752646684646, 0.0715, -1.4964689016342163, 'player-4:stack')
#     (0.10115792602300644, 1, 0.10115792602300644, 'player-9:state-fold')
#     (-0.09874407947063446, 1, -0.09874407947063446, 'player-7:state-active')
#     (-0.09482657912373543, 0.0985, -0.9627063870429993, 'player-3:stack')
#     (0.09142099448612759, 0.08571428571428572, 1.0665782690048218, 'player-0:history')
#     (-0.08893565264344215, 0.06475, -1.3735235929489136, 'player-5:stack')
#     (0.08433828234672547, 0.642, 0.13136804103851318, 'cards')
#     (-0.07294175674021243, 0.08675, -0.8408271670341492, 'player-7:stack')
#     (-0.04559437185525894, 1, -0.04559437185525894, 'player-8:state-active')
#     (-0.013661246210336684, 0.01325, -1.031037449836731, 'player-9:stack')
#     (-0.012637832924723626, 0.01325, -0.9537987112998962, 'player-2:stack')
#     (-0.007065840438008309, 0.00875, -0.8075246214866638, 'pot')
#     (0.00526849552989006, 0.00625, 0.8429592847824097, 'player-0:stack')
#     (0.0, 0.0, 0.9000421762466431, 'player-9:history')
#     (0.0, 0, 0.13206961750984192, 'player-9:state-active')
#     (-0.0, 0, -0.060533251613378525, 'player-8:state-fold')
#     (-0.0, 0, -0.22947770357131958, 'player-7:state-fold')
#     (0.0, 0.0, 1.5047212839126587, 'player-6:history')
#     (0.0, 0, 0.06523146480321884, 'player-6:state-active')
#     (0.0, 0.0, 1.3838133811950684, 'player-5:history')
#     (0.0, 0, 0.45491641759872437, 'player-5:state-active')
#     (0.0, 0.0, 1.222939372062683, 'player-4:history')
#     (0.0, 0, 0.1671353280544281, 'player-4:state-active')
#     (0.0, 0, 0.4172688126564026, 'player-3:state-fold')
#     (0.0, 0, 0.4363452196121216, 'player-2:state-fold')
#     (0.0, 0, 0.38805511593818665, 'player-1:state-fold')
#     (-0.0, 0.0, -1.0582003593444824, 'player-1:stack')
#     (-0.0, 0, -0.16879042983055115, 'player-0:state-fold')
#     (0.0, 0, 0.7164437174797058, 'street-river')
#     (0.0, 0, 0.734492838382721, 'street-turn')
#     (0.0, 0, 0.6086469292640686, 'street-flop')
#     (0.0, 0, 0.9314766526222229, 'btn distance=9')
#     (0.0, 0, 0.2717871069908142, 'btn distance=8')
#     (0.0, 0, 0.3050857186317444, 'btn distance=7')
#     (0.0, 0, 2.627833127975464, 'btn distance=6')
#     (0.0, 0, 2.7287395000457764, 'btn distance=5')
#     (0.0, 0, 2.8521649837493896, 'btn distance=4')
#     (0.0, 0, 2.6455600261688232, 'btn distance=2')
#     (0.0, 0, 2.4956750869750977, 'btn distance=1')
#     (0.0, 0, 2.534360647201538, 'btn distance=0')
#     (-0.0, 0, -0.03168884664773941, 'round level 27')
#     (-0.0, 0, -0.017876192927360535, 'round level 26')
#     (0.0, 0, 0.24670392274856567, 'round level 25')
#     (0.0, 0, 0.23704470694065094, 'round level 24')
#     (-0.0, 0, -0.12388164550065994, 'round level 23')
#     (-0.0, 0, -0.21403175592422485, 'round level 22')
#     (-0.0, 0, -0.2394574135541916, 'round level 21')
#     (0.0, 0, 0.2087094932794571, 'round level 20')
#     (0.0, 0, 0.016761131584644318, 'round level 19')
#     (0.0, 0, 0.03723394498229027, 'round level 18')
#     (0.0, 0, 0.06718005239963531, 'round level 17')
#     (0.0, 0, 0.195980042219162, 'round level 16')
#     (0.0, 0, 0.04985208436846733, 'round level 15')
#     (0.0, 0, 0.18927551805973053, 'round level 14')
#     (-0.0, 0, -0.22544996440410614, 'round level 13')
#     (-0.0, 0, -0.07048213481903076, 'round level 12')
#     (0.0, 0, 0.1204707995057106, 'round level 11')
#     (-0.0, 0, -0.05045364424586296, 'round level 10')
#     (0.0, 0, 0.1273985356092453, 'round level 9')
#     (-0.0, 0, -0.06570541113615036, 'round level 8')
#     (0.0, 0, 0.09865906834602356, 'round level 7')
#     (-0.0, 0, -0.1552954465150833, 'round level 6')
#     (-0.0, 0, -0.11621785163879395, 'round level 5')
#     (0.0, 0, 0.14041194319725037, 'round level 4')
#     (0.0, 0, 0.005522481631487608, 'round level 3')
#     (-0.0, 0, -0.18949121236801147, 'round level 1')
#
# linear combination for max_raise :
#     (2.0583226680755615, 1, 2.0583226680755615, 'btn distance=3')
#     (-1.705495834350586, 1, -1.705495834350586, 'round level 2')
#     (-1.5685375, 0, 0, 'bias')
#     (-1.3696188926696777, 1, -1.3696188926696777, 'player-0:state-active')
#     (-0.4739885926246643, 1, -0.4739885926246643, 'player-8:state-active')
#     (0.4439617693424225, 1, 0.4439617693424225, 'street-preflop')
#     (0.44320815801620483, 1, 0.44320815801620483, 'player-2:state-active')
#     (0.3189268721938133, 0.642, 0.49677082896232605, 'cards')
#     (0.3003631046840123, 0.22857142857142856, 1.3140885829925537, 'player-8:history')
#     (-0.2951608815789223, 0.35375, -0.8343770503997803, 'player-6:stack')
#     (0.26999632971627374, 0.17142857142857143, 1.5749785900115967, 'player-3:history')
#     (0.25705533027648925, 0.2, 1.2852766513824463, 'player-7:history')
#     (0.217672518321446, 0.14285714285714285, 1.523707628250122, 'player-2:history')
#     (-0.18964335228502752, 0.28325, -0.6695263981819153, 'player-8:stack')
#     (0.18305647373199463, 1, 0.18305647373199463, 'player-3:state-active')
#     (0.18107010424137115, 1, 0.18107010424137115, 'player-4:state-fold')
#     (0.16990752518177032, 1, 0.16990752518177032, 'player-6:state-fold')
#     (0.15990298134940012, 0.11428571428571428, 1.399151086807251, 'player-1:history')
#     (0.1499175821031843, 0.08571428571428572, 1.7490384578704834, 'player-0:history')
#     (-0.1316184550523758, 1, -0.1316184550523758, 'player-9:state-fold')
#     (-0.06713996940851212, 0.0985, -0.6816240549087524, 'player-3:stack')
#     (-0.06366831293702126, 0.0715, -0.8904659152030945, 'player-4:stack')
#     (-0.06236826387047767, 0.08675, -0.7189425230026245, 'player-7:stack')
#     (0.03814220800995827, 1, 0.03814220800995827, 'player-1:state-active')
#     (-0.031170533128082753, 0.06475, -0.48139819502830505, 'player-5:stack')
#     (0.0105563685297966, 0.00625, 1.689018964767456, 'player-0:stack')
#     (0.009113033302128315, 1, 0.009113033302128315, 'player-7:state-active')
#     (-0.008543427102267742, 1, -0.008543427102267742, 'player-5:state-fold')
#     (-0.007629235506057739, 0.01325, -0.5757913589477539, 'player-9:stack')
#     (-0.006925632208585739, 0.01325, -0.5226892232894897, 'player-2:stack')
#     (-0.0016813449375331403, 0.00875, -0.1921537071466446, 'pot')
#     (0.0, 0.0, 1.294410228729248, 'player-9:history')
#     (-0.0, 0, -0.1723392754793167, 'player-9:state-active')
#     (-0.0, 0, -0.45327356457710266, 'player-8:state-fold')
#     (-0.0, 0, -0.0054485369473695755, 'player-7:state-fold')
#     (0.0, 0.0, 1.5812280178070068, 'player-6:history')
#     (0.0, 0, 0.2710704803466797, 'player-6:state-active')
#     (0.0, 0.0, 1.4836312532424927, 'player-5:history')
#     (0.0, 0, 0.050112057477235794, 'player-5:state-active')
#     (0.0, 0.0, 1.4741692543029785, 'player-4:history')
#     (0.0, 0, 0.1328335702419281, 'player-4:state-active')
#     (0.0, 0, 0.16700617969036102, 'player-3:state-fold')
#     (0.0, 0, 0.5559921860694885, 'player-2:state-fold')
#     (0.0, 0, 0.08285059034824371, 'player-1:state-fold')
#     (-0.0, 0.0, -0.6171972751617432, 'player-1:stack')
#     (-0.0, 0, -0.07082012295722961, 'player-0:state-fold')
#     (0.0, 0, 0.6438460946083069, 'street-river')
#     (0.0, 0, 0.5357523560523987, 'street-turn')
#     (0.0, 0, 0.3845996558666229, 'street-flop')
#     (0.0, 0, 1.0605579614639282, 'btn distance=9')
#     (0.0, 0, 0.5578138828277588, 'btn distance=8')
#     (0.0, 0, 0.3871185779571533, 'btn distance=7')
#     (0.0, 0, 2.019573450088501, 'btn distance=6')
#     (0.0, 0, 2.1290736198425293, 'btn distance=5')
#     (0.0, 0, 2.1042659282684326, 'btn distance=4')
#     (0.0, 0, 1.996710181236267, 'btn distance=2')
#     (0.0, 0, 1.9347350597381592, 'btn distance=1')
#     (0.0, 0, 1.9695475101470947, 'btn distance=0')
#     (-0.0, 0, -0.0745745450258255, 'round level 27')
#     (0.0, 0, 0.015400783158838749, 'round level 26')
#     (0.0, 0, 0.1319204717874527, 'round level 25')
#     (-0.0, 0, -0.15635602176189423, 'round level 24')
#     (0.0, 0, 0.08905228227376938, 'round level 23')
#     (-0.0, 0, -0.10733900219202042, 'round level 22')
#     (0.0, 0, 0.02085469476878643, 'round level 21')
#     (0.0, 0, 0.24782584607601166, 'round level 20')
#     (-0.0, 0, -0.1948973387479782, 'round level 19')
#     (0.0, 0, 0.1771361082792282, 'round level 18')
#     (0.0, 0, 0.1400010585784912, 'round level 17')
#     (0.0, 0, 0.0674973577260971, 'round level 16')
#     (-0.0, 0, -0.16851937770843506, 'round level 15')
#     (-0.0, 0, -0.10289682447910309, 'round level 14')
#     (0.0, 0, 0.09751802682876587, 'round level 13')
#     (0.0, 0, 0.05579689145088196, 'round level 12')
#     (0.0, 0, 0.062262505292892456, 'round level 11')
#     (0.0, 0, 0.08422500640153885, 'round level 10')
#     (0.0, 0, 0.2191074788570404, 'round level 9')
#     (0.0, 0, 0.1968294382095337, 'round level 8')
#     (-0.0, 0, -0.1691485494375229, 'round level 7')
#     (0.0, 0, 0.08150830864906311, 'round level 6')
#     (0.0, 0, 0.008948147296905518, 'round level 5')
#     (-0.0, 0, -0.23150017857551575, 'round level 4')
#     (0.0, 0, 0.199162557721138, 'round level 3')
#     (0.0, 0, 0.1435113102197647, 'round level 1')

# %% [markdown]
# ### FLOPでCALL

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [100, 100]
# -- hole card --
#   - ['C6', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : flop
#   - community card : ['DA', 'SJ', 'HK']
#   - pot : main = 31475, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 7150
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 6625 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9775 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9250
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 50
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 5575
#     - 6 : agent (uuid-0) => state : participating, stack : 100 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 175, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 200, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 225, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 675, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 750, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1175, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 1275, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1675, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 1800, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2175, 'player': 'agent (uuid=uuid-0)', 'amount': 2325, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2675, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 2850, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 3175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 3375, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 3900, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 4425, 'action': 'RAISE'}
#       - {'add_amount': 5475, 'paid': 7575, 'player': 'agent (uuid=uuid-0)', 'amount': 9900, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 9900, 'paid': 6000}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#     - flop
#       - {'add_amount': 50, 'paid': 50, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 50 (call) ] at round 1
#   => [('fold', -0.7961338758468628), ('call', -0.7830536365509033), ('min_raise', -0.9382864236831665), ('max_raise', -0.9083679914474487)]
# ** weights and features in detail **
# bias : [-1.17843068 -1.02286565 -2.06678295 -1.95017385 -1.70704675 -1.56853747]
#
# linear combination for fold :
#     (-1.218326449394226, 1, -1.218326449394226, 'player-0:state-active')
#     (-1.1784307, 0, 0, 'bias')
#     (-1.1665277481079102, 1, -1.1665277481079102, 'round level 2')
#     (0.9125367403030396, 1, 0.9125367403030396, 'btn distance=6')
#     (0.508106982736383, 0.3145353455123114, 1.615420937538147, 'player-0:history')
#     (0.4789409809779136, 0.3161239078633836, 1.5150419473648071, 'player-8:history')
#     (0.4114610552787781, 1, 0.4114610552787781, 'street-flop')
#     (0.27499473094940186, 1, 0.27499473094940186, 'player-5:state-fold')
#     (0.18702542781829834, 1, 0.18702542781829834, 'player-6:state-fold')
#     (-0.16181939588487146, 0.31475, -0.5141203999519348, 'pot')
#     (0.12527720630168915, 1, 0.12527720630168915, 'player-3:state-fold')
#     (0.12127767503261566, 1, 0.12127767503261566, 'player-7:state-fold')
#     (0.12093259394168854, 1, 0.12093259394168854, 'player-4:state-fold')
#     (0.07350452244281769, 1, 0.07350452244281769, 'player-8:state-active')
#     (-0.05088101923465729, 0.06625, -0.7680153846740723, 'player-5:stack')
#     (-0.0471811361387372, 0.09775, -0.48267146944999695, 'player-6:stack')
#     (-0.046631285548210145, 0.1, -0.46631285548210144, 'player-3:stack')
#     (-0.04510365128517151, 0.1, -0.4510365128517151, 'player-1:stack')
#     (0.04484445974230766, 1, 0.04484445974230766, 'player-9:state-fold')
#     (-0.042758043408393856, 0.0715, -0.5980145931243896, 'player-4:stack')
#     (-0.041738230301910262, 0.69516068696975708, -0.06004112586379051, 'cards')
#     (0.03868267685174942, 1, 0.03868267685174942, 'player-2:state-fold')
#     (-0.037520101666450506, 0.1, -0.375201016664505, 'player-2:stack')
#     (-0.037279911860823634, 0.0925, -0.4030260741710663, 'player-7:stack')
#     (-0.025699604988098146, 0.05575, -0.4609794616699219, 'player-9:stack')
#     (0.005368893034756184, 1, 0.005368893034756184, 'player-1:state-fold')
#     (0.0010491863489151, 0.001, 1.0491863489151, 'player-0:stack')
#     (-0.00023962873220443725, 0.0005, -0.4792574644088745, 'player-8:stack')
#     (0.0, 0.0, 1.5393073558807373, 'player-9:history')
#     (0.0, 0, 0.0024986343923956156, 'player-9:state-active')
#     (0.0, 0, 0.11467187851667404, 'player-8:state-fold')
#     (0.0, 0.0, 1.5559182167053223, 'player-7:history')
#     (0.0, 0, 0.10609544068574905, 'player-7:state-active')
#     (0.0, 0.0, 1.4221173524856567, 'player-6:history')
#     (0.0, 0, 0.1653481423854828, 'player-6:state-active')
#     (0.0, 0.0, 1.4401140213012695, 'player-5:history')
#     (0.0, 0, 0.24999964237213135, 'player-5:state-active')
#     (0.0, 0.0, 1.4575220346450806, 'player-4:history')
#     (0.0, 0, 0.11704733967781067, 'player-4:state-active')
#     (0.0, 0.0, 1.4820276498794556, 'player-3:history')
#     (0.0, 0, 0.08732421696186066, 'player-3:state-active')
#     (0.0, 0.0, 1.5585168600082397, 'player-2:history')
#     (-0.0, 0, -0.010440158657729626, 'player-2:state-active')
#     (0.0, 0.0, 1.5680538415908813, 'player-1:history')
#     (-0.0, 0, -0.030225859954953194, 'player-1:state-active')
#     (0.0, 0, 0.13104617595672607, 'player-0:state-fold')
#     (0.0, 0, 0.5163982510566711, 'street-river')
#     (0.0, 0, 0.47896459698677063, 'street-turn')
#     (0.0, 0, 0.42502614855766296, 'street-preflop')
#     (0.0, 0, 1.2318480014801025, 'btn distance=9')
#     (0.0, 0, 1.2068599462509155, 'btn distance=8')
#     (0.0, 0, 0.694226086139679, 'btn distance=7')
#     (0.0, 0, 0.980753481388092, 'btn distance=5')
#     (0.0, 0, 1.0374095439910889, 'btn distance=4')
#     (0.0, 0, 1.1171241998672485, 'btn distance=3')
#     (0.0, 0, 1.143062710762024, 'btn distance=2')
#     (0.0, 0, 1.1736388206481934, 'btn distance=1')
#     (0.0, 0, 1.194989800453186, 'btn distance=0')
#     (0.0, 0, 0.17381861805915833, 'round level 27')
#     (-0.0, 0, -0.1709413379430771, 'round level 26')
#     (0.0, 0, 0.23499497771263123, 'round level 25')
#     (0.0, 0, 0.2400972843170166, 'round level 24')
#     (0.0, 0, 0.07879160344600677, 'round level 23')
#     (-0.0, 0, -0.20467768609523773, 'round level 22')
#     (-0.0, 0, -0.02996756322681904, 'round level 21')
#     (0.0, 0, 0.021945780143141747, 'round level 20')
#     (-0.0, 0, -0.23729455471038818, 'round level 19')
#     (0.0, 0, 0.20108163356781006, 'round level 18')
#     (0.0, 0, 0.13430552184581757, 'round level 17')
#     (0.0, 0, 0.19009800255298615, 'round level 16')
#     (0.0, 0, 0.2580344080924988, 'round level 15')
#     (-0.0, 0, -0.0939929336309433, 'round level 14')
#     (-0.0, 0, -0.17090654373168945, 'round level 13')
#     (-0.0, 0, -0.06041152775287628, 'round level 12')
#     (0.0, 0, 0.07556843012571335, 'round level 11')
#     (0.0, 0, 0.008105643093585968, 'round level 10')
#     (-0.0, 0, -0.19526717066764832, 'round level 9')
#     (-0.0, 0, -0.09471932053565979, 'round level 8')
#     (-0.0, 0, -0.24805116653442383, 'round level 7')
#     (-0.0, 0, -0.05985160171985626, 'round level 6')
#     (0.0, 0, 0.16501252353191376, 'round level 5')
#     (0.0, 0, 0.1510487198829651, 'round level 4')
#     (-0.0, 0, -0.06887161731719971, 'round level 3')
#     (0.0, 0, 0.15396647155284882, 'round level 1')
#
# linear combination for call :
#     (1.8035677671432495, 1, 1.8035677671432495, 'btn distance=6')
#     (-1.267747163772583, 1, -1.267747163772583, 'round level 2')
#     (-1.0228657, 0, 0, 'bias')
#     (-0.815963625907898, 1, -0.815963625907898, 'player-0:state-active')
#     (0.44812196317980274, 0.3145353455123114, 1.424710988998413, 'player-0:history')
#     (-0.31746150153875347, 0.31475, -1.0086147785186768, 'pot')
#     (0.2862991690635681, 1, 0.2862991690635681, 'street-flop')
#     (0.27731820381799288, 0.69516068696975708, 0.3989267647266388, 'cards')
#     (-0.21578086912631989, 1, -0.21578086912631989, 'player-7:state-fold')
#     (0.1940334219133409, 0.3161239078633836, 0.6137891411781311, 'player-8:history')
#     (0.19041743874549866, 1, 0.19041743874549866, 'player-1:state-fold')
#     (-0.17343391478061676, 1, -0.17343391478061676, 'player-8:state-active')
#     (0.1515781581401825, 1, 0.1515781581401825, 'player-5:state-fold')
#     (0.14377835392951965, 1, 0.14377835392951965, 'player-3:state-fold')
#     (-0.12312944233417511, 1, -0.12312944233417511, 'player-4:state-fold')
#     (-0.057604096040129664, 0.09775, -0.5893002152442932, 'player-6:stack')
#     (-0.05289127305150032, 1, -0.05289127305150032, 'player-6:state-fold')
#     (-0.043379774719476696, 0.0715, -0.6067101359367371, 'player-4:stack')
#     (0.04315764829516411, 1, 0.04315764829516411, 'player-2:state-fold')
#     (-0.04207629263401032, 0.1, -0.42076292634010315, 'player-2:stack')
#     (-0.037613179385662075, 0.0925, -0.40662896633148193, 'player-7:stack')
#     (-0.03541244558990002, 0.06625, -0.5345274806022644, 'player-5:stack')
#     (-0.03180499970912933, 0.1, -0.31804999709129333, 'player-3:stack')
#     (-0.030456164851784706, 0.05575, -0.5462989211082458, 'player-9:stack')
#     (-0.029204374551773073, 0.1, -0.2920437455177307, 'player-1:stack')
#     (-0.025723405182361603, 1, -0.025723405182361603, 'player-9:state-fold')
#     (0.00143608295917511, 0.001, 1.4360829591751099, 'player-0:stack')
#     (-0.00021373417973518372, 0.0005, -0.42746835947036743, 'player-8:stack')
#     (0.0, 0.0, 0.6379348039627075, 'player-9:history')
#     (-0.0, 0, -0.07787381112575531, 'player-9:state-active')
#     (-0.0, 0, -0.09087780117988586, 'player-8:state-fold')
#     (0.0, 0.0, 0.5257284641265869, 'player-7:history')
#     (-0.0, 0, -0.1419263482093811, 'player-7:state-active')
#     (0.0, 0.0, 0.7117400765419006, 'player-6:history')
#     (-0.0, 0, -0.08662305027246475, 'player-6:state-active')
#     (0.0, 0.0, 0.7330848574638367, 'player-5:history')
#     (0.0, 0, 0.25262734293937683, 'player-5:state-active')
#     (0.0, 0.0, 0.6583040952682495, 'player-4:history')
#     (-0.0, 0, -0.08420368283987045, 'player-4:state-active')
#     (0.0, 0.0, 0.7460985779762268, 'player-3:history')
#     (0.0, 0, 0.08468693494796753, 'player-3:state-active')
#     (0.0, 0.0, 0.6259687542915344, 'player-2:history')
#     (0.0, 0, 0.03985699266195297, 'player-2:state-active')
#     (0.0, 0.0, 0.6064308881759644, 'player-1:history')
#     (0.0, 0, 0.2195797711610794, 'player-1:state-active')
#     (-0.0, 0, -0.20277541875839233, 'player-0:state-fold')
#     (0.0, 0, 0.24349345266819, 'street-river')
#     (0.0, 0, 0.2590084373950958, 'street-turn')
#     (0.0, 0, 0.30634018778800964, 'street-preflop')
#     (0.0, 0, 1.1173243522644043, 'btn distance=9')
#     (0.0, 0, 0.30222782492637634, 'btn distance=8')
#     (-0.0, 0, -0.1371598094701767, 'btn distance=7')
#     (0.0, 0, 1.8697949647903442, 'btn distance=5')
#     (0.0, 0, 1.9579356908798218, 'btn distance=4')
#     (0.0, 0, 1.9303548336029053, 'btn distance=3')
#     (0.0, 0, 1.977090835571289, 'btn distance=2')
#     (0.0, 0, 1.8424537181854248, 'btn distance=1')
#     (0.0, 0, 1.8680459260940552, 'btn distance=0')
#     (0.0, 0, 0.07092714309692383, 'round level 27')
#     (-0.0, 0, -0.07035121321678162, 'round level 26')
#     (0.0, 0, 0.1974353939294815, 'round level 25')
#     (-0.0, 0, -0.13411521911621094, 'round level 24')
#     (-0.0, 0, -0.15498259663581848, 'round level 23')
#     (-0.0, 0, -0.128531351685524, 'round level 22')
#     (-0.0, 0, -0.19764813780784607, 'round level 21')
#     (-0.0, 0, -0.20146974921226501, 'round level 20')
#     (0.0, 0, 0.05624271556735039, 'round level 19')
#     (-0.0, 0, -0.11658086627721786, 'round level 18')
#     (-0.0, 0, -0.045278843492269516, 'round level 17')
#     (0.0, 0, 0.14562976360321045, 'round level 16')
#     (0.0, 0, 0.23023651540279388, 'round level 15')
#     (-0.0, 0, -0.048296328634023666, 'round level 14')
#     (-0.0, 0, -0.09172365069389343, 'round level 13')
#     (-0.0, 0, -0.06652963906526566, 'round level 12')
#     (0.0, 0, 0.10760240256786346, 'round level 11')
#     (-0.0, 0, -0.019141659140586853, 'round level 10')
#     (0.0, 0, 0.14686106145381927, 'round level 9')
#     (0.0, 0, 0.09601891785860062, 'round level 8')
#     (0.0, 0, 0.21756060421466827, 'round level 7')
#     (-0.0, 0, -0.052764762192964554, 'round level 6')
#     (-0.0, 0, -0.10461476445198059, 'round level 5')
#     (-0.0, 0, -0.16345806419849396, 'round level 4')
#     (-0.0, 0, -0.2176746279001236, 'round level 3')
#     (0.0, 0, 0.1441952884197235, 'round level 1')
#
# linear combination for min_raise :
#     (3.260719060897827, 1, 3.260719060897827, 'btn distance=6')
#     (-2.265869140625, 1, -2.265869140625, 'round level 2')
#     (-2.187678098678589, 1, -2.187678098678589, 'player-0:state-active')
#     (-2.066783, 0, 0, 'bias')
#     (0.8445892333984375, 1, 0.8445892333984375, 'street-flop')
#     (0.46856209169407514, 0.3145353455123114, 1.4896961450576782, 'player-0:history')
#     (0.46276387572288513, 1, 0.46276387572288513, 'player-1:state-fold')
#     (0.42541566491127014, 1, 0.42541566491127014, 'player-2:state-fold')
#     (0.38637688755989075, 1, 0.38637688755989075, 'player-3:state-fold')
#     (0.3530488605059926, 0.3161239078633836, 1.1168053150177002, 'player-8:history')
#     (-0.32693314644694327, 0.31475, -1.0387073755264282, 'pot')
#     (0.16605611145496368, 1, 0.16605611145496368, 'player-5:state-fold')
#     (-0.1362907588481903, 1, -0.1362907588481903, 'player-7:state-fold')
#     (-0.11893913894891739, 1, -0.11893913894891739, 'player-8:state-active')
#     (0.11001203209161758, 1, 0.11001203209161758, 'player-4:state-fold')
#     (0.10483629463415589, 0.69516068696975708, 0.15080872178077698, 'cards')
#     (-0.08339947199821471, 0.0715, -1.166426181793213, 'player-4:stack')
#     (-0.07363963812589645, 0.09775, -0.7533466815948486, 'player-6:stack')
#     (-0.06883848264813423, 0.0925, -0.744199812412262, 'player-7:stack')
#     (0.06474278122186661, 1, 0.06474278122186661, 'player-6:state-fold')
#     (-0.0632280445843935, 0.06625, -0.9543855786323547, 'player-5:stack')
#     (-0.06303411722183228, 0.1, -0.6303411722183228, 'player-2:stack')
#     (-0.06111159920692444, 0.1, -0.6111159920692444, 'player-1:stack')
#     (-0.04466812464594841, 0.05575, -0.8012219667434692, 'player-9:stack')
#     (-0.037508597970008856, 0.1, -0.3750859797000885, 'player-3:stack')
#     (0.011712395586073399, 1, 0.011712395586073399, 'player-9:state-fold')
#     (0.0010889238119125367, 0.001, 1.0889238119125366, 'player-0:stack')
#     (-0.00028910580277442935, 0.0005, -0.5782116055488586, 'player-8:stack')
#     (0.0, 0.0, 1.1892704963684082, 'player-9:history')
#     (0.0, 0, 0.02560107409954071, 'player-9:state-active')
#     (-0.0, 0, -0.13986387848854065, 'player-8:state-fold')
#     (0.0, 0.0, 1.2528365850448608, 'player-7:history')
#     (-0.0, 0, -0.055880334228277206, 'player-7:state-active')
#     (0.0, 0.0, 1.501294732093811, 'player-6:history')
#     (0.0, 0, 0.12019430100917816, 'player-6:state-active')
#     (0.0, 0.0, 1.5000553131103516, 'player-5:history')
#     (0.0, 0, 0.30910244584083557, 'player-5:state-active')
#     (0.0, 0.0, 1.4716317653656006, 'player-4:history')
#     (0.0, 0, 0.18452391028404236, 'player-4:state-active')
#     (0.0, 0.0, 1.5399361848831177, 'player-3:history')
#     (0.0, 0, 0.282500296831131, 'player-3:state-active')
#     (0.0, 0.0, 1.746171236038208, 'player-2:history')
#     (0.0, 0, 0.3998405933380127, 'player-2:state-active')
#     (0.0, 0.0, 1.468366026878357, 'player-1:history')
#     (0.0, 0, 0.464592844247818, 'player-1:state-active')
#     (-0.0, 0, -0.08319959789514542, 'player-0:state-fold')
#     (0.0, 0, 0.9790592193603516, 'street-river')
#     (0.0, 0, 0.9331514239311218, 'street-turn')
#     (0.0, 0, 0.86588454246521, 'street-preflop')
#     (0.0, 0, 1.4440168142318726, 'btn distance=9')
#     (0.0, 0, 0.6902648210525513, 'btn distance=8')
#     (0.0, 0, 0.6125809550285339, 'btn distance=7')
#     (0.0, 0, 3.378845453262329, 'btn distance=5')
#     (0.0, 0, 3.491258382797241, 'btn distance=4')
#     (0.0, 0, 3.366580009460449, 'btn distance=3')
#     (0.0, 0, 3.403568983078003, 'btn distance=2')
#     (0.0, 0, 3.3066458702087402, 'btn distance=1')
#     (0.0, 0, 3.3113150596618652, 'btn distance=0')
#     (0.0, 0, 0.1864863932132721, 'round level 27')
#     (-0.0, 0, -0.16429129242897034, 'round level 26')
#     (-0.0, 0, -0.046955082565546036, 'round level 25')
#     (-0.0, 0, -0.09106510132551193, 'round level 24')
#     (0.0, 0, 0.19359903037548065, 'round level 23')
#     (-0.0, 0, -0.1129482239484787, 'round level 22')
#     (-0.0, 0, -0.07924514263868332, 'round level 21')
#     (-0.0, 0, -0.07969773560762405, 'round level 20')
#     (-0.0, 0, -0.21454547345638275, 'round level 19')
#     (0.0, 0, 0.059178855270147324, 'round level 18')
#     (-0.0, 0, -0.03560476377606392, 'round level 17')
#     (0.0, 0, 0.007163514383137226, 'round level 16')
#     (-0.0, 0, -0.13512195646762848, 'round level 15')
#     (-0.0, 0, -0.1584649533033371, 'round level 14')
#     (0.0, 0, 0.15792712569236755, 'round level 13')
#     (-0.0, 0, -0.23586158454418182, 'round level 12')
#     (0.0, 0, 0.07051877677440643, 'round level 11')
#     (0.0, 0, 0.08433552831411362, 'round level 10')
#     (0.0, 0, 0.006170609965920448, 'round level 9')
#     (-0.0, 0, -0.07084600627422333, 'round level 8')
#     (0.0, 0, 0.11457421630620956, 'round level 7')
#     (0.0, 0, 0.08975376188755035, 'round level 6')
#     (-0.0, 0, -0.23617757856845856, 'round level 5')
#     (-0.0, 0, -0.22836115956306458, 'round level 4')
#     (0.0, 0, 0.048288315534591675, 'round level 3')
#     (-0.0, 0, -0.07394367456436157, 'round level 1')
#
# linear combination for max_raise :
#     (2.019573450088501, 1, 2.019573450088501, 'btn distance=6')
#     (-1.705495834350586, 1, -1.705495834350586, 'round level 2')
#     (-1.5685375, 0, 0, 'bias')
#     (-1.3696188926696777, 1, -1.3696188926696777, 'player-0:state-active')
#     (0.5559921860694885, 1, 0.5559921860694885, 'player-2:state-fold')
#     (0.5501344156606127, 0.3145353455123114, 1.7490384578704834, 'player-0:history')
#     (-0.4739885926246643, 1, -0.4739885926246643, 'player-8:state-active')
#     (0.4154148181342624, 0.3161239078633836, 1.3140885829925537, 'player-8:history')
#     (0.3845996558666229, 1, 0.3845996558666229, 'street-flop')
#     (0.34533555072798627, 0.69516068696975708, 0.49677082896232605, 'cards')
#     (0.18107010424137115, 1, 0.18107010424137115, 'player-4:state-fold')
#     (0.16990752518177032, 1, 0.16990752518177032, 'player-6:state-fold')
#     (0.16700617969036102, 1, 0.16700617969036102, 'player-3:state-fold')
#     (-0.1316184550523758, 1, -0.1316184550523758, 'player-9:state-fold')
#     (0.08285059034824371, 1, 0.08285059034824371, 'player-1:state-fold')
#     (-0.08156035667657853, 0.09775, -0.8343770503997803, 'player-6:stack')
#     (-0.06816240549087525, 0.1, -0.6816240549087524, 'player-3:stack')
#     (-0.06650218337774276, 0.0925, -0.7189425230026245, 'player-7:stack')
#     (-0.06366831293702126, 0.0715, -0.8904659152030945, 'player-4:stack')
#     (-0.06171972751617432, 0.1, -0.6171972751617432, 'player-1:stack')
#     (-0.06048037932440638, 0.31475, -0.1921537071466446, 'pot')
#     (-0.052268922328948975, 0.1, -0.5226892232894897, 'player-2:stack')
#     (-0.03210036826133728, 0.05575, -0.5757913589477539, 'player-9:stack')
#     (-0.03189263042062521, 0.06625, -0.48139819502830505, 'player-5:stack')
#     (-0.008543427102267742, 1, -0.008543427102267742, 'player-5:state-fold')
#     (-0.0054485369473695755, 1, -0.0054485369473695755, 'player-7:state-fold')
#     (0.001689018964767456, 0.001, 1.689018964767456, 'player-0:stack')
#     (-0.00033476319909095766, 0.0005, -0.6695263981819153, 'player-8:stack')
#     (0.0, 0.0, 1.294410228729248, 'player-9:history')
#     (-0.0, 0, -0.1723392754793167, 'player-9:state-active')
#     (-0.0, 0, -0.45327356457710266, 'player-8:state-fold')
#     (0.0, 0.0, 1.2852766513824463, 'player-7:history')
#     (0.0, 0, 0.009113033302128315, 'player-7:state-active')
#     (0.0, 0.0, 1.5812280178070068, 'player-6:history')
#     (0.0, 0, 0.2710704803466797, 'player-6:state-active')
#     (0.0, 0.0, 1.4836312532424927, 'player-5:history')
#     (0.0, 0, 0.050112057477235794, 'player-5:state-active')
#     (0.0, 0.0, 1.4741692543029785, 'player-4:history')
#     (0.0, 0, 0.1328335702419281, 'player-4:state-active')
#     (0.0, 0.0, 1.5749785900115967, 'player-3:history')
#     (0.0, 0, 0.18305647373199463, 'player-3:state-active')
#     (0.0, 0.0, 1.523707628250122, 'player-2:history')
#     (0.0, 0, 0.44320815801620483, 'player-2:state-active')
#     (0.0, 0.0, 1.399151086807251, 'player-1:history')
#     (0.0, 0, 0.03814220800995827, 'player-1:state-active')
#     (-0.0, 0, -0.07082012295722961, 'player-0:state-fold')
#     (0.0, 0, 0.6438460946083069, 'street-river')
#     (0.0, 0, 0.5357523560523987, 'street-turn')
#     (0.0, 0, 0.4439617693424225, 'street-preflop')
#     (0.0, 0, 1.0605579614639282, 'btn distance=9')
#     (0.0, 0, 0.5578138828277588, 'btn distance=8')
#     (0.0, 0, 0.3871185779571533, 'btn distance=7')
#     (0.0, 0, 2.1290736198425293, 'btn distance=5')
#     (0.0, 0, 2.1042659282684326, 'btn distance=4')
#     (0.0, 0, 2.0583226680755615, 'btn distance=3')
#     (0.0, 0, 1.996710181236267, 'btn distance=2')
#     (0.0, 0, 1.9347350597381592, 'btn distance=1')
#     (0.0, 0, 1.9695475101470947, 'btn distance=0')
#     (-0.0, 0, -0.0745745450258255, 'round level 27')
#     (0.0, 0, 0.015400783158838749, 'round level 26')
#     (0.0, 0, 0.1319204717874527, 'round level 25')
#     (-0.0, 0, -0.15635602176189423, 'round level 24')
#     (0.0, 0, 0.08905228227376938, 'round level 23')
#     (-0.0, 0, -0.10733900219202042, 'round level 22')
#     (0.0, 0, 0.02085469476878643, 'round level 21')
#     (0.0, 0, 0.24782584607601166, 'round level 20')
#     (-0.0, 0, -0.1948973387479782, 'round level 19')
#     (0.0, 0, 0.1771361082792282, 'round level 18')
#     (0.0, 0, 0.1400010585784912, 'round level 17')
#     (0.0, 0, 0.0674973577260971, 'round level 16')
#     (-0.0, 0, -0.16851937770843506, 'round level 15')
#     (-0.0, 0, -0.10289682447910309, 'round level 14')
#     (0.0, 0, 0.09751802682876587, 'round level 13')
#     (0.0, 0, 0.05579689145088196, 'round level 12')
#     (0.0, 0, 0.062262505292892456, 'round level 11')
#     (0.0, 0, 0.08422500640153885, 'round level 10')
#     (0.0, 0, 0.2191074788570404, 'round level 9')
#     (0.0, 0, 0.1968294382095337, 'round level 8')
#     (-0.0, 0, -0.1691485494375229, 'round level 7')
#     (0.0, 0, 0.08150830864906311, 'round level 6')
#     (0.0, 0, 0.008948147296905518, 'round level 5')
#     (-0.0, 0, -0.23150017857551575, 'round level 4')
#     (0.0, 0, 0.199162557721138, 'round level 3')
#     (0.0, 0, 0.1435113102197647, 'round level 1')

# %% [markdown]
# ### 9950払ってせっかくいったturnでFOLD

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [-1, -1]
# -- hole card --
#   - ['C6', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : turn
#   - community card : ['DA', 'SJ', 'HK', 'CQ']
#   - pot : main = 31575, side = [{'amount': 0, 'eligibles': ['uuid-6']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 7150
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 6625 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9775 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9250
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 5575
#     - 6 : agent (uuid-0) => state : participating, stack : 50 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 175, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 200, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 225, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 675, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 750, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1175, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 1275, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 1675, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 1800, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2175, 'player': 'agent (uuid=uuid-0)', 'amount': 2325, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2675, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 2850, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 3175, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 3375, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 3900, 'action': 'RAISE'}
#       - {'add_amount': 525, 'paid': 2625, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 4425, 'action': 'RAISE'}
#       - {'add_amount': 5475, 'paid': 7575, 'player': 'agent (uuid=uuid-0)', 'amount': 9900, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 9900, 'paid': 6000}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#     - flop
#       - {'add_amount': 50, 'paid': 50, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'paid': 50}
#     - turn
#       - {'add_amount': 50, 'paid': 50, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', -0.7215754985809326), ('call', -0.8506796360015869)]
# ** weights and features in detail **
# bias : [-1.17843068 -1.02286565 -2.06678295 -1.95017385 -1.70704675 -1.56853747]
#
# linear combination for fold :
#     (-1.218326449394226, 1, -1.218326449394226, 'player-0:state-active')
#     (-1.1784307, 0, 0, 'bias')
#     (-1.1665277481079102, 1, -1.1665277481079102, 'round level 2')
#     (0.9125367403030396, 1, 0.9125367403030396, 'btn distance=6')
#     (0.5090558457166924, 0.31512272367379257, 1.615420937538147, 'player-0:history')
#     (0.47982326123984387, 0.3167062549485352, 1.5150419473648071, 'player-8:history')
#     (0.47896459698677063, 1, 0.47896459698677063, 'street-turn')
#     (0.27499473094940186, 1, 0.27499473094940186, 'player-5:state-fold')
#     (0.18702542781829834, 1, 0.18702542781829834, 'player-6:state-fold')
#     (-0.1623335162848234, 0.31575, -0.5141203999519348, 'pot')
#     (0.12527720630168915, 1, 0.12527720630168915, 'player-3:state-fold')
#     (0.12127767503261566, 1, 0.12127767503261566, 'player-7:state-fold')
#     (0.12093259394168854, 1, 0.12093259394168854, 'player-4:state-fold')
#     (0.07350452244281769, 1, 0.07350452244281769, 'player-8:state-active')
#     (-0.05088101923465729, 0.06625, -0.7680153846740723, 'player-5:stack')
#     (-0.0471811361387372, 0.09775, -0.48267146944999695, 'player-6:stack')
#     (-0.046631285548210145, 0.1, -0.46631285548210144, 'player-3:stack')
#     (-0.04510365128517151, 0.1, -0.4510365128517151, 'player-1:stack')
#     (0.04484445974230766, 1, 0.04484445974230766, 'player-9:state-fold')
#     (-0.042758043408393856, 0.0715, -0.5980145931243896, 'player-4:stack')
#     (0.03868267685174942, 1, 0.03868267685174942, 'player-2:state-fold')
#     (-0.037520101666450506, 0.1, -0.375201016664505, 'player-2:stack')
#     (-0.037279911860823634, 0.0925, -0.4030260741710663, 'player-7:stack')
#     (-0.035715474679578474, 0.59485018253326416, -0.06004112586379051, 'cards')
#     (-0.025699604988098146, 0.05575, -0.4609794616699219, 'player-9:stack')
#     (0.005368893034756184, 1, 0.005368893034756184, 'player-1:state-fold')
#     (0.00052459317445755, 0.0005, 1.0491863489151, 'player-0:stack')
#     (0.0, 0.0, 1.5393073558807373, 'player-9:history')
#     (0.0, 0, 0.0024986343923956156, 'player-9:state-active')
#     (0.0, 0, 0.11467187851667404, 'player-8:state-fold')
#     (-0.0, 0.0, -0.4792574644088745, 'player-8:stack')
#     (0.0, 0.0, 1.5559182167053223, 'player-7:history')
#     (0.0, 0, 0.10609544068574905, 'player-7:state-active')
#     (0.0, 0.0, 1.4221173524856567, 'player-6:history')
#     (0.0, 0, 0.1653481423854828, 'player-6:state-active')
#     (0.0, 0.0, 1.4401140213012695, 'player-5:history')
#     (0.0, 0, 0.24999964237213135, 'player-5:state-active')
#     (0.0, 0.0, 1.4575220346450806, 'player-4:history')
#     (0.0, 0, 0.11704733967781067, 'player-4:state-active')
#     (0.0, 0.0, 1.4820276498794556, 'player-3:history')
#     (0.0, 0, 0.08732421696186066, 'player-3:state-active')
#     (0.0, 0.0, 1.5585168600082397, 'player-2:history')
#     (-0.0, 0, -0.010440158657729626, 'player-2:state-active')
#     (0.0, 0.0, 1.5680538415908813, 'player-1:history')
#     (-0.0, 0, -0.030225859954953194, 'player-1:state-active')
#     (0.0, 0, 0.13104617595672607, 'player-0:state-fold')
#     (0.0, 0, 0.5163982510566711, 'street-river')
#     (0.0, 0, 0.4114610552787781, 'street-flop')
#     (0.0, 0, 0.42502614855766296, 'street-preflop')
#     (0.0, 0, 1.2318480014801025, 'btn distance=9')
#     (0.0, 0, 1.2068599462509155, 'btn distance=8')
#     (0.0, 0, 0.694226086139679, 'btn distance=7')
#     (0.0, 0, 0.980753481388092, 'btn distance=5')
#     (0.0, 0, 1.0374095439910889, 'btn distance=4')
#     (0.0, 0, 1.1171241998672485, 'btn distance=3')
#     (0.0, 0, 1.143062710762024, 'btn distance=2')
#     (0.0, 0, 1.1736388206481934, 'btn distance=1')
#     (0.0, 0, 1.194989800453186, 'btn distance=0')
#     (0.0, 0, 0.17381861805915833, 'round level 27')
#     (-0.0, 0, -0.1709413379430771, 'round level 26')
#     (0.0, 0, 0.23499497771263123, 'round level 25')
#     (0.0, 0, 0.2400972843170166, 'round level 24')
#     (0.0, 0, 0.07879160344600677, 'round level 23')
#     (-0.0, 0, -0.20467768609523773, 'round level 22')
#     (-0.0, 0, -0.02996756322681904, 'round level 21')
#     (0.0, 0, 0.021945780143141747, 'round level 20')
#     (-0.0, 0, -0.23729455471038818, 'round level 19')
#     (0.0, 0, 0.20108163356781006, 'round level 18')
#     (0.0, 0, 0.13430552184581757, 'round level 17')
#     (0.0, 0, 0.19009800255298615, 'round level 16')
#     (0.0, 0, 0.2580344080924988, 'round level 15')
#     (-0.0, 0, -0.0939929336309433, 'round level 14')
#     (-0.0, 0, -0.17090654373168945, 'round level 13')
#     (-0.0, 0, -0.06041152775287628, 'round level 12')
#     (0.0, 0, 0.07556843012571335, 'round level 11')
#     (0.0, 0, 0.008105643093585968, 'round level 10')
#     (-0.0, 0, -0.19526717066764832, 'round level 9')
#     (-0.0, 0, -0.09471932053565979, 'round level 8')
#     (-0.0, 0, -0.24805116653442383, 'round level 7')
#     (-0.0, 0, -0.05985160171985626, 'round level 6')
#     (0.0, 0, 0.16501252353191376, 'round level 5')
#     (0.0, 0, 0.1510487198829651, 'round level 4')
#     (-0.0, 0, -0.06887161731719971, 'round level 3')
#     (0.0, 0, 0.15396647155284882, 'round level 1')
#
# linear combination for call :
#     (1.8035677671432495, 1, 1.8035677671432495, 'btn distance=6')
#     (-1.267747163772583, 1, -1.267747163772583, 'round level 2')
#     (-1.0228657, 0, 0, 'bias')
#     (-0.815963625907898, 1, -0.815963625907898, 'player-0:state-active')
#     (0.44895880730116267, 0.31512272367379257, 1.424710988998413, 'player-0:history')
#     (-0.3184701163172722, 0.31575, -1.0086147785186768, 'pot')
#     (0.2590084373950958, 1, 0.2590084373950958, 'street-turn')
#     (0.23730165881504561, 0.59485018253326416, 0.3989267647266388, 'cards')
#     (-0.21578086912631989, 1, -0.21578086912631989, 'player-7:state-fold')
#     (0.19439086023060367, 0.3167062549485352, 0.6137891411781311, 'player-8:history')
#     (0.19041743874549866, 1, 0.19041743874549866, 'player-1:state-fold')
#     (-0.17343391478061676, 1, -0.17343391478061676, 'player-8:state-active')
#     (0.1515781581401825, 1, 0.1515781581401825, 'player-5:state-fold')
#     (0.14377835392951965, 1, 0.14377835392951965, 'player-3:state-fold')
#     (-0.12312944233417511, 1, -0.12312944233417511, 'player-4:state-fold')
#     (-0.057604096040129664, 0.09775, -0.5893002152442932, 'player-6:stack')
#     (-0.05289127305150032, 1, -0.05289127305150032, 'player-6:state-fold')
#     (-0.043379774719476696, 0.0715, -0.6067101359367371, 'player-4:stack')
#     (0.04315764829516411, 1, 0.04315764829516411, 'player-2:state-fold')
#     (-0.04207629263401032, 0.1, -0.42076292634010315, 'player-2:stack')
#     (-0.037613179385662075, 0.0925, -0.40662896633148193, 'player-7:stack')
#     (-0.03541244558990002, 0.06625, -0.5345274806022644, 'player-5:stack')
#     (-0.03180499970912933, 0.1, -0.31804999709129333, 'player-3:stack')
#     (-0.030456164851784706, 0.05575, -0.5462989211082458, 'player-9:stack')
#     (-0.029204374551773073, 0.1, -0.2920437455177307, 'player-1:stack')
#     (-0.025723405182361603, 1, -0.025723405182361603, 'player-9:state-fold')
#     (0.000718041479587555, 0.0005, 1.4360829591751099, 'player-0:stack')
#     (0.0, 0.0, 0.6379348039627075, 'player-9:history')
#     (-0.0, 0, -0.07787381112575531, 'player-9:state-active')
#     (-0.0, 0, -0.09087780117988586, 'player-8:state-fold')
#     (-0.0, 0.0, -0.42746835947036743, 'player-8:stack')
#     (0.0, 0.0, 0.5257284641265869, 'player-7:history')
#     (-0.0, 0, -0.1419263482093811, 'player-7:state-active')
#     (0.0, 0.0, 0.7117400765419006, 'player-6:history')
#     (-0.0, 0, -0.08662305027246475, 'player-6:state-active')
#     (0.0, 0.0, 0.7330848574638367, 'player-5:history')
#     (0.0, 0, 0.25262734293937683, 'player-5:state-active')
#     (0.0, 0.0, 0.6583040952682495, 'player-4:history')
#     (-0.0, 0, -0.08420368283987045, 'player-4:state-active')
#     (0.0, 0.0, 0.7460985779762268, 'player-3:history')
#     (0.0, 0, 0.08468693494796753, 'player-3:state-active')
#     (0.0, 0.0, 0.6259687542915344, 'player-2:history')
#     (0.0, 0, 0.03985699266195297, 'player-2:state-active')
#     (0.0, 0.0, 0.6064308881759644, 'player-1:history')
#     (0.0, 0, 0.2195797711610794, 'player-1:state-active')
#     (-0.0, 0, -0.20277541875839233, 'player-0:state-fold')
#     (0.0, 0, 0.24349345266819, 'street-river')
#     (0.0, 0, 0.2862991690635681, 'street-flop')
#     (0.0, 0, 0.30634018778800964, 'street-preflop')
#     (0.0, 0, 1.1173243522644043, 'btn distance=9')
#     (0.0, 0, 0.30222782492637634, 'btn distance=8')
#     (-0.0, 0, -0.1371598094701767, 'btn distance=7')
#     (0.0, 0, 1.8697949647903442, 'btn distance=5')
#     (0.0, 0, 1.9579356908798218, 'btn distance=4')
#     (0.0, 0, 1.9303548336029053, 'btn distance=3')
#     (0.0, 0, 1.977090835571289, 'btn distance=2')
#     (0.0, 0, 1.8424537181854248, 'btn distance=1')
#     (0.0, 0, 1.8680459260940552, 'btn distance=0')
#     (0.0, 0, 0.07092714309692383, 'round level 27')
#     (-0.0, 0, -0.07035121321678162, 'round level 26')
#     (0.0, 0, 0.1974353939294815, 'round level 25')
#     (-0.0, 0, -0.13411521911621094, 'round level 24')
#     (-0.0, 0, -0.15498259663581848, 'round level 23')
#     (-0.0, 0, -0.128531351685524, 'round level 22')
#     (-0.0, 0, -0.19764813780784607, 'round level 21')
#     (-0.0, 0, -0.20146974921226501, 'round level 20')
#     (0.0, 0, 0.05624271556735039, 'round level 19')
#     (-0.0, 0, -0.11658086627721786, 'round level 18')
#     (-0.0, 0, -0.045278843492269516, 'round level 17')
#     (0.0, 0, 0.14562976360321045, 'round level 16')
#     (0.0, 0, 0.23023651540279388, 'round level 15')
#     (-0.0, 0, -0.048296328634023666, 'round level 14')
#     (-0.0, 0, -0.09172365069389343, 'round level 13')
#     (-0.0, 0, -0.06652963906526566, 'round level 12')
#     (0.0, 0, 0.10760240256786346, 'round level 11')
#     (-0.0, 0, -0.019141659140586853, 'round level 10')
#     (0.0, 0, 0.14686106145381927, 'round level 9')
#     (0.0, 0, 0.09601891785860062, 'round level 8')
#     (0.0, 0, 0.21756060421466827, 'round level 7')
#     (-0.0, 0, -0.052764762192964554, 'round level 6')
#     (-0.0, 0, -0.10461476445198059, 'round level 5')
#     (-0.0, 0, -0.16345806419849396, 'round level 4')
#     (-0.0, 0, -0.2176746279001236, 'round level 3')
#     (0.0, 0, 0.1441952884197235, 'round level 1')
