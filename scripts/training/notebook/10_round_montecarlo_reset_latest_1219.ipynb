# %% [markdown]
# # 実験1 とりあえず走らせてみて観察
# ## 10-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 31万5950で打ち切った
# - 5万iteration毎に敵のvalue_functionを最新(agentと同じ重み)に更新しながらself-play
# - 計算時間 : 85595s  => 23.7h

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# <img src="./resource/10_round_montecarlo_after_500000_training_1217_23_35_04/initial_value_transition.png" />

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# <img src="./resource/10_round_montecarlo_after_500000_training_1217_23_35_04/10_round_3000_match_subplot_1220_00_22_32.png " />

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# - プラス収支で終わるときは,MAX_RAISE繰り返して,後半相手が大きなRAISEしてきてCALL or FOLDでFOLDして最終ラウンド
# - 基本MAX_RAISEしてる. 全選択肢の中からFOLDを選ぶ場面もあった.

# %% [markdown]
# ### いきなり MAX_RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['S3', 'D5']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9950
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9950
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'paid': 50}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', -0.5607483386993408), ('call', -0.6432759761810303), ('min_raise', -0.7774497270584106), ('double_raise', -0.8312020301818848), ('triple_raise', -0.7889910936355591), ('max_raise', -0.45131099224090576)]
# ** weights and features in detail **
# bias : [-0.48353687 -0.24881023 -1.78213286 -2.03190184 -1.90978396 -1.12325943]
#
# linear combination for fold :
#     (1.213940143585205, 1, 1.213940143585205, 'btn distance=6')
#     (-0.5504411458969116, 1, -0.5504411458969116, 'round level 2')
#     (-0.48353687, 0, 0, 'bias')
#     (-0.3082176148891449, 1, -0.3082176148891449, 'player-0:state-active')
#     (0.29554614424705505, 1, 0.29554614424705505, 'player-9:state-active')
#     (0.27700312932332355, 0.2222222222222222, 1.246514081954956, 'player-8:history')
#     (0.2374744415283203, 0.2222222222222222, 1.0686349868774414, 'player-9:history')
#     (0.2293556531270345, 0.2222222222222222, 1.0321004390716553, 'player-6:history')
#     (0.21870948208702934, 0.2222222222222222, 0.9841926693916321, 'player-7:history')
#     (-0.185475692152977, 1, -0.185475692152977, 'player-1:state-active')
#     (-0.1634488984644413, 0.09975, -1.6385854482650757, 'player-5:stack')
#     (-0.15811191564798355, 0.0995, -1.5890644788742065, 'player-9:stack')
#     (-0.1438730363249779, 0.0995, -1.4459601640701294, 'player-7:stack')
#     (-0.13984960317611694, 0.1, -1.3984960317611694, 'player-1:stack')
#     (-0.13378541469573976, 0.1, -1.3378541469573975, 'player-4:stack')
#     (-0.13304693698883058, 0.1, -1.3304693698883057, 'player-3:stack')
#     (-0.12974358958005905, 0.0995, -1.3039556741714478, 'player-6:stack')
#     (-0.12544431024789812, 0.0995, -1.2607468366622925, 'player-8:stack')
#     (0.11967706680297852, 0.1111111111111111, 1.0770936012268066, 'player-5:history')
#     (-0.11906939744949341, 0.1, -1.190693974494934, 'player-2:stack')
#     (-0.11354628950357437, 1, -0.11354628950357437, 'player-7:state-active')
#     (-0.09789295494556427, 1, -0.09789295494556427, 'player-2:state-active')
#     (-0.0735795870423317, 1, -0.0735795870423317, 'player-5:state-active')
#     (0.06006211638450623, 0.1, 0.6006211638450623, 'player-0:stack')
#     (-0.04053684324026108, 1, -0.04053684324026108, 'player-3:state-active')
#     (-0.03097626380622387, 1, -0.03097626380622387, 'player-8:state-active')
#     (-0.027194084644317624, 0.564, -0.04821646213531494, 'cards')
#     (-0.025638192892074585, 1, -0.025638192892074585, 'player-4:state-active')
#     (-0.017108134925365448, 1, -0.017108134925365448, 'player-6:state-active')
#     (-0.0091206980869174, 1, -0.0091206980869174, 'street-preflop')
#     (-0.0028789337575435637, 0.00225, -1.2795261144638062, 'pot')
#     (0.0, 0, 0.3290203809738159, 'player-9:state-fold')
#     (-0.0, 0, -0.08074988424777985, 'player-8:state-fold')
#     (-0.0, 0, -0.07800084352493286, 'player-7:state-fold')
#     (-0.0, 0, -0.02842237614095211, 'player-6:state-fold')
#     (-0.0, 0, -0.07917696982622147, 'player-5:state-fold')
#     (0.0, 0.0, 1.1144518852233887, 'player-4:history')
#     (0.0, 0, 0.05473426729440689, 'player-4:state-fold')
#     (0.0, 0.0, 1.0370513200759888, 'player-3:history')
#     (-0.0, 0, -0.055877212435007095, 'player-3:state-fold')
#     (0.0, 0.0, 1.1363270282745361, 'player-2:history')
#     (0.0, 0, 0.020596105605363846, 'player-2:state-fold')
#     (0.0, 0.0, 1.0625455379486084, 'player-1:history')
#     (-0.0, 0, -0.1091219112277031, 'player-1:state-fold')
#     (0.0, 0.0, 1.0638755559921265, 'player-0:history')
#     (-0.0, 0, -0.13157254457473755, 'player-0:state-fold')
#     (-0.0, 0, -0.058312587440013885, 'street-river')
#     (0.0, 0, 0.021209783852100372, 'street-turn')
#     (-0.0, 0, -0.0214112289249897, 'street-flop')
#     (0.0, 0, 1.325065016746521, 'btn distance=9')
#     (0.0, 0, 1.4019274711608887, 'btn distance=8')
#     (0.0, 0, 1.4151992797851562, 'btn distance=7')
#     (0.0, 0, 1.2666823863983154, 'btn distance=5')
#     (0.0, 0, 1.2417488098144531, 'btn distance=4')
#     (0.0, 0, 1.2136343717575073, 'btn distance=3')
#     (0.0, 0, 1.1977404356002808, 'btn distance=2')
#     (0.0, 0, 1.3430707454681396, 'btn distance=1')
#     (0.0, 0, 1.3178373575210571, 'btn distance=0')
#     (-0.0, 0, -0.21972104907035828, 'round level 27')
#     (-0.0, 0, -0.16887789964675903, 'round level 26')
#     (-0.0, 0, -0.056195277720689774, 'round level 25')
#     (-0.0, 0, -0.0224585123360157, 'round level 24')
#     (0.0, 0, 0.21297651529312134, 'round level 23')
#     (0.0, 0, 0.11313529312610626, 'round level 22')
#     (0.0, 0, 0.21001067757606506, 'round level 21')
#     (-0.0, 0, -0.14171156287193298, 'round level 20')
#     (0.0, 0, 0.13536091148853302, 'round level 19')
#     (0.0, 0, 0.22831162810325623, 'round level 18')
#     (-0.0, 0, -0.22597871720790863, 'round level 17')
#     (0.0, 0, 0.07464097440242767, 'round level 16')
#     (0.0, 0, 0.17132167518138885, 'round level 15')
#     (-0.0, 0, -0.05531512200832367, 'round level 14')
#     (0.0, 0, 0.21716493368148804, 'round level 13')
#     (-0.0, 0, -0.09104923903942108, 'round level 12')
#     (-0.0, 0, -0.25070151686668396, 'round level 11')
#     (-0.0, 0, -0.08039606362581253, 'round level 10')
#     (-0.0, 0, -0.05438179895281792, 'round level 9')
#     (0.0, 0, 0.17122764885425568, 'round level 8')
#     (-0.0, 0, -0.18322034180164337, 'round level 7')
#     (0.0, 0, 0.04171256348490715, 'round level 6')
#     (-0.0, 0, -0.2578655481338501, 'round level 5')
#     (-0.0, 0, -0.17897067964076996, 'round level 4')
#     (-0.0, 0, -0.2215890735387802, 'round level 3')
#     (-0.0, 0, -0.01656218059360981, 'round level 1')
#
# linear combination for call :
#     (0.5252928929328918, 0.564, 0.9313703775405884, 'cards')
#     (-0.25926724076271057, 1, -0.25926724076271057, 'street-preflop')
#     (-0.24881023, 0, 0, 'bias')
#     (-0.24511785805225372, 1, -0.24511785805225372, 'player-1:state-active')
#     (0.22829273343086243, 1, 0.22829273343086243, 'player-6:state-active')
#     (-0.17895637831091882, 0.09975, -1.7940489053726196, 'player-5:stack')
#     (0.17627842724323273, 1, 0.17627842724323273, 'player-8:state-active')
#     (-0.1709808945655823, 0.1, -1.7098089456558228, 'player-3:stack')
#     (-0.1591251254081726, 0.1, -1.591251254081726, 'player-1:stack')
#     (0.15847960114479065, 1, 0.15847960114479065, 'player-7:state-active')
#     (-0.15567740201950075, 0.1, -1.5567740201950073, 'player-4:stack')
#     (-0.15231077671051027, 0.1, -1.5231077671051025, 'player-2:stack')
#     (0.15041644871234894, 1, 0.15041644871234894, 'player-3:state-active')
#     (-0.1496345322728157, 0.0995, -1.5038646459579468, 'player-6:stack')
#     (-0.14745876210927963, 0.0995, -1.4819976091384888, 'player-8:stack')
#     (-0.14320931220054628, 0.0995, -1.4392895698547363, 'player-9:stack')
#     (-0.14142374402284624, 0.0995, -1.4213441610336304, 'player-7:stack')
#     (0.14023910462856293, 1, 0.14023910462856293, 'player-9:state-active')
#     (0.139820396900177, 1, 0.139820396900177, 'player-4:state-active')
#     (-0.10114721953868866, 1, -0.10114721953868866, 'round level 2')
#     (-0.0666251853108406, 1, -0.0666251853108406, 'player-0:state-active')
#     (-0.0617591068148613, 1, -0.0617591068148613, 'player-2:state-active')
#     (0.04553006092707316, 0.2222222222222222, 0.20488527417182922, 'player-9:history')
#     (0.04466898573769463, 0.2222222222222222, 0.20101043581962585, 'player-8:history')
#     (0.03996642306447029, 1, 0.03996642306447029, 'player-5:state-active')
#     (0.03783537745475769, 0.1, 0.3783537745475769, 'player-0:stack')
#     (0.033042505383491516, 1, 0.033042505383491516, 'btn distance=6')
#     (0.012432371576627094, 0.2222222222222222, 0.05594567209482193, 'player-7:history')
#     (0.005130098511775334, 0.1111111111111111, 0.04617088660597801, 'player-5:history')
#     (0.00424672621819708, 0.2222222222222222, 0.019110267981886864, 'player-6:history')
#     (-0.0034443699717521667, 0.00225, -1.5308310985565186, 'pot')
#     (0.0, 0, 0.1583608090877533, 'player-9:state-fold')
#     (0.0, 0, 0.18884600698947906, 'player-8:state-fold')
#     (0.0, 0, 0.18202362954616547, 'player-7:state-fold')
#     (0.0, 0, 0.10749158263206482, 'player-6:state-fold')
#     (-0.0, 0, -0.021531887352466583, 'player-5:state-fold')
#     (0.0, 0.0, 0.11255741119384766, 'player-4:history')
#     (0.0, 0, 0.144008606672287, 'player-4:state-fold')
#     (0.0, 0.0, 0.03554701432585716, 'player-3:history')
#     (0.0, 0, 0.12559907138347626, 'player-3:state-fold')
#     (0.0, 0.0, 0.0787128210067749, 'player-2:history')
#     (-0.0, 0, -0.016709184274077415, 'player-2:state-fold')
#     (0.0, 0.0, 0.035544831305742264, 'player-1:history')
#     (-0.0, 0, -0.1712895780801773, 'player-1:state-fold')
#     (0.0, 0.0, 0.6731666326522827, 'player-0:history')
#     (0.0, 0, 0.0506884902715683, 'player-0:state-fold')
#     (-0.0, 0, -0.5945714116096497, 'street-river')
#     (-0.0, 0, -0.42862606048583984, 'street-turn')
#     (-0.0, 0, -0.3372102975845337, 'street-flop')
#     (0.0, 0, 0.22869279980659485, 'btn distance=9')
#     (0.0, 0, 0.2711631953716278, 'btn distance=8')
#     (0.0, 0, 0.2218068391084671, 'btn distance=7')
#     (0.0, 0, 0.1621607095003128, 'btn distance=5')
#     (0.0, 0, 0.11350041627883911, 'btn distance=4')
#     (0.0, 0, 0.2085464596748352, 'btn distance=3')
#     (0.0, 0, 0.16336408257484436, 'btn distance=2')
#     (0.0, 0, 0.09508673846721649, 'btn distance=1')
#     (0.0, 0, 0.1494542807340622, 'btn distance=0')
#     (0.0, 0, 0.05240476503968239, 'round level 27')
#     (0.0, 0, 0.003269001841545105, 'round level 26')
#     (0.0, 0, 0.2429712414741516, 'round level 25')
#     (0.0, 0, 0.18841516971588135, 'round level 24')
#     (0.0, 0, 0.2595265209674835, 'round level 23')
#     (0.0, 0, 0.14526015520095825, 'round level 22')
#     (-0.0, 0, -0.05364101752638817, 'round level 21')
#     (-0.0, 0, -0.25889888405799866, 'round level 20')
#     (0.0, 0, 0.20514066517353058, 'round level 19')
#     (-0.0, 0, -0.15952783823013306, 'round level 18')
#     (-0.0, 0, -0.2368985414505005, 'round level 17')
#     (0.0, 0, 0.021499469876289368, 'round level 16')
#     (-0.0, 0, -0.15992547571659088, 'round level 15')
#     (0.0, 0, 0.13773998618125916, 'round level 14')
#     (0.0, 0, 0.03223136439919472, 'round level 13')
#     (0.0, 0, 0.1264357566833496, 'round level 12')
#     (-0.0, 0, -0.10693281143903732, 'round level 11')
#     (0.0, 0, 0.16666394472122192, 'round level 10')
#     (0.0, 0, 0.20799539983272552, 'round level 9')
#     (0.0, 0, 0.20435722172260284, 'round level 8')
#     (-0.0, 0, -0.012952451594173908, 'round level 7')
#     (0.0, 0, 0.16907642781734467, 'round level 6')
#     (0.0, 0, 0.05249634385108948, 'round level 5')
#     (-0.0, 0, -0.1286989152431488, 'round level 4')
#     (0.0, 0, 0.2346666008234024, 'round level 3')
#     (-0.0, 0, -0.18063881993293762, 'round level 1')
#
# linear combination for min_raise :
#     (3.1817588806152344, 1, 3.1817588806152344, 'btn distance=6')
#     (-1.7821329, 0, 0, 'bias')
#     (-1.747273564338684, 1, -1.747273564338684, 'player-0:state-active')
#     (-1.5308681726455688, 1, -1.5308681726455688, 'round level 2')
#     (0.49008682039048934, 0.2222222222222222, 2.205390691757202, 'player-7:history')
#     (0.4864954948425293, 0.2222222222222222, 2.189229726791382, 'player-8:history')
#     (0.47234837214152015, 0.2222222222222222, 2.125567674636841, 'player-6:history')
#     (0.44638246960110134, 0.2222222222222222, 2.008721113204956, 'player-9:history')
#     (-0.3422319293022156, 1, -0.3422319293022156, 'player-7:state-active')
#     (-0.3169701397418976, 1, -0.3169701397418976, 'player-8:state-active')
#     (0.24080223507351345, 0.1111111111111111, 2.167220115661621, 'player-5:history')
#     (0.19823142957687376, 0.564, 0.35147416591644287, 'cards')
#     (0.18198390305042267, 1, 0.18198390305042267, 'player-2:state-active')
#     (-0.14947839081287384, 1, -0.14947839081287384, 'player-3:state-active')
#     (0.1469043791294098, 1, 0.1469043791294098, 'player-1:state-active')
#     (-0.11795627325773239, 1, -0.11795627325773239, 'player-6:state-active')
#     (0.10328835248947144, 0.1, 1.0328835248947144, 'player-0:stack')
#     (-0.08002043962478639, 0.1, -0.8002043962478638, 'player-3:stack')
#     (-0.07977888849377633, 0.09975, -0.7997883558273315, 'player-5:stack')
#     (-0.07858939856290818, 0.0995, -0.7898432016372681, 'player-7:stack')
#     (-0.07264379411935806, 1, -0.07264379411935806, 'player-5:state-active')
#     (-0.07126668545603752, 0.0995, -0.716248095035553, 'player-8:stack')
#     (-0.07118945121765137, 0.1, -0.7118945121765137, 'player-2:stack')
#     (-0.06770388168096543, 0.0995, -0.6804410219192505, 'player-9:stack')
#     (-0.06444417238235474, 0.1, -0.6444417238235474, 'player-1:stack')
#     (-0.06389769539237022, 0.0995, -0.6421878933906555, 'player-6:stack')
#     (-0.05308401584625244, 1, -0.05308401584625244, 'player-4:state-active')
#     (-0.05077544450759888, 0.1, -0.5077544450759888, 'player-4:stack')
#     (0.027887772768735886, 1, 0.027887772768735886, 'street-preflop')
#     (-0.012242932803928852, 1, -0.012242932803928852, 'player-9:state-active')
#     (-0.0010718083754181862, 0.00225, -0.4763592779636383, 'pot')
#     (-0.0, 0, -0.009885293431580067, 'player-9:state-fold')
#     (-0.0, 0, -0.36383065581321716, 'player-8:state-fold')
#     (-0.0, 0, -0.25521501898765564, 'player-7:state-fold')
#     (-0.0, 0, -0.03639017418026924, 'player-6:state-fold')
#     (-0.0, 0, -0.09889116883277893, 'player-5:state-fold')
#     (0.0, 0.0, 2.2595601081848145, 'player-4:history')
#     (-0.0, 0, -0.061681050807237625, 'player-4:state-fold')
#     (0.0, 0.0, 2.1437301635742188, 'player-3:history')
#     (0.0, 0, 0.016544779762625694, 'player-3:state-fold')
#     (0.0, 0.0, 2.061837911605835, 'player-2:history')
#     (0.0, 0, 0.2779412865638733, 'player-2:state-fold')
#     (0.0, 0.0, 2.265964984893799, 'player-1:history')
#     (0.0, 0, 0.12282508611679077, 'player-1:state-fold')
#     (0.0, 0.0, 2.455728054046631, 'player-0:history')
#     (0.0, 0, 0.07190699130296707, 'player-0:state-fold')
#     (-0.0, 0, -0.050476666539907455, 'street-river')
#     (0.0, 0, 0.11330259591341019, 'street-turn')
#     (0.0, 0, 0.15895408391952515, 'street-flop')
#     (0.0, 0, 3.1835520267486572, 'btn distance=9')
#     (0.0, 0, 3.2953693866729736, 'btn distance=8')
#     (0.0, 0, 3.2720251083374023, 'btn distance=7')
#     (0.0, 0, 3.2197015285491943, 'btn distance=5')
#     (0.0, 0, 3.1331751346588135, 'btn distance=4')
#     (0.0, 0, 3.217989683151245, 'btn distance=3')
#     (0.0, 0, 3.2322170734405518, 'btn distance=2')
#     (0.0, 0, 3.2189176082611084, 'btn distance=1')
#     (0.0, 0, 3.2374656200408936, 'btn distance=0')
#     (0.0, 0, 0.25229722261428833, 'round level 27')
#     (0.0, 0, 0.22346574068069458, 'round level 26')
#     (-0.0, 0, -0.024008633568882942, 'round level 25')
#     (-0.0, 0, -0.16542094945907593, 'round level 24')
#     (-0.0, 0, -0.09414144605398178, 'round level 23')
#     (0.0, 0, 0.1686987429857254, 'round level 22')
#     (0.0, 0, 0.17665095627307892, 'round level 21')
#     (-0.0, 0, -0.18036343157291412, 'round level 20')
#     (0.0, 0, 0.22174479067325592, 'round level 19')
#     (-0.0, 0, -0.15750350058078766, 'round level 18')
#     (0.0, 0, 0.1287153661251068, 'round level 17')
#     (0.0, 0, 0.05211281776428223, 'round level 16')
#     (-0.0, 0, -0.07095134258270264, 'round level 15')
#     (-0.0, 0, -0.16400404274463654, 'round level 14')
#     (-0.0, 0, -0.19781464338302612, 'round level 13')
#     (0.0, 0, 0.00890976283699274, 'round level 12')
#     (-0.0, 0, -0.10713862627744675, 'round level 11')
#     (-0.0, 0, -0.09665833413600922, 'round level 10')
#     (-0.0, 0, -0.03662043809890747, 'round level 9')
#     (0.0, 0, 0.2009717971086502, 'round level 8')
#     (-0.0, 0, -0.08257033675909042, 'round level 7')
#     (0.0, 0, 0.1913730353116989, 'round level 6')
#     (0.0, 0, 0.17685194313526154, 'round level 5')
#     (-0.0, 0, -0.04237651824951172, 'round level 4')
#     (0.0, 0, 0.18527163565158844, 'round level 3')
#     (0.0, 0, 0.05876008793711662, 'round level 1')
#
# linear combination for double_raise :
#     (3.0474212169647217, 1, 3.0474212169647217, 'btn distance=6')
#     (-2.21936297416687, 1, -2.21936297416687, 'round level 2')
#     (-2.0319018, 0, 0, 'bias')
#     (-1.7936919927597046, 1, -1.7936919927597046, 'player-0:state-active')
#     (-0.5111181139945984, 1, -0.5111181139945984, 'player-7:state-active')
#     (0.49676360024346244, 0.2222222222222222, 2.235436201095581, 'player-6:history')
#     (0.47638442781236434, 0.2222222222222222, 2.1437299251556396, 'player-8:history')
#     (0.4667104615105523, 0.2222222222222222, 2.1001970767974854, 'player-7:history')
#     (0.462074703640408, 0.2222222222222222, 2.079336166381836, 'player-9:history')
#     (0.4399876594543457, 1, 0.4399876594543457, 'street-preflop')
#     (0.25662798351711696, 0.1111111111111111, 2.3096518516540527, 'player-5:history')
#     (0.23607796430587769, 1, 0.23607796430587769, 'player-3:state-active')
#     (0.22699761390686035, 1, 0.22699761390686035, 'player-4:state-active')
#     (-0.19770953059196472, 1, -0.19770953059196472, 'player-8:state-active')
#     (-0.18838202953338623, 1, -0.18838202953338623, 'player-9:state-active')
#     (0.15385682880878448, 1, 0.15385682880878448, 'player-6:state-active')
#     (0.14093730449676514, 0.1, 1.4093730449676514, 'player-0:stack')
#     (0.12407863783836363, 0.564, 0.2199975848197937, 'cards')
#     (-0.0681053575873375, 0.09975, -0.68276047706604, 'player-5:stack')
#     (-0.05603376626968384, 0.1, -0.5603376626968384, 'player-3:stack')
#     (-0.05470232826471329, 0.0995, -0.5497721433639526, 'player-7:stack')
#     (-0.046351441740989686, 0.1, -0.46351441740989685, 'player-4:stack')
#     (-0.037882092654705046, 0.0995, -0.38072454929351807, 'player-6:stack')
#     (-0.030823492690920832, 0.0995, -0.30978384613990784, 'player-8:stack')
#     (-0.029804321005940437, 1, -0.029804321005940437, 'player-2:state-active')
#     (-0.02310032793134451, 0.0995, -0.23216409981250763, 'player-9:stack')
#     (-0.021940648555755615, 0.1, -0.21940648555755615, 'player-1:stack')
#     (-0.020117923617362976, 1, -0.020117923617362976, 'player-5:state-active')
#     (-0.01897541619837284, 1, -0.01897541619837284, 'player-1:state-active')
#     (-0.009575264155864717, 0.1, -0.09575264155864716, 'player-2:stack')
#     (0.0004583249799907207, 0.00225, 0.203699991106987, 'pot')
#     (-0.0, 0, -0.34994077682495117, 'player-9:state-fold')
#     (-0.0, 0, -0.274885892868042, 'player-8:state-fold')
#     (-0.0, 0, -0.48104143142700195, 'player-7:state-fold')
#     (0.0, 0, 0.19748517870903015, 'player-6:state-fold')
#     (0.0, 0, 0.07114457339048386, 'player-5:state-fold')
#     (0.0, 0.0, 2.2322287559509277, 'player-4:history')
#     (0.0, 0, 0.2913406491279602, 'player-4:state-fold')
#     (0.0, 0.0, 2.2680790424346924, 'player-3:history')
#     (0.0, 0, 0.21921734511852264, 'player-3:state-fold')
#     (0.0, 0.0, 2.1039273738861084, 'player-2:history')
#     (-0.0, 0, -0.005740904249250889, 'player-2:state-fold')
#     (0.0, 0.0, 2.0015361309051514, 'player-1:history')
#     (0.0, 0, 0.03557249531149864, 'player-1:state-fold')
#     (0.0, 0.0, 2.134503126144409, 'player-0:history')
#     (-0.0, 0, -0.21569909155368805, 'player-0:state-fold')
#     (0.0, 0, 0.5574126243591309, 'street-river')
#     (0.0, 0, 0.7263288497924805, 'street-turn')
#     (0.0, 0, 0.5284073948860168, 'street-flop')
#     (0.0, 0, 3.3597800731658936, 'btn distance=9')
#     (0.0, 0, 3.3063313961029053, 'btn distance=8')
#     (0.0, 0, 3.296417713165283, 'btn distance=7')
#     (0.0, 0, 3.279503583908081, 'btn distance=5')
#     (0.0, 0, 3.1960201263427734, 'btn distance=4')
#     (0.0, 0, 3.3553316593170166, 'btn distance=3')
#     (0.0, 0, 3.3526527881622314, 'btn distance=2')
#     (0.0, 0, 3.1485042572021484, 'btn distance=1')
#     (0.0, 0, 3.3223490715026855, 'btn distance=0')
#     (0.0, 0, 0.09741748869419098, 'round level 27')
#     (0.0, 0, 0.07910311967134476, 'round level 26')
#     (-0.0, 0, -0.059776660054922104, 'round level 25')
#     (-0.0, 0, -0.08622538298368454, 'round level 24')
#     (-0.0, 0, -0.251736581325531, 'round level 23')
#     (0.0, 0, 0.10754083842039108, 'round level 22')
#     (0.0, 0, 0.1417292058467865, 'round level 21')
#     (-0.0, 0, -0.0754241794347763, 'round level 20')
#     (0.0, 0, 0.2072998434305191, 'round level 19')
#     (-0.0, 0, -0.08121882379055023, 'round level 18')
#     (0.0, 0, 0.12156017124652863, 'round level 17')
#     (0.0, 0, 0.1160498857498169, 'round level 16')
#     (-0.0, 0, -0.08847133815288544, 'round level 15')
#     (0.0, 0, 0.04204520210623741, 'round level 14')
#     (-0.0, 0, -0.16658198833465576, 'round level 13')
#     (-0.0, 0, -0.21181248128414154, 'round level 12')
#     (0.0, 0, 0.13953788578510284, 'round level 11')
#     (-0.0, 0, -0.04653386026620865, 'round level 10')
#     (-0.0, 0, -0.24382942914962769, 'round level 9')
#     (-0.0, 0, -0.11428096145391464, 'round level 8')
#     (-0.0, 0, -0.20654737949371338, 'round level 7')
#     (0.0, 0, 0.18043582141399384, 'round level 6')
#     (-0.0, 0, -0.01020144671201706, 'round level 5')
#     (-0.0, 0, -0.13242115080356598, 'round level 4')
#     (0.0, 0, 0.20534852147102356, 'round level 3')
#     (0.0, 0, 0.005193918477743864, 'round level 1')
#
# linear combination for triple_raise :
#     (2.777012586593628, 1, 2.777012586593628, 'btn distance=6')
#     (-1.9720299243927002, 1, -1.9720299243927002, 'round level 2')
#     (-1.909784, 0, 0, 'bias')
#     (-1.7248280048370361, 1, -1.7248280048370361, 'player-0:state-active')
#     (0.518446147441864, 1, 0.518446147441864, 'street-preflop')
#     (-0.46799078583717346, 1, -0.46799078583717346, 'player-7:state-active')
#     (0.41638093524509, 0.2222222222222222, 1.8737142086029053, 'player-8:history')
#     (0.4136280218760172, 0.2222222222222222, 1.8613260984420776, 'player-6:history')
#     (0.39202311303880477, 0.2222222222222222, 1.7641040086746216, 'player-7:history')
#     (0.35728200276692706, 0.2222222222222222, 1.6077690124511719, 'player-9:history')
#     (0.21896723906199136, 0.1111111111111111, 1.9707051515579224, 'player-5:history')
#     (0.14130128622055055, 0.1, 1.4130128622055054, 'player-0:stack')
#     (0.12791864573955536, 1, 0.12791864573955536, 'player-9:state-active')
#     (0.12441851943731308, 1, 0.12441851943731308, 'player-1:state-active')
#     (0.09357129335403441, 0.564, 0.16590654850006104, 'cards')
#     (-0.06654716283082962, 1, -0.06654716283082962, 'player-5:state-active')
#     (0.06000101566314697, 1, 0.06000101566314697, 'player-3:state-active')
#     (0.05870455503463745, 1, 0.05870455503463745, 'player-4:state-active')
#     (-0.053477797329425814, 0.09975, -0.5361182689666748, 'player-5:stack')
#     (-0.04669942454993725, 0.0995, -0.4693409502506256, 'player-7:stack')
#     (-0.041102665662765506, 0.1, -0.41102665662765503, 'player-3:stack')
#     (-0.03881293535232544, 1, -0.03881293535232544, 'player-8:state-active')
#     (-0.036144770413637166, 0.0995, -0.3632640242576599, 'player-8:stack')
#     (-0.03553432142734528, 0.0995, -0.3571288585662842, 'player-6:stack')
#     (-0.03138427436351776, 0.1, -0.3138427436351776, 'player-4:stack')
#     (-0.02249520616233349, 0.0995, -0.2260824739933014, 'player-9:stack')
#     (-0.01850664019584656, 0.1, -0.18506640195846558, 'player-1:stack')
#     (-0.015496170520782471, 0.1, -0.1549617052078247, 'player-2:stack')
#     (-0.011507687158882618, 1, -0.011507687158882618, 'player-2:state-active')
#     (0.003263970138505101, 1, 0.003263970138505101, 'player-6:state-active')
#     (0.0004312784560024738, 0.00225, 0.19167931377887726, 'pot')
#     (0.0, 0, 0.07081695646047592, 'player-9:state-fold')
#     (-0.0, 0, -0.1046701967716217, 'player-8:state-fold')
#     (-0.0, 0, -0.36458832025527954, 'player-7:state-fold')
#     (0.0, 0, 0.054962389171123505, 'player-6:state-fold')
#     (-0.0, 0, -0.0387587696313858, 'player-5:state-fold')
#     (0.0, 0.0, 1.9687550067901611, 'player-4:history')
#     (0.0, 0, 0.13877908885478973, 'player-4:state-fold')
#     (0.0, 0.0, 2.0312254428863525, 'player-3:history')
#     (0.0, 0, 0.1692361831665039, 'player-3:state-fold')
#     (0.0, 0.0, 1.6113736629486084, 'player-2:history')
#     (0.0, 0, 0.03628944978117943, 'player-2:state-fold')
#     (0.0, 0.0, 1.802942156791687, 'player-1:history')
#     (0.0, 0, 0.18471992015838623, 'player-1:state-fold')
#     (0.0, 0.0, 1.668687105178833, 'player-0:history')
#     (0.0, 0, 0.04075248911976814, 'player-0:state-fold')
#     (0.0, 0, 0.6322498917579651, 'street-river')
#     (0.0, 0, 0.7929822206497192, 'street-turn')
#     (0.0, 0, 0.6097040176391602, 'street-flop')
#     (0.0, 0, 2.932969093322754, 'btn distance=9')
#     (0.0, 0, 2.9253368377685547, 'btn distance=8')
#     (0.0, 0, 3.011202573776245, 'btn distance=7')
#     (0.0, 0, 2.911156415939331, 'btn distance=5')
#     (0.0, 0, 2.848299026489258, 'btn distance=4')
#     (0.0, 0, 2.864824056625366, 'btn distance=3')
#     (0.0, 0, 3.043997287750244, 'btn distance=2')
#     (0.0, 0, 2.8935697078704834, 'btn distance=1')
#     (0.0, 0, 2.9243359565734863, 'btn distance=0')
#     (0.0, 0, 0.008020950481295586, 'round level 27')
#     (-0.0, 0, -0.17888143658638, 'round level 26')
#     (-0.0, 0, -0.11052364110946655, 'round level 25')
#     (0.0, 0, 0.10888233035802841, 'round level 24')
#     (0.0, 0, 0.1608966886997223, 'round level 23')
#     (-0.0, 0, -0.2377060353755951, 'round level 22')
#     (0.0, 0, 0.21409714221954346, 'round level 21')
#     (-0.0, 0, -0.21496911346912384, 'round level 20')
#     (0.0, 0, 0.0673115998506546, 'round level 19')
#     (-0.0, 0, -0.1885412335395813, 'round level 18')
#     (0.0, 0, 0.2565755248069763, 'round level 17')
#     (-0.0, 0, -0.047796376049518585, 'round level 16')
#     (0.0, 0, 0.0011935263173654675, 'round level 15')
#     (-0.0, 0, -0.20940327644348145, 'round level 14')
#     (0.0, 0, 0.14690224826335907, 'round level 13')
#     (0.0, 0, 0.054154470562934875, 'round level 12')
#     (0.0, 0, 0.15597549080848694, 'round level 11')
#     (0.0, 0, 0.07684778422117233, 'round level 10')
#     (-0.0, 0, -0.04693513736128807, 'round level 9')
#     (0.0, 0, 0.21320003271102905, 'round level 8')
#     (-0.0, 0, -0.06822678446769714, 'round level 7')
#     (0.0, 0, 0.12110030651092529, 'round level 6')
#     (0.0, 0, 0.09163427352905273, 'round level 5')
#     (0.0, 0, 0.030093930661678314, 'round level 4')
#     (-0.0, 0, -0.005681139416992664, 'round level 3')
#     (0.0, 0, 0.10348723828792572, 'round level 1')
#
# linear combination for max_raise :
#     (1.9072638750076294, 1, 1.9072638750076294, 'btn distance=6')
#     (-1.3490060567855835, 1, -1.3490060567855835, 'player-0:state-active')
#     (-1.1446064710617065, 1, -1.1446064710617065, 'round level 2')
#     (-1.1232594, 0, 0, 'bias')
#     (0.4695134692721896, 0.2222222222222222, 2.1128106117248535, 'player-6:history')
#     (0.4344698588053385, 0.2222222222222222, 1.9551143646240234, 'player-7:history')
#     (0.42502450942993164, 0.2222222222222222, 1.9126102924346924, 'player-8:history')
#     (0.4126768112182617, 0.2222222222222222, 1.8570456504821777, 'player-9:history')
#     (0.28351616859436035, 1, 0.28351616859436035, 'player-3:state-active')
#     (0.2610180079936981, 1, 0.2610180079936981, 'street-preflop')
#     (0.25589228296279903, 0.564, 0.4537097215652466, 'cards')
#     (0.22324268023173013, 0.1111111111111111, 2.0091841220855713, 'player-5:history')
#     (-0.21485579013824463, 1, -0.21485579013824463, 'player-7:state-active')
#     (-0.19954265654087067, 1, -0.19954265654087067, 'player-8:state-active')
#     (-0.15554408177733423, 0.09975, -1.559339165687561, 'player-5:stack')
#     (-0.15312464237213136, 0.1, -1.5312464237213135, 'player-4:stack')
#     (0.1449057161808014, 1, 0.1449057161808014, 'player-9:state-active')
#     (-0.14076958012580873, 0.0995, -1.4147696495056152, 'player-6:stack')
#     (-0.1370841717720032, 0.0995, -1.377730369567871, 'player-8:stack')
#     (-0.1366030216217041, 0.1, -1.366030216217041, 'player-3:stack')
#     (-0.13502114349603653, 0.0995, -1.3569964170455933, 'player-7:stack')
#     (-0.12207783460617067, 0.1, -1.2207783460617065, 'player-2:stack')
#     (-0.11952316761016846, 0.1, -1.1952316761016846, 'player-1:stack')
#     (-0.11390052735805511, 1, -0.11390052735805511, 'player-1:state-active')
#     (-0.10995652836561204, 0.0995, -1.1050907373428345, 'player-9:stack')
#     (0.057177519798278814, 0.1, 0.5717751979827881, 'player-0:stack')
#     (0.049003951251506805, 1, 0.049003951251506805, 'player-6:state-active')
#     (-0.01595880836248398, 1, -0.01595880836248398, 'player-4:state-active')
#     (-0.0018702379893511534, 1, -0.0018702379893511534, 'player-2:state-active')
#     (-0.0012868270576000213, 0.00225, -0.5719231367111206, 'pot')
#     (-0.0010247888276353478, 1, -0.0010247888276353478, 'player-5:state-active')
#     (0.0, 0, 0.16054750978946686, 'player-9:state-fold')
#     (-0.0, 0, -0.21090620756149292, 'player-8:state-fold')
#     (-0.0, 0, -0.15849505364894867, 'player-7:state-fold')
#     (0.0, 0, 0.0888524055480957, 'player-6:state-fold')
#     (0.0, 0, 0.048960186541080475, 'player-5:state-fold')
#     (0.0, 0.0, 1.9253836870193481, 'player-4:history')
#     (0.0, 0, 0.005241335369646549, 'player-4:state-fold')
#     (0.0, 0.0, 1.9096097946166992, 'player-3:history')
#     (0.0, 0, 0.29177629947662354, 'player-3:state-fold')
#     (0.0, 0.0, 1.9809449911117554, 'player-2:history')
#     (-0.0, 0, -0.07218189537525177, 'player-2:state-fold')
#     (0.0, 0.0, 1.9770967960357666, 'player-1:history')
#     (-0.0, 0, -0.08752410858869553, 'player-1:state-fold')
#     (0.0, 0.0, 2.359785556793213, 'player-0:history')
#     (0.0, 0, 0.07609657943248749, 'player-0:state-fold')
#     (0.0, 0, 0.3033589720726013, 'street-river')
#     (0.0, 0, 0.2428460568189621, 'street-turn')
#     (0.0, 0, 0.13293105363845825, 'street-flop')
#     (0.0, 0, 1.9139002561569214, 'btn distance=9')
#     (0.0, 0, 1.9561764001846313, 'btn distance=8')
#     (0.0, 0, 2.0012102127075195, 'btn distance=7')
#     (0.0, 0, 1.8928141593933105, 'btn distance=5')
#     (0.0, 0, 1.8904449939727783, 'btn distance=4')
#     (0.0, 0, 1.8775173425674438, 'btn distance=3')
#     (0.0, 0, 1.9946576356887817, 'btn distance=2')
#     (0.0, 0, 1.9409385919570923, 'btn distance=1')
#     (0.0, 0, 1.9573183059692383, 'btn distance=0')
#     (0.0, 0, 0.11246933043003082, 'round level 27')
#     (0.0, 0, 0.23121540248394012, 'round level 26')
#     (-0.0, 0, -0.1518223136663437, 'round level 25')
#     (0.0, 0, 0.143166646361351, 'round level 24')
#     (-0.0, 0, -0.11743029952049255, 'round level 23')
#     (0.0, 0, 0.11338414996862411, 'round level 22')
#     (0.0, 0, 0.17218057811260223, 'round level 21')
#     (-0.0, 0, -0.15079127252101898, 'round level 20')
#     (-0.0, 0, -0.027193639427423477, 'round level 19')
#     (-0.0, 0, -0.21092025935649872, 'round level 18')
#     (-0.0, 0, -0.06381283700466156, 'round level 17')
#     (-0.0, 0, -0.2114313393831253, 'round level 16')
#     (-0.0, 0, -0.13992951810359955, 'round level 15')
#     (-0.0, 0, -0.06705165654420853, 'round level 14')
#     (0.0, 0, 0.22516068816184998, 'round level 13')
#     (0.0, 0, 0.05737944692373276, 'round level 12')
#     (0.0, 0, 0.07443779706954956, 'round level 11')
#     (-0.0, 0, -0.11053375899791718, 'round level 10')
#     (-0.0, 0, -0.2071506381034851, 'round level 9')
#     (-0.0, 0, -0.0842650830745697, 'round level 8')
#     (0.0, 0, 0.004014415666460991, 'round level 7')
#     (0.0, 0, 0.14635255932807922, 'round level 6')
#     (0.0, 0, 0.08912111073732376, 'round level 5')
#     (-0.0, 0, -0.12405151128768921, 'round level 4')
#     (-0.0, 0, -0.1515631377696991, 'round level 3')
#     (-0.0, 0, -0.17977669835090637, 'round level 1')

# %% [markdown]
# ### FOLD or CALL でFOLDする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 39675
#   - raise: [-1, -1]
# -- hole card --
#   - ['DT', 'SQ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 19400, side = [{'amount': 30000, 'eligibles': ['uuid-7']}, {'amount': 0, 'eligibles': ['uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : allin, stack : 0
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 0
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 0
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 0
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0 <= SB
#     - 6 : agent (uuid-0) => state : participating, stack : 31050 <= BB, CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 9775
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 9775
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'add_amount': 9625, 'paid': 9675, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 9675, 'action': 'RAISE'}
#       - {'add_amount': 30000, 'paid': 39650, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 39675, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 8
#   => [('fold', 0.06814971566200256), ('call', -0.09554660320281982)]
# ** weights and features in detail **
# bias : [-0.48353687 -0.24881023 -1.78213286 -2.03190184 -1.90978396 -1.12325943]
#
# linear combination for fold :
#     (1.213940143585205, 1, 1.213940143585205, 'btn distance=6')
#     (0.858260994015435, 0.8031376518218624, 1.0686349868774414, 'player-9:history')
#     (-0.6320859005451203, 0.494, -1.2795261144638062, 'pot')
#     (-0.5504411458969116, 1, -0.5504411458969116, 'round level 2')
#     (-0.48353687, 0, 0, 'bias')
#     (-0.3082176148891449, 1, -0.3082176148891449, 'player-0:state-active')
#     (0.29554614424705505, 1, 0.29554614424705505, 'player-9:state-active')
#     (0.2182656273185483, 0.1958502024291498, 1.1144518852233887, 'player-4:history')
#     (0.18649287137389184, 0.3105, 0.6006211638450623, 'player-0:stack')
#     (-0.1367029871046543, 0.09775, -1.3984960317611694, 'player-1:stack')
#     (-0.11639033600687981, 0.09775, -1.190693974494934, 'player-2:stack')
#     (-0.1091219112277031, 1, -0.1091219112277031, 'player-1:state-fold')
#     (-0.08074988424777985, 1, -0.08074988424777985, 'player-8:state-fold')
#     (-0.07917696982622147, 1, -0.07917696982622147, 'player-5:state-fold')
#     (-0.07800084352493286, 1, -0.07800084352493286, 'player-7:state-fold')
#     (-0.055877212435007095, 1, -0.055877212435007095, 'player-3:state-fold')
#     (-0.03254611194133759, 0.675, -0.04821646213531494, 'cards')
#     (-0.02842237614095211, 1, -0.02842237614095211, 'player-6:state-fold')
#     (-0.025638192892074585, 1, -0.025638192892074585, 'player-4:state-active')
#     (0.020596105605363846, 1, 0.020596105605363846, 'player-2:state-fold')
#     (-0.0091206980869174, 1, -0.0091206980869174, 'street-preflop')
#     (0.0010767971214495208, 0.0010121457489878543, 1.0638755559921265, 'player-0:history')
#     (0.0, 0, 0.3290203809738159, 'player-9:state-fold')
#     (-0.0, 0.0, -1.5890644788742065, 'player-9:stack')
#     (0.0, 0.0, 1.246514081954956, 'player-8:history')
#     (-0.0, 0, -0.03097626380622387, 'player-8:state-active')
#     (-0.0, 0.0, -1.2607468366622925, 'player-8:stack')
#     (0.0, 0.0, 0.9841926693916321, 'player-7:history')
#     (-0.0, 0, -0.11354628950357437, 'player-7:state-active')
#     (-0.0, 0.0, -1.4459601640701294, 'player-7:stack')
#     (0.0, 0.0, 1.0321004390716553, 'player-6:history')
#     (-0.0, 0, -0.017108134925365448, 'player-6:state-active')
#     (-0.0, 0.0, -1.3039556741714478, 'player-6:stack')
#     (0.0, 0.0, 1.0770936012268066, 'player-5:history')
#     (-0.0, 0, -0.0735795870423317, 'player-5:state-active')
#     (-0.0, 0.0, -1.6385854482650757, 'player-5:stack')
#     (0.0, 0, 0.05473426729440689, 'player-4:state-fold')
#     (-0.0, 0.0, -1.3378541469573975, 'player-4:stack')
#     (0.0, 0.0, 1.0370513200759888, 'player-3:history')
#     (-0.0, 0, -0.04053684324026108, 'player-3:state-active')
#     (-0.0, 0.0, -1.3304693698883057, 'player-3:stack')
#     (0.0, 0.0, 1.1363270282745361, 'player-2:history')
#     (-0.0, 0, -0.09789295494556427, 'player-2:state-active')
#     (0.0, 0.0, 1.0625455379486084, 'player-1:history')
#     (-0.0, 0, -0.185475692152977, 'player-1:state-active')
#     (-0.0, 0, -0.13157254457473755, 'player-0:state-fold')
#     (-0.0, 0, -0.058312587440013885, 'street-river')
#     (0.0, 0, 0.021209783852100372, 'street-turn')
#     (-0.0, 0, -0.0214112289249897, 'street-flop')
#     (0.0, 0, 1.325065016746521, 'btn distance=9')
#     (0.0, 0, 1.4019274711608887, 'btn distance=8')
#     (0.0, 0, 1.4151992797851562, 'btn distance=7')
#     (0.0, 0, 1.2666823863983154, 'btn distance=5')
#     (0.0, 0, 1.2417488098144531, 'btn distance=4')
#     (0.0, 0, 1.2136343717575073, 'btn distance=3')
#     (0.0, 0, 1.1977404356002808, 'btn distance=2')
#     (0.0, 0, 1.3430707454681396, 'btn distance=1')
#     (0.0, 0, 1.3178373575210571, 'btn distance=0')
#     (-0.0, 0, -0.21972104907035828, 'round level 27')
#     (-0.0, 0, -0.16887789964675903, 'round level 26')
#     (-0.0, 0, -0.056195277720689774, 'round level 25')
#     (-0.0, 0, -0.0224585123360157, 'round level 24')
#     (0.0, 0, 0.21297651529312134, 'round level 23')
#     (0.0, 0, 0.11313529312610626, 'round level 22')
#     (0.0, 0, 0.21001067757606506, 'round level 21')
#     (-0.0, 0, -0.14171156287193298, 'round level 20')
#     (0.0, 0, 0.13536091148853302, 'round level 19')
#     (0.0, 0, 0.22831162810325623, 'round level 18')
#     (-0.0, 0, -0.22597871720790863, 'round level 17')
#     (0.0, 0, 0.07464097440242767, 'round level 16')
#     (0.0, 0, 0.17132167518138885, 'round level 15')
#     (-0.0, 0, -0.05531512200832367, 'round level 14')
#     (0.0, 0, 0.21716493368148804, 'round level 13')
#     (-0.0, 0, -0.09104923903942108, 'round level 12')
#     (-0.0, 0, -0.25070151686668396, 'round level 11')
#     (-0.0, 0, -0.08039606362581253, 'round level 10')
#     (-0.0, 0, -0.05438179895281792, 'round level 9')
#     (0.0, 0, 0.17122764885425568, 'round level 8')
#     (-0.0, 0, -0.18322034180164337, 'round level 7')
#     (0.0, 0, 0.04171256348490715, 'round level 6')
#     (-0.0, 0, -0.2578655481338501, 'round level 5')
#     (-0.0, 0, -0.17897067964076996, 'round level 4')
#     (-0.0, 0, -0.2215890735387802, 'round level 3')
#     (-0.0, 0, -0.01656218059360981, 'round level 1')
#
# linear combination for call :
#     (-0.7562305626869201, 0.494, -1.5308310985565186, 'pot')
#     (0.6286750048398972, 0.675, 0.9313703775405884, 'cards')
#     (-0.25926724076271057, 1, -0.25926724076271057, 'street-preflop')
#     (-0.24881023, 0, 0, 'bias')
#     (0.18884600698947906, 1, 0.18884600698947906, 'player-8:state-fold')
#     (0.18202362954616547, 1, 0.18202362954616547, 'player-7:state-fold')
#     (-0.1712895780801773, 1, -0.1712895780801773, 'player-1:state-fold')
#     (0.16455107799124138, 0.8031376518218624, 0.20488527417182922, 'player-9:history')
#     (-0.15554481008648874, 0.09775, -1.591251254081726, 'player-1:stack')
#     (-0.14888378423452378, 0.09775, -1.5231077671051025, 'player-2:stack')
#     (0.14023910462856293, 1, 0.14023910462856293, 'player-9:state-active')
#     (0.139820396900177, 1, 0.139820396900177, 'player-4:state-active')
#     (0.12559907138347626, 1, 0.12559907138347626, 'player-3:state-fold')
#     (0.11747884699702263, 0.3105, 0.3783537745475769, 'player-0:stack')
#     (0.10749158263206482, 1, 0.10749158263206482, 'player-6:state-fold')
#     (-0.10114721953868866, 1, -0.10114721953868866, 'round level 2')
#     (-0.0666251853108406, 1, -0.0666251853108406, 'player-0:state-active')
#     (0.033042505383491516, 1, 0.033042505383491516, 'btn distance=6')
#     (0.022044391767216114, 0.1958502024291498, 0.11255741119384766, 'player-4:history')
#     (-0.021531887352466583, 1, -0.021531887352466583, 'player-5:state-fold')
#     (-0.016709184274077415, 1, -0.016709184274077415, 'player-2:state-fold')
#     (0.0006813427455994764, 0.0010121457489878543, 0.6731666326522827, 'player-0:history')
#     (0.0, 0, 0.1583608090877533, 'player-9:state-fold')
#     (-0.0, 0.0, -1.4392895698547363, 'player-9:stack')
#     (0.0, 0.0, 0.20101043581962585, 'player-8:history')
#     (0.0, 0, 0.17627842724323273, 'player-8:state-active')
#     (-0.0, 0.0, -1.4819976091384888, 'player-8:stack')
#     (0.0, 0.0, 0.05594567209482193, 'player-7:history')
#     (0.0, 0, 0.15847960114479065, 'player-7:state-active')
#     (-0.0, 0.0, -1.4213441610336304, 'player-7:stack')
#     (0.0, 0.0, 0.019110267981886864, 'player-6:history')
#     (0.0, 0, 0.22829273343086243, 'player-6:state-active')
#     (-0.0, 0.0, -1.5038646459579468, 'player-6:stack')
#     (0.0, 0.0, 0.04617088660597801, 'player-5:history')
#     (0.0, 0, 0.03996642306447029, 'player-5:state-active')
#     (-0.0, 0.0, -1.7940489053726196, 'player-5:stack')
#     (0.0, 0, 0.144008606672287, 'player-4:state-fold')
#     (-0.0, 0.0, -1.5567740201950073, 'player-4:stack')
#     (0.0, 0.0, 0.03554701432585716, 'player-3:history')
#     (0.0, 0, 0.15041644871234894, 'player-3:state-active')
#     (-0.0, 0.0, -1.7098089456558228, 'player-3:stack')
#     (0.0, 0.0, 0.0787128210067749, 'player-2:history')
#     (-0.0, 0, -0.0617591068148613, 'player-2:state-active')
#     (0.0, 0.0, 0.035544831305742264, 'player-1:history')
#     (-0.0, 0, -0.24511785805225372, 'player-1:state-active')
#     (0.0, 0, 0.0506884902715683, 'player-0:state-fold')
#     (-0.0, 0, -0.5945714116096497, 'street-river')
#     (-0.0, 0, -0.42862606048583984, 'street-turn')
#     (-0.0, 0, -0.3372102975845337, 'street-flop')
#     (0.0, 0, 0.22869279980659485, 'btn distance=9')
#     (0.0, 0, 0.2711631953716278, 'btn distance=8')
#     (0.0, 0, 0.2218068391084671, 'btn distance=7')
#     (0.0, 0, 0.1621607095003128, 'btn distance=5')
#     (0.0, 0, 0.11350041627883911, 'btn distance=4')
#     (0.0, 0, 0.2085464596748352, 'btn distance=3')
#     (0.0, 0, 0.16336408257484436, 'btn distance=2')
#     (0.0, 0, 0.09508673846721649, 'btn distance=1')
#     (0.0, 0, 0.1494542807340622, 'btn distance=0')
#     (0.0, 0, 0.05240476503968239, 'round level 27')
#     (0.0, 0, 0.003269001841545105, 'round level 26')
#     (0.0, 0, 0.2429712414741516, 'round level 25')
#     (0.0, 0, 0.18841516971588135, 'round level 24')
#     (0.0, 0, 0.2595265209674835, 'round level 23')
#     (0.0, 0, 0.14526015520095825, 'round level 22')
#     (-0.0, 0, -0.05364101752638817, 'round level 21')
#     (-0.0, 0, -0.25889888405799866, 'round level 20')
#     (0.0, 0, 0.20514066517353058, 'round level 19')
#     (-0.0, 0, -0.15952783823013306, 'round level 18')
#     (-0.0, 0, -0.2368985414505005, 'round level 17')
#     (0.0, 0, 0.021499469876289368, 'round level 16')
#     (-0.0, 0, -0.15992547571659088, 'round level 15')
#     (0.0, 0, 0.13773998618125916, 'round level 14')
#     (0.0, 0, 0.03223136439919472, 'round level 13')
#     (0.0, 0, 0.1264357566833496, 'round level 12')
#     (-0.0, 0, -0.10693281143903732, 'round level 11')
#     (0.0, 0, 0.16666394472122192, 'round level 10')
#     (0.0, 0, 0.20799539983272552, 'round level 9')
#     (0.0, 0, 0.20435722172260284, 'round level 8')
#     (-0.0, 0, -0.012952451594173908, 'round level 7')
#     (0.0, 0, 0.16907642781734467, 'round level 6')
#     (0.0, 0, 0.05249634385108948, 'round level 5')
#     (-0.0, 0, -0.1286989152431488, 'round level 4')
#     (0.0, 0, 0.2346666008234024, 'round level 3')
#     (-0.0, 0, -0.18063881993293762, 'round level 1')

# %% [markdown]
# ### 全選択肢からFOLDを選ぶ場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 60125]
# -- hole card --
#   - ['H3', 'D8']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 0
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 0
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9925 <= SB
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9900 <= BB
#     - 6 : agent (uuid-0) => state : participating, stack : 60125 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 0
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 0
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'add_amount': 25}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 2
#   => [('fold', 0.7117838859558105), ('call', 0.5277034640312195), ('min_raise', 0.4719395637512207), ('double_raise', 0.3619663715362549), ('triple_raise', 0.47892940044403076), ('max_raise', 0.4414132833480835)]
# ** weights and features in detail **
# bias : [-0.48353687 -0.24881023 -1.78213286 -2.03190184 -1.90978396 -1.12325943]
#
# linear combination for fold :
#     (1.2666823863983154, 1, 1.2666823863983154, 'btn distance=5')
#     (0.7124233245849609, 0.6666666666666666, 1.0686349868774414, 'player-9:history')
#     (-0.5504411458969116, 1, -0.5504411458969116, 'round level 2')
#     (-0.48353687, 0, 0, 'bias')
#     (0.41550469398498535, 0.3333333333333333, 1.246514081954956, 'player-8:history')
#     (0.36112347476184364, 0.60125, 0.6006211638450623, 'player-0:stack')
#     (-0.3082176148891449, 1, -0.3082176148891449, 'player-0:state-active')
#     (0.29554614424705505, 1, 0.29554614424705505, 'player-9:state-active')
#     (-0.1634488984644413, 0.09975, -1.6385854482650757, 'player-5:stack')
#     (-0.15731738340854645, 0.099, -1.5890644788742065, 'player-9:stack')
#     (-0.13378541469573976, 0.1, -1.3378541469573975, 'player-4:stack')
#     (-0.12512912353873254, 0.09925, -1.2607468366622925, 'player-8:stack')
#     (-0.1091219112277031, 1, -0.1091219112277031, 'player-1:state-fold')
#     (-0.07800084352493286, 1, -0.07800084352493286, 'player-7:state-fold')
#     (-0.0735795870423317, 1, -0.0735795870423317, 'player-5:state-active')
#     (-0.055877212435007095, 1, -0.055877212435007095, 'player-3:state-fold')
#     (-0.03097626380622387, 1, -0.03097626380622387, 'player-8:state-active')
#     (-0.02842237614095211, 1, -0.02842237614095211, 'player-6:state-fold')
#     (-0.02651905417442322, 0.55, -0.04821646213531494, 'cards')
#     (-0.025638192892074585, 1, -0.025638192892074585, 'player-4:state-active')
#     (0.020596105605363846, 1, 0.020596105605363846, 'player-2:state-fold')
#     (-0.0091206980869174, 1, -0.0091206980869174, 'street-preflop')
#     (-0.0009596445858478547, 0.00075, -1.2795261144638062, 'pot')
#     (0.0, 0, 0.3290203809738159, 'player-9:state-fold')
#     (-0.0, 0, -0.08074988424777985, 'player-8:state-fold')
#     (0.0, 0.0, 0.9841926693916321, 'player-7:history')
#     (-0.0, 0, -0.11354628950357437, 'player-7:state-active')
#     (-0.0, 0.0, -1.4459601640701294, 'player-7:stack')
#     (0.0, 0.0, 1.0321004390716553, 'player-6:history')
#     (-0.0, 0, -0.017108134925365448, 'player-6:state-active')
#     (-0.0, 0.0, -1.3039556741714478, 'player-6:stack')
#     (0.0, 0.0, 1.0770936012268066, 'player-5:history')
#     (-0.0, 0, -0.07917696982622147, 'player-5:state-fold')
#     (0.0, 0.0, 1.1144518852233887, 'player-4:history')
#     (0.0, 0, 0.05473426729440689, 'player-4:state-fold')
#     (0.0, 0.0, 1.0370513200759888, 'player-3:history')
#     (-0.0, 0, -0.04053684324026108, 'player-3:state-active')
#     (-0.0, 0.0, -1.3304693698883057, 'player-3:stack')
#     (0.0, 0.0, 1.1363270282745361, 'player-2:history')
#     (-0.0, 0, -0.09789295494556427, 'player-2:state-active')
#     (-0.0, 0.0, -1.190693974494934, 'player-2:stack')
#     (0.0, 0.0, 1.0625455379486084, 'player-1:history')
#     (-0.0, 0, -0.185475692152977, 'player-1:state-active')
#     (-0.0, 0.0, -1.3984960317611694, 'player-1:stack')
#     (0.0, 0.0, 1.0638755559921265, 'player-0:history')
#     (-0.0, 0, -0.13157254457473755, 'player-0:state-fold')
#     (-0.0, 0, -0.058312587440013885, 'street-river')
#     (0.0, 0, 0.021209783852100372, 'street-turn')
#     (-0.0, 0, -0.0214112289249897, 'street-flop')
#     (0.0, 0, 1.325065016746521, 'btn distance=9')
#     (0.0, 0, 1.4019274711608887, 'btn distance=8')
#     (0.0, 0, 1.4151992797851562, 'btn distance=7')
#     (0.0, 0, 1.213940143585205, 'btn distance=6')
#     (0.0, 0, 1.2417488098144531, 'btn distance=4')
#     (0.0, 0, 1.2136343717575073, 'btn distance=3')
#     (0.0, 0, 1.1977404356002808, 'btn distance=2')
#     (0.0, 0, 1.3430707454681396, 'btn distance=1')
#     (0.0, 0, 1.3178373575210571, 'btn distance=0')
#     (-0.0, 0, -0.21972104907035828, 'round level 27')
#     (-0.0, 0, -0.16887789964675903, 'round level 26')
#     (-0.0, 0, -0.056195277720689774, 'round level 25')
#     (-0.0, 0, -0.0224585123360157, 'round level 24')
#     (0.0, 0, 0.21297651529312134, 'round level 23')
#     (0.0, 0, 0.11313529312610626, 'round level 22')
#     (0.0, 0, 0.21001067757606506, 'round level 21')
#     (-0.0, 0, -0.14171156287193298, 'round level 20')
#     (0.0, 0, 0.13536091148853302, 'round level 19')
#     (0.0, 0, 0.22831162810325623, 'round level 18')
#     (-0.0, 0, -0.22597871720790863, 'round level 17')
#     (0.0, 0, 0.07464097440242767, 'round level 16')
#     (0.0, 0, 0.17132167518138885, 'round level 15')
#     (-0.0, 0, -0.05531512200832367, 'round level 14')
#     (0.0, 0, 0.21716493368148804, 'round level 13')
#     (-0.0, 0, -0.09104923903942108, 'round level 12')
#     (-0.0, 0, -0.25070151686668396, 'round level 11')
#     (-0.0, 0, -0.08039606362581253, 'round level 10')
#     (-0.0, 0, -0.05438179895281792, 'round level 9')
#     (0.0, 0, 0.17122764885425568, 'round level 8')
#     (-0.0, 0, -0.18322034180164337, 'round level 7')
#     (0.0, 0, 0.04171256348490715, 'round level 6')
#     (-0.0, 0, -0.2578655481338501, 'round level 5')
#     (-0.0, 0, -0.17897067964076996, 'round level 4')
#     (-0.0, 0, -0.2215890735387802, 'round level 3')
#     (-0.0, 0, -0.01656218059360981, 'round level 1')
#
# linear combination for call :
#     (0.5122537076473237, 0.55, 0.9313703775405884, 'cards')
#     (-0.25926724076271057, 1, -0.25926724076271057, 'street-preflop')
#     (-0.24881023, 0, 0, 'bias')
#     (0.2274852069467306, 0.60125, 0.3783537745475769, 'player-0:stack')
#     (0.18202362954616547, 1, 0.18202362954616547, 'player-7:state-fold')
#     (-0.17895637831091882, 0.09975, -1.7940489053726196, 'player-5:stack')
#     (0.17627842724323273, 1, 0.17627842724323273, 'player-8:state-active')
#     (-0.1712895780801773, 1, -0.1712895780801773, 'player-1:state-fold')
#     (0.1621607095003128, 1, 0.1621607095003128, 'btn distance=5')
#     (-0.15567740201950075, 0.1, -1.5567740201950073, 'player-4:stack')
#     (-0.14708826270699502, 0.09925, -1.4819976091384888, 'player-8:stack')
#     (-0.14248966741561891, 0.099, -1.4392895698547363, 'player-9:stack')
#     (0.14023910462856293, 1, 0.14023910462856293, 'player-9:state-active')
#     (0.139820396900177, 1, 0.139820396900177, 'player-4:state-active')
#     (0.13659018278121948, 0.6666666666666666, 0.20488527417182922, 'player-9:history')
#     (0.12559907138347626, 1, 0.12559907138347626, 'player-3:state-fold')
#     (0.10749158263206482, 1, 0.10749158263206482, 'player-6:state-fold')
#     (-0.10114721953868866, 1, -0.10114721953868866, 'round level 2')
#     (0.06700347860654195, 0.3333333333333333, 0.20101043581962585, 'player-8:history')
#     (-0.0666251853108406, 1, -0.0666251853108406, 'player-0:state-active')
#     (0.03996642306447029, 1, 0.03996642306447029, 'player-5:state-active')
#     (-0.016709184274077415, 1, -0.016709184274077415, 'player-2:state-fold')
#     (-0.001148123323917389, 0.00075, -1.5308310985565186, 'pot')
#     (0.0, 0, 0.1583608090877533, 'player-9:state-fold')
#     (0.0, 0, 0.18884600698947906, 'player-8:state-fold')
#     (0.0, 0.0, 0.05594567209482193, 'player-7:history')
#     (0.0, 0, 0.15847960114479065, 'player-7:state-active')
#     (-0.0, 0.0, -1.4213441610336304, 'player-7:stack')
#     (0.0, 0.0, 0.019110267981886864, 'player-6:history')
#     (0.0, 0, 0.22829273343086243, 'player-6:state-active')
#     (-0.0, 0.0, -1.5038646459579468, 'player-6:stack')
#     (0.0, 0.0, 0.04617088660597801, 'player-5:history')
#     (-0.0, 0, -0.021531887352466583, 'player-5:state-fold')
#     (0.0, 0.0, 0.11255741119384766, 'player-4:history')
#     (0.0, 0, 0.144008606672287, 'player-4:state-fold')
#     (0.0, 0.0, 0.03554701432585716, 'player-3:history')
#     (0.0, 0, 0.15041644871234894, 'player-3:state-active')
#     (-0.0, 0.0, -1.7098089456558228, 'player-3:stack')
#     (0.0, 0.0, 0.0787128210067749, 'player-2:history')
#     (-0.0, 0, -0.0617591068148613, 'player-2:state-active')
#     (-0.0, 0.0, -1.5231077671051025, 'player-2:stack')
#     (0.0, 0.0, 0.035544831305742264, 'player-1:history')
#     (-0.0, 0, -0.24511785805225372, 'player-1:state-active')
#     (-0.0, 0.0, -1.591251254081726, 'player-1:stack')
#     (0.0, 0.0, 0.6731666326522827, 'player-0:history')
#     (0.0, 0, 0.0506884902715683, 'player-0:state-fold')
#     (-0.0, 0, -0.5945714116096497, 'street-river')
#     (-0.0, 0, -0.42862606048583984, 'street-turn')
#     (-0.0, 0, -0.3372102975845337, 'street-flop')
#     (0.0, 0, 0.22869279980659485, 'btn distance=9')
#     (0.0, 0, 0.2711631953716278, 'btn distance=8')
#     (0.0, 0, 0.2218068391084671, 'btn distance=7')
#     (0.0, 0, 0.033042505383491516, 'btn distance=6')
#     (0.0, 0, 0.11350041627883911, 'btn distance=4')
#     (0.0, 0, 0.2085464596748352, 'btn distance=3')
#     (0.0, 0, 0.16336408257484436, 'btn distance=2')
#     (0.0, 0, 0.09508673846721649, 'btn distance=1')
#     (0.0, 0, 0.1494542807340622, 'btn distance=0')
#     (0.0, 0, 0.05240476503968239, 'round level 27')
#     (0.0, 0, 0.003269001841545105, 'round level 26')
#     (0.0, 0, 0.2429712414741516, 'round level 25')
#     (0.0, 0, 0.18841516971588135, 'round level 24')
#     (0.0, 0, 0.2595265209674835, 'round level 23')
#     (0.0, 0, 0.14526015520095825, 'round level 22')
#     (-0.0, 0, -0.05364101752638817, 'round level 21')
#     (-0.0, 0, -0.25889888405799866, 'round level 20')
#     (0.0, 0, 0.20514066517353058, 'round level 19')
#     (-0.0, 0, -0.15952783823013306, 'round level 18')
#     (-0.0, 0, -0.2368985414505005, 'round level 17')
#     (0.0, 0, 0.021499469876289368, 'round level 16')
#     (-0.0, 0, -0.15992547571659088, 'round level 15')
#     (0.0, 0, 0.13773998618125916, 'round level 14')
#     (0.0, 0, 0.03223136439919472, 'round level 13')
#     (0.0, 0, 0.1264357566833496, 'round level 12')
#     (-0.0, 0, -0.10693281143903732, 'round level 11')
#     (0.0, 0, 0.16666394472122192, 'round level 10')
#     (0.0, 0, 0.20799539983272552, 'round level 9')
#     (0.0, 0, 0.20435722172260284, 'round level 8')
#     (-0.0, 0, -0.012952451594173908, 'round level 7')
#     (0.0, 0, 0.16907642781734467, 'round level 6')
#     (0.0, 0, 0.05249634385108948, 'round level 5')
#     (-0.0, 0, -0.1286989152431488, 'round level 4')
#     (0.0, 0, 0.2346666008234024, 'round level 3')
#     (-0.0, 0, -0.18063881993293762, 'round level 1')
#
# linear combination for min_raise :
#     (3.2197015285491943, 1, 3.2197015285491943, 'btn distance=5')
#     (-1.7821329, 0, 0, 'bias')
#     (-1.747273564338684, 1, -1.747273564338684, 'player-0:state-active')
#     (-1.5308681726455688, 1, -1.5308681726455688, 'round level 2')
#     (1.339147408803304, 0.6666666666666666, 2.008721113204956, 'player-9:history')
#     (0.729743242263794, 0.3333333333333333, 2.189229726791382, 'player-8:history')
#     (0.621021219342947, 0.60125, 1.0328835248947144, 'player-0:stack')
#     (-0.3169701397418976, 1, -0.3169701397418976, 'player-8:state-active')
#     (0.2779412865638733, 1, 0.2779412865638733, 'player-2:state-fold')
#     (-0.25521501898765564, 1, -0.25521501898765564, 'player-7:state-fold')
#     (0.1933107912540436, 0.55, 0.35147416591644287, 'cards')
#     (0.12282508611679077, 1, 0.12282508611679077, 'player-1:state-fold')
#     (-0.07977888849377633, 0.09975, -0.7997883558273315, 'player-5:stack')
#     (-0.07264379411935806, 1, -0.07264379411935806, 'player-5:state-active')
#     (-0.07108762343227863, 0.09925, -0.716248095035553, 'player-8:stack')
#     (-0.0673636611700058, 0.099, -0.6804410219192505, 'player-9:stack')
#     (-0.05308401584625244, 1, -0.05308401584625244, 'player-4:state-active')
#     (-0.05077544450759888, 0.1, -0.5077544450759888, 'player-4:stack')
#     (-0.03639017418026924, 1, -0.03639017418026924, 'player-6:state-fold')
#     (0.027887772768735886, 1, 0.027887772768735886, 'street-preflop')
#     (0.016544779762625694, 1, 0.016544779762625694, 'player-3:state-fold')
#     (-0.012242932803928852, 1, -0.012242932803928852, 'player-9:state-active')
#     (-0.00035726945847272876, 0.00075, -0.4763592779636383, 'pot')
#     (-0.0, 0, -0.009885293431580067, 'player-9:state-fold')
#     (-0.0, 0, -0.36383065581321716, 'player-8:state-fold')
#     (0.0, 0.0, 2.205390691757202, 'player-7:history')
#     (-0.0, 0, -0.3422319293022156, 'player-7:state-active')
#     (-0.0, 0.0, -0.7898432016372681, 'player-7:stack')
#     (0.0, 0.0, 2.125567674636841, 'player-6:history')
#     (-0.0, 0, -0.11795627325773239, 'player-6:state-active')
#     (-0.0, 0.0, -0.6421878933906555, 'player-6:stack')
#     (0.0, 0.0, 2.167220115661621, 'player-5:history')
#     (-0.0, 0, -0.09889116883277893, 'player-5:state-fold')
#     (0.0, 0.0, 2.2595601081848145, 'player-4:history')
#     (-0.0, 0, -0.061681050807237625, 'player-4:state-fold')
#     (0.0, 0.0, 2.1437301635742188, 'player-3:history')
#     (-0.0, 0, -0.14947839081287384, 'player-3:state-active')
#     (-0.0, 0.0, -0.8002043962478638, 'player-3:stack')
#     (0.0, 0.0, 2.061837911605835, 'player-2:history')
#     (0.0, 0, 0.18198390305042267, 'player-2:state-active')
#     (-0.0, 0.0, -0.7118945121765137, 'player-2:stack')
#     (0.0, 0.0, 2.265964984893799, 'player-1:history')
#     (0.0, 0, 0.1469043791294098, 'player-1:state-active')
#     (-0.0, 0.0, -0.6444417238235474, 'player-1:stack')
#     (0.0, 0.0, 2.455728054046631, 'player-0:history')
#     (0.0, 0, 0.07190699130296707, 'player-0:state-fold')
#     (-0.0, 0, -0.050476666539907455, 'street-river')
#     (0.0, 0, 0.11330259591341019, 'street-turn')
#     (0.0, 0, 0.15895408391952515, 'street-flop')
#     (0.0, 0, 3.1835520267486572, 'btn distance=9')
#     (0.0, 0, 3.2953693866729736, 'btn distance=8')
#     (0.0, 0, 3.2720251083374023, 'btn distance=7')
#     (0.0, 0, 3.1817588806152344, 'btn distance=6')
#     (0.0, 0, 3.1331751346588135, 'btn distance=4')
#     (0.0, 0, 3.217989683151245, 'btn distance=3')
#     (0.0, 0, 3.2322170734405518, 'btn distance=2')
#     (0.0, 0, 3.2189176082611084, 'btn distance=1')
#     (0.0, 0, 3.2374656200408936, 'btn distance=0')
#     (0.0, 0, 0.25229722261428833, 'round level 27')
#     (0.0, 0, 0.22346574068069458, 'round level 26')
#     (-0.0, 0, -0.024008633568882942, 'round level 25')
#     (-0.0, 0, -0.16542094945907593, 'round level 24')
#     (-0.0, 0, -0.09414144605398178, 'round level 23')
#     (0.0, 0, 0.1686987429857254, 'round level 22')
#     (0.0, 0, 0.17665095627307892, 'round level 21')
#     (-0.0, 0, -0.18036343157291412, 'round level 20')
#     (0.0, 0, 0.22174479067325592, 'round level 19')
#     (-0.0, 0, -0.15750350058078766, 'round level 18')
#     (0.0, 0, 0.1287153661251068, 'round level 17')
#     (0.0, 0, 0.05211281776428223, 'round level 16')
#     (-0.0, 0, -0.07095134258270264, 'round level 15')
#     (-0.0, 0, -0.16400404274463654, 'round level 14')
#     (-0.0, 0, -0.19781464338302612, 'round level 13')
#     (0.0, 0, 0.00890976283699274, 'round level 12')
#     (-0.0, 0, -0.10713862627744675, 'round level 11')
#     (-0.0, 0, -0.09665833413600922, 'round level 10')
#     (-0.0, 0, -0.03662043809890747, 'round level 9')
#     (0.0, 0, 0.2009717971086502, 'round level 8')
#     (-0.0, 0, -0.08257033675909042, 'round level 7')
#     (0.0, 0, 0.1913730353116989, 'round level 6')
#     (0.0, 0, 0.17685194313526154, 'round level 5')
#     (-0.0, 0, -0.04237651824951172, 'round level 4')
#     (0.0, 0, 0.18527163565158844, 'round level 3')
#     (0.0, 0, 0.05876008793711662, 'round level 1')
#
# linear combination for double_raise :
#     (3.279503583908081, 1, 3.279503583908081, 'btn distance=5')
#     (-2.21936297416687, 1, -2.21936297416687, 'round level 2')
#     (-2.0319018, 0, 0, 'bias')
#     (-1.7936919927597046, 1, -1.7936919927597046, 'player-0:state-active')
#     (1.3862241109212239, 0.6666666666666666, 2.079336166381836, 'player-9:history')
#     (0.8473855432868003, 0.60125, 1.4093730449676514, 'player-0:stack')
#     (0.7145766417185465, 0.3333333333333333, 2.1437299251556396, 'player-8:history')
#     (-0.48104143142700195, 1, -0.48104143142700195, 'player-7:state-fold')
#     (0.4399876594543457, 1, 0.4399876594543457, 'street-preflop')
#     (0.22699761390686035, 1, 0.22699761390686035, 'player-4:state-active')
#     (0.21921734511852264, 1, 0.21921734511852264, 'player-3:state-fold')
#     (-0.19770953059196472, 1, -0.19770953059196472, 'player-8:state-active')
#     (0.19748517870903015, 1, 0.19748517870903015, 'player-6:state-fold')
#     (-0.18838202953338623, 1, -0.18838202953338623, 'player-9:state-active')
#     (0.12099867165088654, 0.55, 0.2199975848197937, 'cards')
#     (-0.0681053575873375, 0.09975, -0.68276047706604, 'player-5:stack')
#     (-0.046351441740989686, 0.1, -0.46351441740989685, 'player-4:stack')
#     (0.03557249531149864, 1, 0.03557249531149864, 'player-1:state-fold')
#     (-0.030746046729385853, 0.09925, -0.30978384613990784, 'player-8:stack')
#     (-0.022984245881438256, 0.099, -0.23216409981250763, 'player-9:stack')
#     (-0.020117923617362976, 1, -0.020117923617362976, 'player-5:state-active')
#     (-0.005740904249250889, 1, -0.005740904249250889, 'player-2:state-fold')
#     (0.00015277499333024024, 0.00075, 0.203699991106987, 'pot')
#     (-0.0, 0, -0.34994077682495117, 'player-9:state-fold')
#     (-0.0, 0, -0.274885892868042, 'player-8:state-fold')
#     (0.0, 0.0, 2.1001970767974854, 'player-7:history')
#     (-0.0, 0, -0.5111181139945984, 'player-7:state-active')
#     (-0.0, 0.0, -0.5497721433639526, 'player-7:stack')
#     (0.0, 0.0, 2.235436201095581, 'player-6:history')
#     (0.0, 0, 0.15385682880878448, 'player-6:state-active')
#     (-0.0, 0.0, -0.38072454929351807, 'player-6:stack')
#     (0.0, 0.0, 2.3096518516540527, 'player-5:history')
#     (0.0, 0, 0.07114457339048386, 'player-5:state-fold')
#     (0.0, 0.0, 2.2322287559509277, 'player-4:history')
#     (0.0, 0, 0.2913406491279602, 'player-4:state-fold')
#     (0.0, 0.0, 2.2680790424346924, 'player-3:history')
#     (0.0, 0, 0.23607796430587769, 'player-3:state-active')
#     (-0.0, 0.0, -0.5603376626968384, 'player-3:stack')
#     (0.0, 0.0, 2.1039273738861084, 'player-2:history')
#     (-0.0, 0, -0.029804321005940437, 'player-2:state-active')
#     (-0.0, 0.0, -0.09575264155864716, 'player-2:stack')
#     (0.0, 0.0, 2.0015361309051514, 'player-1:history')
#     (-0.0, 0, -0.01897541619837284, 'player-1:state-active')
#     (-0.0, 0.0, -0.21940648555755615, 'player-1:stack')
#     (0.0, 0.0, 2.134503126144409, 'player-0:history')
#     (-0.0, 0, -0.21569909155368805, 'player-0:state-fold')
#     (0.0, 0, 0.5574126243591309, 'street-river')
#     (0.0, 0, 0.7263288497924805, 'street-turn')
#     (0.0, 0, 0.5284073948860168, 'street-flop')
#     (0.0, 0, 3.3597800731658936, 'btn distance=9')
#     (0.0, 0, 3.3063313961029053, 'btn distance=8')
#     (0.0, 0, 3.296417713165283, 'btn distance=7')
#     (0.0, 0, 3.0474212169647217, 'btn distance=6')
#     (0.0, 0, 3.1960201263427734, 'btn distance=4')
#     (0.0, 0, 3.3553316593170166, 'btn distance=3')
#     (0.0, 0, 3.3526527881622314, 'btn distance=2')
#     (0.0, 0, 3.1485042572021484, 'btn distance=1')
#     (0.0, 0, 3.3223490715026855, 'btn distance=0')
#     (0.0, 0, 0.09741748869419098, 'round level 27')
#     (0.0, 0, 0.07910311967134476, 'round level 26')
#     (-0.0, 0, -0.059776660054922104, 'round level 25')
#     (-0.0, 0, -0.08622538298368454, 'round level 24')
#     (-0.0, 0, -0.251736581325531, 'round level 23')
#     (0.0, 0, 0.10754083842039108, 'round level 22')
#     (0.0, 0, 0.1417292058467865, 'round level 21')
#     (-0.0, 0, -0.0754241794347763, 'round level 20')
#     (0.0, 0, 0.2072998434305191, 'round level 19')
#     (-0.0, 0, -0.08121882379055023, 'round level 18')
#     (0.0, 0, 0.12156017124652863, 'round level 17')
#     (0.0, 0, 0.1160498857498169, 'round level 16')
#     (-0.0, 0, -0.08847133815288544, 'round level 15')
#     (0.0, 0, 0.04204520210623741, 'round level 14')
#     (-0.0, 0, -0.16658198833465576, 'round level 13')
#     (-0.0, 0, -0.21181248128414154, 'round level 12')
#     (0.0, 0, 0.13953788578510284, 'round level 11')
#     (-0.0, 0, -0.04653386026620865, 'round level 10')
#     (-0.0, 0, -0.24382942914962769, 'round level 9')
#     (-0.0, 0, -0.11428096145391464, 'round level 8')
#     (-0.0, 0, -0.20654737949371338, 'round level 7')
#     (0.0, 0, 0.18043582141399384, 'round level 6')
#     (-0.0, 0, -0.01020144671201706, 'round level 5')
#     (-0.0, 0, -0.13242115080356598, 'round level 4')
#     (0.0, 0, 0.20534852147102356, 'round level 3')
#     (0.0, 0, 0.005193918477743864, 'round level 1')
#
# linear combination for triple_raise :
#     (2.911156415939331, 1, 2.911156415939331, 'btn distance=5')
#     (-1.9720299243927002, 1, -1.9720299243927002, 'round level 2')
#     (-1.909784, 0, 0, 'bias')
#     (-1.7248280048370361, 1, -1.7248280048370361, 'player-0:state-active')
#     (1.0718460083007812, 0.6666666666666666, 1.6077690124511719, 'player-9:history')
#     (0.84957398340106, 0.60125, 1.4130128622055054, 'player-0:stack')
#     (0.624571402867635, 0.3333333333333333, 1.8737142086029053, 'player-8:history')
#     (0.518446147441864, 1, 0.518446147441864, 'street-preflop')
#     (-0.36458832025527954, 1, -0.36458832025527954, 'player-7:state-fold')
#     (0.18471992015838623, 1, 0.18471992015838623, 'player-1:state-fold')
#     (0.1692361831665039, 1, 0.1692361831665039, 'player-3:state-fold')
#     (0.12791864573955536, 1, 0.12791864573955536, 'player-9:state-active')
#     (0.09124860167503358, 0.55, 0.16590654850006104, 'cards')
#     (-0.06654716283082962, 1, -0.06654716283082962, 'player-5:state-active')
#     (0.05870455503463745, 1, 0.05870455503463745, 'player-4:state-active')
#     (0.054962389171123505, 1, 0.054962389171123505, 'player-6:state-fold')
#     (-0.053477797329425814, 0.09975, -0.5361182689666748, 'player-5:stack')
#     (-0.03881293535232544, 1, -0.03881293535232544, 'player-8:state-active')
#     (0.03628944978117943, 1, 0.03628944978117943, 'player-2:state-fold')
#     (-0.036053954407572746, 0.09925, -0.3632640242576599, 'player-8:stack')
#     (-0.03138427436351776, 0.1, -0.3138427436351776, 'player-4:stack')
#     (-0.022382164925336838, 0.099, -0.2260824739933014, 'player-9:stack')
#     (0.00014375948533415796, 0.00075, 0.19167931377887726, 'pot')
#     (0.0, 0, 0.07081695646047592, 'player-9:state-fold')
#     (-0.0, 0, -0.1046701967716217, 'player-8:state-fold')
#     (0.0, 0.0, 1.7641040086746216, 'player-7:history')
#     (-0.0, 0, -0.46799078583717346, 'player-7:state-active')
#     (-0.0, 0.0, -0.4693409502506256, 'player-7:stack')
#     (0.0, 0.0, 1.8613260984420776, 'player-6:history')
#     (0.0, 0, 0.003263970138505101, 'player-6:state-active')
#     (-0.0, 0.0, -0.3571288585662842, 'player-6:stack')
#     (0.0, 0.0, 1.9707051515579224, 'player-5:history')
#     (-0.0, 0, -0.0387587696313858, 'player-5:state-fold')
#     (0.0, 0.0, 1.9687550067901611, 'player-4:history')
#     (0.0, 0, 0.13877908885478973, 'player-4:state-fold')
#     (0.0, 0.0, 2.0312254428863525, 'player-3:history')
#     (0.0, 0, 0.06000101566314697, 'player-3:state-active')
#     (-0.0, 0.0, -0.41102665662765503, 'player-3:stack')
#     (0.0, 0.0, 1.6113736629486084, 'player-2:history')
#     (-0.0, 0, -0.011507687158882618, 'player-2:state-active')
#     (-0.0, 0.0, -0.1549617052078247, 'player-2:stack')
#     (0.0, 0.0, 1.802942156791687, 'player-1:history')
#     (0.0, 0, 0.12441851943731308, 'player-1:state-active')
#     (-0.0, 0.0, -0.18506640195846558, 'player-1:stack')
#     (0.0, 0.0, 1.668687105178833, 'player-0:history')
#     (0.0, 0, 0.04075248911976814, 'player-0:state-fold')
#     (0.0, 0, 0.6322498917579651, 'street-river')
#     (0.0, 0, 0.7929822206497192, 'street-turn')
#     (0.0, 0, 0.6097040176391602, 'street-flop')
#     (0.0, 0, 2.932969093322754, 'btn distance=9')
#     (0.0, 0, 2.9253368377685547, 'btn distance=8')
#     (0.0, 0, 3.011202573776245, 'btn distance=7')
#     (0.0, 0, 2.777012586593628, 'btn distance=6')
#     (0.0, 0, 2.848299026489258, 'btn distance=4')
#     (0.0, 0, 2.864824056625366, 'btn distance=3')
#     (0.0, 0, 3.043997287750244, 'btn distance=2')
#     (0.0, 0, 2.8935697078704834, 'btn distance=1')
#     (0.0, 0, 2.9243359565734863, 'btn distance=0')
#     (0.0, 0, 0.008020950481295586, 'round level 27')
#     (-0.0, 0, -0.17888143658638, 'round level 26')
#     (-0.0, 0, -0.11052364110946655, 'round level 25')
#     (0.0, 0, 0.10888233035802841, 'round level 24')
#     (0.0, 0, 0.1608966886997223, 'round level 23')
#     (-0.0, 0, -0.2377060353755951, 'round level 22')
#     (0.0, 0, 0.21409714221954346, 'round level 21')
#     (-0.0, 0, -0.21496911346912384, 'round level 20')
#     (0.0, 0, 0.0673115998506546, 'round level 19')
#     (-0.0, 0, -0.1885412335395813, 'round level 18')
#     (0.0, 0, 0.2565755248069763, 'round level 17')
#     (-0.0, 0, -0.047796376049518585, 'round level 16')
#     (0.0, 0, 0.0011935263173654675, 'round level 15')
#     (-0.0, 0, -0.20940327644348145, 'round level 14')
#     (0.0, 0, 0.14690224826335907, 'round level 13')
#     (0.0, 0, 0.054154470562934875, 'round level 12')
#     (0.0, 0, 0.15597549080848694, 'round level 11')
#     (0.0, 0, 0.07684778422117233, 'round level 10')
#     (-0.0, 0, -0.04693513736128807, 'round level 9')
#     (0.0, 0, 0.21320003271102905, 'round level 8')
#     (-0.0, 0, -0.06822678446769714, 'round level 7')
#     (0.0, 0, 0.12110030651092529, 'round level 6')
#     (0.0, 0, 0.09163427352905273, 'round level 5')
#     (0.0, 0, 0.030093930661678314, 'round level 4')
#     (-0.0, 0, -0.005681139416992664, 'round level 3')
#     (0.0, 0, 0.10348723828792572, 'round level 1')
#
# linear combination for max_raise :
#     (1.8928141593933105, 1, 1.8928141593933105, 'btn distance=5')
#     (-1.3490060567855835, 1, -1.3490060567855835, 'player-0:state-active')
#     (1.2380304336547852, 0.6666666666666666, 1.8570456504821777, 'player-9:history')
#     (-1.1446064710617065, 1, -1.1446064710617065, 'round level 2')
#     (-1.1232594, 0, 0, 'bias')
#     (0.6375367641448975, 0.3333333333333333, 1.9126102924346924, 'player-8:history')
#     (0.3437798377871513, 0.60125, 0.5717751979827881, 'player-0:stack')
#     (0.29177629947662354, 1, 0.29177629947662354, 'player-3:state-fold')
#     (0.2610180079936981, 1, 0.2610180079936981, 'street-preflop')
#     (0.24954034686088564, 0.55, 0.4537097215652466, 'cards')
#     (-0.19954265654087067, 1, -0.19954265654087067, 'player-8:state-active')
#     (-0.15849505364894867, 1, -0.15849505364894867, 'player-7:state-fold')
#     (-0.15554408177733423, 0.09975, -1.559339165687561, 'player-5:stack')
#     (-0.15312464237213136, 0.1, -1.5312464237213135, 'player-4:stack')
#     (0.1449057161808014, 1, 0.1449057161808014, 'player-9:state-active')
#     (-0.1367397391796112, 0.09925, -1.377730369567871, 'player-8:stack')
#     (-0.10940398299694062, 0.099, -1.1050907373428345, 'player-9:stack')
#     (0.0888524055480957, 1, 0.0888524055480957, 'player-6:state-fold')
#     (-0.08752410858869553, 1, -0.08752410858869553, 'player-1:state-fold')
#     (-0.07218189537525177, 1, -0.07218189537525177, 'player-2:state-fold')
#     (-0.01595880836248398, 1, -0.01595880836248398, 'player-4:state-active')
#     (-0.0010247888276353478, 1, -0.0010247888276353478, 'player-5:state-active')
#     (-0.00042894235253334044, 0.00075, -0.5719231367111206, 'pot')
#     (0.0, 0, 0.16054750978946686, 'player-9:state-fold')
#     (-0.0, 0, -0.21090620756149292, 'player-8:state-fold')
#     (0.0, 0.0, 1.9551143646240234, 'player-7:history')
#     (-0.0, 0, -0.21485579013824463, 'player-7:state-active')
#     (-0.0, 0.0, -1.3569964170455933, 'player-7:stack')
#     (0.0, 0.0, 2.1128106117248535, 'player-6:history')
#     (0.0, 0, 0.049003951251506805, 'player-6:state-active')
#     (-0.0, 0.0, -1.4147696495056152, 'player-6:stack')
#     (0.0, 0.0, 2.0091841220855713, 'player-5:history')
#     (0.0, 0, 0.048960186541080475, 'player-5:state-fold')
#     (0.0, 0.0, 1.9253836870193481, 'player-4:history')
#     (0.0, 0, 0.005241335369646549, 'player-4:state-fold')
#     (0.0, 0.0, 1.9096097946166992, 'player-3:history')
#     (0.0, 0, 0.28351616859436035, 'player-3:state-active')
#     (-0.0, 0.0, -1.366030216217041, 'player-3:stack')
#     (0.0, 0.0, 1.9809449911117554, 'player-2:history')
#     (-0.0, 0, -0.0018702379893511534, 'player-2:state-active')
#     (-0.0, 0.0, -1.2207783460617065, 'player-2:stack')
#     (0.0, 0.0, 1.9770967960357666, 'player-1:history')
#     (-0.0, 0, -0.11390052735805511, 'player-1:state-active')
#     (-0.0, 0.0, -1.1952316761016846, 'player-1:stack')
#     (0.0, 0.0, 2.359785556793213, 'player-0:history')
#     (0.0, 0, 0.07609657943248749, 'player-0:state-fold')
#     (0.0, 0, 0.3033589720726013, 'street-river')
#     (0.0, 0, 0.2428460568189621, 'street-turn')
#     (0.0, 0, 0.13293105363845825, 'street-flop')
#     (0.0, 0, 1.9139002561569214, 'btn distance=9')
#     (0.0, 0, 1.9561764001846313, 'btn distance=8')
#     (0.0, 0, 2.0012102127075195, 'btn distance=7')
#     (0.0, 0, 1.9072638750076294, 'btn distance=6')
#     (0.0, 0, 1.8904449939727783, 'btn distance=4')
#     (0.0, 0, 1.8775173425674438, 'btn distance=3')
#     (0.0, 0, 1.9946576356887817, 'btn distance=2')
#     (0.0, 0, 1.9409385919570923, 'btn distance=1')
#     (0.0, 0, 1.9573183059692383, 'btn distance=0')
#     (0.0, 0, 0.11246933043003082, 'round level 27')
#     (0.0, 0, 0.23121540248394012, 'round level 26')
#     (-0.0, 0, -0.1518223136663437, 'round level 25')
#     (0.0, 0, 0.143166646361351, 'round level 24')
#     (-0.0, 0, -0.11743029952049255, 'round level 23')
#     (0.0, 0, 0.11338414996862411, 'round level 22')
#     (0.0, 0, 0.17218057811260223, 'round level 21')
#     (-0.0, 0, -0.15079127252101898, 'round level 20')
#     (-0.0, 0, -0.027193639427423477, 'round level 19')
#     (-0.0, 0, -0.21092025935649872, 'round level 18')
#     (-0.0, 0, -0.06381283700466156, 'round level 17')
#     (-0.0, 0, -0.2114313393831253, 'round level 16')
#     (-0.0, 0, -0.13992951810359955, 'round level 15')
#     (-0.0, 0, -0.06705165654420853, 'round level 14')
#     (0.0, 0, 0.22516068816184998, 'round level 13')
#     (0.0, 0, 0.05737944692373276, 'round level 12')
#     (0.0, 0, 0.07443779706954956, 'round level 11')
#     (-0.0, 0, -0.11053375899791718, 'round level 10')
#     (-0.0, 0, -0.2071506381034851, 'round level 9')
#     (-0.0, 0, -0.0842650830745697, 'round level 8')
#     (0.0, 0, 0.004014415666460991, 'round level 7')
#     (0.0, 0, 0.14635255932807922, 'round level 6')
#     (0.0, 0, 0.08912111073732376, 'round level 5')
#     (-0.0, 0, -0.12405151128768921, 'round level 4')
#     (-0.0, 0, -0.1515631377696991, 'round level 3')
#     (-0.0, 0, -0.17977669835090637, 'round level 1')

# %% [markdown]
# ###  TRIPLE_RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 9925
#   - raise: [19800, 60125]
# -- hole card --
#   - ['ST', 'DA']
# -- round state --
#   - dealer btn : cpu6
#   - street : preflop
#   - community card : []
#   - pot : main = 10000, side = [{'amount': 0, 'eligibles': ['uuid-8']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : allin, stack : 0
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 0
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10075
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9875 <= SB
#     - 6 : agent (uuid-0) => state : participating, stack : 60075 <= BB, CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 0
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 0
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9875, 'paid': 9925, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 9925, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 59400 (triple_raise) ] at round 3
#   => [('fold', 0.6033049821853638), ('call', 0.5295572876930237), ('min_raise', 0.6464195251464844), ('double_raise', 0.5063982009887695), ('triple_raise', 0.852798342704773), ('max_raise', 0.7966012954711914)]
# ** weights and features in detail **
# bias : [-0.48353687 -0.24881023 -1.78213286 -2.03190184 -1.90978396 -1.12325943]
#
# linear combination for fold :
#     (1.1977404356002808, 1, 1.1977404356002808, 'btn distance=2')
#     (1.1060934960842133, 0.9925, 1.1144518852233887, 'player-4:history')
#     (-0.5504411458969116, 1, -0.5504411458969116, 'round level 2')
#     (-0.48353687, 0, 0, 'bias')
#     (0.36082316417992116, 0.60075, 0.6006211638450623, 'player-0:stack')
#     (0.3290203809738159, 1, 0.3290203809738159, 'player-9:state-fold')
#     (-0.3082176148891449, 1, -0.3082176148891449, 'player-0:state-active')
#     (-0.1634488984644413, 0.09975, -1.6385854482650757, 'player-5:stack')
#     (-0.1569201172888279, 0.09875, -1.5890644788742065, 'player-9:stack')
#     (-0.12795261144638062, 0.1, -1.2795261144638062, 'pot')
#     (-0.12702024379372598, 0.10075, -1.2607468366622925, 'player-8:stack')
#     (-0.1091219112277031, 1, -0.1091219112277031, 'player-1:state-fold')
#     (-0.08074988424777985, 1, -0.08074988424777985, 'player-8:state-fold')
#     (-0.07917696982622147, 1, -0.07917696982622147, 'player-5:state-fold')
#     (-0.07800084352493286, 1, -0.07800084352493286, 'player-7:state-fold')
#     (-0.055877212435007095, 1, -0.055877212435007095, 'player-3:state-fold')
#     (-0.03264254486560822, 0.677, -0.04821646213531494, 'cards')
#     (-0.02842237614095211, 1, -0.02842237614095211, 'player-6:state-fold')
#     (-0.025638192892074585, 1, -0.025638192892074585, 'player-4:state-active')
#     (0.020596105605363846, 1, 0.020596105605363846, 'player-2:state-fold')
#     (-0.0091206980869174, 1, -0.0091206980869174, 'street-preflop')
#     (0.005319377779960633, 0.005, 1.0638755559921265, 'player-0:history')
#     (0.0, 0.0, 1.0686349868774414, 'player-9:history')
#     (0.0, 0, 0.29554614424705505, 'player-9:state-active')
#     (0.0, 0.0, 1.246514081954956, 'player-8:history')
#     (-0.0, 0, -0.03097626380622387, 'player-8:state-active')
#     (0.0, 0.0, 0.9841926693916321, 'player-7:history')
#     (-0.0, 0, -0.11354628950357437, 'player-7:state-active')
#     (-0.0, 0.0, -1.4459601640701294, 'player-7:stack')
#     (0.0, 0.0, 1.0321004390716553, 'player-6:history')
#     (-0.0, 0, -0.017108134925365448, 'player-6:state-active')
#     (-0.0, 0.0, -1.3039556741714478, 'player-6:stack')
#     (0.0, 0.0, 1.0770936012268066, 'player-5:history')
#     (-0.0, 0, -0.0735795870423317, 'player-5:state-active')
#     (0.0, 0, 0.05473426729440689, 'player-4:state-fold')
#     (-0.0, 0.0, -1.3378541469573975, 'player-4:stack')
#     (0.0, 0.0, 1.0370513200759888, 'player-3:history')
#     (-0.0, 0, -0.04053684324026108, 'player-3:state-active')
#     (-0.0, 0.0, -1.3304693698883057, 'player-3:stack')
#     (0.0, 0.0, 1.1363270282745361, 'player-2:history')
#     (-0.0, 0, -0.09789295494556427, 'player-2:state-active')
#     (-0.0, 0.0, -1.190693974494934, 'player-2:stack')
#     (0.0, 0.0, 1.0625455379486084, 'player-1:history')
#     (-0.0, 0, -0.185475692152977, 'player-1:state-active')
#     (-0.0, 0.0, -1.3984960317611694, 'player-1:stack')
#     (-0.0, 0, -0.13157254457473755, 'player-0:state-fold')
#     (-0.0, 0, -0.058312587440013885, 'street-river')
#     (0.0, 0, 0.021209783852100372, 'street-turn')
#     (-0.0, 0, -0.0214112289249897, 'street-flop')
#     (0.0, 0, 1.325065016746521, 'btn distance=9')
#     (0.0, 0, 1.4019274711608887, 'btn distance=8')
#     (0.0, 0, 1.4151992797851562, 'btn distance=7')
#     (0.0, 0, 1.213940143585205, 'btn distance=6')
#     (0.0, 0, 1.2666823863983154, 'btn distance=5')
#     (0.0, 0, 1.2417488098144531, 'btn distance=4')
#     (0.0, 0, 1.2136343717575073, 'btn distance=3')
#     (0.0, 0, 1.3430707454681396, 'btn distance=1')
#     (0.0, 0, 1.3178373575210571, 'btn distance=0')
#     (-0.0, 0, -0.21972104907035828, 'round level 27')
#     (-0.0, 0, -0.16887789964675903, 'round level 26')
#     (-0.0, 0, -0.056195277720689774, 'round level 25')
#     (-0.0, 0, -0.0224585123360157, 'round level 24')
#     (0.0, 0, 0.21297651529312134, 'round level 23')
#     (0.0, 0, 0.11313529312610626, 'round level 22')
#     (0.0, 0, 0.21001067757606506, 'round level 21')
#     (-0.0, 0, -0.14171156287193298, 'round level 20')
#     (0.0, 0, 0.13536091148853302, 'round level 19')
#     (0.0, 0, 0.22831162810325623, 'round level 18')
#     (-0.0, 0, -0.22597871720790863, 'round level 17')
#     (0.0, 0, 0.07464097440242767, 'round level 16')
#     (0.0, 0, 0.17132167518138885, 'round level 15')
#     (-0.0, 0, -0.05531512200832367, 'round level 14')
#     (0.0, 0, 0.21716493368148804, 'round level 13')
#     (-0.0, 0, -0.09104923903942108, 'round level 12')
#     (-0.0, 0, -0.25070151686668396, 'round level 11')
#     (-0.0, 0, -0.08039606362581253, 'round level 10')
#     (-0.0, 0, -0.05438179895281792, 'round level 9')
#     (0.0, 0, 0.17122764885425568, 'round level 8')
#     (-0.0, 0, -0.18322034180164337, 'round level 7')
#     (0.0, 0, 0.04171256348490715, 'round level 6')
#     (-0.0, 0, -0.2578655481338501, 'round level 5')
#     (-0.0, 0, -0.17897067964076996, 'round level 4')
#     (-0.0, 0, -0.2215890735387802, 'round level 3')
#     (-0.0, 0, -0.01656218059360981, 'round level 1')
#
# linear combination for call :
#     (0.6305377455949783, 0.677, 0.9313703775405884, 'cards')
#     (-0.25926724076271057, 1, -0.25926724076271057, 'street-preflop')
#     (-0.24881023, 0, 0, 'bias')
#     (0.22729603005945684, 0.60075, 0.3783537745475769, 'player-0:stack')
#     (0.18884600698947906, 1, 0.18884600698947906, 'player-8:state-fold')
#     (0.18202362954616547, 1, 0.18202362954616547, 'player-7:state-fold')
#     (-0.17895637831091882, 0.09975, -1.7940489053726196, 'player-5:stack')
#     (-0.1712895780801773, 1, -0.1712895780801773, 'player-1:state-fold')
#     (0.16336408257484436, 1, 0.16336408257484436, 'btn distance=2')
#     (0.1583608090877533, 1, 0.1583608090877533, 'player-9:state-fold')
#     (-0.15308310985565188, 0.1, -1.5308310985565186, 'pot')
#     (-0.14931125912070276, 0.10075, -1.4819976091384888, 'player-8:stack')
#     (-0.14212984502315523, 0.09875, -1.4392895698547363, 'player-9:stack')
#     (0.139820396900177, 1, 0.139820396900177, 'player-4:state-active')
#     (0.12559907138347626, 1, 0.12559907138347626, 'player-3:state-fold')
#     (0.1117132306098938, 0.9925, 0.11255741119384766, 'player-4:history')
#     (0.10749158263206482, 1, 0.10749158263206482, 'player-6:state-fold')
#     (-0.10114721953868866, 1, -0.10114721953868866, 'round level 2')
#     (-0.0666251853108406, 1, -0.0666251853108406, 'player-0:state-active')
#     (-0.021531887352466583, 1, -0.021531887352466583, 'player-5:state-fold')
#     (-0.016709184274077415, 1, -0.016709184274077415, 'player-2:state-fold')
#     (0.0033658331632614134, 0.005, 0.6731666326522827, 'player-0:history')
#     (0.0, 0.0, 0.20488527417182922, 'player-9:history')
#     (0.0, 0, 0.14023910462856293, 'player-9:state-active')
#     (0.0, 0.0, 0.20101043581962585, 'player-8:history')
#     (0.0, 0, 0.17627842724323273, 'player-8:state-active')
#     (0.0, 0.0, 0.05594567209482193, 'player-7:history')
#     (0.0, 0, 0.15847960114479065, 'player-7:state-active')
#     (-0.0, 0.0, -1.4213441610336304, 'player-7:stack')
#     (0.0, 0.0, 0.019110267981886864, 'player-6:history')
#     (0.0, 0, 0.22829273343086243, 'player-6:state-active')
#     (-0.0, 0.0, -1.5038646459579468, 'player-6:stack')
#     (0.0, 0.0, 0.04617088660597801, 'player-5:history')
#     (0.0, 0, 0.03996642306447029, 'player-5:state-active')
#     (0.0, 0, 0.144008606672287, 'player-4:state-fold')
#     (-0.0, 0.0, -1.5567740201950073, 'player-4:stack')
#     (0.0, 0.0, 0.03554701432585716, 'player-3:history')
#     (0.0, 0, 0.15041644871234894, 'player-3:state-active')
#     (-0.0, 0.0, -1.7098089456558228, 'player-3:stack')
#     (0.0, 0.0, 0.0787128210067749, 'player-2:history')
#     (-0.0, 0, -0.0617591068148613, 'player-2:state-active')
#     (-0.0, 0.0, -1.5231077671051025, 'player-2:stack')
#     (0.0, 0.0, 0.035544831305742264, 'player-1:history')
#     (-0.0, 0, -0.24511785805225372, 'player-1:state-active')
#     (-0.0, 0.0, -1.591251254081726, 'player-1:stack')
#     (0.0, 0, 0.0506884902715683, 'player-0:state-fold')
#     (-0.0, 0, -0.5945714116096497, 'street-river')
#     (-0.0, 0, -0.42862606048583984, 'street-turn')
#     (-0.0, 0, -0.3372102975845337, 'street-flop')
#     (0.0, 0, 0.22869279980659485, 'btn distance=9')
#     (0.0, 0, 0.2711631953716278, 'btn distance=8')
#     (0.0, 0, 0.2218068391084671, 'btn distance=7')
#     (0.0, 0, 0.033042505383491516, 'btn distance=6')
#     (0.0, 0, 0.1621607095003128, 'btn distance=5')
#     (0.0, 0, 0.11350041627883911, 'btn distance=4')
#     (0.0, 0, 0.2085464596748352, 'btn distance=3')
#     (0.0, 0, 0.09508673846721649, 'btn distance=1')
#     (0.0, 0, 0.1494542807340622, 'btn distance=0')
#     (0.0, 0, 0.05240476503968239, 'round level 27')
#     (0.0, 0, 0.003269001841545105, 'round level 26')
#     (0.0, 0, 0.2429712414741516, 'round level 25')
#     (0.0, 0, 0.18841516971588135, 'round level 24')
#     (0.0, 0, 0.2595265209674835, 'round level 23')
#     (0.0, 0, 0.14526015520095825, 'round level 22')
#     (-0.0, 0, -0.05364101752638817, 'round level 21')
#     (-0.0, 0, -0.25889888405799866, 'round level 20')
#     (0.0, 0, 0.20514066517353058, 'round level 19')
#     (-0.0, 0, -0.15952783823013306, 'round level 18')
#     (-0.0, 0, -0.2368985414505005, 'round level 17')
#     (0.0, 0, 0.021499469876289368, 'round level 16')
#     (-0.0, 0, -0.15992547571659088, 'round level 15')
#     (0.0, 0, 0.13773998618125916, 'round level 14')
#     (0.0, 0, 0.03223136439919472, 'round level 13')
#     (0.0, 0, 0.1264357566833496, 'round level 12')
#     (-0.0, 0, -0.10693281143903732, 'round level 11')
#     (0.0, 0, 0.16666394472122192, 'round level 10')
#     (0.0, 0, 0.20799539983272552, 'round level 9')
#     (0.0, 0, 0.20435722172260284, 'round level 8')
#     (-0.0, 0, -0.012952451594173908, 'round level 7')
#     (0.0, 0, 0.16907642781734467, 'round level 6')
#     (0.0, 0, 0.05249634385108948, 'round level 5')
#     (-0.0, 0, -0.1286989152431488, 'round level 4')
#     (0.0, 0, 0.2346666008234024, 'round level 3')
#     (-0.0, 0, -0.18063881993293762, 'round level 1')
#
# linear combination for min_raise :
#     (3.2322170734405518, 1, 3.2322170734405518, 'btn distance=2')
#     (2.2426134073734283, 0.9925, 2.2595601081848145, 'player-4:history')
#     (-1.7821329, 0, 0, 'bias')
#     (-1.747273564338684, 1, -1.747273564338684, 'player-0:state-active')
#     (-1.5308681726455688, 1, -1.5308681726455688, 'round level 2')
#     (0.6205047775804996, 0.60075, 1.0328835248947144, 'player-0:stack')
#     (-0.36383065581321716, 1, -0.36383065581321716, 'player-8:state-fold')
#     (0.2779412865638733, 1, 0.2779412865638733, 'player-2:state-fold')
#     (-0.25521501898765564, 1, -0.25521501898765564, 'player-7:state-fold')
#     (0.23794801032543184, 0.677, 0.35147416591644287, 'cards')
#     (0.12282508611679077, 1, 0.12282508611679077, 'player-1:state-fold')
#     (-0.09889116883277893, 1, -0.09889116883277893, 'player-5:state-fold')
#     (-0.07977888849377633, 0.09975, -0.7997883558273315, 'player-5:stack')
#     (-0.07216199557483197, 0.10075, -0.716248095035553, 'player-8:stack')
#     (-0.06719355091452599, 0.09875, -0.6804410219192505, 'player-9:stack')
#     (-0.05308401584625244, 1, -0.05308401584625244, 'player-4:state-active')
#     (-0.04763592779636383, 0.1, -0.4763592779636383, 'pot')
#     (-0.03639017418026924, 1, -0.03639017418026924, 'player-6:state-fold')
#     (0.027887772768735886, 1, 0.027887772768735886, 'street-preflop')
#     (0.016544779762625694, 1, 0.016544779762625694, 'player-3:state-fold')
#     (0.012278640270233154, 0.005, 2.455728054046631, 'player-0:history')
#     (-0.009885293431580067, 1, -0.009885293431580067, 'player-9:state-fold')
#     (0.0, 0.0, 2.008721113204956, 'player-9:history')
#     (-0.0, 0, -0.012242932803928852, 'player-9:state-active')
#     (0.0, 0.0, 2.189229726791382, 'player-8:history')
#     (-0.0, 0, -0.3169701397418976, 'player-8:state-active')
#     (0.0, 0.0, 2.205390691757202, 'player-7:history')
#     (-0.0, 0, -0.3422319293022156, 'player-7:state-active')
#     (-0.0, 0.0, -0.7898432016372681, 'player-7:stack')
#     (0.0, 0.0, 2.125567674636841, 'player-6:history')
#     (-0.0, 0, -0.11795627325773239, 'player-6:state-active')
#     (-0.0, 0.0, -0.6421878933906555, 'player-6:stack')
#     (0.0, 0.0, 2.167220115661621, 'player-5:history')
#     (-0.0, 0, -0.07264379411935806, 'player-5:state-active')
#     (-0.0, 0, -0.061681050807237625, 'player-4:state-fold')
#     (-0.0, 0.0, -0.5077544450759888, 'player-4:stack')
#     (0.0, 0.0, 2.1437301635742188, 'player-3:history')
#     (-0.0, 0, -0.14947839081287384, 'player-3:state-active')
#     (-0.0, 0.0, -0.8002043962478638, 'player-3:stack')
#     (0.0, 0.0, 2.061837911605835, 'player-2:history')
#     (0.0, 0, 0.18198390305042267, 'player-2:state-active')
#     (-0.0, 0.0, -0.7118945121765137, 'player-2:stack')
#     (0.0, 0.0, 2.265964984893799, 'player-1:history')
#     (0.0, 0, 0.1469043791294098, 'player-1:state-active')
#     (-0.0, 0.0, -0.6444417238235474, 'player-1:stack')
#     (0.0, 0, 0.07190699130296707, 'player-0:state-fold')
#     (-0.0, 0, -0.050476666539907455, 'street-river')
#     (0.0, 0, 0.11330259591341019, 'street-turn')
#     (0.0, 0, 0.15895408391952515, 'street-flop')
#     (0.0, 0, 3.1835520267486572, 'btn distance=9')
#     (0.0, 0, 3.2953693866729736, 'btn distance=8')
#     (0.0, 0, 3.2720251083374023, 'btn distance=7')
#     (0.0, 0, 3.1817588806152344, 'btn distance=6')
#     (0.0, 0, 3.2197015285491943, 'btn distance=5')
#     (0.0, 0, 3.1331751346588135, 'btn distance=4')
#     (0.0, 0, 3.217989683151245, 'btn distance=3')
#     (0.0, 0, 3.2189176082611084, 'btn distance=1')
#     (0.0, 0, 3.2374656200408936, 'btn distance=0')
#     (0.0, 0, 0.25229722261428833, 'round level 27')
#     (0.0, 0, 0.22346574068069458, 'round level 26')
#     (-0.0, 0, -0.024008633568882942, 'round level 25')
#     (-0.0, 0, -0.16542094945907593, 'round level 24')
#     (-0.0, 0, -0.09414144605398178, 'round level 23')
#     (0.0, 0, 0.1686987429857254, 'round level 22')
#     (0.0, 0, 0.17665095627307892, 'round level 21')
#     (-0.0, 0, -0.18036343157291412, 'round level 20')
#     (0.0, 0, 0.22174479067325592, 'round level 19')
#     (-0.0, 0, -0.15750350058078766, 'round level 18')
#     (0.0, 0, 0.1287153661251068, 'round level 17')
#     (0.0, 0, 0.05211281776428223, 'round level 16')
#     (-0.0, 0, -0.07095134258270264, 'round level 15')
#     (-0.0, 0, -0.16400404274463654, 'round level 14')
#     (-0.0, 0, -0.19781464338302612, 'round level 13')
#     (0.0, 0, 0.00890976283699274, 'round level 12')
#     (-0.0, 0, -0.10713862627744675, 'round level 11')
#     (-0.0, 0, -0.09665833413600922, 'round level 10')
#     (-0.0, 0, -0.03662043809890747, 'round level 9')
#     (0.0, 0, 0.2009717971086502, 'round level 8')
#     (-0.0, 0, -0.08257033675909042, 'round level 7')
#     (0.0, 0, 0.1913730353116989, 'round level 6')
#     (0.0, 0, 0.17685194313526154, 'round level 5')
#     (-0.0, 0, -0.04237651824951172, 'round level 4')
#     (0.0, 0, 0.18527163565158844, 'round level 3')
#     (0.0, 0, 0.05876008793711662, 'round level 1')
#
# linear combination for double_raise :
#     (3.3526527881622314, 1, 3.3526527881622314, 'btn distance=2')
#     (-2.21936297416687, 1, -2.21936297416687, 'round level 2')
#     (2.215487040281296, 0.9925, 2.2322287559509277, 'player-4:history')
#     (-2.0319018, 0, 0, 'bias')
#     (-1.7936919927597046, 1, -1.7936919927597046, 'player-0:state-active')
#     (0.8466808567643166, 0.60075, 1.4093730449676514, 'player-0:stack')
#     (-0.48104143142700195, 1, -0.48104143142700195, 'player-7:state-fold')
#     (0.4399876594543457, 1, 0.4399876594543457, 'street-preflop')
#     (-0.34994077682495117, 1, -0.34994077682495117, 'player-9:state-fold')
#     (-0.274885892868042, 1, -0.274885892868042, 'player-8:state-fold')
#     (0.22699761390686035, 1, 0.22699761390686035, 'player-4:state-active')
#     (0.21921734511852264, 1, 0.21921734511852264, 'player-3:state-fold')
#     (0.19748517870903015, 1, 0.19748517870903015, 'player-6:state-fold')
#     (0.14893836492300033, 0.677, 0.2199975848197937, 'cards')
#     (0.07114457339048386, 1, 0.07114457339048386, 'player-5:state-fold')
#     (-0.0681053575873375, 0.09975, -0.68276047706604, 'player-5:stack')
#     (0.03557249531149864, 1, 0.03557249531149864, 'player-1:state-fold')
#     (-0.031210722498595717, 0.10075, -0.30978384613990784, 'player-8:stack')
#     (-0.022926204856485128, 0.09875, -0.23216409981250763, 'player-9:stack')
#     (0.0203699991106987, 0.1, 0.203699991106987, 'pot')
#     (0.010672515630722046, 0.005, 2.134503126144409, 'player-0:history')
#     (-0.005740904249250889, 1, -0.005740904249250889, 'player-2:state-fold')
#     (0.0, 0.0, 2.079336166381836, 'player-9:history')
#     (-0.0, 0, -0.18838202953338623, 'player-9:state-active')
#     (0.0, 0.0, 2.1437299251556396, 'player-8:history')
#     (-0.0, 0, -0.19770953059196472, 'player-8:state-active')
#     (0.0, 0.0, 2.1001970767974854, 'player-7:history')
#     (-0.0, 0, -0.5111181139945984, 'player-7:state-active')
#     (-0.0, 0.0, -0.5497721433639526, 'player-7:stack')
#     (0.0, 0.0, 2.235436201095581, 'player-6:history')
#     (0.0, 0, 0.15385682880878448, 'player-6:state-active')
#     (-0.0, 0.0, -0.38072454929351807, 'player-6:stack')
#     (0.0, 0.0, 2.3096518516540527, 'player-5:history')
#     (-0.0, 0, -0.020117923617362976, 'player-5:state-active')
#     (0.0, 0, 0.2913406491279602, 'player-4:state-fold')
#     (-0.0, 0.0, -0.46351441740989685, 'player-4:stack')
#     (0.0, 0.0, 2.2680790424346924, 'player-3:history')
#     (0.0, 0, 0.23607796430587769, 'player-3:state-active')
#     (-0.0, 0.0, -0.5603376626968384, 'player-3:stack')
#     (0.0, 0.0, 2.1039273738861084, 'player-2:history')
#     (-0.0, 0, -0.029804321005940437, 'player-2:state-active')
#     (-0.0, 0.0, -0.09575264155864716, 'player-2:stack')
#     (0.0, 0.0, 2.0015361309051514, 'player-1:history')
#     (-0.0, 0, -0.01897541619837284, 'player-1:state-active')
#     (-0.0, 0.0, -0.21940648555755615, 'player-1:stack')
#     (-0.0, 0, -0.21569909155368805, 'player-0:state-fold')
#     (0.0, 0, 0.5574126243591309, 'street-river')
#     (0.0, 0, 0.7263288497924805, 'street-turn')
#     (0.0, 0, 0.5284073948860168, 'street-flop')
#     (0.0, 0, 3.3597800731658936, 'btn distance=9')
#     (0.0, 0, 3.3063313961029053, 'btn distance=8')
#     (0.0, 0, 3.296417713165283, 'btn distance=7')
#     (0.0, 0, 3.0474212169647217, 'btn distance=6')
#     (0.0, 0, 3.279503583908081, 'btn distance=5')
#     (0.0, 0, 3.1960201263427734, 'btn distance=4')
#     (0.0, 0, 3.3553316593170166, 'btn distance=3')
#     (0.0, 0, 3.1485042572021484, 'btn distance=1')
#     (0.0, 0, 3.3223490715026855, 'btn distance=0')
#     (0.0, 0, 0.09741748869419098, 'round level 27')
#     (0.0, 0, 0.07910311967134476, 'round level 26')
#     (-0.0, 0, -0.059776660054922104, 'round level 25')
#     (-0.0, 0, -0.08622538298368454, 'round level 24')
#     (-0.0, 0, -0.251736581325531, 'round level 23')
#     (0.0, 0, 0.10754083842039108, 'round level 22')
#     (0.0, 0, 0.1417292058467865, 'round level 21')
#     (-0.0, 0, -0.0754241794347763, 'round level 20')
#     (0.0, 0, 0.2072998434305191, 'round level 19')
#     (-0.0, 0, -0.08121882379055023, 'round level 18')
#     (0.0, 0, 0.12156017124652863, 'round level 17')
#     (0.0, 0, 0.1160498857498169, 'round level 16')
#     (-0.0, 0, -0.08847133815288544, 'round level 15')
#     (0.0, 0, 0.04204520210623741, 'round level 14')
#     (-0.0, 0, -0.16658198833465576, 'round level 13')
#     (-0.0, 0, -0.21181248128414154, 'round level 12')
#     (0.0, 0, 0.13953788578510284, 'round level 11')
#     (-0.0, 0, -0.04653386026620865, 'round level 10')
#     (-0.0, 0, -0.24382942914962769, 'round level 9')
#     (-0.0, 0, -0.11428096145391464, 'round level 8')
#     (-0.0, 0, -0.20654737949371338, 'round level 7')
#     (0.0, 0, 0.18043582141399384, 'round level 6')
#     (-0.0, 0, -0.01020144671201706, 'round level 5')
#     (-0.0, 0, -0.13242115080356598, 'round level 4')
#     (0.0, 0, 0.20534852147102356, 'round level 3')
#     (0.0, 0, 0.005193918477743864, 'round level 1')
#
# linear combination for triple_raise :
#     (3.043997287750244, 1, 3.043997287750244, 'btn distance=2')
#     (-1.9720299243927002, 1, -1.9720299243927002, 'round level 2')
#     (1.953989344239235, 0.9925, 1.9687550067901611, 'player-4:history')
#     (-1.909784, 0, 0, 'bias')
#     (-1.7248280048370361, 1, -1.7248280048370361, 'player-0:state-active')
#     (0.8488674769699573, 0.60075, 1.4130128622055054, 'player-0:stack')
#     (0.518446147441864, 1, 0.518446147441864, 'street-preflop')
#     (-0.36458832025527954, 1, -0.36458832025527954, 'player-7:state-fold')
#     (0.18471992015838623, 1, 0.18471992015838623, 'player-1:state-fold')
#     (0.1692361831665039, 1, 0.1692361831665039, 'player-3:state-fold')
#     (0.11231873333454133, 0.677, 0.16590654850006104, 'cards')
#     (-0.1046701967716217, 1, -0.1046701967716217, 'player-8:state-fold')
#     (0.07081695646047592, 1, 0.07081695646047592, 'player-9:state-fold')
#     (0.05870455503463745, 1, 0.05870455503463745, 'player-4:state-active')
#     (0.054962389171123505, 1, 0.054962389171123505, 'player-6:state-fold')
#     (-0.053477797329425814, 0.09975, -0.5361182689666748, 'player-5:stack')
#     (-0.0387587696313858, 1, -0.0387587696313858, 'player-5:state-fold')
#     (-0.03659885044395924, 0.10075, -0.3632640242576599, 'player-8:stack')
#     (0.03628944978117943, 1, 0.03628944978117943, 'player-2:state-fold')
#     (-0.022325644306838515, 0.09875, -0.2260824739933014, 'player-9:stack')
#     (0.019167931377887727, 0.1, 0.19167931377887726, 'pot')
#     (0.008343435525894165, 0.005, 1.668687105178833, 'player-0:history')
#     (0.0, 0.0, 1.6077690124511719, 'player-9:history')
#     (0.0, 0, 0.12791864573955536, 'player-9:state-active')
#     (0.0, 0.0, 1.8737142086029053, 'player-8:history')
#     (-0.0, 0, -0.03881293535232544, 'player-8:state-active')
#     (0.0, 0.0, 1.7641040086746216, 'player-7:history')
#     (-0.0, 0, -0.46799078583717346, 'player-7:state-active')
#     (-0.0, 0.0, -0.4693409502506256, 'player-7:stack')
#     (0.0, 0.0, 1.8613260984420776, 'player-6:history')
#     (0.0, 0, 0.003263970138505101, 'player-6:state-active')
#     (-0.0, 0.0, -0.3571288585662842, 'player-6:stack')
#     (0.0, 0.0, 1.9707051515579224, 'player-5:history')
#     (-0.0, 0, -0.06654716283082962, 'player-5:state-active')
#     (0.0, 0, 0.13877908885478973, 'player-4:state-fold')
#     (-0.0, 0.0, -0.3138427436351776, 'player-4:stack')
#     (0.0, 0.0, 2.0312254428863525, 'player-3:history')
#     (0.0, 0, 0.06000101566314697, 'player-3:state-active')
#     (-0.0, 0.0, -0.41102665662765503, 'player-3:stack')
#     (0.0, 0.0, 1.6113736629486084, 'player-2:history')
#     (-0.0, 0, -0.011507687158882618, 'player-2:state-active')
#     (-0.0, 0.0, -0.1549617052078247, 'player-2:stack')
#     (0.0, 0.0, 1.802942156791687, 'player-1:history')
#     (0.0, 0, 0.12441851943731308, 'player-1:state-active')
#     (-0.0, 0.0, -0.18506640195846558, 'player-1:stack')
#     (0.0, 0, 0.04075248911976814, 'player-0:state-fold')
#     (0.0, 0, 0.6322498917579651, 'street-river')
#     (0.0, 0, 0.7929822206497192, 'street-turn')
#     (0.0, 0, 0.6097040176391602, 'street-flop')
#     (0.0, 0, 2.932969093322754, 'btn distance=9')
#     (0.0, 0, 2.9253368377685547, 'btn distance=8')
#     (0.0, 0, 3.011202573776245, 'btn distance=7')
#     (0.0, 0, 2.777012586593628, 'btn distance=6')
#     (0.0, 0, 2.911156415939331, 'btn distance=5')
#     (0.0, 0, 2.848299026489258, 'btn distance=4')
#     (0.0, 0, 2.864824056625366, 'btn distance=3')
#     (0.0, 0, 2.8935697078704834, 'btn distance=1')
#     (0.0, 0, 2.9243359565734863, 'btn distance=0')
#     (0.0, 0, 0.008020950481295586, 'round level 27')
#     (-0.0, 0, -0.17888143658638, 'round level 26')
#     (-0.0, 0, -0.11052364110946655, 'round level 25')
#     (0.0, 0, 0.10888233035802841, 'round level 24')
#     (0.0, 0, 0.1608966886997223, 'round level 23')
#     (-0.0, 0, -0.2377060353755951, 'round level 22')
#     (0.0, 0, 0.21409714221954346, 'round level 21')
#     (-0.0, 0, -0.21496911346912384, 'round level 20')
#     (0.0, 0, 0.0673115998506546, 'round level 19')
#     (-0.0, 0, -0.1885412335395813, 'round level 18')
#     (0.0, 0, 0.2565755248069763, 'round level 17')
#     (-0.0, 0, -0.047796376049518585, 'round level 16')
#     (0.0, 0, 0.0011935263173654675, 'round level 15')
#     (-0.0, 0, -0.20940327644348145, 'round level 14')
#     (0.0, 0, 0.14690224826335907, 'round level 13')
#     (0.0, 0, 0.054154470562934875, 'round level 12')
#     (0.0, 0, 0.15597549080848694, 'round level 11')
#     (0.0, 0, 0.07684778422117233, 'round level 10')
#     (-0.0, 0, -0.04693513736128807, 'round level 9')
#     (0.0, 0, 0.21320003271102905, 'round level 8')
#     (-0.0, 0, -0.06822678446769714, 'round level 7')
#     (0.0, 0, 0.12110030651092529, 'round level 6')
#     (0.0, 0, 0.09163427352905273, 'round level 5')
#     (0.0, 0, 0.030093930661678314, 'round level 4')
#     (-0.0, 0, -0.005681139416992664, 'round level 3')
#     (0.0, 0, 0.10348723828792572, 'round level 1')
#
# linear combination for max_raise :
#     (1.9946576356887817, 1, 1.9946576356887817, 'btn distance=2')
#     (1.9109433093667032, 0.9925, 1.9253836870193481, 'player-4:history')
#     (-1.3490060567855835, 1, -1.3490060567855835, 'player-0:state-active')
#     (-1.1446064710617065, 1, -1.1446064710617065, 'round level 2')
#     (-1.1232594, 0, 0, 'bias')
#     (0.3434939501881599, 0.60075, 0.5717751979827881, 'player-0:stack')
#     (0.307161481499672, 0.677, 0.4537097215652466, 'cards')
#     (0.29177629947662354, 1, 0.29177629947662354, 'player-3:state-fold')
#     (0.2610180079936981, 1, 0.2610180079936981, 'street-preflop')
#     (-0.21090620756149292, 1, -0.21090620756149292, 'player-8:state-fold')
#     (0.16054750978946686, 1, 0.16054750978946686, 'player-9:state-fold')
#     (-0.15849505364894867, 1, -0.15849505364894867, 'player-7:state-fold')
#     (-0.15554408177733423, 0.09975, -1.559339165687561, 'player-5:stack')
#     (-0.13880633473396303, 0.10075, -1.377730369567871, 'player-8:stack')
#     (-0.1091277103126049, 0.09875, -1.1050907373428345, 'player-9:stack')
#     (0.0888524055480957, 1, 0.0888524055480957, 'player-6:state-fold')
#     (-0.08752410858869553, 1, -0.08752410858869553, 'player-1:state-fold')
#     (-0.07218189537525177, 1, -0.07218189537525177, 'player-2:state-fold')
#     (-0.05719231367111206, 0.1, -0.5719231367111206, 'pot')
#     (0.048960186541080475, 1, 0.048960186541080475, 'player-5:state-fold')
#     (-0.01595880836248398, 1, -0.01595880836248398, 'player-4:state-active')
#     (0.011798927783966065, 0.005, 2.359785556793213, 'player-0:history')
#     (0.0, 0.0, 1.8570456504821777, 'player-9:history')
#     (0.0, 0, 0.1449057161808014, 'player-9:state-active')
#     (0.0, 0.0, 1.9126102924346924, 'player-8:history')
#     (-0.0, 0, -0.19954265654087067, 'player-8:state-active')
#     (0.0, 0.0, 1.9551143646240234, 'player-7:history')
#     (-0.0, 0, -0.21485579013824463, 'player-7:state-active')
#     (-0.0, 0.0, -1.3569964170455933, 'player-7:stack')
#     (0.0, 0.0, 2.1128106117248535, 'player-6:history')
#     (0.0, 0, 0.049003951251506805, 'player-6:state-active')
#     (-0.0, 0.0, -1.4147696495056152, 'player-6:stack')
#     (0.0, 0.0, 2.0091841220855713, 'player-5:history')
#     (-0.0, 0, -0.0010247888276353478, 'player-5:state-active')
#     (0.0, 0, 0.005241335369646549, 'player-4:state-fold')
#     (-0.0, 0.0, -1.5312464237213135, 'player-4:stack')
#     (0.0, 0.0, 1.9096097946166992, 'player-3:history')
#     (0.0, 0, 0.28351616859436035, 'player-3:state-active')
#     (-0.0, 0.0, -1.366030216217041, 'player-3:stack')
#     (0.0, 0.0, 1.9809449911117554, 'player-2:history')
#     (-0.0, 0, -0.0018702379893511534, 'player-2:state-active')
#     (-0.0, 0.0, -1.2207783460617065, 'player-2:stack')
#     (0.0, 0.0, 1.9770967960357666, 'player-1:history')
#     (-0.0, 0, -0.11390052735805511, 'player-1:state-active')
#     (-0.0, 0.0, -1.1952316761016846, 'player-1:stack')
#     (0.0, 0, 0.07609657943248749, 'player-0:state-fold')
#     (0.0, 0, 0.3033589720726013, 'street-river')
#     (0.0, 0, 0.2428460568189621, 'street-turn')
#     (0.0, 0, 0.13293105363845825, 'street-flop')
#     (0.0, 0, 1.9139002561569214, 'btn distance=9')
#     (0.0, 0, 1.9561764001846313, 'btn distance=8')
#     (0.0, 0, 2.0012102127075195, 'btn distance=7')
#     (0.0, 0, 1.9072638750076294, 'btn distance=6')
#     (0.0, 0, 1.8928141593933105, 'btn distance=5')
#     (0.0, 0, 1.8904449939727783, 'btn distance=4')
#     (0.0, 0, 1.8775173425674438, 'btn distance=3')
#     (0.0, 0, 1.9409385919570923, 'btn distance=1')
#     (0.0, 0, 1.9573183059692383, 'btn distance=0')
#     (0.0, 0, 0.11246933043003082, 'round level 27')
#     (0.0, 0, 0.23121540248394012, 'round level 26')
#     (-0.0, 0, -0.1518223136663437, 'round level 25')
#     (0.0, 0, 0.143166646361351, 'round level 24')
#     (-0.0, 0, -0.11743029952049255, 'round level 23')
#     (0.0, 0, 0.11338414996862411, 'round level 22')
#     (0.0, 0, 0.17218057811260223, 'round level 21')
#     (-0.0, 0, -0.15079127252101898, 'round level 20')
#     (-0.0, 0, -0.027193639427423477, 'round level 19')
#     (-0.0, 0, -0.21092025935649872, 'round level 18')
#     (-0.0, 0, -0.06381283700466156, 'round level 17')
#     (-0.0, 0, -0.2114313393831253, 'round level 16')
#     (-0.0, 0, -0.13992951810359955, 'round level 15')
#     (-0.0, 0, -0.06705165654420853, 'round level 14')
#     (0.0, 0, 0.22516068816184998, 'round level 13')
#     (0.0, 0, 0.05737944692373276, 'round level 12')
#     (0.0, 0, 0.07443779706954956, 'round level 11')
#     (-0.0, 0, -0.11053375899791718, 'round level 10')
#     (-0.0, 0, -0.2071506381034851, 'round level 9')
#     (-0.0, 0, -0.0842650830745697, 'round level 8')
#     (0.0, 0, 0.004014415666460991, 'round level 7')
#     (0.0, 0, 0.14635255932807922, 'round level 6')
#     (0.0, 0, 0.08912111073732376, 'round level 5')
#     (-0.0, 0, -0.12405151128768921, 'round level 4')
#     (-0.0, 0, -0.1515631377696991, 'round level 3')
#     (-0.0, 0, -0.17977669835090637, 'round level 1')
