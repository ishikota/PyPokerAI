# %% [markdown]
# # Shuffle Position Test
# - training length : 1000000 iteration
# - epsilon annealing : range=[0.99,0.1], length=800000
# - **shuffle seat position at every episode**
#
# #### feature expression
# 1. Scaled Scalar Feature
# 2. Binary Onehot Feature
#
# #### algorithms
# 1. MonteCarlo
# 2. Sarsa
# 3. QLearning
#
# ## Conclusion
# **=> "shuffle position" brings good effect for training**

# %% [markdown]
# ## Learning by Scaled Scalar Feature

# %% [markdown]
# ## MonteCarlo
# training time : 39578s
#
# ### Initial Value Transition
# <img src="./resource/shuffle_position/scaled_scalar/montecarlo/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/scaled_scalar/montecarlo/1_round_3000_match_subplot_0103_09_14_23.png"/> | <img src="./resource/shuffle_position/scaled_scalar/montecarlo/1_round_3000_match_histgram_0103_09_14_23.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : 0.0051
#     - CALL : -0.527
#     - MIN_RAISE : -0.1233
#     - DOUBLE_RAISE : 0.3132
#     - TRIPLE_RAISE : 0.205
#     - MAX_RAISE : 0.1249
# cards
#     - FOLD : 0.002
#     - CALL : 1.142
#     - MIN_RAISE : 0.0406
#     - DOUBLE_RAISE : 0.0554
#     - TRIPLE_RAISE : 0.0973
#     - MAX_RAISE : -0.085
# pot
#     - FOLD : 0.0034
#     - CALL : -2.2629
#     - MIN_RAISE : -3.0166
#     - DOUBLE_RAISE : -3.5545
#     - TRIPLE_RAISE : -3.351
#     - MAX_RAISE : 1.15

# %% [markdown]
# ## Sarsa
# training time : 40912s
#
# ### Initial Value Transition
# <img src="./resource/shuffle_position/scaled_scalar/sarsa/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/scaled_scalar/sarsa/1_round_3000_match_subplot_0103_09_20_43.png"/> | <img src="./resource/shuffle_position/scaled_scalar/sarsa/1_round_3000_match_histgram_0103_09_20_43.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : 0.0018
#     - CALL : -0.6398
#     - MIN_RAISE : 0.2678
#     - DOUBLE_RAISE : 0.4986
#     - TRIPLE_RAISE : 0.3595
#     - MAX_RAISE : -0.0678
# cards
#     - FOLD : -0.0049
#     - CALL : 0.9107
#     - MIN_RAISE : -0.0266
#     - DOUBLE_RAISE : -0.0087
#     - TRIPLE_RAISE : -0.0092
#     - MAX_RAISE : 0.0009
# pot
#     - FOLD : 0.048
#     - CALL : -2.6959
#     - MIN_RAISE : -2.0358
#     - DOUBLE_RAISE : -4.4042
#     - TRIPLE_RAISE : -2.8125
#     - MAX_RAISE : 1.3219

# %% [markdown]
# ## QLearning
# training time : 204470s
#
# ### Initial Value Transition
# <img src="./resource/shuffle_position/scaled_scalar/q_learning/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/scaled_scalar/q_learning/1_round_3000_match_subplot_0103_10_45_45.png"/> | <img src="./resource/shuffle_position/scaled_scalar/q_learning/1_round_3000_match_histgram_0103_10_45_45.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : -0.0053
#     - CALL : -0.0399
#     - MIN_RAISE : 0.0167
#     - DOUBLE_RAISE : 0.0042
#     - TRIPLE_RAISE : 0.0473
#     - MAX_RAISE : 0.2511
# cards
#     - FOLD : 0.0023
#     - CALL : 0.0718
#     - MIN_RAISE : 0.0074
#     - DOUBLE_RAISE : 0.0143
#     - TRIPLE_RAISE : 0.0261
#     - MAX_RAISE : 1.3621
# pot
#     - FOLD : 0.058
#     - CALL : 1.3134
#     - MIN_RAISE : 1.2354
#     - DOUBLE_RAISE : -0.9173
#     - TRIPLE_RAISE : -1.0417
#     - MAX_RAISE : -0.5617

# %% [markdown]
# ### Round-Robin by all algorithms using scaled scalar features
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/scaled_scalar/1_round_3000_match_subplot_0103_11_26_41.png"/> | <img src="./resource/shuffle_position/scaled_scalar/1_round_3000_match_histgram_0103_11_26_41.png" />|

# %% [markdown]
# ### Round-Robin by all algorithms using scaled scalar features to see shuffle_position effect
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/scaled_scalar/1_round_3000_match_subplot_0103_11_55_48.png"/> | <img src="./resource/shuffle_position/scaled_scalar/1_round_3000_match_histgram_0103_11_55_48.png" />|

# %% [markdown]
# ## Learning by Binary Onehot Feature

# %% [markdown]
# ## MonteCarlo
# training time : 96917s
#
# ### Initial Value Transition
# <img src="./resource/shuffle_position/binary_onehot/montecarlo/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/binary_onehot/montecarlo/1_round_3000_match_subplot_0103_11_05_49.png"/> | <img src="./resource/shuffle_position/binary_onehot/montecarlo/1_round_3000_match_histgram_0103_11_05_49.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : [0.0312, 0.0647, 0.0677, 0.0185]
#     - CALL : [0.0806, -0.3074, -0.3958, -0.375]
#     - MIN_RAISE : [0.1687, 0.2213, -0.0667, -0.0805]
#     - DOUBLE_RAISE : [-0.2554, -0.1859, -0.4744, -0.4287]
#     - TRIPLE_RAISE : [-0.2432, -0.185, -0.3785, -0.2137]
#     - MAX_RAISE : [0.3973, 0.3363, 0.299, 0.1887]
# cards
#     - FOLD : [-0.0045, 0.0003, -0.0026, -0.0091, 0.0, -0.0031, 0.0015, -0.0193, -0.0006, -0.0062]
#     - CALL : [-0.0436, -0.0579, -0.015, -0.0343, 0.0247, 0.0296, 0.0151, 0.0501, 0.0797, 0.1171]
#     - MIN_RAISE : [-0.0338, -0.0231, -0.0726, 0.0066, 0.0238, -0.0352, -0.0021, 0.0074, -0.0094, 0.0064]
#     - DOUBLE_RAISE : [0.0514, 0.0037, -0.0192, 0.0112, -0.0068, -0.0069, -0.0109, -0.0305, 0.0576, 0.062]
#     - TRIPLE_RAISE : [-0.0232, -0.0605, -0.0152, -0.0133, -0.0257, 0.0245, 0.0286, 0.0324, -0.0004, 0.1088]
#     - MAX_RAISE : [0.041, -0.0017, 0.0502, -0.0193, 0.0384, 0.0228, -0.0192, 0.0213, 0.0259, 0.1153]
# pot
#     - FOLD : [-0.0076, 0.0143, -0.0024, -0.0059, -0.0284, 0.0097, 0.0038, -0.0108, -0.0845, -0.0893]
#     - CALL : [0.0437, -0.0334, -0.0014, -0.0309, -0.0204, -0.0708, -0.1229, -0.3294, -0.4594, -0.5716]
#     - MIN_RAISE : [-0.0325, 0.0145, -0.0085, -0.0017, -0.013, -0.1003, -0.0621, -0.2261, -0.5651, -0.7611]
#     - DOUBLE_RAISE : [0.0075, -0.0125, 0.0511, -0.0304, -0.0681, -0.0875, -0.0989, -0.1338, -0.6664, -0.4707]
#     - TRIPLE_RAISE : [-0.0582, -0.0265, -0.0437, -0.0176, -0.0687, -0.1655, -0.0567, -0.3345, -0.9168, -0.6947]
#     - MAX_RAISE : [-0.006, 0.0122, 0.0172, 0.012, 0.0098, -0.0804, -0.0865, 0.0297, -0.076, -0.206]

# %% [markdown]
# ## Sarsa
# training time : 63799s
#
# ### Initial Value Transition
# <img src="./resource/shuffle_position/binary_onehot/sarsa/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/binary_onehot/sarsa/1_round_3000_match_subplot_0103_11_10_26.png"/> | <img src="./resource/shuffle_position/binary_onehot/sarsa/1_round_3000_match_histgram_0103_11_10_26.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : [0.0125, 0.0058, 0.0658, 0.1048]
#     - CALL : [-0.0805, -0.2291, -0.3567, -0.274]
#     - MIN_RAISE : [0.0953, -0.0075, -0.0103, -0.2748]
#     - DOUBLE_RAISE : [0.2321, 0.0516, -0.0302, -0.1046]
#     - TRIPLE_RAISE : [0.172, -0.0862, 0.0593, -0.0239]
#     - MAX_RAISE : [0.0713, 0.0748, -0.0513, -0.1852]
# cards
#     - FOLD : [0.0053, -0.0164, -0.001, -0.0139, 0.0069, -0.0031, -0.0046, -0.0055, 0.0118, -0.014]
#     - CALL : [0.0188, -0.0132, 0.0196, -0.0231, 0.0081, 0.0279, 0.0443, 0.0812, 0.186, 0.4149]
#     - MIN_RAISE : [-0.0311, -0.0219, -0.0494, 0.0149, 0.0269, -0.0117, 0.0039, -0.0267, 0.0821, 0.2044]
#     - DOUBLE_RAISE : [0.0422, 0.0031, 0.0039, 0.0308, 0.0512, 0.0076, -0.0424, 0.0055, -0.0595, 0.2148]
#     - TRIPLE_RAISE : [0.0184, -0.0026, 0.0673, 0.0156, 0.0152, -0.0815, -0.0457, 0.0063, -0.1119, 0.0914]
#     - MAX_RAISE : [0.0157, -0.0108, 0.0854, 0.0571, -0.0924, -0.0269, 0.0746, 0.0757, -0.0276, 0.123]
# pot
#     - FOLD : [-0.0052, -0.0111, -0.0003, -0.0073, -0.0027, 0.0132, 0.0093, 0.0046, 0.0307, 0.0672]
#     - CALL : [0.0251, -0.0128, -0.047, -0.024, -0.0287, -0.0765, -0.2089, -0.2789, -0.6533, -0.3102]
#     - MIN_RAISE : [-0.0711, 0.0475, -0.0311, -0.057, 0.0315, -0.0304, -0.032, 0.1171, -0.1653, -0.0226]
#     - DOUBLE_RAISE : [-0.148, -0.0817, -0.0357, -0.1133, -0.1891, -0.298, -0.9286, -0.1636, 0.0087, 0.0307]
#     - TRIPLE_RAISE : [-0.0043, 0.0826, -0.1223, -0.0671, 0.076, -0.0669, 0.0547, -0.2213, -0.1835, -0.0525]
#     - MAX_RAISE : [-0.0566, -0.0162, 0.0461, 0.0978, 0.0335, -0.0074, 0.1314, 0.1643, 0.1156, -0.081]

# %% [markdown]
# ## QLearning
# training time : 63799s
#
# ### Initial Value Transition
# <img src="./resource/shuffle_position/binary_onehot/q_learning/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/binary_onehot/q_learning/1_round_3000_match_subplot_0103_10_49_31.png"/> | <img src="./resource/shuffle_position/binary_onehot/q_learning/1_round_3000_match_histgram_0103_10_49_31.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : [-0.0456, -0.0426, 0.0408, 0.006]
#     - CALL : [1.1171, 0.8989, 0.852, 0.6504]
#     - MIN_RAISE : [0.7655, 0.9805, 0.7955, 0.9402]
#     - DOUBLE_RAISE : [-0.4032, -0.0642, -0.5321, -0.274]
#     - TRIPLE_RAISE : [-0.3021, -0.0231, -0.2725, -0.2529]
#     - MAX_RAISE : [0.0074, 0.2534, 0.4187, 0.6581]
# cards
#     - FOLD : [-0.0047, -0.0018, 0.0083, 0.0081, 0.0023, 0.0008, 0.0016, 0.0177, -0.0186, -0.0019]
#     - CALL : [0.011, -0.0139, -0.0088, -0.0313, -0.0241, 0.0128, 0.0184, -0.0201, 0.0529, 0.0864]
#     - MIN_RAISE : [-0.0421, -0.0412, 0.0146, 0.0012, 0.0044, -0.0208, 0.0159, -0.0416, -0.0619, 0.0777]
#     - DOUBLE_RAISE : [0.052, -0.0167, 0.0245, 0.0103, -0.0314, 0.0873, 0.0301, -0.0221, 0.0834, 0.1222]
#     - TRIPLE_RAISE : [0.0611, 0.0633, -0.0048, 0.0596, 0.0672, 0.0053, 0.0416, -0.0116, 0.0835, -0.002]
#     - MAX_RAISE : [-0.0282, -0.036, 0.0353, -0.0394, 0.0141, 0.0622, 0.087, 0.1368, 0.4941, 0.5012]
# pot
#     - FOLD : [0.0084, -0.0035, 0.0053, 0.0052, 0.0092, 0.0201, 0.0127, 0.0026, 0.0012, -0.0201]
#     - CALL : [-0.0054, -0.0211, -0.0103, -0.0397, -0.0182, -0.0593, -0.0413, -0.066, -0.1226, -0.1824]
#     - MIN_RAISE : [0.01, -0.0076, 0.0085, -0.0183, 0.0137, 0.0148, 0.0228, -0.0093, -0.1116, -0.224]
#     - DOUBLE_RAISE : [-0.0063, 0.0228, -0.0193, -0.0396, 0.054, -0.0096, -0.0781, 0.1013, -0.211, -0.2321]
#     - TRIPLE_RAISE : [-0.0026, 0.0065, -0.0237, 0.0336, 0.0377, -0.058, -0.0237, -0.1612, -0.0172, -0.2558]
#     - MAX_RAISE : [-0.0397, -0.033, 0.0243, -0.0615, 0.081, 0.0409, 0.0364, -0.0104, -0.0964, -0.0292]

# %% [markdown]
# ### Round-Robin by all algorithms using binary onehot features
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/binary_onehot/1_round_3000_match_subplot_0103_11_34_47.png"/> | <img src="./resource/shuffle_position/binary_onehot/1_round_3000_match_histgram_0103_11_34_47.png" />|

# %% [markdown]
# ### Round-Robin by all algorithms using binary onehot features to see shuffle_position effect
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/binary_onehot/1_round_3000_match_subplot_0103_11_59_01.png"/> | <img src="./resource/shuffle_position/binary_onehot/1_round_3000_match_histgram_0103_11_59_01.png" />|

# %% [markdown]
# ## Round-Robin by all algorithms and all feature expressions
# **with rondom players**
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/1_round_3000_match_subplot_0103_12_17_49.png"/> | <img src="./resource/shuffle_position/1_round_3000_match_histgram_0103_12_17_49.png" />|
#
# **with fold players**
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/shuffle_position/1_round_3000_match_subplot_0103_12_18_38.png"/> | <img src="./resource/shuffle_position/1_round_3000_match_histgram_0103_12_18_38.png" />|
