# %% [markdown]
# # 実験3 いろんなfeature表現を試す
# ## scalar feature (not scaled)

# %% [markdown]
# ## 2-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 100万
# - 5万iteration毎に敵のvalue_functionを過去のweightsのいずれかにセットし直しながらself-play
# - 計算時間 : 49986s => 13.9h
#     - aws g2.x.large上でやった

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# <img src="./resource/2round_scalar_feature_montecarlo_trash_1224_02_45_12/initial_value_transition.png" />

# %% [markdown]
# <img src="./resource/2round_scalar_feature_montecarlo_trash_1224_02_45_12/initial_value_transition_slimmed.png" />

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# <img src="./resource/2round_scalar_feature_montecarlo_trash_1224_02_45_12/2_round_3000_match_subplot_1225_17_15_19.png" />

# %% [markdown]
# <img src="./resource/2round_scalar_feature_montecarlo_trash_1224_02_45_12/2_round_3000_match_histgram_1225_17_15_19.png" />

# %% [markdown]
# # Weight analysis

# %% [markdown]
# ### 100万iteration後

# %% [raw]
# ****************************************
# After 1000000 iteration
# ****************************************
# round count
#   FOLD : -0.7727
#   CALL : -0.4958
#   MIN_RAISE : -1.0512
#   DOUBLE_RAISE : 4.2635
#   TRIPLE_RAISE : 0.3185
#   MAX_RAISE : 3.6085
# dealer button
#   FOLD : 1.4432
#   CALL : 0.1895
#   MIN_RAISE : -1.2885
#   DOUBLE_RAISE : 6.1123
#   TRIPLE_RAISE : 0.705
#   MAX_RAISE : 2.7942
# street
#   FOLD : 0.8842
#   CALL : -1.5226
#   MIN_RAISE : 0.4614
#   DOUBLE_RAISE : -1.2929
#   TRIPLE_RAISE : -0.2912
#   MAX_RAISE : -3.6813
# cards
#   FOLD : -0.3311
#   CALL : -0.5737
#   MIN_RAISE : -0.5743
#   DOUBLE_RAISE : 3.6493
#   TRIPLE_RAISE : 0.221
#   MAX_RAISE : 3.2901
# pot
#   FOLD : -0.1459
#   CALL : -0.2529
#   MIN_RAISE : -1.6093
#   DOUBLE_RAISE : -1.1358
#   TRIPLE_RAISE : -0.6582
#   MAX_RAISE : -0.7414
# seats
#     player 0
#       stack : {'DOUBLE_RAISE': 0.2861, 'TRIPLE_RAISE': 0.0303, 'MAX_RAISE': -0.0341, 'FOLD': 0.0102, 'MIN_RAISE': 0.0691, 'CALL': 0.0197}
#       state : {'DOUBLE_RAISE': 4.0231, 'TRIPLE_RAISE': 0.6968, 'MAX_RAISE': 3.216, 'FOLD': -0.2696, 'MIN_RAISE': -0.6444, 'CALL': -0.4209}
#       history(paid sum) : {'DOUBLE_RAISE': -1.64, 'TRIPLE_RAISE': 0.8395, 'MAX_RAISE': -3.8444, 'FOLD': 0.205, 'MIN_RAISE': -1.1015, 'CALL': 0.2821}
#     player 1
#       stack : {'DOUBLE_RAISE': 0.2465, 'TRIPLE_RAISE': -1.7844, 'MAX_RAISE': -0.5837, 'FOLD': 0.0368, 'MIN_RAISE': -0.0204, 'CALL': 0.0371}
#       state : {'DOUBLE_RAISE': -0.5329, 'TRIPLE_RAISE': 0.0994, 'MAX_RAISE': 3.3815, 'FOLD': 5.6889, 'MIN_RAISE': 3.4483, 'CALL': 2.7548}
#       history(paid sum) : {'DOUBLE_RAISE': -1.1145, 'TRIPLE_RAISE': -0.1665, 'MAX_RAISE': 0.9951, 'FOLD': 0.2063, 'MIN_RAISE': 1.0185, 'CALL': 0.2699}
#     player 2
#       stack : {'DOUBLE_RAISE': -2.019, 'TRIPLE_RAISE': -1.2742, 'MAX_RAISE': 0.0782, 'FOLD': -0.1032, 'MIN_RAISE': -0.4257, 'CALL': -0.1085}
#       state : {'DOUBLE_RAISE': -2.578, 'TRIPLE_RAISE': 0.6377, 'MAX_RAISE': 1.1196, 'FOLD': 4.8225, 'MIN_RAISE': -0.792, 'CALL': 0.6556}
#       history(paid sum) : {'DOUBLE_RAISE': -3.6001, 'TRIPLE_RAISE': -1.4599, 'MAX_RAISE': 0.1411, 'FOLD': 0.002, 'MIN_RAISE': 1.0683, 'CALL': 0.1305}
#     player 3
#       stack : {'DOUBLE_RAISE': 0.508, 'TRIPLE_RAISE': 0.3402, 'MAX_RAISE': -0.2518, 'FOLD': -0.0734, 'MIN_RAISE': 0.3732, 'CALL': -0.1073}
#       state : {'DOUBLE_RAISE': -3.8193, 'TRIPLE_RAISE': -3.2635, 'MAX_RAISE': 5.5599, 'FOLD': 1.5206, 'MIN_RAISE': 2.3267, 'CALL': 0.9752}
#       history(paid sum) : {'DOUBLE_RAISE': -8.6165, 'TRIPLE_RAISE': -1.0725, 'MAX_RAISE': -0.0741, 'FOLD': 0.0958, 'MIN_RAISE': -0.6734, 'CALL': 0.1511}
#     player 4
#       stack : {'DOUBLE_RAISE': -4.5746, 'TRIPLE_RAISE': 0.107, 'MAX_RAISE': -0.0001, 'FOLD': 0.0503, 'MIN_RAISE': -0.0266, 'CALL': 0.0086}
#       state : {'DOUBLE_RAISE': -3.0017, 'TRIPLE_RAISE': 3.3197, 'MAX_RAISE': 1.2304, 'FOLD': 5.2646, 'MIN_RAISE': 2.6065, 'CALL': 1.2572}
#       history(paid sum) : {'DOUBLE_RAISE': -5.2243, 'TRIPLE_RAISE': -0.7515, 'MAX_RAISE': -1.0142, 'FOLD': 0.176, 'MIN_RAISE': -1.1845, 'CALL': 0.2876}
#     player 5
#       stack : {'DOUBLE_RAISE': 0.1808, 'TRIPLE_RAISE': 0.127, 'MAX_RAISE': -0.0333, 'FOLD': 0.0401, 'MIN_RAISE': -0.0708, 'CALL': 0.0273}
#       state : {'DOUBLE_RAISE': -1.9744, 'TRIPLE_RAISE': -1.038, 'MAX_RAISE': -0.2291, 'FOLD': 1.3259, 'MIN_RAISE': -1.4478, 'CALL': 0.3023}
#       history(paid sum) : {'DOUBLE_RAISE': -9.5227, 'TRIPLE_RAISE': -0.3227, 'MAX_RAISE': -6.4745, 'FOLD': 0.1779, 'MIN_RAISE': -0.9116, 'CALL': 0.2879}
#     player 6
#       stack : {'DOUBLE_RAISE': 0.1958, 'TRIPLE_RAISE': 0.1486, 'MAX_RAISE': -0.0345, 'FOLD': 0.0408, 'MIN_RAISE': -0.0735, 'CALL': 0.0277}
#       state : {'DOUBLE_RAISE': -3.1726, 'TRIPLE_RAISE': 0.4966, 'MAX_RAISE': 6.6605, 'FOLD': 1.8478, 'MIN_RAISE': 0.0213, 'CALL': 1.1825}
#       history(paid sum) : {'DOUBLE_RAISE': -11.6113, 'TRIPLE_RAISE': -0.4699, 'MAX_RAISE': 3.4472, 'FOLD': 0.1298, 'MIN_RAISE': 2.2199, 'CALL': 0.2701}
#     player 7
#       stack : {'DOUBLE_RAISE': 0.3895, 'TRIPLE_RAISE': -0.0482, 'MAX_RAISE': 0.0737, 'FOLD': 0.0055, 'MIN_RAISE': -0.1226, 'CALL': 0.0352}
#       state : {'DOUBLE_RAISE': -1.7464, 'TRIPLE_RAISE': 1.394, 'MAX_RAISE': -0.2531, 'FOLD': 0.4987, 'MIN_RAISE': -0.5531, 'CALL': -1.1517}
#       history(paid sum) : {'DOUBLE_RAISE': 9.4258, 'TRIPLE_RAISE': -2.5306, 'MAX_RAISE': 2.1762, 'FOLD': 0.1289, 'MIN_RAISE': 3.1278, 'CALL': 0.2835}
#     player 8
#       stack : {'DOUBLE_RAISE': -0.2043, 'TRIPLE_RAISE': 0.2076, 'MAX_RAISE': 0.2414, 'FOLD': -0.0417, 'MIN_RAISE': 0.3767, 'CALL': 0.0022}
#       state : {'DOUBLE_RAISE': 5.9767, 'TRIPLE_RAISE': -2.8257, 'MAX_RAISE': 3.5283, 'FOLD': 5.8329, 'MIN_RAISE': 6.1042, 'CALL': 0.8573}
#       history(paid sum) : {'DOUBLE_RAISE': 0.8993, 'TRIPLE_RAISE': 1.1667, 'MAX_RAISE': 0.8501, 'FOLD': 0.1047, 'MIN_RAISE': 1.191, 'CALL': 0.2461}
#     player 9
#       stack : {'DOUBLE_RAISE': 0.211, 'TRIPLE_RAISE': 0.1382, 'MAX_RAISE': -0.0204, 'FOLD': 0.0278, 'MIN_RAISE': -0.0679, 'CALL': 0.0255}
#       state : {'DOUBLE_RAISE': -3.688, 'TRIPLE_RAISE': 0.1149, 'MAX_RAISE': 2.3698, 'FOLD': 4.8375, 'MIN_RAISE': 0.3745, 'CALL': -0.1574}
#       history(paid sum) : {'DOUBLE_RAISE': -6.9313, 'TRIPLE_RAISE': 1.4963, 'MAX_RAISE': -0.8597, 'FOLD': 0.1788, 'MIN_RAISE': 0.6877, 'CALL': 0.29}

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# - 100万iteration後の価値関数10人で対戦させる.
# - プレイの度に結果が変わる
# - stack, historyなど値が大きい要素が支配的になってしまっている.
# - 重みはstackなど大きい値に対しても,cardsなど小さい値に対しても同じくらいのscaleになってしまってる

# %% [markdown]
# ### MIN_RAISEに対してFOLD

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 150
#   - raise: [175, 10000]
# -- hole card --
#   - ['HJ', 'H3']
# -- round state --
#   - dealer btn : cpu5
#   - street : preflop
#   - community card : []
#   - pot : main = 525, side = []
#   - players information
#     - 0 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 1 : agent (uuid-0) => state : participating, stack : 9975 <= SB, CURRENT
#     - 2 : cpu9 (uuid-9) => state : participating, stack : 9950 <= BB
#     - 3 : cpu8 (uuid-8) => state : participating, stack : 9925
#     - 4 : cpu1 (uuid-1) => state : participating, stack : 9900
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9875
#     - 6 : cpu2 (uuid-2) => state : participating, stack : 9850
#     - 7 : cpu3 (uuid-3) => state : folded, stack : 10000
#     - 8 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 9 : cpu4 (uuid-4) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', -52.78112030029297), ('call', -316.4781799316406), ('min_raise', -968.5753784179688), ('double_raise', -51072.25390625), ('triple_raise', -20651.013671875), ('max_raise', -7097.38330078125)]
# ** weights and features in detail **
# features : [1, 1, 0, 0.637, 9975, 1, 25, 9950, 1, 50, 9925, 1, 75, 9900, 1, 100, 9875, 1, 125, 9850, 1, 150, 10000, 0, 0, 10000, 0, 0, 10000, 0, 0, 10000, 0, 0, 525]
# bias : [-0.5284971  -0.6841774  -0.82024276  3.91709399  0.47396657  3.37526679]
#
# linear combination for fold :
#     (-1023.9998891949654, 9925, -0.10317379236221313, 'player-2:stack')
#     (-726.5808373689651, 9900, -0.07339200377464294, 'player-3:stack')
#     (496.77664088085294, 9875, 0.050306495279073715, 'player-4:stack')
#     (-417.06956923007965, 10000, -0.041706956923007965, 'player-8:stack')
#     (407.7688604593277, 10000, 0.04077688604593277, 'player-6:stack')
#     (394.9797973036766, 9850, 0.04009947180747986, 'player-5:stack')
#     (365.8967237919569, 9950, 0.03677354007959366, 'player-1:stack')
#     (278.02713215351105, 10000, 0.027802713215351105, 'player-9:stack')
#     (101.28543020691723, 9975, 0.010153927840292454, 'player-0:stack')
#     (-76.61599963903427, 525, -0.14593523740768433, 'pot')
#     (54.61078602820635, 10000, 0.005461078602820635, 'player-7:stack')
#     (26.684638112783432, 150, 0.1778975874185562, 'player-5:history')
#     (22.002598270773888, 125, 0.1760207861661911, 'player-4:history')
#     (10.31469851732254, 50, 0.2062939703464508, 'player-1:history')
#     (9.5780611038208, 100, 0.09578061103820801, 'player-3:history')
#     (5.688854217529297, 1, 5.688854217529297, 'player-1:state')
#     (5.264644145965576, 1, 5.264644145965576, 'player-4:state')
#     (5.125118792057037, 25, 0.2050047516822815, 'player-0:history')
#     (4.822535037994385, 1, 4.822535037994385, 'player-2:state')
#     (1.52057683467865, 1, 1.52057683467865, 'player-3:state')
#     (1.4432274103164673, 1, 1.4432274103164673, 'btn distance')
#     (1.325937032699585, 1, 1.325937032699585, 'player-5:state')
#     (-0.7727053761482239, 1, -0.7727053761482239, 'round level')
#     (-0.5284971, 0, 0, 'bias')
#     (-0.26959481835365295, 1, -0.26959481835365295, 'player-0:state')
#     (-0.21093892106413842, 0.637, -0.3311443030834198, 'cards')
#     (0.15059459838084877, 75, 0.002007927978411317, 'player-2:history')
#
# linear combination for call :
#     (-1076.6057938337326, 9925, -0.10847413539886475, 'player-2:stack')
#     (-1062.0782800018787, 9900, -0.10728063434362411, 'player-3:stack')
#     (368.7622344121337, 9950, 0.037061531096696854, 'player-1:stack')
#     (352.4314612150192, 10000, 0.03524314612150192, 'player-7:stack')
#     (277.27145701646805, 10000, 0.027727145701646805, 'player-6:stack')
#     (269.1751439124346, 9850, 0.02732742577791214, 'player-5:stack')
#     (255.17601519823074, 10000, 0.025517601519823074, 'player-9:stack')
#     (196.15444564260542, 9975, 0.01966460607945919, 'player-0:stack')
#     (-132.78480023145676, 525, -0.2529234290122986, 'pot')
#     (84.95059760753065, 9875, 0.008602592162787914, 'player-4:stack')
#     (43.182648718357086, 150, 0.28788432478904724, 'player-5:history')
#     (35.94692423939705, 125, 0.2875753939151764, 'player-4:history')
#     (22.31938298791647, 10000, 0.002231938298791647, 'player-8:stack')
#     (15.114173293113708, 100, 0.15114173293113708, 'player-3:history')
#     (13.495750725269318, 50, 0.26991501450538635, 'player-1:history')
#     (9.788944199681282, 75, 0.13051925599575043, 'player-2:history')
#     (7.053185254335403, 25, 0.28212741017341614, 'player-0:history')
#     (2.754791736602783, 1, 2.754791736602783, 'player-1:state')
#     (1.2572400569915771, 1, 1.2572400569915771, 'player-4:state')
#     (0.9752382636070251, 1, 0.9752382636070251, 'player-3:state')
#     (-0.6841774, 0, 0, 'bias')
#     (0.6556318998336792, 1, 0.6556318998336792, 'player-2:state')
#     (-0.4957827031612396, 1, -0.4957827031612396, 'round level')
#     (-0.4208604693412781, 1, -0.4208604693412781, 'player-0:state')
#     (-0.3654257206320763, 0.637, -0.5736667513847351, 'cards')
#     (0.3022642731666565, 1, 0.3022642731666565, 'player-5:state')
#     (0.18949362635612488, 1, 0.18949362635612488, 'btn distance')
#
# linear combination for min_raise :
#     (-4224.731840193272, 9925, -0.4256656765937805, 'player-2:stack')
#     (3766.5173411369324, 10000, 0.37665173411369324, 'player-8:stack')
#     (3694.6664214134216, 9900, 0.37319862842559814, 'player-3:stack')
#     (-1226.0396033525467, 10000, -0.12260396033525467, 'player-7:stack')
#     (-844.8654860258102, 525, -1.6092675924301147, 'pot')
#     (-735.1056486368179, 10000, -0.0735105648636818, 'player-6:stack')
#     (-697.6267941296101, 9850, -0.07082505524158478, 'player-5:stack')
#     (689.3599737435579, 9975, 0.06910876929759979, 'player-0:stack')
#     (-678.8966059684753, 10000, -0.06788966059684753, 'player-9:stack')
#     (-262.68023741431534, 9875, -0.026600530371069908, 'player-4:stack')
#     (-202.503608353436, 9950, -0.02035212144255638, 'player-1:stack')
#     (-148.06820452213287, 125, -1.184545636177063, 'player-4:history')
#     (-136.74203753471375, 150, -0.9116135835647583, 'player-5:history')
#     (80.12165129184723, 75, 1.0682886838912964, 'player-2:history')
#     (-67.3369824886322, 100, -0.673369824886322, 'player-3:history')
#     (50.92325210571289, 50, 1.0184650421142578, 'player-1:history')
#     (-27.538487315177917, 25, -1.1015394926071167, 'player-0:history')
#     (3.448328971862793, 1, 3.448328971862793, 'player-1:state')
#     (2.6065385341644287, 1, 2.6065385341644287, 'player-4:state')
#     (2.326658010482788, 1, 2.326658010482788, 'player-3:state')
#     (-1.4478068351745605, 1, -1.4478068351745605, 'player-5:state')
#     (-1.2884678840637207, 1, -1.2884678840637207, 'btn distance')
#     (-1.051241159439087, 1, -1.051241159439087, 'round level')
#     (-0.82024276, 0, 0, 'bias')
#     (-0.7919857501983643, 1, -0.7919857501983643, 'player-2:state')
#     (-0.6443517208099365, 1, -0.6443517208099365, 'player-0:state')
#     (-0.3658095407485962, 0.637, -0.5742692947387695, 'cards')
#
# linear combination for double_raise :
#     (-45174.31843280792, 9875, -4.574614524841309, 'player-4:stack')
#     (-20038.828724622726, 9925, -2.0190255641937256, 'player-2:stack')
#     (5028.939932584763, 9900, 0.5079737305641174, 'player-3:stack')
#     (3895.3715562820435, 10000, 0.38953715562820435, 'player-7:stack')
#     (2853.8531497120857, 9975, 0.2861005663871765, 'player-0:stack')
#     (2453.0529350042343, 9950, 0.246537983417511, 'player-1:stack')
#     (2110.065668821335, 10000, 0.21100656688213348, 'player-9:stack')
#     (-2042.669951915741, 10000, -0.2042669951915741, 'player-8:stack')
#     (1958.324909210205, 10000, 0.1958324909210205, 'player-6:stack')
#     (1781.3387334346771, 9850, 0.18084657192230225, 'player-5:stack')
#     (-1428.3981800079346, 150, -9.52265453338623, 'player-5:history')
#     (-861.6535186767578, 100, -8.616535186767578, 'player-3:history')
#     (-653.0361771583557, 125, -5.224289417266846, 'player-4:history')
#     (-596.2973803281784, 525, -1.135804533958435, 'pot')
#     (-270.0078248977661, 75, -3.600104331970215, 'player-2:history')
#     (-55.72282671928406, 50, -1.1144565343856812, 'player-1:history')
#     (-40.999966859817505, 25, -1.6399986743927002, 'player-0:history')
#     (6.112326622009277, 1, 6.112326622009277, 'btn distance')
#     (4.263469696044922, 1, 4.263469696044922, 'round level')
#     (4.023079872131348, 1, 4.023079872131348, 'player-0:state')
#     (3.917094, 0, 0, 'bias')
#     (-3.8193256855010986, 1, -3.8193256855010986, 'player-3:state')
#     (-3.001655101776123, 1, -3.001655101776123, 'player-4:state')
#     (-2.578047513961792, 1, -2.578047513961792, 'player-2:state')
#     (2.324614338159561, 0.637, 3.6493160724639893, 'cards')
#     (-1.9744051694869995, 1, -1.9744051694869995, 'player-5:state')
#     (-0.5328550338745117, 1, -0.5328550338745117, 'player-1:state')
#
# linear combination for triple_raise :
#     (-17754.689717292786, 9950, -1.784390926361084, 'player-1:stack')
#     (-12646.536380052567, 9925, -1.2742102146148682, 'player-2:stack')
#     (3368.3022558689117, 9900, 0.3402325510978699, 'player-3:stack')
#     (2075.5943655967712, 10000, 0.20755943655967712, 'player-8:stack')
#     (1485.9996736049652, 10000, 0.14859996736049652, 'player-6:stack')
#     (1382.1513950824738, 10000, 0.13821513950824738, 'player-9:stack')
#     (1251.1926613748074, 9850, 0.12702463567256927, 'player-5:stack')
#     (1056.7586924880743, 9875, 0.10701353847980499, 'player-4:stack')
#     (-482.03490674495697, 10000, -0.0482034906744957, 'player-7:stack')
#     (-345.55069506168365, 525, -0.6581918001174927, 'pot')
#     (302.1156805101782, 9975, 0.030287286266684532, 'player-0:stack')
#     (-109.48995351791382, 75, -1.4598660469055176, 'player-2:history')
#     (-107.24600553512573, 100, -1.0724600553512573, 'player-3:history')
#     (-93.93621236085892, 125, -0.7514896988868713, 'player-4:history')
#     (-48.397886753082275, 150, -0.32265257835388184, 'player-5:history')
#     (20.98757177591324, 25, 0.8395028710365295, 'player-0:history')
#     (-8.327115327119827, 50, -0.16654230654239655, 'player-1:history')
#     (3.3197178840637207, 1, 3.3197178840637207, 'player-4:state')
#     (-3.263518810272217, 1, -3.263518810272217, 'player-3:state')
#     (-1.0379902124404907, 1, -1.0379902124404907, 'player-5:state')
#     (0.7049521207809448, 1, 0.7049521207809448, 'btn distance')
#     (0.6967635750770569, 1, 0.6967635750770569, 'player-0:state')
#     (0.6377264261245728, 1, 0.6377264261245728, 'player-2:state')
#     (0.47396657, 0, 0, 'bias')
#     (0.3185389041900635, 1, 0.3185389041900635, 'round level')
#     (0.14075509290397167, 0.637, 0.22096560895442963, 'cards')
#     (0.09936961531639099, 1, 0.09936961531639099, 'player-1:state')
#
# linear combination for max_raise :
#     (-5808.247950673103, 9950, -0.5837435126304626, 'player-1:stack')
#     (-2493.2428032159805, 9900, -0.2518427073955536, 'player-3:stack')
#     (2413.748651742935, 10000, 0.24137486517429352, 'player-8:stack')
#     (-971.1786031723022, 150, -6.474524021148682, 'player-5:history')
#     (776.6202898696065, 9925, 0.07824889570474625, 'player-2:stack')
#     (736.643373966217, 10000, 0.0736643373966217, 'player-7:stack')
#     (-389.23018276691437, 525, -0.7413908243179321, 'pot')
#     (-345.24306654930115, 10000, -0.034524306654930115, 'player-6:stack')
#     (-340.1229355484247, 9975, -0.03409753739833832, 'player-0:stack')
#     (-328.24906408786774, 9850, -0.03332477807998657, 'player-5:stack')
#     (-204.2825147509575, 10000, -0.02042825147509575, 'player-9:stack')
#     (-126.77296996116638, 125, -1.014183759689331, 'player-4:history')
#     (-96.11096978187561, 25, -3.8444387912750244, 'player-0:history')
#     (49.757036566734314, 50, 0.9951407313346863, 'player-1:history')
#     (10.584719851613045, 75, 0.14112959802150726, 'player-2:history')
#     (-7.410845160484314, 100, -0.07410845160484314, 'player-3:history')
#     (5.559932708740234, 1, 5.559932708740234, 'player-3:state')
#     (3.6084768772125244, 1, 3.6084768772125244, 'round level')
#     (3.3815178871154785, 1, 3.3815178871154785, 'player-1:state')
#     (3.3752668, 0, 0, 'bias')
#     (3.216010332107544, 1, 3.216010332107544, 'player-0:state')
#     (2.7941577434539795, 1, 2.7941577434539795, 'btn distance')
#     (2.095797103404999, 0.637, 3.2901053428649902, 'cards')
#     (1.2304402589797974, 1, 1.2304402589797974, 'player-4:state')
#     (1.1196054220199585, 1, 1.1196054220199585, 'player-2:state')
#     (-0.7973573565323022, 9875, -8.074504876276478e-05, 'player-4:stack')
#     (-0.22909387946128845, 1, -0.22909387946128845, 'player-5:state')

# %% [markdown]
# ### MIN_RAISE

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['H9', 'H6']
# -- round state --
#   - dealer btn : cpu6
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu6 (uuid-6) => state : participating, stack : 10000
#     - 1 : cpu5 (uuid-5) => state : participating, stack : 9975 <= SB
#     - 2 : cpu7 (uuid-7) => state : participating, stack : 9950 <= BB
#     - 3 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 4 : cpu9 (uuid-9) => state : participating, stack : 10000
#     - 5 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 6 : cpu3 (uuid-3) => state : participating, stack : 10000
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu4 (uuid-4) => state : participating, stack : 10000
#     - 9 : cpu2 (uuid-2) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'add_amount': 25}
# ======================================================================
# Agent took action [ raise: 75 (min_raise) ] at round 1
#   => [('fold', -34.535133361816406), ('call', -318.1614685058594), ('min_raise', 57.897743225097656), ('double_raise', -48197.09375), ('triple_raise', -20033.521484375), ('max_raise', -5685.83349609375)]
# ** weights and features in detail **
# features : [1, 3, 0, 0.639, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 10000, 1, 0, 9975, 1, 25, 9950, 1, 50, 75]
# bias : [-0.5284971  -0.6841774  -0.82024276  3.91709399  0.47396657  3.37526679]
#
# linear combination for fold :
#     (-1031.7379236221313, 10000, -0.10317379236221313, 'player-2:stack')
#     (-733.9200377464294, 10000, -0.07339200377464294, 'player-3:stack')
#     (503.06495279073715, 10000, 0.050306495279073715, 'player-4:stack')
#     (-416.02689530700445, 9975, -0.041706956923007965, 'player-8:stack')
#     (407.7688604593277, 10000, 0.04077688604593277, 'player-6:stack')
#     (400.9947180747986, 10000, 0.04009947180747986, 'player-5:stack')
#     (367.7354007959366, 10000, 0.03677354007959366, 'player-1:stack')
#     (276.6369964927435, 9950, 0.027802713215351105, 'player-9:stack')
#     (101.53927840292454, 10000, 0.010153927840292454, 'player-0:stack')
#     (54.61078602820635, 10000, 0.005461078602820635, 'player-7:stack')
#     (-10.945142805576324, 75, -0.14593523740768433, 'pot')
#     (8.939065784215927, 50, 0.17878131568431854, 'player-9:history')
#     (5.832931995391846, 1, 5.832931995391846, 'player-8:state')
#     (5.688854217529297, 1, 5.688854217529297, 'player-1:state')
#     (5.264644145965576, 1, 5.264644145965576, 'player-4:state')
#     (4.837528705596924, 1, 4.837528705596924, 'player-9:state')
#     (4.822535037994385, 1, 4.822535037994385, 'player-2:state')
#     (4.329682230949402, 3, 1.4432274103164673, 'btn distance')
#     (2.618108130991459, 25, 0.10472432523965836, 'player-8:history')
#     (1.8477801084518433, 1, 1.8477801084518433, 'player-6:state')
#     (1.52057683467865, 1, 1.52057683467865, 'player-3:state')
#     (1.325937032699585, 1, 1.325937032699585, 'player-5:state')
#     (-0.7727053761482239, 1, -0.7727053761482239, 'round level')
#     (-0.5284971, 0, 0, 'bias')
#     (0.49869561195373535, 1, 0.49869561195373535, 'player-7:state')
#     (-0.26959481835365295, 1, -0.26959481835365295, 'player-0:state')
#     (-0.21160120967030527, 0.639, -0.3311443030834198, 'cards')
#
# linear combination for call :
#     (-1084.7413539886475, 10000, -0.10847413539886475, 'player-2:stack')
#     (-1072.8063434362411, 10000, -0.10728063434362411, 'player-3:stack')
#     (370.61531096696854, 10000, 0.037061531096696854, 'player-1:stack')
#     (352.4314612150192, 10000, 0.03524314612150192, 'player-7:stack')
#     (277.27145701646805, 10000, 0.027727145701646805, 'player-6:stack')
#     (273.2742577791214, 10000, 0.02732742577791214, 'player-5:stack')
#     (253.9001351222396, 9950, 0.025517601519823074, 'player-9:stack')
#     (196.6460607945919, 10000, 0.01966460607945919, 'player-0:stack')
#     (86.02592162787914, 10000, 0.008602592162787914, 'player-4:stack')
#     (22.26358453044668, 9975, 0.002231938298791647, 'player-8:stack')
#     (-18.969257175922394, 75, -0.2529234290122986, 'pot')
#     (14.498281478881836, 50, 0.2899656295776367, 'player-9:history')
#     (6.1521608382463455, 25, 0.24608643352985382, 'player-8:history')
#     (2.754791736602783, 1, 2.754791736602783, 'player-1:state')
#     (1.2572400569915771, 1, 1.2572400569915771, 'player-4:state')
#     (1.182464361190796, 1, 1.182464361190796, 'player-6:state')
#     (-1.1517257690429688, 1, -1.1517257690429688, 'player-7:state')
#     (0.9752382636070251, 1, 0.9752382636070251, 'player-3:state')
#     (0.8573418259620667, 1, 0.8573418259620667, 'player-8:state')
#     (-0.6841774, 0, 0, 'bias')
#     (0.6556318998336792, 1, 0.6556318998336792, 'player-2:state')
#     (0.5684808790683746, 3, 0.18949362635612488, 'btn distance')
#     (-0.4957827031612396, 1, -0.4957827031612396, 'round level')
#     (-0.4208604693412781, 1, -0.4208604693412781, 'player-0:state')
#     (-0.36657305413484575, 0.639, -0.5736667513847351, 'cards')
#     (0.3022642731666565, 1, 0.3022642731666565, 'player-5:state')
#     (-0.15737740695476532, 1, -0.15737740695476532, 'player-9:state')
#
# linear combination for min_raise :
#     (-4256.656765937805, 10000, -0.4256656765937805, 'player-2:stack')
#     (3757.10104778409, 9975, 0.37665173411369324, 'player-8:stack')
#     (3731.9862842559814, 10000, 0.37319862842559814, 'player-3:stack')
#     (-1226.0396033525467, 10000, -0.12260396033525467, 'player-7:stack')
#     (-735.1056486368179, 10000, -0.0735105648636818, 'player-6:stack')
#     (-708.2505524158478, 10000, -0.07082505524158478, 'player-5:stack')
#     (691.0876929759979, 10000, 0.06910876929759979, 'player-0:stack')
#     (-675.502122938633, 9950, -0.06788966059684753, 'player-9:stack')
#     (-266.0053037106991, 10000, -0.026600530371069908, 'player-4:stack')
#     (-203.5212144255638, 10000, -0.02035212144255638, 'player-1:stack')
#     (-120.6950694322586, 75, -1.6092675924301147, 'pot')
#     (34.38478410243988, 50, 0.6876956820487976, 'player-9:history')
#     (29.77403998374939, 25, 1.1909615993499756, 'player-8:history')
#     (6.104168891906738, 1, 6.104168891906738, 'player-8:state')
#     (-3.865403652191162, 3, -1.2884678840637207, 'btn distance')
#     (3.448328971862793, 1, 3.448328971862793, 'player-1:state')
#     (2.6065385341644287, 1, 2.6065385341644287, 'player-4:state')
#     (2.326658010482788, 1, 2.326658010482788, 'player-3:state')
#     (-1.4478068351745605, 1, -1.4478068351745605, 'player-5:state')
#     (-1.051241159439087, 1, -1.051241159439087, 'round level')
#     (-0.82024276, 0, 0, 'bias')
#     (-0.7919857501983643, 1, -0.7919857501983643, 'player-2:state')
#     (-0.6443517208099365, 1, -0.6443517208099365, 'player-0:state')
#     (-0.5531448125839233, 1, -0.5531448125839233, 'player-7:state')
#     (0.3744605481624603, 1, 0.3744605481624603, 'player-9:state')
#     (-0.36695807933807373, 0.639, -0.5742692947387695, 'cards')
#     (0.02125852182507515, 1, 0.02125852182507515, 'player-6:state')
#
# linear combination for double_raise :
#     (-45746.145248413086, 10000, -4.574614524841309, 'player-4:stack')
#     (-20190.255641937256, 10000, -2.0190255641937256, 'player-2:stack')
#     (5079.737305641174, 10000, 0.5079737305641174, 'player-3:stack')
#     (3895.3715562820435, 10000, 0.38953715562820435, 'player-7:stack')
#     (2861.005663871765, 10000, 0.2861005663871765, 'player-0:stack')
#     (2465.37983417511, 10000, 0.246537983417511, 'player-1:stack')
#     (2099.515340477228, 9950, 0.21100656688213348, 'player-9:stack')
#     (-2037.5632770359516, 9975, -0.2042669951915741, 'player-8:stack')
#     (1958.324909210205, 10000, 0.1958324909210205, 'player-6:stack')
#     (1808.4657192230225, 10000, 0.18084657192230225, 'player-5:stack')
#     (-346.56593799591064, 50, -6.931318759918213, 'player-9:history')
#     (-85.18534004688263, 75, -1.135804533958435, 'pot')
#     (22.4815770983696, 25, 0.8992630839347839, 'player-8:history')
#     (18.336979866027832, 3, 6.112326622009277, 'btn distance')
#
# linear combination for triple_raise :
#     (-17843.90926361084, 10000, -1.784390926361084, 'player-1:stack')
#     (-12742.102146148682, 10000, -1.2742102146148682, 'player-2:stack')
#     (3402.3255109786987, 10000, 0.3402325510978699, 'player-3:stack')
#     (2070.4053796827793, 9975, 0.20755943655967712, 'player-8:stack')
#     (1485.9996736049652, 10000, 0.14859996736049652, 'player-6:stack')
#     (1375.2406381070614, 9950, 0.13821513950824738, 'player-9:stack')
#     (1270.2463567256927, 10000, 0.12702463567256927, 'player-5:stack')
#     (1070.13538479805, 10000, 0.10701353847980499, 'player-4:stack')
#     (-482.03490674495697, 10000, -0.0482034906744957, 'player-7:stack')
#     (302.8728626668453, 10000, 0.030287286266684532, 'player-0:stack')
#     (74.8145043849945, 50, 1.4962900876998901, 'player-9:history')
#     (-49.36438500881195, 75, -0.6581918001174927, 'pot')
#     (29.16831076145172, 25, 1.1667324304580688, 'player-8:history')
#     (3.3197178840637207, 1, 3.3197178840637207, 'player-4:state')
#     (-3.263518810272217, 1, -3.263518810272217, 'player-3:state')
#     (-2.8256802558898926, 1, -2.8256802558898926, 'player-8:state')
#     (2.1148563623428345, 3, 0.7049521207809448, 'btn distance')
#     (1.3939698934555054, 1, 1.3939698934555054, 'player-7:state')
#     (-1.0379902124404907, 1, -1.0379902124404907, 'player-5:state')
#     (0.6967635750770569, 1, 0.6967635750770569, 'player-0:state')
#     (0.6377264261245728, 1, 0.6377264261245728, 'player-2:state')
#     (0.49656206369400024, 1, 0.49656206369400024, 'player-6:state')
#     (0.47396657, 0, 0, 'bias')
#     (0.3185389041900635, 1, 0.3185389041900635, 'round level')
#     (0.14119702412188054, 0.639, 0.22096560895442963, 'cards')
#     (0.11487279832363129, 1, 0.11487279832363129, 'player-9:state')
#     (0.09936961531639099, 1, 0.09936961531639099, 'player-1:state')
#
# linear combination for max_raise :
#     (-5837.4351263046265, 10000, -0.5837435126304626, 'player-1:stack')
#     (-2518.427073955536, 10000, -0.2518427073955536, 'player-3:stack')
#     (2407.714280113578, 9975, 0.24137486517429352, 'player-8:stack')
#     (782.4889570474625, 10000, 0.07824889570474625, 'player-2:stack')
#     (736.643373966217, 10000, 0.0736643373966217, 'player-7:stack')
#     (-345.24306654930115, 10000, -0.034524306654930115, 'player-6:stack')
#     (-340.9753739833832, 10000, -0.03409753739833832, 'player-0:stack')
#     (-333.2477807998657, 10000, -0.03332477807998657, 'player-5:stack')
#     (-203.2611021772027, 9950, -0.02042825147509575, 'player-9:stack')
#     (-55.60431182384491, 75, -0.7413908243179321, 'pot')
#     (-42.98388659954071, 50, -0.8596777319908142, 'player-9:history')
#     (21.252581477165222, 25, 0.8501032590866089, 'player-8:history')
#     (8.382473230361938, 3, 2.7941577434539795, 'btn distance')
#     (6.660478591918945, 1, 6.660478591918945, 'player-6:state')
#     (5.559932708740234, 1, 5.559932708740234, 'player-3:state')
#     (3.6084768772125244, 1, 3.6084768772125244, 'round level')
#     (3.528339385986328, 1, 3.528339385986328, 'player-8:state')
#     (3.3815178871154785, 1, 3.3815178871154785, 'player-1:state')
#     (3.3752668, 0, 0, 'bias')
#     (3.216010332107544, 1, 3.216010332107544, 'player-0:state')
#     (2.36977481842041, 1, 2.36977481842041, 'player-9:state')
#     (2.1023773140907287, 0.639, 3.2901053428649902, 'cards')
#     (1.2304402589797974, 1, 1.2304402589797974, 'player-4:state')
#     (1.1196054220199585, 1, 1.1196054220199585, 'player-2:state')
#     (-0.8074504876276478, 10000, -8.074504876276478e-05, 'player-4:stack')
#     (-0.25307849049568176, 1, -0.25307849049568176, 'player-7:state')
#     (-0.22909387946128845, 1, -0.22909387946128845, 'player-5:state')
