# %% [markdown]
# # Train by 1-hidden layer NeuralNet
# - algorithm : Sarsa
# - feature : scaled scalar features
# - final_round : 1,2,5
# - number of unit on hidden layer : 32, 128, 512

# %% [markdown]
# # 1 round

# %% [markdown]
# ## 32 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/1round/32unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/1round/32unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/1round/32unit/1_round_3000_match_subplot_0116_12_26_51.png"/> | <img src="./resource/mlp_1layer_trial_0116/1round/32unit/1_round_3000_match_histgram_0116_12_26_51.png" />|

# %% [markdown]
# ### なぜかMAX_RAISE (相手が降りたので勝ってるが)

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['SJ', 'S4']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', 0.098692886531353), ('call', 0.09650066494941711), ('min_raise', 0.09361770749092102), ('double_raise', 0.0726204514503479), ('triple_raise', 0.09748920798301697), ('max_raise', 0.13739125430583954)]

# %% [markdown]
# ### MAX_RAISEにCALLして負ける

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['CJ', 'CQ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', 0.09945353865623474), ('call', 0.10444106161594391)]

# %% [markdown]
# ### MAX_RAISEにCALLして勝つ

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['HK', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', 0.09930580109357834), ('call', 0.10986480116844177)]

# %% [markdown]
# ## 128 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/1round/128unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/1round/128unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/1round/128unit/1_round_3000_match_subplot_0116_12_39_25.png"/> | <img src="./resource/mlp_1layer_trial_0116/1round/128unit/1_round_3000_match_histgram_0116_12_39_25.png" />|

# %% [markdown]
# ### 2回 TRIPLE RAISEするも,FLOPですぐ降りる

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 800
#   - raise: [1375, 10000]
# -- hole card --
#   - ['DT', 'D7']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 1850, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9200
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9200 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 9775 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 175, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 225, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 575, 'paid': 800, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 800, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 800, 'paid': 750}
# ======================================================================
# Agent took action [ raise: 4125 (triple_raise) ] at round 1
#   => [('fold', 0.0993894413113594), ('call', 0.09781698882579803), ('min_raise', 0.05248498544096947), ('double_raise', 0.0890844389796257), ('triple_raise', 0.1051291823387146), ('max_raise', 0.052297621965408325)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 0
#   - raise: [50, 5875]
# -- hole card --
#   - ['DT', 'D7']
# -- round state --
#   - dealer btn : cpu8
#   - street : flop
#   - community card : ['HK', 'C6', 'S9']
#   - pot : main = 12400, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 5875
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 5875 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 5875 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 175, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 225, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 575, 'paid': 800, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 800, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 800, 'paid': 750}
#       - {'add_amount': 3325, 'paid': 3900, 'player': 'agent (uuid=uuid-0)', 'amount': 4125, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 4125, 'paid': 3325}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 4125, 'paid': 3325}
#     - flop
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.04816889017820358), ('call', 0.043031055480241776), ('min_raise', -0.028732560575008392), ('double_raise', 0.013123273849487305), ('triple_raise', 0.01338157057762146), ('max_raise', 0.002079922705888748)]

# %% [markdown]
# ### QK-> RAISE -> FLOPでQのONE-PAIR完成 -> RAISE CALL. 理解できてそうな雰囲気

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['CQ', 'SK']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 225 (triple_raise) ] at round 1
#   => [('fold', 0.10069945454597473), ('call', 0.09115808457136154), ('min_raise', 0.04414278641343117), ('double_raise', 0.10263954848051071), ('triple_raise', 0.10715842247009277), ('max_raise', 0.04307164251804352)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 100
#   - raise: [200, 9200]
# -- hole card --
#   - ['CQ', 'SK']
# -- round state --
#   - dealer btn : cpu8
#   - street : flop
#   - community card : ['H3', 'C3', 'C6']
#   - pot : main = 2575, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9100
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 9200 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 9200
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 175, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 225, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 225, 'paid': 225}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 575, 'paid': 800, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 800, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 800, 'paid': 575}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 800, 'paid': 575}
#     - flop
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'add_amount': 100, 'paid': 100, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 100, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 100 (call) ] at round 1
#   => [('fold', 0.07631608843803406), ('call', 0.08154748380184174), ('min_raise', -0.009635567665100098), ('double_raise', 0.03807956725358963), ('triple_raise', 0.039208222180604935), ('max_raise', 0.031020941212773323)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 0
#   - raise: [50, 9100]
# -- hole card --
#   - ['CQ', 'SK']
# -- round state --
#   - dealer btn : cpu8
#   - street : turn
#   - community card : ['H3', 'C3', 'C6', 'DQ']
#   - pot : main = 2675, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9100
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 9100 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 9200
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 175, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 225, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 225, 'paid': 225}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 575, 'paid': 800, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 800, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 800, 'paid': 575}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 800, 'paid': 575}
#     - flop
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'add_amount': 100, 'paid': 100, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 100, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 100, 'paid': 100}
# ======================================================================
# Agent took action [ call: 0 (call) ] at round 1
#   => [('fold', 0.06640858948230743), ('call', 0.15600134432315826), ('min_raise', -0.012077119201421738), ('double_raise', 0.06279277056455612), ('triple_raise', 0.06504824012517929), ('max_raise', 0.10272238403558731)]

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 100
#   - raise: [200, 9000]
# -- hole card --
#   - ['CQ', 'SK']
# -- round state --
#   - dealer btn : cpu8
#   - street : river
#   - community card : ['H3', 'C3', 'C6', 'DQ', 'SJ']
#   - pot : main = 2975, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 8900
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 9000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 9200
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 175, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 225, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 225, 'paid': 225}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 575, 'paid': 800, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 800, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 800, 'paid': 575}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 800, 'paid': 575}
#     - flop
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'add_amount': 100, 'paid': 100, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 100, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 100, 'paid': 100}
#     - turn
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#       - {'add_amount': 100, 'paid': 100, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 100, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 100, 'paid': 100}
#     - river
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#       - {'add_amount': 100, 'paid': 100, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 100, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 100 (call) ] at round 1
#   => [('fold', 0.05190404877066612), ('call', 0.14909696578979492), ('min_raise', -0.03485194593667984), ('double_raise', 0.05345531553030014), ('triple_raise', 0.045872561633586884), ('max_raise', 0.10077890753746033)]

# %% [markdown]
# ### One-PairでRAISEをけしかけていくが,RIVERでカードが悪くなり,諦めてFOLD
# - PREFLOPで0.1あったCALLの価値が,RIVERではほぼ０になっている

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['HT', 'ST']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 125, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9950
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'paid': 50}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 225 (triple_raise) ] at round 1
#   => [('fold', 0.10127437859773636), ('call', 0.10935702174901962), ('min_raise', 0.04779179394245148), ('double_raise', 0.10689577460289001), ('triple_raise', 0.11917836964130402), ('max_raise', 0.06020059436559677)]

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 0
#   - raise: [50, 5875]
# -- hole card --
#   - ['HT', 'ST']
# -- round state --
#   - dealer btn : cpu8
#   - street : river
#   - community card : ['C2', 'C5', 'C4', 'D4', 'CQ']
#   - pot : main = 9125, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 9200
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 5875
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 5875 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'paid': 50}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 175, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 225, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'add_amount': 575, 'paid': 800, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 800, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'add_amount': 3325, 'paid': 4075, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 4125, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 4125, 'paid': 3900}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#     - flop
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#     - turn
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#     - river
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 0, 'paid': 0}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.015696503221988678), ('call', -0.028892971575260162), ('min_raise', -0.10893037915229797), ('double_raise', -0.02844487875699997), ('triple_raise', -0.050851285457611084), ('max_raise', -0.04840297996997833)]

# %% [markdown]
# ## 512 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/1round/512unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/1round/512unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/1round/512unit/1_round_3000_match_subplot_0116_12_47_06.png"/> | <img src="./resource/mlp_1layer_trial_0116/1round/512unit/1_round_3000_match_histgram_0116_12_47_06.png" />|

# %% [markdown]
# ### ひたすらFOLD

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['DA', 'CJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.09857480227947235), ('call', 0.04475540295243263), ('min_raise', 0.08888694643974304), ('double_raise', 0.06146414205431938), ('triple_raise', 0.042156416922807693), ('max_raise', -0.020823277533054352)]

# %% [markdown]
# ## OnePairの時だけ動く

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['C9', 'S9']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 75 (min_raise) ] at round 1
#   => [('fold', 0.09741120040416718), ('call', 0.0664132758975029), ('min_raise', 0.10303580015897751), ('double_raise', 0.07478678226470947), ('triple_raise', 0.05134463310241699), ('max_raise', -0.004367835819721222)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['HQ', 'CQ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 75 (min_raise) ] at round 1
#   => [('fold', 0.09630578756332397), ('call', 0.08698827028274536), ('min_raise', 0.11647725105285645), ('double_raise', 0.08744333684444427), ('triple_raise', 0.060073450207710266), ('max_raise', 0.011264830827713013)]

# %% [markdown]
# # 2 round

# %% [markdown]
# ## 32 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/2round/32unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/2round/32unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/2round/32unit/2_round_3000_match_subplot_0116_13_10_11.png"/> | <img src="./resource/mlp_1layer_trial_0116/2round/32unit/2_round_3000_match_histgram_0116_13_10_11.png" />|

# %% [markdown]
# ### A,KでALLINにCALL

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['CA', 'DK']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-5']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', 0.0923411175608635), ('call', 0.09524624049663544)]

# %% [markdown]
# ### DOUBLE RAISE.(次にALLINされて,CALLの価値が0.02くらいでFOLD)

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 500
#   - raise: [850, 10000]
# -- hole card --
#   - ['C3', 'S8']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 725, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 10025 <= BB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9850
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9500
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 500, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 1700 (double_raise) ] at round 2
#   => [('fold', 0.09077411890029907), ('call', 0.07049563527107239), ('min_raise', 0.05934411287307739), ('double_raise', 0.09226879477500916), ('triple_raise', 0.07423710823059082), ('max_raise', 0.06805117428302765)]

# %% [markdown]
# ### ONE-PAIRでALLIN CALL

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['H8', 'S8']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-5']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', 0.09250176697969437), ('call', 0.09948031604290009)]

# %% [markdown]
# ### 謎のALLIN

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 500
#   - raise: [850, 10000]
# -- hole card --
#   - ['S3', 'SQ']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 725, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9800 <= BB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 10075
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9500
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 500, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 2
#   => [('fold', 0.09107773005962372), ('call', 0.07768072187900543), ('min_raise', 0.07303836196660995), ('double_raise', 0.09688380360603333), ('triple_raise', 0.08515753597021103), ('max_raise', 0.1043415293097496)]

# %% [markdown]
# ## 128 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/2round/128unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/2round/128unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/2round/128unit/2_round_3000_match_subplot_0116_13_41_06.png"/> | <img src="./resource/mlp_1layer_trial_0116/2round/128unit/2_round_3000_match_histgram_0116_13_41_06.png" />|

# %% [markdown]
# ### MIN_RAISE合戦の末負ける
# - カードが全く強くない(ex.7&4)のにMIN_RAISEを繰り返して,どこかで降りるか,最後までいくかのどちらか
# - 必ずこの流れになってしまう

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['C9', 'H3']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 61025, side = [{'amount': 0, 'eligibles': ['uuid-4', 'uuid-5', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-4', 'uuid-5', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-4', 'uuid-5', 'uuid-3']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 5525
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 5725 <= SB
#     - 2 : cpu4 (uuid-4) => state : allin, stack : 0 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 5450
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 5875
#     - 6 : agent (uuid-0) => state : participating, stack : 5425 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 5400
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 5575
#     - 9 : cpu3 (uuid-3) => state : allin, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       # .....................................................
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 4350, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 4375, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 4400, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 4425, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 4450, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 4475, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'add_amount': 25, 'paid': 200, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 4500, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 200, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 4525, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 200, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 4550, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 200, 'player': 'agent (uuid=uuid-0)', 'amount': 4575, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 200, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 4600, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'add_amount': 5400, 'paid': 5550, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 10000, 'paid': 5500}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'paid': 5475}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', 0.08599381893873215), ('call', 0.13871651887893677)]

# %% [markdown]
# ## 512 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/2round/512unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/2round/512unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/2round/512unit/2_round_3000_match_subplot_0116_13_27_00.png"/> | <img src="./resource/mlp_1layer_trial_0116/2round/512unit/2_round_3000_match_histgram_0116_13_27_00.png" />|

# %% [markdown]
# ### OnePairでBB call, A-8だとFOLD
# - OnePair以外FOLD, OnePairでもCALL.しかも,それで決着つく

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['SJ', 'DJ']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 10000 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ call: 50 (call) ] at round 2
#   => [('fold', 0.0950494185090065), ('call', 0.1271887570619583), ('min_raise', 0.011857927776873112), ('double_raise', -0.015861235558986664), ('triple_raise', 0.006681131664663553), ('max_raise', -0.09425497055053711)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['DA', 'HA']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ call: 50 (call) ] at round 1
#   => [('fold', 0.09548703581094742), ('call', 0.13206323981285095), ('min_raise', 0.02059972658753395), ('double_raise', -0.05844530463218689), ('triple_raise', 0.010425368323922157), ('max_raise', -0.05864470824599266)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['HA', 'D8']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.09766490012407303), ('call', 0.04450782760977745), ('min_raise', 0.028545953333377838), ('double_raise', -0.0717226192355156), ('triple_raise', -0.04045901447534561), ('max_raise', -0.1784188598394394)]

# %% [markdown]
# # 5 round

# %% [markdown]
# ## 32 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/5round/32unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/5round/32unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/5round/32unit/5_round_3000_match_subplot_0116_18_57_58.png"/> | <img src="./resource/mlp_1layer_trial_0116/5round/32unit/5_round_3000_match_histgram_0116_18_57_58.png" />|

# %% [markdown]
# ### 手札が弱くてもとりあえずCALL

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['D4', 'H2']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9950
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9950
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'paid': 50}
# ======================================================================
# Agent took action [ call: 50 (call) ] at round 1
#   => [('fold', 0.13767866790294647), ('call', 0.17981290817260742), ('min_raise', 0.11035284399986267), ('double_raise', 0.031386181712150574), ('triple_raise', 0.034921079874038696), ('max_raise', -0.11255869269371033)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 0
#   - raise: [50, 9900]
# -- hole card --
#   - ['HK', 'C5']
# -- round state --
#   - dealer btn : cpu9
#   - street : turn
#   - community card : ['H6', 'H8', 'SQ', 'HJ']
#   - pot : main = 500, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9900
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 10400
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9900 <= SB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9900 <= BB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9900
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9900
#     - 6 : agent (uuid-0) => state : participating, stack : 9900 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 9900
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 9900
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 9900
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu2 (uuid=uuid-2)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'paid': 25}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'paid': 0}
#     - flop
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu2 (uuid=uuid-2)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 0, 'paid': 0}
#     - turn
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 0, 'paid': 0}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 0, 'paid': 0}
# ======================================================================
# Agent took action [ call: 0 (call) ] at round 2
#   => [('fold', 0.14280083775520325), ('call', 0.16009530425071716), ('min_raise', 0.09041102230548859), ('double_raise', -0.01357153058052063), ('triple_raise', 0.01234029233455658), ('max_raise', -0.18390655517578125)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 0
#   - raise: [50, 9900]
# -- hole card --
#   - ['HK', 'C5']
# -- round state --
#   - dealer btn : cpu9
#   - street : river
#   - community card : ['H6', 'H8', 'SQ', 'HJ', 'DQ']
#   - pot : main = 500, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9900
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 10400
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9900 <= SB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9900 <= BB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9900
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9900
#     - 6 : agent (uuid-0) => state : participating, stack : 9900 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 9900
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 9900
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 9900
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
# ....................
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 0, 'paid': 0}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#     - river
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 0, 'paid': 0}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 2
#   => [('fold', 0.1373041868209839), ('call', 0.1276334822177887), ('min_raise', 0.07506683468818665), ('double_raise', -0.03910292685031891), ('triple_raise', 0.0004017651081085205), ('max_raise', -0.19880041480064392)]

# %% [markdown]
# ## 128 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/5round/128unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/5round/128unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/5round/128unit/5_round_3000_match_subplot_0116_18_55_51.png"/> | <img src="./resource/mlp_1layer_trial_0116/5round/128unit/5_round_3000_match_histgram_0116_18_55_51.png" />|

# %% [markdown]
# ### 急にMAX_RAISE (MAX_RAISEで相手が降りて,あとは自分が全部降りて¥50+で終了
# - カードが良くてもCALLの価値があまり変わってない(0.07辺)ので,ALLINを決めてあとは降りる作戦を覚えた?

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['DK', 'HJ']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 10000
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925 <= SB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9950 <= BB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10075
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 3
#   => [('fold', 0.09318052232265472), ('call', 0.06930293142795563), ('min_raise', 0.03345610946416855), ('double_raise', 0.08278167247772217), ('triple_raise', 0.058614011853933334), ('max_raise', 0.09540829062461853)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['H7', 'C7']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 10050
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925 <= SB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9950 <= BB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10075
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 3
#   => [('fold', 0.09279057383537292), ('call', 0.07337925583124161), ('min_raise', 0.041295088827610016), ('double_raise', 0.0847119390964508), ('triple_raise', 0.05849243700504303), ('max_raise', 0.1215071827173233)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['DJ', 'DQ']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 10025 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 2
#   => [('fold', 0.09417761862277985), ('call', 0.0695314034819603), ('min_raise', 0.02443145215511322), ('double_raise', 0.08072207123041153), ('triple_raise', 0.0561332106590271), ('max_raise', 0.09753523766994476)]

# %% [markdown]
# ### ALLINにFOLD

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['H7', 'C9']
# -- round state --
#   - dealer btn : cpu6
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-3']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9925
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10075
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 9925
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9925 <= SB
#     - 6 : agent (uuid-0) => state : participating, stack : 10025 <= BB, CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10075
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : allin, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 5
#   => [('fold', 0.09655106067657471), ('call', 0.08378316462039948)]

# %% [markdown]
# ## 512 unit
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_trial_0116/5round/512unit/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_trial_0116/5round/512unit/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/5round/512unit/5_round_3000_match_subplot_0116_19_02_19.png"/> | <img src="./resource/mlp_1layer_trial_0116/5round/512unit/5_round_3000_match_histgram_0116_19_02_19.png" />|

# %% [markdown]
# ### 良くないALLIN
# - さらにFOLDの価値がかなり低い
# - 全員ALLINするので,最初にALLINして全負け or 全勝ちで終了

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['H7', 'D4']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 30075, side = [{'amount': 0, 'eligibles': ['uuid-5', 'uuid-6', 'uuid-7']}, {'amount': 0, 'eligibles': ['uuid-5', 'uuid-6', 'uuid-7']}, {'amount': 0, 'eligibles': ['uuid-5', 'uuid-6', 'uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'paid': 10000}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', -0.12814094126224518), ('call', 0.002527490258216858)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['H9', 'HT']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 30075, side = [{'amount': 0, 'eligibles': ['uuid-5', 'uuid-6', 'uuid-7']}, {'amount': 0, 'eligibles': ['uuid-5', 'uuid-6', 'uuid-7']}, {'amount': 0, 'eligibles': ['uuid-5', 'uuid-6', 'uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'paid': 10000}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'paid': 10000}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', -0.12802930176258087), ('call', 0.01998215913772583)]

# %% [markdown]
# # Round-Robin by with and without hidden layer learning results
#
# ## 1-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/1round/1_round_3000_match_subplot_0116_19_28_54.png"/> | <img src="./resource/mlp_1layer_trial_0116/1round/1_round_3000_match_histgram_0116_19_28_54.png" />|
#
# ## 2-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/2round/2_round_3000_match_subplot_0116_19_30_11.png"/> | <img src="./resource/mlp_1layer_trial_0116/2round/2_round_3000_match_histgram_0116_19_30_11.png" />|
#
# ## 5-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_trial_0116/5round/5_round_3000_match_subplot_0116_19_34_21.png"/> | <img src="./resource/mlp_1layer_trial_0116/5round/5_round_3000_match_histgram_0116_19_34_21.png" />|
