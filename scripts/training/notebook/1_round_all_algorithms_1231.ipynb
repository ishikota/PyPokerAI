# %% [markdown]
# # Learning 1-round poker
#
# - training length : 1000000 iteration
# - epsilon annealing : range=[0.99,0.1], length=800000
#
# ### feature expressions
# 1. Scaled Scalar Feature
# 2. Binary Onehot Feature
#
# ### algorithms
# 1. MonteCarlo
# 2. Sarsa
# 3. QLearning
# 4. Deep QLearning (TODO)

# %% [markdown]
# ## Learning by Scaled Scalar Feature

# %% [markdown]
# ## MonteCarlo
# training time : 41367s
#
# ### Initial Value Transition
# <img src="./resource/1round_all_algorithms/montecarlo/scaled_scalar/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/montecarlo/scaled_scalar/1_round_3000_match_subplot_1227_10_53_40.png"/> | <img src="./resource/1round_all_algorithms/montecarlo/scaled_scalar/1_round_3000_match_histgram_1227_10_53_40.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : -0.041
#     - CALL : -0.0257
#     - MIN_RAISE : 0.1292
#     - DOUBLE_RAISE : -0.1093
#     - TRIPLE_RAISE : 0.2241
#     - MAX_RAISE : 0.1516
# cards
#     - FOLD : 0.0
#     - CALL : 1.8258
#     - MIN_RAISE : 0.24
#     - DOUBLE_RAISE : -0.0444
#     - TRIPLE_RAISE : -0.2009
#     - MAX_RAISE : 0.0878
# pot
#     - FOLD : 0.003
#     - CALL : -0.1955
#     - MIN_RAISE : -0.2534
#     - DOUBLE_RAISE : 0.2799
#     - TRIPLE_RAISE : 0.0886
#     - MAX_RAISE : 0.1115

# %% [markdown]
# ## Sarsa
# training time : 37227s
#
# ### Initial Value Transition
# <img src="./resource/1round_all_algorithms/sarsa/scaled_scalar/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/sarsa/scaled_scalar/1_round_3000_match_subplot_1231_13_20_51.png"/> | <img src="./resource/1round_all_algorithms/sarsa/scaled_scalar/1_round_3000_match_histgram_1231_13_20_51.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : -0.0529
#     - CALL : -0.0088
#     - MIN_RAISE : -0.1451
#     - DOUBLE_RAISE : 0.1581
#     - TRIPLE_RAISE : -0.2123
#     - MAX_RAISE : -0.1757
# cards
#     - FOLD : -0.0001
#     - CALL : 1.8058
#     - MIN_RAISE : -0.0045
#     - DOUBLE_RAISE : 0.0179
#     - TRIPLE_RAISE : -0.3077
#     - MAX_RAISE : -0.1568
# pot
#     - FOLD : 0.2504
#     - CALL : -0.6294
#     - MIN_RAISE : 0.1849
#     - DOUBLE_RAISE : -0.2076
#     - TRIPLE_RAISE : 0.3281
#     - MAX_RAISE : 0.1305

# %% [markdown]
# ## QLeaning
# training time : 37789s
#
# ### Initial Value Transition
# <img src="./resource/1round_all_algorithms/q_learning/scaled_scalar/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/q_learning/scaled_scalar/1_round_3000_match_subplot_1231_13_20_48.png"/> | <img src="./resource/1round_all_algorithms/q_learning/scaled_scalar/1_round_3000_match_histgram_1231_13_20_48.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : 0.3756
#     - CALL : -0.2451
#     - MIN_RAISE : 0.2075
#     - DOUBLE_RAISE : -0.3066
#     - TRIPLE_RAISE : -0.0753
#     - MAX_RAISE : -0.2955
# cards
#     - FOLD : 0.0
#     - CALL : 1.6614
#     - MIN_RAISE : -0.3813
#     - DOUBLE_RAISE : -0.2899
#     - TRIPLE_RAISE : 0.0186
#     - MAX_RAISE : -0.3796
# pot
#     - FOLD : -0.0767
#     - CALL : -0.451
#     - MIN_RAISE : -0.2919
#     - DOUBLE_RAISE : -0.3103
#     - TRIPLE_RAISE : -0.2594
#     - MAX_RAISE : -0.0934

# %% [markdown]
# ### Round-Robin by all algorithms using scaled scalar features
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/3_algorithms/scaled_scalar/1_round_3000_match_subplot_1231_13_56_25.png"/> | <img src="./resource/1round_all_algorithms/3_algorithms/scaled_scalar/1_round_3000_match_histgram_1231_13_56_25.png" />|

# %% [markdown]
# ## Learning by Binary Onehot Feature

# %% [markdown]
# ## MonteCarlo
# training time : 49553s
#
# ### Initial Value Transition
# <img src="./resource/1round_all_algorithms/montecarlo/binary_onehot/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/montecarlo/binary_onehot/1_round_3000_match_subplot_1231_13_36_48.png"/> | <img src="./resource/1round_all_algorithms/montecarlo/binary_onehot/1_round_3000_match_histgram_1231_13_36_48.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : [-0.0683, 0.0911, -0.0311, 0.1366]
#     - CALL : [-0.1229, -0.1118, 0.0363, -0.1274]
#     - MIN_RAISE : [-0.1391, -0.051, 0.1318, -0.1072]
#     - DOUBLE_RAISE : [0.0845, 0.1219, 0.0414, 0.0673]
#     - TRIPLE_RAISE : [0.0589, -0.0216, 0.0661, -0.0396]
#     - MAX_RAISE : [0.0152, 0.1355, 0.0289, 0.0753]
# cards
#     - FOLD : [0.0002, 0.0002, -0.0001, -0.0004, 0.0002, 0.0003, 0.0002, -0.0001, -0.0022, -0.0009]
#     - CALL : [-0.0417, 0.041, -0.0387, -0.0073, -0.0322, 0.0086, 0.0731, 0.1438, 0.2547, 0.5497]
#     - MIN_RAISE : [-0.0197, 0.021, 0.1383, -0.0615, 0.0008, 0.0248, -0.0135, -0.1016, 0.1099, -0.0936]
#     - DOUBLE_RAISE : [-0.0898, 0.1395, -0.1361, 0.0029, 0.0557, 0.1312, -0.0681, -0.1146, -0.0906, 0.0429]
#     - TRIPLE_RAISE : [-0.1442, -0.1381, -0.0022, -0.0786, 0.1348, -0.1299, 0.1296, -0.0603, 0.0881, 0.0712]
#     - MAX_RAISE : [-0.1393, -0.0058, -0.0047, 0.1212, -0.1351, -0.0728, 0.1367, -0.1238, 0.0783, -0.1228]
# pot
#     - FOLD : [0.0575, 0.0028, -0.077, 0.0592, -0.0336, -0.0518, 0.0717, -0.0389, 0.0964, -0.1151]
#     - CALL : [-0.0354, 0.0768, -0.126, 0.0941, -0.0203, -0.0861, 0.0698, -0.1412, -0.0069, 0.0215]
#     - MIN_RAISE : [0.03, -0.003, 0.03, 0.0989, 0.064, 0.0059, 0.141, 0.0589, 0.1215, -0.0446]
#     - DOUBLE_RAISE : [-0.0174, 0.0047, 0.1127, 0.013, 0.0511, -0.0966, 0.025, -0.0427, -0.1006, -0.0292]
#     - TRIPLE_RAISE : [-0.011, -0.0626, -0.0617, 0.0057, -0.0265, 0.0502, -0.0263, 0.0662, 0.0006, 0.0279]
#     - MAX_RAISE : [-0.0323, 0.0694, 0.0621, 0.0146, -0.0312, 0.1246, 0.0197, -0.1004, -0.0812, -0.028]

# %% [markdown]
# ## Sarsa
# training time : 50988s
#
# ### Initial Value Transition
# <img src="./resource/1round_all_algorithms/sarsa/binary_onehot/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/sarsa/binary_onehot/1_round_3000_match_subplot_1231_13_38_12.png"/> | <img src="./resource/1round_all_algorithms/sarsa/binary_onehot/1_round_3000_match_histgram_1231_13_38_12.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : [-0.1016, -0.0858, -0.1986, -0.0612]
#     - CALL : [0.0491, -0.0967, -0.0546, -0.0722]
#     - MIN_RAISE : [-0.089, 0.1568, -0.1458, -0.1458]
#     - DOUBLE_RAISE : [0.4675, -0.1024, -0.1979, -0.1067]
#     - TRIPLE_RAISE : [-0.1844, 0.0545, -0.0159, 0.2827]
#     - MAX_RAISE : [-0.1202, -0.1179, 0.0708, -0.2252]
# cards
#     - FOLD : [-0.0012, -0.0003, -0.0002, 0.0, 0.0003, 0.0002, 0.0004, -0.0, 0.0011, -0.0048]
#     - CALL : [0.0066, 0.0022, 0.0282, -0.034, -0.013, 0.0596, 0.1361, 0.1699, 0.316, 0.588]
#     - MIN_RAISE : [-0.0614, -0.0314, 0.0128, -0.0415, -0.0293, -0.0017, 0.0001, -0.0581, -0.0156, 0.084]
#     - DOUBLE_RAISE : [-0.0583, -0.0677, 0.0071, 0.0047, -0.0171, 0.0227, 0.0805, 0.0393, -0.3024, 0.3161]
#     - TRIPLE_RAISE : [0.0002, 0.0164, -0.0356, -0.0473, 0.0155, -0.0611, 0.0044, 0.0137, 0.0635, 0.11]
#     - MAX_RAISE : [-0.0071, 0.0031, -0.0026, 0.009, 0.0025, 0.0005, 0.0426, 0.0344, 0.1479, 0.2598]
# pot
#     - FOLD : [0.0019, -0.0048, 0.0107, 0.0359, -0.0343, -0.0335, 0.0126, -0.0547, 0.0297, -0.0605]
#     - CALL : [-0.073, -0.0991, -0.0826, -0.0887, -0.0377, -0.0959, 0.0459, -0.1091, -0.0396, -0.0086]
#     - MIN_RAISE : [0.0413, -0.0019, 0.0369, 0.047, 0.0588, -0.0052, -0.0059, -0.0784, -0.0918, -0.1134]
#     - DOUBLE_RAISE : [-0.2624, 0.2187, 1.1117, -0.1089, -0.3225, 8.1482, 0.0726, -0.2198, 0.7386, -0.0532]
#     - TRIPLE_RAISE : [-1.1002, -0.2365, -1.4892, -0.0656, -0.1217, -1.7119, -0.9866, 0.1155, -0.29, 0.167]
#     - MAX_RAISE : [0.5743, -1.6641, 0.9934, 0.015, 0.0257, 2.3864, 0.7103, -0.0283, -0.1652, 0.2096]

# %% [markdown]
# ## QLeaning
# training time : 128506s
#
# ### Initial Value Transition
# <img src="./resource/1round_all_algorithms/q_learning/binary_onehot/initial_value_transition.png" width=600 />
#
# ### Round-Robin match
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/q_learning/binary_onehot/1_round_3000_match_subplot_1231_13_57_07.png"/> | <img src="./resource/1round_all_algorithms/q_learning/binary_onehot/1_round_3000_match_histgram_1231_13_57_07.png" />|
#
# ### Weights for Important Elements
# street
#     - FOLD : [0.0066, 0.0452, 0.1263, 0.0687]
#     - CALL : [0.1822, 0.1237, -0.0784, -0.1047]
#     - MIN_RAISE : [0.2606, 0.2534, -0.0272, 0.2477]
#     - DOUBLE_RAISE : [1.4062, 0.5934, -0.0627, -0.686]
#     - TRIPLE_RAISE : [0.9078, -0.3404, -0.4627, -0.5133]
#     - MAX_RAISE : [0.5071, 0.1023, -0.1262, 0.0589]
# cards
#     - FOLD : [-0.0008, -0.0163, 0.0173, 0.0117, 0.0115, 0.002, 0.0016, 0.0233, -0.0102, -0.0093]
#     - CALL : [-0.0012, 0.0222, 0.0051, -0.0242, -0.0298, 0.0143, 0.0185, -0.0102, 0.0658, 0.0842]
#     - MIN_RAISE : [-0.0682, -0.012, -0.0544, -0.0442, -0.0356, 0.0132, -0.0414, -0.025, -0.0107, 0.0178]
#     - DOUBLE_RAISE : [-0.0092, -0.0557, 0.0537, -0.0225, -0.0747, 0.0009, 0.0226, -0.0096, -0.0669, 0.0403]
#     - TRIPLE_RAISE : [-0.0062, -0.0175, 0.0063, -0.0353, 0.0282, 0.0155, -0.0687, -0.0516, -0.0165, -0.0237]
#     - MAX_RAISE : [0.0087, -0.0051, -0.0137, 0.0006, 0.0077, 0.0138, -0.0038, -0.0005, 0.0068, 0.0051]
# pot
#     - FOLD : [-0.0129, 0.0073, 0.0357, 0.0003, 0.0137, 0.025, 0.0059, 0.0444, -0.0112, -0.0137]
#     - CALL : [-0.0214, -0.1521, -0.0514, 0.0487, 0.0053, 0.0068, 0.0165, -0.0276, -0.0959, 0.021]
#     - MIN_RAISE : [0.1796, 0.078, 0.1391, 0.0774, 0.043, -0.1707, -0.118, 0.1275, -0.0676, -0.0285]
#     - DOUBLE_RAISE : [-0.694, 0.2322, -0.074, 0.449, -0.1813, -1.0632, -0.072, -1.1126, -0.3995, -0.3653]
#     - TRIPLE_RAISE : [0.2745, -0.0068, 0.3179, -0.0204, 0.6127, -1.2962, 0.0772, -1.1063, 0.0603, 0.2694]
#     - MAX_RAISE : [-0.0513, -0.3157, -0.1206, 0.1464, 0.119, 0.0969, -0.011, 0.0356, 0.1662, -0.1494]

# %% [markdown]
# ### Round-Robin by all algorithms using binary onehot features
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/3_algorithms/binary_onehot/1_round_3000_match_subplot_1231_14_12_22.png"/> | <img src="./resource/1round_all_algorithms/3_algorithms/binary_onehot/1_round_3000_match_histgram_1231_14_12_22.png" />|

# %% [markdown]
# ## Round-Robin by all algorithms and all feature expressions
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/3_algorithms/mix/1_round_3000_match_subplot_1231_15_22_19.png"/> | <img src="./resource/1round_all_algorithms/3_algorithms/mix/1_round_3000_match_histgram_1231_15_22_19.png" />|
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/1round_all_algorithms/3_algorithms/mix/1_round_3000_match_subplot_1231_15_50_09.png"/> | <img src="./resource/1round_all_algorithms/3_algorithms/mix/1_round_3000_match_histgram_1231_15_50_09.png" />|
