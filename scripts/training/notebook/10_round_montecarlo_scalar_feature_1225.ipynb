# %% [markdown]
# # 実験3 いろんなfeature表現を試す
# ## scalar feature (not scaled)

# %% [markdown]
# ## 10-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 100万
# - 5万iteration毎に敵のvalue_functionを過去のweightsのいずれかにセットし直しながらself-play
# - 計算時間 : 71853s => 20.0h
#     - aws g2.x.large上でやった
#     - 3-round, 5-roundよりも早く終わった

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# <img src="./resource/10_round_scalar_feature_montecarlo_trash_1224_02_47_45/initial_value_transition.png" />

# %% [markdown]
# <img src="./resource/10_round_scalar_feature_montecarlo_trash_1224_02_47_45/initial_value_transition_slimmed.png" />

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# <img src="./resource/10_round_scalar_feature_montecarlo_trash_1224_02_47_45/10_round_3000_match_subplot_1225_18_35_18.png" />

# %% [markdown]
# <img src="./resource/10_round_scalar_feature_montecarlo_trash_1224_02_47_45/10_round_3000_match_histgram_1225_18_35_18.png" />

# %% [markdown]
# # Weight analysis

# %% [markdown]
# ### 100万iteration後

# %% [raw]
# ****************************************
# After 1000000 iteration
# ****************************************
# round count
#   FOLD : -3.2566
#   CALL : -1.1882
#   MIN_RAISE : -1.1579
#   DOUBLE_RAISE : -1.6552
#   TRIPLE_RAISE : -0.5865
#   MAX_RAISE : -0.8598
# dealer button
#   FOLD : 5.733
#   CALL : 0.2623
#   MIN_RAISE : 6.1787
#   DOUBLE_RAISE : 3.9745
#   TRIPLE_RAISE : 5.4122
#   MAX_RAISE : 2.7362
# street
#   FOLD : 18.9671
#   CALL : 5.7746
#   MIN_RAISE : 23.0716
#   DOUBLE_RAISE : 19.4855
#   TRIPLE_RAISE : 19.2458
#   MAX_RAISE : 25.7719
# cards
#   FOLD : -3.8768
#   CALL : -1.268
#   MIN_RAISE : -1.2648
#   DOUBLE_RAISE : -2.5902
#   TRIPLE_RAISE : -1.8348
#   MAX_RAISE : -2.019
# pot
#   FOLD : -0.8538
#   CALL : -0.1115
#   MIN_RAISE : -0.329
#   DOUBLE_RAISE : -0.219
#   TRIPLE_RAISE : -0.0856
#   MAX_RAISE : -0.1675
# seats
#     player 0
#       stack : {'DOUBLE_RAISE': -0.0236, 'TRIPLE_RAISE': 0.0106, 'MAX_RAISE': -0.0393, 'FOLD': 0.0038, 'MIN_RAISE': -0.0244, 'CALL': 0.0061}
#       state : {'DOUBLE_RAISE': -1.0794, 'TRIPLE_RAISE': -0.4477, 'MAX_RAISE': -0.7498, 'FOLD': -3.3387, 'MIN_RAISE': -1.1079, 'CALL': -1.4968}
#       history(paid sum) : {'DOUBLE_RAISE': 0.1583, 'TRIPLE_RAISE': 0.2005, 'MAX_RAISE': 0.3108, 'FOLD': 0.8314, 'MIN_RAISE': 0.3001, 'CALL': 0.124}
#     player 1
#       stack : {'DOUBLE_RAISE': -0.0429, 'TRIPLE_RAISE': -0.0272, 'MAX_RAISE': -0.0188, 'FOLD': -0.0105, 'MIN_RAISE': 0.0298, 'CALL': 0.0031}
#       state : {'DOUBLE_RAISE': -4.0833, 'TRIPLE_RAISE': -4.5004, 'MAX_RAISE': -6.6619, 'FOLD': 15.776, 'MIN_RAISE': -3.9843, 'CALL': -0.7924}
#       history(paid sum) : {'DOUBLE_RAISE': 0.166, 'TRIPLE_RAISE': 0.0645, 'MAX_RAISE': 0.2037, 'FOLD': 0.8499, 'MIN_RAISE': 0.275, 'CALL': 0.1006}
#     player 2
#       stack : {'DOUBLE_RAISE': -0.0323, 'TRIPLE_RAISE': -0.057, 'MAX_RAISE': -0.012, 'FOLD': -0.0229, 'MIN_RAISE': -0.0228, 'CALL': 0.0085}
#       state : {'DOUBLE_RAISE': -3.3371, 'TRIPLE_RAISE': -1.138, 'MAX_RAISE': -4.1325, 'FOLD': 12.0851, 'MIN_RAISE': -0.0531, 'CALL': 1.8325}
#       history(paid sum) : {'DOUBLE_RAISE': 0.2183, 'TRIPLE_RAISE': 0.1235, 'MAX_RAISE': 0.146, 'FOLD': 0.8172, 'MIN_RAISE': 0.3395, 'CALL': 0.1251}
#     player 3
#       stack : {'DOUBLE_RAISE': 0.0201, 'TRIPLE_RAISE': -0.0405, 'MAX_RAISE': 0.0148, 'FOLD': -0.0024, 'MIN_RAISE': -0.0368, 'CALL': -0.017}
#       state : {'DOUBLE_RAISE': 3.5593, 'TRIPLE_RAISE': 1.7245, 'MAX_RAISE': 0.3886, 'FOLD': 24.4961, 'MIN_RAISE': 3.4428, 'CALL': 3.9843}
#       history(paid sum) : {'DOUBLE_RAISE': -0.7341, 'TRIPLE_RAISE': -0.5346, 'MAX_RAISE': 0.0586, 'FOLD': 0.8808, 'MIN_RAISE': 0.2184, 'CALL': 0.1148}
#     player 4
#       stack : {'DOUBLE_RAISE': -0.0009, 'TRIPLE_RAISE': -0.0172, 'MAX_RAISE': 0.0182, 'FOLD': -0.0341, 'MIN_RAISE': 0.0562, 'CALL': 0.0261}
#       state : {'DOUBLE_RAISE': -2.8457, 'TRIPLE_RAISE': -1.8149, 'MAX_RAISE': -4.2517, 'FOLD': 8.8343, 'MIN_RAISE': -0.9318, 'CALL': -4.4954}
#       history(paid sum) : {'DOUBLE_RAISE': 0.2554, 'TRIPLE_RAISE': 0.1063, 'MAX_RAISE': -0.034, 'FOLD': 0.8551, 'MIN_RAISE': 0.3779, 'CALL': 0.0713}
#     player 5
#       stack : {'DOUBLE_RAISE': -0.0343, 'TRIPLE_RAISE': -0.0157, 'MAX_RAISE': 0.0153, 'FOLD': -0.0076, 'MIN_RAISE': -0.0241, 'CALL': -0.0235}
#       state : {'DOUBLE_RAISE': 2.3881, 'TRIPLE_RAISE': 2.9651, 'MAX_RAISE': 1.0504, 'FOLD': 27.8138, 'MIN_RAISE': 4.0692, 'CALL': 5.9168}
#       history(paid sum) : {'DOUBLE_RAISE': -0.0296, 'TRIPLE_RAISE': 0.0909, 'MAX_RAISE': 0.1768, 'FOLD': 0.8329, 'MIN_RAISE': 0.1959, 'CALL': 0.0708}
#     player 6
#       stack : {'DOUBLE_RAISE': 0.0125, 'TRIPLE_RAISE': -0.0373, 'MAX_RAISE': -0.0404, 'FOLD': -0.0085, 'MIN_RAISE': 0.0173, 'CALL': 0.0079}
#       state : {'DOUBLE_RAISE': 1.7167, 'TRIPLE_RAISE': 0.982, 'MAX_RAISE': -3.855, 'FOLD': 8.9821, 'MIN_RAISE': 2.5093, 'CALL': -5.7961}
#       history(paid sum) : {'DOUBLE_RAISE': 0.1966, 'TRIPLE_RAISE': -0.1335, 'MAX_RAISE': 0.1222, 'FOLD': 0.8052, 'MIN_RAISE': 0.1286, 'CALL': 0.138}
#     player 7
#       stack : {'DOUBLE_RAISE': -0.0181, 'TRIPLE_RAISE': 0.0372, 'MAX_RAISE': 0.013, 'FOLD': 0.0124, 'MIN_RAISE': 0.0064, 'CALL': -0.0443}
#       state : {'DOUBLE_RAISE': 2.5346, 'TRIPLE_RAISE': 2.3047, 'MAX_RAISE': -0.4227, 'FOLD': 20.638, 'MIN_RAISE': 3.2311, 'CALL': -1.0073}
#       history(paid sum) : {'DOUBLE_RAISE': 0.3047, 'TRIPLE_RAISE': 0.1983, 'MAX_RAISE': 0.1401, 'FOLD': 0.8479, 'MIN_RAISE': 0.1772, 'CALL': 0.0732}
#     player 8
#       stack : {'DOUBLE_RAISE': -0.0464, 'TRIPLE_RAISE': -0.0076, 'MAX_RAISE': -0.0074, 'FOLD': 0.011, 'MIN_RAISE': -0.006, 'CALL': -0.0217}
#       state : {'DOUBLE_RAISE': 1.8234, 'TRIPLE_RAISE': 1.0714, 'MAX_RAISE': 1.7586, 'FOLD': 21.1621, 'MIN_RAISE': 2.6293, 'CALL': 1.9767}
#       history(paid sum) : {'DOUBLE_RAISE': 0.2045, 'TRIPLE_RAISE': 0.1649, 'MAX_RAISE': 0.3072, 'FOLD': 0.8512, 'MIN_RAISE': 0.2348, 'CALL': 0.0893}
#     player 9
#       stack : {'DOUBLE_RAISE': 0.0188, 'TRIPLE_RAISE': -0.0567, 'MAX_RAISE': -0.0096, 'FOLD': -0.0083, 'MIN_RAISE': -0.0171, 'CALL': -0.0238}
#       state : {'DOUBLE_RAISE': -0.7567, 'TRIPLE_RAISE': 0.4584, 'MAX_RAISE': -2.2654, 'FOLD': 18.6912, 'MIN_RAISE': -1.6509, 'CALL': -1.4315}
#       history(paid sum) : {'DOUBLE_RAISE': 0.3007, 'TRIPLE_RAISE': 0.137, 'MAX_RAISE': 0.2465, 'FOLD': 0.8544, 'MIN_RAISE': 0.1988, 'CALL': 0.1669}

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# - 100万iteration後の価値関数10人で対戦させる.
# - 必ずALLINになって,勝つ or reward=-1の負けのどちらか
#     - 小さい RAISE が全体的に続いて, ALLINが出て皆CALLする.
#     - episodeの長さが短いので,計算が早く終わったのも頷ける

# %% [markdown]
# ### ALLINにCALL

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['DQ', 'DT']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 80900, side = [{'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}, {'amount': 0, 'eligibles': ['uuid-8', 'uuid-4', 'uuid-5', 'uuid-6', 'uuid-7', 'uuid-1', 'uuid-2', 'uuid-3']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : allin, stack : 0
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9725 <= SB
#     - 2 : cpu4 (uuid-4) => state : allin, stack : 0 <= BB
#     - 3 : cpu5 (uuid-5) => state : allin, stack : 0
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 9375 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : allin, stack : 0
#     - 8 : cpu2 (uuid-2) => state : allin, stack : 0
#     - 9 : cpu3 (uuid-3) => state : allin, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 100, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 100, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 125, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 125, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 175, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 175, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 200, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 200, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 225, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 250, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu9 (uuid=uuid-9)', 'amount': 275, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 300, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 325, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 350, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 375, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'agent (uuid=uuid-0)', 'amount': 400, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 425, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 450, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 475, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 250, 'player': 'cpu8 (uuid=uuid-8)', 'amount': 500, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 525, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 550, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 575, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 600, 'action': 'RAISE'}
#       - {'add_amount': 25, 'paid': 225, 'player': 'agent (uuid=uuid-0)', 'amount': 625, 'action': 'RAISE'}
#       - {'add_amount': 9375, 'paid': 9575, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 10000, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu2 (uuid=uuid-2)', 'amount': 10000, 'paid': 9550}
#       - {'action': 'CALL', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 10000, 'paid': 9525}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 10000, 'paid': 9500}
#       - {'action': 'CALL', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 10000, 'paid': 9475}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 10000, 'paid': 9450}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'paid': 9425}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'paid': 9400}
# ======================================================================
# Agent took action [ call: 10000 (call) ] at round 1
#   => [('fold', -823.8666381835938), ('call', -328.3279113769531)]
# ** weights and features in detail **
# features : [1, 6, 0, 0.699, 9375, 1, 625, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 9725, 0, 0, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 0, 1, 10000, 80900]
# bias : [-3.2182014  -1.44997787 -0.794312   -1.38333237 -0.56915033 -0.64339095]
#
# linear combination for fold :
#     (-69074.86948370934, 80900, -0.8538302779197693, 'pot')
#     (8807.668089866638, 10000, 0.8807668089866638, 'player-3:history')
#     (8550.551533699036, 10000, 0.8550551533699036, 'player-4:history')
#     (8544.197678565979, 10000, 0.8544197678565979, 'player-9:history')
#     (8511.76142692566, 10000, 0.8511761426925659, 'player-8:history')
#     (8499.373197555542, 10000, 0.8499373197555542, 'player-1:history')
#     (8479.105830192566, 10000, 0.8479105830192566, 'player-7:history')
#     (8172.379732131958, 10000, 0.8172379732131958, 'player-2:history')
#     (8051.871657371521, 10000, 0.8051871657371521, 'player-6:history')
#     (519.6445062756538, 625, 0.8314312100410461, 'player-0:history')
#     (-74.1512962966226, 9725, -0.0076248119585216045, 'player-5:stack')
#     (36.070749774808064, 9375, 0.0038475466426461935, 'player-0:stack')
#     (34.398067474365234, 6, 5.733011245727539, 'btn distance')
#     (24.496091842651367, 1, 24.496091842651367, 'player-3:state')
#     (21.162057876586914, 1, 21.162057876586914, 'player-8:state')
#     (20.638025283813477, 1, 20.638025283813477, 'player-7:state')
#     (18.691234588623047, 1, 18.691234588623047, 'player-9:state')
#     (15.775989532470703, 1, 15.775989532470703, 'player-1:state')
#     (12.085062980651855, 1, 12.085062980651855, 'player-2:state')
#     (8.982144355773926, 1, 8.982144355773926, 'player-6:state')
#     (8.834344863891602, 1, 8.834344863891602, 'player-4:state')
#     (-3.338711977005005, 1, -3.338711977005005, 'player-0:state')
#     (-3.2566468715667725, 1, -3.2566468715667725, 'round level')
#     (-3.2182014, 0, 0, 'bias')
#     (-2.7098629102706906, 0.699, -3.8767709732055664, 'cards')
#
# linear combination for call :
#     (-9017.090515047312, 80900, -0.11145970970392227, 'pot')
#     (1668.7686741352081, 10000, 0.1668768674135208, 'player-9:history')
#     (1380.4949820041656, 10000, 0.13804949820041656, 'player-6:history')
#     (1251.0277330875397, 10000, 0.12510277330875397, 'player-2:history')
#     (1147.688403725624, 10000, 0.11476884037256241, 'player-3:history')
#     (1005.8212280273438, 10000, 0.10058212280273438, 'player-1:history')
#     (893.2358771562576, 10000, 0.08932358771562576, 'player-8:history')
#     (731.6973805427551, 10000, 0.07316973805427551, 'player-7:history')
#     (713.152289390564, 10000, 0.0713152289390564, 'player-4:history')
#     (-228.89568284153938, 9725, -0.02353683114051819, 'player-5:stack')
#     (77.48494856059551, 625, 0.12397591769695282, 'player-0:history')
#     (57.463398843538016, 9375, 0.006129429209977388, 'player-0:stack')
#     (-5.796088218688965, 1, -5.796088218688965, 'player-6:state')
#     (-4.495357990264893, 1, -4.495357990264893, 'player-4:state')
#     (3.984323501586914, 1, 3.984323501586914, 'player-3:state')
#     (1.976737380027771, 1, 1.976737380027771, 'player-8:state')
#     (1.8325247764587402, 1, 1.8325247764587402, 'player-2:state')
#     (1.5740150213241577, 6, 0.2623358368873596, 'btn distance')
#     (-1.4967817068099976, 1, -1.4967817068099976, 'player-0:state')
#     (-1.4499779, 0, 0, 'bias')
#     (-1.4314780235290527, 1, -1.4314780235290527, 'player-9:state')
#     (-1.188156008720398, 1, -1.188156008720398, 'round level')
#     (-1.0072797536849976, 1, -1.0072797536849976, 'player-7:state')
#     (-0.8863244218826294, 0.699, -1.267989158630371, 'cards')
#     (-0.79238361120224, 1, -0.79238361120224, 'player-1:state')

# %% [markdown]
# ### ALLINする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 5700
#   - raise: [9825, 58350]
# -- hole card --
#   - ['C8', 'D2']
# -- round state --
#   - dealer btn : cpu6
#   - street : preflop
#   - community card : []
#   - pot : main = 10000, side = [{'amount': 1850, 'eligibles': ['uuid-5']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 775
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 0
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 7200
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 3025
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 2200
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0 <= SB
#     - 6 : agent (uuid-0) => state : participating, stack : 58300 <= BB, CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 7600
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 8500
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 550
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 75, 'action': 'RAISE'}
#       - {'add_amount': 225, 'paid': 300, 'player': 'cpu3 (uuid=uuid-3)', 'amount': 300, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 300, 'paid': 300}
#       - {'add_amount': 1275, 'paid': 1575, 'player': 'cpu4 (uuid=uuid-4)', 'amount': 1575, 'action': 'RAISE'}
#       - {'add_amount': 4125, 'paid': 5700, 'player': 'cpu5 (uuid=uuid-5)', 'amount': 5700, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 3850, 'paid': 3825}
# ======================================================================
# Agent took action [ raise: 58350 (max_raise) ] at round 5
#   => [('fold', -1018.6587524414062), ('call', -487.76824951171875), ('min_raise', -1119.937255859375), ('double_raise', -2167.72802734375), ('triple_raise', -1266.1138916015625), ('max_raise', -478.5093688964844)]
# ** weights and features in detail **
# features : [1, 2, 0, 0.538, 58300, 1, 50, 7600, 0, 0, 8500, 1, 75, 550, 1, 300, 775, 1, 300, 0, 0, 0, 7200, 1, 1575, 3025, 1, 5700, 2200, 0, 0, 0, 1, 3850, 11850]
# bias : [-1.94632328 -1.49570858 -1.19680524 -1.50724602 -0.86452085 -0.25888935]
#
# linear combination for fold :
#     (-4369.067779183388, 11850, -0.3686977028846741, 'pot')
#     (2129.552310705185, 5700, 0.3736056685447693, 'player-7:history')
#     (1395.206592977047, 3850, 0.36239132285118103, 'player-9:history')
#     (-1148.8053744658828, 58300, -0.019705066457390785, 'player-0:stack')
#     (588.8483718037605, 1575, 0.37387198209762573, 'player-6:history')
#     (116.66505932807922, 300, 0.3888835310935974, 'player-4:history')
#     (116.02380573749542, 300, 0.38674601912498474, 'player-3:history')
#     (100.1325435936451, 8500, 0.011780299246311188, 'player-2:stack')
#     (-94.52041387557983, 7600, -0.012436896562576294, 'player-1:stack')
#     (29.934433847665787, 75, 0.3991257846355438, 'player-2:history')
#     (23.2318058013916, 1, 23.2318058013916, 'player-4:state')
#     (22.945405960083008, 1, 22.945405960083008, 'player-2:state')
#     (22.71958351135254, 1, 22.71958351135254, 'player-7:state')
#     (21.000396728515625, 1, 21.000396728515625, 'player-3:state')
#     (20.43222486972809, 50, 0.40864449739456177, 'player-0:history')
#     (20.06359100341797, 1, 20.06359100341797, 'player-9:state')
#     (17.25283432006836, 2, 8.62641716003418, 'btn distance')
#     (16.5665283203125, 1, 16.5665283203125, 'player-6:state')
#     (-15.283568622544408, 3025, -0.005052419379353523, 'player-7:stack')
#     (-14.501255052164197, 775, -0.01871129684150219, 'player-4:stack')
#     (-4.197256499901414, 2200, -0.0019078438635915518, 'player-8:stack')
#     (-4.00025867857039, 7200, -0.0005555914831347764, 'player-6:stack')
#     (-2.1022517466917634, 550, -0.0038222759030759335, 'player-3:stack')
#     (-1.9774525165557861, 1, -1.9774525165557861, 'round level')
#     (-1.9463233, 0, 0, 'bias')
#     (-1.5801805257797241, 1, -1.5801805257797241, 'player-0:state')
#     (-1.2521744050979615, 0.538, -2.3274617195129395, 'cards')
#
# linear combination for call :
#     (-401.7853243276477, 11850, -0.033905934542417526, 'pot')
#     (-390.429453458637, 58300, -0.006696903146803379, 'player-0:stack')
#     (106.9124330766499, 3850, 0.027769463136792183, 'player-9:history')
#     (69.56731528043747, 7200, 0.009662127122282982, 'player-6:stack')
#     (65.94500625506043, 1575, 0.04186984524130821, 'player-6:history')
#     (55.75817935168743, 7600, 0.007336602546274662, 'player-1:stack')
#     (25.959823047742248, 8500, 0.0030540968291461468, 'player-2:stack')
#     (-21.07343953102827, 2200, -0.009578836150467396, 'player-8:stack')
#     (-16.021165740676224, 5700, -0.002810730831697583, 'player-7:history')
#     (-15.329923667013645, 3025, -0.005067743360996246, 'player-7:stack')
#     (9.72823016345501, 300, 0.032427433878183365, 'player-3:history')
#     (-8.19458074402064, 775, -0.01057365257292986, 'player-4:stack')
#     (7.534802436828613, 1, 7.534802436828613, 'player-2:state')
#     (7.502329163253307, 300, 0.025007763877511024, 'player-4:history')
#     (7.421785354614258, 2, 3.710892677307129, 'btn distance')
#     (4.340573310852051, 1, 4.340573310852051, 'player-3:state')
#     (4.274597644805908, 1, 4.274597644805908, 'player-4:state')
#     (3.63501850515604, 75, 0.048466913402080536, 'player-2:history')
#     (2.1664085388183594, 1, 2.1664085388183594, 'player-7:state')
#     (-1.880349323619157, 550, -0.003418816952034831, 'player-3:stack')
#     (-1.7509422302246094, 1, -1.7509422302246094, 'round level')
#     (-1.639702320098877, 1, -1.639702320098877, 'player-0:state')
#     (1.5957921743392944, 50, 0.03191584348678589, 'player-0:history')
#     (-1.4957086, 0, 0, 'bias')
#     (-0.5106062854528427, 0.538, -0.9490823149681091, 'cards')
#
# linear combination for min_raise :
#     (-4256.90141916275, 11850, -0.35923218727111816, 'pot')
#     (2074.8694360256195, 5700, 0.3640121817588806, 'player-7:history')
#     (1341.3131386041641, 3850, 0.3483930230140686, 'player-9:history')
#     (-751.6716007143259, 58300, -0.01289316639304161, 'player-0:stack')
#     (541.0201326012611, 1575, 0.3435048460960388, 'player-6:history')
#     (-168.11271663755178, 8500, -0.019777966663241386, 'player-2:stack')
#     (91.28968119621277, 300, 0.30429893732070923, 'player-3:history')
#     (-89.60546730086207, 3025, -0.02962164208292961, 'player-7:stack')
#     (73.23754280805588, 300, 0.2441251426935196, 'player-4:history')
#     (-40.5657397583127, 7600, -0.005337597336620092, 'player-1:stack')
#     (25.41983127593994, 75, 0.3389310836791992, 'player-2:history')
#     (18.4564471244812, 2200, 0.008389294147491455, 'player-8:stack')
#     (-16.550835594534874, 7200, -0.0022987271659076214, 'player-6:stack')
#     (-14.371228590607643, 550, -0.026129506528377533, 'player-3:stack')
#     (14.195284247398376, 50, 0.28390568494796753, 'player-0:history')
#     (12.812004191800952, 775, 0.01653161831200123, 'player-4:stack')
#     (8.774198532104492, 1, 8.774198532104492, 'player-3:state')
#     (5.662459850311279, 2, 2.8312299251556396, 'btn distance')
#     (5.184709548950195, 1, 5.184709548950195, 'player-2:state')
#     (4.530365943908691, 1, 4.530365943908691, 'player-7:state')
#     (3.5040369033813477, 1, 3.5040369033813477, 'player-6:state')
#     (1.2630248069763184, 1, 1.2630248069763184, 'player-4:state')
#     (-1.258048176765442, 1, -1.258048176765442, 'player-0:state')
#     (-1.1968052, 0, 0, 'bias')
#     (-1.1825795159339905, 0.538, -2.198103189468384, 'cards')
#     (-0.9077081680297852, 1, -0.9077081680297852, 'round level')
#     (0.8546848297119141, 1, 0.8546848297119141, 'player-9:state')
#
# linear combination for double_raise :
#     (-3059.7867742180824, 11850, -0.25820985436439514, 'pot')
#     (1213.2524147629738, 5700, 0.21285130083560944, 'player-7:history')
#     (-706.1836261302233, 58300, -0.012112926691770554, 'player-0:stack')
#     (289.5039349794388, 1575, 0.18381202220916748, 'player-6:history')
#     (170.69300655275583, 3850, 0.04433584585785866, 'player-9:history')
#     (-118.90823859721422, 8500, -0.013989204540848732, 'player-2:stack')
#     (-111.67048327624798, 7600, -0.014693484641611576, 'player-1:stack')
#     (73.41999113559723, 300, 0.2447333037853241, 'player-3:history')
#     (63.0194216966629, 300, 0.21006473898887634, 'player-4:history')
#     (-55.29757319018245, 3025, -0.018280189484357834, 'player-7:stack')
#     (13.949135597795248, 7200, 0.001937379944138229, 'player-6:stack')
#     (13.057364523410797, 50, 0.26114729046821594, 'player-0:history')
#     (12.035689875483513, 75, 0.16047586500644684, 'player-2:history')
#     (-11.710872198455036, 775, -0.015110802836716175, 'player-4:stack')
#     (9.178776741027832, 2, 4.589388370513916, 'btn distance')
#     (8.75470619648695, 550, 0.015917647629976273, 'player-3:stack')
#     (8.47929573059082, 1, 8.47929573059082, 'player-3:state')
#     (7.827791245654225, 2200, 0.0035580869298428297, 'player-8:stack')
#     (5.384831428527832, 1, 5.384831428527832, 'player-2:state')
#     (5.198060989379883, 1, 5.198060989379883, 'player-7:state')
#     (3.292711019515991, 1, 3.292711019515991, 'player-6:state')
#     (2.042097568511963, 1, 2.042097568511963, 'player-4:state')
#     (1.8545644283294678, 1, 1.8545644283294678, 'player-9:state')
#     (-1.507246, 0, 0, 'bias')
#     (-1.2865926027297974, 1, -1.2865926027297974, 'round level')
#     (-1.1620986452102662, 0.538, -2.160034656524658, 'cards')
#     (-1.1580846309661865, 1, -1.1580846309661865, 'player-0:state')
#
# linear combination for triple_raise :
#     (-2053.9312943816185, 11850, -0.17332753539085388, 'pot')
#     (747.3790526390076, 5700, 0.13111913204193115, 'player-7:history')
#     (-401.65848545730114, 58300, -0.006889510899782181, 'player-0:stack')
#     (350.1778557896614, 3850, 0.09095528721809387, 'player-9:history')
#     (-291.85670241713524, 8500, -0.03433608263731003, 'player-2:stack')
#     (209.72729735076427, 1575, 0.13316018879413605, 'player-6:history')
#     (72.7652508765459, 7600, 0.009574375115334988, 'player-1:stack')
#     (46.00621461868286, 300, 0.15335404872894287, 'player-3:history')
#     (-45.76422572135925, 7200, -0.006356142461299896, 'player-6:stack')
#     (32.07937404513359, 300, 0.10693124681711197, 'player-4:history')
#     (23.983622202649713, 3025, 0.007928470149636269, 'player-7:stack')
#     (-20.067263022065163, 2200, -0.009121483191847801, 'player-8:stack')
#     (16.763191064819694, 775, 0.021629923954606056, 'player-4:stack')
#     (10.639339447021484, 2, 5.319669723510742, 'btn distance')
#     (8.726651966571808, 75, 0.11635535955429077, 'player-2:history')
#     (8.00973129272461, 1, 8.00973129272461, 'player-3:state')
#     (6.552299976348877, 1, 6.552299976348877, 'player-7:state')
#     (6.530885398387909, 50, 0.13061770796775818, 'player-0:history')
#     (5.271271705627441, 1, 5.271271705627441, 'player-2:state')
#     (-4.121189960278571, 550, -0.007493072655051947, 'player-3:stack')
#     (3.374154567718506, 1, 3.374154567718506, 'player-6:state')
#     (3.213885545730591, 1, 3.213885545730591, 'player-4:state')
#     (2.908301830291748, 1, 2.908301830291748, 'player-9:state')
#     (-0.9350600838661194, 1, -0.9350600838661194, 'round level')
#     (-0.86452085, 0, 0, 'bias')
#     (-0.5347295203208924, 0.538, -0.9939210414886475, 'cards')
#     (-0.4885573983192444, 1, -0.4885573983192444, 'player-0:state')
#
# linear combination for max_raise :
#     (-6653.460842370987, 11850, -0.5614734888076782, 'pot')
#     (3435.1039052009583, 5700, 0.6026498079299927, 'player-7:history')
#     (1922.0446690917015, 3850, 0.49923238158226013, 'player-9:history')
#     (835.1841375231743, 1575, 0.5302756428718567, 'player-6:history')
#     (-258.28178226947784, 7600, -0.03398444503545761, 'player-1:stack')
#     (-222.11785707622766, 8500, -0.026131512597203255, 'player-2:stack')
#     (162.56209015846252, 300, 0.5418736338615417, 'player-3:history')
#     (158.05490612983704, 300, 0.5268496870994568, 'player-4:history')
#     (156.22611821163446, 58300, 0.002679693279787898, 'player-0:stack')
#     (-48.62963296473026, 7200, -0.00675411568954587, 'player-6:stack')
#     (42.02851206064224, 75, 0.5603801608085632, 'player-2:history')
#     (-28.729934757575393, 3025, -0.009497499093413353, 'player-7:stack')
#     (28.66290509700775, 50, 0.573258101940155, 'player-0:history')
#     (-5.854404391720891, 550, -0.010644371621310711, 'player-3:stack')
#     (4.552662908099592, 775, 0.00587440375238657, 'player-4:stack')
#     (-2.9232592582702637, 1, -2.9232592582702637, 'player-2:state')
#     (2.644378662109375, 1, 2.644378662109375, 'player-7:state')
#     (-2.2911376552656293, 2200, -0.0010414262069389224, 'player-8:stack')
#     (-1.8168439865112305, 1, -1.8168439865112305, 'player-9:state')
#     (1.0194135904312134, 1, 1.0194135904312134, 'player-3:state')
#     (-0.5749073624610901, 1, -0.5749073624610901, 'round level')
#     (-0.5356515049934387, 2, -0.26782575249671936, 'btn distance')
#     (-0.5277604625225067, 0.538, -0.9809674024581909, 'cards')
#     (-0.25888935, 0, 0, 'bias')
#     (-0.24058279395103455, 1, -0.24058279395103455, 'player-4:state')
#     (-0.1794799268245697, 1, -0.1794799268245697, 'player-6:state')
#     (-0.17007818818092346, 1, -0.17007818818092346, 'player-0:state')

# %% [markdown]
# ### FOLDする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 150
#   - raise: [250, 7600]
# -- hole card --
#   - ['C7', 'D2']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 2275
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 2275
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 2275
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 2250 <= SB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 14225 <= BB
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 8650
#     - 6 : agent (uuid-0) => state : participating, stack : 7600 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 2275
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 55675
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 2275
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 150, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 3
#   => [('fold', 658.5487670898438), ('call', -15.484082221984863), ('min_raise', -1362.634033203125), ('double_raise', -1233.899169921875), ('triple_raise', -2021.5379638671875), ('max_raise', -1711.5877685546875)]
# ** weights and features in detail **
# features : [1, 4, 0, 0.558, 7600, 1, 0, 2275, 1, 0, 55675, 1, 0, 2275, 1, 0, 2275, 1, 0, 2275, 1, 0, 2275, 1, 0, 2250, 1, 25, 14225, 1, 50, 8650, 1, 150, 225]
# bias : [-1.94632328 -1.49570858 -1.19680524 -1.50724602 -0.86452085 -0.25888935]
#
# linear combination for fold :
#     (655.8681605383754, 55675, 0.011780299246311188, 'player-2:stack')
#     (-149.75850507616997, 7600, -0.019705066457390785, 'player-0:stack')
#     (-82.95698314905167, 225, -0.3686977028846741, 'pot')
#     (54.358698427677155, 150, 0.36239132285118103, 'player-9:history')
#     (-42.56820031441748, 2275, -0.01871129684150219, 'player-4:stack')
#     (34.64281463623047, 1, 34.64281463623047, 'player-1:state')
#     (34.50566864013672, 4, 8.62641716003418, 'btn distance')
#     (29.19172670226544, 8650, 0.00337476609274745, 'player-9:stack')
#     (-28.29393967986107, 2275, -0.012436896562576294, 'player-1:stack')
#     (-27.139078959589824, 14225, -0.0019078438635915518, 'player-8:stack')
#     (24.816875457763672, 1, 24.816875457763672, 'player-8:state')
#     (23.2318058013916, 1, 23.2318058013916, 'player-4:state')
#     (22.945405960083008, 1, 22.945405960083008, 'player-2:state')
#     (22.71958351135254, 1, 22.71958351135254, 'player-7:state')
#     (21.000396728515625, 1, 21.000396728515625, 'player-3:state')
#     (20.55794334411621, 1, 20.55794334411621, 'player-5:state')
#     (20.06359100341797, 1, 20.06359100341797, 'player-9:state')
#     (18.379920721054077, 50, 0.36759841442108154, 'player-8:history')
#     (16.5665283203125, 1, 16.5665283203125, 'player-6:state')
#     (-11.367943603545427, 2250, -0.005052419379353523, 'player-7:stack')
#     (9.340141713619232, 25, 0.3736056685447693, 'player-7:history')
#     (9.206459589768201, 2275, 0.0040467954240739346, 'player-5:stack')
#     (-8.695677679497749, 2275, -0.0038222759030759335, 'player-3:stack')
#     (-1.9774525165557861, 1, -1.9774525165557861, 'round level')
#     (-1.9463233, 0, 0, 'bias')
#     (-1.5801805257797241, 1, -1.5801805257797241, 'player-0:state')
#     (-1.2987236394882202, 0.558, -2.3274617195129395, 'cards')
#     (-1.2639706241316162, 2275, -0.0005555914831347764, 'player-6:stack')
#
# linear combination for call :
#     (170.03684096271172, 55675, 0.0030540968291461468, 'player-2:stack')
#     (-136.2589442403987, 14225, -0.009578836150467396, 'player-8:stack')
#     (-50.89646391570568, 7600, -0.006696903146803379, 'player-0:stack')
#     (-41.6925763245672, 8650, -0.004819951020181179, 'player-9:stack')
#     (-24.05505960341543, 2275, -0.01057365257292986, 'player-4:stack')
#     (21.981339203193784, 2275, 0.009662127122282982, 'player-6:stack')
#     (16.690770792774856, 2275, 0.007336602546274662, 'player-1:stack')
#     (14.843570709228516, 4, 3.710892677307129, 'btn distance')
#     (12.875012397766113, 1, 12.875012397766113, 'player-1:state')
#     (-11.402422562241554, 2250, -0.005067743360996246, 'player-7:stack')
#     (-7.777808565879241, 2275, -0.003418816952034831, 'player-3:stack')
#     (-7.628835272043943, 225, -0.033905934542417526, 'pot')
#     (7.534802436828613, 1, 7.534802436828613, 'player-2:state')
#     (4.340573310852051, 1, 4.340573310852051, 'player-3:state')
#     (4.274597644805908, 1, 4.274597644805908, 'player-4:state')
#     (4.165419470518827, 150, 0.027769463136792183, 'player-9:history')
#     (3.3469626903533936, 1, 3.3469626903533936, 'player-5:state')
#     (3.297353744506836, 1, 3.297353744506836, 'player-8:state')
#     (2.3801730945706367, 50, 0.047603461891412735, 'player-8:history')
#     (2.1664085388183594, 1, 2.1664085388183594, 'player-7:state')
#     (1.779786175757181, 2275, 0.0007823235937394202, 'player-5:stack')
#     (-1.7509422302246094, 1, -1.7509422302246094, 'round level')
#     (-1.639702320098877, 1, -1.639702320098877, 'player-0:state')
#     (-1.4957086, 0, 0, 'bias')
#     (-0.529587931752205, 0.558, -0.9490823149681091, 'cards')
#     (0.4143158197402954, 1, 0.4143158197402954, 'player-6:state')
#     (-0.4136908948421478, 1, -0.4136908948421478, 'player-9:state')
#     (-0.07026827079243958, 25, -0.002810730831697583, 'player-7:history')
#
# linear combination for min_raise :
#     (-1101.1382939759642, 55675, -0.019777966663241386, 'player-2:stack')
#     (-214.1822366975248, 8650, -0.024760952219367027, 'player-9:stack')
#     (119.33770924806595, 14225, 0.008389294147491455, 'player-8:stack')
#     (-97.98806458711624, 7600, -0.01289316639304161, 'player-0:stack')
#     (-80.82724213600159, 225, -0.35923218727111816, 'pot')
#     (-66.64869468659163, 2250, -0.02962164208292961, 'player-7:stack')
#     (-59.44462735205889, 2275, -0.026129506528377533, 'player-3:stack')
#     (52.25895345211029, 150, 0.3483930230140686, 'player-9:history')
#     (37.609431659802794, 2275, 0.01653161831200123, 'player-4:stack')
#     (15.04376232624054, 50, 0.3008752465248108, 'player-8:history')
#     (-12.14303394081071, 2275, -0.005337597336620092, 'player-1:stack')
#     (11.324919700622559, 4, 2.8312299251556396, 'btn distance')
#     (9.100304543972015, 25, 0.3640121817588806, 'player-7:history')
#     (8.852386474609375, 1, 8.852386474609375, 'player-1:state')
#     (8.774198532104492, 1, 8.774198532104492, 'player-3:state')
#     (-5.229604302439839, 2275, -0.0022987271659076214, 'player-6:stack')
#     (5.184709548950195, 1, 5.184709548950195, 'player-2:state')
#     (4.530365943908691, 1, 4.530365943908691, 'player-7:state')
#     (4.414352893829346, 1, 4.414352893829346, 'player-5:state')
#     (3.5040369033813477, 1, 3.5040369033813477, 'player-6:state')
#     (-2.456023686681874, 2275, -0.0010795708512887359, 'player-5:stack')
#     (1.2630248069763184, 1, 1.2630248069763184, 'player-4:state')
#     (-1.258048176765442, 1, -1.258048176765442, 'player-0:state')
#     (-1.2265415797233583, 0.558, -2.198103189468384, 'cards')
#     (-1.1968052, 0, 0, 'bias')
#     (-0.9077081680297852, 1, -0.9077081680297852, 'round level')
#     (0.8546848297119141, 1, 0.8546848297119141, 'player-9:state')
#     (-0.0399356335401535, 1, -0.0399356335401535, 'player-8:state')
#
# linear combination for double_raise :
#     (-778.8489628117532, 55675, -0.013989204540848732, 'player-2:stack')
#     (-309.9573288112879, 8650, -0.035833217203617096, 'player-9:stack')
#     (-92.05824285745621, 7600, -0.012112926691770554, 'player-0:stack')
#     (-58.09721723198891, 225, -0.25820985436439514, 'pot')
#     (-52.72387764416635, 2275, -0.023175330832600594, 'player-5:stack')
#     (50.61378657701425, 14225, 0.0035580869298428297, 'player-8:stack')
#     (-41.130426339805126, 2250, -0.018280189484357834, 'player-7:stack')
#     (36.21264835819602, 2275, 0.015917647629976273, 'player-3:stack')
#     (-34.3770764535293, 2275, -0.015110802836716175, 'player-4:stack')
#     (-33.427677559666336, 2275, -0.014693484641611576, 'player-1:stack')
#     (18.357553482055664, 4, 4.589388370513916, 'btn distance')
#     (12.311448901891708, 50, 0.24622897803783417, 'player-8:history')
#     (8.47929573059082, 1, 8.47929573059082, 'player-3:state')
#     (8.474353790283203, 1, 8.474353790283203, 'player-1:state')
#     (6.650376878678799, 150, 0.04433584585785866, 'player-9:history')
#     (5.384831428527832, 1, 5.384831428527832, 'player-2:state')
#     (5.321282520890236, 25, 0.21285130083560944, 'player-7:history')
#     (5.198060989379883, 1, 5.198060989379883, 'player-7:state')
#     (4.407539372914471, 2275, 0.001937379944138229, 'player-6:stack')
#     (3.292711019515991, 1, 3.292711019515991, 'player-6:state')
#     (3.158712387084961, 1, 3.158712387084961, 'player-5:state')
#     (2.042097568511963, 1, 2.042097568511963, 'player-4:state')
#     (1.8545644283294678, 1, 1.8545644283294678, 'player-9:state')
#     (-1.507246, 0, 0, 'bias')
#     (-1.2865926027297974, 1, -1.2865926027297974, 'round level')
#     (-1.2052993383407593, 0.558, -2.160034656524658, 'cards')
#     (-1.1580846309661865, 1, -1.1580846309661865, 'player-0:state')
#     (0.11936622112989426, 1, 0.11936622112989426, 'player-8:state')
#
# linear combination for triple_raise :
#     (-1911.6614008322358, 55675, -0.03433608263731003, 'player-2:stack')
#     (-129.75309840403497, 14225, -0.009121483191847801, 'player-8:stack')
#     (-76.55336889438331, 8650, -0.008850100450217724, 'player-9:stack')
#     (-52.360282838344574, 7600, -0.006889510899782181, 'player-0:stack')
#     (49.20807699672878, 2275, 0.021629923954606056, 'player-4:stack')
#     (47.92555836029351, 2275, 0.021066179499030113, 'player-5:stack')
#     (-38.99869546294212, 225, -0.17332753539085388, 'pot')
#     (21.781703387387097, 2275, 0.009574375115334988, 'player-1:stack')
#     (21.27867889404297, 4, 5.319669723510742, 'btn distance')
#     (17.839057836681604, 2250, 0.007928470149636269, 'player-7:stack')
#     (-17.04674029024318, 2275, -0.007493072655051947, 'player-3:stack')
#     (-14.460224099457264, 2275, -0.006356142461299896, 'player-6:stack')
#     (13.64329308271408, 150, 0.09095528721809387, 'player-9:history')
#     (8.00973129272461, 1, 8.00973129272461, 'player-3:state')
#     (7.567593574523926, 1, 7.567593574523926, 'player-1:state')
#     (7.033907622098923, 50, 0.14067815244197845, 'player-8:history')
#     (6.552299976348877, 1, 6.552299976348877, 'player-7:state')
#     (5.271271705627441, 1, 5.271271705627441, 'player-2:state')
#     (3.820591688156128, 1, 3.820591688156128, 'player-5:state')
#     (3.374154567718506, 1, 3.374154567718506, 'player-6:state')
#     (3.277978301048279, 25, 0.13111913204193115, 'player-7:history')
#     (3.213885545730591, 1, 3.213885545730591, 'player-4:state')
#     (2.908301830291748, 1, 2.908301830291748, 'player-9:state')
#     (-0.9350600838661194, 1, -0.9350600838661194, 'round level')
#     (-0.86452085, 0, 0, 'bias')
#     (-0.5676905512809753, 1, -0.5676905512809753, 'player-8:state')
#     (-0.5546079411506654, 0.558, -0.9939210414886475, 'cards')
#     (-0.4885573983192444, 1, -0.4885573983192444, 'player-0:state')
#
# linear combination for max_raise :
#     (-1454.8719638492912, 55675, -0.026131512597203255, 'player-2:stack')
#     (-126.3315349817276, 225, -0.5614734888076782, 'pot')
#     (-87.9887277726084, 8650, -0.010172107256948948, 'player-9:stack')
#     (-77.31461245566607, 2275, -0.03398444503545761, 'player-1:stack')
#     (74.88485723733902, 150, 0.49923238158226013, 'player-9:history')
#     (-37.97622271813452, 2275, -0.01669284515082836, 'player-5:stack')
#     (25.75715184211731, 50, 0.5151430368423462, 'player-8:history')
#     (-24.215945438481867, 2275, -0.010644371621310711, 'player-3:stack')
#     (-21.369372960180044, 2250, -0.009497499093413353, 'player-7:stack')
#     (20.365668926388025, 7600, 0.002679693279787898, 'player-0:stack')
#     (-15.365613193716854, 2275, -0.00675411568954587, 'player-6:stack')
#     (15.066245198249817, 25, 0.6026498079299927, 'player-7:history')
#     (-14.814287793706171, 14225, -0.0010414262069389224, 'player-8:stack')
#     (13.364268536679447, 2275, 0.00587440375238657, 'player-4:stack')
#     (3.9071714878082275, 1, 3.9071714878082275, 'player-1:state')
#     (-2.9232592582702637, 1, -2.9232592582702637, 'player-2:state')
#     (2.644378662109375, 1, 2.644378662109375, 'player-7:state')
#     (-1.8168439865112305, 1, -1.8168439865112305, 'player-9:state')
#     (-1.2440648078918457, 1, -1.2440648078918457, 'player-8:state')
#     (-1.0713030099868774, 4, -0.26782575249671936, 'btn distance')
#     (1.0194135904312134, 1, 1.0194135904312134, 'player-3:state')
#     (0.6782481670379639, 1, 0.6782481670379639, 'player-5:state')
#     (-0.5749073624610901, 1, -0.5749073624610901, 'round level')
#     (-0.5473798105716706, 0.558, -0.9809674024581909, 'cards')
#     (-0.25888935, 0, 0, 'bias')
#     (-0.24058279395103455, 1, -0.24058279395103455, 'player-4:state')
#     (-0.1794799268245697, 1, -0.1794799268245697, 'player-6:state')
#     (-0.17007818818092346, 1, -0.17007818818092346, 'player-0:state')
