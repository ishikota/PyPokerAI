# %% [markdown]
# # 実験1 とりあえず走らせてみて観察
# ## 2-round poker

# %% [markdown]
# # Training detail
# - algorithm : montecarlo
# - training length : 50万x2=100万
# - 5万iteration毎に敵のvalue_functionを最新(agentと同じ重み)に更新しながらself-play
# - 計算時間 : 73062s + 80269s => 20.2h + 22.3h

# %% [markdown]
# # Initial Value Transition

# %% [markdown]
# ### 0~50万

# %% [markdown]
# <img src="./resource/3round_montecarlo_first_run_1217_00_56_10/initial_value_transition.png" width=500/>

# %% [markdown]
# ### 50万~100万

# %% [markdown]
# <img src="./resource/3round_montecarlo_after_500000_training_1217_22_49_34/initial_value_transition.png" width=500/>

# %% [markdown]
# # Round-robin match result

# %% [markdown]
# ### 0~50万

# %% [markdown]
# <img src="./resource/3round_montecarlo_first_run_1217_00_56_10/3_round_3000_match_subplot_1219_17_48_41.png"/>

# %% [markdown]
# ### 50~100万

# %% [markdown]
# <img src="./resource/3round_montecarlo_after_500000_training_1217_22_49_34/3_round_3000_match_subplot_1219_18_20_03.png" />

# %% [markdown]
# ## 0~100万

# %% [markdown]
# <img src="./resource/3round_montecarlo_summary/3_round_3000_match_subplot_1219_18_23_33.png" />

# %% [markdown]
# # Watch game in detail

# %% [markdown]
# ### 50万iteration後のvalue function10人で対戦
# 1roundは,double raise => fold

# %% [markdown]
# ### DOUBLE RAISE する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 150
#   - raise: [250, 10000]
# -- hole card --
#   - ['CT', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9850
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 500 (double_raise) ] at round 1
#   => [('fold', 0.3072561025619507), ('call', -0.016020774841308594), ('min_raise', 0.28197336196899414), ('double_raise', 0.41495275497436523), ('triple_raise', 0.2835264205932617), ('max_raise', 0.2574824094772339)]
# ** weights and features in detail **
# bias : [-1.55898881 -1.67052042 -2.22016835 -2.0899353  -2.10360384 -1.67133498]
#
# linear combination for fold :
#     (2.9704649448394775, 1, 2.9704649448394775, 'street-preflop')
#     (-1.5589888, 0, 0, 'bias')
#     (-1.5441920757293701, 1, -1.5441920757293701, 'player-0:state-active')
#     (-1.4612571001052856, 1, -1.4612571001052856, 'round level 2')
#     (0.7291356921195984, 1, 0.7291356921195984, 'btn distance=6')
#     (0.6810815334320068, 1, 0.6810815334320068, 'player-9:state-fold')
#     (0.3590715726216634, 0.6666666666666666, 0.5386073589324951, 'player-8:history')
#     (0.25149619579315186, 1, 0.25149619579315186, 'player-2:state-active')
#     (0.24464909235636392, 0.1111111111111111, 2.2018418312072754, 'player-5:history')
#     (0.20635151863098145, 1, 0.20635151863098145, 'player-4:state-active')
#     (0.1839430332183838, 1, 0.1839430332183838, 'player-6:state-active')
#     (-0.1669168919324875, 1, -0.1669168919324875, 'player-8:state-active')
#     (0.1662919670343399, 1, 0.1662919670343399, 'player-1:state-active')
#     (-0.16613179588317872, 0.0995, -1.6696662902832031, 'player-6:stack')
#     (-0.15515435934066774, 0.1, -1.5515435934066772, 'player-7:stack')
#     (-0.14752224683761597, 0.1, -1.4752224683761597, 'player-3:stack')
#     (0.13138611614704132, 1, 0.13138611614704132, 'player-5:state-active')
#     (-0.12465298175811768, 0.1, -1.2465298175811768, 'player-4:stack')
#     (-0.11465718746185304, 0.1, -1.1465718746185303, 'player-2:stack')
#     (0.1051850120226542, 0.2222222222222222, 0.47333255410194397, 'player-6:history')
#     (-0.07128117680549621, 0.1, -0.7128117680549622, 'player-9:stack')
#     (-0.06994461759924889, 0.09975, -0.7011991739273071, 'player-5:stack')
#     (-0.06426747819781303, 0.0985, -0.6524617075920105, 'player-8:stack')
#     (-0.0627477526664734, 0.1, -0.6274775266647339, 'player-1:stack')
#     (-0.03917863592505455, 1, -0.03917863592505455, 'player-7:state-fold')
#     (0.01845618933439255, 0.1, 0.18456189334392548, 'player-0:stack')
#     (0.008200302720069885, 1, 0.008200302720069885, 'player-3:state-active')
#     (-0.002216987773776054, 0.00225, -0.9853278994560242, 'pot')
#     (0.0006529669667361304, 0.663, 0.000984867219813168, 'cards')
#     (0.0, 0.0, 0.7250006198883057, 'player-9:history')
#     (0.0, 0, 0.632540762424469, 'player-9:state-active')
#     (-0.0, 0, -0.22895732522010803, 'player-8:state-fold')
#     (0.0, 0.0, 0.24329331517219543, 'player-7:history')
#     (-0.0, 0, -0.0930999219417572, 'player-7:state-active')
#     (0.0, 0, 0.30152055621147156, 'player-6:state-fold')
#     (0.0, 0, 0.14345857501029968, 'player-5:state-fold')
#     (0.0, 0.0, 0.7096555829048157, 'player-4:history')
#     (0.0, 0, 0.3477531671524048, 'player-4:state-fold')
#     (0.0, 0.0, 0.38791540265083313, 'player-3:history')
#     (-0.0, 0, -0.05360166355967522, 'player-3:state-fold')
#     (0.0, 0.0, 0.17896975576877594, 'player-2:history')
#     (0.0, 0, 0.17204277217388153, 'player-2:state-fold')
#     (0.0, 0.0, 0.3307403028011322, 'player-1:history')
#     (0.0, 0, 0.19814316928386688, 'player-1:state-fold')
#     (0.0, 0.0, 0.288990318775177, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 2.4131579399108887, 'street-river')
#     (0.0, 0, 2.957214593887329, 'street-turn')
#     (0.0, 0, 2.995706558227539, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 0.7153593301773071, 'btn distance=5')
#     (0.0, 0, 0.8408181667327881, 'btn distance=4')
#     (0.0, 0, 0.11172295361757278, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.10479549318552017, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (2.2067880630493164, 1, 2.2067880630493164, 'btn distance=6')
#     (-1.6705204, 0, 0, 'bias')
#     (-1.565030813217163, 1, -1.565030813217163, 'player-0:state-active')
#     (-1.4174758195877075, 1, -1.4174758195877075, 'round level 2')
#     (0.6621841788291931, 1, 0.6621841788291931, 'street-preflop')
#     (0.5947113037109375, 1, 0.5947113037109375, 'player-9:state-fold')
#     (0.5145376920700073, 1, 0.5145376920700073, 'player-1:state-active')
#     (0.5064280827840169, 0.1111111111111111, 4.557852745056152, 'player-5:history')
#     (0.3658600250879923, 0.6666666666666666, 0.5487900376319885, 'player-8:history')
#     (0.31320011615753174, 1, 0.31320011615753174, 'player-8:state-active')
#     (-0.26677846908569336, 1, -0.26677846908569336, 'player-3:state-active')
#     (0.23857755938172343, 0.663, 0.35984548926353455, 'cards')
#     (0.22495703399181366, 1, 0.22495703399181366, 'player-7:state-fold')
#     (0.2243090718984604, 1, 0.2243090718984604, 'player-2:state-active')
#     (-0.19515249133110046, 1, -0.19515249133110046, 'player-4:state-active')
#     (-0.1653817415237427, 0.1, -1.6538174152374268, 'player-7:stack')
#     (-0.16380187273025515, 0.1, -1.6380187273025513, 'player-4:stack')
#     (-0.1593497160077095, 0.0995, -1.6015046834945679, 'player-6:stack')
#     (0.15384340286254883, 0.1, 1.5384340286254883, 'player-0:stack')
#     (-0.13326185941696167, 0.1, -1.3326185941696167, 'player-3:stack')
#     (0.12808146741655138, 0.2222222222222222, 0.5763666033744812, 'player-6:history')
#     (-0.1269157544374466, 0.09975, -1.2723383903503418, 'player-5:stack')
#     (-0.09066972732543946, 0.1, -0.9066972732543945, 'player-1:stack')
#     (-0.07986369729042053, 0.1, -0.7986369729042053, 'player-2:stack')
#     (-0.06195943430066109, 1, -0.06195943430066109, 'player-5:state-active')
#     (-0.0560939621925354, 0.0985, -0.5694818496704102, 'player-8:stack')
#     (0.01702827513217926, 0.1, 0.1702827513217926, 'player-9:stack')
#     (-0.011722148396074772, 1, -0.011722148396074772, 'player-6:state-active')
#     (-0.0025490641593933104, 0.00225, -1.1329174041748047, 'pot')
#     (0.0, 0.0, 0.8361873030662537, 'player-9:history')
#     (0.0, 0, 0.462638258934021, 'player-9:state-active')
#     (0.0, 0, 0.050377484411001205, 'player-8:state-fold')
#     (0.0, 0.0, 0.34182360768318176, 'player-7:history')
#     (0.0, 0, 0.3592289388179779, 'player-7:state-active')
#     (-0.0, 0, -0.314838707447052, 'player-6:state-fold')
#     (-0.0, 0, -0.16778706014156342, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.3006676733493805, 'player-4:state-fold')
#     (0.0, 0.0, 1.2594202756881714, 'player-3:history')
#     (-0.0, 0, -0.18486566841602325, 'player-3:state-fold')
#     (0.0, 0.0, 1.3610700368881226, 'player-2:history')
#     (0.0, 0, 0.05764586478471756, 'player-2:state-fold')
#     (0.0, 0.0, 1.5406986474990845, 'player-1:history')
#     (0.0, 0, 0.4644852578639984, 'player-1:state-fold')
#     (0.0, 0.0, 3.0044336318969727, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 0.5740861892700195, 'street-river')
#     (0.0, 0, 0.23288992047309875, 'street-turn')
#     (0.0, 0, 0.1424984335899353, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 2.22404146194458, 'btn distance=5')
#     (0.0, 0, 2.325878381729126, 'btn distance=4')
#     (0.0, 0, 0.25714433193206787, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (-0.0, 0, -0.027183566242456436, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (2.374540328979492, 1, 2.374540328979492, 'btn distance=6')
#     (-2.2201684, 0, 0, 'bias')
#     (-2.0789220333099365, 1, -2.0789220333099365, 'round level 2')
#     (-1.998337984085083, 1, -1.998337984085083, 'player-0:state-active')
#     (1.8561913967132568, 1, 1.8561913967132568, 'street-preflop')
#     (0.8981153964996338, 1, 0.8981153964996338, 'player-2:state-active')
#     (0.6524067521095276, 1, 0.6524067521095276, 'player-9:state-fold')
#     (0.5129716396331787, 1, 0.5129716396331787, 'player-1:state-active')
#     (0.3940722644329071, 1, 0.3940722644329071, 'player-8:state-active')
#     (0.38107914394802517, 0.1111111111111111, 3.4297122955322266, 'player-5:history')
#     (0.38011018435160315, 0.6666666666666666, 0.5701652765274048, 'player-8:history')
#     (-0.31149518489837646, 1, -0.31149518489837646, 'player-6:state-active')
#     (0.22392034530639648, 0.2222222222222222, 1.0076415538787842, 'player-6:history')
#     (-0.21782557964324953, 0.1, -2.178255796432495, 'player-7:stack')
#     (-0.20419166088104249, 0.1, -2.041916608810425, 'player-4:stack')
#     (0.19231440126895905, 1, 0.19231440126895905, 'player-7:state-fold')
#     (-0.18330993509292604, 0.0995, -1.842310905456543, 'player-6:stack')
#     (-0.18097137212753298, 0.1, -1.8097137212753296, 'player-3:stack')
#     (0.14121900498867035, 1, 0.14121900498867035, 'player-3:state-active')
#     (-0.11701351404190063, 1, -0.11701351404190063, 'player-4:state-active')
#     (-0.10727992513775826, 0.09975, -1.0754879713058472, 'player-5:stack')
#     (-0.08878108263015748, 0.1, -0.8878108263015747, 'player-1:stack')
#     (0.08243725448846817, 1, 0.08243725448846817, 'player-5:state-active')
#     (-0.06662828326225281, 0.0985, -0.676429271697998, 'player-8:stack')
#     (0.04870302379131317, 0.1, 0.4870302379131317, 'player-0:stack')
#     (-0.04568533003330231, 0.1, -0.45685330033302307, 'player-9:stack')
#     (-0.03563198447227478, 0.1, -0.3563198447227478, 'player-2:stack')
#     (0.0036316983732394875, 0.663, 0.005477674771100283, 'cards')
#     (-0.003497304707765579, 0.00225, -1.554357647895813, 'pot')
#     (0.0, 0.0, 0.9098794460296631, 'player-9:history')
#     (0.0, 0, 0.4734603762626648, 'player-9:state-active')
#     (0.0, 0, 0.30269142985343933, 'player-8:state-fold')
#     (0.0, 0.0, 0.20390835404396057, 'player-7:history')
#     (0.0, 0, 0.2394191324710846, 'player-7:state-active')
#     (-0.0, 0, -0.24992208182811737, 'player-6:state-fold')
#     (0.0, 0, 0.057786691933870316, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.10096412897109985, 'player-4:state-fold')
#     (0.0, 0.0, 0.4895218312740326, 'player-3:history')
#     (0.0, 0, 0.1697189062833786, 'player-3:state-fold')
#     (0.0, 0.0, 0.7493898868560791, 'player-2:history')
#     (0.0, 0, 0.7233438491821289, 'player-2:state-fold')
#     (0.0, 0.0, 0.45885005593299866, 'player-1:history')
#     (0.0, 0, 0.4630233347415924, 'player-1:state-fold')
#     (0.0, 0.0, 0.8247711062431335, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 1.6931723356246948, 'street-river')
#     (0.0, 0, 1.9459458589553833, 'street-turn')
#     (0.0, 0, 1.8393696546554565, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 2.3336832523345947, 'btn distance=5')
#     (0.0, 0, 2.5783846378326416, 'btn distance=4')
#     (0.0, 0, 0.3861742615699768, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (2.3866612911224365, 1, 2.3866612911224365, 'btn distance=6')
#     (-2.1693177223205566, 1, -2.1693177223205566, 'round level 2')
#     (-2.0899353, 0, 0, 'bias')
#     (-1.989793062210083, 1, -1.989793062210083, 'player-0:state-active')
#     (1.5268641710281372, 1, 1.5268641710281372, 'street-preflop')
#     (0.9683846831321716, 1, 0.9683846831321716, 'player-8:state-active')
#     (0.6580949425697327, 1, 0.6580949425697327, 'player-9:state-fold')
#     (0.5415549874305725, 1, 0.5415549874305725, 'player-7:state-fold')
#     (0.4935045540332794, 1, 0.4935045540332794, 'player-1:state-active')
#     (0.4514596727159288, 0.1111111111111111, 4.063137054443359, 'player-5:history')
#     (0.3981684843699137, 0.6666666666666666, 0.5972527265548706, 'player-8:history')
#     (0.3373173872629801, 0.2222222222222222, 1.5179282426834106, 'player-6:history')
#     (0.2826194167137146, 1, 0.2826194167137146, 'player-2:state-active')
#     (-0.228678560256958, 0.1, -2.28678560256958, 'player-7:stack')
#     (-0.21861775267124178, 0.0995, -2.1971633434295654, 'player-6:stack')
#     (-0.20103013515472412, 0.1, -2.010301351547241, 'player-4:stack')
#     (-0.19620796442031863, 0.1, -1.962079644203186, 'player-3:stack')
#     (0.16314665973186493, 1, 0.16314665973186493, 'player-3:state-active')
#     (-0.13846114656329156, 0.09975, -1.388081669807434, 'player-5:stack')
#     (-0.13577983379364014, 0.1, -1.3577983379364014, 'player-2:stack')
#     (-0.12167444080114365, 1, -0.12167444080114365, 'player-5:state-active')
#     (-0.11367033421993256, 1, -0.11367033421993256, 'player-4:state-active')
#     (-0.105177940428257, 0.0985, -1.0677963495254517, 'player-8:stack')
#     (-0.0986370325088501, 0.1, -0.986370325088501, 'player-1:stack')
#     (0.0649658739566803, 1, 0.0649658739566803, 'player-6:state-active')
#     (-0.06336216926574707, 0.1, -0.6336216926574707, 'player-9:stack')
#     (0.0109551340341568, 0.1, 0.109551340341568, 'player-0:stack')
#     (0.0068263160325586795, 0.663, 0.010296102613210678, 'cards')
#     (-0.005227649509906769, 0.00225, -2.323399782180786, 'pot')
#     (0.0, 0.0, 0.7091440558433533, 'player-9:history')
#     (0.0, 0, 0.4694209694862366, 'player-9:state-active')
#     (0.0, 0, 0.9448767900466919, 'player-8:state-fold')
#     (0.0, 0.0, 0.4933747351169586, 'player-7:history')
#     (0.0, 0, 0.6356079578399658, 'player-7:state-active')
#     (-0.0, 0, -0.1039939895272255, 'player-6:state-fold')
#     (-0.0, 0, -0.08493565768003464, 'player-5:state-fold')
#     (0.0, 0.0, 0.6780285835266113, 'player-4:history')
#     (-0.0, 0, -0.015592820942401886, 'player-4:state-fold')
#     (0.0, 0.0, 0.9237784147262573, 'player-3:history')
#     (0.0, 0, 0.31402891874313354, 'player-3:state-fold')
#     (0.0, 0.0, 0.6499181985855103, 'player-2:history')
#     (0.0, 0, 0.6079424619674683, 'player-2:state-fold')
#     (0.0, 0.0, 0.31196364760398865, 'player-1:history')
#     (0.0, 0, 0.35019147396087646, 'player-1:state-fold')
#     (0.0, 0.0, 1.1408227682113647, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 1.5670738220214844, 'street-river')
#     (0.0, 0, 1.3895366191864014, 'street-turn')
#     (0.0, 0, 1.4037833213806152, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 2.4277405738830566, 'btn distance=5')
#     (0.0, 0, 2.6131505966186523, 'btn distance=4')
#     (0.0, 0, 0.3329910337924957, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (-0.0, 0, -0.01431115809828043, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (2.428459644317627, 1, 2.428459644317627, 'btn distance=6')
#     (-2.31951904296875, 1, -2.31951904296875, 'round level 2')
#     (-2.1535284519195557, 1, -2.1535284519195557, 'player-0:state-active')
#     (-2.1036038, 0, 0, 'bias')
#     (1.4314368963241577, 1, 1.4314368963241577, 'street-preflop')
#     (0.904315173625946, 1, 0.904315173625946, 'player-8:state-active')
#     (0.6664431095123291, 1, 0.6664431095123291, 'player-9:state-fold')
#     (0.5659430424372355, 0.6666666666666666, 0.8489145636558533, 'player-8:history')
#     (0.49769866466522217, 1, 0.49769866466522217, 'player-1:state-active')
#     (0.4935069680213928, 1, 0.4935069680213928, 'player-7:state-fold')
#     (0.4139717155032687, 0.1111111111111111, 3.725745439529419, 'player-5:history')
#     (0.37894688712226016, 0.2222222222222222, 1.705260992050171, 'player-6:history')
#     (0.22700640559196472, 1, 0.22700640559196472, 'player-2:state-active')
#     (-0.2118021882772446, 0.0995, -2.1286652088165283, 'player-6:stack')
#     (-0.19895819425582886, 0.1, -1.9895819425582886, 'player-4:stack')
#     (-0.1904520630836487, 0.1, -1.9045206308364868, 'player-7:stack')
#     (-0.19017614126205445, 0.1, -1.9017614126205444, 'player-3:stack')
#     (-0.1555991852581501, 0.09975, -1.5598915815353394, 'player-5:stack')
#     (0.1423758715391159, 1, 0.1423758715391159, 'player-3:state-active')
#     (0.12941569089889526, 1, 0.12941569089889526, 'player-5:state-active')
#     (-0.12825465202331543, 0.1, -1.2825465202331543, 'player-1:stack')
#     (-0.12270451784133912, 0.1, -1.2270451784133911, 'player-2:stack')
#     (-0.11618789935112, 0.0985, -1.179572582244873, 'player-8:stack')
#     (-0.08739940524101258, 0.1, -0.8739940524101257, 'player-9:stack')
#     (-0.02029792219400406, 1, -0.02029792219400406, 'player-6:state-active')
#     (0.017692089080810547, 0.1, 0.17692089080810547, 'player-0:stack')
#     (-0.011390859261155128, 1, -0.011390859261155128, 'player-4:state-active')
#     (-0.003450714200735092, 0.00225, -1.5336507558822632, 'pot')
#     (-0.00036069658922497185, 0.663, -0.0005440370878204703, 'cards')
#     (0.0, 0.0, 0.9967906475067139, 'player-9:history')
#     (0.0, 0, 0.41812750697135925, 'player-9:state-active')
#     (0.0, 0, 0.9965319037437439, 'player-8:state-fold')
#     (0.0, 0.0, 0.5559170246124268, 'player-7:history')
#     (0.0, 0, 0.6117324233055115, 'player-7:state-active')
#     (-0.0, 0, -0.21435418725013733, 'player-6:state-fold')
#     (0.0, 0, 0.15621395409107208, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.12340544909238815, 'player-4:state-fold')
#     (0.0, 0.0, 0.8774658441543579, 'player-3:history')
#     (0.0, 0, 0.2819548547267914, 'player-3:state-fold')
#     (0.0, 0.0, 0.7273887395858765, 'player-2:history')
#     (0.0, 0, 0.5529121160507202, 'player-2:state-fold')
#     (0.0, 0.0, 0.8880079388618469, 'player-1:history')
#     (0.0, 0, 0.4988119900226593, 'player-1:state-fold')
#     (0.0, 0.0, 0.6189841628074646, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 1.314842700958252, 'street-river')
#     (0.0, 0, 1.4213526248931885, 'street-turn')
#     (0.0, 0, 1.5551739931106567, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 2.5488789081573486, 'btn distance=5')
#     (0.0, 0, 2.6901073455810547, 'btn distance=4')
#     (0.0, 0, 0.4982319474220276, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (-1.7271546125411987, 1, -1.7271546125411987, 'player-0:state-active')
#     (1.6743172407150269, 1, 1.6743172407150269, 'btn distance=6')
#     (-1.671335, 0, 0, 'bias')
#     (1.665412425994873, 1, 1.665412425994873, 'street-preflop')
#     (-1.649506688117981, 1, -1.649506688117981, 'round level 2')
#     (0.765361487865448, 1, 0.765361487865448, 'player-9:state-fold')
#     (0.6200821399688721, 1, 0.6200821399688721, 'player-7:state-fold')
#     (0.39096311728159583, 0.6666666666666666, 0.5864446759223938, 'player-8:history')
#     (0.31775495409965515, 1, 0.31775495409965515, 'player-2:state-active')
#     (0.29196155071258545, 1, 0.29196155071258545, 'player-1:state-active')
#     (-0.2090632438659668, 0.1, -2.090632438659668, 'player-7:stack')
#     (0.1963210768169827, 0.1111111111111111, 1.7668896913528442, 'player-5:history')
#     (-0.1869731664657593, 0.1, -1.8697316646575928, 'player-4:stack')
#     (-0.18135348558425904, 0.1, -1.8135348558425903, 'player-3:stack')
#     (-0.1686408668756485, 1, -0.1686408668756485, 'player-6:state-active')
#     (-0.1595471477508545, 0.0995, -1.6034889221191406, 'player-6:stack')
#     (0.1244274377822876, 0.2222222222222222, 0.5599234700202942, 'player-6:history')
#     (0.11077957153320313, 0.1, 1.1077957153320312, 'player-0:stack')
#     (0.08522438257932663, 1, 0.08522438257932663, 'player-4:state-active')
#     (-0.07722781375050546, 0.09975, -0.7742136716842651, 'player-5:stack')
#     (0.05815807357430458, 1, 0.05815807357430458, 'player-8:state-active')
#     (-0.041863877326250076, 1, -0.041863877326250076, 'player-5:state-active')
#     (0.024999359250068666, 0.1, 0.24999359250068665, 'player-2:stack')
#     (-0.015894461423158646, 1, -0.015894461423158646, 'player-3:state-active')
#     (0.014214366674423218, 0.1, 0.14214366674423218, 'player-9:stack')
#     (0.004830241697374732, 0.663, 0.0072854324243962765, 'cards')
#     (0.0014251514337956907, 0.1, 0.014251514337956905, 'player-1:stack')
#     (-0.0012248808383010328, 0.0985, -0.012435338459908962, 'player-8:stack')
#     (0.0010350157096982002, 0.00225, 0.460006982088089, 'pot')
#     (0.0, 0.0, 0.9480952024459839, 'player-9:history')
#     (0.0, 0, 0.3634771704673767, 'player-9:state-active')
#     (0.0, 0, 0.1915341317653656, 'player-8:state-fold')
#     (0.0, 0.0, 0.06328362226486206, 'player-7:history')
#     (0.0, 0, 0.3599641025066376, 'player-7:state-active')
#     (-0.0, 0, -0.02465648762881756, 'player-6:state-fold')
#     (-0.0, 0, -0.21264591813087463, 'player-5:state-fold')
#     (0.0, 0.0, 0.6586898565292358, 'player-4:history')
#     (-0.0, 0, -0.022165140137076378, 'player-4:state-fold')
#     (0.0, 0.0, 0.07129468768835068, 'player-3:history')
#     (-0.0, 0, -0.11512207239866257, 'player-3:state-fold')
#     (0.0, 0.0, 0.2524775266647339, 'player-2:history')
#     (0.0, 0, 0.005736817605793476, 'player-2:state-fold')
#     (0.0, 0.0, 0.19451376795768738, 'player-1:history')
#     (0.0, 0, 0.29147276282310486, 'player-1:state-fold')
#     (0.0, 0.0, 0.5361006855964661, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 1.5800559520721436, 'street-river')
#     (0.0, 0, 1.5945707559585571, 'street-turn')
#     (0.0, 0, 1.6251622438430786, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 1.6758811473846436, 'btn distance=5')
#     (0.0, 0, 2.0806338787078857, 'btn distance=4')
#     (-0.0, 0, -0.02149493806064129, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.07707057148218155, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### FOLD する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 150
#   - raise: [250, 10000]
# -- hole card --
#   - ['CT', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9850
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 500 (double_raise) ] at round 1
#   => [('fold', 0.3072561025619507), ('call', -0.016020774841308594), ('min_raise', 0.28197336196899414), ('double_raise', 0.41495275497436523), ('triple_raise', 0.2835264205932617), ('max_raise', 0.2574824094772339)]
# ** weights and features in detail **
# bias : [-1.55898881 -1.67052042 -2.22016835 -2.0899353  -2.10360384 -1.67133498]
#
# linear combination for fold :
#     (2.9704649448394775, 1, 2.9704649448394775, 'street-preflop')
#     (-1.5589888, 0, 0, 'bias')
#     (-1.5441920757293701, 1, -1.5441920757293701, 'player-0:state-active')
#     (-1.4612571001052856, 1, -1.4612571001052856, 'round level 2')
#     (0.7291356921195984, 1, 0.7291356921195984, 'btn distance=6')
#     (0.6810815334320068, 1, 0.6810815334320068, 'player-9:state-fold')
#     (0.3590715726216634, 0.6666666666666666, 0.5386073589324951, 'player-8:history')
#     (0.25149619579315186, 1, 0.25149619579315186, 'player-2:state-active')
#     (0.24464909235636392, 0.1111111111111111, 2.2018418312072754, 'player-5:history')
#     (0.20635151863098145, 1, 0.20635151863098145, 'player-4:state-active')
#     (0.1839430332183838, 1, 0.1839430332183838, 'player-6:state-active')
#     (-0.1669168919324875, 1, -0.1669168919324875, 'player-8:state-active')
#     (0.1662919670343399, 1, 0.1662919670343399, 'player-1:state-active')
#     (-0.16613179588317872, 0.0995, -1.6696662902832031, 'player-6:stack')
#     (-0.15515435934066774, 0.1, -1.5515435934066772, 'player-7:stack')
#     (-0.14752224683761597, 0.1, -1.4752224683761597, 'player-3:stack')
#     (0.13138611614704132, 1, 0.13138611614704132, 'player-5:state-active')
#     (-0.12465298175811768, 0.1, -1.2465298175811768, 'player-4:stack')
#     (-0.11465718746185304, 0.1, -1.1465718746185303, 'player-2:stack')
#     (0.1051850120226542, 0.2222222222222222, 0.47333255410194397, 'player-6:history')
#     (-0.07128117680549621, 0.1, -0.7128117680549622, 'player-9:stack')
#     (-0.06994461759924889, 0.09975, -0.7011991739273071, 'player-5:stack')
#     (-0.06426747819781303, 0.0985, -0.6524617075920105, 'player-8:stack')
#     (-0.0627477526664734, 0.1, -0.6274775266647339, 'player-1:stack')
#     (-0.03917863592505455, 1, -0.03917863592505455, 'player-7:state-fold')
#     (0.01845618933439255, 0.1, 0.18456189334392548, 'player-0:stack')
#     (0.008200302720069885, 1, 0.008200302720069885, 'player-3:state-active')
#     (-0.002216987773776054, 0.00225, -0.9853278994560242, 'pot')
#     (0.0006529669667361304, 0.663, 0.000984867219813168, 'cards')
#     (0.0, 0.0, 0.7250006198883057, 'player-9:history')
#     (0.0, 0, 0.632540762424469, 'player-9:state-active')
#     (-0.0, 0, -0.22895732522010803, 'player-8:state-fold')
#     (0.0, 0.0, 0.24329331517219543, 'player-7:history')
#     (-0.0, 0, -0.0930999219417572, 'player-7:state-active')
#     (0.0, 0, 0.30152055621147156, 'player-6:state-fold')
#     (0.0, 0, 0.14345857501029968, 'player-5:state-fold')
#     (0.0, 0.0, 0.7096555829048157, 'player-4:history')
#     (0.0, 0, 0.3477531671524048, 'player-4:state-fold')
#     (0.0, 0.0, 0.38791540265083313, 'player-3:history')
#     (-0.0, 0, -0.05360166355967522, 'player-3:state-fold')
#     (0.0, 0.0, 0.17896975576877594, 'player-2:history')
#     (0.0, 0, 0.17204277217388153, 'player-2:state-fold')
#     (0.0, 0.0, 0.3307403028011322, 'player-1:history')
#     (0.0, 0, 0.19814316928386688, 'player-1:state-fold')
#     (0.0, 0.0, 0.288990318775177, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 2.4131579399108887, 'street-river')
#     (0.0, 0, 2.957214593887329, 'street-turn')
#     (0.0, 0, 2.995706558227539, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 0.7153593301773071, 'btn distance=5')
#     (0.0, 0, 0.8408181667327881, 'btn distance=4')
#     (0.0, 0, 0.11172295361757278, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.10479549318552017, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (2.2067880630493164, 1, 2.2067880630493164, 'btn distance=6')
#     (-1.6705204, 0, 0, 'bias')
#     (-1.565030813217163, 1, -1.565030813217163, 'player-0:state-active')
#     (-1.4174758195877075, 1, -1.4174758195877075, 'round level 2')
#     (0.6621841788291931, 1, 0.6621841788291931, 'street-preflop')
#     (0.5947113037109375, 1, 0.5947113037109375, 'player-9:state-fold')
#     (0.5145376920700073, 1, 0.5145376920700073, 'player-1:state-active')
#     (0.5064280827840169, 0.1111111111111111, 4.557852745056152, 'player-5:history')
#     (0.3658600250879923, 0.6666666666666666, 0.5487900376319885, 'player-8:history')
#     (0.31320011615753174, 1, 0.31320011615753174, 'player-8:state-active')
#     (-0.26677846908569336, 1, -0.26677846908569336, 'player-3:state-active')
#     (0.23857755938172343, 0.663, 0.35984548926353455, 'cards')
#     (0.22495703399181366, 1, 0.22495703399181366, 'player-7:state-fold')
#     (0.2243090718984604, 1, 0.2243090718984604, 'player-2:state-active')
#     (-0.19515249133110046, 1, -0.19515249133110046, 'player-4:state-active')
#     (-0.1653817415237427, 0.1, -1.6538174152374268, 'player-7:stack')
#     (-0.16380187273025515, 0.1, -1.6380187273025513, 'player-4:stack')
#     (-0.1593497160077095, 0.0995, -1.6015046834945679, 'player-6:stack')
#     (0.15384340286254883, 0.1, 1.5384340286254883, 'player-0:stack')
#     (-0.13326185941696167, 0.1, -1.3326185941696167, 'player-3:stack')
#     (0.12808146741655138, 0.2222222222222222, 0.5763666033744812, 'player-6:history')
#     (-0.1269157544374466, 0.09975, -1.2723383903503418, 'player-5:stack')
#     (-0.09066972732543946, 0.1, -0.9066972732543945, 'player-1:stack')
#     (-0.07986369729042053, 0.1, -0.7986369729042053, 'player-2:stack')
#     (-0.06195943430066109, 1, -0.06195943430066109, 'player-5:state-active')
#     (-0.0560939621925354, 0.0985, -0.5694818496704102, 'player-8:stack')
#     (0.01702827513217926, 0.1, 0.1702827513217926, 'player-9:stack')
#     (-0.011722148396074772, 1, -0.011722148396074772, 'player-6:state-active')
#     (-0.0025490641593933104, 0.00225, -1.1329174041748047, 'pot')
#     (0.0, 0.0, 0.8361873030662537, 'player-9:history')
#     (0.0, 0, 0.462638258934021, 'player-9:state-active')
#     (0.0, 0, 0.050377484411001205, 'player-8:state-fold')
#     (0.0, 0.0, 0.34182360768318176, 'player-7:history')
#     (0.0, 0, 0.3592289388179779, 'player-7:state-active')
#     (-0.0, 0, -0.314838707447052, 'player-6:state-fold')
#     (-0.0, 0, -0.16778706014156342, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.3006676733493805, 'player-4:state-fold')
#     (0.0, 0.0, 1.2594202756881714, 'player-3:history')
#     (-0.0, 0, -0.18486566841602325, 'player-3:state-fold')
#     (0.0, 0.0, 1.3610700368881226, 'player-2:history')
#     (0.0, 0, 0.05764586478471756, 'player-2:state-fold')
#     (0.0, 0.0, 1.5406986474990845, 'player-1:history')
#     (0.0, 0, 0.4644852578639984, 'player-1:state-fold')
#     (0.0, 0.0, 3.0044336318969727, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 0.5740861892700195, 'street-river')
#     (0.0, 0, 0.23288992047309875, 'street-turn')
#     (0.0, 0, 0.1424984335899353, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 2.22404146194458, 'btn distance=5')
#     (0.0, 0, 2.325878381729126, 'btn distance=4')
#     (0.0, 0, 0.25714433193206787, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (-0.0, 0, -0.027183566242456436, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (2.374540328979492, 1, 2.374540328979492, 'btn distance=6')
#     (-2.2201684, 0, 0, 'bias')
#     (-2.0789220333099365, 1, -2.0789220333099365, 'round level 2')
#     (-1.998337984085083, 1, -1.998337984085083, 'player-0:state-active')
#     (1.8561913967132568, 1, 1.8561913967132568, 'street-preflop')
#     (0.8981153964996338, 1, 0.8981153964996338, 'player-2:state-active')
#     (0.6524067521095276, 1, 0.6524067521095276, 'player-9:state-fold')
#     (0.5129716396331787, 1, 0.5129716396331787, 'player-1:state-active')
#     (0.3940722644329071, 1, 0.3940722644329071, 'player-8:state-active')
#     (0.38107914394802517, 0.1111111111111111, 3.4297122955322266, 'player-5:history')
#     (0.38011018435160315, 0.6666666666666666, 0.5701652765274048, 'player-8:history')
#     (-0.31149518489837646, 1, -0.31149518489837646, 'player-6:state-active')
#     (0.22392034530639648, 0.2222222222222222, 1.0076415538787842, 'player-6:history')
#     (-0.21782557964324953, 0.1, -2.178255796432495, 'player-7:stack')
#     (-0.20419166088104249, 0.1, -2.041916608810425, 'player-4:stack')
#     (0.19231440126895905, 1, 0.19231440126895905, 'player-7:state-fold')
#     (-0.18330993509292604, 0.0995, -1.842310905456543, 'player-6:stack')
#     (-0.18097137212753298, 0.1, -1.8097137212753296, 'player-3:stack')
#     (0.14121900498867035, 1, 0.14121900498867035, 'player-3:state-active')
#     (-0.11701351404190063, 1, -0.11701351404190063, 'player-4:state-active')
#     (-0.10727992513775826, 0.09975, -1.0754879713058472, 'player-5:stack')
#     (-0.08878108263015748, 0.1, -0.8878108263015747, 'player-1:stack')
#     (0.08243725448846817, 1, 0.08243725448846817, 'player-5:state-active')
#     (-0.06662828326225281, 0.0985, -0.676429271697998, 'player-8:stack')
#     (0.04870302379131317, 0.1, 0.4870302379131317, 'player-0:stack')
#     (-0.04568533003330231, 0.1, -0.45685330033302307, 'player-9:stack')
#     (-0.03563198447227478, 0.1, -0.3563198447227478, 'player-2:stack')
#     (0.0036316983732394875, 0.663, 0.005477674771100283, 'cards')
#     (-0.003497304707765579, 0.00225, -1.554357647895813, 'pot')
#     (0.0, 0.0, 0.9098794460296631, 'player-9:history')
#     (0.0, 0, 0.4734603762626648, 'player-9:state-active')
#     (0.0, 0, 0.30269142985343933, 'player-8:state-fold')
#     (0.0, 0.0, 0.20390835404396057, 'player-7:history')
#     (0.0, 0, 0.2394191324710846, 'player-7:state-active')
#     (-0.0, 0, -0.24992208182811737, 'player-6:state-fold')
#     (0.0, 0, 0.057786691933870316, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.10096412897109985, 'player-4:state-fold')
#     (0.0, 0.0, 0.4895218312740326, 'player-3:history')
#     (0.0, 0, 0.1697189062833786, 'player-3:state-fold')
#     (0.0, 0.0, 0.7493898868560791, 'player-2:history')
#     (0.0, 0, 0.7233438491821289, 'player-2:state-fold')
#     (0.0, 0.0, 0.45885005593299866, 'player-1:history')
#     (0.0, 0, 0.4630233347415924, 'player-1:state-fold')
#     (0.0, 0.0, 0.8247711062431335, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 1.6931723356246948, 'street-river')
#     (0.0, 0, 1.9459458589553833, 'street-turn')
#     (0.0, 0, 1.8393696546554565, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 2.3336832523345947, 'btn distance=5')
#     (0.0, 0, 2.5783846378326416, 'btn distance=4')
#     (0.0, 0, 0.3861742615699768, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (2.3866612911224365, 1, 2.3866612911224365, 'btn distance=6')
#     (-2.1693177223205566, 1, -2.1693177223205566, 'round level 2')
#     (-2.0899353, 0, 0, 'bias')
#     (-1.989793062210083, 1, -1.989793062210083, 'player-0:state-active')
#     (1.5268641710281372, 1, 1.5268641710281372, 'street-preflop')
#     (0.9683846831321716, 1, 0.9683846831321716, 'player-8:state-active')
#     (0.6580949425697327, 1, 0.6580949425697327, 'player-9:state-fold')
#     (0.5415549874305725, 1, 0.5415549874305725, 'player-7:state-fold')
#     (0.4935045540332794, 1, 0.4935045540332794, 'player-1:state-active')
#     (0.4514596727159288, 0.1111111111111111, 4.063137054443359, 'player-5:history')
#     (0.3981684843699137, 0.6666666666666666, 0.5972527265548706, 'player-8:history')
#     (0.3373173872629801, 0.2222222222222222, 1.5179282426834106, 'player-6:history')
#     (0.2826194167137146, 1, 0.2826194167137146, 'player-2:state-active')
#     (-0.228678560256958, 0.1, -2.28678560256958, 'player-7:stack')
#     (-0.21861775267124178, 0.0995, -2.1971633434295654, 'player-6:stack')
#     (-0.20103013515472412, 0.1, -2.010301351547241, 'player-4:stack')
#     (-0.19620796442031863, 0.1, -1.962079644203186, 'player-3:stack')
#     (0.16314665973186493, 1, 0.16314665973186493, 'player-3:state-active')
#     (-0.13846114656329156, 0.09975, -1.388081669807434, 'player-5:stack')
#     (-0.13577983379364014, 0.1, -1.3577983379364014, 'player-2:stack')
#     (-0.12167444080114365, 1, -0.12167444080114365, 'player-5:state-active')
#     (-0.11367033421993256, 1, -0.11367033421993256, 'player-4:state-active')
#     (-0.105177940428257, 0.0985, -1.0677963495254517, 'player-8:stack')
#     (-0.0986370325088501, 0.1, -0.986370325088501, 'player-1:stack')
#     (0.0649658739566803, 1, 0.0649658739566803, 'player-6:state-active')
#     (-0.06336216926574707, 0.1, -0.6336216926574707, 'player-9:stack')
#     (0.0109551340341568, 0.1, 0.109551340341568, 'player-0:stack')
#     (0.0068263160325586795, 0.663, 0.010296102613210678, 'cards')
#     (-0.005227649509906769, 0.00225, -2.323399782180786, 'pot')
#     (0.0, 0.0, 0.7091440558433533, 'player-9:history')
#     (0.0, 0, 0.4694209694862366, 'player-9:state-active')
#     (0.0, 0, 0.9448767900466919, 'player-8:state-fold')
#     (0.0, 0.0, 0.4933747351169586, 'player-7:history')
#     (0.0, 0, 0.6356079578399658, 'player-7:state-active')
#     (-0.0, 0, -0.1039939895272255, 'player-6:state-fold')
#     (-0.0, 0, -0.08493565768003464, 'player-5:state-fold')
#     (0.0, 0.0, 0.6780285835266113, 'player-4:history')
#     (-0.0, 0, -0.015592820942401886, 'player-4:state-fold')
#     (0.0, 0.0, 0.9237784147262573, 'player-3:history')
#     (0.0, 0, 0.31402891874313354, 'player-3:state-fold')
#     (0.0, 0.0, 0.6499181985855103, 'player-2:history')
#     (0.0, 0, 0.6079424619674683, 'player-2:state-fold')
#     (0.0, 0.0, 0.31196364760398865, 'player-1:history')
#     (0.0, 0, 0.35019147396087646, 'player-1:state-fold')
#     (0.0, 0.0, 1.1408227682113647, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 1.5670738220214844, 'street-river')
#     (0.0, 0, 1.3895366191864014, 'street-turn')
#     (0.0, 0, 1.4037833213806152, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 2.4277405738830566, 'btn distance=5')
#     (0.0, 0, 2.6131505966186523, 'btn distance=4')
#     (0.0, 0, 0.3329910337924957, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (-0.0, 0, -0.01431115809828043, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (2.428459644317627, 1, 2.428459644317627, 'btn distance=6')
#     (-2.31951904296875, 1, -2.31951904296875, 'round level 2')
#     (-2.1535284519195557, 1, -2.1535284519195557, 'player-0:state-active')
#     (-2.1036038, 0, 0, 'bias')
#     (1.4314368963241577, 1, 1.4314368963241577, 'street-preflop')
#     (0.904315173625946, 1, 0.904315173625946, 'player-8:state-active')
#     (0.6664431095123291, 1, 0.6664431095123291, 'player-9:state-fold')
#     (0.5659430424372355, 0.6666666666666666, 0.8489145636558533, 'player-8:history')
#     (0.49769866466522217, 1, 0.49769866466522217, 'player-1:state-active')
#     (0.4935069680213928, 1, 0.4935069680213928, 'player-7:state-fold')
#     (0.4139717155032687, 0.1111111111111111, 3.725745439529419, 'player-5:history')
#     (0.37894688712226016, 0.2222222222222222, 1.705260992050171, 'player-6:history')
#     (0.22700640559196472, 1, 0.22700640559196472, 'player-2:state-active')
#     (-0.2118021882772446, 0.0995, -2.1286652088165283, 'player-6:stack')
#     (-0.19895819425582886, 0.1, -1.9895819425582886, 'player-4:stack')
#     (-0.1904520630836487, 0.1, -1.9045206308364868, 'player-7:stack')
#     (-0.19017614126205445, 0.1, -1.9017614126205444, 'player-3:stack')
#     (-0.1555991852581501, 0.09975, -1.5598915815353394, 'player-5:stack')
#     (0.1423758715391159, 1, 0.1423758715391159, 'player-3:state-active')
#     (0.12941569089889526, 1, 0.12941569089889526, 'player-5:state-active')
#     (-0.12825465202331543, 0.1, -1.2825465202331543, 'player-1:stack')
#     (-0.12270451784133912, 0.1, -1.2270451784133911, 'player-2:stack')
#     (-0.11618789935112, 0.0985, -1.179572582244873, 'player-8:stack')
#     (-0.08739940524101258, 0.1, -0.8739940524101257, 'player-9:stack')
#     (-0.02029792219400406, 1, -0.02029792219400406, 'player-6:state-active')
#     (0.017692089080810547, 0.1, 0.17692089080810547, 'player-0:stack')
#     (-0.011390859261155128, 1, -0.011390859261155128, 'player-4:state-active')
#     (-0.003450714200735092, 0.00225, -1.5336507558822632, 'pot')
#     (-0.00036069658922497185, 0.663, -0.0005440370878204703, 'cards')
#     (0.0, 0.0, 0.9967906475067139, 'player-9:history')
#     (0.0, 0, 0.41812750697135925, 'player-9:state-active')
#     (0.0, 0, 0.9965319037437439, 'player-8:state-fold')
#     (0.0, 0.0, 0.5559170246124268, 'player-7:history')
#     (0.0, 0, 0.6117324233055115, 'player-7:state-active')
#     (-0.0, 0, -0.21435418725013733, 'player-6:state-fold')
#     (0.0, 0, 0.15621395409107208, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.12340544909238815, 'player-4:state-fold')
#     (0.0, 0.0, 0.8774658441543579, 'player-3:history')
#     (0.0, 0, 0.2819548547267914, 'player-3:state-fold')
#     (0.0, 0.0, 0.7273887395858765, 'player-2:history')
#     (0.0, 0, 0.5529121160507202, 'player-2:state-fold')
#     (0.0, 0.0, 0.8880079388618469, 'player-1:history')
#     (0.0, 0, 0.4988119900226593, 'player-1:state-fold')
#     (0.0, 0.0, 0.6189841628074646, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 1.314842700958252, 'street-river')
#     (0.0, 0, 1.4213526248931885, 'street-turn')
#     (0.0, 0, 1.5551739931106567, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 2.5488789081573486, 'btn distance=5')
#     (0.0, 0, 2.6901073455810547, 'btn distance=4')
#     (0.0, 0, 0.4982319474220276, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (-1.7271546125411987, 1, -1.7271546125411987, 'player-0:state-active')
#     (1.6743172407150269, 1, 1.6743172407150269, 'btn distance=6')
#     (-1.671335, 0, 0, 'bias')
#     (1.665412425994873, 1, 1.665412425994873, 'street-preflop')
#     (-1.649506688117981, 1, -1.649506688117981, 'round level 2')
#     (0.765361487865448, 1, 0.765361487865448, 'player-9:state-fold')
#     (0.6200821399688721, 1, 0.6200821399688721, 'player-7:state-fold')
#     (0.39096311728159583, 0.6666666666666666, 0.5864446759223938, 'player-8:history')
#     (0.31775495409965515, 1, 0.31775495409965515, 'player-2:state-active')
#     (0.29196155071258545, 1, 0.29196155071258545, 'player-1:state-active')
#     (-0.2090632438659668, 0.1, -2.090632438659668, 'player-7:stack')
#     (0.1963210768169827, 0.1111111111111111, 1.7668896913528442, 'player-5:history')
#     (-0.1869731664657593, 0.1, -1.8697316646575928, 'player-4:stack')
#     (-0.18135348558425904, 0.1, -1.8135348558425903, 'player-3:stack')
#     (-0.1686408668756485, 1, -0.1686408668756485, 'player-6:state-active')
#     (-0.1595471477508545, 0.0995, -1.6034889221191406, 'player-6:stack')
#     (0.1244274377822876, 0.2222222222222222, 0.5599234700202942, 'player-6:history')
#     (0.11077957153320313, 0.1, 1.1077957153320312, 'player-0:stack')
#     (0.08522438257932663, 1, 0.08522438257932663, 'player-4:state-active')
#     (-0.07722781375050546, 0.09975, -0.7742136716842651, 'player-5:stack')
#     (0.05815807357430458, 1, 0.05815807357430458, 'player-8:state-active')
#     (-0.041863877326250076, 1, -0.041863877326250076, 'player-5:state-active')
#     (0.024999359250068666, 0.1, 0.24999359250068665, 'player-2:stack')
#     (-0.015894461423158646, 1, -0.015894461423158646, 'player-3:state-active')
#     (0.014214366674423218, 0.1, 0.14214366674423218, 'player-9:stack')
#     (0.004830241697374732, 0.663, 0.0072854324243962765, 'cards')
#     (0.0014251514337956907, 0.1, 0.014251514337956905, 'player-1:stack')
#     (-0.0012248808383010328, 0.0985, -0.012435338459908962, 'player-8:stack')
#     (0.0010350157096982002, 0.00225, 0.460006982088089, 'pot')
#     (0.0, 0.0, 0.9480952024459839, 'player-9:history')
#     (0.0, 0, 0.3634771704673767, 'player-9:state-active')
#     (0.0, 0, 0.1915341317653656, 'player-8:state-fold')
#     (0.0, 0.0, 0.06328362226486206, 'player-7:history')
#     (0.0, 0, 0.3599641025066376, 'player-7:state-active')
#     (-0.0, 0, -0.02465648762881756, 'player-6:state-fold')
#     (-0.0, 0, -0.21264591813087463, 'player-5:state-fold')
#     (0.0, 0.0, 0.6586898565292358, 'player-4:history')
#     (-0.0, 0, -0.022165140137076378, 'player-4:state-fold')
#     (0.0, 0.0, 0.07129468768835068, 'player-3:history')
#     (-0.0, 0, -0.11512207239866257, 'player-3:state-fold')
#     (0.0, 0.0, 0.2524775266647339, 'player-2:history')
#     (0.0, 0, 0.005736817605793476, 'player-2:state-fold')
#     (0.0, 0.0, 0.19451376795768738, 'player-1:history')
#     (0.0, 0, 0.29147276282310486, 'player-1:state-fold')
#     (0.0, 0.0, 0.5361006855964661, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 1.5800559520721436, 'street-river')
#     (0.0, 0, 1.5945707559585571, 'street-turn')
#     (0.0, 0, 1.6251622438430786, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 1.6758811473846436, 'btn distance=5')
#     (0.0, 0, 2.0806338787078857, 'btn distance=4')
#     (-0.0, 0, -0.02149493806064129, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.07707057148218155, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')
# >>> type something to go next...
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['CT', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10575, side = [{'amount': 0, 'eligibles': ['uuid-6']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 9500 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'agent (uuid=uuid-0)', 'amount': 500, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'add_amount': 9500, 'paid': 9850, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.24434614181518555), ('call', -1.0735037326812744)]
# do you want to see weights? (y/n)y
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['CT', 'HJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10575, side = [{'amount': 0, 'eligibles': ['uuid-6']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : allin, stack : 0
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 9500 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'agent (uuid=uuid-0)', 'amount': 500, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'add_amount': 9500, 'paid': 9850, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 10000, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.24434614181518555), ('call', -1.0735037326812744)]
# ** weights and features in detail **
# bias : [-1.55898881 -1.67052042 -2.22016835 -2.0899353  -2.10360384 -1.67133498]
#
# linear combination for fold :
#     (2.9704649448394775, 1, 2.9704649448394775, 'street-preflop')
#     (-1.5589888, 0, 0, 'bias')
#     (-1.5441920757293701, 1, -1.5441920757293701, 'player-0:state-active')
#     (-1.4612571001052856, 1, -1.4612571001052856, 'round level 2')
#     (0.7291356921195984, 1, 0.7291356921195984, 'btn distance=6')
#     (0.6810815334320068, 1, 0.6810815334320068, 'player-9:state-fold')
#     (0.5093213796051963, 0.9456264775413712, 0.5386073589324951, 'player-8:history')
#     (0.3477531671524048, 1, 0.3477531671524048, 'player-4:state-fold')
#     (0.30152055621147156, 1, 0.30152055621147156, 'player-6:state-fold')
#     (0.19814316928386688, 1, 0.19814316928386688, 'player-1:state-fold')
#     (0.17204277217388153, 1, 0.17204277217388153, 'player-2:state-fold')
#     (-0.1669168919324875, 1, -0.1669168919324875, 'player-8:state-active')
#     (-0.16613179588317872, 0.0995, -1.6696662902832031, 'player-6:stack')
#     (-0.15515435934066774, 0.1, -1.5515435934066772, 'player-7:stack')
#     (-0.14752224683761597, 0.1, -1.4752224683761597, 'player-3:stack')
#     (0.14345857501029968, 1, 0.14345857501029968, 'player-5:state-fold')
#     (-0.12465298175811768, 0.1, -1.2465298175811768, 'player-4:stack')
#     (-0.11465718746185304, 0.1, -1.1465718746185303, 'player-2:stack')
#     (-0.10419842536747455, 0.10575, -0.9853278994560242, 'pot')
#     (-0.07128117680549621, 0.1, -0.7128117680549622, 'player-9:stack')
#     (-0.06994461759924889, 0.09975, -0.7011991739273071, 'player-5:stack')
#     (-0.0627477526664734, 0.1, -0.6274775266647339, 'player-1:stack')
#     (-0.05360166355967522, 1, -0.05360166355967522, 'player-3:state-fold')
#     (-0.03917863592505455, 1, -0.03917863592505455, 'player-7:state-fold')
#     (0.01753337986767292, 0.095, 0.18456189334392548, 'player-0:stack')
#     (0.01366384485934643, 0.04728132387706856, 0.288990318775177, 'player-0:history')
#     (0.0006529669667361304, 0.663, 0.000984867219813168, 'cards')
#     (0.0, 0.0, 0.7250006198883057, 'player-9:history')
#     (0.0, 0, 0.632540762424469, 'player-9:state-active')
#     (-0.0, 0, -0.22895732522010803, 'player-8:state-fold')
#     (-0.0, 0.0, -0.6524617075920105, 'player-8:stack')
#     (0.0, 0.0, 0.24329331517219543, 'player-7:history')
#     (-0.0, 0, -0.0930999219417572, 'player-7:state-active')
#     (0.0, 0.0, 0.47333255410194397, 'player-6:history')
#     (0.0, 0, 0.1839430332183838, 'player-6:state-active')
#     (0.0, 0.0, 2.2018418312072754, 'player-5:history')
#     (0.0, 0, 0.13138611614704132, 'player-5:state-active')
#     (0.0, 0.0, 0.7096555829048157, 'player-4:history')
#     (0.0, 0, 0.20635151863098145, 'player-4:state-active')
#     (0.0, 0.0, 0.38791540265083313, 'player-3:history')
#     (0.0, 0, 0.008200302720069885, 'player-3:state-active')
#     (0.0, 0.0, 0.17896975576877594, 'player-2:history')
#     (0.0, 0, 0.25149619579315186, 'player-2:state-active')
#     (0.0, 0.0, 0.3307403028011322, 'player-1:history')
#     (0.0, 0, 0.1662919670343399, 'player-1:state-active')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 2.4131579399108887, 'street-river')
#     (0.0, 0, 2.957214593887329, 'street-turn')
#     (0.0, 0, 2.995706558227539, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 0.7153593301773071, 'btn distance=5')
#     (0.0, 0, 0.8408181667327881, 'btn distance=4')
#     (0.0, 0, 0.11172295361757278, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.10479549318552017, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (2.2067880630493164, 1, 2.2067880630493164, 'btn distance=6')
#     (-1.6705204, 0, 0, 'bias')
#     (-1.565030813217163, 1, -1.565030813217163, 'player-0:state-active')
#     (-1.4174758195877075, 1, -1.4174758195877075, 'round level 2')
#     (0.6621841788291931, 1, 0.6621841788291931, 'street-preflop')
#     (0.5947113037109375, 1, 0.5947113037109375, 'player-9:state-fold')
#     (0.5189503901957339, 0.9456264775413712, 0.5487900376319885, 'player-8:history')
#     (0.4644852578639984, 1, 0.4644852578639984, 'player-1:state-fold')
#     (-0.314838707447052, 1, -0.314838707447052, 'player-6:state-fold')
#     (0.31320011615753174, 1, 0.31320011615753174, 'player-8:state-active')
#     (-0.3006676733493805, 1, -0.3006676733493805, 'player-4:state-fold')
#     (0.23857755938172343, 0.663, 0.35984548926353455, 'cards')
#     (0.22495703399181366, 1, 0.22495703399181366, 'player-7:state-fold')
#     (-0.18486566841602325, 1, -0.18486566841602325, 'player-3:state-fold')
#     (-0.16778706014156342, 1, -0.16778706014156342, 'player-5:state-fold')
#     (-0.1653817415237427, 0.1, -1.6538174152374268, 'player-7:stack')
#     (-0.16380187273025515, 0.1, -1.6380187273025513, 'player-4:stack')
#     (-0.1593497160077095, 0.0995, -1.6015046834945679, 'player-6:stack')
#     (0.14615123271942138, 0.095, 1.5384340286254883, 'player-0:stack')
#     (0.14205359961687813, 0.04728132387706856, 3.0044336318969727, 'player-0:history')
#     (-0.13326185941696167, 0.1, -1.3326185941696167, 'player-3:stack')
#     (-0.1269157544374466, 0.09975, -1.2723383903503418, 'player-5:stack')
#     (-0.11980601549148559, 0.10575, -1.1329174041748047, 'pot')
#     (-0.09066972732543946, 0.1, -0.9066972732543945, 'player-1:stack')
#     (-0.07986369729042053, 0.1, -0.7986369729042053, 'player-2:stack')
#     (0.05764586478471756, 1, 0.05764586478471756, 'player-2:state-fold')
#     (0.01702827513217926, 0.1, 0.1702827513217926, 'player-9:stack')
#     (0.0, 0.0, 0.8361873030662537, 'player-9:history')
#     (0.0, 0, 0.462638258934021, 'player-9:state-active')
#     (0.0, 0, 0.050377484411001205, 'player-8:state-fold')
#     (-0.0, 0.0, -0.5694818496704102, 'player-8:stack')
#     (0.0, 0.0, 0.34182360768318176, 'player-7:history')
#     (0.0, 0, 0.3592289388179779, 'player-7:state-active')
#     (0.0, 0.0, 0.5763666033744812, 'player-6:history')
#     (-0.0, 0, -0.011722148396074772, 'player-6:state-active')
#     (0.0, 0.0, 4.557852745056152, 'player-5:history')
#     (-0.0, 0, -0.06195943430066109, 'player-5:state-active')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.19515249133110046, 'player-4:state-active')
#     (0.0, 0.0, 1.2594202756881714, 'player-3:history')
#     (-0.0, 0, -0.26677846908569336, 'player-3:state-active')
#     (0.0, 0.0, 1.3610700368881226, 'player-2:history')
#     (0.0, 0, 0.2243090718984604, 'player-2:state-active')
#     (0.0, 0.0, 1.5406986474990845, 'player-1:history')
#     (0.0, 0, 0.5145376920700073, 'player-1:state-active')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 0.5740861892700195, 'street-river')
#     (0.0, 0, 0.23288992047309875, 'street-turn')
#     (0.0, 0, 0.1424984335899353, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 2.22404146194458, 'btn distance=5')
#     (0.0, 0, 2.325878381729126, 'btn distance=4')
#     (0.0, 0, 0.25714433193206787, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (-0.0, 0, -0.027183566242456436, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')

# %% [markdown]
# ### FOLD する場面2

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 150
#   - raise: [250, 9500]
# -- hole card --
#   - ['D9', 'CK']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10575
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9850
#     - 6 : agent (uuid-0) => state : participating, stack : 9500 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 150, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 2
#   => [('fold', 0.006682038307189941), ('call', -0.5695514678955078), ('min_raise', -0.2084062099456787), ('double_raise', -0.10352575778961182), ('triple_raise', -0.02189803123474121), ('max_raise', -0.2772747278213501)]
# ** weights and features in detail **
# bias : [-1.55898881 -1.67052042 -2.22016835 -2.0899353  -2.10360384 -1.67133498]
#
# linear combination for fold :
#     (2.9704649448394775, 1, 2.9704649448394775, 'street-preflop')
#     (-1.5589888, 0, 0, 'bias')
#     (-1.5441920757293701, 1, -1.5441920757293701, 'player-0:state-active')
#     (-1.4612571001052856, 1, -1.4612571001052856, 'round level 2')
#     (0.7153593301773071, 1, 0.7153593301773071, 'btn distance=5')
#     (0.632540762424469, 1, 0.632540762424469, 'player-9:state-active')
#     (0.48333374659220374, 0.6666666666666666, 0.7250006198883057, 'player-9:history')
#     (0.25149619579315186, 1, 0.25149619579315186, 'player-2:state-active')
#     (-0.22895732522010803, 1, -0.22895732522010803, 'player-8:state-fold')
#     (0.20635151863098145, 1, 0.20635151863098145, 'player-4:state-active')
#     (0.1839430332183838, 1, 0.1839430332183838, 'player-6:state-active')
#     (0.1662919670343399, 1, 0.1662919670343399, 'player-1:state-active')
#     (-0.16571437931060792, 0.09925, -1.6696662902832031, 'player-6:stack')
#     (-0.15437858754396439, 0.0995, -1.5515435934066772, 'player-7:stack')
#     (-0.14752224683761597, 0.1, -1.4752224683761597, 'player-3:stack')
#     (0.13138611614704132, 1, 0.13138611614704132, 'player-5:state-active')
#     (-0.12465298175811768, 0.1, -1.2465298175811768, 'player-4:stack')
#     (-0.11465718746185304, 0.1, -1.1465718746185303, 'player-2:stack')
#     (-0.0930999219417572, 1, -0.0930999219417572, 'player-7:state-active')
#     (-0.07021195915341377, 0.0985, -0.7128117680549622, 'player-9:stack')
#     (-0.06994461759924889, 0.09975, -0.7011991739273071, 'player-5:stack')
#     (-0.06899782557785511, 0.10575, -0.6524617075920105, 'player-8:stack')
#     (-0.0627477526664734, 0.1, -0.6274775266647339, 'player-1:stack')
#     (0.05406518114937676, 0.2222222222222222, 0.24329331517219543, 'player-7:history')
#     (0.0525925060113271, 0.1111111111111111, 0.47333255410194397, 'player-6:history')
#     (0.01753337986767292, 0.095, 0.18456189334392548, 'player-0:stack')
#     (0.008200302720069885, 1, 0.008200302720069885, 'player-3:state-active')
#     (-0.002216987773776054, 0.00225, -0.9853278994560242, 'pot')
#     (0.0006628156389342621, 0.673, 0.000984867219813168, 'cards')
#     (0.0, 0, 0.6810815334320068, 'player-9:state-fold')
#     (0.0, 0.0, 0.5386073589324951, 'player-8:history')
#     (-0.0, 0, -0.1669168919324875, 'player-8:state-active')
#     (-0.0, 0, -0.03917863592505455, 'player-7:state-fold')
#     (0.0, 0, 0.30152055621147156, 'player-6:state-fold')
#     (0.0, 0.0, 2.2018418312072754, 'player-5:history')
#     (0.0, 0, 0.14345857501029968, 'player-5:state-fold')
#     (0.0, 0.0, 0.7096555829048157, 'player-4:history')
#     (0.0, 0, 0.3477531671524048, 'player-4:state-fold')
#     (0.0, 0.0, 0.38791540265083313, 'player-3:history')
#     (-0.0, 0, -0.05360166355967522, 'player-3:state-fold')
#     (0.0, 0.0, 0.17896975576877594, 'player-2:history')
#     (0.0, 0, 0.17204277217388153, 'player-2:state-fold')
#     (0.0, 0.0, 0.3307403028011322, 'player-1:history')
#     (0.0, 0, 0.19814316928386688, 'player-1:state-fold')
#     (0.0, 0.0, 0.288990318775177, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 2.4131579399108887, 'street-river')
#     (0.0, 0, 2.957214593887329, 'street-turn')
#     (0.0, 0, 2.995706558227539, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 0.7291356921195984, 'btn distance=6')
#     (0.0, 0, 0.8408181667327881, 'btn distance=4')
#     (0.0, 0, 0.11172295361757278, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.10479549318552017, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (2.22404146194458, 1, 2.22404146194458, 'btn distance=5')
#     (-1.6705204, 0, 0, 'bias')
#     (-1.565030813217163, 1, -1.565030813217163, 'player-0:state-active')
#     (-1.4174758195877075, 1, -1.4174758195877075, 'round level 2')
#     (0.6621841788291931, 1, 0.6621841788291931, 'street-preflop')
#     (0.5574582020441691, 0.6666666666666666, 0.8361873030662537, 'player-9:history')
#     (0.5145376920700073, 1, 0.5145376920700073, 'player-1:state-active')
#     (0.462638258934021, 1, 0.462638258934021, 'player-9:state-active')
#     (0.3592289388179779, 1, 0.3592289388179779, 'player-7:state-active')
#     (-0.26677846908569336, 1, -0.26677846908569336, 'player-3:state-active')
#     (0.24217601427435875, 0.673, 0.35984548926353455, 'cards')
#     (0.2243090718984604, 1, 0.2243090718984604, 'player-2:state-active')
#     (-0.19515249133110046, 1, -0.19515249133110046, 'player-4:state-active')
#     (-0.16455483281612396, 0.0995, -1.6538174152374268, 'player-7:stack')
#     (-0.16380187273025515, 0.1, -1.6380187273025513, 'player-4:stack')
#     (-0.15894933983683587, 0.09925, -1.6015046834945679, 'player-6:stack')
#     (0.14615123271942138, 0.095, 1.5384340286254883, 'player-0:stack')
#     (-0.13326185941696167, 0.1, -1.3326185941696167, 'player-3:stack')
#     (-0.1269157544374466, 0.09975, -1.2723383903503418, 'player-5:stack')
#     (-0.09066972732543946, 0.1, -0.9066972732543945, 'player-1:stack')
#     (-0.07986369729042053, 0.1, -0.7986369729042053, 'player-2:stack')
#     (0.07596080170737372, 0.2222222222222222, 0.34182360768318176, 'player-7:history')
#     (0.06404073370827569, 0.1111111111111111, 0.5763666033744812, 'player-6:history')
#     (-0.06195943430066109, 1, -0.06195943430066109, 'player-5:state-active')
#     (-0.06022270560264587, 0.10575, -0.5694818496704102, 'player-8:stack')
#     (0.050377484411001205, 1, 0.050377484411001205, 'player-8:state-fold')
#     (0.01677285100519657, 0.0985, 0.1702827513217926, 'player-9:stack')
#     (-0.011722148396074772, 1, -0.011722148396074772, 'player-6:state-active')
#     (-0.0025490641593933104, 0.00225, -1.1329174041748047, 'pot')
#     (0.0, 0, 0.5947113037109375, 'player-9:state-fold')
#     (0.0, 0.0, 0.5487900376319885, 'player-8:history')
#     (0.0, 0, 0.31320011615753174, 'player-8:state-active')
#     (0.0, 0, 0.22495703399181366, 'player-7:state-fold')
#     (-0.0, 0, -0.314838707447052, 'player-6:state-fold')
#     (0.0, 0.0, 4.557852745056152, 'player-5:history')
#     (-0.0, 0, -0.16778706014156342, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.3006676733493805, 'player-4:state-fold')
#     (0.0, 0.0, 1.2594202756881714, 'player-3:history')
#     (-0.0, 0, -0.18486566841602325, 'player-3:state-fold')
#     (0.0, 0.0, 1.3610700368881226, 'player-2:history')
#     (0.0, 0, 0.05764586478471756, 'player-2:state-fold')
#     (0.0, 0.0, 1.5406986474990845, 'player-1:history')
#     (0.0, 0, 0.4644852578639984, 'player-1:state-fold')
#     (0.0, 0.0, 3.0044336318969727, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 0.5740861892700195, 'street-river')
#     (0.0, 0, 0.23288992047309875, 'street-turn')
#     (0.0, 0, 0.1424984335899353, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 2.2067880630493164, 'btn distance=6')
#     (0.0, 0, 2.325878381729126, 'btn distance=4')
#     (0.0, 0, 0.25714433193206787, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (-0.0, 0, -0.027183566242456436, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (2.3336832523345947, 1, 2.3336832523345947, 'btn distance=5')
#     (-2.2201684, 0, 0, 'bias')
#     (-2.0789220333099365, 1, -2.0789220333099365, 'round level 2')
#     (-1.998337984085083, 1, -1.998337984085083, 'player-0:state-active')
#     (1.8561913967132568, 1, 1.8561913967132568, 'street-preflop')
#     (0.8981153964996338, 1, 0.8981153964996338, 'player-2:state-active')
#     (0.6065862973531086, 0.6666666666666666, 0.9098794460296631, 'player-9:history')
#     (0.5129716396331787, 1, 0.5129716396331787, 'player-1:state-active')
#     (0.4734603762626648, 1, 0.4734603762626648, 'player-9:state-active')
#     (-0.31149518489837646, 1, -0.31149518489837646, 'player-6:state-active')
#     (0.30269142985343933, 1, 0.30269142985343933, 'player-8:state-fold')
#     (0.2394191324710846, 1, 0.2394191324710846, 'player-7:state-active')
#     (-0.21673645174503328, 0.0995, -2.178255796432495, 'player-7:stack')
#     (-0.20419166088104249, 0.1, -2.041916608810425, 'player-4:stack')
#     (-0.1828493573665619, 0.09925, -1.842310905456543, 'player-6:stack')
#     (-0.18097137212753298, 0.1, -1.8097137212753296, 'player-3:stack')
#     (0.14121900498867035, 1, 0.14121900498867035, 'player-3:state-active')
#     (-0.11701351404190063, 1, -0.11701351404190063, 'player-4:state-active')
#     (0.11196017265319824, 0.1111111111111111, 1.0076415538787842, 'player-6:history')
#     (-0.10727992513775826, 0.09975, -1.0754879713058472, 'player-5:stack')
#     (-0.08878108263015748, 0.1, -0.8878108263015747, 'player-1:stack')
#     (0.08243725448846817, 1, 0.08243725448846817, 'player-5:state-active')
#     (-0.07153239548206329, 0.10575, -0.676429271697998, 'player-8:stack')
#     (0.046267872601747514, 0.095, 0.4870302379131317, 'player-0:stack')
#     (0.04531296756532457, 0.2222222222222222, 0.20390835404396057, 'player-7:history')
#     (-0.04500005008280277, 0.0985, -0.45685330033302307, 'player-9:stack')
#     (-0.03563198447227478, 0.1, -0.3563198447227478, 'player-2:stack')
#     (0.0036864751209504903, 0.673, 0.005477674771100283, 'cards')
#     (-0.003497304707765579, 0.00225, -1.554357647895813, 'pot')
#     (0.0, 0, 0.6524067521095276, 'player-9:state-fold')
#     (0.0, 0.0, 0.5701652765274048, 'player-8:history')
#     (0.0, 0, 0.3940722644329071, 'player-8:state-active')
#     (0.0, 0, 0.19231440126895905, 'player-7:state-fold')
#     (-0.0, 0, -0.24992208182811737, 'player-6:state-fold')
#     (0.0, 0.0, 3.4297122955322266, 'player-5:history')
#     (0.0, 0, 0.057786691933870316, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.10096412897109985, 'player-4:state-fold')
#     (0.0, 0.0, 0.4895218312740326, 'player-3:history')
#     (0.0, 0, 0.1697189062833786, 'player-3:state-fold')
#     (0.0, 0.0, 0.7493898868560791, 'player-2:history')
#     (0.0, 0, 0.7233438491821289, 'player-2:state-fold')
#     (0.0, 0.0, 0.45885005593299866, 'player-1:history')
#     (0.0, 0, 0.4630233347415924, 'player-1:state-fold')
#     (0.0, 0.0, 0.8247711062431335, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 1.6931723356246948, 'street-river')
#     (0.0, 0, 1.9459458589553833, 'street-turn')
#     (0.0, 0, 1.8393696546554565, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 2.374540328979492, 'btn distance=6')
#     (0.0, 0, 2.5783846378326416, 'btn distance=4')
#     (0.0, 0, 0.3861742615699768, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (2.4277405738830566, 1, 2.4277405738830566, 'btn distance=5')
#     (-2.1693177223205566, 1, -2.1693177223205566, 'round level 2')
#     (-2.0899353, 0, 0, 'bias')
#     (-1.989793062210083, 1, -1.989793062210083, 'player-0:state-active')
#     (1.5268641710281372, 1, 1.5268641710281372, 'street-preflop')
#     (0.9448767900466919, 1, 0.9448767900466919, 'player-8:state-fold')
#     (0.6356079578399658, 1, 0.6356079578399658, 'player-7:state-active')
#     (0.4935045540332794, 1, 0.4935045540332794, 'player-1:state-active')
#     (0.47276270389556885, 0.6666666666666666, 0.7091440558433533, 'player-9:history')
#     (0.4694209694862366, 1, 0.4694209694862366, 'player-9:state-active')
#     (0.2826194167137146, 1, 0.2826194167137146, 'player-2:state-active')
#     (-0.22753516745567323, 0.0995, -2.28678560256958, 'player-7:stack')
#     (-0.2180684618353844, 0.09925, -2.1971633434295654, 'player-6:stack')
#     (-0.20103013515472412, 0.1, -2.010301351547241, 'player-4:stack')
#     (-0.19620796442031863, 0.1, -1.962079644203186, 'player-3:stack')
#     (0.16865869363149005, 0.1111111111111111, 1.5179282426834106, 'player-6:history')
#     (0.16314665973186493, 1, 0.16314665973186493, 'player-3:state-active')
#     (-0.13846114656329156, 0.09975, -1.388081669807434, 'player-5:stack')
#     (-0.13577983379364014, 0.1, -1.3577983379364014, 'player-2:stack')
#     (-0.12167444080114365, 1, -0.12167444080114365, 'player-5:state-active')
#     (-0.11367033421993256, 1, -0.11367033421993256, 'player-4:state-active')
#     (-0.11291946396231652, 0.10575, -1.0677963495254517, 'player-8:stack')
#     (0.1096388300259908, 0.2222222222222222, 0.4933747351169586, 'player-7:history')
#     (-0.0986370325088501, 0.1, -0.986370325088501, 'player-1:stack')
#     (0.0649658739566803, 1, 0.0649658739566803, 'player-6:state-active')
#     (-0.06241173672676087, 0.0985, -0.6336216926574707, 'player-9:stack')
#     (0.01040737733244896, 0.095, 0.109551340341568, 'player-0:stack')
#     (0.006929277058690787, 0.673, 0.010296102613210678, 'cards')
#     (-0.005227649509906769, 0.00225, -2.323399782180786, 'pot')
#     (0.0, 0, 0.6580949425697327, 'player-9:state-fold')
#     (0.0, 0.0, 0.5972527265548706, 'player-8:history')
#     (0.0, 0, 0.9683846831321716, 'player-8:state-active')
#     (0.0, 0, 0.5415549874305725, 'player-7:state-fold')
#     (-0.0, 0, -0.1039939895272255, 'player-6:state-fold')
#     (0.0, 0.0, 4.063137054443359, 'player-5:history')
#     (-0.0, 0, -0.08493565768003464, 'player-5:state-fold')
#     (0.0, 0.0, 0.6780285835266113, 'player-4:history')
#     (-0.0, 0, -0.015592820942401886, 'player-4:state-fold')
#     (0.0, 0.0, 0.9237784147262573, 'player-3:history')
#     (0.0, 0, 0.31402891874313354, 'player-3:state-fold')
#     (0.0, 0.0, 0.6499181985855103, 'player-2:history')
#     (0.0, 0, 0.6079424619674683, 'player-2:state-fold')
#     (0.0, 0.0, 0.31196364760398865, 'player-1:history')
#     (0.0, 0, 0.35019147396087646, 'player-1:state-fold')
#     (0.0, 0.0, 1.1408227682113647, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 1.5670738220214844, 'street-river')
#     (0.0, 0, 1.3895366191864014, 'street-turn')
#     (0.0, 0, 1.4037833213806152, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 2.3866612911224365, 'btn distance=6')
#     (0.0, 0, 2.6131505966186523, 'btn distance=4')
#     (0.0, 0, 0.3329910337924957, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (-0.0, 0, -0.01431115809828043, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (2.5488789081573486, 1, 2.5488789081573486, 'btn distance=5')
#     (-2.31951904296875, 1, -2.31951904296875, 'round level 2')
#     (-2.1535284519195557, 1, -2.1535284519195557, 'player-0:state-active')
#     (-2.1036038, 0, 0, 'bias')
#     (1.4314368963241577, 1, 1.4314368963241577, 'street-preflop')
#     (0.9965319037437439, 1, 0.9965319037437439, 'player-8:state-fold')
#     (0.6645270983378092, 0.6666666666666666, 0.9967906475067139, 'player-9:history')
#     (0.6117324233055115, 1, 0.6117324233055115, 'player-7:state-active')
#     (0.49769866466522217, 1, 0.49769866466522217, 'player-1:state-active')
#     (0.41812750697135925, 1, 0.41812750697135925, 'player-9:state-active')
#     (0.22700640559196472, 1, 0.22700640559196472, 'player-2:state-active')
#     (-0.21127002197504044, 0.09925, -2.1286652088165283, 'player-6:stack')
#     (-0.19895819425582886, 0.1, -1.9895819425582886, 'player-4:stack')
#     (-0.19017614126205445, 0.1, -1.9017614126205444, 'player-3:stack')
#     (-0.18949980276823045, 0.0995, -1.9045206308364868, 'player-7:stack')
#     (0.18947344356113008, 0.1111111111111111, 1.705260992050171, 'player-6:history')
#     (-0.1555991852581501, 0.09975, -1.5598915815353394, 'player-5:stack')
#     (0.1423758715391159, 1, 0.1423758715391159, 'player-3:state-active')
#     (0.12941569089889526, 1, 0.12941569089889526, 'player-5:state-active')
#     (-0.12825465202331543, 0.1, -1.2825465202331543, 'player-1:stack')
#     (-0.12473980057239532, 0.10575, -1.179572582244873, 'player-8:stack')
#     (0.12353711658053927, 0.2222222222222222, 0.5559170246124268, 'player-7:history')
#     (-0.12270451784133912, 0.1, -1.2270451784133911, 'player-2:stack')
#     (-0.08608841416239739, 0.0985, -0.8739940524101257, 'player-9:stack')
#     (-0.02029792219400406, 1, -0.02029792219400406, 'player-6:state-active')
#     (0.01680748462677002, 0.095, 0.17692089080810547, 'player-0:stack')
#     (-0.011390859261155128, 1, -0.011390859261155128, 'player-4:state-active')
#     (-0.003450714200735092, 0.00225, -1.5336507558822632, 'pot')
#     (-0.0003661369601031766, 0.673, -0.0005440370878204703, 'cards')
#     (0.0, 0, 0.6664431095123291, 'player-9:state-fold')
#     (0.0, 0.0, 0.8489145636558533, 'player-8:history')
#     (0.0, 0, 0.904315173625946, 'player-8:state-active')
#     (0.0, 0, 0.4935069680213928, 'player-7:state-fold')
#     (-0.0, 0, -0.21435418725013733, 'player-6:state-fold')
#     (0.0, 0.0, 3.725745439529419, 'player-5:history')
#     (0.0, 0, 0.15621395409107208, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.12340544909238815, 'player-4:state-fold')
#     (0.0, 0.0, 0.8774658441543579, 'player-3:history')
#     (0.0, 0, 0.2819548547267914, 'player-3:state-fold')
#     (0.0, 0.0, 0.7273887395858765, 'player-2:history')
#     (0.0, 0, 0.5529121160507202, 'player-2:state-fold')
#     (0.0, 0.0, 0.8880079388618469, 'player-1:history')
#     (0.0, 0, 0.4988119900226593, 'player-1:state-fold')
#     (0.0, 0.0, 0.6189841628074646, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 1.314842700958252, 'street-river')
#     (0.0, 0, 1.4213526248931885, 'street-turn')
#     (0.0, 0, 1.5551739931106567, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 2.428459644317627, 'btn distance=6')
#     (0.0, 0, 2.6901073455810547, 'btn distance=4')
#     (0.0, 0, 0.4982319474220276, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (-1.7271546125411987, 1, -1.7271546125411987, 'player-0:state-active')
#     (1.6758811473846436, 1, 1.6758811473846436, 'btn distance=5')
#     (-1.671335, 0, 0, 'bias')
#     (1.665412425994873, 1, 1.665412425994873, 'street-preflop')
#     (-1.649506688117981, 1, -1.649506688117981, 'round level 2')
#     (0.6320634682973225, 0.6666666666666666, 0.9480952024459839, 'player-9:history')
#     (0.3634771704673767, 1, 0.3634771704673767, 'player-9:state-active')
#     (0.3599641025066376, 1, 0.3599641025066376, 'player-7:state-active')
#     (0.31775495409965515, 1, 0.31775495409965515, 'player-2:state-active')
#     (0.29196155071258545, 1, 0.29196155071258545, 'player-1:state-active')
#     (-0.20801792764663699, 0.0995, -2.090632438659668, 'player-7:stack')
#     (0.1915341317653656, 1, 0.1915341317653656, 'player-8:state-fold')
#     (-0.1869731664657593, 0.1, -1.8697316646575928, 'player-4:stack')
#     (-0.18135348558425904, 0.1, -1.8135348558425903, 'player-3:stack')
#     (-0.1686408668756485, 1, -0.1686408668756485, 'player-6:state-active')
#     (-0.1591462755203247, 0.09925, -1.6034889221191406, 'player-6:stack')
#     (0.10524059295654296, 0.095, 1.1077957153320312, 'player-0:stack')
#     (0.08522438257932663, 1, 0.08522438257932663, 'player-4:state-active')
#     (-0.07722781375050546, 0.09975, -0.7742136716842651, 'player-5:stack')
#     (0.0622137188911438, 0.1111111111111111, 0.5599234700202942, 'player-6:history')
#     (-0.041863877326250076, 1, -0.041863877326250076, 'player-5:state-active')
#     (0.024999359250068666, 0.1, 0.24999359250068665, 'player-2:stack')
#     (-0.015894461423158646, 1, -0.015894461423158646, 'player-3:state-active')
#     (0.014063027169969346, 0.2222222222222222, 0.06328362226486206, 'player-7:history')
#     (0.014001151174306871, 0.0985, 0.14214366674423218, 'player-9:stack')
#     (0.004903096021618695, 0.673, 0.0072854324243962765, 'cards')
#     (0.0014251514337956907, 0.1, 0.014251514337956905, 'player-1:stack')
#     (-0.0013150370421353727, 0.10575, -0.012435338459908962, 'player-8:stack')
#     (0.0010350157096982002, 0.00225, 0.460006982088089, 'pot')
#     (0.0, 0, 0.765361487865448, 'player-9:state-fold')
#     (0.0, 0.0, 0.5864446759223938, 'player-8:history')
#     (0.0, 0, 0.05815807357430458, 'player-8:state-active')
#     (0.0, 0, 0.6200821399688721, 'player-7:state-fold')
#     (-0.0, 0, -0.02465648762881756, 'player-6:state-fold')
#     (0.0, 0.0, 1.7668896913528442, 'player-5:history')
#     (-0.0, 0, -0.21264591813087463, 'player-5:state-fold')
#     (0.0, 0.0, 0.6586898565292358, 'player-4:history')
#     (-0.0, 0, -0.022165140137076378, 'player-4:state-fold')
#     (0.0, 0.0, 0.07129468768835068, 'player-3:history')
#     (-0.0, 0, -0.11512207239866257, 'player-3:state-fold')
#     (0.0, 0.0, 0.2524775266647339, 'player-2:history')
#     (0.0, 0, 0.005736817605793476, 'player-2:state-fold')
#     (0.0, 0.0, 0.19451376795768738, 'player-1:history')
#     (0.0, 0, 0.29147276282310486, 'player-1:state-fold')
#     (0.0, 0.0, 0.5361006855964661, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 1.5800559520721436, 'street-river')
#     (0.0, 0, 1.5945707559585571, 'street-turn')
#     (0.0, 0, 1.6251622438430786, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 1.6743172407150269, 'btn distance=6')
#     (0.0, 0, 2.0806338787078857, 'btn distance=4')
#     (-0.0, 0, -0.02149493806064129, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.07707057148218155, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### DOUBLE_RAISE する場面2

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 9500]
# -- hole card --
#   - ['S3', 'C2']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925 <= SB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 10525 <= BB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10575
#     - 6 : agent (uuid-0) => state : participating, stack : 9500 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 9500
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 150 (double_raise) ] at round 3
#   => [('fold', 0.09288537502288818), ('call', -0.346724271774292), ('min_raise', -0.005796670913696289), ('double_raise', 0.1087183952331543), ('triple_raise', 0.05268049240112305), ('max_raise', 0.09919750690460205)]
# ** weights and features in detail **
# bias : [-1.55898881 -1.67052042 -2.22016835 -2.0899353  -2.10360384 -1.67133498]
#
# linear combination for fold :
#     (2.9704649448394775, 1, 2.9704649448394775, 'street-preflop')
#     (-1.5589888, 0, 0, 'bias')
#     (-1.5441920757293701, 1, -1.5441920757293701, 'player-0:state-active')
#     (-1.4612571001052856, 1, -1.4612571001052856, 'round level 2')
#     (0.8408181667327881, 1, 0.8408181667327881, 'btn distance=4')
#     (0.6810815334320068, 1, 0.6810815334320068, 'player-9:state-fold')
#     (0.3590715726216634, 0.6666666666666666, 0.5386073589324951, 'player-8:history')
#     (0.25149619579315186, 1, 0.25149619579315186, 'player-2:state-active')
#     (0.20635151863098145, 1, 0.20635151863098145, 'player-4:state-active')
#     (0.1839430332183838, 1, 0.1839430332183838, 'player-6:state-active')
#     (-0.1669168919324875, 1, -0.1669168919324875, 'player-8:state-active')
#     (0.1662919670343399, 1, 0.1662919670343399, 'player-1:state-active')
#     (-0.16571437931060792, 0.09925, -1.6696662902832031, 'player-6:stack')
#     (-0.15399070164561274, 0.09925, -1.5515435934066772, 'player-7:stack')
#     (-0.14752224683761597, 0.1, -1.4752224683761597, 'player-3:stack')
#     (0.13138611614704132, 1, 0.13138611614704132, 'player-5:state-active')
#     (-0.12465298175811768, 0.1, -1.2465298175811768, 'player-4:stack')
#     (-0.11465718746185304, 0.1, -1.1465718746185303, 'player-2:stack')
#     (-0.0930999219417572, 1, -0.0930999219417572, 'player-7:state-active')
#     (0.08109777172406514, 0.3333333333333333, 0.24329331517219543, 'player-7:history')
#     (-0.07537984447181224, 0.10575, -0.7128117680549622, 'player-9:stack')
#     (-0.06994461759924889, 0.09975, -0.7011991739273071, 'player-5:stack')
#     (-0.0686715947240591, 0.10525, -0.6524617075920105, 'player-8:stack')
#     (-0.05961036503314972, 0.095, -0.6274775266647339, 'player-1:stack')
#     (0.01753337986767292, 0.095, 0.18456189334392548, 'player-0:stack')
#     (0.008200302720069885, 1, 0.008200302720069885, 'player-3:state-active')
#     (-0.0007389959245920182, 0.00075, -0.9853278994560242, 'pot')
#     (0.000486524406587705, 0.494, 0.000984867219813168, 'cards')
#     (0.0, 0.0, 0.7250006198883057, 'player-9:history')
#     (0.0, 0, 0.632540762424469, 'player-9:state-active')
#     (-0.0, 0, -0.22895732522010803, 'player-8:state-fold')
#     (-0.0, 0, -0.03917863592505455, 'player-7:state-fold')
#     (0.0, 0.0, 0.47333255410194397, 'player-6:history')
#     (0.0, 0, 0.30152055621147156, 'player-6:state-fold')
#     (0.0, 0.0, 2.2018418312072754, 'player-5:history')
#     (0.0, 0, 0.14345857501029968, 'player-5:state-fold')
#     (0.0, 0.0, 0.7096555829048157, 'player-4:history')
#     (0.0, 0, 0.3477531671524048, 'player-4:state-fold')
#     (0.0, 0.0, 0.38791540265083313, 'player-3:history')
#     (-0.0, 0, -0.05360166355967522, 'player-3:state-fold')
#     (0.0, 0.0, 0.17896975576877594, 'player-2:history')
#     (0.0, 0, 0.17204277217388153, 'player-2:state-fold')
#     (0.0, 0.0, 0.3307403028011322, 'player-1:history')
#     (0.0, 0, 0.19814316928386688, 'player-1:state-fold')
#     (0.0, 0.0, 0.288990318775177, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 2.4131579399108887, 'street-river')
#     (0.0, 0, 2.957214593887329, 'street-turn')
#     (0.0, 0, 2.995706558227539, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 0.7291356921195984, 'btn distance=6')
#     (0.0, 0, 0.7153593301773071, 'btn distance=5')
#     (0.0, 0, 0.11172295361757278, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.10479549318552017, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (2.325878381729126, 1, 2.325878381729126, 'btn distance=4')
#     (-1.6705204, 0, 0, 'bias')
#     (-1.565030813217163, 1, -1.565030813217163, 'player-0:state-active')
#     (-1.4174758195877075, 1, -1.4174758195877075, 'round level 2')
#     (0.6621841788291931, 1, 0.6621841788291931, 'street-preflop')
#     (0.5947113037109375, 1, 0.5947113037109375, 'player-9:state-fold')
#     (0.5145376920700073, 1, 0.5145376920700073, 'player-1:state-active')
#     (0.3658600250879923, 0.6666666666666666, 0.5487900376319885, 'player-8:history')
#     (0.3592289388179779, 1, 0.3592289388179779, 'player-7:state-active')
#     (0.31320011615753174, 1, 0.31320011615753174, 'player-8:state-active')
#     (-0.26677846908569336, 1, -0.26677846908569336, 'player-3:state-active')
#     (0.2243090718984604, 1, 0.2243090718984604, 'player-2:state-active')
#     (-0.19515249133110046, 1, -0.19515249133110046, 'player-4:state-active')
#     (0.17776367169618607, 0.494, 0.35984548926353455, 'cards')
#     (-0.1641413784623146, 0.09925, -1.6538174152374268, 'player-7:stack')
#     (-0.16380187273025515, 0.1, -1.6380187273025513, 'player-4:stack')
#     (-0.15894933983683587, 0.09925, -1.6015046834945679, 'player-6:stack')
#     (0.14615123271942138, 0.095, 1.5384340286254883, 'player-0:stack')
#     (-0.13326185941696167, 0.1, -1.3326185941696167, 'player-3:stack')
#     (-0.1269157544374466, 0.09975, -1.2723383903503418, 'player-5:stack')
#     (0.11394120256106058, 0.3333333333333333, 0.34182360768318176, 'player-7:history')
#     (-0.08613624095916748, 0.095, -0.9066972732543945, 'player-1:stack')
#     (-0.07986369729042053, 0.1, -0.7986369729042053, 'player-2:stack')
#     (-0.06195943430066109, 1, -0.06195943430066109, 'player-5:state-active')
#     (-0.059937964677810665, 0.10525, -0.5694818496704102, 'player-8:stack')
#     (0.018007400952279567, 0.10575, 0.1702827513217926, 'player-9:stack')
#     (-0.011722148396074772, 1, -0.011722148396074772, 'player-6:state-active')
#     (-0.0008496880531311035, 0.00075, -1.1329174041748047, 'pot')
#     (0.0, 0.0, 0.8361873030662537, 'player-9:history')
#     (0.0, 0, 0.462638258934021, 'player-9:state-active')
#     (0.0, 0, 0.050377484411001205, 'player-8:state-fold')
#     (0.0, 0, 0.22495703399181366, 'player-7:state-fold')
#     (0.0, 0.0, 0.5763666033744812, 'player-6:history')
#     (-0.0, 0, -0.314838707447052, 'player-6:state-fold')
#     (0.0, 0.0, 4.557852745056152, 'player-5:history')
#     (-0.0, 0, -0.16778706014156342, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.3006676733493805, 'player-4:state-fold')
#     (0.0, 0.0, 1.2594202756881714, 'player-3:history')
#     (-0.0, 0, -0.18486566841602325, 'player-3:state-fold')
#     (0.0, 0.0, 1.3610700368881226, 'player-2:history')
#     (0.0, 0, 0.05764586478471756, 'player-2:state-fold')
#     (0.0, 0.0, 1.5406986474990845, 'player-1:history')
#     (0.0, 0, 0.4644852578639984, 'player-1:state-fold')
#     (0.0, 0.0, 3.0044336318969727, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 0.5740861892700195, 'street-river')
#     (0.0, 0, 0.23288992047309875, 'street-turn')
#     (0.0, 0, 0.1424984335899353, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 2.2067880630493164, 'btn distance=6')
#     (0.0, 0, 2.22404146194458, 'btn distance=5')
#     (0.0, 0, 0.25714433193206787, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (-0.0, 0, -0.027183566242456436, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (2.5783846378326416, 1, 2.5783846378326416, 'btn distance=4')
#     (-2.2201684, 0, 0, 'bias')
#     (-2.0789220333099365, 1, -2.0789220333099365, 'round level 2')
#     (-1.998337984085083, 1, -1.998337984085083, 'player-0:state-active')
#     (1.8561913967132568, 1, 1.8561913967132568, 'street-preflop')
#     (0.8981153964996338, 1, 0.8981153964996338, 'player-2:state-active')
#     (0.6524067521095276, 1, 0.6524067521095276, 'player-9:state-fold')
#     (0.5129716396331787, 1, 0.5129716396331787, 'player-1:state-active')
#     (0.3940722644329071, 1, 0.3940722644329071, 'player-8:state-active')
#     (0.38011018435160315, 0.6666666666666666, 0.5701652765274048, 'player-8:history')
#     (-0.31149518489837646, 1, -0.31149518489837646, 'player-6:state-active')
#     (0.2394191324710846, 1, 0.2394191324710846, 'player-7:state-active')
#     (-0.21619188779592516, 0.09925, -2.178255796432495, 'player-7:stack')
#     (-0.20419166088104249, 0.1, -2.041916608810425, 'player-4:stack')
#     (-0.1828493573665619, 0.09925, -1.842310905456543, 'player-6:stack')
#     (-0.18097137212753298, 0.1, -1.8097137212753296, 'player-3:stack')
#     (0.14121900498867035, 1, 0.14121900498867035, 'player-3:state-active')
#     (-0.11701351404190063, 1, -0.11701351404190063, 'player-4:state-active')
#     (-0.10727992513775826, 0.09975, -1.0754879713058472, 'player-5:stack')
#     (-0.0843420284986496, 0.095, -0.8878108263015747, 'player-1:stack')
#     (0.08243725448846817, 1, 0.08243725448846817, 'player-5:state-active')
#     (-0.07119418084621429, 0.10525, -0.676429271697998, 'player-8:stack')
#     (0.06796945134798685, 0.3333333333333333, 0.20390835404396057, 'player-7:history')
#     (-0.04831223651021719, 0.10575, -0.45685330033302307, 'player-9:stack')
#     (0.046267872601747514, 0.095, 0.4870302379131317, 'player-0:stack')
#     (-0.03563198447227478, 0.1, -0.3563198447227478, 'player-2:stack')
#     (0.0027059713369235396, 0.494, 0.005477674771100283, 'cards')
#     (-0.0011657682359218597, 0.00075, -1.554357647895813, 'pot')
#     (0.0, 0.0, 0.9098794460296631, 'player-9:history')
#     (0.0, 0, 0.4734603762626648, 'player-9:state-active')
#     (0.0, 0, 0.30269142985343933, 'player-8:state-fold')
#     (0.0, 0, 0.19231440126895905, 'player-7:state-fold')
#     (0.0, 0.0, 1.0076415538787842, 'player-6:history')
#     (-0.0, 0, -0.24992208182811737, 'player-6:state-fold')
#     (0.0, 0.0, 3.4297122955322266, 'player-5:history')
#     (0.0, 0, 0.057786691933870316, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.10096412897109985, 'player-4:state-fold')
#     (0.0, 0.0, 0.4895218312740326, 'player-3:history')
#     (0.0, 0, 0.1697189062833786, 'player-3:state-fold')
#     (0.0, 0.0, 0.7493898868560791, 'player-2:history')
#     (0.0, 0, 0.7233438491821289, 'player-2:state-fold')
#     (0.0, 0.0, 0.45885005593299866, 'player-1:history')
#     (0.0, 0, 0.4630233347415924, 'player-1:state-fold')
#     (0.0, 0.0, 0.8247711062431335, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 1.6931723356246948, 'street-river')
#     (0.0, 0, 1.9459458589553833, 'street-turn')
#     (0.0, 0, 1.8393696546554565, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 2.374540328979492, 'btn distance=6')
#     (0.0, 0, 2.3336832523345947, 'btn distance=5')
#     (0.0, 0, 0.3861742615699768, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (2.6131505966186523, 1, 2.6131505966186523, 'btn distance=4')
#     (-2.1693177223205566, 1, -2.1693177223205566, 'round level 2')
#     (-2.0899353, 0, 0, 'bias')
#     (-1.989793062210083, 1, -1.989793062210083, 'player-0:state-active')
#     (1.5268641710281372, 1, 1.5268641710281372, 'street-preflop')
#     (0.9683846831321716, 1, 0.9683846831321716, 'player-8:state-active')
#     (0.6580949425697327, 1, 0.6580949425697327, 'player-9:state-fold')
#     (0.6356079578399658, 1, 0.6356079578399658, 'player-7:state-active')
#     (0.4935045540332794, 1, 0.4935045540332794, 'player-1:state-active')
#     (0.3981684843699137, 0.6666666666666666, 0.5972527265548706, 'player-8:history')
#     (0.2826194167137146, 1, 0.2826194167137146, 'player-2:state-active')
#     (-0.22696347105503084, 0.09925, -2.28678560256958, 'player-7:stack')
#     (-0.2180684618353844, 0.09925, -2.1971633434295654, 'player-6:stack')
#     (-0.20103013515472412, 0.1, -2.010301351547241, 'player-4:stack')
#     (-0.19620796442031863, 0.1, -1.962079644203186, 'player-3:stack')
#     (0.1644582450389862, 0.3333333333333333, 0.4933747351169586, 'player-7:history')
#     (0.16314665973186493, 1, 0.16314665973186493, 'player-3:state-active')
#     (-0.13846114656329156, 0.09975, -1.388081669807434, 'player-5:stack')
#     (-0.13577983379364014, 0.1, -1.3577983379364014, 'player-2:stack')
#     (-0.12167444080114365, 1, -0.12167444080114365, 'player-5:state-active')
#     (-0.11367033421993256, 1, -0.11367033421993256, 'player-4:state-active')
#     (-0.11238556578755378, 0.10525, -1.0677963495254517, 'player-8:stack')
#     (-0.0937051808834076, 0.095, -0.986370325088501, 'player-1:stack')
#     (-0.06700549399852752, 0.10575, -0.6336216926574707, 'player-9:stack')
#     (0.0649658739566803, 1, 0.0649658739566803, 'player-6:state-active')
#     (0.01040737733244896, 0.095, 0.109551340341568, 'player-0:stack')
#     (0.005086274690926075, 0.494, 0.010296102613210678, 'cards')
#     (-0.0017425498366355897, 0.00075, -2.323399782180786, 'pot')
#     (0.0, 0.0, 0.7091440558433533, 'player-9:history')
#     (0.0, 0, 0.4694209694862366, 'player-9:state-active')
#     (0.0, 0, 0.9448767900466919, 'player-8:state-fold')
#     (0.0, 0, 0.5415549874305725, 'player-7:state-fold')
#     (0.0, 0.0, 1.5179282426834106, 'player-6:history')
#     (-0.0, 0, -0.1039939895272255, 'player-6:state-fold')
#     (0.0, 0.0, 4.063137054443359, 'player-5:history')
#     (-0.0, 0, -0.08493565768003464, 'player-5:state-fold')
#     (0.0, 0.0, 0.6780285835266113, 'player-4:history')
#     (-0.0, 0, -0.015592820942401886, 'player-4:state-fold')
#     (0.0, 0.0, 0.9237784147262573, 'player-3:history')
#     (0.0, 0, 0.31402891874313354, 'player-3:state-fold')
#     (0.0, 0.0, 0.6499181985855103, 'player-2:history')
#     (0.0, 0, 0.6079424619674683, 'player-2:state-fold')
#     (0.0, 0.0, 0.31196364760398865, 'player-1:history')
#     (0.0, 0, 0.35019147396087646, 'player-1:state-fold')
#     (0.0, 0.0, 1.1408227682113647, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 1.5670738220214844, 'street-river')
#     (0.0, 0, 1.3895366191864014, 'street-turn')
#     (0.0, 0, 1.4037833213806152, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 2.3866612911224365, 'btn distance=6')
#     (0.0, 0, 2.4277405738830566, 'btn distance=5')
#     (0.0, 0, 0.3329910337924957, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (-0.0, 0, -0.01431115809828043, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (2.6901073455810547, 1, 2.6901073455810547, 'btn distance=4')
#     (-2.31951904296875, 1, -2.31951904296875, 'round level 2')
#     (-2.1535284519195557, 1, -2.1535284519195557, 'player-0:state-active')
#     (-2.1036038, 0, 0, 'bias')
#     (1.4314368963241577, 1, 1.4314368963241577, 'street-preflop')
#     (0.904315173625946, 1, 0.904315173625946, 'player-8:state-active')
#     (0.6664431095123291, 1, 0.6664431095123291, 'player-9:state-fold')
#     (0.6117324233055115, 1, 0.6117324233055115, 'player-7:state-active')
#     (0.5659430424372355, 0.6666666666666666, 0.8489145636558533, 'player-8:history')
#     (0.49769866466522217, 1, 0.49769866466522217, 'player-1:state-active')
#     (0.22700640559196472, 1, 0.22700640559196472, 'player-2:state-active')
#     (-0.21127002197504044, 0.09925, -2.1286652088165283, 'player-6:stack')
#     (-0.19895819425582886, 0.1, -1.9895819425582886, 'player-4:stack')
#     (-0.19017614126205445, 0.1, -1.9017614126205444, 'player-3:stack')
#     (-0.18902367261052133, 0.09925, -1.9045206308364868, 'player-7:stack')
#     (0.1853056748708089, 0.3333333333333333, 0.5559170246124268, 'player-7:history')
#     (-0.1555991852581501, 0.09975, -1.5598915815353394, 'player-5:stack')
#     (0.1423758715391159, 1, 0.1423758715391159, 'player-3:state-active')
#     (0.12941569089889526, 1, 0.12941569089889526, 'player-5:state-active')
#     (-0.12415001428127288, 0.10525, -1.179572582244873, 'player-8:stack')
#     (-0.12270451784133912, 0.1, -1.2270451784133911, 'player-2:stack')
#     (-0.12184191942214966, 0.095, -1.2825465202331543, 'player-1:stack')
#     (-0.0924248710423708, 0.10575, -0.8739940524101257, 'player-9:stack')
#     (-0.02029792219400406, 1, -0.02029792219400406, 'player-6:state-active')
#     (0.01680748462677002, 0.095, 0.17692089080810547, 'player-0:stack')
#     (-0.011390859261155128, 1, -0.011390859261155128, 'player-4:state-active')
#     (-0.0011502380669116974, 0.00075, -1.5336507558822632, 'pot')
#     (-0.00026875432138331233, 0.494, -0.0005440370878204703, 'cards')
#     (0.0, 0.0, 0.9967906475067139, 'player-9:history')
#     (0.0, 0, 0.41812750697135925, 'player-9:state-active')
#     (0.0, 0, 0.9965319037437439, 'player-8:state-fold')
#     (0.0, 0, 0.4935069680213928, 'player-7:state-fold')
#     (0.0, 0.0, 1.705260992050171, 'player-6:history')
#     (-0.0, 0, -0.21435418725013733, 'player-6:state-fold')
#     (0.0, 0.0, 3.725745439529419, 'player-5:history')
#     (0.0, 0, 0.15621395409107208, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.12340544909238815, 'player-4:state-fold')
#     (0.0, 0.0, 0.8774658441543579, 'player-3:history')
#     (0.0, 0, 0.2819548547267914, 'player-3:state-fold')
#     (0.0, 0.0, 0.7273887395858765, 'player-2:history')
#     (0.0, 0, 0.5529121160507202, 'player-2:state-fold')
#     (0.0, 0.0, 0.8880079388618469, 'player-1:history')
#     (0.0, 0, 0.4988119900226593, 'player-1:state-fold')
#     (0.0, 0.0, 0.6189841628074646, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 1.314842700958252, 'street-river')
#     (0.0, 0, 1.4213526248931885, 'street-turn')
#     (0.0, 0, 1.5551739931106567, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 2.428459644317627, 'btn distance=6')
#     (0.0, 0, 2.5488789081573486, 'btn distance=5')
#     (0.0, 0, 0.4982319474220276, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (2.0806338787078857, 1, 2.0806338787078857, 'btn distance=4')
#     (-1.7271546125411987, 1, -1.7271546125411987, 'player-0:state-active')
#     (-1.671335, 0, 0, 'bias')
#     (1.665412425994873, 1, 1.665412425994873, 'street-preflop')
#     (-1.649506688117981, 1, -1.649506688117981, 'round level 2')
#     (0.765361487865448, 1, 0.765361487865448, 'player-9:state-fold')
#     (0.39096311728159583, 0.6666666666666666, 0.5864446759223938, 'player-8:history')
#     (0.3599641025066376, 1, 0.3599641025066376, 'player-7:state-active')
#     (0.31775495409965515, 1, 0.31775495409965515, 'player-2:state-active')
#     (0.29196155071258545, 1, 0.29196155071258545, 'player-1:state-active')
#     (-0.20749526953697206, 0.09925, -2.090632438659668, 'player-7:stack')
#     (-0.1869731664657593, 0.1, -1.8697316646575928, 'player-4:stack')
#     (-0.18135348558425904, 0.1, -1.8135348558425903, 'player-3:stack')
#     (-0.1686408668756485, 1, -0.1686408668756485, 'player-6:state-active')
#     (-0.1591462755203247, 0.09925, -1.6034889221191406, 'player-6:stack')
#     (0.10524059295654296, 0.095, 1.1077957153320312, 'player-0:stack')
#     (0.08522438257932663, 1, 0.08522438257932663, 'player-4:state-active')
#     (-0.07722781375050546, 0.09975, -0.7742136716842651, 'player-5:stack')
#     (0.05815807357430458, 1, 0.05815807357430458, 'player-8:state-active')
#     (-0.041863877326250076, 1, -0.041863877326250076, 'player-5:state-active')
#     (0.024999359250068666, 0.1, 0.24999359250068665, 'player-2:stack')
#     (0.021094540754954018, 0.3333333333333333, 0.06328362226486206, 'player-7:history')
#     (-0.015894461423158646, 1, -0.015894461423158646, 'player-3:state-active')
#     (0.015031692758202552, 0.10575, 0.14214366674423218, 'player-9:stack')
#     (0.0035990036176517604, 0.494, 0.0072854324243962765, 'cards')
#     (0.001353893862105906, 0.095, 0.014251514337956905, 'player-1:stack')
#     (-0.0013088193729054183, 0.10525, -0.012435338459908962, 'player-8:stack')
#     (0.00034500523656606677, 0.00075, 0.460006982088089, 'pot')
#     (0.0, 0.0, 0.9480952024459839, 'player-9:history')
#     (0.0, 0, 0.3634771704673767, 'player-9:state-active')
#     (0.0, 0, 0.1915341317653656, 'player-8:state-fold')
#     (0.0, 0, 0.6200821399688721, 'player-7:state-fold')
#     (0.0, 0.0, 0.5599234700202942, 'player-6:history')
#     (-0.0, 0, -0.02465648762881756, 'player-6:state-fold')
#     (0.0, 0.0, 1.7668896913528442, 'player-5:history')
#     (-0.0, 0, -0.21264591813087463, 'player-5:state-fold')
#     (0.0, 0.0, 0.6586898565292358, 'player-4:history')
#     (-0.0, 0, -0.022165140137076378, 'player-4:state-fold')
#     (0.0, 0.0, 0.07129468768835068, 'player-3:history')
#     (-0.0, 0, -0.11512207239866257, 'player-3:state-fold')
#     (0.0, 0.0, 0.2524775266647339, 'player-2:history')
#     (0.0, 0, 0.005736817605793476, 'player-2:state-fold')
#     (0.0, 0.0, 0.19451376795768738, 'player-1:history')
#     (0.0, 0, 0.29147276282310486, 'player-1:state-fold')
#     (0.0, 0.0, 0.5361006855964661, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 1.5800559520721436, 'street-river')
#     (0.0, 0, 1.5945707559585571, 'street-turn')
#     (0.0, 0, 1.6251622438430786, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 1.6743172407150269, 'btn distance=6')
#     (0.0, 0, 1.6758811473846436, 'btn distance=5')
#     (-0.0, 0, -0.02149493806064129, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.07707057148218155, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### ALLIN する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 500
#   - raise: [850, 9500]
# -- hole card --
#   - ['S3', 'C2']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 725, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9925
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9925 <= SB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10525 <= BB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10575
#     - 6 : agent (uuid-0) => state : participating, stack : 9350 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : folded, stack : 9500
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 9500
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 100, 'paid': 150, 'player': 'agent (uuid=uuid-0)', 'amount': 150, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu1 (uuid=uuid-1)'}
#       - {'add_amount': 350, 'paid': 500, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 500, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
# ======================================================================
# Agent took action [ raise: 9500 (max_raise) ] at round 3
#   => [('fold', 0.06796777248382568), ('call', -0.15162158012390137), ('min_raise', 0.11757254600524902), ('double_raise', 0.07773089408874512), ('triple_raise', 0.009267807006835938), ('max_raise', 0.13184785842895508)]
# ** weights and features in detail **
# bias : [-1.55898881 -1.67052042 -2.22016835 -2.0899353  -2.10360384 -1.67133498]
#
# linear combination for fold :
#     (2.9704649448394775, 1, 2.9704649448394775, 'street-preflop')
#     (-1.5589888, 0, 0, 'bias')
#     (-1.5441920757293701, 1, -1.5441920757293701, 'player-0:state-active')
#     (-1.4612571001052856, 1, -1.4612571001052856, 'round level 2')
#     (0.8408181667327881, 1, 0.8408181667327881, 'btn distance=4')
#     (0.6810815334320068, 1, 0.6810815334320068, 'player-9:state-fold')
#     (0.3477531671524048, 1, 0.3477531671524048, 'player-4:state-fold')
#     (0.30152055621147156, 1, 0.30152055621147156, 'player-6:state-fold')
#     (0.25149619579315186, 1, 0.25149619579315186, 'player-2:state-active')
#     (-0.22895732522010803, 1, -0.22895732522010803, 'player-8:state-fold')
#     (0.19814316928386688, 1, 0.19814316928386688, 'player-1:state-fold')
#     (-0.16571437931060792, 0.09925, -1.6696662902832031, 'player-6:stack')
#     (-0.15399070164561274, 0.09925, -1.5515435934066772, 'player-7:stack')
#     (-0.14752224683761597, 0.1, -1.4752224683761597, 'player-3:stack')
#     (0.14345857501029968, 1, 0.14345857501029968, 'player-5:state-fold')
#     (-0.12465298175811768, 0.1, -1.2465298175811768, 'player-4:stack')
#     (0.12342741777156963, 0.6896551724137931, 0.17896975576877594, 'player-2:history')
#     (-0.10892432808876037, 0.095, -1.1465718746185303, 'player-2:stack')
#     (-0.07537984447181224, 0.10575, -0.7128117680549622, 'player-9:stack')
#     (-0.06994461759924889, 0.09975, -0.7011991739273071, 'player-5:stack')
#     (-0.0686715947240591, 0.10525, -0.6524617075920105, 'player-8:stack')
#     (0.05979110043624352, 0.20689655172413793, 0.288990318775177, 'player-0:history')
#     (-0.05961036503314972, 0.095, -0.6274775266647339, 'player-1:stack')
#     (-0.05360166355967522, 1, -0.05360166355967522, 'player-3:state-fold')
#     (-0.03917863592505455, 1, -0.03917863592505455, 'player-7:state-fold')
#     (0.017256537027657032, 0.0935, 0.18456189334392548, 'player-0:stack')
#     (-0.007143627271056175, 0.00725, -0.9853278994560242, 'pot')
#     (0.000486524406587705, 0.494, 0.000984867219813168, 'cards')
#     (0.0, 0.0, 0.7250006198883057, 'player-9:history')
#     (0.0, 0, 0.632540762424469, 'player-9:state-active')
#     (0.0, 0.0, 0.5386073589324951, 'player-8:history')
#     (-0.0, 0, -0.1669168919324875, 'player-8:state-active')
#     (0.0, 0.0, 0.24329331517219543, 'player-7:history')
#     (-0.0, 0, -0.0930999219417572, 'player-7:state-active')
#     (0.0, 0.0, 0.47333255410194397, 'player-6:history')
#     (0.0, 0, 0.1839430332183838, 'player-6:state-active')
#     (0.0, 0.0, 2.2018418312072754, 'player-5:history')
#     (0.0, 0, 0.13138611614704132, 'player-5:state-active')
#     (0.0, 0.0, 0.7096555829048157, 'player-4:history')
#     (0.0, 0, 0.20635151863098145, 'player-4:state-active')
#     (0.0, 0.0, 0.38791540265083313, 'player-3:history')
#     (0.0, 0, 0.008200302720069885, 'player-3:state-active')
#     (0.0, 0, 0.17204277217388153, 'player-2:state-fold')
#     (0.0, 0.0, 0.3307403028011322, 'player-1:history')
#     (0.0, 0, 0.1662919670343399, 'player-1:state-active')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 2.4131579399108887, 'street-river')
#     (0.0, 0, 2.957214593887329, 'street-turn')
#     (0.0, 0, 2.995706558227539, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 0.7291356921195984, 'btn distance=6')
#     (0.0, 0, 0.7153593301773071, 'btn distance=5')
#     (0.0, 0, 0.11172295361757278, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.10479549318552017, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (2.325878381729126, 1, 2.325878381729126, 'btn distance=4')
#     (-1.6705204, 0, 0, 'bias')
#     (-1.565030813217163, 1, -1.565030813217163, 'player-0:state-active')
#     (-1.4174758195877075, 1, -1.4174758195877075, 'round level 2')
#     (0.9386689909573259, 0.6896551724137931, 1.3610700368881226, 'player-2:history')
#     (0.6621841788291931, 1, 0.6621841788291931, 'street-preflop')
#     (0.6216069583235115, 0.20689655172413793, 3.0044336318969727, 'player-0:history')
#     (0.5947113037109375, 1, 0.5947113037109375, 'player-9:state-fold')
#     (0.4644852578639984, 1, 0.4644852578639984, 'player-1:state-fold')
#     (-0.314838707447052, 1, -0.314838707447052, 'player-6:state-fold')
#     (-0.3006676733493805, 1, -0.3006676733493805, 'player-4:state-fold')
#     (0.22495703399181366, 1, 0.22495703399181366, 'player-7:state-fold')
#     (0.2243090718984604, 1, 0.2243090718984604, 'player-2:state-active')
#     (-0.18486566841602325, 1, -0.18486566841602325, 'player-3:state-fold')
#     (0.17776367169618607, 0.494, 0.35984548926353455, 'cards')
#     (-0.16778706014156342, 1, -0.16778706014156342, 'player-5:state-fold')
#     (-0.1641413784623146, 0.09925, -1.6538174152374268, 'player-7:stack')
#     (-0.16380187273025515, 0.1, -1.6380187273025513, 'player-4:stack')
#     (-0.15894933983683587, 0.09925, -1.6015046834945679, 'player-6:stack')
#     (0.14384358167648315, 0.0935, 1.5384340286254883, 'player-0:stack')
#     (-0.13326185941696167, 0.1, -1.3326185941696167, 'player-3:stack')
#     (-0.1269157544374466, 0.09975, -1.2723383903503418, 'player-5:stack')
#     (-0.08613624095916748, 0.095, -0.9066972732543945, 'player-1:stack')
#     (-0.07587051242589951, 0.095, -0.7986369729042053, 'player-2:stack')
#     (-0.059937964677810665, 0.10525, -0.5694818496704102, 'player-8:stack')
#     (0.050377484411001205, 1, 0.050377484411001205, 'player-8:state-fold')
#     (0.018007400952279567, 0.10575, 0.1702827513217926, 'player-9:stack')
#     (-0.008213651180267335, 0.00725, -1.1329174041748047, 'pot')
#     (0.0, 0.0, 0.8361873030662537, 'player-9:history')
#     (0.0, 0, 0.462638258934021, 'player-9:state-active')
#     (0.0, 0.0, 0.5487900376319885, 'player-8:history')
#     (0.0, 0, 0.31320011615753174, 'player-8:state-active')
#     (0.0, 0.0, 0.34182360768318176, 'player-7:history')
#     (0.0, 0, 0.3592289388179779, 'player-7:state-active')
#     (0.0, 0.0, 0.5763666033744812, 'player-6:history')
#     (-0.0, 0, -0.011722148396074772, 'player-6:state-active')
#     (0.0, 0.0, 4.557852745056152, 'player-5:history')
#     (-0.0, 0, -0.06195943430066109, 'player-5:state-active')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.19515249133110046, 'player-4:state-active')
#     (0.0, 0.0, 1.2594202756881714, 'player-3:history')
#     (-0.0, 0, -0.26677846908569336, 'player-3:state-active')
#     (0.0, 0, 0.05764586478471756, 'player-2:state-fold')
#     (0.0, 0.0, 1.5406986474990845, 'player-1:history')
#     (0.0, 0, 0.5145376920700073, 'player-1:state-active')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 0.5740861892700195, 'street-river')
#     (0.0, 0, 0.23288992047309875, 'street-turn')
#     (0.0, 0, 0.1424984335899353, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 2.2067880630493164, 'btn distance=6')
#     (0.0, 0, 2.22404146194458, 'btn distance=5')
#     (0.0, 0, 0.25714433193206787, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (-0.0, 0, -0.027183566242456436, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (2.5783846378326416, 1, 2.5783846378326416, 'btn distance=4')
#     (-2.2201684, 0, 0, 'bias')
#     (-2.0789220333099365, 1, -2.0789220333099365, 'round level 2')
#     (-1.998337984085083, 1, -1.998337984085083, 'player-0:state-active')
#     (1.8561913967132568, 1, 1.8561913967132568, 'street-preflop')
#     (0.8981153964996338, 1, 0.8981153964996338, 'player-2:state-active')
#     (0.6524067521095276, 1, 0.6524067521095276, 'player-9:state-fold')
#     (0.5168206116248821, 0.6896551724137931, 0.7493898868560791, 'player-2:history')
#     (0.4630233347415924, 1, 0.4630233347415924, 'player-1:state-fold')
#     (0.30269142985343933, 1, 0.30269142985343933, 'player-8:state-fold')
#     (-0.24992208182811737, 1, -0.24992208182811737, 'player-6:state-fold')
#     (-0.21619188779592516, 0.09925, -2.178255796432495, 'player-7:stack')
#     (-0.20419166088104249, 0.1, -2.041916608810425, 'player-4:stack')
#     (0.19231440126895905, 1, 0.19231440126895905, 'player-7:state-fold')
#     (-0.1828493573665619, 0.09925, -1.842310905456543, 'player-6:stack')
#     (-0.18097137212753298, 0.1, -1.8097137212753296, 'player-3:stack')
#     (0.17064229784340693, 0.20689655172413793, 0.8247711062431335, 'player-0:history')
#     (0.1697189062833786, 1, 0.1697189062833786, 'player-3:state-fold')
#     (-0.10727992513775826, 0.09975, -1.0754879713058472, 'player-5:stack')
#     (-0.10096412897109985, 1, -0.10096412897109985, 'player-4:state-fold')
#     (-0.0843420284986496, 0.095, -0.8878108263015747, 'player-1:stack')
#     (-0.07119418084621429, 0.10525, -0.676429271697998, 'player-8:stack')
#     (0.057786691933870316, 1, 0.057786691933870316, 'player-5:state-fold')
#     (-0.04831223651021719, 0.10575, -0.45685330033302307, 'player-9:stack')
#     (0.045537327244877815, 0.0935, 0.4870302379131317, 'player-0:stack')
#     (-0.03385038524866104, 0.095, -0.3563198447227478, 'player-2:stack')
#     (-0.011269092947244645, 0.00725, -1.554357647895813, 'pot')
#     (0.0027059713369235396, 0.494, 0.005477674771100283, 'cards')
#     (0.0, 0.0, 0.9098794460296631, 'player-9:history')
#     (0.0, 0, 0.4734603762626648, 'player-9:state-active')
#     (0.0, 0.0, 0.5701652765274048, 'player-8:history')
#     (0.0, 0, 0.3940722644329071, 'player-8:state-active')
#     (0.0, 0.0, 0.20390835404396057, 'player-7:history')
#     (0.0, 0, 0.2394191324710846, 'player-7:state-active')
#     (0.0, 0.0, 1.0076415538787842, 'player-6:history')
#     (-0.0, 0, -0.31149518489837646, 'player-6:state-active')
#     (0.0, 0.0, 3.4297122955322266, 'player-5:history')
#     (0.0, 0, 0.08243725448846817, 'player-5:state-active')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.11701351404190063, 'player-4:state-active')
#     (0.0, 0.0, 0.4895218312740326, 'player-3:history')
#     (0.0, 0, 0.14121900498867035, 'player-3:state-active')
#     (0.0, 0, 0.7233438491821289, 'player-2:state-fold')
#     (0.0, 0.0, 0.45885005593299866, 'player-1:history')
#     (0.0, 0, 0.5129716396331787, 'player-1:state-active')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 1.6931723356246948, 'street-river')
#     (0.0, 0, 1.9459458589553833, 'street-turn')
#     (0.0, 0, 1.8393696546554565, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 2.374540328979492, 'btn distance=6')
#     (0.0, 0, 2.3336832523345947, 'btn distance=5')
#     (0.0, 0, 0.3861742615699768, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (2.6131505966186523, 1, 2.6131505966186523, 'btn distance=4')
#     (-2.1693177223205566, 1, -2.1693177223205566, 'round level 2')
#     (-2.0899353, 0, 0, 'bias')
#     (-1.989793062210083, 1, -1.989793062210083, 'player-0:state-active')
#     (1.5268641710281372, 1, 1.5268641710281372, 'street-preflop')
#     (0.9448767900466919, 1, 0.9448767900466919, 'player-8:state-fold')
#     (0.6580949425697327, 1, 0.6580949425697327, 'player-9:state-fold')
#     (0.5415549874305725, 1, 0.5415549874305725, 'player-7:state-fold')
#     (0.4482194473003519, 0.6896551724137931, 0.6499181985855103, 'player-2:history')
#     (0.35019147396087646, 1, 0.35019147396087646, 'player-1:state-fold')
#     (0.31402891874313354, 1, 0.31402891874313354, 'player-3:state-fold')
#     (0.2826194167137146, 1, 0.2826194167137146, 'player-2:state-active')
#     (0.23603229687131685, 0.20689655172413793, 1.1408227682113647, 'player-0:history')
#     (-0.22696347105503084, 0.09925, -2.28678560256958, 'player-7:stack')
#     (-0.2180684618353844, 0.09925, -2.1971633434295654, 'player-6:stack')
#     (-0.20103013515472412, 0.1, -2.010301351547241, 'player-4:stack')
#     (-0.19620796442031863, 0.1, -1.962079644203186, 'player-3:stack')
#     (-0.13846114656329156, 0.09975, -1.388081669807434, 'player-5:stack')
#     (-0.12899084210395814, 0.095, -1.3577983379364014, 'player-2:stack')
#     (-0.11238556578755378, 0.10525, -1.0677963495254517, 'player-8:stack')
#     (-0.1039939895272255, 1, -0.1039939895272255, 'player-6:state-fold')
#     (-0.0937051808834076, 0.095, -0.986370325088501, 'player-1:stack')
#     (-0.08493565768003464, 1, -0.08493565768003464, 'player-5:state-fold')
#     (-0.06700549399852752, 0.10575, -0.6336216926574707, 'player-9:stack')
#     (-0.0168446484208107, 0.00725, -2.323399782180786, 'pot')
#     (-0.015592820942401886, 1, -0.015592820942401886, 'player-4:state-fold')
#     (0.010243050321936608, 0.0935, 0.109551340341568, 'player-0:stack')
#     (0.005086274690926075, 0.494, 0.010296102613210678, 'cards')
#     (0.0, 0.0, 0.7091440558433533, 'player-9:history')
#     (0.0, 0, 0.4694209694862366, 'player-9:state-active')
#     (0.0, 0.0, 0.5972527265548706, 'player-8:history')
#     (0.0, 0, 0.9683846831321716, 'player-8:state-active')
#     (0.0, 0.0, 0.4933747351169586, 'player-7:history')
#     (0.0, 0, 0.6356079578399658, 'player-7:state-active')
#     (0.0, 0.0, 1.5179282426834106, 'player-6:history')
#     (0.0, 0, 0.0649658739566803, 'player-6:state-active')
#     (0.0, 0.0, 4.063137054443359, 'player-5:history')
#     (-0.0, 0, -0.12167444080114365, 'player-5:state-active')
#     (0.0, 0.0, 0.6780285835266113, 'player-4:history')
#     (-0.0, 0, -0.11367033421993256, 'player-4:state-active')
#     (0.0, 0.0, 0.9237784147262573, 'player-3:history')
#     (0.0, 0, 0.16314665973186493, 'player-3:state-active')
#     (0.0, 0, 0.6079424619674683, 'player-2:state-fold')
#     (0.0, 0.0, 0.31196364760398865, 'player-1:history')
#     (0.0, 0, 0.4935045540332794, 'player-1:state-active')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 1.5670738220214844, 'street-river')
#     (0.0, 0, 1.3895366191864014, 'street-turn')
#     (0.0, 0, 1.4037833213806152, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 2.3866612911224365, 'btn distance=6')
#     (0.0, 0, 2.4277405738830566, 'btn distance=5')
#     (0.0, 0, 0.3329910337924957, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (-0.0, 0, -0.01431115809828043, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (2.6901073455810547, 1, 2.6901073455810547, 'btn distance=4')
#     (-2.31951904296875, 1, -2.31951904296875, 'round level 2')
#     (-2.1535284519195557, 1, -2.1535284519195557, 'player-0:state-active')
#     (-2.1036038, 0, 0, 'bias')
#     (1.4314368963241577, 1, 1.4314368963241577, 'street-preflop')
#     (0.9965319037437439, 1, 0.9965319037437439, 'player-8:state-fold')
#     (0.6664431095123291, 1, 0.6664431095123291, 'player-9:state-fold')
#     (0.5016474066109493, 0.6896551724137931, 0.7273887395858765, 'player-2:history')
#     (0.4988119900226593, 1, 0.4988119900226593, 'player-1:state-fold')
#     (0.4935069680213928, 1, 0.4935069680213928, 'player-7:state-fold')
#     (0.2819548547267914, 1, 0.2819548547267914, 'player-3:state-fold')
#     (0.22700640559196472, 1, 0.22700640559196472, 'player-2:state-active')
#     (-0.21435418725013733, 1, -0.21435418725013733, 'player-6:state-fold')
#     (-0.21127002197504044, 0.09925, -2.1286652088165283, 'player-6:stack')
#     (-0.19895819425582886, 0.1, -1.9895819425582886, 'player-4:stack')
#     (-0.19017614126205445, 0.1, -1.9017614126205444, 'player-3:stack')
#     (-0.18902367261052133, 0.09925, -1.9045206308364868, 'player-7:stack')
#     (0.15621395409107208, 1, 0.15621395409107208, 'player-5:state-fold')
#     (-0.1555991852581501, 0.09975, -1.5598915815353394, 'player-5:stack')
#     (0.12806568885671682, 0.20689655172413793, 0.6189841628074646, 'player-0:history')
#     (-0.12415001428127288, 0.10525, -1.179572582244873, 'player-8:stack')
#     (0.12340544909238815, 1, 0.12340544909238815, 'player-4:state-fold')
#     (-0.12184191942214966, 0.095, -1.2825465202331543, 'player-1:stack')
#     (-0.11656929194927215, 0.095, -1.2270451784133911, 'player-2:stack')
#     (-0.0924248710423708, 0.10575, -0.8739940524101257, 'player-9:stack')
#     (0.01654210329055786, 0.0935, 0.17692089080810547, 'player-0:stack')
#     (-0.011118967980146409, 0.00725, -1.5336507558822632, 'pot')
#     (-0.00026875432138331233, 0.494, -0.0005440370878204703, 'cards')
#     (0.0, 0.0, 0.9967906475067139, 'player-9:history')
#     (0.0, 0, 0.41812750697135925, 'player-9:state-active')
#     (0.0, 0.0, 0.8489145636558533, 'player-8:history')
#     (0.0, 0, 0.904315173625946, 'player-8:state-active')
#     (0.0, 0.0, 0.5559170246124268, 'player-7:history')
#     (0.0, 0, 0.6117324233055115, 'player-7:state-active')
#     (0.0, 0.0, 1.705260992050171, 'player-6:history')
#     (-0.0, 0, -0.02029792219400406, 'player-6:state-active')
#     (0.0, 0.0, 3.725745439529419, 'player-5:history')
#     (0.0, 0, 0.12941569089889526, 'player-5:state-active')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (-0.0, 0, -0.011390859261155128, 'player-4:state-active')
#     (0.0, 0.0, 0.8774658441543579, 'player-3:history')
#     (0.0, 0, 0.1423758715391159, 'player-3:state-active')
#     (0.0, 0, 0.5529121160507202, 'player-2:state-fold')
#     (0.0, 0.0, 0.8880079388618469, 'player-1:history')
#     (0.0, 0, 0.49769866466522217, 'player-1:state-active')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 1.314842700958252, 'street-river')
#     (0.0, 0, 1.4213526248931885, 'street-turn')
#     (0.0, 0, 1.5551739931106567, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 2.428459644317627, 'btn distance=6')
#     (0.0, 0, 2.5488789081573486, 'btn distance=5')
#     (0.0, 0, 0.4982319474220276, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (2.0806338787078857, 1, 2.0806338787078857, 'btn distance=4')
#     (-1.7271546125411987, 1, -1.7271546125411987, 'player-0:state-active')
#     (-1.671335, 0, 0, 'bias')
#     (1.665412425994873, 1, 1.665412425994873, 'street-preflop')
#     (-1.649506688117981, 1, -1.649506688117981, 'round level 2')
#     (0.765361487865448, 1, 0.765361487865448, 'player-9:state-fold')
#     (0.6200821399688721, 1, 0.6200821399688721, 'player-7:state-fold')
#     (0.31775495409965515, 1, 0.31775495409965515, 'player-2:state-active')
#     (0.29147276282310486, 1, 0.29147276282310486, 'player-1:state-fold')
#     (-0.21264591813087463, 1, -0.21264591813087463, 'player-5:state-fold')
#     (-0.20749526953697206, 0.09925, -2.090632438659668, 'player-7:stack')
#     (0.1915341317653656, 1, 0.1915341317653656, 'player-8:state-fold')
#     (-0.1869731664657593, 0.1, -1.8697316646575928, 'player-4:stack')
#     (-0.18135348558425904, 0.1, -1.8135348558425903, 'player-3:stack')
#     (0.17412243218257512, 0.6896551724137931, 0.2524775266647339, 'player-2:history')
#     (-0.1591462755203247, 0.09925, -1.6034889221191406, 'player-6:stack')
#     (-0.11512207239866257, 1, -0.11512207239866257, 'player-3:state-fold')
#     (0.11091738322685504, 0.20689655172413793, 0.5361006855964661, 'player-0:history')
#     (0.10357889938354492, 0.0935, 1.1077957153320312, 'player-0:stack')
#     (-0.07722781375050546, 0.09975, -0.7742136716842651, 'player-5:stack')
#     (-0.02465648762881756, 1, -0.02465648762881756, 'player-6:state-fold')
#     (0.02374939128756523, 0.095, 0.24999359250068665, 'player-2:stack')
#     (-0.022165140137076378, 1, -0.022165140137076378, 'player-4:state-fold')
#     (0.015031692758202552, 0.10575, 0.14214366674423218, 'player-9:stack')
#     (0.0035990036176517604, 0.494, 0.0072854324243962765, 'cards')
#     (0.0033350506201386453, 0.00725, 0.460006982088089, 'pot')
#     (0.001353893862105906, 0.095, 0.014251514337956905, 'player-1:stack')
#     (-0.0013088193729054183, 0.10525, -0.012435338459908962, 'player-8:stack')
#     (0.0, 0.0, 0.9480952024459839, 'player-9:history')
#     (0.0, 0, 0.3634771704673767, 'player-9:state-active')
#     (0.0, 0.0, 0.5864446759223938, 'player-8:history')
#     (0.0, 0, 0.05815807357430458, 'player-8:state-active')
#     (0.0, 0.0, 0.06328362226486206, 'player-7:history')
#     (0.0, 0, 0.3599641025066376, 'player-7:state-active')
#     (0.0, 0.0, 0.5599234700202942, 'player-6:history')
#     (-0.0, 0, -0.1686408668756485, 'player-6:state-active')
#     (0.0, 0.0, 1.7668896913528442, 'player-5:history')
#     (-0.0, 0, -0.041863877326250076, 'player-5:state-active')
#     (0.0, 0.0, 0.6586898565292358, 'player-4:history')
#     (0.0, 0, 0.08522438257932663, 'player-4:state-active')
#     (0.0, 0.0, 0.07129468768835068, 'player-3:history')
#     (-0.0, 0, -0.015894461423158646, 'player-3:state-active')
#     (0.0, 0, 0.005736817605793476, 'player-2:state-fold')
#     (0.0, 0.0, 0.19451376795768738, 'player-1:history')
#     (0.0, 0, 0.29196155071258545, 'player-1:state-active')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 1.5800559520721436, 'street-river')
#     (0.0, 0, 1.5945707559585571, 'street-turn')
#     (0.0, 0, 1.6251622438430786, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 1.6743172407150269, 'btn distance=6')
#     (0.0, 0, 1.6758811473846436, 'btn distance=5')
#     (-0.0, 0, -0.02149493806064129, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.07707057148218155, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### 100万iteration後のvalue function10人で対戦
# 1roundは,double raise => fold

# %% [markdown]
# ### DOUBLE RAISE

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 75
#   - raise: [100, 10000]
# -- hole card --
#   - ['ST', 'DA']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9925
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9925
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu6 (uuid=uuid-6)', 'amount': 75, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 75, 'paid': 75}
# ======================================================================
# Agent took action [ raise: 200 (double_raise) ] at round 1
#   => [('fold', -0.1520686149597168), ('call', -0.25064706802368164), ('min_raise', -0.15530633926391602), ('double_raise', -0.11402082443237305), ('triple_raise', -0.19747161865234375), ('max_raise', -0.24290227890014648)]
# ** weights and features in detail **
# bias : [-3.25083518 -3.24774957 -4.6558404  -4.3275876  -4.26411343 -3.1577177 ]
#
# linear combination for fold :
#     (5.679295539855957, 1, 5.679295539855957, 'street-preflop')
#     (-3.2508352, 0, 0, 'bias')
#     (-3.236041307449341, 1, -3.236041307449341, 'player-0:state-active')
#     (-3.1531357765197754, 1, -3.1531357765197754, 'round level 2')
#     (1.892627239227295, 1, 1.892627239227295, 'player-9:state-active')
#     (1.7218908071517944, 1, 1.7218908071517944, 'btn distance=6')
#     (0.783786416053772, 1, 0.783786416053772, 'player-2:state-active')
#     (-0.6163124442100525, 1, -0.6163124442100525, 'player-7:state-fold')
#     (0.48228156566619873, 1, 0.48228156566619873, 'player-1:state-active')
#     (0.3531394302845001, 1, 0.3531394302845001, 'player-8:state-active')
#     (0.34711805979410804, 0.1111111111111111, 3.1240625381469727, 'player-5:history')
#     (-0.33724753046035766, 0.0995, -3.3894224166870117, 'player-6:stack')
#     (-0.3209871768951416, 0.1, -3.209871768951416, 'player-7:stack')
#     (-0.31416447162628175, 0.1, -3.1416447162628174, 'player-3:stack')
#     (-0.2934215307235718, 0.1, -2.9342153072357178, 'player-4:stack')
#     (0.25807565450668335, 1, 0.25807565450668335, 'player-6:state-active')
#     (0.2559640142652723, 0.2222222222222222, 1.1518380641937256, 'player-6:history')
#     (-0.23696591967344285, 0.09975, -2.375598192214966, 'player-5:stack')
#     (-0.20628998279571534, 0.1, -2.0628998279571533, 'player-2:stack')
#     (0.19107064604759216, 1, 0.19107064604759216, 'player-4:state-active')
#     (0.14975817501544952, 1, 0.14975817501544952, 'player-5:state-active')
#     (-0.12948022490739822, 0.09925, -1.30458664894104, 'player-9:stack')
#     (-0.12240741205215455, 0.09925, -1.2333240509033203, 'player-8:stack')
#     (-0.10782396793365479, 0.1, -1.0782396793365479, 'player-1:stack')
#     (0.07035095989704132, 0.3333333333333333, 0.21105287969112396, 'player-9:history')
#     (0.06133017440636952, 0.3333333333333333, 0.18399052321910858, 'player-8:history')
#     (-0.040660858154296875, 1, -0.040660858154296875, 'player-3:state-active')
#     (-0.030057603120803834, 0.1, -0.30057603120803833, 'player-0:stack')
#     (-0.003763896435499191, 0.00225, -1.6728428602218628, 'pot')
#     (0.000838063499191776, 0.677, 0.0012379076797515154, 'cards')
#     (0.0, 0, 1.629240870475769, 'player-9:state-fold')
#     (0.0, 0, 0.10857503861188889, 'player-8:state-fold')
#     (0.0, 0.0, 0.3504723012447357, 'player-7:history')
#     (0.0, 0, 0.03959277644753456, 'player-7:state-active')
#     (0.0, 0, 0.3351663649082184, 'player-6:state-fold')
#     (0.0, 0, 0.28576943278312683, 'player-5:state-fold')
#     (0.0, 0.0, 0.7414211630821228, 'player-4:history')
#     (0.0, 0, 0.5315114259719849, 'player-4:state-fold')
#     (0.0, 0.0, 0.04860743507742882, 'player-3:history')
#     (0.0, 0, 0.22788932919502258, 'player-3:state-fold')
#     (0.0, 0.0, 0.33559858798980713, 'player-2:history')
#     (0.0, 0, 0.8573673367500305, 'player-2:state-fold')
#     (0.0, 0.0, 0.5185162425041199, 'player-1:history')
#     (0.0, 0, 0.5799099206924438, 'player-1:state-fold')
#     (0.0, 0.0, 0.1817125827074051, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 5.779847145080566, 'street-river')
#     (0.0, 0, 5.775496482849121, 'street-turn')
#     (0.0, 0, 5.783719062805176, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 1.882977843284607, 'btn distance=5')
#     (0.0, 0, 2.0152363777160645, 'btn distance=4')
#     (0.0, 0, 0.8341370820999146, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.16832740604877472, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (4.534221649169922, 1, 4.534221649169922, 'btn distance=6')
#     (-3.2477496, 0, 0, 'bias')
#     (-3.1422784328460693, 1, -3.1422784328460693, 'player-0:state-active')
#     (-2.9947614669799805, 1, -2.9947614669799805, 'round level 2')
#     (1.8247454166412354, 1, 1.8247454166412354, 'player-9:state-active')
#     (1.8120472431182861, 1, 1.8120472431182861, 'street-preflop')
#     (0.9818313717842102, 1, 0.9818313717842102, 'player-1:state-active')
#     (0.663237452507019, 1, 0.663237452507019, 'player-8:state-active')
#     (0.5781336426734924, 1, 0.5781336426734924, 'player-2:state-active')
#     (0.43941071298387313, 0.1111111111111111, 3.9546964168548584, 'player-5:history')
#     (0.43039222558339435, 0.3333333333333333, 1.291176676750183, 'player-9:history')
#     (0.39317897955576575, 0.3333333333333333, 1.1795369386672974, 'player-8:history')
#     (-0.383811354637146, 1, -0.383811354637146, 'player-3:state-active')
#     (-0.3317417409420014, 0.0995, -3.33408784866333, 'player-6:stack')
#     (-0.322771817445755, 1, -0.322771817445755, 'player-4:state-active')
#     (-0.32201619148254396, 0.1, -3.2201619148254395, 'player-4:stack')
#     (-0.31868016719818115, 0.1, -3.1868016719818115, 'player-7:stack')
#     (-0.28652439117431644, 0.1, -2.865243911743164, 'player-3:stack')
#     (-0.2758033618927002, 0.09975, -2.7649459838867188, 'player-5:stack')
#     (0.2513267464107937, 0.2222222222222222, 1.1309703588485718, 'player-6:history')
#     (-0.1573736071586609, 1, -0.1573736071586609, 'player-6:state-active')
#     (-0.12567837536334991, 1, -0.12567837536334991, 'player-5:state-active')
#     (-0.11248470544815065, 0.1, -1.1248470544815063, 'player-2:stack')
#     (-0.08436869025230408, 0.09925, -0.850062370300293, 'player-8:stack')
#     (-0.06137265424430371, 0.09925, -0.6183642745018005, 'player-9:stack')
#     (-0.06086798012256622, 1, -0.06086798012256622, 'player-7:state-fold')
#     (0.053529292345047, 0.1, 0.53529292345047, 'player-0:stack')
#     (0.02554953080415726, 0.677, 0.037739336490631104, 'cards')
#     (-0.007149560749530793, 0.1, -0.07149560749530792, 'player-1:stack')
#     (-0.002817487299442291, 0.00225, -1.2522165775299072, 'pot')
#     (0.0, 0, 1.6943824291229248, 'player-9:state-fold')
#     (0.0, 0, 0.7169987559318542, 'player-8:state-fold')
#     (0.0, 0.0, 1.0383859872817993, 'player-7:history')
#     (0.0, 0, 0.7693021297454834, 'player-7:state-active')
#     (-0.0, 0, -0.2671574652194977, 'player-6:state-fold')
#     (-0.0, 0, -0.14990326762199402, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.2590565085411072, 'player-4:state-fold')
#     (0.0, 0.0, 1.215385913848877, 'player-3:history')
#     (-0.0, 0, -0.09796147793531418, 'player-3:state-fold')
#     (0.0, 0.0, 1.2303870916366577, 'player-2:history')
#     (0.0, 0, 0.845072329044342, 'player-2:state-fold')
#     (0.0, 0.0, 1.51348078250885, 'player-1:history')
#     (0.0, 0, 1.1562014818191528, 'player-1:state-fold')
#     (0.0, 0.0, 1.2330117225646973, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 1.6342405080795288, 'street-river')
#     (0.0, 0, 1.6452300548553467, 'street-turn')
#     (0.0, 0, 1.6558911800384521, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 4.532103538513184, 'btn distance=5')
#     (0.0, 0, 4.487122535705566, 'btn distance=4')
#     (0.0, 0, 2.3121118545532227, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (0.0, 0, 0.004582444205880165, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (4.818927764892578, 1, 4.818927764892578, 'street-preflop')
#     (4.781858921051025, 1, 4.781858921051025, 'btn distance=6')
#     (-4.6558404, 0, 0, 'bias')
#     (-4.514601707458496, 1, -4.514601707458496, 'round level 2')
#     (-4.434072494506836, 1, -4.434072494506836, 'player-0:state-active')
#     (2.0814356803894043, 1, 2.0814356803894043, 'player-9:state-active')
#     (1.4725059270858765, 1, 1.4725059270858765, 'player-1:state-active')
#     (1.4199254512786865, 1, 1.4199254512786865, 'player-2:state-active')
#     (1.3031387329101562, 1, 1.3031387329101562, 'player-8:state-active')
#     (0.5134843190511067, 0.1111111111111111, 4.621358871459961, 'player-5:history')
#     (-0.45658450126647954, 0.1, -4.565845012664795, 'player-7:stack')
#     (-0.4487069129943848, 0.1, -4.487069129943848, 'player-4:stack')
#     (-0.44268265247344973, 0.0995, -4.449071884155273, 'player-6:stack')
#     (-0.4251497268676758, 0.1, -4.251497268676758, 'player-3:stack')
#     (-0.4027332663536072, 1, -0.4027332663536072, 'player-6:state-active')
#     (-0.35961834847927093, 0.09975, -3.605196475982666, 'player-5:stack')
#     (0.30743525425593055, 0.3333333333333333, 0.9223057627677917, 'player-9:history')
#     (0.247996277279324, 0.2222222222222222, 1.115983247756958, 'player-6:history')
#     (-0.2157161422967911, 0.09925, -2.173462390899658, 'player-8:stack')
#     (-0.1988848924636841, 0.1, -1.9888489246368408, 'player-2:stack')
#     (-0.1980748474597931, 1, -0.1980748474597931, 'player-4:state-active')
#     (-0.196974668353796, 0.09925, -1.9846314191818237, 'player-9:stack')
#     (0.16460007429122925, 1, 0.16460007429122925, 'player-3:state-active')
#     (-0.13906216621398926, 0.1, -1.3906216621398926, 'player-1:stack')
#     (-0.1000925824046135, 1, -0.1000925824046135, 'player-7:state-fold')
#     (-0.07687127590179443, 0.1, -0.7687127590179443, 'player-0:stack')
#     (-0.06596492230892181, 1, -0.06596492230892181, 'player-5:state-active')
#     (0.047075574596722916, 0.3333333333333333, 0.14122672379016876, 'player-8:history')
#     (0.022978925049304964, 0.677, 0.03394228219985962, 'cards')
#     (-0.005038287162780762, 0.00225, -2.239238739013672, 'pot')
#     (0.0, 0, 1.9543581008911133, 'player-9:state-fold')
#     (0.0, 0, 0.7432066798210144, 'player-8:state-fold')
#     (0.0, 0.0, 0.8793066143989563, 'player-7:history')
#     (0.0, 0, 0.7299915552139282, 'player-7:state-active')
#     (-0.0, 0, -0.1636284589767456, 'player-6:state-fold')
#     (0.0, 0, 0.14702603220939636, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.0480794794857502, 'player-4:state-fold')
#     (0.0, 0.0, 0.7735869288444519, 'player-3:history')
#     (0.0, 0, 0.044549502432346344, 'player-3:state-fold')
#     (0.0, 0.0, 1.1248043775558472, 'player-2:history')
#     (0.0, 0, 1.6524394750595093, 'player-2:state-fold')
#     (0.0, 0.0, 1.083045482635498, 'player-1:history')
#     (0.0, 0, 1.6003220081329346, 'player-1:state-fold')
#     (0.0, 0.0, 0.9507765769958496, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 4.711547374725342, 'street-river')
#     (0.0, 0, 4.759979248046875, 'street-turn')
#     (0.0, 0, 4.742796421051025, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 5.055746078491211, 'btn distance=5')
#     (0.0, 0, 5.038480281829834, 'btn distance=4')
#     (0.0, 0, 2.464824676513672, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (4.431316375732422, 1, 4.431316375732422, 'btn distance=6')
#     (-4.406982898712158, 1, -4.406982898712158, 'round level 2')
#     (-4.3275876, 0, 0, 'bias')
#     (-4.227409362792969, 1, -4.227409362792969, 'player-0:state-active')
#     (3.9146602153778076, 1, 3.9146602153778076, 'street-preflop')
#     (2.1582446098327637, 1, 2.1582446098327637, 'player-9:state-active')
#     (2.0035831928253174, 1, 2.0035831928253174, 'player-8:state-active')
#     (1.1610509157180786, 1, 1.1610509157180786, 'player-1:state-active')
#     (1.1588884592056274, 1, 1.1588884592056274, 'player-2:state-active')
#     (0.5101218753390842, 0.1111111111111111, 4.591096878051758, 'player-5:history')
#     (-0.45337505340576173, 0.1, -4.533750534057617, 'player-7:stack')
#     (-0.45334574580192566, 0.0995, -4.556238651275635, 'player-6:stack')
#     (-0.4266695499420166, 0.1, -4.266695499420166, 'player-4:stack')
#     (-0.42118577957153325, 0.1, -4.211857795715332, 'player-3:stack')
#     (-0.3783639010190964, 0.09975, -3.793121814727783, 'player-5:stack')
#     (0.37751859426498413, 1, 0.37751859426498413, 'player-7:state-fold')
#     (-0.3306515693664551, 0.1, -3.306515693664551, 'player-2:stack')
#     (0.3138149579366048, 0.2222222222222222, 1.4121673107147217, 'player-6:history')
#     (0.2654922306537628, 1, 0.2654922306537628, 'player-3:state-active')
#     (0.26533917586008704, 0.3333333333333333, 0.7960175275802612, 'player-9:history')
#     (-0.2457582950592041, 1, -0.2457582950592041, 'player-5:state-active')
#     (-0.22566524547338487, 0.09925, -2.273705244064331, 'player-8:stack')
#     (-0.2210977573990822, 0.09925, -2.2276852130889893, 'player-9:stack')
#     (-0.2166170120239258, 0.1, -2.166170120239258, 'player-1:stack')
#     (-0.1636890172958374, 1, -0.1636890172958374, 'player-4:state-active')
#     (-0.1499478816986084, 1, -0.1499478816986084, 'player-6:state-active')
#     (-0.12710357904434205, 0.1, -1.2710357904434204, 'player-0:stack')
#     (0.1101973553498586, 0.3333333333333333, 0.3305920660495758, 'player-8:history')
#     (-0.007560548543930053, 0.00225, -3.360243797302246, 'pot')
#     (-0.0012374519323930144, 0.677, -0.0018278462812304497, 'cards')
#     (0.0, 0, 2.0677928924560547, 'player-9:state-fold')
#     (0.0, 0, 1.4921538829803467, 'player-8:state-fold')
#     (0.0, 0.0, 0.9742657542228699, 'player-7:history')
#     (0.0, 0, 1.0885356664657593, 'player-7:state-active')
#     (0.0, 0, 0.10210249572992325, 'player-6:state-fold')
#     (0.0, 0, 0.03121505118906498, 'player-5:state-fold')
#     (0.0, 0.0, 0.7097942233085632, 'player-4:history')
#     (0.0, 0, 0.002188226208090782, 'player-4:state-fold')
#     (0.0, 0.0, 1.2310571670532227, 'player-3:history')
#     (0.0, 0, 0.10334695130586624, 'player-3:state-fold')
#     (0.0, 0.0, 0.9553847908973694, 'player-2:history')
#     (0.0, 0, 1.2212973833084106, 'player-2:state-fold')
#     (0.0, 0.0, 1.2011051177978516, 'player-1:history')
#     (0.0, 0, 1.365329623222351, 'player-1:state-fold')
#     (0.0, 0.0, 0.8295992016792297, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 3.7991323471069336, 'street-river')
#     (0.0, 0, 3.79378604888916, 'street-turn')
#     (0.0, 0, 3.8325355052948, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 4.482860088348389, 'btn distance=5')
#     (0.0, 0, 4.559382438659668, 'btn distance=4')
#     (0.0, 0, 2.1376571655273438, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (0.0, 0, 0.017454855144023895, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (4.520473003387451, 1, 4.520473003387451, 'btn distance=6')
#     (-4.480043888092041, 1, -4.480043888092041, 'round level 2')
#     (-4.3140716552734375, 1, -4.3140716552734375, 'player-0:state-active')
#     (-4.2641134, 0, 0, 'bias')
#     (3.4204375743865967, 1, 3.4204375743865967, 'street-preflop')
#     (2.078235149383545, 1, 2.078235149383545, 'player-8:state-active')
#     (1.877943754196167, 1, 1.877943754196167, 'player-9:state-active')
#     (1.0051987171173096, 1, 1.0051987171173096, 'player-1:state-active')
#     (0.8060318827629089, 1, 0.8060318827629089, 'player-7:state-fold')
#     (0.7729678153991699, 1, 0.7729678153991699, 'player-2:state-active')
#     (0.5435661209954156, 0.1111111111111111, 4.89209508895874, 'player-5:history')
#     (-0.42944123935699463, 0.0995, -4.31599235534668, 'player-6:stack')
#     (-0.4149498462677002, 0.1, -4.149498462677002, 'player-4:stack')
#     (-0.41011061668396, 0.1, -4.1011061668396, 'player-3:stack')
#     (-0.406051778793335, 0.1, -4.06051778793335, 'player-7:stack')
#     (-0.38557817620038987, 0.09975, -3.865445375442505, 'player-5:stack')
#     (0.3744829230838352, 0.2222222222222222, 1.6851731538772583, 'player-6:history')
#     (-0.3193996906280518, 0.1, -3.1939969062805176, 'player-2:stack')
#     (0.2968495190143585, 1, 0.2968495190143585, 'player-3:state-active')
#     (0.25687193870544434, 0.3333333333333333, 0.770615816116333, 'player-9:history')
#     (-0.24502334284782412, 0.09925, -2.4687490463256836, 'player-8:stack')
#     (-0.23613147735595705, 0.1, -2.3613147735595703, 'player-1:stack')
#     (-0.233040140748024, 0.09925, -2.3480114936828613, 'player-9:stack')
#     (0.20867904027303058, 0.3333333333333333, 0.6260371208190918, 'player-8:history')
#     (-0.1532966047525406, 1, -0.1532966047525406, 'player-6:state-active')
#     (-0.13292374610900878, 0.1, -1.329237461090088, 'player-0:stack')
#     (0.08034905046224594, 1, 0.08034905046224594, 'player-5:state-active')
#     (-0.03344249725341797, 1, -0.03344249725341797, 'player-4:state-active')
#     (0.02519145166501403, 0.677, 0.03721041604876518, 'cards')
#     (-0.007131822109222412, 0.00225, -3.169698715209961, 'pot')
#     (0.0, 0, 1.6473029851913452, 'player-9:state-fold')
#     (0.0, 0, 1.7670563459396362, 'player-8:state-fold')
#     (0.0, 0.0, 1.1300346851348877, 'player-7:history')
#     (0.0, 0, 1.586179256439209, 'player-7:state-active')
#     (0.0, 0, 0.1650526374578476, 'player-6:state-fold')
#     (0.0, 0, 0.40404701232910156, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.3784959018230438, 'player-4:state-fold')
#     (0.0, 0.0, 1.095296859741211, 'player-3:history')
#     (0.0, 0, 0.2227562665939331, 'player-3:state-fold')
#     (0.0, 0.0, 0.8755476474761963, 'player-2:history')
#     (0.0, 0, 0.8816099762916565, 'player-2:state-fold')
#     (0.0, 0.0, 1.483224868774414, 'player-1:history')
#     (0.0, 0, 1.1522746086120605, 'player-1:state-fold')
#     (0.0, 0.0, 0.8813244104385376, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 3.3509480953216553, 'street-river')
#     (0.0, 0, 3.3434667587280273, 'street-turn')
#     (0.0, 0, 3.3365421295166016, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 4.522878646850586, 'btn distance=5')
#     (0.0, 0, 4.673919200897217, 'btn distance=4')
#     (0.0, 0, 2.2241458892822266, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (4.41821813583374, 1, 4.41821813583374, 'street-preflop')
#     (-3.2135443687438965, 1, -3.2135443687438965, 'player-0:state-active')
#     (-3.1577177, 0, 0, 'bias')
#     (-3.13590145111084, 1, -3.13590145111084, 'round level 2')
#     (2.790525197982788, 1, 2.790525197982788, 'btn distance=6')
#     (0.9348535537719727, 1, 0.9348535537719727, 'player-8:state-active')
#     (0.8671867251396179, 1, 0.8671867251396179, 'player-9:state-active')
#     (0.7097644805908203, 1, 0.7097644805908203, 'player-1:state-active')
#     (0.471826434135437, 1, 0.471826434135437, 'player-2:state-active')
#     (0.42348459362983704, 1, 0.42348459362983704, 'player-7:state-fold')
#     (-0.3629549443721771, 1, -0.3629549443721771, 'player-6:state-active')
#     (-0.35086534023284915, 0.1, -3.508653402328491, 'player-7:stack')
#     (0.33791139390733504, 0.1111111111111111, 3.0412025451660156, 'player-5:history')
#     (-0.33510909080505374, 0.1, -3.351090908050537, 'player-4:stack')
#     (-0.3343605756759644, 0.1, -3.3436057567596436, 'player-3:stack')
#     (-0.31531114983558656, 0.0995, -3.1689562797546387, 'player-6:stack')
#     (-0.25344574451446533, 1, -0.25344574451446533, 'player-5:state-active')
#     (-0.23615927320718766, 0.09975, -2.367511510848999, 'player-5:stack')
#     (0.1752251519097222, 0.2222222222222222, 0.78851318359375, 'player-6:history')
#     (0.1732498009999593, 0.3333333333333333, 0.5197494029998779, 'player-8:history')
#     (0.16119306087493898, 0.1, 1.6119306087493896, 'player-0:stack')
#     (0.12280101142823698, 0.677, 0.1813899725675583, 'cards')
#     (-0.11196428537368774, 1, -0.11196428537368774, 'player-4:state-active')
#     (0.10505444804827371, 0.3333333333333333, 0.31516334414482117, 'player-9:history')
#     (-0.07745938003063202, 1, -0.07745938003063202, 'player-3:state-active')
#     (-0.031474488973617556, 0.1, -0.31474488973617554, 'player-1:stack')
#     (-0.0241244896017015, 0.09925, -0.2430679053068161, 'player-8:stack')
#     (0.006867504864931107, 0.1, 0.06867504864931107, 'player-2:stack')
#     (-0.0021671549254097047, 0.09925, -0.021835314109921455, 'player-9:stack')
#     (0.0014956397116184233, 0.00225, 0.6647287607192993, 'pot')
#     (0.0, 0, 0.9034026265144348, 'player-9:state-fold')
#     (0.0, 0, 0.6469631195068359, 'player-8:state-fold')
#     (0.0, 0.0, 0.24247685074806213, 'player-7:history')
#     (0.0, 0, 1.0271284580230713, 'player-7:state-active')
#     (-0.0, 0, -0.001967048505321145, 'player-6:state-fold')
#     (-0.0, 0, -0.12164759635925293, 'player-5:state-fold')
#     (0.0, 0.0, 0.6614777445793152, 'player-4:history')
#     (0.0, 0, 0.02694733813405037, 'player-4:state-fold')
#     (0.0, 0.0, 0.18499401211738586, 'player-3:history')
#     (-0.0, 0, -0.26166993379592896, 'player-3:state-fold')
#     (0.0, 0.0, 0.9312912225723267, 'player-2:history')
#     (0.0, 0, 0.45517832040786743, 'player-2:state-fold')
#     (0.0, 0.0, 0.7740957736968994, 'player-1:history')
#     (0.0, 0, 0.6840940713882446, 'player-1:state-fold')
#     (0.0, 0.0, 0.516033947467804, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 4.547295570373535, 'street-river')
#     (0.0, 0, 4.49630880355835, 'street-turn')
#     (0.0, 0, 4.49180269241333, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 3.0787465572357178, 'btn distance=5')
#     (0.0, 0, 2.7943179607391357, 'btn distance=4')
#     (0.0, 0, 1.7247602939605713, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.04199141263961792, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### CALL する場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 75
#   - raise: [100, 10225]
# -- hole card --
#   - ['H8', 'HJ']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 150, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 9925
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9850
#     - 6 : agent (uuid-0) => state : participating, stack : 10225 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 75, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 75 (call) ] at round 2
#   => [('fold', 0.10392093658447266), ('call', 0.301877498626709), ('min_raise', 0.21762323379516602), ('double_raise', -0.09948873519897461), ('triple_raise', -0.06281566619873047), ('max_raise', -0.055939435958862305)]
# ** weights and features in detail **
# bias : [-3.25083518 -3.24774957 -4.6558404  -4.3275876  -4.26411343 -3.1577177 ]
#
# linear combination for fold :
#     (5.679295539855957, 1, 5.679295539855957, 'street-preflop')
#     (-3.2508352, 0, 0, 'bias')
#     (-3.236041307449341, 1, -3.236041307449341, 'player-0:state-active')
#     (-3.1531357765197754, 1, -3.1531357765197754, 'round level 2')
#     (1.892627239227295, 1, 1.892627239227295, 'player-9:state-active')
#     (1.882977843284607, 1, 1.882977843284607, 'btn distance=5')
#     (0.783786416053772, 1, 0.783786416053772, 'player-2:state-active')
#     (0.48228156566619873, 1, 0.48228156566619873, 'player-1:state-active')
#     (-0.33640017485618595, 0.09925, -3.3894224166870117, 'player-6:stack')
#     (-0.3193822410106659, 0.0995, -3.209871768951416, 'player-7:stack')
#     (-0.31416447162628175, 0.1, -3.1416447162628174, 'player-3:stack')
#     (-0.2934215307235718, 0.1, -2.9342153072357178, 'player-4:stack')
#     (0.25807565450668335, 1, 0.25807565450668335, 'player-6:state-active')
#     (-0.23696591967344285, 0.09975, -2.375598192214966, 'player-5:stack')
#     (-0.20628998279571534, 0.1, -2.0628998279571533, 'player-2:stack')
#     (0.19197301069895426, 0.16666666666666666, 1.1518380641937256, 'player-6:history')
#     (0.19107064604759216, 1, 0.19107064604759216, 'player-4:state-active')
#     (0.14975817501544952, 1, 0.14975817501544952, 'player-5:state-active')
#     (-0.12850178492069245, 0.0985, -1.30458664894104, 'player-9:stack')
#     (-0.12240741205215455, 0.09925, -1.2333240509033203, 'player-8:stack')
#     (0.1168241004149119, 0.3333333333333333, 0.3504723012447357, 'player-7:history')
#     (0.10857503861188889, 1, 0.10857503861188889, 'player-8:state-fold')
#     (-0.10782396793365479, 0.1, -1.0782396793365479, 'player-1:stack')
#     (0.10552643984556198, 0.5, 0.21105287969112396, 'player-9:history')
#     (-0.040660858154296875, 1, -0.040660858154296875, 'player-3:state-active')
#     (0.03959277644753456, 1, 0.03959277644753456, 'player-7:state-active')
#     (-0.03073389919102192, 0.10225, -0.30057603120803833, 'player-0:stack')
#     (-0.002509264290332794, 0.0015, -1.6728428602218628, 'pot')
#     (0.0008306360531132669, 0.671, 0.0012379076797515154, 'cards')
#     (0.0, 0, 1.629240870475769, 'player-9:state-fold')
#     (0.0, 0.0, 0.18399052321910858, 'player-8:history')
#     (0.0, 0, 0.3531394302845001, 'player-8:state-active')
#     (-0.0, 0, -0.6163124442100525, 'player-7:state-fold')
#     (0.0, 0, 0.3351663649082184, 'player-6:state-fold')
#     (0.0, 0.0, 3.1240625381469727, 'player-5:history')
#     (0.0, 0, 0.28576943278312683, 'player-5:state-fold')
#     (0.0, 0.0, 0.7414211630821228, 'player-4:history')
#     (0.0, 0, 0.5315114259719849, 'player-4:state-fold')
#     (0.0, 0.0, 0.04860743507742882, 'player-3:history')
#     (0.0, 0, 0.22788932919502258, 'player-3:state-fold')
#     (0.0, 0.0, 0.33559858798980713, 'player-2:history')
#     (0.0, 0, 0.8573673367500305, 'player-2:state-fold')
#     (0.0, 0.0, 0.5185162425041199, 'player-1:history')
#     (0.0, 0, 0.5799099206924438, 'player-1:state-fold')
#     (0.0, 0.0, 0.1817125827074051, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 5.779847145080566, 'street-river')
#     (0.0, 0, 5.775496482849121, 'street-turn')
#     (0.0, 0, 5.783719062805176, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 1.7218908071517944, 'btn distance=6')
#     (0.0, 0, 2.0152363777160645, 'btn distance=4')
#     (0.0, 0, 0.8341370820999146, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.16832740604877472, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (4.532103538513184, 1, 4.532103538513184, 'btn distance=5')
#     (-3.2477496, 0, 0, 'bias')
#     (-3.1422784328460693, 1, -3.1422784328460693, 'player-0:state-active')
#     (-2.9947614669799805, 1, -2.9947614669799805, 'round level 2')
#     (1.8247454166412354, 1, 1.8247454166412354, 'player-9:state-active')
#     (1.8120472431182861, 1, 1.8120472431182861, 'street-preflop')
#     (0.9818313717842102, 1, 0.9818313717842102, 'player-1:state-active')
#     (0.7693021297454834, 1, 0.7693021297454834, 'player-7:state-active')
#     (0.7169987559318542, 1, 0.7169987559318542, 'player-8:state-fold')
#     (0.6455883383750916, 0.5, 1.291176676750183, 'player-9:history')
#     (0.5781336426734924, 1, 0.5781336426734924, 'player-2:state-active')
#     (-0.383811354637146, 1, -0.383811354637146, 'player-3:state-active')
#     (0.3461286624272664, 0.3333333333333333, 1.0383859872817993, 'player-7:history')
#     (-0.3309082189798355, 0.09925, -3.33408784866333, 'player-6:stack')
#     (-0.322771817445755, 1, -0.322771817445755, 'player-4:state-active')
#     (-0.32201619148254396, 0.1, -3.2201619148254395, 'player-4:stack')
#     (-0.31708676636219024, 0.0995, -3.1868016719818115, 'player-7:stack')
#     (-0.28652439117431644, 0.1, -2.865243911743164, 'player-3:stack')
#     (-0.2758033618927002, 0.09975, -2.7649459838867188, 'player-5:stack')
#     (0.18849505980809528, 0.16666666666666666, 1.1309703588485718, 'player-6:history')
#     (-0.1573736071586609, 1, -0.1573736071586609, 'player-6:state-active')
#     (-0.12567837536334991, 1, -0.12567837536334991, 'player-5:state-active')
#     (-0.11248470544815065, 0.1, -1.1248470544815063, 'player-2:stack')
#     (-0.08436869025230408, 0.09925, -0.850062370300293, 'player-8:stack')
#     (-0.06090888103842736, 0.0985, -0.6183642745018005, 'player-9:stack')
#     (0.05473370142281055, 0.10225, 0.53529292345047, 'player-0:stack')
#     (0.02532309478521347, 0.671, 0.037739336490631104, 'cards')
#     (-0.007149560749530793, 0.1, -0.07149560749530792, 'player-1:stack')
#     (-0.001878324866294861, 0.0015, -1.2522165775299072, 'pot')
#     (0.0, 0, 1.6943824291229248, 'player-9:state-fold')
#     (0.0, 0.0, 1.1795369386672974, 'player-8:history')
#     (0.0, 0, 0.663237452507019, 'player-8:state-active')
#     (-0.0, 0, -0.06086798012256622, 'player-7:state-fold')
#     (-0.0, 0, -0.2671574652194977, 'player-6:state-fold')
#     (0.0, 0.0, 3.9546964168548584, 'player-5:history')
#     (-0.0, 0, -0.14990326762199402, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.2590565085411072, 'player-4:state-fold')
#     (0.0, 0.0, 1.215385913848877, 'player-3:history')
#     (-0.0, 0, -0.09796147793531418, 'player-3:state-fold')
#     (0.0, 0.0, 1.2303870916366577, 'player-2:history')
#     (0.0, 0, 0.845072329044342, 'player-2:state-fold')
#     (0.0, 0.0, 1.51348078250885, 'player-1:history')
#     (0.0, 0, 1.1562014818191528, 'player-1:state-fold')
#     (0.0, 0.0, 1.2330117225646973, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 1.6342405080795288, 'street-river')
#     (0.0, 0, 1.6452300548553467, 'street-turn')
#     (0.0, 0, 1.6558911800384521, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 4.534221649169922, 'btn distance=6')
#     (0.0, 0, 4.487122535705566, 'btn distance=4')
#     (0.0, 0, 2.3121118545532227, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (0.0, 0, 0.004582444205880165, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (5.055746078491211, 1, 5.055746078491211, 'btn distance=5')
#     (4.818927764892578, 1, 4.818927764892578, 'street-preflop')
#     (-4.6558404, 0, 0, 'bias')
#     (-4.514601707458496, 1, -4.514601707458496, 'round level 2')
#     (-4.434072494506836, 1, -4.434072494506836, 'player-0:state-active')
#     (2.0814356803894043, 1, 2.0814356803894043, 'player-9:state-active')
#     (1.4725059270858765, 1, 1.4725059270858765, 'player-1:state-active')
#     (1.4199254512786865, 1, 1.4199254512786865, 'player-2:state-active')
#     (0.7432066798210144, 1, 0.7432066798210144, 'player-8:state-fold')
#     (0.7299915552139282, 1, 0.7299915552139282, 'player-7:state-active')
#     (0.4611528813838959, 0.5, 0.9223057627677917, 'player-9:history')
#     (-0.4543015787601471, 0.0995, -4.565845012664795, 'player-7:stack')
#     (-0.4487069129943848, 0.1, -4.487069129943848, 'player-4:stack')
#     (-0.44157038450241093, 0.09925, -4.449071884155273, 'player-6:stack')
#     (-0.4251497268676758, 0.1, -4.251497268676758, 'player-3:stack')
#     (-0.4027332663536072, 1, -0.4027332663536072, 'player-6:state-active')
#     (-0.35961834847927093, 0.09975, -3.605196475982666, 'player-5:stack')
#     (0.2931022047996521, 0.3333333333333333, 0.8793066143989563, 'player-7:history')
#     (-0.2157161422967911, 0.09925, -2.173462390899658, 'player-8:stack')
#     (-0.1988848924636841, 0.1, -1.9888489246368408, 'player-2:stack')
#     (-0.1980748474597931, 1, -0.1980748474597931, 'player-4:state-active')
#     (-0.19548619478940965, 0.0985, -1.9846314191818237, 'player-9:stack')
#     (0.18599720795949298, 0.16666666666666666, 1.115983247756958, 'player-6:history')
#     (0.16460007429122925, 1, 0.16460007429122925, 'player-3:state-active')
#     (-0.13906216621398926, 0.1, -1.3906216621398926, 'player-1:stack')
#     (-0.0786008796095848, 0.10225, -0.7687127590179443, 'player-0:stack')
#     (-0.06596492230892181, 1, -0.06596492230892181, 'player-5:state-active')
#     (0.022775271356105804, 0.671, 0.03394228219985962, 'cards')
#     (-0.003358858108520508, 0.0015, -2.239238739013672, 'pot')
#     (0.0, 0, 1.9543581008911133, 'player-9:state-fold')
#     (0.0, 0.0, 0.14122672379016876, 'player-8:history')
#     (0.0, 0, 1.3031387329101562, 'player-8:state-active')
#     (-0.0, 0, -0.1000925824046135, 'player-7:state-fold')
#     (-0.0, 0, -0.1636284589767456, 'player-6:state-fold')
#     (0.0, 0.0, 4.621358871459961, 'player-5:history')
#     (0.0, 0, 0.14702603220939636, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.0480794794857502, 'player-4:state-fold')
#     (0.0, 0.0, 0.7735869288444519, 'player-3:history')
#     (0.0, 0, 0.044549502432346344, 'player-3:state-fold')
#     (0.0, 0.0, 1.1248043775558472, 'player-2:history')
#     (0.0, 0, 1.6524394750595093, 'player-2:state-fold')
#     (0.0, 0.0, 1.083045482635498, 'player-1:history')
#     (0.0, 0, 1.6003220081329346, 'player-1:state-fold')
#     (0.0, 0.0, 0.9507765769958496, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 4.711547374725342, 'street-river')
#     (0.0, 0, 4.759979248046875, 'street-turn')
#     (0.0, 0, 4.742796421051025, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 4.781858921051025, 'btn distance=6')
#     (0.0, 0, 5.038480281829834, 'btn distance=4')
#     (0.0, 0, 2.464824676513672, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (4.482860088348389, 1, 4.482860088348389, 'btn distance=5')
#     (-4.406982898712158, 1, -4.406982898712158, 'round level 2')
#     (-4.3275876, 0, 0, 'bias')
#     (-4.227409362792969, 1, -4.227409362792969, 'player-0:state-active')
#     (3.9146602153778076, 1, 3.9146602153778076, 'street-preflop')
#     (2.1582446098327637, 1, 2.1582446098327637, 'player-9:state-active')
#     (1.4921538829803467, 1, 1.4921538829803467, 'player-8:state-fold')
#     (1.1610509157180786, 1, 1.1610509157180786, 'player-1:state-active')
#     (1.1588884592056274, 1, 1.1588884592056274, 'player-2:state-active')
#     (1.0885356664657593, 1, 1.0885356664657593, 'player-7:state-active')
#     (-0.45220668613910675, 0.09925, -4.556238651275635, 'player-6:stack')
#     (-0.45110817813873294, 0.0995, -4.533750534057617, 'player-7:stack')
#     (-0.4266695499420166, 0.1, -4.266695499420166, 'player-4:stack')
#     (-0.42118577957153325, 0.1, -4.211857795715332, 'player-3:stack')
#     (0.3980087637901306, 0.5, 0.7960175275802612, 'player-9:history')
#     (-0.3783639010190964, 0.09975, -3.793121814727783, 'player-5:stack')
#     (-0.3306515693664551, 0.1, -3.306515693664551, 'player-2:stack')
#     (0.3247552514076233, 0.3333333333333333, 0.9742657542228699, 'player-7:history')
#     (0.2654922306537628, 1, 0.2654922306537628, 'player-3:state-active')
#     (-0.2457582950592041, 1, -0.2457582950592041, 'player-5:state-active')
#     (0.2353612184524536, 0.16666666666666666, 1.4121673107147217, 'player-6:history')
#     (-0.22566524547338487, 0.09925, -2.273705244064331, 'player-8:stack')
#     (-0.21942699348926545, 0.0985, -2.2276852130889893, 'player-9:stack')
#     (-0.2166170120239258, 0.1, -2.166170120239258, 'player-1:stack')
#     (-0.1636890172958374, 1, -0.1636890172958374, 'player-4:state-active')
#     (-0.1499478816986084, 1, -0.1499478816986084, 'player-6:state-active')
#     (-0.12996340957283972, 0.10225, -1.2710357904434204, 'player-0:stack')
#     (-0.005040365695953369, 0.0015, -3.360243797302246, 'pot')
#     (-0.001226484854705632, 0.671, -0.0018278462812304497, 'cards')
#     (0.0, 0, 2.0677928924560547, 'player-9:state-fold')
#     (0.0, 0.0, 0.3305920660495758, 'player-8:history')
#     (0.0, 0, 2.0035831928253174, 'player-8:state-active')
#     (0.0, 0, 0.37751859426498413, 'player-7:state-fold')
#     (0.0, 0, 0.10210249572992325, 'player-6:state-fold')
#     (0.0, 0.0, 4.591096878051758, 'player-5:history')
#     (0.0, 0, 0.03121505118906498, 'player-5:state-fold')
#     (0.0, 0.0, 0.7097942233085632, 'player-4:history')
#     (0.0, 0, 0.002188226208090782, 'player-4:state-fold')
#     (0.0, 0.0, 1.2310571670532227, 'player-3:history')
#     (0.0, 0, 0.10334695130586624, 'player-3:state-fold')
#     (0.0, 0.0, 0.9553847908973694, 'player-2:history')
#     (0.0, 0, 1.2212973833084106, 'player-2:state-fold')
#     (0.0, 0.0, 1.2011051177978516, 'player-1:history')
#     (0.0, 0, 1.365329623222351, 'player-1:state-fold')
#     (0.0, 0.0, 0.8295992016792297, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 3.7991323471069336, 'street-river')
#     (0.0, 0, 3.79378604888916, 'street-turn')
#     (0.0, 0, 3.8325355052948, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 4.431316375732422, 'btn distance=6')
#     (0.0, 0, 4.559382438659668, 'btn distance=4')
#     (0.0, 0, 2.1376571655273438, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (0.0, 0, 0.017454855144023895, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (4.522878646850586, 1, 4.522878646850586, 'btn distance=5')
#     (-4.480043888092041, 1, -4.480043888092041, 'round level 2')
#     (-4.3140716552734375, 1, -4.3140716552734375, 'player-0:state-active')
#     (-4.2641134, 0, 0, 'bias')
#     (3.4204375743865967, 1, 3.4204375743865967, 'street-preflop')
#     (1.877943754196167, 1, 1.877943754196167, 'player-9:state-active')
#     (1.7670563459396362, 1, 1.7670563459396362, 'player-8:state-fold')
#     (1.586179256439209, 1, 1.586179256439209, 'player-7:state-active')
#     (1.0051987171173096, 1, 1.0051987171173096, 'player-1:state-active')
#     (0.7729678153991699, 1, 0.7729678153991699, 'player-2:state-active')
#     (-0.428362241268158, 0.09925, -4.31599235534668, 'player-6:stack')
#     (-0.4149498462677002, 0.1, -4.149498462677002, 'player-4:stack')
#     (-0.41011061668396, 0.1, -4.1011061668396, 'player-3:stack')
#     (-0.4040215198993683, 0.0995, -4.06051778793335, 'player-7:stack')
#     (-0.38557817620038987, 0.09975, -3.865445375442505, 'player-5:stack')
#     (0.3853079080581665, 0.5, 0.770615816116333, 'player-9:history')
#     (0.3766782283782959, 0.3333333333333333, 1.1300346851348877, 'player-7:history')
#     (-0.3193996906280518, 0.1, -3.1939969062805176, 'player-2:stack')
#     (0.2968495190143585, 1, 0.2968495190143585, 'player-3:state-active')
#     (0.28086219231287635, 0.16666666666666666, 1.6851731538772583, 'player-6:history')
#     (-0.24502334284782412, 0.09925, -2.4687490463256836, 'player-8:stack')
#     (-0.23613147735595705, 0.1, -2.3613147735595703, 'player-1:stack')
#     (-0.23127913212776186, 0.0985, -2.3480114936828613, 'player-9:stack')
#     (-0.1532966047525406, 1, -0.1532966047525406, 'player-6:state-active')
#     (-0.13591453039646148, 0.10225, -1.329237461090088, 'player-0:stack')
#     (0.08034905046224594, 1, 0.08034905046224594, 'player-5:state-active')
#     (-0.03344249725341797, 1, -0.03344249725341797, 'player-4:state-active')
#     (0.024968189168721438, 0.671, 0.03721041604876518, 'cards')
#     (-0.0047545480728149415, 0.0015, -3.169698715209961, 'pot')
#     (0.0, 0, 1.6473029851913452, 'player-9:state-fold')
#     (0.0, 0.0, 0.6260371208190918, 'player-8:history')
#     (0.0, 0, 2.078235149383545, 'player-8:state-active')
#     (0.0, 0, 0.8060318827629089, 'player-7:state-fold')
#     (0.0, 0, 0.1650526374578476, 'player-6:state-fold')
#     (0.0, 0.0, 4.89209508895874, 'player-5:history')
#     (0.0, 0, 0.40404701232910156, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.3784959018230438, 'player-4:state-fold')
#     (0.0, 0.0, 1.095296859741211, 'player-3:history')
#     (0.0, 0, 0.2227562665939331, 'player-3:state-fold')
#     (0.0, 0.0, 0.8755476474761963, 'player-2:history')
#     (0.0, 0, 0.8816099762916565, 'player-2:state-fold')
#     (0.0, 0.0, 1.483224868774414, 'player-1:history')
#     (0.0, 0, 1.1522746086120605, 'player-1:state-fold')
#     (0.0, 0.0, 0.8813244104385376, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 3.3509480953216553, 'street-river')
#     (0.0, 0, 3.3434667587280273, 'street-turn')
#     (0.0, 0, 3.3365421295166016, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 4.520473003387451, 'btn distance=6')
#     (0.0, 0, 4.673919200897217, 'btn distance=4')
#     (0.0, 0, 2.2241458892822266, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (4.41821813583374, 1, 4.41821813583374, 'street-preflop')
#     (-3.2135443687438965, 1, -3.2135443687438965, 'player-0:state-active')
#     (-3.1577177, 0, 0, 'bias')
#     (-3.13590145111084, 1, -3.13590145111084, 'round level 2')
#     (3.0787465572357178, 1, 3.0787465572357178, 'btn distance=5')
#     (1.0271284580230713, 1, 1.0271284580230713, 'player-7:state-active')
#     (0.8671867251396179, 1, 0.8671867251396179, 'player-9:state-active')
#     (0.7097644805908203, 1, 0.7097644805908203, 'player-1:state-active')
#     (0.6469631195068359, 1, 0.6469631195068359, 'player-8:state-fold')
#     (0.471826434135437, 1, 0.471826434135437, 'player-2:state-active')
#     (-0.3629549443721771, 1, -0.3629549443721771, 'player-6:state-active')
#     (-0.3491110135316849, 0.0995, -3.508653402328491, 'player-7:stack')
#     (-0.33510909080505374, 0.1, -3.351090908050537, 'player-4:stack')
#     (-0.3343605756759644, 0.1, -3.3436057567596436, 'player-3:stack')
#     (-0.3145189107656479, 0.09925, -3.1689562797546387, 'player-6:stack')
#     (-0.25344574451446533, 1, -0.25344574451446533, 'player-5:state-active')
#     (-0.23615927320718766, 0.09975, -2.367511510848999, 'player-5:stack')
#     (0.16481990474462507, 0.10225, 1.6119306087493896, 'player-0:stack')
#     (0.15758167207241058, 0.5, 0.31516334414482117, 'player-9:history')
#     (0.13141886393229166, 0.16666666666666666, 0.78851318359375, 'player-6:history')
#     (0.12171267159283163, 0.671, 0.1813899725675583, 'cards')
#     (-0.11196428537368774, 1, -0.11196428537368774, 'player-4:state-active')
#     (0.0808256169160207, 0.3333333333333333, 0.24247685074806213, 'player-7:history')
#     (-0.07745938003063202, 1, -0.07745938003063202, 'player-3:state-active')
#     (-0.031474488973617556, 0.1, -0.31474488973617554, 'player-1:stack')
#     (-0.0241244896017015, 0.09925, -0.2430679053068161, 'player-8:stack')
#     (0.006867504864931107, 0.1, 0.06867504864931107, 'player-2:stack')
#     (-0.0021507784398272635, 0.0985, -0.021835314109921455, 'player-9:stack')
#     (0.000997093141078949, 0.0015, 0.6647287607192993, 'pot')
#     (0.0, 0, 0.9034026265144348, 'player-9:state-fold')
#     (0.0, 0.0, 0.5197494029998779, 'player-8:history')
#     (0.0, 0, 0.9348535537719727, 'player-8:state-active')
#     (0.0, 0, 0.42348459362983704, 'player-7:state-fold')
#     (-0.0, 0, -0.001967048505321145, 'player-6:state-fold')
#     (0.0, 0.0, 3.0412025451660156, 'player-5:history')
#     (-0.0, 0, -0.12164759635925293, 'player-5:state-fold')
#     (0.0, 0.0, 0.6614777445793152, 'player-4:history')
#     (0.0, 0, 0.02694733813405037, 'player-4:state-fold')
#     (0.0, 0.0, 0.18499401211738586, 'player-3:history')
#     (-0.0, 0, -0.26166993379592896, 'player-3:state-fold')
#     (0.0, 0.0, 0.9312912225723267, 'player-2:history')
#     (0.0, 0, 0.45517832040786743, 'player-2:state-fold')
#     (0.0, 0.0, 0.7740957736968994, 'player-1:history')
#     (0.0, 0, 0.6840940713882446, 'player-1:state-fold')
#     (0.0, 0.0, 0.516033947467804, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 4.547295570373535, 'street-river')
#     (0.0, 0, 4.49630880355835, 'street-turn')
#     (0.0, 0, 4.49180269241333, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 2.790525197982788, 'btn distance=6')
#     (0.0, 0, 2.7943179607391357, 'btn distance=4')
#     (0.0, 0, 1.7247602939605713, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.04199141263961792, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### 2round目で1度CALLしておいてFOLDする場面

# %% [raw]
# do you want to see weights? (y/n)y
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 200
#   - raise: [325, 10225]
# -- hole card --
#   - ['H8', 'HJ']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 425, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 9925
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9850
#     - 6 : agent (uuid-0) => state : participating, stack : 10150 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 9800
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 75, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'agent (uuid=uuid-0)', 'amount': 75, 'paid': 75}
#       - {'add_amount': 125, 'paid': 200, 'player': 'cpu1 (uuid=uuid-1)', 'amount': 200, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 2
#   => [('fold', -0.06016397476196289), ('call', -0.43025851249694824), ('min_raise', -0.29058408737182617), ('double_raise', -0.5562474727630615), ('triple_raise', -0.1773991584777832), ('max_raise', -0.10576081275939941)]
# ** weights and features in detail **
# bias : [-3.25083518 -3.24774957 -4.6558404  -4.3275876  -4.26411343 -3.1577177 ]
#
# linear combination for fold :
#     (5.679295539855957, 1, 5.679295539855957, 'street-preflop')
#     (-3.2508352, 0, 0, 'bias')
#     (-3.236041307449341, 1, -3.236041307449341, 'player-0:state-active')
#     (-3.1531357765197754, 1, -3.1531357765197754, 'round level 2')
#     (1.882977843284607, 1, 1.882977843284607, 'btn distance=5')
#     (1.629240870475769, 1, 1.629240870475769, 'player-9:state-fold')
#     (0.8573673367500305, 1, 0.8573673367500305, 'player-2:state-fold')
#     (-0.6163124442100525, 1, -0.6163124442100525, 'player-7:state-fold')
#     (0.5315114259719849, 1, 0.5315114259719849, 'player-4:state-fold')
#     (0.48228156566619873, 1, 0.48228156566619873, 'player-1:state-active')
#     (-0.33640017485618595, 0.09925, -3.3894224166870117, 'player-6:stack')
#     (0.3351663649082184, 1, 0.3351663649082184, 'player-6:state-fold')
#     (-0.3193822410106659, 0.0995, -3.209871768951416, 'player-7:stack')
#     (-0.31416447162628175, 0.1, -3.1416447162628174, 'player-3:stack')
#     (-0.2934215307235718, 0.1, -2.9342153072357178, 'player-4:stack')
#     (0.28576943278312683, 1, 0.28576943278312683, 'player-5:state-fold')
#     (0.24400764353135052, 0.47058823529411764, 0.5185162425041199, 'player-1:history')
#     (-0.23696591967344285, 0.09975, -2.375598192214966, 'player-5:stack')
#     (0.22788932919502258, 1, 0.22788932919502258, 'player-3:state-fold')
#     (-0.20628998279571534, 0.1, -2.0628998279571533, 'player-2:stack')
#     (-0.12850178492069245, 0.0985, -1.30458664894104, 'player-9:stack')
#     (-0.12240741205215455, 0.09925, -1.2333240509033203, 'player-8:stack')
#     (0.10857503861188889, 1, 0.10857503861188889, 'player-8:state-fold')
#     (-0.10566748857498169, 0.098, -1.0782396793365479, 'player-1:stack')
#     (0.03206692636013031, 0.17647058823529413, 0.1817125827074051, 'player-0:history')
#     (-0.030508467167615894, 0.1015, -0.30057603120803833, 'player-0:stack')
#     (-0.007109582155942917, 0.00425, -1.6728428602218628, 'pot')
#     (0.0008306360531132669, 0.671, 0.0012379076797515154, 'cards')
#     (0.0, 0.0, 0.21105287969112396, 'player-9:history')
#     (0.0, 0, 1.892627239227295, 'player-9:state-active')
#     (0.0, 0.0, 0.18399052321910858, 'player-8:history')
#     (0.0, 0, 0.3531394302845001, 'player-8:state-active')
#     (0.0, 0.0, 0.3504723012447357, 'player-7:history')
#     (0.0, 0, 0.03959277644753456, 'player-7:state-active')
#     (0.0, 0.0, 1.1518380641937256, 'player-6:history')
#     (0.0, 0, 0.25807565450668335, 'player-6:state-active')
#     (0.0, 0.0, 3.1240625381469727, 'player-5:history')
#     (0.0, 0, 0.14975817501544952, 'player-5:state-active')
#     (0.0, 0.0, 0.7414211630821228, 'player-4:history')
#     (0.0, 0, 0.19107064604759216, 'player-4:state-active')
#     (0.0, 0.0, 0.04860743507742882, 'player-3:history')
#     (-0.0, 0, -0.040660858154296875, 'player-3:state-active')
#     (0.0, 0.0, 0.33559858798980713, 'player-2:history')
#     (0.0, 0, 0.783786416053772, 'player-2:state-active')
#     (0.0, 0, 0.5799099206924438, 'player-1:state-fold')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 5.779847145080566, 'street-river')
#     (0.0, 0, 5.775496482849121, 'street-turn')
#     (0.0, 0, 5.783719062805176, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 1.7218908071517944, 'btn distance=6')
#     (0.0, 0, 2.0152363777160645, 'btn distance=4')
#     (0.0, 0, 0.8341370820999146, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.16832740604877472, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (4.532103538513184, 1, 4.532103538513184, 'btn distance=5')
#     (-3.2477496, 0, 0, 'bias')
#     (-3.1422784328460693, 1, -3.1422784328460693, 'player-0:state-active')
#     (-2.9947614669799805, 1, -2.9947614669799805, 'round level 2')
#     (1.8120472431182861, 1, 1.8120472431182861, 'street-preflop')
#     (1.6943824291229248, 1, 1.6943824291229248, 'player-9:state-fold')
#     (0.9818313717842102, 1, 0.9818313717842102, 'player-1:state-active')
#     (0.845072329044342, 1, 0.845072329044342, 'player-2:state-fold')
#     (0.7169987559318542, 1, 0.7169987559318542, 'player-8:state-fold')
#     (0.7122262505924001, 0.47058823529411764, 1.51348078250885, 'player-1:history')
#     (-0.3309082189798355, 0.09925, -3.33408784866333, 'player-6:stack')
#     (-0.32201619148254396, 0.1, -3.2201619148254395, 'player-4:stack')
#     (-0.31708676636219024, 0.0995, -3.1868016719818115, 'player-7:stack')
#     (-0.28652439117431644, 0.1, -2.865243911743164, 'player-3:stack')
#     (-0.2758033618927002, 0.09975, -2.7649459838867188, 'player-5:stack')
#     (-0.2671574652194977, 1, -0.2671574652194977, 'player-6:state-fold')
#     (-0.2590565085411072, 1, -0.2590565085411072, 'player-4:state-fold')
#     (0.2175903039820054, 0.17647058823529413, 1.2330117225646973, 'player-0:history')
#     (-0.14990326762199402, 1, -0.14990326762199402, 'player-5:state-fold')
#     (-0.11248470544815065, 0.1, -1.1248470544815063, 'player-2:stack')
#     (-0.09796147793531418, 1, -0.09796147793531418, 'player-3:state-fold')
#     (-0.08436869025230408, 0.09925, -0.850062370300293, 'player-8:stack')
#     (-0.06090888103842736, 0.0985, -0.6183642745018005, 'player-9:stack')
#     (-0.06086798012256622, 1, -0.06086798012256622, 'player-7:state-fold')
#     (0.0543322317302227, 0.1015, 0.53529292345047, 'player-0:stack')
#     (0.02532309478521347, 0.671, 0.037739336490631104, 'cards')
#     (-0.007006569534540177, 0.098, -0.07149560749530792, 'player-1:stack')
#     (-0.005321920454502106, 0.00425, -1.2522165775299072, 'pot')
#     (0.0, 0.0, 1.291176676750183, 'player-9:history')
#     (0.0, 0, 1.8247454166412354, 'player-9:state-active')
#     (0.0, 0.0, 1.1795369386672974, 'player-8:history')
#     (0.0, 0, 0.663237452507019, 'player-8:state-active')
#     (0.0, 0.0, 1.0383859872817993, 'player-7:history')
#     (0.0, 0, 0.7693021297454834, 'player-7:state-active')
#     (0.0, 0.0, 1.1309703588485718, 'player-6:history')
#     (-0.0, 0, -0.1573736071586609, 'player-6:state-active')
#     (0.0, 0.0, 3.9546964168548584, 'player-5:history')
#     (-0.0, 0, -0.12567837536334991, 'player-5:state-active')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.322771817445755, 'player-4:state-active')
#     (0.0, 0.0, 1.215385913848877, 'player-3:history')
#     (-0.0, 0, -0.383811354637146, 'player-3:state-active')
#     (0.0, 0.0, 1.2303870916366577, 'player-2:history')
#     (0.0, 0, 0.5781336426734924, 'player-2:state-active')
#     (0.0, 0, 1.1562014818191528, 'player-1:state-fold')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 1.6342405080795288, 'street-river')
#     (0.0, 0, 1.6452300548553467, 'street-turn')
#     (0.0, 0, 1.6558911800384521, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 4.534221649169922, 'btn distance=6')
#     (0.0, 0, 4.487122535705566, 'btn distance=4')
#     (0.0, 0, 2.3121118545532227, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (0.0, 0, 0.004582444205880165, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (5.055746078491211, 1, 5.055746078491211, 'btn distance=5')
#     (4.818927764892578, 1, 4.818927764892578, 'street-preflop')
#     (-4.6558404, 0, 0, 'bias')
#     (-4.514601707458496, 1, -4.514601707458496, 'round level 2')
#     (-4.434072494506836, 1, -4.434072494506836, 'player-0:state-active')
#     (1.9543581008911133, 1, 1.9543581008911133, 'player-9:state-fold')
#     (1.6524394750595093, 1, 1.6524394750595093, 'player-2:state-fold')
#     (1.4725059270858765, 1, 1.4725059270858765, 'player-1:state-active')
#     (0.7432066798210144, 1, 0.7432066798210144, 'player-8:state-fold')
#     (0.5096684624167049, 0.47058823529411764, 1.083045482635498, 'player-1:history')
#     (-0.4543015787601471, 0.0995, -4.565845012664795, 'player-7:stack')
#     (-0.4487069129943848, 0.1, -4.487069129943848, 'player-4:stack')
#     (-0.44157038450241093, 0.09925, -4.449071884155273, 'player-6:stack')
#     (-0.4251497268676758, 0.1, -4.251497268676758, 'player-3:stack')
#     (-0.35961834847927093, 0.09975, -3.605196475982666, 'player-5:stack')
#     (-0.2157161422967911, 0.09925, -2.173462390899658, 'player-8:stack')
#     (-0.1988848924636841, 0.1, -1.9888489246368408, 'player-2:stack')
#     (-0.19548619478940965, 0.0985, -1.9846314191818237, 'player-9:stack')
#     (0.167784101822797, 0.17647058823529413, 0.9507765769958496, 'player-0:history')
#     (-0.1636284589767456, 1, -0.1636284589767456, 'player-6:state-fold')
#     (0.14702603220939636, 1, 0.14702603220939636, 'player-5:state-fold')
#     (-0.13628092288970947, 0.098, -1.3906216621398926, 'player-1:stack')
#     (-0.1000925824046135, 1, -0.1000925824046135, 'player-7:state-fold')
#     (-0.07802434504032135, 0.1015, -0.7687127590179443, 'player-0:stack')
#     (-0.0480794794857502, 1, -0.0480794794857502, 'player-4:state-fold')
#     (0.044549502432346344, 1, 0.044549502432346344, 'player-3:state-fold')
#     (0.022775271356105804, 0.671, 0.03394228219985962, 'cards')
#     (-0.009516764640808107, 0.00425, -2.239238739013672, 'pot')
#     (0.0, 0.0, 0.9223057627677917, 'player-9:history')
#     (0.0, 0, 2.0814356803894043, 'player-9:state-active')
#     (0.0, 0.0, 0.14122672379016876, 'player-8:history')
#     (0.0, 0, 1.3031387329101562, 'player-8:state-active')
#     (0.0, 0.0, 0.8793066143989563, 'player-7:history')
#     (0.0, 0, 0.7299915552139282, 'player-7:state-active')
#     (0.0, 0.0, 1.115983247756958, 'player-6:history')
#     (-0.0, 0, -0.4027332663536072, 'player-6:state-active')
#     (0.0, 0.0, 4.621358871459961, 'player-5:history')
#     (-0.0, 0, -0.06596492230892181, 'player-5:state-active')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.1980748474597931, 'player-4:state-active')
#     (0.0, 0.0, 0.7735869288444519, 'player-3:history')
#     (0.0, 0, 0.16460007429122925, 'player-3:state-active')
#     (0.0, 0.0, 1.1248043775558472, 'player-2:history')
#     (0.0, 0, 1.4199254512786865, 'player-2:state-active')
#     (0.0, 0, 1.6003220081329346, 'player-1:state-fold')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 4.711547374725342, 'street-river')
#     (0.0, 0, 4.759979248046875, 'street-turn')
#     (0.0, 0, 4.742796421051025, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 4.781858921051025, 'btn distance=6')
#     (0.0, 0, 5.038480281829834, 'btn distance=4')
#     (0.0, 0, 2.464824676513672, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (4.482860088348389, 1, 4.482860088348389, 'btn distance=5')
#     (-4.406982898712158, 1, -4.406982898712158, 'round level 2')
#     (-4.3275876, 0, 0, 'bias')
#     (-4.227409362792969, 1, -4.227409362792969, 'player-0:state-active')
#     (3.9146602153778076, 1, 3.9146602153778076, 'street-preflop')
#     (2.0677928924560547, 1, 2.0677928924560547, 'player-9:state-fold')
#     (1.4921538829803467, 1, 1.4921538829803467, 'player-8:state-fold')
#     (1.2212973833084106, 1, 1.2212973833084106, 'player-2:state-fold')
#     (1.1610509157180786, 1, 1.1610509157180786, 'player-1:state-active')
#     (0.5652259377872243, 0.47058823529411764, 1.2011051177978516, 'player-1:history')
#     (-0.45220668613910675, 0.09925, -4.556238651275635, 'player-6:stack')
#     (-0.45110817813873294, 0.0995, -4.533750534057617, 'player-7:stack')
#     (-0.4266695499420166, 0.1, -4.266695499420166, 'player-4:stack')
#     (-0.42118577957153325, 0.1, -4.211857795715332, 'player-3:stack')
#     (-0.3783639010190964, 0.09975, -3.793121814727783, 'player-5:stack')
#     (0.37751859426498413, 1, 0.37751859426498413, 'player-7:state-fold')
#     (-0.3306515693664551, 0.1, -3.306515693664551, 'player-2:stack')
#     (-0.22566524547338487, 0.09925, -2.273705244064331, 'player-8:stack')
#     (-0.21942699348926545, 0.0985, -2.2276852130889893, 'player-9:stack')
#     (-0.2122846717834473, 0.098, -2.166170120239258, 'player-1:stack')
#     (0.14639985911986408, 0.17647058823529413, 0.8295992016792297, 'player-0:history')
#     (-0.1290101327300072, 0.1015, -1.2710357904434204, 'player-0:stack')
#     (0.10334695130586624, 1, 0.10334695130586624, 'player-3:state-fold')
#     (0.10210249572992325, 1, 0.10210249572992325, 'player-6:state-fold')
#     (0.03121505118906498, 1, 0.03121505118906498, 'player-5:state-fold')
#     (-0.014281036138534547, 0.00425, -3.360243797302246, 'pot')
#     (0.002188226208090782, 1, 0.002188226208090782, 'player-4:state-fold')
#     (-0.001226484854705632, 0.671, -0.0018278462812304497, 'cards')
#     (0.0, 0.0, 0.7960175275802612, 'player-9:history')
#     (0.0, 0, 2.1582446098327637, 'player-9:state-active')
#     (0.0, 0.0, 0.3305920660495758, 'player-8:history')
#     (0.0, 0, 2.0035831928253174, 'player-8:state-active')
#     (0.0, 0.0, 0.9742657542228699, 'player-7:history')
#     (0.0, 0, 1.0885356664657593, 'player-7:state-active')
#     (0.0, 0.0, 1.4121673107147217, 'player-6:history')
#     (-0.0, 0, -0.1499478816986084, 'player-6:state-active')
#     (0.0, 0.0, 4.591096878051758, 'player-5:history')
#     (-0.0, 0, -0.2457582950592041, 'player-5:state-active')
#     (0.0, 0.0, 0.7097942233085632, 'player-4:history')
#     (-0.0, 0, -0.1636890172958374, 'player-4:state-active')
#     (0.0, 0.0, 1.2310571670532227, 'player-3:history')
#     (0.0, 0, 0.2654922306537628, 'player-3:state-active')
#     (0.0, 0.0, 0.9553847908973694, 'player-2:history')
#     (0.0, 0, 1.1588884592056274, 'player-2:state-active')
#     (0.0, 0, 1.365329623222351, 'player-1:state-fold')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 3.7991323471069336, 'street-river')
#     (0.0, 0, 3.79378604888916, 'street-turn')
#     (0.0, 0, 3.8325355052948, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 4.431316375732422, 'btn distance=6')
#     (0.0, 0, 4.559382438659668, 'btn distance=4')
#     (0.0, 0, 2.1376571655273438, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (0.0, 0, 0.017454855144023895, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (4.522878646850586, 1, 4.522878646850586, 'btn distance=5')
#     (-4.480043888092041, 1, -4.480043888092041, 'round level 2')
#     (-4.3140716552734375, 1, -4.3140716552734375, 'player-0:state-active')
#     (-4.2641134, 0, 0, 'bias')
#     (3.4204375743865967, 1, 3.4204375743865967, 'street-preflop')
#     (1.7670563459396362, 1, 1.7670563459396362, 'player-8:state-fold')
#     (1.6473029851913452, 1, 1.6473029851913452, 'player-9:state-fold')
#     (1.0051987171173096, 1, 1.0051987171173096, 'player-1:state-active')
#     (0.8816099762916565, 1, 0.8816099762916565, 'player-2:state-fold')
#     (0.8060318827629089, 1, 0.8060318827629089, 'player-7:state-fold')
#     (0.6979881735409007, 0.47058823529411764, 1.483224868774414, 'player-1:history')
#     (-0.428362241268158, 0.09925, -4.31599235534668, 'player-6:stack')
#     (-0.4149498462677002, 0.1, -4.149498462677002, 'player-4:stack')
#     (-0.41011061668396, 0.1, -4.1011061668396, 'player-3:stack')
#     (0.40404701232910156, 1, 0.40404701232910156, 'player-5:state-fold')
#     (-0.4040215198993683, 0.0995, -4.06051778793335, 'player-7:stack')
#     (-0.38557817620038987, 0.09975, -3.865445375442505, 'player-5:stack')
#     (0.3784959018230438, 1, 0.3784959018230438, 'player-4:state-fold')
#     (-0.3193996906280518, 0.1, -3.1939969062805176, 'player-2:stack')
#     (-0.24502334284782412, 0.09925, -2.4687490463256836, 'player-8:stack')
#     (-0.2314088478088379, 0.098, -2.3613147735595703, 'player-1:stack')
#     (-0.23127913212776186, 0.0985, -2.3480114936828613, 'player-9:stack')
#     (0.2227562665939331, 1, 0.2227562665939331, 'player-3:state-fold')
#     (0.1650526374578476, 1, 0.1650526374578476, 'player-6:state-fold')
#     (0.15552783713621252, 0.17647058823529413, 0.8813244104385376, 'player-0:history')
#     (-0.13491760230064392, 0.1015, -1.329237461090088, 'player-0:stack')
#     (0.024968189168721438, 0.671, 0.03721041604876518, 'cards')
#     (-0.013471219539642336, 0.00425, -3.169698715209961, 'pot')
#     (0.0, 0.0, 0.770615816116333, 'player-9:history')
#     (0.0, 0, 1.877943754196167, 'player-9:state-active')
#     (0.0, 0.0, 0.6260371208190918, 'player-8:history')
#     (0.0, 0, 2.078235149383545, 'player-8:state-active')
#     (0.0, 0.0, 1.1300346851348877, 'player-7:history')
#     (0.0, 0, 1.586179256439209, 'player-7:state-active')
#     (0.0, 0.0, 1.6851731538772583, 'player-6:history')
#     (-0.0, 0, -0.1532966047525406, 'player-6:state-active')
#     (0.0, 0.0, 4.89209508895874, 'player-5:history')
#     (0.0, 0, 0.08034905046224594, 'player-5:state-active')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (-0.0, 0, -0.03344249725341797, 'player-4:state-active')
#     (0.0, 0.0, 1.095296859741211, 'player-3:history')
#     (0.0, 0, 0.2968495190143585, 'player-3:state-active')
#     (0.0, 0.0, 0.8755476474761963, 'player-2:history')
#     (0.0, 0, 0.7729678153991699, 'player-2:state-active')
#     (0.0, 0, 1.1522746086120605, 'player-1:state-fold')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 3.3509480953216553, 'street-river')
#     (0.0, 0, 3.3434667587280273, 'street-turn')
#     (0.0, 0, 3.3365421295166016, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 4.520473003387451, 'btn distance=6')
#     (0.0, 0, 4.673919200897217, 'btn distance=4')
#     (0.0, 0, 2.2241458892822266, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (4.41821813583374, 1, 4.41821813583374, 'street-preflop')
#     (-3.2135443687438965, 1, -3.2135443687438965, 'player-0:state-active')
#     (-3.1577177, 0, 0, 'bias')
#     (-3.13590145111084, 1, -3.13590145111084, 'round level 2')
#     (3.0787465572357178, 1, 3.0787465572357178, 'btn distance=5')
#     (0.9034026265144348, 1, 0.9034026265144348, 'player-9:state-fold')
#     (0.7097644805908203, 1, 0.7097644805908203, 'player-1:state-active')
#     (0.6469631195068359, 1, 0.6469631195068359, 'player-8:state-fold')
#     (0.45517832040786743, 1, 0.45517832040786743, 'player-2:state-fold')
#     (0.42348459362983704, 1, 0.42348459362983704, 'player-7:state-fold')
#     (0.3642803640926585, 0.47058823529411764, 0.7740957736968994, 'player-1:history')
#     (-0.3491110135316849, 0.0995, -3.508653402328491, 'player-7:stack')
#     (-0.33510909080505374, 0.1, -3.351090908050537, 'player-4:stack')
#     (-0.3343605756759644, 0.1, -3.3436057567596436, 'player-3:stack')
#     (-0.3145189107656479, 0.09925, -3.1689562797546387, 'player-6:stack')
#     (-0.26166993379592896, 1, -0.26166993379592896, 'player-3:state-fold')
#     (-0.23615927320718766, 0.09975, -2.367511510848999, 'player-5:stack')
#     (0.16361095678806306, 0.1015, 1.6119306087493896, 'player-0:stack')
#     (0.12171267159283163, 0.671, 0.1813899725675583, 'cards')
#     (-0.12164759635925293, 1, -0.12164759635925293, 'player-5:state-fold')
#     (0.09106481425902423, 0.17647058823529413, 0.516033947467804, 'player-0:history')
#     (-0.030844999194145205, 0.098, -0.31474488973617554, 'player-1:stack')
#     (0.02694733813405037, 1, 0.02694733813405037, 'player-4:state-fold')
#     (-0.0241244896017015, 0.09925, -0.2430679053068161, 'player-8:stack')
#     (0.006867504864931107, 0.1, 0.06867504864931107, 'player-2:stack')
#     (0.0028250972330570224, 0.00425, 0.6647287607192993, 'pot')
#     (-0.0021507784398272635, 0.0985, -0.021835314109921455, 'player-9:stack')
#     (-0.001967048505321145, 1, -0.001967048505321145, 'player-6:state-fold')
#     (0.0, 0.0, 0.31516334414482117, 'player-9:history')
#     (0.0, 0, 0.8671867251396179, 'player-9:state-active')
#     (0.0, 0.0, 0.5197494029998779, 'player-8:history')
#     (0.0, 0, 0.9348535537719727, 'player-8:state-active')
#     (0.0, 0.0, 0.24247685074806213, 'player-7:history')
#     (0.0, 0, 1.0271284580230713, 'player-7:state-active')
#     (0.0, 0.0, 0.78851318359375, 'player-6:history')
#     (-0.0, 0, -0.3629549443721771, 'player-6:state-active')
#     (0.0, 0.0, 3.0412025451660156, 'player-5:history')
#     (-0.0, 0, -0.25344574451446533, 'player-5:state-active')
#     (0.0, 0.0, 0.6614777445793152, 'player-4:history')
#     (-0.0, 0, -0.11196428537368774, 'player-4:state-active')
#     (0.0, 0.0, 0.18499401211738586, 'player-3:history')
#     (-0.0, 0, -0.07745938003063202, 'player-3:state-active')
#     (0.0, 0.0, 0.9312912225723267, 'player-2:history')
#     (0.0, 0, 0.471826434135437, 'player-2:state-active')
#     (0.0, 0, 0.6840940713882446, 'player-1:state-fold')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 4.547295570373535, 'street-river')
#     (0.0, 0, 4.49630880355835, 'street-turn')
#     (0.0, 0, 4.49180269241333, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 2.790525197982788, 'btn distance=6')
#     (0.0, 0, 2.7943179607391357, 'btn distance=4')
#     (0.0, 0, 1.7247602939605713, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.04199141263961792, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### 3 round目で序盤にMIN_RAISEする場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10150]
# -- hole card --
#   - ['S6', 'C4']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925 <= SB
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9875 <= BB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9850
#     - 6 : agent (uuid-0) => state : participating, stack : 10150 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10225
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 75 (min_raise) ] at round 3
#   => [('fold', 0.04284214973449707), ('call', 0.022078990936279297), ('min_raise', 0.07746124267578125), ('double_raise', -0.013873100280761719), ('triple_raise', -0.08424186706542969), ('max_raise', 0.017872095108032227)]
# ** weights and features in detail **
# bias : [-3.25083518 -3.24774957 -4.6558404  -4.3275876  -4.26411343 -3.1577177 ]
#
# linear combination for fold :
#     (5.679295539855957, 1, 5.679295539855957, 'street-preflop')
#     (-3.2508352, 0, 0, 'bias')
#     (-3.236041307449341, 1, -3.236041307449341, 'player-0:state-active')
#     (-3.1531357765197754, 1, -3.1531357765197754, 'round level 2')
#     (2.0152363777160645, 1, 2.0152363777160645, 'btn distance=4')
#     (1.629240870475769, 1, 1.629240870475769, 'player-9:state-fold')
#     (0.783786416053772, 1, 0.783786416053772, 'player-2:state-active')
#     (0.48228156566619873, 1, 0.48228156566619873, 'player-1:state-active')
#     (0.3531394302845001, 1, 0.3531394302845001, 'player-8:state-active')
#     (-0.33640017485618595, 0.09925, -3.3894224166870117, 'player-6:stack')
#     (-0.31857977306842805, 0.09925, -3.209871768951416, 'player-7:stack')
#     (-0.31416447162628175, 0.1, -3.1416447162628174, 'player-3:stack')
#     (-0.2934215307235718, 0.1, -2.9342153072357178, 'player-4:stack')
#     (0.25807565450668335, 1, 0.25807565450668335, 'player-6:state-active')
#     (-0.23696591967344285, 0.09975, -2.375598192214966, 'player-5:stack')
#     (-0.20628998279571534, 0.1, -2.0628998279571533, 'player-2:stack')
#     (0.19107064604759216, 1, 0.19107064604759216, 'player-4:state-active')
#     (0.14975817501544952, 1, 0.14975817501544952, 'player-5:state-active')
#     (-0.12850178492069245, 0.0985, -1.30458664894104, 'player-9:stack')
#     (0.12266034881273905, 0.6666666666666666, 0.18399052321910858, 'player-8:history')
#     (-0.1217907500267029, 0.09875, -1.2333240509033203, 'player-8:stack')
#     (0.1168241004149119, 0.3333333333333333, 0.3504723012447357, 'player-7:history')
#     (-0.11025000721216201, 0.10225, -1.0782396793365479, 'player-1:stack')
#     (-0.040660858154296875, 1, -0.040660858154296875, 'player-3:state-active')
#     (0.03959277644753456, 1, 0.03959277644753456, 'player-7:state-active')
#     (-0.030508467167615894, 0.1015, -0.30057603120803833, 'player-0:stack')
#     (-0.001254632145166397, 0.00075, -1.6728428602218628, 'pot')
#     (0.0006808492238633336, 0.55, 0.0012379076797515154, 'cards')
#     (0.0, 0.0, 0.21105287969112396, 'player-9:history')
#     (0.0, 0, 1.892627239227295, 'player-9:state-active')
#     (0.0, 0, 0.10857503861188889, 'player-8:state-fold')
#     (-0.0, 0, -0.6163124442100525, 'player-7:state-fold')
#     (0.0, 0.0, 1.1518380641937256, 'player-6:history')
#     (0.0, 0, 0.3351663649082184, 'player-6:state-fold')
#     (0.0, 0.0, 3.1240625381469727, 'player-5:history')
#     (0.0, 0, 0.28576943278312683, 'player-5:state-fold')
#     (0.0, 0.0, 0.7414211630821228, 'player-4:history')
#     (0.0, 0, 0.5315114259719849, 'player-4:state-fold')
#     (0.0, 0.0, 0.04860743507742882, 'player-3:history')
#     (0.0, 0, 0.22788932919502258, 'player-3:state-fold')
#     (0.0, 0.0, 0.33559858798980713, 'player-2:history')
#     (0.0, 0, 0.8573673367500305, 'player-2:state-fold')
#     (0.0, 0.0, 0.5185162425041199, 'player-1:history')
#     (0.0, 0, 0.5799099206924438, 'player-1:state-fold')
#     (0.0, 0.0, 0.1817125827074051, 'player-0:history')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 5.779847145080566, 'street-river')
#     (0.0, 0, 5.775496482849121, 'street-turn')
#     (0.0, 0, 5.783719062805176, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 1.7218908071517944, 'btn distance=6')
#     (0.0, 0, 1.882977843284607, 'btn distance=5')
#     (0.0, 0, 0.8341370820999146, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.16832740604877472, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (4.487122535705566, 1, 4.487122535705566, 'btn distance=4')
#     (-3.2477496, 0, 0, 'bias')
#     (-3.1422784328460693, 1, -3.1422784328460693, 'player-0:state-active')
#     (-2.9947614669799805, 1, -2.9947614669799805, 'round level 2')
#     (1.8120472431182861, 1, 1.8120472431182861, 'street-preflop')
#     (1.6943824291229248, 1, 1.6943824291229248, 'player-9:state-fold')
#     (0.9818313717842102, 1, 0.9818313717842102, 'player-1:state-active')
#     (0.7863579591115315, 0.6666666666666666, 1.1795369386672974, 'player-8:history')
#     (0.7693021297454834, 1, 0.7693021297454834, 'player-7:state-active')
#     (0.663237452507019, 1, 0.663237452507019, 'player-8:state-active')
#     (0.5781336426734924, 1, 0.5781336426734924, 'player-2:state-active')
#     (-0.383811354637146, 1, -0.383811354637146, 'player-3:state-active')
#     (0.3461286624272664, 0.3333333333333333, 1.0383859872817993, 'player-7:history')
#     (-0.3309082189798355, 0.09925, -3.33408784866333, 'player-6:stack')
#     (-0.322771817445755, 1, -0.322771817445755, 'player-4:state-active')
#     (-0.32201619148254396, 0.1, -3.2201619148254395, 'player-4:stack')
#     (-0.3162900659441948, 0.09925, -3.1868016719818115, 'player-7:stack')
#     (-0.28652439117431644, 0.1, -2.865243911743164, 'player-3:stack')
#     (-0.2758033618927002, 0.09975, -2.7649459838867188, 'player-5:stack')
#     (-0.1573736071586609, 1, -0.1573736071586609, 'player-6:state-active')
#     (-0.12567837536334991, 1, -0.12567837536334991, 'player-5:state-active')
#     (-0.11248470544815065, 0.1, -1.1248470544815063, 'player-2:stack')
#     (-0.08394365906715394, 0.09875, -0.850062370300293, 'player-8:stack')
#     (-0.06090888103842736, 0.0985, -0.6183642745018005, 'player-9:stack')
#     (0.0543322317302227, 0.1015, 0.53529292345047, 'player-0:stack')
#     (0.02075663506984711, 0.55, 0.037739336490631104, 'cards')
#     (-0.007310425866395235, 0.10225, -0.07149560749530792, 'player-1:stack')
#     (-0.0009391624331474305, 0.00075, -1.2522165775299072, 'pot')
#     (0.0, 0.0, 1.291176676750183, 'player-9:history')
#     (0.0, 0, 1.8247454166412354, 'player-9:state-active')
#     (0.0, 0, 0.7169987559318542, 'player-8:state-fold')
#     (-0.0, 0, -0.06086798012256622, 'player-7:state-fold')
#     (0.0, 0.0, 1.1309703588485718, 'player-6:history')
#     (-0.0, 0, -0.2671574652194977, 'player-6:state-fold')
#     (0.0, 0.0, 3.9546964168548584, 'player-5:history')
#     (-0.0, 0, -0.14990326762199402, 'player-5:state-fold')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.2590565085411072, 'player-4:state-fold')
#     (0.0, 0.0, 1.215385913848877, 'player-3:history')
#     (-0.0, 0, -0.09796147793531418, 'player-3:state-fold')
#     (0.0, 0.0, 1.2303870916366577, 'player-2:history')
#     (0.0, 0, 0.845072329044342, 'player-2:state-fold')
#     (0.0, 0.0, 1.51348078250885, 'player-1:history')
#     (0.0, 0, 1.1562014818191528, 'player-1:state-fold')
#     (0.0, 0.0, 1.2330117225646973, 'player-0:history')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 1.6342405080795288, 'street-river')
#     (0.0, 0, 1.6452300548553467, 'street-turn')
#     (0.0, 0, 1.6558911800384521, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 4.534221649169922, 'btn distance=6')
#     (0.0, 0, 4.532103538513184, 'btn distance=5')
#     (0.0, 0, 2.3121118545532227, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (0.0, 0, 0.004582444205880165, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (5.038480281829834, 1, 5.038480281829834, 'btn distance=4')
#     (4.818927764892578, 1, 4.818927764892578, 'street-preflop')
#     (-4.6558404, 0, 0, 'bias')
#     (-4.514601707458496, 1, -4.514601707458496, 'round level 2')
#     (-4.434072494506836, 1, -4.434072494506836, 'player-0:state-active')
#     (1.9543581008911133, 1, 1.9543581008911133, 'player-9:state-fold')
#     (1.4725059270858765, 1, 1.4725059270858765, 'player-1:state-active')
#     (1.4199254512786865, 1, 1.4199254512786865, 'player-2:state-active')
#     (1.3031387329101562, 1, 1.3031387329101562, 'player-8:state-active')
#     (0.7299915552139282, 1, 0.7299915552139282, 'player-7:state-active')
#     (-0.45316011750698093, 0.09925, -4.565845012664795, 'player-7:stack')
#     (-0.4487069129943848, 0.1, -4.487069129943848, 'player-4:stack')
#     (-0.44157038450241093, 0.09925, -4.449071884155273, 'player-6:stack')
#     (-0.4251497268676758, 0.1, -4.251497268676758, 'player-3:stack')
#     (-0.4027332663536072, 1, -0.4027332663536072, 'player-6:state-active')
#     (-0.35961834847927093, 0.09975, -3.605196475982666, 'player-5:stack')
#     (0.2931022047996521, 0.3333333333333333, 0.8793066143989563, 'player-7:history')
#     (-0.21462941110134126, 0.09875, -2.173462390899658, 'player-8:stack')
#     (-0.1988848924636841, 0.1, -1.9888489246368408, 'player-2:stack')
#     (-0.1980748474597931, 1, -0.1980748474597931, 'player-4:state-active')
#     (-0.19548619478940965, 0.0985, -1.9846314191818237, 'player-9:stack')
#     (0.16460007429122925, 1, 0.16460007429122925, 'player-3:state-active')
#     (-0.14219106495380401, 0.10225, -1.3906216621398926, 'player-1:stack')
#     (0.09415114919344583, 0.6666666666666666, 0.14122672379016876, 'player-8:history')
#     (-0.07802434504032135, 0.1015, -0.7687127590179443, 'player-0:stack')
#     (-0.06596492230892181, 1, -0.06596492230892181, 'player-5:state-active')
#     (0.018668255209922793, 0.55, 0.03394228219985962, 'cards')
#     (-0.001679429054260254, 0.00075, -2.239238739013672, 'pot')
#     (0.0, 0.0, 0.9223057627677917, 'player-9:history')
#     (0.0, 0, 2.0814356803894043, 'player-9:state-active')
#     (0.0, 0, 0.7432066798210144, 'player-8:state-fold')
#     (-0.0, 0, -0.1000925824046135, 'player-7:state-fold')
#     (0.0, 0.0, 1.115983247756958, 'player-6:history')
#     (-0.0, 0, -0.1636284589767456, 'player-6:state-fold')
#     (0.0, 0.0, 4.621358871459961, 'player-5:history')
#     (0.0, 0, 0.14702603220939636, 'player-5:state-fold')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.0480794794857502, 'player-4:state-fold')
#     (0.0, 0.0, 0.7735869288444519, 'player-3:history')
#     (0.0, 0, 0.044549502432346344, 'player-3:state-fold')
#     (0.0, 0.0, 1.1248043775558472, 'player-2:history')
#     (0.0, 0, 1.6524394750595093, 'player-2:state-fold')
#     (0.0, 0.0, 1.083045482635498, 'player-1:history')
#     (0.0, 0, 1.6003220081329346, 'player-1:state-fold')
#     (0.0, 0.0, 0.9507765769958496, 'player-0:history')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 4.711547374725342, 'street-river')
#     (0.0, 0, 4.759979248046875, 'street-turn')
#     (0.0, 0, 4.742796421051025, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 4.781858921051025, 'btn distance=6')
#     (0.0, 0, 5.055746078491211, 'btn distance=5')
#     (0.0, 0, 2.464824676513672, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (4.559382438659668, 1, 4.559382438659668, 'btn distance=4')
#     (-4.406982898712158, 1, -4.406982898712158, 'round level 2')
#     (-4.3275876, 0, 0, 'bias')
#     (-4.227409362792969, 1, -4.227409362792969, 'player-0:state-active')
#     (3.9146602153778076, 1, 3.9146602153778076, 'street-preflop')
#     (2.0677928924560547, 1, 2.0677928924560547, 'player-9:state-fold')
#     (2.0035831928253174, 1, 2.0035831928253174, 'player-8:state-active')
#     (1.1610509157180786, 1, 1.1610509157180786, 'player-1:state-active')
#     (1.1588884592056274, 1, 1.1588884592056274, 'player-2:state-active')
#     (1.0885356664657593, 1, 1.0885356664657593, 'player-7:state-active')
#     (-0.45220668613910675, 0.09925, -4.556238651275635, 'player-6:stack')
#     (-0.4499747405052185, 0.09925, -4.533750534057617, 'player-7:stack')
#     (-0.4266695499420166, 0.1, -4.266695499420166, 'player-4:stack')
#     (-0.42118577957153325, 0.1, -4.211857795715332, 'player-3:stack')
#     (-0.3783639010190964, 0.09975, -3.793121814727783, 'player-5:stack')
#     (-0.3306515693664551, 0.1, -3.306515693664551, 'player-2:stack')
#     (0.3247552514076233, 0.3333333333333333, 0.9742657542228699, 'player-7:history')
#     (0.2654922306537628, 1, 0.2654922306537628, 'player-3:state-active')
#     (-0.2457582950592041, 1, -0.2457582950592041, 'player-5:state-active')
#     (-0.2245283928513527, 0.09875, -2.273705244064331, 'player-8:stack')
#     (-0.2214908947944641, 0.10225, -2.166170120239258, 'player-1:stack')
#     (0.2203947106997172, 0.6666666666666666, 0.3305920660495758, 'player-8:history')
#     (-0.21942699348926545, 0.0985, -2.2276852130889893, 'player-9:stack')
#     (-0.1636890172958374, 1, -0.1636890172958374, 'player-4:state-active')
#     (-0.1499478816986084, 1, -0.1499478816986084, 'player-6:state-active')
#     (-0.1290101327300072, 0.1015, -1.2710357904434204, 'player-0:stack')
#     (-0.0025201828479766847, 0.00075, -3.360243797302246, 'pot')
#     (-0.0010053154546767473, 0.55, -0.0018278462812304497, 'cards')
#     (0.0, 0.0, 0.7960175275802612, 'player-9:history')
#     (0.0, 0, 2.1582446098327637, 'player-9:state-active')
#     (0.0, 0, 1.4921538829803467, 'player-8:state-fold')
#     (0.0, 0, 0.37751859426498413, 'player-7:state-fold')
#     (0.0, 0.0, 1.4121673107147217, 'player-6:history')
#     (0.0, 0, 0.10210249572992325, 'player-6:state-fold')
#     (0.0, 0.0, 4.591096878051758, 'player-5:history')
#     (0.0, 0, 0.03121505118906498, 'player-5:state-fold')
#     (0.0, 0.0, 0.7097942233085632, 'player-4:history')
#     (0.0, 0, 0.002188226208090782, 'player-4:state-fold')
#     (0.0, 0.0, 1.2310571670532227, 'player-3:history')
#     (0.0, 0, 0.10334695130586624, 'player-3:state-fold')
#     (0.0, 0.0, 0.9553847908973694, 'player-2:history')
#     (0.0, 0, 1.2212973833084106, 'player-2:state-fold')
#     (0.0, 0.0, 1.2011051177978516, 'player-1:history')
#     (0.0, 0, 1.365329623222351, 'player-1:state-fold')
#     (0.0, 0.0, 0.8295992016792297, 'player-0:history')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 3.7991323471069336, 'street-river')
#     (0.0, 0, 3.79378604888916, 'street-turn')
#     (0.0, 0, 3.8325355052948, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 4.431316375732422, 'btn distance=6')
#     (0.0, 0, 4.482860088348389, 'btn distance=5')
#     (0.0, 0, 2.1376571655273438, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (0.0, 0, 0.017454855144023895, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (4.673919200897217, 1, 4.673919200897217, 'btn distance=4')
#     (-4.480043888092041, 1, -4.480043888092041, 'round level 2')
#     (-4.3140716552734375, 1, -4.3140716552734375, 'player-0:state-active')
#     (-4.2641134, 0, 0, 'bias')
#     (3.4204375743865967, 1, 3.4204375743865967, 'street-preflop')
#     (2.078235149383545, 1, 2.078235149383545, 'player-8:state-active')
#     (1.6473029851913452, 1, 1.6473029851913452, 'player-9:state-fold')
#     (1.586179256439209, 1, 1.586179256439209, 'player-7:state-active')
#     (1.0051987171173096, 1, 1.0051987171173096, 'player-1:state-active')
#     (0.7729678153991699, 1, 0.7729678153991699, 'player-2:state-active')
#     (-0.428362241268158, 0.09925, -4.31599235534668, 'player-6:stack')
#     (0.41735808054606116, 0.6666666666666666, 0.6260371208190918, 'player-8:history')
#     (-0.4149498462677002, 0.1, -4.149498462677002, 'player-4:stack')
#     (-0.41011061668396, 0.1, -4.1011061668396, 'player-3:stack')
#     (-0.40300639045238495, 0.09925, -4.06051778793335, 'player-7:stack')
#     (-0.38557817620038987, 0.09975, -3.865445375442505, 'player-5:stack')
#     (0.3766782283782959, 0.3333333333333333, 1.1300346851348877, 'player-7:history')
#     (-0.3193996906280518, 0.1, -3.1939969062805176, 'player-2:stack')
#     (0.2968495190143585, 1, 0.2968495190143585, 'player-3:state-active')
#     (-0.24378896832466126, 0.09875, -2.4687490463256836, 'player-8:stack')
#     (-0.24144443559646606, 0.10225, -2.3613147735595703, 'player-1:stack')
#     (-0.23127913212776186, 0.0985, -2.3480114936828613, 'player-9:stack')
#     (-0.1532966047525406, 1, -0.1532966047525406, 'player-6:state-active')
#     (-0.13491760230064392, 0.1015, -1.329237461090088, 'player-0:stack')
#     (0.08034905046224594, 1, 0.08034905046224594, 'player-5:state-active')
#     (-0.03344249725341797, 1, -0.03344249725341797, 'player-4:state-active')
#     (0.02046572882682085, 0.55, 0.03721041604876518, 'cards')
#     (-0.0023772740364074708, 0.00075, -3.169698715209961, 'pot')
#     (0.0, 0.0, 0.770615816116333, 'player-9:history')
#     (0.0, 0, 1.877943754196167, 'player-9:state-active')
#     (0.0, 0, 1.7670563459396362, 'player-8:state-fold')
#     (0.0, 0, 0.8060318827629089, 'player-7:state-fold')
#     (0.0, 0.0, 1.6851731538772583, 'player-6:history')
#     (0.0, 0, 0.1650526374578476, 'player-6:state-fold')
#     (0.0, 0.0, 4.89209508895874, 'player-5:history')
#     (0.0, 0, 0.40404701232910156, 'player-5:state-fold')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (0.0, 0, 0.3784959018230438, 'player-4:state-fold')
#     (0.0, 0.0, 1.095296859741211, 'player-3:history')
#     (0.0, 0, 0.2227562665939331, 'player-3:state-fold')
#     (0.0, 0.0, 0.8755476474761963, 'player-2:history')
#     (0.0, 0, 0.8816099762916565, 'player-2:state-fold')
#     (0.0, 0.0, 1.483224868774414, 'player-1:history')
#     (0.0, 0, 1.1522746086120605, 'player-1:state-fold')
#     (0.0, 0.0, 0.8813244104385376, 'player-0:history')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 3.3509480953216553, 'street-river')
#     (0.0, 0, 3.3434667587280273, 'street-turn')
#     (0.0, 0, 3.3365421295166016, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 4.520473003387451, 'btn distance=6')
#     (0.0, 0, 4.522878646850586, 'btn distance=5')
#     (0.0, 0, 2.2241458892822266, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (4.41821813583374, 1, 4.41821813583374, 'street-preflop')
#     (-3.2135443687438965, 1, -3.2135443687438965, 'player-0:state-active')
#     (-3.1577177, 0, 0, 'bias')
#     (-3.13590145111084, 1, -3.13590145111084, 'round level 2')
#     (2.7943179607391357, 1, 2.7943179607391357, 'btn distance=4')
#     (1.0271284580230713, 1, 1.0271284580230713, 'player-7:state-active')
#     (0.9348535537719727, 1, 0.9348535537719727, 'player-8:state-active')
#     (0.9034026265144348, 1, 0.9034026265144348, 'player-9:state-fold')
#     (0.7097644805908203, 1, 0.7097644805908203, 'player-1:state-active')
#     (0.471826434135437, 1, 0.471826434135437, 'player-2:state-active')
#     (-0.3629549443721771, 1, -0.3629549443721771, 'player-6:state-active')
#     (-0.34823385018110276, 0.09925, -3.508653402328491, 'player-7:stack')
#     (0.3464996019999186, 0.6666666666666666, 0.5197494029998779, 'player-8:history')
#     (-0.33510909080505374, 0.1, -3.351090908050537, 'player-4:stack')
#     (-0.3343605756759644, 0.1, -3.3436057567596436, 'player-3:stack')
#     (-0.3145189107656479, 0.09925, -3.1689562797546387, 'player-6:stack')
#     (-0.25344574451446533, 1, -0.25344574451446533, 'player-5:state-active')
#     (-0.23615927320718766, 0.09975, -2.367511510848999, 'player-5:stack')
#     (0.16361095678806306, 0.1015, 1.6119306087493896, 'player-0:stack')
#     (-0.11196428537368774, 1, -0.11196428537368774, 'player-4:state-active')
#     (0.09976448491215707, 0.55, 0.1813899725675583, 'cards')
#     (0.0808256169160207, 0.3333333333333333, 0.24247685074806213, 'player-7:history')
#     (-0.07745938003063202, 1, -0.07745938003063202, 'player-3:state-active')
#     (-0.032182664975523946, 0.10225, -0.31474488973617554, 'player-1:stack')
#     (-0.024002955649048092, 0.09875, -0.2430679053068161, 'player-8:stack')
#     (0.006867504864931107, 0.1, 0.06867504864931107, 'player-2:stack')
#     (-0.0021507784398272635, 0.0985, -0.021835314109921455, 'player-9:stack')
#     (0.0004985465705394745, 0.00075, 0.6647287607192993, 'pot')
#     (0.0, 0.0, 0.31516334414482117, 'player-9:history')
#     (0.0, 0, 0.8671867251396179, 'player-9:state-active')
#     (0.0, 0, 0.6469631195068359, 'player-8:state-fold')
#     (0.0, 0, 0.42348459362983704, 'player-7:state-fold')
#     (0.0, 0.0, 0.78851318359375, 'player-6:history')
#     (-0.0, 0, -0.001967048505321145, 'player-6:state-fold')
#     (0.0, 0.0, 3.0412025451660156, 'player-5:history')
#     (-0.0, 0, -0.12164759635925293, 'player-5:state-fold')
#     (0.0, 0.0, 0.6614777445793152, 'player-4:history')
#     (0.0, 0, 0.02694733813405037, 'player-4:state-fold')
#     (0.0, 0.0, 0.18499401211738586, 'player-3:history')
#     (-0.0, 0, -0.26166993379592896, 'player-3:state-fold')
#     (0.0, 0.0, 0.9312912225723267, 'player-2:history')
#     (0.0, 0, 0.45517832040786743, 'player-2:state-fold')
#     (0.0, 0.0, 0.7740957736968994, 'player-1:history')
#     (0.0, 0, 0.6840940713882446, 'player-1:state-fold')
#     (0.0, 0.0, 0.516033947467804, 'player-0:history')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 4.547295570373535, 'street-river')
#     (0.0, 0, 4.49630880355835, 'street-turn')
#     (0.0, 0, 4.49180269241333, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 2.790525197982788, 'btn distance=6')
#     (0.0, 0, 3.0787465572357178, 'btn distance=5')
#     (0.0, 0, 1.7247602939605713, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.04199141263961792, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')

# %% [markdown]
# ### 3roune目で1度RAISEしたのに,相手のMIN_RAISEでFOLDしてしまう場面

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 200
#   - raise: [325, 10150]
# -- hole card --
#   - ['S6', 'C4']
# -- round state --
#   - dealer btn : cpu4
#   - street : preflop
#   - community card : []
#   - pot : main = 425, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 9925
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 9925 <= SB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 9875 <= BB
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9850
#     - 6 : agent (uuid-0) => state : participating, stack : 10075 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10150
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 9800
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
#       - {'add_amount': 25, 'paid': 75, 'player': 'agent (uuid=uuid-0)', 'amount': 75, 'action': 'RAISE'}
#       - {'action': 'CALL', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 75, 'paid': 75}
#       - {'add_amount': 125, 'paid': 200, 'player': 'cpu2 (uuid=uuid-2)', 'amount': 200, 'action': 'RAISE'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 3
#   => [('fold', 0.005784749984741211), ('call', -0.610060453414917), ('min_raise', -0.33177852630615234), ('double_raise', -0.4433314800262451), ('triple_raise', -0.1623549461364746), ('max_raise', -0.18635916709899902)]
# ** weights and features in detail **
# bias : [-3.25083518 -3.24774957 -4.6558404  -4.3275876  -4.26411343 -3.1577177 ]
#
# linear combination for fold :
#     (5.679295539855957, 1, 5.679295539855957, 'street-preflop')
#     (-3.2508352, 0, 0, 'bias')
#     (-3.236041307449341, 1, -3.236041307449341, 'player-0:state-active')
#     (-3.1531357765197754, 1, -3.1531357765197754, 'round level 2')
#     (2.0152363777160645, 1, 2.0152363777160645, 'btn distance=4')
#     (1.629240870475769, 1, 1.629240870475769, 'player-9:state-fold')
#     (0.783786416053772, 1, 0.783786416053772, 'player-2:state-active')
#     (-0.6163124442100525, 1, -0.6163124442100525, 'player-7:state-fold')
#     (0.5315114259719849, 1, 0.5315114259719849, 'player-4:state-fold')
#     (0.48228156566619873, 1, 0.48228156566619873, 'player-1:state-active')
#     (-0.33640017485618595, 0.09925, -3.3894224166870117, 'player-6:stack')
#     (0.3351663649082184, 1, 0.3351663649082184, 'player-6:state-fold')
#     (-0.31857977306842805, 0.09925, -3.209871768951416, 'player-7:stack')
#     (-0.31416447162628175, 0.1, -3.1416447162628174, 'player-3:stack')
#     (-0.2934215307235718, 0.1, -2.9342153072357178, 'player-4:stack')
#     (0.28576943278312683, 1, 0.28576943278312683, 'player-5:state-fold')
#     (-0.23696591967344285, 0.09975, -2.375598192214966, 'player-5:stack')
#     (0.22788932919502258, 1, 0.22788932919502258, 'player-3:state-fold')
#     (-0.20216418313980103, 0.098, -2.0628998279571533, 'player-2:stack')
#     (0.157928747289321, 0.47058823529411764, 0.33559858798980713, 'player-2:history')
#     (-0.12850178492069245, 0.0985, -1.30458664894104, 'player-9:stack')
#     (-0.1217907500267029, 0.09875, -1.2333240509033203, 'player-8:stack')
#     (-0.10944132745265961, 0.1015, -1.0782396793365479, 'player-1:stack')
#     (0.10857503861188889, 1, 0.10857503861188889, 'player-8:state-fold')
#     (0.09150286632425646, 0.17647058823529413, 0.5185162425041199, 'player-1:history')
#     (0.03206692636013031, 0.17647058823529413, 0.1817125827074051, 'player-0:history')
#     (-0.030283035144209863, 0.10075, -0.30057603120803833, 'player-0:stack')
#     (-0.007109582155942917, 0.00425, -1.6728428602218628, 'pot')
#     (0.0006808492238633336, 0.55, 0.0012379076797515154, 'cards')
#     (0.0, 0.0, 0.21105287969112396, 'player-9:history')
#     (0.0, 0, 1.892627239227295, 'player-9:state-active')
#     (0.0, 0.0, 0.18399052321910858, 'player-8:history')
#     (0.0, 0, 0.3531394302845001, 'player-8:state-active')
#     (0.0, 0.0, 0.3504723012447357, 'player-7:history')
#     (0.0, 0, 0.03959277644753456, 'player-7:state-active')
#     (0.0, 0.0, 1.1518380641937256, 'player-6:history')
#     (0.0, 0, 0.25807565450668335, 'player-6:state-active')
#     (0.0, 0.0, 3.1240625381469727, 'player-5:history')
#     (0.0, 0, 0.14975817501544952, 'player-5:state-active')
#     (0.0, 0.0, 0.7414211630821228, 'player-4:history')
#     (0.0, 0, 0.19107064604759216, 'player-4:state-active')
#     (0.0, 0.0, 0.04860743507742882, 'player-3:history')
#     (-0.0, 0, -0.040660858154296875, 'player-3:state-active')
#     (0.0, 0, 0.8573673367500305, 'player-2:state-fold')
#     (0.0, 0, 0.5799099206924438, 'player-1:state-fold')
#     (-0.0, 0, -0.03733432665467262, 'player-0:state-fold')
#     (0.0, 0, 5.779847145080566, 'street-river')
#     (0.0, 0, 5.775496482849121, 'street-turn')
#     (0.0, 0, 5.783719062805176, 'street-flop')
#     (-0.0, 0, -0.09396886825561523, 'btn distance=9')
#     (0.0, 0, 0.06547679007053375, 'btn distance=8')
#     (-0.0, 0, -0.13481009006500244, 'btn distance=7')
#     (0.0, 0, 1.7218908071517944, 'btn distance=6')
#     (0.0, 0, 1.882977843284607, 'btn distance=5')
#     (0.0, 0, 0.8341370820999146, 'btn distance=3')
#     (0.0, 0, 0.18242201209068298, 'btn distance=2')
#     (0.0, 0, 0.16832740604877472, 'btn distance=1')
#     (0.0, 0, 0.021276582032442093, 'btn distance=0')
#     (0.0, 0, 0.007088616956025362, 'round level 27')
#     (0.0, 0, 0.2061028629541397, 'round level 26')
#     (-0.0, 0, -0.011795706115663052, 'round level 25')
#     (-0.0, 0, -0.06370362639427185, 'round level 24')
#     (-0.0, 0, -0.20823605358600616, 'round level 23')
#     (-0.0, 0, -0.24441765248775482, 'round level 22')
#     (-0.0, 0, -0.25912153720855713, 'round level 21')
#     (-0.0, 0, -0.2508646249771118, 'round level 20')
#     (-0.0, 0, -0.23230525851249695, 'round level 19')
#     (0.0, 0, 0.18624910712242126, 'round level 18')
#     (-0.0, 0, -0.013323252089321613, 'round level 17')
#     (0.0, 0, 0.24789856374263763, 'round level 16')
#     (0.0, 0, 0.2062944620847702, 'round level 15')
#     (-0.0, 0, -0.03182568401098251, 'round level 14')
#     (-0.0, 0, -0.025036368519067764, 'round level 13')
#     (-0.0, 0, -0.0955527275800705, 'round level 12')
#     (0.0, 0, 0.06590766459703445, 'round level 11')
#     (0.0, 0, 0.11238410323858261, 'round level 10')
#     (0.0, 0, 0.13858292996883392, 'round level 9')
#     (0.0, 0, 0.24407505989074707, 'round level 8')
#     (0.0, 0, 0.18806888163089752, 'round level 7')
#     (0.0, 0, 0.14435210824012756, 'round level 6')
#     (-0.0, 0, -0.23356394469738007, 'round level 5')
#     (-0.0, 0, -0.24355392158031464, 'round level 4')
#     (-0.0, 0, -0.19761787354946136, 'round level 3')
#     (0.0, 0, 0.23532238602638245, 'round level 1')
#
# linear combination for call :
#     (4.487122535705566, 1, 4.487122535705566, 'btn distance=4')
#     (-3.2477496, 0, 0, 'bias')
#     (-3.1422784328460693, 1, -3.1422784328460693, 'player-0:state-active')
#     (-2.9947614669799805, 1, -2.9947614669799805, 'round level 2')
#     (1.8120472431182861, 1, 1.8120472431182861, 'street-preflop')
#     (1.6943824291229248, 1, 1.6943824291229248, 'player-9:state-fold')
#     (0.9818313717842102, 1, 0.9818313717842102, 'player-1:state-active')
#     (0.7169987559318542, 1, 0.7169987559318542, 'player-8:state-fold')
#     (0.5790056901819566, 0.47058823529411764, 1.2303870916366577, 'player-2:history')
#     (0.5781336426734924, 1, 0.5781336426734924, 'player-2:state-active')
#     (-0.3309082189798355, 0.09925, -3.33408784866333, 'player-6:stack')
#     (-0.32201619148254396, 0.1, -3.2201619148254395, 'player-4:stack')
#     (-0.3162900659441948, 0.09925, -3.1868016719818115, 'player-7:stack')
#     (-0.28652439117431644, 0.1, -2.865243911743164, 'player-3:stack')
#     (-0.2758033618927002, 0.09975, -2.7649459838867188, 'player-5:stack')
#     (-0.2671574652194977, 1, -0.2671574652194977, 'player-6:state-fold')
#     (0.26708484397215004, 0.17647058823529413, 1.51348078250885, 'player-1:history')
#     (-0.2590565085411072, 1, -0.2590565085411072, 'player-4:state-fold')
#     (0.2175903039820054, 0.17647058823529413, 1.2330117225646973, 'player-0:history')
#     (-0.14990326762199402, 1, -0.14990326762199402, 'player-5:state-fold')
#     (-0.11023501133918763, 0.098, -1.1248470544815063, 'player-2:stack')
#     (-0.09796147793531418, 1, -0.09796147793531418, 'player-3:state-fold')
#     (-0.08394365906715394, 0.09875, -0.850062370300293, 'player-8:stack')
#     (-0.06090888103842736, 0.0985, -0.6183642745018005, 'player-9:stack')
#     (-0.06086798012256622, 1, -0.06086798012256622, 'player-7:state-fold')
#     (0.053930762037634854, 0.10075, 0.53529292345047, 'player-0:stack')
#     (0.02075663506984711, 0.55, 0.037739336490631104, 'cards')
#     (-0.007256804160773755, 0.1015, -0.07149560749530792, 'player-1:stack')
#     (-0.005321920454502106, 0.00425, -1.2522165775299072, 'pot')
#     (0.0, 0.0, 1.291176676750183, 'player-9:history')
#     (0.0, 0, 1.8247454166412354, 'player-9:state-active')
#     (0.0, 0.0, 1.1795369386672974, 'player-8:history')
#     (0.0, 0, 0.663237452507019, 'player-8:state-active')
#     (0.0, 0.0, 1.0383859872817993, 'player-7:history')
#     (0.0, 0, 0.7693021297454834, 'player-7:state-active')
#     (0.0, 0.0, 1.1309703588485718, 'player-6:history')
#     (-0.0, 0, -0.1573736071586609, 'player-6:state-active')
#     (0.0, 0.0, 3.9546964168548584, 'player-5:history')
#     (-0.0, 0, -0.12567837536334991, 'player-5:state-active')
#     (0.0, 0.0, 0.33820709586143494, 'player-4:history')
#     (-0.0, 0, -0.322771817445755, 'player-4:state-active')
#     (0.0, 0.0, 1.215385913848877, 'player-3:history')
#     (-0.0, 0, -0.383811354637146, 'player-3:state-active')
#     (0.0, 0, 0.845072329044342, 'player-2:state-fold')
#     (0.0, 0, 1.1562014818191528, 'player-1:state-fold')
#     (0.0, 0, 0.08453390002250671, 'player-0:state-fold')
#     (0.0, 0, 1.6342405080795288, 'street-river')
#     (0.0, 0, 1.6452300548553467, 'street-turn')
#     (0.0, 0, 1.6558911800384521, 'street-flop')
#     (-0.0, 0, -0.13875500857830048, 'btn distance=9')
#     (0.0, 0, 0.10401767492294312, 'btn distance=8')
#     (0.0, 0, 0.1129365935921669, 'btn distance=7')
#     (0.0, 0, 4.534221649169922, 'btn distance=6')
#     (0.0, 0, 4.532103538513184, 'btn distance=5')
#     (0.0, 0, 2.3121118545532227, 'btn distance=3')
#     (-0.0, 0, -0.29015228152275085, 'btn distance=2')
#     (0.0, 0, 0.004582444205880165, 'btn distance=1')
#     (-0.0, 0, -0.22328659892082214, 'btn distance=0')
#     (-0.0, 0, -0.09912467002868652, 'round level 27')
#     (-0.0, 0, -0.09958845376968384, 'round level 26')
#     (0.0, 0, 0.10356885939836502, 'round level 25')
#     (0.0, 0, 0.20577694475650787, 'round level 24')
#     (-0.0, 0, -0.1781451553106308, 'round level 23')
#     (0.0, 0, 0.18505509197711945, 'round level 22')
#     (0.0, 0, 0.12568825483322144, 'round level 21')
#     (0.0, 0, 0.015028374269604683, 'round level 20')
#     (-0.0, 0, -0.09063269942998886, 'round level 19')
#     (-0.0, 0, -0.11459366232156754, 'round level 18')
#     (-0.0, 0, -0.1732233166694641, 'round level 17')
#     (0.0, 0, 0.12376215308904648, 'round level 16')
#     (-0.0, 0, -0.25382450222969055, 'round level 15')
#     (-0.0, 0, -0.18417148292064667, 'round level 14')
#     (0.0, 0, 0.20761051774024963, 'round level 13')
#     (0.0, 0, 0.12169675529003143, 'round level 12')
#     (0.0, 0, 0.24083228409290314, 'round level 11')
#     (-0.0, 0, -0.24315626919269562, 'round level 10')
#     (-0.0, 0, -0.21992196142673492, 'round level 9')
#     (0.0, 0, 0.06606831401586533, 'round level 8')
#     (0.0, 0, 0.15511608123779297, 'round level 7')
#     (-0.0, 0, -0.2144855260848999, 'round level 6')
#     (-0.0, 0, -0.10436449944972992, 'round level 5')
#     (0.0, 0, 0.23807618021965027, 'round level 4')
#     (-0.0, 0, -0.1270373910665512, 'round level 3')
#     (0.0, 0, 0.12540709972381592, 'round level 1')
#
# linear combination for min_raise :
#     (5.038480281829834, 1, 5.038480281829834, 'btn distance=4')
#     (4.818927764892578, 1, 4.818927764892578, 'street-preflop')
#     (-4.6558404, 0, 0, 'bias')
#     (-4.514601707458496, 1, -4.514601707458496, 'round level 2')
#     (-4.434072494506836, 1, -4.434072494506836, 'player-0:state-active')
#     (1.9543581008911133, 1, 1.9543581008911133, 'player-9:state-fold')
#     (1.4725059270858765, 1, 1.4725059270858765, 'player-1:state-active')
#     (1.4199254512786865, 1, 1.4199254512786865, 'player-2:state-active')
#     (0.7432066798210144, 1, 0.7432066798210144, 'player-8:state-fold')
#     (0.5293197070851046, 0.47058823529411764, 1.1248043775558472, 'player-2:history')
#     (-0.45316011750698093, 0.09925, -4.565845012664795, 'player-7:stack')
#     (-0.4487069129943848, 0.1, -4.487069129943848, 'player-4:stack')
#     (-0.44157038450241093, 0.09925, -4.449071884155273, 'player-6:stack')
#     (-0.4251497268676758, 0.1, -4.251497268676758, 'player-3:stack')
#     (-0.35961834847927093, 0.09975, -3.605196475982666, 'player-5:stack')
#     (-0.21462941110134126, 0.09875, -2.173462390899658, 'player-8:stack')
#     (-0.19548619478940965, 0.0985, -1.9846314191818237, 'player-9:stack')
#     (-0.19490719461441042, 0.098, -1.9888489246368408, 'player-2:stack')
#     (0.19112567340626438, 0.17647058823529413, 1.083045482635498, 'player-1:history')
#     (0.167784101822797, 0.17647058823529413, 0.9507765769958496, 'player-0:history')
#     (-0.1636284589767456, 1, -0.1636284589767456, 'player-6:state-fold')
#     (0.14702603220939636, 1, 0.14702603220939636, 'player-5:state-fold')
#     (-0.1411480987071991, 0.1015, -1.3906216621398926, 'player-1:stack')
#     (-0.1000925824046135, 1, -0.1000925824046135, 'player-7:state-fold')
#     (-0.07744781047105789, 0.10075, -0.7687127590179443, 'player-0:stack')
#     (-0.0480794794857502, 1, -0.0480794794857502, 'player-4:state-fold')
#     (0.044549502432346344, 1, 0.044549502432346344, 'player-3:state-fold')
#     (0.018668255209922793, 0.55, 0.03394228219985962, 'cards')
#     (-0.009516764640808107, 0.00425, -2.239238739013672, 'pot')
#     (0.0, 0.0, 0.9223057627677917, 'player-9:history')
#     (0.0, 0, 2.0814356803894043, 'player-9:state-active')
#     (0.0, 0.0, 0.14122672379016876, 'player-8:history')
#     (0.0, 0, 1.3031387329101562, 'player-8:state-active')
#     (0.0, 0.0, 0.8793066143989563, 'player-7:history')
#     (0.0, 0, 0.7299915552139282, 'player-7:state-active')
#     (0.0, 0.0, 1.115983247756958, 'player-6:history')
#     (-0.0, 0, -0.4027332663536072, 'player-6:state-active')
#     (0.0, 0.0, 4.621358871459961, 'player-5:history')
#     (-0.0, 0, -0.06596492230892181, 'player-5:state-active')
#     (0.0, 0.0, 0.7859339118003845, 'player-4:history')
#     (-0.0, 0, -0.1980748474597931, 'player-4:state-active')
#     (0.0, 0.0, 0.7735869288444519, 'player-3:history')
#     (0.0, 0, 0.16460007429122925, 'player-3:state-active')
#     (0.0, 0, 1.6524394750595093, 'player-2:state-fold')
#     (0.0, 0, 1.6003220081329346, 'player-1:state-fold')
#     (0.0, 0, 0.07889767736196518, 'player-0:state-fold')
#     (0.0, 0, 4.711547374725342, 'street-river')
#     (0.0, 0, 4.759979248046875, 'street-turn')
#     (0.0, 0, 4.742796421051025, 'street-flop')
#     (0.0, 0, 0.11340643465518951, 'btn distance=9')
#     (0.0, 0, 0.24821768701076508, 'btn distance=8')
#     (0.0, 0, 0.05030427873134613, 'btn distance=7')
#     (0.0, 0, 4.781858921051025, 'btn distance=6')
#     (0.0, 0, 5.055746078491211, 'btn distance=5')
#     (0.0, 0, 2.464824676513672, 'btn distance=3')
#     (0.0, 0, 0.10971111059188843, 'btn distance=2')
#     (0.0, 0, 0.15281547605991364, 'btn distance=1')
#     (-0.0, 0, -0.13502471148967743, 'btn distance=0')
#     (-0.0, 0, -0.17338871955871582, 'round level 27')
#     (-0.0, 0, -0.05444741249084473, 'round level 26')
#     (0.0, 0, 0.06424499303102493, 'round level 25')
#     (-0.0, 0, -0.1450921893119812, 'round level 24')
#     (-0.0, 0, -0.14374063909053802, 'round level 23')
#     (0.0, 0, 0.19989460706710815, 'round level 22')
#     (-0.0, 0, -0.16650894284248352, 'round level 21')
#     (-0.0, 0, -0.034722402691841125, 'round level 20')
#     (-0.0, 0, -0.09511221945285797, 'round level 19')
#     (0.0, 0, 0.2571088373661041, 'round level 18')
#     (0.0, 0, 0.02249528281390667, 'round level 17')
#     (0.0, 0, 0.05685090273618698, 'round level 16')
#     (-0.0, 0, -0.19107164442539215, 'round level 15')
#     (-0.0, 0, -0.03510827571153641, 'round level 14')
#     (0.0, 0, 0.19866538047790527, 'round level 13')
#     (0.0, 0, 0.18236275017261505, 'round level 12')
#     (-0.0, 0, -0.09551361203193665, 'round level 11')
#     (-0.0, 0, -0.023744147270917892, 'round level 10')
#     (-0.0, 0, -0.1801074594259262, 'round level 9')
#     (0.0, 0, 0.08721116185188293, 'round level 8')
#     (0.0, 0, 0.2054033726453781, 'round level 7')
#     (-0.0, 0, -0.009914405643939972, 'round level 6')
#     (0.0, 0, 0.07710976153612137, 'round level 5')
#     (-0.0, 0, -0.024766113609075546, 'round level 4')
#     (-0.0, 0, -0.1667419672012329, 'round level 3')
#     (-0.0, 0, -0.1585337072610855, 'round level 1')
#
# linear combination for double_raise :
#     (4.559382438659668, 1, 4.559382438659668, 'btn distance=4')
#     (-4.406982898712158, 1, -4.406982898712158, 'round level 2')
#     (-4.3275876, 0, 0, 'bias')
#     (-4.227409362792969, 1, -4.227409362792969, 'player-0:state-active')
#     (3.9146602153778076, 1, 3.9146602153778076, 'street-preflop')
#     (2.0677928924560547, 1, 2.0677928924560547, 'player-9:state-fold')
#     (1.4921538829803467, 1, 1.4921538829803467, 'player-8:state-fold')
#     (1.1610509157180786, 1, 1.1610509157180786, 'player-1:state-active')
#     (1.1588884592056274, 1, 1.1588884592056274, 'player-2:state-active')
#     (-0.45220668613910675, 0.09925, -4.556238651275635, 'player-6:stack')
#     (-0.4499747405052185, 0.09925, -4.533750534057617, 'player-7:stack')
#     (0.44959284277523265, 0.47058823529411764, 0.9553847908973694, 'player-2:history')
#     (-0.4266695499420166, 0.1, -4.266695499420166, 'player-4:stack')
#     (-0.42118577957153325, 0.1, -4.211857795715332, 'player-3:stack')
#     (-0.3783639010190964, 0.09975, -3.793121814727783, 'player-5:stack')
#     (0.37751859426498413, 1, 0.37751859426498413, 'player-7:state-fold')
#     (-0.32403853797912596, 0.098, -3.306515693664551, 'player-2:stack')
#     (-0.2245283928513527, 0.09875, -2.273705244064331, 'player-8:stack')
#     (-0.21986626720428468, 0.1015, -2.166170120239258, 'player-1:stack')
#     (-0.21942699348926545, 0.0985, -2.2276852130889893, 'player-9:stack')
#     (0.21195972667020913, 0.17647058823529413, 1.2011051177978516, 'player-1:history')
#     (0.14639985911986408, 0.17647058823529413, 0.8295992016792297, 'player-0:history')
#     (-0.1280568558871746, 0.10075, -1.2710357904434204, 'player-0:stack')
#     (0.10334695130586624, 1, 0.10334695130586624, 'player-3:state-fold')
#     (0.10210249572992325, 1, 0.10210249572992325, 'player-6:state-fold')
#     (0.03121505118906498, 1, 0.03121505118906498, 'player-5:state-fold')
#     (-0.014281036138534547, 0.00425, -3.360243797302246, 'pot')
#     (0.002188226208090782, 1, 0.002188226208090782, 'player-4:state-fold')
#     (-0.0010053154546767473, 0.55, -0.0018278462812304497, 'cards')
#     (0.0, 0.0, 0.7960175275802612, 'player-9:history')
#     (0.0, 0, 2.1582446098327637, 'player-9:state-active')
#     (0.0, 0.0, 0.3305920660495758, 'player-8:history')
#     (0.0, 0, 2.0035831928253174, 'player-8:state-active')
#     (0.0, 0.0, 0.9742657542228699, 'player-7:history')
#     (0.0, 0, 1.0885356664657593, 'player-7:state-active')
#     (0.0, 0.0, 1.4121673107147217, 'player-6:history')
#     (-0.0, 0, -0.1499478816986084, 'player-6:state-active')
#     (0.0, 0.0, 4.591096878051758, 'player-5:history')
#     (-0.0, 0, -0.2457582950592041, 'player-5:state-active')
#     (0.0, 0.0, 0.7097942233085632, 'player-4:history')
#     (-0.0, 0, -0.1636890172958374, 'player-4:state-active')
#     (0.0, 0.0, 1.2310571670532227, 'player-3:history')
#     (0.0, 0, 0.2654922306537628, 'player-3:state-active')
#     (0.0, 0, 1.2212973833084106, 'player-2:state-fold')
#     (0.0, 0, 1.365329623222351, 'player-1:state-fold')
#     (0.0, 0, 0.020809147506952286, 'player-0:state-fold')
#     (0.0, 0, 3.7991323471069336, 'street-river')
#     (0.0, 0, 3.79378604888916, 'street-turn')
#     (0.0, 0, 3.8325355052948, 'street-flop')
#     (-0.0, 0, -0.19487541913986206, 'btn distance=9')
#     (0.0, 0, 0.10332157462835312, 'btn distance=8')
#     (-0.0, 0, -0.21233400702476501, 'btn distance=7')
#     (0.0, 0, 4.431316375732422, 'btn distance=6')
#     (0.0, 0, 4.482860088348389, 'btn distance=5')
#     (0.0, 0, 2.1376571655273438, 'btn distance=3')
#     (0.0, 0, 0.11168938875198364, 'btn distance=2')
#     (0.0, 0, 0.017454855144023895, 'btn distance=1')
#     (-0.0, 0, -0.17281554639339447, 'btn distance=0')
#     (0.0, 0, 0.1078585684299469, 'round level 27')
#     (-0.0, 0, -0.22759635746479034, 'round level 26')
#     (-0.0, 0, -0.07455950975418091, 'round level 25')
#     (0.0, 0, 0.005871549714356661, 'round level 24')
#     (-0.0, 0, -0.09874570369720459, 'round level 23')
#     (-0.0, 0, -0.020397674292325974, 'round level 22')
#     (-0.0, 0, -0.003707975149154663, 'round level 21')
#     (-0.0, 0, -0.031172651797533035, 'round level 20')
#     (-0.0, 0, -0.21925047039985657, 'round level 19')
#     (0.0, 0, 0.09739404171705246, 'round level 18')
#     (0.0, 0, 0.029009733349084854, 'round level 17')
#     (0.0, 0, 0.12481406331062317, 'round level 16')
#     (0.0, 0, 0.09991913288831711, 'round level 15')
#     (0.0, 0, 0.033742908388376236, 'round level 14')
#     (-0.0, 0, -0.07699281722307205, 'round level 13')
#     (0.0, 0, 0.08483527600765228, 'round level 12')
#     (-0.0, 0, -0.0049691214226186275, 'round level 11')
#     (-0.0, 0, -0.2583889067173004, 'round level 10')
#     (0.0, 0, 0.12946048378944397, 'round level 9')
#     (-0.0, 0, -0.0813131332397461, 'round level 8')
#     (-0.0, 0, -0.09622789919376373, 'round level 7')
#     (0.0, 0, 0.09733013808727264, 'round level 6')
#     (-0.0, 0, -0.04034019261598587, 'round level 5')
#     (0.0, 0, 0.12968383729457855, 'round level 4')
#     (-0.0, 0, -0.1715087741613388, 'round level 3')
#     (-0.0, 0, -0.07605915516614914, 'round level 1')
#
# linear combination for triple_raise :
#     (4.673919200897217, 1, 4.673919200897217, 'btn distance=4')
#     (-4.480043888092041, 1, -4.480043888092041, 'round level 2')
#     (-4.3140716552734375, 1, -4.3140716552734375, 'player-0:state-active')
#     (-4.2641134, 0, 0, 'bias')
#     (3.4204375743865967, 1, 3.4204375743865967, 'street-preflop')
#     (1.7670563459396362, 1, 1.7670563459396362, 'player-8:state-fold')
#     (1.6473029851913452, 1, 1.6473029851913452, 'player-9:state-fold')
#     (1.0051987171173096, 1, 1.0051987171173096, 'player-1:state-active')
#     (0.8060318827629089, 1, 0.8060318827629089, 'player-7:state-fold')
#     (0.7729678153991699, 1, 0.7729678153991699, 'player-2:state-active')
#     (-0.428362241268158, 0.09925, -4.31599235534668, 'player-6:stack')
#     (-0.4149498462677002, 0.1, -4.149498462677002, 'player-4:stack')
#     (0.4120224223417394, 0.47058823529411764, 0.8755476474761963, 'player-2:history')
#     (-0.41011061668396, 0.1, -4.1011061668396, 'player-3:stack')
#     (0.40404701232910156, 1, 0.40404701232910156, 'player-5:state-fold')
#     (-0.40300639045238495, 0.09925, -4.06051778793335, 'player-7:stack')
#     (-0.38557817620038987, 0.09975, -3.865445375442505, 'player-5:stack')
#     (0.3784959018230438, 1, 0.3784959018230438, 'player-4:state-fold')
#     (-0.31301169681549074, 0.098, -3.1939969062805176, 'player-2:stack')
#     (0.2617455650778378, 0.17647058823529413, 1.483224868774414, 'player-1:history')
#     (-0.24378896832466126, 0.09875, -2.4687490463256836, 'player-8:stack')
#     (-0.2396734495162964, 0.1015, -2.3613147735595703, 'player-1:stack')
#     (-0.23127913212776186, 0.0985, -2.3480114936828613, 'player-9:stack')
#     (0.2227562665939331, 1, 0.2227562665939331, 'player-3:state-fold')
#     (0.1650526374578476, 1, 0.1650526374578476, 'player-6:state-fold')
#     (0.15552783713621252, 0.17647058823529413, 0.8813244104385376, 'player-0:history')
#     (-0.13392067420482637, 0.10075, -1.329237461090088, 'player-0:stack')
#     (0.02046572882682085, 0.55, 0.03721041604876518, 'cards')
#     (-0.013471219539642336, 0.00425, -3.169698715209961, 'pot')
#     (0.0, 0.0, 0.770615816116333, 'player-9:history')
#     (0.0, 0, 1.877943754196167, 'player-9:state-active')
#     (0.0, 0.0, 0.6260371208190918, 'player-8:history')
#     (0.0, 0, 2.078235149383545, 'player-8:state-active')
#     (0.0, 0.0, 1.1300346851348877, 'player-7:history')
#     (0.0, 0, 1.586179256439209, 'player-7:state-active')
#     (0.0, 0.0, 1.6851731538772583, 'player-6:history')
#     (-0.0, 0, -0.1532966047525406, 'player-6:state-active')
#     (0.0, 0.0, 4.89209508895874, 'player-5:history')
#     (0.0, 0, 0.08034905046224594, 'player-5:state-active')
#     (0.0, 0.0, 0.7114231586456299, 'player-4:history')
#     (-0.0, 0, -0.03344249725341797, 'player-4:state-active')
#     (0.0, 0.0, 1.095296859741211, 'player-3:history')
#     (0.0, 0, 0.2968495190143585, 'player-3:state-active')
#     (0.0, 0, 0.8816099762916565, 'player-2:state-fold')
#     (0.0, 0, 1.1522746086120605, 'player-1:state-fold')
#     (0.0, 0, 0.07488908618688583, 'player-0:state-fold')
#     (0.0, 0, 3.3509480953216553, 'street-river')
#     (0.0, 0, 3.3434667587280273, 'street-turn')
#     (0.0, 0, 3.3365421295166016, 'street-flop')
#     (0.0, 0, 0.17059645056724548, 'btn distance=9')
#     (-0.0, 0, -0.20341463387012482, 'btn distance=8')
#     (-0.0, 0, -0.1927756518125534, 'btn distance=7')
#     (0.0, 0, 4.520473003387451, 'btn distance=6')
#     (0.0, 0, 4.522878646850586, 'btn distance=5')
#     (0.0, 0, 2.2241458892822266, 'btn distance=3')
#     (0.0, 0, 0.05474678426980972, 'btn distance=2')
#     (-0.0, 0, -0.1754060536623001, 'btn distance=1')
#     (-0.0, 0, -0.11297421157360077, 'btn distance=0')
#     (0.0, 0, 0.24916978180408478, 'round level 27')
#     (-0.0, 0, -0.04319116100668907, 'round level 26')
#     (-0.0, 0, -0.011913638561964035, 'round level 25')
#     (-0.0, 0, -0.18689073622226715, 'round level 24')
#     (0.0, 0, 0.19961902499198914, 'round level 23')
#     (0.0, 0, 0.0992523729801178, 'round level 22')
#     (0.0, 0, 0.24211782217025757, 'round level 21')
#     (-0.0, 0, -0.17394030094146729, 'round level 20')
#     (-0.0, 0, -0.09691328555345535, 'round level 19')
#     (0.0, 0, 0.021142255514860153, 'round level 18')
#     (0.0, 0, 0.13246987760066986, 'round level 17')
#     (0.0, 0, 0.06548882275819778, 'round level 16')
#     (0.0, 0, 0.25080206990242004, 'round level 15')
#     (-0.0, 0, -0.12780633568763733, 'round level 14')
#     (-0.0, 0, -0.015322891995310783, 'round level 13')
#     (0.0, 0, 0.10485604405403137, 'round level 12')
#     (-0.0, 0, -0.18820275366306305, 'round level 11')
#     (-0.0, 0, -0.2197113335132599, 'round level 10')
#     (-0.0, 0, -0.017122719436883926, 'round level 9')
#     (-0.0, 0, -0.05129392072558403, 'round level 8')
#     (0.0, 0, 0.07489215582609177, 'round level 7')
#     (-0.0, 0, -0.07150573283433914, 'round level 6')
#     (0.0, 0, 0.22329925000667572, 'round level 5')
#     (0.0, 0, 0.11327579617500305, 'round level 4')
#     (-0.0, 0, -0.025713765993714333, 'round level 3')
#     (-0.0, 0, -0.05159087851643562, 'round level 1')
#
# linear combination for max_raise :
#     (4.41821813583374, 1, 4.41821813583374, 'street-preflop')
#     (-3.2135443687438965, 1, -3.2135443687438965, 'player-0:state-active')
#     (-3.1577177, 0, 0, 'bias')
#     (-3.13590145111084, 1, -3.13590145111084, 'round level 2')
#     (2.7943179607391357, 1, 2.7943179607391357, 'btn distance=4')
#     (0.9034026265144348, 1, 0.9034026265144348, 'player-9:state-fold')
#     (0.7097644805908203, 1, 0.7097644805908203, 'player-1:state-active')
#     (0.6469631195068359, 1, 0.6469631195068359, 'player-8:state-fold')
#     (0.471826434135437, 1, 0.471826434135437, 'player-2:state-active')
#     (0.4382546929752125, 0.47058823529411764, 0.9312912225723267, 'player-2:history')
#     (0.42348459362983704, 1, 0.42348459362983704, 'player-7:state-fold')
#     (-0.34823385018110276, 0.09925, -3.508653402328491, 'player-7:stack')
#     (-0.33510909080505374, 0.1, -3.351090908050537, 'player-4:stack')
#     (-0.3343605756759644, 0.1, -3.3436057567596436, 'player-3:stack')
#     (-0.3145189107656479, 0.09925, -3.1689562797546387, 'player-6:stack')
#     (-0.26166993379592896, 1, -0.26166993379592896, 'player-3:state-fold')
#     (-0.23615927320718766, 0.09975, -2.367511510848999, 'player-5:stack')
#     (0.16240200883150102, 0.10075, 1.6119306087493896, 'player-0:stack')
#     (0.13660513653474696, 0.17647058823529413, 0.7740957736968994, 'player-1:history')
#     (-0.12164759635925293, 1, -0.12164759635925293, 'player-5:state-fold')
#     (0.09976448491215707, 0.55, 0.1813899725675583, 'cards')
#     (0.09106481425902423, 0.17647058823529413, 0.516033947467804, 'player-0:history')
#     (-0.03194660630822182, 0.1015, -0.31474488973617554, 'player-1:stack')
#     (0.02694733813405037, 1, 0.02694733813405037, 'player-4:state-fold')
#     (-0.024002955649048092, 0.09875, -0.2430679053068161, 'player-8:stack')
#     (0.006730154767632485, 0.098, 0.06867504864931107, 'player-2:stack')
#     (0.0028250972330570224, 0.00425, 0.6647287607192993, 'pot')
#     (-0.0021507784398272635, 0.0985, -0.021835314109921455, 'player-9:stack')
#     (-0.001967048505321145, 1, -0.001967048505321145, 'player-6:state-fold')
#     (0.0, 0.0, 0.31516334414482117, 'player-9:history')
#     (0.0, 0, 0.8671867251396179, 'player-9:state-active')
#     (0.0, 0.0, 0.5197494029998779, 'player-8:history')
#     (0.0, 0, 0.9348535537719727, 'player-8:state-active')
#     (0.0, 0.0, 0.24247685074806213, 'player-7:history')
#     (0.0, 0, 1.0271284580230713, 'player-7:state-active')
#     (0.0, 0.0, 0.78851318359375, 'player-6:history')
#     (-0.0, 0, -0.3629549443721771, 'player-6:state-active')
#     (0.0, 0.0, 3.0412025451660156, 'player-5:history')
#     (-0.0, 0, -0.25344574451446533, 'player-5:state-active')
#     (0.0, 0.0, 0.6614777445793152, 'player-4:history')
#     (-0.0, 0, -0.11196428537368774, 'player-4:state-active')
#     (0.0, 0.0, 0.18499401211738586, 'player-3:history')
#     (-0.0, 0, -0.07745938003063202, 'player-3:state-active')
#     (0.0, 0, 0.45517832040786743, 'player-2:state-fold')
#     (0.0, 0, 0.6840940713882446, 'player-1:state-fold')
#     (0.0, 0, 0.1978996843099594, 'player-0:state-fold')
#     (0.0, 0, 4.547295570373535, 'street-river')
#     (0.0, 0, 4.49630880355835, 'street-turn')
#     (0.0, 0, 4.49180269241333, 'street-flop')
#     (0.0, 0, 0.0016371457604691386, 'btn distance=9')
#     (-0.0, 0, -0.14669746160507202, 'btn distance=8')
#     (0.0, 0, 0.10521026700735092, 'btn distance=7')
#     (0.0, 0, 2.790525197982788, 'btn distance=6')
#     (0.0, 0, 3.0787465572357178, 'btn distance=5')
#     (0.0, 0, 1.7247602939605713, 'btn distance=3')
#     (-0.0, 0, -0.08318664878606796, 'btn distance=2')
#     (-0.0, 0, -0.04199141263961792, 'btn distance=1')
#     (-0.0, 0, -0.11538852006196976, 'btn distance=0')
#     (-0.0, 0, -0.03647061064839363, 'round level 27')
#     (-0.0, 0, -0.2561314105987549, 'round level 26')
#     (-0.0, 0, -0.017437446862459183, 'round level 25')
#     (0.0, 0, 0.21594639122486115, 'round level 24')
#     (0.0, 0, 0.2112048864364624, 'round level 23')
#     (0.0, 0, 0.18610483407974243, 'round level 22')
#     (-0.0, 0, -0.07909655570983887, 'round level 21')
#     (-0.0, 0, -0.12388546764850616, 'round level 20')
#     (0.0, 0, 0.2037031203508377, 'round level 19')
#     (0.0, 0, 0.19245855510234833, 'round level 18')
#     (0.0, 0, 0.23192478716373444, 'round level 17')
#     (-0.0, 0, -0.07351304590702057, 'round level 16')
#     (0.0, 0, 0.09287410229444504, 'round level 15')
#     (0.0, 0, 0.14794018864631653, 'round level 14')
#     (-0.0, 0, -0.046679623425006866, 'round level 13')
#     (0.0, 0, 0.12648889422416687, 'round level 12')
#     (0.0, 0, 0.026773523539304733, 'round level 11')
#     (0.0, 0, 0.09113265573978424, 'round level 10')
#     (0.0, 0, 0.19289016723632812, 'round level 9')
#     (0.0, 0, 0.16020435094833374, 'round level 8')
#     (-0.0, 0, -0.168232262134552, 'round level 7')
#     (0.0, 0, 0.2101428210735321, 'round level 6')
#     (-0.0, 0, -0.2593339681625366, 'round level 5')
#     (-0.0, 0, -0.03799914941191673, 'round level 4')
#     (-0.0, 0, -0.15310907363891602, 'round level 3')
#     (0.0, 0, 0.19185692071914673, 'round level 1')
