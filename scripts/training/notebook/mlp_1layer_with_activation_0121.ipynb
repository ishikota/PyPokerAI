# %% [markdown]
# # Train by 1-hidden layer NeuralNet
# - algorithm : Sarsa
# - feature : scaled scalar features
# - final_round : 1,2,5, 10, 50
# - number of unit on hidden layer : 128
# - **with relu activation function**

# %% [markdown]
# # 1 round
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_with_activation_0122/1round/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_with_activation_0122/1round/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/1round/1_round_3000_match_subplot_0121_20_22_20.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/1round/1_round_3000_match_histgram_0121_20_22_20.png" />|

# %% [markdown]
# ### A,KでALLIN

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['DA', 'HK']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', 0.09991195052862167), ('call', 0.10101770609617233), ('min_raise', 0.10567918419837952), ('double_raise', 0.10484238713979721), ('triple_raise', 0.10788467526435852), ('max_raise', 0.11280053853988647)]

# %% [markdown]
# ### FOLD

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 10000
#   - raise: [-1, -1]
# -- hole card --
#   - ['C5', 'S7']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 10075, side = [{'amount': 0, 'eligibles': ['uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 9950, 'paid': 10000, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 10000, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 1
#   => [('fold', 0.09980733692646027), ('call', 0.06883267313241959)]

# %% [markdown]
# # 2 round
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_with_activation_0122/2round/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_with_activation_0122/2round/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/2round/1_round_3000_match_subplot_0121_22_36_16.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/2round/1_round_3000_match_histgram_0121_22_36_16.png" />|

# %% [markdown]
# ### 100% FOLD

# %% [raw]
# -- Declare your action --
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['H9', 'D9']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 10000 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 2
#   => [('fold', 0.09850035607814789), ('call', 0.09162965416908264), ('min_raise', 0.07773293554782867), ('double_raise', 0.08804267644882202), ('triple_raise', 0.07770589739084244), ('max_raise', 0.061160434037446976)]

# %% [markdown]
# # 5 round
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_with_activation_0122/5round/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_with_activation_0122/5round/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/5round/1_round_3000_match_subplot_0121_22_41_51.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/5round/1_round_3000_match_histgram_0121_22_41_51.png" />|

# %% [markdown]
# ### とにかくCALL (100万episode後)

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['C3', 'SJ']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 225, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 9950
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9950
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'CALL', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 50, 'paid': 50}
#       - {'action': 'CALL', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'paid': 50}
# ======================================================================
# Agent took action [ call: 50 (call) ] at round 1
#   => [('fold', 0.07616224139928818), ('call', 0.08866731077432632), ('min_raise', 0.07660195976495743), ('double_raise', 0.07470528781414032), ('triple_raise', 0.07472743839025497), ('max_raise', 0.04357102885842323)]

# %% [markdown]
# ### 90万エピソード後

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['H4', 'D4']
# -- round state --
#   - dealer btn : cpu5
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 10050
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 10000
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9925
#     - 4 : cpu6 (uuid-6) => state : participating, stack : 10000 <= SB
#     - 5 : cpu7 (uuid-7) => state : participating, stack : 9950 <= BB
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu6 (uuid=uuid-6)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu7 (uuid=uuid-7)', 'amount': 50, 'add_amount': 25}
# ======================================================================
# Agent took action [ fold: 0 (fold) ] at round 4
#   => [('fold', 0.08839823305606842), ('call', 0.05795205757021904), ('min_raise', 0.08013847470283508), ('double_raise', 0.08166169375181198), ('triple_raise', 0.0862244963645935), ('max_raise', 0.06911949813365936)]

# %% [markdown]
# # 10 round
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_with_activation_0122/10round/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_with_activation_0122/10round/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/10round/10_round_3000_match_subplot_0122_11_36_50.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/10round/10_round_3000_match_subplot_0122_11_36_50.png" />|

# %% [markdown]
# ### A-K, Q-Qでdouble raise

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['SA', 'HK']
# -- round state --
#   - dealer btn : cpu9
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9925 <= SB
#     - 3 : cpu5 (uuid-5) => state : participating, stack : 9950 <= BB
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10075
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu5 (uuid=uuid-5)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 150 (double_raise) ] at round 2
#   => [('fold', 0.08749385923147202), ('call', 0.08740979433059692), ('min_raise', 0.07171597331762314), ('double_raise', 0.09187001734972), ('triple_raise', 0.09047286957502365), ('max_raise', 0.08859039843082428)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 9925]
# -- hole card --
#   - ['DQ', 'SQ']
# -- round state --
#   - dealer btn : cpu2
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9800 <= BB
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 16100
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 4125
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9925
#     - 6 : agent (uuid-0) => state : participating, stack : 9925 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10075
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000 <= SB
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu3 (uuid=uuid-3)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu8 (uuid=uuid-8)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 150 (double_raise) ] at round 9
#   => [('fold', 0.06605509668588638), ('call', 0.15209850668907166), ('min_raise', 0.12293905019760132), ('double_raise', 0.15596772730350494), ('triple_raise', 0.12985584139823914), ('max_raise', 0.13831926882266998)]

# %% [markdown]
# # 50 round
# ### Training Metrics
#
# | InitialValue | Loss |
# |------|------|
# | <img src="./resource/mlp_1layer_with_activation_0122/50round/initial_value_transition.png" width=600 /> | <img src="./resource/mlp_1layer_with_activation_0122/50round/loss_history.png" width=600 /> |
#
# ### RoundRobin
#
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/50round/50_round_3000_match_subplot_0122_18_47_06.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/50round/50_round_3000_match_histgram_0122_18_47_06.png" />|
#
# ### 50-round poker by 5-round no activation mlp
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/sample/50_round_3000_match_subplot_0122_17_30_02.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/sample/50_round_3000_match_histgram_0122_17_30_02.png" />|

# %% [markdown]
# ### 9-9 , K-T, A-TでALLIN

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 9925
#   - raise: [-1, -1]
# -- hole card --
#   - ['S9', 'H9']
# -- round state --
#   - dealer btn : cpu7
#   - street : preflop
#   - community card : []
#   - pot : main = 10000, side = [{'amount': 0, 'eligibles': ['uuid-7']}]
#   - players information
#     - 0 : cpu8 (uuid-8) => state : folded, stack : 75
#     - 1 : cpu9 (uuid-9) => state : folded, stack : 9975
#     - 2 : cpu4 (uuid-4) => state : folded, stack : 20075
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 0
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 9925
#     - 5 : cpu7 (uuid-7) => state : allin, stack : 0
#     - 6 : agent (uuid-0) => state : participating, stack : 9925 <= SB, CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 9950 <= BB
#     - 8 : cpu2 (uuid-2) => state : folded, stack : 20075
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'agent (uuid=uuid-0)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu1 (uuid=uuid-1)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu2 (uuid=uuid-2)'}
#       - {'action': 'FOLD', 'player': 'cpu3 (uuid=uuid-3)'}
#       - {'action': 'FOLD', 'player': 'cpu8 (uuid=uuid-8)'}
#       - {'action': 'FOLD', 'player': 'cpu9 (uuid=uuid-9)'}
#       - {'action': 'FOLD', 'player': 'cpu4 (uuid=uuid-4)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'add_amount': 9875, 'paid': 9925, 'player': 'cpu7 (uuid=uuid-7)', 'amount': 9925, 'action': 'RAISE'}
# ======================================================================
# Agent took action [ call: 9925 (call) ] at round 6
#   => [('fold', 0.09376260638237), ('call', 0.09851883351802826)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 10000]
# -- hole card --
#   - ['DK', 'DT']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 10000
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9975 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9950 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10000
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 10000
#     - 6 : agent (uuid-0) => state : participating, stack : 10000 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10000
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : participating, stack : 10000
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 10000 (max_raise) ] at round 1
#   => [('fold', 0.10793861746788025), ('call', 0.07291363179683685), ('min_raise', 0.09556841850280762), ('double_raise', 0.09972155094146729), ('triple_raise', 0.060908496379852295), ('max_raise', 0.13408082723617554)]

# %% [raw]
# ======================================================================
# -- valid actions --
#   - fold
#   - call: 50
#   - raise: [75, 20075]
# -- hole card --
#   - ['HA', 'HT']
# -- round state --
#   - dealer btn : cpu8
#   - street : preflop
#   - community card : []
#   - pot : main = 75, side = []
#   - players information
#     - 0 : cpu8 (uuid-8) => state : participating, stack : 9925
#     - 1 : cpu9 (uuid-9) => state : participating, stack : 9900 <= SB
#     - 2 : cpu4 (uuid-4) => state : participating, stack : 9875 <= BB
#     - 3 : cpu5 (uuid-5) => state : folded, stack : 10150
#     - 4 : cpu6 (uuid-6) => state : folded, stack : 10000
#     - 5 : cpu7 (uuid-7) => state : folded, stack : 9925
#     - 6 : agent (uuid-0) => state : participating, stack : 20075 <= CURRENT
#     - 7 : cpu1 (uuid-1) => state : participating, stack : 10075
#     - 8 : cpu2 (uuid-2) => state : participating, stack : 10000
#     - 9 : cpu3 (uuid-3) => state : folded, stack : 0
#   - action histories
#     - preflop
#       - {'action': 'SMALLBLIND', 'player': 'cpu9 (uuid=uuid-9)', 'amount': 25, 'add_amount': 25}
#       - {'action': 'BIGBLIND', 'player': 'cpu4 (uuid=uuid-4)', 'amount': 50, 'add_amount': 25}
#       - {'action': 'FOLD', 'player': 'cpu5 (uuid=uuid-5)'}
#       - {'action': 'FOLD', 'player': 'cpu6 (uuid=uuid-6)'}
#       - {'action': 'FOLD', 'player': 'cpu7 (uuid=uuid-7)'}
# ======================================================================
# Agent took action [ raise: 20075 (max_raise) ] at round 10
#   => [('fold', 0.1913837492465973), ('call', 0.1911514401435852), ('min_raise', 0.19002078473567963), ('double_raise', 0.21658504009246826), ('triple_raise', 0.15990716218948364), ('max_raise', 0.2640535533428192)]

# %% [markdown]
# # RoundRobin with no-activation result (trained by 5-round poker)
# - player1~4: with relu-activation 1-layer MLP trained by N-round poker
# - player5~8:  no-activation 1-layer MLP trained by 5-round poker
# - player9,10: random player
#
# ## 1-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/1round/1_round_3000_match_subplot_0122_19_40_39.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/1round/1_round_3000_match_histgram_0122_19_40_39.png" />|
#
# ## 2-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/2round/2_round_3000_match_subplot_0122_20_48_22.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/2round/2_round_3000_match_histgram_0122_20_48_22.png" />|
#
# ## 5-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/5round/5_round_3000_match_subplot_0122_21_06_11.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/5round/5_round_3000_match_histgram_0122_21_06_11.png" />|
#
# ## 10-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/10round/10_round_3000_match_subplot_0122_20_12_04.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/10round/10_round_3000_match_histgram_0122_20_12_04.png" />|
#
# ## 50-round
# | plot | hist |
# |------|------|
# |  <img src="./resource/mlp_1layer_with_activation_0122/50round/50_round_3000_match_subplot_0122_20_49_13.png"/> | <img src="./resource/mlp_1layer_with_activation_0122/50round/50_round_3000_match_subplot_0122_20_49_13.png" />|
